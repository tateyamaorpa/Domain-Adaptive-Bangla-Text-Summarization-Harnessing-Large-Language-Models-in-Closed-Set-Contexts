# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset I

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model

df = pd.read_csv('/content/drive/MyDrive/Colab/updated_ittefaq_international.csv')
df.head()
# Out:
#         category                                              title  \
# 0  international      শনিবার একই সারিতে থাকবে পৃথিবী-সূর্য-বৃহস্পতি
# 1  international  ক্যালিফোর্নিয়ায় ৭.০ মাত্রার ভূমিকম্প, সুনামি ...
# 2  international  সিরিয়ায় বিদ্রোহীদের পেছনে যুক্তরাষ্ট্র-যুক্ত...
# 3  international  ২১০০ সালের মধ্যে পৃথিবীর এক তৃতীয়াংশ প্রজাতি ...
# 4  international    পাকিস্তানে অসহযোগ আন্দোলনের ডাক দিলেন ইমরান খান
#
#                                                 text  \
# 0  আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং...
# 1  যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2  সিরিয়ায় বিদ্রোহীদের সমর্থনের পেছনে যুক্তরাষ্...
# 3  জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4  পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...
#
#                                              summary
# 0  আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং...
# 1  যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2  সিরিয়ায় বিদ্রোহীদের সমর্থনের পেছনে যুক্তরাষ্...
# 3  জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4  পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...

# %%
df
# Out:
#           category                                              title  \
# 0    international      শনিবার একই সারিতে থাকবে পৃথিবী-সূর্য-বৃহস্পতি
# 1    international  ক্যালিফোর্নিয়ায় ৭.০ মাত্রার ভূমিকম্প, সুনামি ...
# 2    international  সিরিয়ায় বিদ্রোহীদের পেছনে যুক্তরাষ্ট্র-যুক্ত...
# 3    international  ২১০০ সালের মধ্যে পৃথিবীর এক তৃতীয়াংশ প্রজাতি ...
# 4    international    পাকিস্তানে অসহযোগ আন্দোলনের ডাক দিলেন ইমরান খান
# ..             ...                                                ...
# 495  international  স্বামী-স্ত্রীর মধ্যে ঝগড়া, একে-অপরের আঘাতে প্র...
# 496  international  গাজা-লেবানন যুদ্ধ: একত্রিত হচ্ছেন আরব ও মুসলিম...
# 497  international  দুই হাজার ৬৪৫ লিটার বুকের দুধ দান করে বিশ্বরেক...
# 498  international  সৌদি আরবে এক সপ্তাহে ২০ হাজারের বেশি প্রবাসী গ...
# 499  international  সর্বকালের সর্বোচ্চ রেকর্ড, ৮০ হাজার ডলারে বিটক...
#
#                                                   text  \
# 0    আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং...
# 1    যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2    সিরিয়ায় বিদ্রোহীদের সমর্থনের পেছনে যুক্তরাষ্...
# 3    জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4    পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...
# ..                                                 ...
# 495  ঘরের মধ্যে ঝগড়া বাঁধে দুজনের মধ্যে। সেটি রূপ ন...
# 496  গাজা এবং লেবাননে ইসরাইলের চলমান আগ্রাসনের প্রে...
# 497  অভাবী শিশুদের জন্য বুকের দুধ দান করে বিশ্ব রেক...
# 498  গত এক সপ্তাহে সৌদি আরবজুড়ে ২০ হাজারেরও বেশি অ...
# 499  শীর্ষস্থানীয় ক্রিপ্টোকারেন্সি বিটকয়েন ফের (ব...
#
#                                                summary
# 0    আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং...
# 1    যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2    সিরিয়ায় বিদ্রোহীদের সমর্থনের পেছনে যুক্তরাষ্...
# 3    জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4    পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...
# ..                                                 ...
# 495  ঘরের মধ্যে ঝগড়া বাঁধে দুজনের মধ্যে। সেটি রূপ ন...
# 496  গাজা এবং লেবাননে ইসরাইলের চলমান আগ্রাসনের প্রে...
# 497  অভাবী শিশুদের জন্য বুকের দুধ দান করে বিশ্ব রেক...
# 498  গত এক সপ্তাহে সৌদি আরবজুড়ে ২০ হাজারেরও বেশি অ...
# 499  শীর্ষস্থানীয় ক্রিপ্টোকারেন্সি বিটকয়েন ফের (ব...
#
# [500 rows x 4 columns]

# %% [markdown]
# # Install and Imports

# %%
# !pip install sentencepiece
# !pip install transformers
# !pip install git+https://github.com/csebuetnlp/normalizer

import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

from normalizer import normalize # pip install git+https://github.com/csebuetnlp/normalizer


from transformers import XLMProphetNetForConditionalGeneration, XLMProphetNetTokenizer


from transformers import MBartForConditionalGeneration, AutoModelForSeq2SeqLM
from transformers import AlbertTokenizer, AutoTokenizer
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-ebuy35cq
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-ebuy35cq
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from normalizer==0.0.1) (2024.9.11)
# Collecting emoji==1.4.2 (from normalizer==0.0.1)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy==6.0.3 (from normalizer==0.0.1)
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.13)
# Building wheels for collected packages: normalizer, emoji, ftfy
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6860 sha256=e4a613cda628ee5ce6c22cb5d752b372b3db309a478414159c40285e849ca226
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rmdhqpx6/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186455 sha256=025d484ec969d51b3fb63cc1e3a4711a698f791653be7a66e4100e781912ed04
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41931 sha256=6c2fbe68e369a51288bd8d8981246cae47059108f6927ec926adb6cc32dce0b1
#   Stored in directory: /root/.cache/pip/wheels/92/8e/16/c1e4d4d65685d71085e4e27b44d6ed880b0559474c9ee4ff66
# Successfully built normalizer emoji ftfy
# Installing collected packages: emoji, ftfy, normalizer
# Successfully installed emoji-1.4.2 ftfy-6.0.3 normalizer-0.0.1

# %%
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ### Functions

# %%
def cleanText(text2clean):
    empty_string = ""

    space = chr(32)
    flag  = 0

    for i in range(len(text2clean)):
        if text2clean[i] != "'" and text2clean[i] != "\n":
            if text2clean[i] == space and flag == 0:
                flag = 1
                empty_string = empty_string + text2clean[i]
            elif text2clean[i] != space:
                empty_string = empty_string + text2clean[i]
                flag = 0
    return empty_string

# %% [markdown]
# # Model Loading

# %% [markdown]
# ### Model Setup

# %%
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

tokenizer_path = "/content/drive/MyDrive/Colab/mT5_Tokenizer_XLSum"
model_path = "/content/drive/MyDrive/Colab/mT5_Model_XLSum"

# Step 4: Load the tokenizer and model from the specified paths
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=250112, bias=False)
# )

# %% [markdown]
# ### Run dataset over the Model

# %%
df.columns
# Out:
# Index(['category', 'title', 'text', 'summary'], dtype='object')

# %%
rows = df.shape[0]
rows
# Out:
# 500

# %%
# Create empty DataFrame without the "title" column
genDf = pd.DataFrame(columns=["text", "givenSummary", "mT5_Test_XLSum"])

# Load over the dataset
for i in range(rows):
        article_text = normalize(df['text'][i])

        # Tokenize the input text
        input_ids = tokenizer(
            [WHITESPACE_HANDLER(article_text)],
            return_tensors="pt",
            padding="max_length",
            max_length=512,
            truncation=True
        )["input_ids"]

        # Generate the summary
        output_ids = model.generate(
            input_ids=input_ids.cuda(),
            max_length=400,
            min_length=64,
            no_repeat_ngram_size=2,
            num_beams=4
        )[0]

        # Decode the generated summary
        summary = tokenizer.decode(
            output_ids,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=False
        )

        # Add the text, given summary, and generated summary to the DataFrame
        genDf.loc[i] = [df['text'][i], df['summary'][i], summary]

        # Print the generated summary for verification
        print(i, '  ', summary)

# Save the DataFrame to CSV
genDf.to_csv('/content/drive/My Drive/Colab/international_zeroshot.csv')
# Out:
# 0    পৃথিবী, সূর্য এবং বৃহস্পতি গ্রহ একই সরলরেখায় অবস্থান করবে বলে জানিয়েছে মার্কিন মহাজাগতিক সংস্থা 'ফোর্বস ম্যাগাজিন'। এই ঘটনা পর্যবেক্ষণের জন্য মানুষের কৌতুহল বাড়ছে।
# 1    যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অংশে শক্তিশালী ভূমিকম্প আঘাত হেনেছে। এর ফলে সুনামি সতর্কতা জারি করেছে দেশটির জাতীয় আবহাওয়া পরিষেবা। এখন পর্যন্ত কোনো হতাহতের খবর পাওয়া যায়নি।
# 2    সিরিয়ায় আল-কায়েদা সন্ত্রাসী গোষ্ঠীর সমর্থনের পেছনে যুক্তরাষ্ট্র ও নিউ ইয়র্ক জড়িত থাকতে পারে বলে জানিয়েছে রাশিয়া। এই পরিস্থিতিকে ঘোলাটে করে তুলতে আগ্রহী ইসরায়েল ও আমেরিকা।
# 3    জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্রিনহাউস গ্যাস নির্গমন অব্যাহত থাকলে চলতি শতাব্দীর শেষ নাগাদ বিশ্বের প্রায় এক-তৃতীয়াংশ প্রজাতি বিলুপ্তির ঝুঁকিতে পড়বে।
# 4    পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরান খান ১৩ ডিসেম্বর থেকে অসহযোগ আন্দোলনের ডাক দিয়েছেন। তিনি বলেছেন, যদি এই দাবি মানা না হয়, তবে ১৪ ডিসের মধ্যে একটি অ সহযোগ আন্দোলন শুরু হবে।
# 5    ভারতের রাজধানী দিল্লিতে ফসলের ন্যায্য দামের দাবিতে পাঞ্জাব রাজ্য থেকে দিল্লি অভিমুখে কৃষকদের পদযাত্রা ছত্রভঙ্গ করে দিয়েছে পুলিশ। বিক্ষোভকারীদের মধ্যে সুরক্ষা বাহিনী পিছু হটে।
# 6    রাশিয়ার পররাষ্ট্রমন্ত্রী সের্গেই ল্যাভরভ বলেছেন, পশ্চিমারা বিশ্বের যে কোনো অঞ্চলের ওপর তাদের আধিপত্য বজায় রাখার জন্য লড়াই করছে, তা ঠেকাতে মস্কো 'সব উপায়' ব্যবহার করতে প্রস্তুত বলে হুঁশিয়ারি দিয়েছেন।
# 7    বিশ্বব্যাংক আফ্রিকার ৭৮টি দেশকে নতুন করে প্রায় ১০০ বিলিয়ন ডলারের ঋণ ও অনুদান দেওয়ার ঘোষণা দিয়েছে। এই সহায়তার মাধ্যমে অর্থনীতি স্থিতিশীল এবং কর্মসংস্থান তৈরি করতে সাহায্য করবে ব্যাংক।
# 8    সিরিয়ার বিদ্রোহীদের বিরুদ্ধে লড়াইয়ে উত্তপ্ত পরিস্থিতির মধ্যে সিরিয়া সরকারকে সহায়তার প্রস্তাব দিয়েছে লেবাননভিত্তিক সশস্ত্র সংগঠন হিজবুল্লাহ। যুদ্ধবিরতির সময় ইরান সমর্থিত গোষ্ঠীটি এই প্রকল্পের লক্ষ্য ব্যর্থ করবে।
# 9    বাংলাদেশে হিন্দুদের কথিত আটকের প্রতিবাদে ধর্মীয় বিদ্বেষ ছড়ানোর অভিযোগে ভারতের অন্যতম প্রধান রাজনৈতিক দল বিজেপির একজন নেতার বিরুদ্ধে মামলা দায়ের করেছে স্থানীয় পুলিশের কর্মকর্তারা।
# 10    ভারতে কংগ্রেসের সংসদ সদস্য অভিষেক মনু সিংভির আসন থেকে ৫০ হাজার রুপির একটি বান্ডেল উদ্ধার করা হয়েছে বলে দাবি করেছেন পার্লামেন্টের উচ্চকক্ষ রাজ্যসভার চেয়ারপার্সন জগদীপ ধনখড়।
# 11    যেকোনো উপায়ে নিজ দেশকে রক্ষা করতে রাশিয়া প্রস্তুত ছিল বলে মন্তব্য করেছেন রুশ পররাষ্ট্রমন্ত্রী সের্গেই ল্যাভরভ। যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প এবং তার মিত্রদের মধ্যে ইউক্রেন যুদ্ধের বিষয়ে তিনি সতর্ক করে দিয়েছেন
# 12    বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ও ইসকনের সাবেক নেতা চিন্ময় কৃষ্ণ দাস ব্রহ্মচারীর গ্রেপ্তার ইস্যুতে ক্ষোভ প্রকাশ করেছেন ভারতের ক্ষমতাসীন বিজেপির নেত্রী হেমা মালিনী।
# 13    চীনে যুক্তরাষ্ট্রের রাষ্ট্রদূত হিসেবে মার্কিন সাবেক সিনেটর ডেভিড পার্ডিউকে নিয়োগ দিয়েছেন নব-নির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। এর আগে থেকেই তিনি এই পদক্ষেপ নিয়েছেন।
# 14    প্রেসিডেন্ট ইউন সুক ইওল যদি ক্ষমতায় থাকেন, তাহলে দক্ষিণ কোরীয়রা বড় ধরনের বিপদের মুখে পড়তে পারে বলে সতর্ক করেছেন তার দল পিপলস পাওয়ার পার্টি-এর প্রধান।
# 15    যুক্তরাজ্যের সশস্ত্র বাহিনীর প্রধান অ্যাডমিরাল টনি রাডাকিন বলেছেন, বিশ্ব বর্তমানে তৃতীয় পারমাণবিক যুগের দ্বারপ্রান্তে রয়েছে বলে সতর্ক করেছেন তিনি। সেইসঙ্গে চীন, রাশিয়া, ইরান এবং উত্তর কোরিয়ার বেপরোয়া হুমকি পা
# 16    মার্কিন যুক্তরাষ্ট্রের নতুন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প তার দেশে অনিয়মিত অবস্থানরত কিউবাসহ বিভিন্ন দেশ থেকে আসা অভিবাসীদের ঢালাওভাবে বিতাড়নের যে পরিকল্পনা নিয়েছেন সেটি বাস্তবসম্মত নয়।
# 17    ফ্রান্সের প্রধানমন্ত্রী মিশেল বার্নিয়ের অনাস্থা ভোটে হেরে যাওয়ায় দেশটির সরকার ভেঙে পড়েছে। রাজনৈতিক সংকটে টালমাটালের পরিস্থিতি তৈরি হয়েছে। এরইমধ্যে প্রেসিডেন্ট ইমানুয়েল ম্যাক্রোঁ বলেছেন, তিনি পদত্যাগ করবেন না এব
# 18    যুক্তরাষ্ট্রের ক্যালিফোর্নিয়ার উত্তর উপকূলে ৭ মাত্রার শক্তিশালী ভূমিকম্প আঘাত হেনেছে। এরপর এখন পর্যন্ত কোনো হতাহত বা বড় ধরনের ক্ষয়ক্ষতির খবর পাওয়া গেছে না।
# 19    সিরিয়ার দ্বিতীয় বৃহত্তম শহর আলেপ্পো দখলের পর এবার সিিয়ার আরেক গুরুত্বপূর্ণ শহরা হামা নিয়ন্ত্রণে নিয়েছে বিদ্রোহীরা। এরপর গতকাল থেকে লড়াই শুরু করেছে বিরোধী ইসলামি গোষ্ঠী এইচটিএস।
# 20    চীন তাইওয়ান অঞ্চলে সেমিকন্ডাক্টর বা চিপ বিক্রির ওপর নতুন করে নিষেধাজ্ঞা আরোপ করেছে। যুক্তরাষ্ট্রের মুখপাত্র লিন চিয়ান বলেছেন, 'তাইওয়ানের স্বাধীনতা' প্রচেষ্টার মূল অংশ।
# 21    সান্তা ক্লজ নামে পরিচিত সেন্ট নিকোলাস অব মায়রার মুখমণ্ডলের একটি ছবি প্রকাশ করেছেন বিজ্ঞানীরা। এই প্রথমবারের মতো সেই ছবির কাঠামো পুনর্গঠন করা হয়েছে। এটি নিয়ে নতুন করে আলোচনা শুরু হয়েছে ইসরায়েলে।
# 22    ভারতের উত্তরপূর্বাঞ্চলীয় রাজ্য ত্রিপুরার হোটেল ও রেস্টুরেন্টে বাংলাদেশি নাগরিকদের জায়গা দেওয়া হবে না বলে ঘোষণা দিয়েছে দেশটির কট্টর হিন্দুত্ববাদী বিভিন্ন সংগঠনের কর্মী-সমর্থকরা।
# 23    ভারতীয় পশ্চিমবঙ্গের শিলিগুড়িতে বাংলাদেশি পর্যটকদের অভাবে অর্থনৈতিক সংকট চরমে পৌঁছেছে। এই পরিস্থিতি চলতে থাকলে অনেকের জীবিকা হুমকির মুখে পড়বে বলে আশঙ্কা করা হচ্ছে।
# 24    রাশিয়া ও পাকিস্তান আগামী বছর প্রথমবারের মতো সরাসরি ট্রেন চালু করবে বলে জানিয়েছে দেশটির জ্বালানি মন্ত্রী। এর আগে ইসলামাবাদ-মস্কো সমঝোতা স্মারক সই করা হয়েছিল ।
# 25    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প ২০ জানুয়ারি অভিষেকের আগেই গাজায় ইসরায়েলের যুদ্ধবিরতি চান বলে জানিয়েছেন কাতারের প্রধানমন্ত্রী। তিনি বলেছেন, যতটা সম্ভব এই প্রক্রিয়া রক্ষার জন্য তার সর্বোচ্চ চেষ্টা করে যাচ্ছেন।
# 26    সিরিয়ার রাজধানী দামেস্ক ও প্রাচীন শহর আলেপ্পোর মধ্যবর্তী কৌশলগত গুরুত্বপূর্ণ অঞ্চল 'হামা'র কেন্দ্রস্থল নিয়ন্ত্রণে নিয়েছে সরকারবিরোধী সশস্ত্র গোষ্ঠীগুলো। এ ঘোষণা দেয়া হয়েছে।
# 27    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের স্ত্রী বুশরা বিবির বিরুদ্ধে দুর্নীতি মামলায় গ্রেপ্তারি পরোয়ানা জারি করেছে দেশটির একটি আদালত। তাকে যাবজ্জীবন কারাদণ্ড দেয়া হবে বলে জানিয়েছে সরকার।
# 28    ফ্রান্সে ৬০ বছরেরও বেশি সময়ের মধ্যে প্রথমবারের মতো অনাস্থা ভোটের মাধ্যমে ক্ষমতাচ্যুত হলেন প্রধানমন্ত্রী মিশেল বার্নিয়ার। কিন্তু তার পদত্যাগ ঘোষণা করেছেন প্রেসিডেন্ট এমানুয়েল মাক্রোঁর।
# 29    বরফে ঢেকে থাকা আর্কটিক মহাসাগর ২০২৭ সালের মধ্যে প্রথম একেবারে 'বরফমুক্ত' দিন দেখতে পারে বলে নতুন একটি গবেষণায় উঠে এসেছে। বিজ্ঞানীরা বলছেন, আগামী তিন থেকে ছয় বছর এই গ্রহের জন্য অশুভ ম
# 30    সৌদি আরবে চলতি বছর রেকর্ড ৩০০ জনেরও বেশি লোকের মৃত্যুদণ্ড কার্যকর করা হয়েছে। মানবাধিকার সংস্থাগুলো বলছে, এই সংখ্যা 'রকেট গতির' সঙ্গে তালিকাভুক্ত।
# 31    মার্কিন প্রেসিডেন্ট নির্বাচনে ডোনাল্ড ট্রাম্পের জয়ের পর থেকে হু হু করে বেড়েই চলছে শীর্ষস্থানীয় ক্রিপ্টোকারেন্সি বিটকয়েনের (বিটিসি) মান। এবারের রেকর্ড ভেঙে ৭৬ হাজার ডলারের মাইলফলক স্পর্শ করেছে বিটয়েন।
# 32    ভারতের তামিলনাড়ু রাজ্যের রাজধানী চেন্নাইয়ে বাংলাদেশবিরোধী বিক্ষোভ থেকে ১০০ নারীসহ ৫০০ জনকে গ্রেপ্তার করেছে পুলিশ। এদের মধ্যে বেশ কয়েকজন হিন্দুত্ববাদী সংগঠনের নেতা রয়েছেন।
# 33    দক্ষিণ আফ্রিকার প্রথম কৃষ্ণাঙ্গ প্রেসিডেন্ট নেলসন ম্যান্ডেলার ১১তম মৃত্যুবার্ষিকী আজ। তিনি ছিলেন বিশ্বের সবচেয়ে জনপ্রিয় এবং আকর্ষণীয় রাষ্ট্রনায়কদের একজন, যিনি বর্ণবাদবিরোধী আন্দোলনের পুরোধা।
# 34    তাইওয়ান অঞ্চলের কাছে অস্ত্র বিক্রির কারণে যুক্তরাষ্ট্রের ১৩টি প্রতিরক্ষা কোম্পানি ও ছয় জন নির্বাহীর ওপর নিষেধাজ্ঞা আরোপ করেছে চীন। এই পদক্ষেপকে কেন্দ্র করে চীনের পররাষ্ট্র মন্ত্রণালয় বলছে, এ ধরনের নিষিদ্ধতা কার্যকর হচ্ছে।
# 35    অ্যামনেস্টি ইন্টারন্যাশনাল বলছে, গাজায় ফিলিস্তিনিদের ওপর 'গণহত্যা' চালানোর জন্য ইসরায়েলকে দায়ী করেছে। গত বছর যুদ্ধ শুরু হওয়ার পর থেকে গাজা নিয়ে ইসরায়েলে এই হামলা চালাতে হয়েছে।
# 36    দক্ষিণ কোরিয়ায় চলমান উত্তেজনার মধ্যেই পদত্যাগের ঘোষণা দিয়েছেন দেশটির প্রতিরক্ষামন্ত্রী কিম ইয়ং-হিউন। কিন্তু বিরোধীদের অভিশংসনের প্রক্রিয়া শুরু করেছে শাসক পিপল পাওয়ার পার্টি।
# 37    ভারতের আসাম রাজ্যে হোটেল, রেস্তোরাঁ ও প্রকাশ্য স্থানে গরুর মাংস খাওয়ার ওপর নিষেধাজ্ঞা আরোপ করা হয়েছে। এর মধ্যে কোনো আনুষ্ঠানিক বা সরকারি অনুষ্ঠান বা হোটেলে গরু খাওয়া যাবে না।
# 38    ফ্রান্সের প্রধানমন্ত্রী মিশেল বার্নিয়ের ক্ষমতাচ্যুত করার প্রস্তাবের বিরুদ্ধে সংসদে অনাস্থা ভোটে হেরে যাওয়ায় দেশটির সরকার ভেঙে পড়েছে। বিবিসির প্রতিবেদনে বলা হচ্ছে, এই ঘটনা ঘটেছে গত কয়েক দশক ধরে।
# 39    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প কানাডার প্রধানমন্ত্রী জাস্টিন ট্রুডোর বিরুদ্ধে শুল্ক আরোপের হুঁশিয়ারি দিয়েছেন। তবে তিনি এমন মন্তব্য করলেও কানারায় কৌতুহল দেখা দিয়েছে।
# 40    ভিয়েতনামে দক্ষিণাঞ্চলে প্রশিক্ষণ চলাকালে দৃশ্যত দুর্ঘটনাজনিত বিস্ফোরণে অন্তত ১২ সেনা নিহত হয়েছেন। এর মধ্যে বেশ কয়েকজন টিমমেট নিখোঁজ রয়েছেন।
# 41    ভারতে চিকিৎসা নিতে আসা বাংলাদেশি রোগীদের বয়কটের সিদ্ধান্ত থেকে সরে এসেছে দুই দেশের মেডিকেল অ্যাসোসিয়েশন ও বেঙ্গল চেম্বার অব কমার্স। এর মধ্যে ভারত-বাংলাদেশ সম্পর্কের উন্নয়নে বড় ধরনের প্রভাব পড়তে হবে বলে মনে করেছে তারা
# 42    শান্তিতে নোবেলজয়ী ইরানের কারাবন্দীর মানবাধিকারকর্মী নার্গিস মোহাম্মদিকে সাময়িক সময়ের জন্য মুক্তি দেওয়া হয়েছে। গত ২১ দিনের কারাদণ্ড স্থগিত হওয়ার পর তিনি এখন চিকিৎসা নিচ্ছেন।
# 43    যুক্তরাষ্ট্রের ম্যানহাটানে বন্দুকধারীর গুলিতে নিহত বিমা প্রতিষ্ঠান 'ইউনাইটেড হেলথ কেয়ার'-এর প্রধান ব্রায়ান থম্পসনের স্ত্রী দাবি করেছেন, কিছু লোক তাকে হত্যার হুমকি দিয়েছিল।
# 44    রাশিয়ার আক্রমণ শুরু হওয়ার পর এবার ন্যাটো নামে একটি আন্তর্জাতিক ত্রাণ সংস্থার সদস্যপদ পেতে চাইছে ইউক্রেনের প্রেসিডেন্ট ভলোদিমির জেলেনস্কি। তাদের দাবি, ন্যাটোর যুক্ত হলে সাহায্যের গ্যারান্টি পাওয়া সম্ভব।
# 45    আফ্রিকার দেশ নামিবিয়ায় ক্ষমতাসীন দলের প্রার্থী নেতুম্বো নন্দী-এনদাইতওয়াহকে বিজয়ী ঘোষণা করা হয়েছে। তিনি দেশটির নতুন রাষ্ট্রপতি হিসেবে দায়িত্ব পালন করছেন। আন্তর্জাতিক গণমাধ্যমে এই খবর পাওয়া যাচ্ছে।
# 46    ভারতের উত্তরাঞ্চলীয় অমৃতসরের স্বর্ণ মন্দিরে বন্দুকধারীর গুলি চালানোর ঘটনায় একজন পুলিশ কর্মকর্তাকে গ্রেপ্তার করা হয়েছে। হামলাকারী ছিলেন পাঞ্জাবের প্রাক্তন উপ-মুখ্যমন্ত্রী।
# 47    দক্ষিণ কোরিয়াতে বিরোধীদের 'দমন করতে' আকস্মিক সামরিক আইন জারির ঘটনায় উত্তপ্ত হয়ে উঠেছে দেশটির নাগরিকরা। এর ফলে দেশটিতে তীব্র উত্তেজনা তৈরি হয়েছিল সরকারের বিরুদ্ধে।
# 48    রাশিয়ার প্রেসিডেন্ট ভ্লাদিমির পুতিন দেশটির জাতীয় প্রতিরক্ষার জন্য রেকর্ড পরিমাণ বাজেট অনুমোদন করেছেন। এ বছর সরকারি ব্যয়ের ৩২.৫ শতাংশের চেয়ে প্রায় ১৩ বিলিয়ন ডলার বরাদ্দ করা হয়েছে।
# 49    ভারতের উত্তরপ্রদেশের সম্ভলে একটি শাহী জামে মসজিদকে ঘিরে ব্যাপক উত্তেজনা দেখা দিয়েছে। সেখানে চার মুসলিম তরুণকে গুলি করে হত্যা করে পুলিশ। এমন পরিস্থিতির মধ্যে বিরোধী দলনেতা রাহুল গান্ধী ও তার বোন প্রিয়ঙ্ক
# 50    ভারতের উত্তর-পূর্বাঞ্চলীয় রাজ্য তেলেঙ্গানায় শক্তিশালী এক ভূমিকম্পে অন্তত ৫.৩ মাত্রার কম্পন হয়েছে। স্থানীয়দের মধ্যে আতঙ্ক ছড়িয়ে পড়েছে বলে খবর পাওয়া যাচ্ছে বলে।
# 51    ন্যাটো সামরিক জোটের মহাসচিব মার্ক রুট বলেছেন, রাশিয়ার সঙ্গে যে কোনো শান্তি আলোচনায় আরও অস্ত্র পাঠিয়ে ইউক্রেনে যোগ দিতে হলে তা 'উত্তপ্ত পর্যায়ের' অবসান ঘটাতে পারে।
# 52    ভারত ও বাংলাদেশের মধ্যে কূটনৈতিক সম্পর্ক টানাপোড়েন করার পর বাংলাদেশি পর্যটকদের জন্য সাময়িকভাবে হোটেল ভাড়া না দেওয়ার সিদ্ধান্তের বিরুদ্ধে তীব্র সমালোচনা তৈরি হচ্ছে।
# 53    দক্ষিণ কোরিয়ায় সামরিক আইন জারি করার ঘটনাকে কেন্দ্র করে দেশটির প্রেসিডেন্ট ইউন সুক-ইওলকে অভিশংসনের আহ্বান জানিয়েছেন দেশটি থেকে বিরোধীদের একটি জোট। তারা আজ পার্লামেন্টের মনোনিবেশ করছেন।
# 54    দক্ষিণ আফ্রিকার দেশ নামিবিয়ার ক্ষমতাসীন এসডব্লিউএপিও দলের নেত্রী নেতুম্বো নান্দি নাদাইতওয়া দেশটির প্রেসিডেন্ট হিসেবে নির্বাচিত হয়েছেন। দলটির নেতা ছিলেন সাবেক পররাষ্ট্রমন্ত্রী পান্দুলেনি ইতুলা।
# 55    বাংলাদেশে সংখ্যালঘুদের নিরাপত্তা দেওয়ার ক্ষেত্রে অন্তর্বর্তী সরকারের কথিত 'নিষ্ক্রিয়তা'র অভিযোগের ব্যাপারে যুক্তরাষ্ট্র বাংলাদেশসহ সকল দেশকে মতপ্রকাশের স্বাধীনতা হিসেবে সমর্থন করেছে।
# 56    প্রতিবেশী দেশ কানাডাকে যুক্তরাষ্ট্রের ৫১তম অঙ্গরাজ্য হয়ে যাওয়ার প্রস্তাব দিয়েছেন নবনির্বাচিত মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। এর মধ্যে একটি বড় অংশের শুল্ক বাণিজ্য ও অভিবাসন ইস্যুতে।
# 57    ভারতের অর্থনীতি খারাপ সময়ের ভেতর দিয়ে যাচ্ছে। গত ১৮ মাসের মধ্যে প্রবৃদ্ধি ৬ শতাংশের বেশি হবে বলে পূর্বাভাস ছিল। আর এর ফলে রুপির মান ইতিহাসের সর্বনিম্ন স্তরে নেমে গেছে।
# 58    বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র চিন্ময় কৃষ্ণ দাসকে গ্রেপ্তারের বিষয়ে যুক্তরাষ্ট্রের পররাষ্ট্র দপ্তর বলেছে, যেকোনো ধরনের ক্র্যাকডাউন না হলেও সকল দেশের সরকারকে আইনের শাসনকে সম্মান করতে হবে।
# 59    বাংলাদেশে সংখ্যালঘুদের ওপর হামলার অভিযোগ নিয়ে সরব হয়েছেন ব্রিটিশ সাংসদরা। যুক্তরাজ্যের ফরেন, কমনওয়েলথ ও ডেভেলপমেন্ট অফিস এবং ইংল্যান্ডের পররাষ্ট্রমন্ত্রীরা বলছেন, হিন্দু সম্প্রদায়কে সহযোগিতা করার প্রয়োজনীয়তা র
# 60    বাংলাদেশে সংখ্যালঘুদের ওপর 'দমনপীড়ন' এবং গ্রেপ্তারের ঘটনায় উদ্বেগ প্রকাশ করেছেন ভারতের সাবেক কেন্দ্রীয় মন্ত্রী ও বিজেপি নেতা চিন্ময় কৃষ্ণ দাসের মুক্তি দাবি।
# 61    দক্ষিণ কোরিয়ায় জরুরি অবস্থা ঘোষণা করে সামরিক আইন জারি করেছেন দেশটির প্রেসিডেন্ট ইউন সুক-ইওল। বিরোধী দলকে 'রাষ্ট্রবিরোধী' হিসেবে অভিহিত করে তিনি এই পদক্ষেপ নিয়েছেন।
# 62    ভারতের লোকসভাতেও বাংলাদেশে শান্তিরক্ষী বাহিনী পাঠানোর জন্য জাতিসংঘকে অনুরোধ জানানোর প্রস্তাব উঠেছে। বিধানসভার পরে এবার  ভারতীয় সংসদে বাংলাদেশের সাম্প্রতিক পরিস্থিতি সম্পর্কে সরকারের অবহিত করা হচ্ছে।
# 63    বাংলাদেশে জাতিসংঘ শান্তিরক্ষী পাঠানোর প্রস্তাব দিয়ে বিতর্কের মুখে পড়েছেন ভারতের পশ্চিমবঙ্গের মুখ্যমন্ত্রী মমতা বন্দ্যোপাধ্যায়। তিনি বলেছেন, বাংলাদেশের অভ্যন্তরীণ বিষয়ে নিজেই অনুরোধ জানালে, তা সম্ভব।
# 64    ভারতের উত্তরপ্রদেশ রাজ্যের আগ্রায় সম্রাট শাহজাহান নির্মিত অমূল্য নিদর্শন তাজমহলকে বোমা মেরে উড়িয়ে দেওয়ার হুমকি দেওয়া হয়েছে বলে জানিয়েছে দেশটির পুলিশ। কিন্তু সন্দেহজনক কোনো বস্তু উদ্ধার করা হয়নি।
# 65    বাংলাদেশ ও ভারতে চলমান উত্তেজনার মধ্যে এবার পশ্চিমবঙ্গ রাজ্যের উত্তরবঙ্গা এলাকার আট জেলার বাংলাদেশ সীমান্তে নিরাপত্তাব্যবস্থা জোরদার করেছে ভারত। থার্মাল ক্যামেরা, নাইটভিশন ক্যামরা ও ড্রোনের সাহায্যে নজরদারি চালানো হয়েছে।
# 66    ভারতের উত্তর-পূর্বাঞ্চলীয় রাজ্য মণিপুরে একটি বেকারি থেকে ২৯ জন সন্দেহভাজন বাংলাদেশিকে আটক করেছে মনিপুর পুলিশ। তারা আসামের ইনার লাইন পারমিট (আইএলপি) নীতি লঙ্ঘন করেছেন।
# 67    কলম্বিয়ায় বিলুপ্ত ফার্ক গেরিলা গোষ্ঠীর দুটি ভিন্নমতাবলম্বী উপদলের মধ্যে সংঘর্ষের ঘটনায় বেশ কয়েকজন নিহত হয়েছে বলে দেশটির সরকারি কর্মকর্তারা জানিয়েছেন। স্থানীয় লোকজন বলছেন, এর সঙ্গে যোগ দেয়া হয়েছে সেগুন্ডা মার্কেটালিয়ার
# 68    বাংলাদেশে বিগত সরকার পতনের পর সংখ্যালঘুদের নিরাপত্তার দাবিতে বাংলাদেশের হিন্দু সম্প্রদায়ের একটি অংশ টানা আন্দোলনে নেমেছে। কিন্তু ভারতের বেশ কিছু গণমাধ্যম বাংলাদেশি ভক্তদের প্রাণ বাঁচানোর পরামর্শ দিচ্ছে।
# 69    আগরতলায় বাংলাদেশের সহকারী হাইকমিশনে হামলা ও জাতীয় পতাকা অবমাননার ঘটনায় ত্রিপুরা পুলিশ তাদের তিনজন সাব-ইন্সপেক্টরকে বরখাস্ত করেছে এবং দায়িত্বে অবহেলার অভিযোগে একজন উপ-পুলিশ সুপারকে প্রত্যাহার করা হয়েছে।
# 70    রুশ প্রেসিডেন্ট ভ্লাদিমির পুতিন ২০২৫ সালের শুরুর দিকে ভারত সফরে যাবেন বলে জানিয়েছে ক্রেমলিনের পক্ষ থেকে। কিন্তু তিনি এখনো নিশ্চিত করেছেন না যে তারা এবারের সঙ্গে বৈঠক করবেন।
# 71    গাজায় ইসরায়েলের সঙ্গে যুদ্ধ চলছে বলে অভিযোগ করে ইয়েমেনের আনসারুল্লাহ মুভমেন্টকে আনুষ্ঠানিকভাবে সন্ত্রাসী সংগঠন হিসেবে ঘোষণা করেছে কানাডা। এর ফলে তাদের কোনো সম্পদ নেই।
# 72    যুদ্ধবিরতি চুক্তি স্বাক্ষরের পর এক সপ্তাহ না যেতেই আবারও লেবাননে হামলা চালিয়েছে ইসরায়েল, এমন অভিযোগ নাকচ করে দিয়েছে দেশটির সশস্ত্র গোষ্ঠী হিজবুল্লাহ। এর আগে থেকেই এই প্রথমবারের মতো এ ঘটনা ঘটেছে।
# 73    সিরিয়ায় বাশার আসাদের সরকারের বিরুদ্ধে নতুন করে সংঘাত শুরু হয়েছে। গত এক সপ্তাহ ধরে দেশটির সবচেয়ে বড় জঙ্গি সংগঠন আল কায়েদা এবং তাদের মধ্যে সংঘর্ষ চলছে।
# 74    লেবানন জানিয়েছে, গত সপ্তাহে কার্যকর হওয়া যুদ্ধবিরতি লঙ্ঘন করেছে ইসরায়েল ও হিজবুল্লাহ। এরপরও দেশটির দুই পক্ষের মধ্যে বিমান হামলা চালিয়েছে ইসরায়েলে।
# 75    ফিলিস্তিনের স্বাধীনতাকামী সশস্ত্র সংগঠন হামাসকে কড়া হুঁশিয়ার বার্তা দিলেন যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। তিনি বলেছেন, গাজায় জিম্মিদের মুক্তি দেওয়া হবে।
# 76    মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প এবার আরেক মেয়ের শ্বশুরকে মধ্যপ্রাচ্য বিষয়ক উপদেষ্টা করেছেন নতুন একজন লেবানিজ-আমেরিকান ব্যবসায়ীকে যুক্তরাষ্ট্রের পরবর্তী রাষ্ট্রদূত হিসেবে মনোনয়ন দিয়েছেন।
# 77    ভারতের উত্তর-পূর্বাঞ্চলীয় রাজ্য ত্রিপুরা রাজ্যের সব হোটেল বাংলাদেশি নাগরিকদের জন্য সাময়িকভাবে বন্ধ রাখার সিদ্ধান্ত নিয়েছে দেশটির কর্তৃপক্ষ। কিন্তু এই পদক্ষেপ নিয়ে উদ্বেগ তৈরি হয়েছে।
# 78    পশ্চিমবঙ্গের বিধানসভার বিরোধী নেতা শুভেন্দু অধিকারী বাংলাদেশের অন্তর্বর্তী সরকারের প্রধান ড. মুহম্মদ ইউনূসকে কড়া হুঁশিয়ারি দিয়েছেন। সেই সঙ্গে বাংলাদেশে আলু-পেঁয়াজ রপ্তানি বন্ধ করে দেওয়ার কথাও বলেছেন তিনি।
# 79    বাংলাদেশের বিদ্যুৎ ও জ্বালানি উপদেষ্টা বলছে, ভারতের আদানি গ্রুপের সঙ্গে যে চুক্তি হয়েছে তা পুনর্মূল্যায়নের জন্য একটি বিশেষজ্ঞ কমিটিকে নির্দেশ দিয়েছে হাইকোর্ট। কিন্তু দুর্নীতি ও ঘুসের মতো অনিয়ম হয়ে থাকলে ঐ গ্রुपের কাছ থেকে কেনা
# 80    বাংলাদেশের কাছে জরুরি ভিত্তিতে বকেয়া বিদ্যুৎ বিল বাবদ ১৩৫ কোটি রুপি চেয়েছে ত্রিপুরা রাজ্য সরকার। কিন্তু এখনও উল্লেখযোগ্য পরিমাণ অর্থ এখনোও বকয়া রয়েছে।
# 81    পাকিস্তানের উত্তর-পশ্চিমাঞ্চলীয় একটি জেলায় সাম্প্রদায়িক সহিংসতায় গত ১০ দিনে অন্তত ১৩০ জন নিহত হয়েছে বলে সরকারি গণমাধ্যম সিএনএন জানিয়েছে। এর মধ্যে আফগানিস্তানের সীমান্তবর্তী কুররাম জেলার সংখ্যালঘুদের সঙ্গে যুদ্ধবির
# 82    পশ্চিম আফ্রিকার দেশ নাইজেরিয়ায় ২ শতাধিক যাত্রী নিয়ে নৌকাডুবির ঘটনা ঘটেছে। গত ৬০ দিনে তৃতীয়বারের মতো এই দুর্ঘটনার খবর পাওয়া গেছে বলে জানা যাচ্ছে।
# 83    ভারতের পশ্চিমবঙ্গের মুখ্যমন্ত্রী মমতা বন্দ্যোপাধ্যায় জাতিসংঘের কাছে বাংলাদেশে শান্তিরক্ষা বাহিনীর মোতায়েন করার আহ্বান জানিয়েছেন। তিনি বলেছেন, এই বিষয়ে সিদ্ধান্ত নেওয়ার এখতিয়ার রাজ্য সরকার নেই।
# 84    গিনির রাজধানী এন'জেরেকোরে ফুটবল ম্যাচের সময় দুই পক্ষের দর্শকদের মধ্যে ব্যাপক সংঘর্ষে অন্তত ১০০ জন নিহত হয়েছে বলে চিকিৎসকরা জানিয়েছেন। মৃতদের বেশির ভাগই হাসপাতালে ভর্তি।
# 85    সিরিয়ার বিদ্রোহীরা আলেপ্পো দখলের পর আরও অগ্রসর হয়েছে বলে জানিয়েছে দেশটির একটি মানবাধিকার সংস্থা। যুদ্ধবিমান হামলা চালিয়ে রাশিয়ার বিমান বাহিনী এই অভিযানে অন্তত ১৩ জনকে নিহত করেছে।
# 86    ইসরায়েলে মসজিদ থেকে লাউড স্পিকারে আজান দেওয়ার ওপর নিষেধাজ্ঞা আরোপের নির্দেশনা দিয়েছে দেশটির নিরাপত্তা কর্তৃপক্ষ। এর আগে প্রধানমন্ত্রী ইমানুয়েল ম্যাক্রঁর সঙ্গে কথা বলা হয়েছিল।
# 87    যুক্তরাষ্ট্রের প্রেসিডেন্ট হিসেবে মেয়াদ শেষের আগেই দোষী সাব্যস্ত ছেলে হান্টার বাইডেনকে আনুষ্ঠানিকভাবে ক্ষমা ঘোষণা করেছেন জো বারডেন। এর আগে তার বিরুদ্ধে ওঠা অভিযোগ রাজনৈতিক।
# 88    ভারতের রাজস্থানের আজমিরের বিখ্যাত খওয়াজা মৈনুদ্দিন চিশতির দরগাহ আসলে একটি শিব মন্দিরের ওপরে বানানো হয়েছিল বলে সেখানকার আদালতে মামলা দায়ের করেছেন এক হিন্দু নেতা।
# 89    আগ্নেয়াস্ত্র ও কর ফাঁকির মামলায় দোষী সাব্যস্ত বিদায়ী মার্কিন প্রেসিডেন্ট জো বাইডেন বলেছেন, পারিবারিক নামের কারণে তার ছেলেকে বেছে নেওয়া হয়েছে এবং অন্যায়ভাবে বিচার হয়েছে।
# 90    ভারতের জাতীয় পতাকা অবমাননার জেরে বাংলাদেশের কোনো রোগীকে চিকিৎসাসেবা না দেওয়ার ঘোষণা দিয়েছে কলকাতার একাধিক চিনিৎসক ও বেসরকারি হাসপাতাল। এই সিদ্ধান্তের বিরুদ্ধে বিতর্ক শুরু হয়েছে।
# 91    সিরিয়ার উত্তরাঞ্চলীয় আলেপ্পো শহরে হামলাকারী কয়েকটি গোষ্ঠীকে ইউক্রেনের সামরিক গোয়েন্দা সংস্থার (এইচইউআর) বিশেষ বাহিনী ইউনিট থেকে প্রশিক্ষণ দেওয়া হয়েছে বলে দাবি করেছে দেশটির গণমাধ্যম কিয়েভ পোস্ট।
# 92    ভারত-শাসিত জম্মু-কাশ্মীরের উত্তরপ্রদেশের শাহি জামে একটি মসজিদের স্থানে হিন্দুত্ববাদী গোষ্ঠীর গুলিতে ৪ জন মুসলিম নিহত হওয়ার পর সেখানকার তরুণরা মন্দির ভাঙার চেষ্টা করছে।
# 93    স্পেনের রাজধানী ভ্যালেন্সিয়ায় বন্যা মোকাবিলায় কর্তৃপক্ষের ব্যর্থতার জন্য অসন্তোষ জানিয়ে প্রায় ১ লাখ লোক বিক্ষোভ করেছে। বন্যায় মারা যাওয়া বন্ধুর মায়ের স্মরণে তারা একটি ব্যানার বহন করেছেন।
# 94    রাশিয়ার আইনশৃঙ্খলা রক্ষাকারী বাহিনী মস্কোর বেশ কয়েকটি নাইট ক্লাবে অভিযান চালিয়েছে। সেখানে মুখোশধারী প্রচারণার অভিযোগ ওঠার পর পুলিশ তাদের বিরুদ্ধে তল্লাশি শুরু করেছে।
# 95    ভারতের পশ্চিমবঙ্গের শিলিগুড়ির এক চিকিৎসক বলেছেন, তিনি বাংলাদেশ থেকে আগত রোগীদের ফিরিয়ে দেবেন। কিন্তু এরজন্য ভারতীয় পতাকায় প্রণাম করে তার চেম্বারে প্রবেশ করতে হবে।
# 96    সিরিয়ার দ্বিতীয় বৃহত্তম শহর আলেপ্পোতে নতুন বিদ্রোহী জোট অতর্কিত হামলা চালানোর পর আবার আলোচনায় এসেছে দেশটির গৃহযুদ্ধ। এই যুদ্ধে সবচেয়ে বেশি প্রাণহানি হয়েছে।
# 97    ইসরায়েলের সাবেক প্রতিরক্ষামন্ত্রী মোশে ইয়ালন বলেছেন, গাজার উত্তরাঞ্চল 'জাতিগত নিধন' চালাচ্ছে। সেখানকার বাসিন্দাদের বাস্তুচ্যুত করতে চাইছে ফিলিস্তিনি গোষ্ঠী হামাস এবং আরবদের এলাকা সাফ করে ফেলেছে।
# 98    তাইওয়ানের কাছে যুক্তরাষ্ট্রের অস্ত্র বিক্রির ব্যাপারে তীব্র অসন্তুষ্ট হওয়ার পর চীনের পররাষ্ট্র মন্ত্রণালয় এই সিদ্ধান্তকে 'অবিলম্বে' বন্ধ করার আহ্বান জানিয়েছে। কিন্তু চীন এখন তা নাকচ করে দিয়েছে।
# 99    জাতিসংঘ বলছে, গাজা উপত্যকায় ইসরায়েলি বিমান হামলার পর এখন পর্যন্ত ৪ লাখ ১৫ হাজারেরও বেশি মানুষ অস্থায়ী আশ্রয়কেন্দ্রে বসবাসের চেষ্টা করছে। এদের মধ্যে বেশিরভাগই ফিলিস্তিনি।
# 100    চীন ও রাশিয়া সমর্থিত উদীয়মান অর্থনীতির দেশগুলোর কাছে নতুন ব্রিকস মুদ্রা তৈরি না করার প্রতিশ্রুতি চাইলেন যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। এই প্রস্তাবকে ভিত্তিহীন বলে বর্ণনা করেছেন তিনি।
# 101    রাশিয়ার সঙ্গে তীব্র উত্তেজনার মধ্যেই যুক্তরাষ্ট্র, ব্রিটিশ ও ডাচ মেরিনদের প্রশিক্ষণ দিতে নতুন একটি ন্যাটোর যুদ্ধ কেন্দ্র প্রতিষ্ঠার পরিকল্পনা করছে নরওয়ে। এই প্রকল্পের আওতায় ন্যাটো কর্মীদের উভচর আক্রমণে সহায়তা করতে হবে
# 102    সিরিয়ার উত্তরাঞ্চলীয় শহর আলেপ্পোতে সশস্ত্র বিদ্রোহীরা আক্রমণ করেছে এবং সেনাবাহিনীর সঙ্গে সংঘর্ষে অন্তত ৪০ জন নিহত হয়েছে। এর মধ্যে বেশ কয়েকজন আহত হবার খবর পাওয়া গেছে।
# 103    কলকাতার পার্ক স্ট্রিট পুলিশ স্টেশন থেকে বাংলাদেশ জাতীয়তাবাদী দলের (বিএনপি) সাবেক এক নেতাকে গ্রেপ্তার করা হয়েছে বলে জানিয়েছে সেখানকার রাজধানী মারকুইসের এক হোটেলে অভিযান চালানো হয়েছে।
# 104    কলকাতার পর এবার বাংলাদেশি রোগীদের চিকিৎসা না দেয়ার ঘোষণা দিয়েছে ভারতের উত্তর-পূর্বাঞ্চলীয় রাজ্য ত্রিপুরার একটি হাসপাতাল। এরই মধ্যে ঢাকার আখাউড়া চেকপোস্ট এবং আগরতলায় অবস্থিত আইএলএস নামে একটা সরকারি হাস
# 105    পাকিস্তানের উত্তরপশ্চিমাঞ্চলীয় কুররাম জেলায় জাতিগত দাঙ্গা কোনোভাবেই থামছে না। এমন পরিস্থিতিতে নতুন করে সংঘাতবিরতির চেষ্টা চালিয়ে যাচ্ছেন স্থানীয় নেতারা। যুদ্ধবিরতি কার্যকর করতে আলোচনা শুরু হয়েছে।
# 106    গাজায় গত এক বছরের বেশি সময় ধরে চলছে ইসরায়েলি বাহিনীর হামলার পর এখন পর্যন্ত ফিলিস্তিনকে রাষ্ট্র হিসেবে আনুষ্ঠানিকভাবে স্বীকৃতি দিয়েছে বিভিন্ন দেশের মধ্যে রয়েছে আর্মেনিয়া, স্লোভেনিয়া এবং আয়ারল্যান্ড।
# 107    ঘূর্ণিঝড় ফিনজাল ভারতের দক্ষিণাঞ্চলীয় রাজ্য তামিলনাড়ু ও পুদুচেরীতে আঘাত হানে। এরইমধ্যে লঘুচাপে পরিণত হয়েছে চেন্নাই বিমানবন্দর। এতে তিনজনের মৃত্যু হয়েছে।
# 108    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের মুক্তির দাবিতে দেশটির বিভিন্ন প্রান্ত থেকে ইসলামাবাদে জড়ো হয়েছিলেন আধ্যাত্মিক নেতা বুশরা বিবি। কিন্তু সেই সঙ্গে কী ঘটেছে?
# 109    ইরান সমর্থিত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহর সঙ্গে গত বুধবার থেকে শুরু হওয়া যুদ্ধবিরতির পর এখন পর্যন্ত অন্তত তিনজন নিহত হয়েছে বলে জানিয়েছে ইসরায়েলের কর্মকর্তারা।
# 110    প্রেসিডেন্ট বাশার আল-আসাদ শাসিত সিরিয়ার দ্বিতীয় বৃহত্তম শহর আলেপ্পোর বেশিরভাগ এলাকা নিয়ন্ত্রণ নিয়েছে দেশটির বিদ্রোহী গোষ্ঠী। এতে তিন শতাধিক মানুষ নিহত হয়েছে।
# 111    কুয়েত জানিয়েছে, এইচআইভি পজিটিভ প্রবাসীদের মধ্যে ১০০ জনেরও বেশি মানুষকে দেশে ফেরত পাঠিয়েছে দেশটি। এর মানে, দেশটির নাগরিকদের ৯০ শতাংশই এইডস শনাক্ত করেছে।
# 112    যুক্তরাষ্ট্রের কেন্দ্রীয় গোয়েন্দা সংস্থা এফবিআই-এর পরবর্তী পরিচালক হিসেবে কাশ প্যাটেলকে বেছে নিয়েছেন মার্কিন নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। এ নিয়ে তীব্র প্রতিক্রিয়া জানিয়েছেন তিনি।
# 113    বিশ্বে প্রতি ১০ মিনিটে একজন নারী তার প্রেমিক কিংবা পরিবারের সদস্যের হাতে প্রাণ হারাচ্ছেন। জাতিসংঘের এক তথ্য অনুযায়ী, গত ২০২৩ সালে এ সংখ্যা ৮৫ হাজার নারীকে পরিকল্পনা করে হত্যা করা হয়েছে।
# 114    ভারতের আদানি গ্রুপের প্রতিষ্ঠাতা গৌতম আদানির বিরুদ্ধে ঘুষ ও প্রতারণার অভিযোগ তুলে গ্রেপ্তারি পরোয়ানা জারি করেছে যুক্তরাষ্ট্রে। তিনি বলেছেন, প্রতিটি আক্রমণ তার প্রতিষ্ঠানকে আরও শক্তিশালী করে তোলে।
# 115    যুক্তরাষ্ট্র তাইওয়ানের কাছে নতুন করে ৩৮ কোটি ৫০ লাখ ডলারের nueva অস্ত্র বিক্রিতে সই করেছে। দুই দেশের কূটনৈতিক সম্পর্ক গভীর করার লক্ষ্য নিয়ে এই পরিকল্পনা করা হয়েছে।
# 116    বাংলাদেশে সংখ্যালঘুদের ওপর কথিত হামলার অভিযোগ নিয়ে সরব ভারতের ক্ষমতাশীন বিজেপি সরকার। বাংলাদেশ ইস্যুতে ভারতে যে পরিস্থিতি চলছে, সেটি 'বাড়াবাড়ি' হচ্ছে বলে মন্তব্য করেছেন পশ্চিমবঙ্গের মন্ত্রী সিদ্দিকুল্লাহ চৌধুরী।
# 117    চীনের ভূতাত্ত্বিকরা জানিয়েছেন, বিশ্বের 'সবচেয়ে বড়' সোনার মজুদের সন্ধান পেয়েছে চীন। ওয়াঙ্গু গোল্ডফিল্ডের গভীরে এটি আছে মূল্যবান ধাতুর একটি শিরা।
# 118    উত্তর কোরিয়ার নেতা কিম জং উন বলেছেন, পশ্চিমাদের বিরুদ্ধে 'সামাজিক সংঘাতে সরাসরি সামরিক হস্তক্ষেপ' নেওয়া উচিৎ। রাশিয়ার সঙ্গে কৌশলগত সহযোগিতা চুক্তি সই করেছে দুই দেশ।
# 119    রাশিয়া বলছে, সোভিয়েত ইউনিয়ন থাকাকালে দেশটির পারমাণবিক অস্ত্র পরীক্ষা পুনরায় শুরু করা হবে। এর আগে মস্কোর নোভায়া জিমলিয়া দ্বীপপুঞ্জে অবস্থিত এই পরিক্ষাকেন্দ্রে আর কোনো পারমানবিক পরেক্ষা হয়নি।
# 120    ইসরায়েলি হামলার কারণে লেবাননের গুরুত্বপূর্ণ খাতগুলোতে আনুমানিক দেড় হাজার কোটি ডলারের ক্ষতি হয়েছে বলে জানিয়েছেন দেশটির অর্থ ও বাণিজ্যমন্ত্রী আমিন সালাম। যুদ্ধবিরতি কার্যকর হওয়ার পর এই পরিমাণ বেশিরভাগ দেশের জনগণের একত্রীকরণের ওপর জোর
# 121    নাইজেরিয়ার মধ্যাঞ্চলীয় কোগি রাজ্যে একটি নৌকাডুবিতে অন্তত ২৭ জনের মৃত্যু হয়েছে। উদ্ধারকারীরা বলছেন, দুর্ঘটনায় নিহতদের বেশিরভাগই নারী, ব্যবসায়ী এবং কারিগর।
# 122    মালয়েশিয়ার উত্তরাঞ্চলীয় রাজ্যগুলোতে টানা বর্ষণে সৃষ্ট বন্যায় ১ লাখ ২২ হাজারের বেশি মানুষ বাস্তুচ্যুত হয়েছে বলে দেশটির দুর্যোগ ব্যবস্থাপনা সংস্থার তথ্য অনুসারে উঠে এসেছে।
# 123    পাকিস্তানের রাজনীতিতে এক নতুন অধ্যায়ের সূচনা করেছেন দেশটির সাবেক প্রধানমন্ত্রী ইমরান খানের স্ত্রী বুশরা বিবি। গত কয়েকদিন ধরে এই আন্দোলনে অংশ নিয়ে বিক্ষোভ করছেন বিরোধীরা।
# 124    ভারতের তামিলনাড়ুর দিকে ধেয়ে আসছে ঘূর্ণিঝড় ফিনজাল। এরই মধ্যে ট্রেন ও ফ্লাইট বন্ধ রাখার সিদ্ধান্ত নিয়েছে দেশটির কর্তৃপক্ষ। সেইসঙ্গে রেড অ্যালার্ট জারি করা হয়েছে।
# 125    পাকিস্তানের উত্তরপশ্চিমাঞ্চলীয় কুররাম জেলায় জাতিগত দাঙ্গা কোনোভাবেই থামছে না। গত কয়েকদিন ধরে শিয়া ও সুন্নি গোষ্ঠীর মধ্যে সংঘাত চলছে বলে খবর পাওয়া যাচ্ছে।
# 126    ভারতের একটি ছোট্ট গ্রামের মানুষ কখনও মুখ থেকে খারাপ শব্দ বের না করার প্রতিশ্রুতি নিয়েছেন। এমনটা করলে জরিমানা দিতে হবে। কিন্তু এই শপথ নিতে পারেন কেউ।
# 127    ইসরায়েল ও ইরান সমর্থিত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহর মধ্যে যুদ্ধবিরতির পর প্রথমবারের মতো ভাষণ দিয়েছেন গোষ্টীটির প্রধান শেখ নাইম কাসেম। তিনি বলেছেন, আমরা একটি মহান বিজয়ের মুখোমুখি যা জুলাই ২০০৬-কে ছা
# 128    নব-নির্বাচিত মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের প্রস্তাবিত আমদানি শুল্ক আরোপের ফলে যুক্তরাষ্ট্রে অন্তত ৪ লাখ লোকের কর্মসংস্থান হুমকির মুখে পড়বে বলে সতর্ক করেছে মেক্সিকো।
# 129    হংকংয়ে একটি নিলামে স্কচটেপ দিয়ে দেওয়ালে আটকানো কলার শিল্পকর্ম বিক্রি হলো ৬২ লাখ ডলারের মতো। কিন্তু সেই কলা সত্যিই খেয়ে ফেলেছেন একজন চীনা ক্রিপ্টোকারেন্সি ব্যবসায়ী।
# 130    অবৈধ অভিবাসী, সীমান্তে নিরাপত্তা ও মাদক চোরাচালান ইস্যুতে গত সপ্তাহে হুঁশিয়ার বার্তা দেন মার্কিন নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। এমন হুমকির পর ফ্লোরিডায় গেছেন কানাডার প্রধানমন্ত্রী জাস্টিন ট্রুডো।
# 131    সিরিয়ার বিদ্রোহী বাহিনী দেশটির দ্বিতীয় বৃহত্তম শহর আলেপ্পোর বেশিরভাগ এলাকা নিয়ন্ত্রণে নিয়েছে। শনিবার রাত থেকে শুরু হওয়া এই হামলায় অন্তত ১৩ জন নিহত হয়েছে বলে খবর পাওয়া যাচ্ছে।
# 132    নিবনির্বাচিত মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের হবু প্রশাসনের সদস্যরা বোমা হামলার হুমকি পাওয়ার পর এবার একই হুমকিতে পড়েছেন দেশটির অন্তত পাঁচজন ডেমোক্র্যাটিক আইনপ্রণেতার বাড়িতে।
# 133    ফিলিস্তিনের স্বাধীনতাকামী সশস্ত্র সংগঠন হামাস নিয়ন্ত্রিত গাজায় অবিরাম হামলা চালিয়ে যাচ্ছে ইসরায়েলি বাহিনী। এতে অন্তত ৭৫ জন নিহত হয়েছে বলে জানিয়েছে গাজা সরকারের মিডিয়া কার্যালয়।
# 134    গাজা উপত্যকায় ইসরায়েলি বাহিনীর হামলার পর যুক্তরাজ্য সরকারের কাছে একটি চিঠি দিয়েছেন ব্রিটিশ সংসদ সদস্যরা। সেখানে 'আন্তর্জাতিক আইন বারবার লঙ্ঘনের' জন্য নিষেধাজ্ঞা আরোপের আহ্বান জানানো হয়েছে।
# 135    কিয়েভেনের সেনাবাহিনীর বিরুদ্ধে পলায়নের অভিযোগ আনা হওয়ার পর থেকে এই প্রথমবারের মতো কয়েক লাখ ইউক্রেনীয় সৈন্য পদত্যাগ করেছেন বলে মার্কিন বার্তা সংস্থা অ্যাসোসিয়েটেড প্রেস জানিয়েছে।
# 136    ইসরায়েলি গোয়েন্দা সংস্থা মোসাদকে গুপ্তচরবৃত্তির অভিযোগে তুরস্কে সাত জনের বিরুদ্ধে মামলা দায়ের করেছে ইস্তাম্বুলের পাবলিক প্রসিকিউটর। এদের প্রত্যেকের কারাদণ্ড হতে হবে।
# 137    ১৭ বছর আগে ২০০৭ সালে সাবেক জার্মান চ্যান্সেলর অ্যাঞ্জেলা মার্কেলের সঙ্গে এক বৈঠকে নিজের পোষা কুকুরকে নিয়ে হাজির হয়েছিলেন রুশ প্রেসিডেন্ট ভ্লাদিমির পুতিন।
# 138    ইরানের উৎপাদন সক্ষমতা ৬০ শতাংশ বাড়ানোর ঘোষণা দিয়েছে পশ্চিমা শক্তিধর দেশগুলো। কিন্তু ইরান বলছে, ইউরেনিয়াম সমৃদ্ধকরণ প্ল্যান্টগুলোতে ছয় হাজারেরও বেশি সেন্ট্রিফিউজ বসাতে যাচ্ছে তারা।
# 139    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প নিরাপদ নন বলে মনে করেন রাশিয়ার প্রশাসক ভ্লাদিমির পুতিন। তিনি বলেছেন, মার্কিন নির্বাচনী প্রচারণা এবং লড়াইয়ের জন্য একেবারেই অসভ্য পদ্ধতি ব্যবহার করা হয়েছে।
# 140    বাংলাদেশের আবহাওয়া অধিদপ্তর বলছে, চলতি সপ্তাহের শেষে বঙ্গোপসাগরে অবস্থান করা একটি লঘুচাপ ঘনীভূত হয়ে একটির ঘূর্ণিঝড়ে রূপ নিতে পারে বলে আশঙ্কা করছেন আব হাওয়াবিদরা।
# 141    ইরানের পারমাণবিক অস্ত্রের শক্তিধর হওয়া ঠেকাতে ইসরায়েল সবকিছু করবে বলে হুমকি দিয়েছেন দেশটির প্রধানমন্ত্রী বেনিয়ামিন নেতানিয়াহু। লেবাননে যেদিন থেকে যুদ্ধবিরতি কার্যকর হবে, তার আগে থেকেই ইরান তার ওপর আরও নিষেধাজ্ঞা আরোপ
# 142    মিয়ানমারের সামরিক প্রধান সিনিয়র জেনারেল মিন অং হ্লাইংয়ের বিরুদ্ধে গ্রেপ্তারি পরোয়ানা জারির আবেদন জানিয়েছে আন্তর্জাতিক অপরাধ আদালত (আইসিসি), এবং বাংলাদেশ সরকার তাকে স্বাগত জানাচ্ছে।
# 143    ইরান সমর্থিত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহ এবং ইসরায়েলের মধ্যে যুদ্ধবিরতি শুরুর পর প্রথমবারের মতো সাক্ষাৎকার দিয়েছেন ইসরায়েলে প্রধানমন্ত্রী বেনিয়ামিন নেতানিয়াহু।
# 144    পাকিস্তানের উপজাতীয় জেলা কুররামে গত কয়েকদিন ধরে জাতিগত দাঙ্গা অব্যাহত রয়েছে। এতে নিহতের সংখ্যা বেড়ে ১১০ জনে দাঁড়িয়েছে। এর মধ্যে আফগান বিবদমান গোষ্ঠীগুলোর সঙ্গে সংঘর্ষও হয়েছে।
# 145    অস্ট্রেলিয়ায় ১৬ বছরের কম বয়সী শিশুদের জন্য সামাজিক যোগাযোগমাধ্যম ব্যবহারে নিষেধাজ্ঞা আরোপ করছে দেশটির সেনেট। এর ফলে প্রযুক্তি কোম্পানিগুলোকে জরিমানা করা হতে পারে।
# 146    লেবাননে হিজবুল্লাহ এবং ইসরায়েলের মধ্যে যে যুদ্ধবিরতি শুরু হয়েছে, তাতে সেনাবাহিনীর বিরুদ্ধে হামলা চালানোর অভিযোগ উঠেছে। এর আগেই লড়াই শেষ হওয়ার কথা রয়েছে।
# 147    যুক্তরাষ্ট্রের নব-নির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের বিরুদ্ধে যে হত্যাচেষ্টা চালানো হয়েছে তাতে তিনি স্তব্ধ বলে মন্তব্য করেছেন রুশ প্রশাসক ভ্লাদিমির পুতিন। গতকাল বৃহস্পতিবার কাজাখস্থানে এক বৈঠকের পর এই প্রশ্নের উত্তরে সাংবাদ
# 148    ইউক্রেনের জ্বালানি খাতে ব্যাপক হামলার পর নতুন করে হুঁশিয়ার বার্তা দিলেন রুশ প্রেসিডেন্ট ভ্লাদিমির পুতিন। তিনি বলেছেন, এই আক্রমণের মাধ্যমে ব্লাকমেইলের কড়া জবাব দেওয়া হবে।
# 149    ফিলিস্তিনের স্বাধীনতাকামী সশস্ত্র সংগঠন হামাস নিয়ন্ত্রিত গাজায় হামলার পরিমাণ বাড়িয়েছে ইসরায়েলি বাহিনী। সেইসঙ্গে ট্যাঙ্ক নিয়ে যাচ্ছে জাতিসংঘের বিবৃতিতে বলা হয়েছে, এতে নিহত হয়েছে অন্তত ১৩ জন।
# 150    লেবাননের সামরিক দল হিজবুল্লাহ যুদ্ধবিরতি কার্যকর হওয়ার পর প্রথম বিবৃতিতে বলেছে, তারা ইসরাইলের বিরুদ্ধে 'বিজয়' অর্জন করেছে এবং তার যোদ্ধারা প্রস্তুত রয়েছে।
# 151    আগুন থেকে সৃষ্ট বায়ু দূষণে বিশ্বব্যাপী বছরে ১৫ লাখের বেশি লোকের মৃত্যু ঘটেছে। এদের মধ্যে হৃদরোগের সঙ্গে জড়িত থাকার সংখ্যাও রয়েছে বলে নতুন এক গবেষণায় উঠে এসেছে।
# 152    পশ্চিমা দেশগুলোর চেয়ে রাশিয়ার কাছে শক্তিশালী ও আরও বেশি অত্যাধুনিক অস্ত্র রয়েছে বলে হুঁশিয়ারি দিয়েছেন রুশ প্রেসিডেন্ট ভ্লাদিমির পুতিন। তিনি বলেছেন, যুক্তরাষ্ট্রের তৈরি এটিএসিএমএসের সমান।
# 153    অস্ট্রেলিয়ার পার্লামেন্টে ১৬ বছরের কম বয়সী শিশুদের জন্য সামাজিক যোগাযোগ মাধ্যম নিষেধাজ্ঞা আইন পাস করেছে দেশটির মধ্য-বামপন্থী প্রধানমন্ত্রী অ্যান্থনি অ্যালবানিজের দল।
# 154    লন্ডনের একটি কারাগার থেকে দুঃসাহসিকতার সঙ্গে পালিয়ে আসা সাবেক এক ব্রিটিশ সেনা ইরানের হয়ে গুপ্তচরবৃত্তি করার অভিযোগে তাকে দোষী সাব্যস্ত করেছে ব্রিটেনের উলউইচ ক্রাউন কোর্ট।
# 155    ফ্রান্সের প্রধানমন্ত্রী মিশেল বার্নিয়ারের প্রস্তাবিত বাজেট নিয়ে ক্ষোভের কারণে দেশটির প্রায় ৫৩ শতাংশ মানুষের ওপর চালানো এক জরিপে ইঙ্গিত দেওয়া হয়েছে যে তারা সরকারের পতন চাইছে।
# 156    ইন্দোনেশিয়ার উত্তর সুমাত্রা প্রদেশে সপ্তাহান্তে আকস্মিক বন্যা ও ভূমিধসে অন্তত ২৭ জন নিহত হয়েছে বলে পুলিশ জানিয়েছে। এর মধ্যে আহতদের সংখ্যাও বাড়ছে বলে জানাচ্ছে দেশটির কর্তৃপক্ষ।
# 157    উগান্ডায় হ্যাকাররা কেন্দ্রীয় ব্যাংক থেকে ৬২ বিলিয়নউগান্ডান শিলিং (প্রায় ১৭ মিলিয়ন ডলার) চুরি করেছে বলে খবর পাওয়া গেছে। এই ঘটনায় তদন্তের নির্দেশ দিয়েছেন প্রেসিডেন্ট ইয়োয়েরি মুসেভেনি।
# 158    বাংলাদেশে সংখ্যালঘুদের নিরাপত্তা ও বিভিন্ন দাবি তুলে বাংলাদেশের হিন্দু ধর্মাবলম্বীদের আন্দোলনে নেমে থাকা চিন্ময় কৃষ্ণ দাসকে গ্রেপ্তার এবং তাকে জামিন নামঞ্জুরের ঘটনায় ভারতের পররাষ্ট্রমন্ত্রী এস জয়শঙ্কর উদ্বেগ প্রকাশ করেছেন।
# 159    ভারতের শীতকালীন অধিবেশনের প্রথম দিন থেকেই সংসদে ব্যাপক তোলপাড় শুরু হয়েছে। প্রধানমন্ত্রী নরেন্দ্র মোদির কাছে জবাব চাইছেন বিরোধী দল বিজেপি নেতা গৌতম আদানির।
# 160    দক্ষিণ লেবাননে ইসরায়েল ও হিজবুল্লাহর মধ্যে দুই মাসের যুদ্ধবিরতি ঘোষণার পর এখন থেকে দেশে ফিরে এসেছে লক্ষ হাজারেরও বেশি মানুষ। তারা বলছেন, এই চুক্তির শর্ত লঙ্ঘন করলে তাদের সশস্ত্র উপস্থিতি শেষ কর
# 161    বাংলাদেশের চলমান ইসকন ইস্যু নিয়ে মন্তব্য করেছেন পশ্চিমবঙ্গের মুখ্যমন্ত্রী মমতা ব্যানার্জী ও কংগ্রেস নেত্রী এবং সদ্য নির্বাচিত সংসদ সদস্য প্রিয়াঙ্কা গান্ধী। এই প্রশ্নের জবাবে তিনি বলেছেন, ভারতে হিন্দুদের ওপরে অত্যাচার হওয়া উ
# 162    ভারতের পার্লামেন্টের নিম্নকক্ষ লোকসভার সদস্য হিসেবে শপথ নিয়েছেন কংগ্রেস নেত্রী প্রিয়াঙ্কা গান্ধী ভদ্র। এই নির্বাচনকে কেন্দ্র করে তিনি তৃতীয়বারের মতো সংবিধান হারিয়েছেন।
# 163    পাকিস্তানের উত্তর-পশ্চিমাঞ্চলে ফের সাম্প্রদায়িক সহিংসতা শুরু হয়েছে। এতে আরও পাঁচজন নিহত হয়েছে বলে খবর পাওয়া যাচ্ছে। স্থানীয় বিবদমান গোষ্ঠীগুলোর মধ্যে নতুন করে সংঘর্ষের পর সেখানকার প্রধান হাইওয়ে বন্ধ হয়ে গেছে।
# 164    রাশিয়ার বিমান বাহিনীর হামলায় ইউক্রেনের জ্বালানি অবকাঠামোতে ব্যাপক বিস্ফোরণ হয়েছে বলে জানিয়েছে দেশটির কর্তৃপক্ষ। এর মধ্যে লুতস্কের মেয়র ওলেগ কিপের বাসিন্দাদের নিরাপদ স্থানে আশ্রয় নেওয়ার আহ্বান জানিয়েছেন।
# 165    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের সাথে বৈঠক করেছেন মেক্সিকোর প্রশাসক ক্লডিয়া শেইনবম। কিন্তু দুই নেতার মধ্যে কথাবার্তা ফলপ্রসূ হয়েছে বলে জানা গেছে।
# 166    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের মন্ত্রিসভার জন্য বেছে নেওয়া একাধিক সদস্য ও মনোনীত কর্মকর্তাকে বোমা হামলার হুমকি দেওয়ার ঘটনা নিয়ে তদন্ত শুরু করেছে দেশটির আইন শৃঙ্খলা বাহিনী।
# 167    যুক্তরাষ্ট্রের বিদায়ী প্রেসিডেন্ট জো বাইডেনের প্রশাসন ইসরায়েলের কাছে আরও ৬৮ কোটি ডলারের অস্ত্র বিক্রির প্রাথমিক অনুমোদন দিয়েছে। এর মধ্যে লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহকে লক্ষ্যবস্তুতে নির্ভুলভাবে হামলার উপযোগী
# 168    যুক্তরাজ্যের কর্মীদের মধ্যে ভয়াবহ মানসিক চাপ তৈরি করছে। কর্মসংস্থান আইনের আওতায় কর্মক্ষেত্রে সবচেয়ে কঠোর সময়সীমা এবং সীমিত কাজের স্বাধীনতার অভাব দেখা যাচ্ছে।
# 169    ভারতের পুলিশ বলছে, প্রেমিকাকে শ্বাসরোধে হত্যার পর তার দেহ ৪০ থেকে ৫০ টুকরা করার অভিযোগে এক ব্যক্তিকে গ্রেপ্তার করা হয়েছে। এই ঘটনা প্রকাশ্যে এসেছে ১৪ দিন পর।
# 170    পাকিস্তানের সাবেক প্রধানমন্ত্রী ও पाकिस्तान তেহরিক-ই-ইনসাফের (পিটিআই) প্রতিষ্ঠাতা ইমরান খান ও তার স্ত্রীর বিরুদ্ধে নতুন করে আটটি মামলা দায়ের করেছে ইসলামাবাদ পুলিশ।
# 171    গুপ্তচরবৃত্তির অভিযোগে মস্কো দূতাবাসে কর্মরত এক ব্রিটিশ কূটনীতিককে বহিষ্কার করেছে রাশিয়া। এরপর তাকে দুই সপ্তাহের মধ্যে ছাড়ার নির্দেশ দিয়েছে ব্রিটেনের নিরাপত্তা কর্তৃপক্ষ।
# 172    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পকে হত্যার হুমকি দেওয়ার অভিযোগে অ্যারিজোনার এক ব্যক্তিকে, যার নাম উল্লেখ করা হয়নি, তা গ্রেপ্তার করেছে শীর্ষ একটি আদালত।
# 173    মার্কিন যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প উত্তর কোরিয়ার নেতা কিম জং উনের সঙ্গে সরাসরি আলোচনার বিষয়ে কথা বলছেন। রয়টার্সের একটি সূত্র বলছে, এই প্রচেষ্টার লক্ষ্য হবে পারমাণবিক নিষেধাজ্ঞা শিথিল
# 174    মানসিক চাপ থেকে মুক্তি পেতে এক হাজারেরও বেশি অচেনা বাড়িতে ঢুকে পড়া জাপানের এক ব্যক্তিকে গ্রেপ্তার করেছে দেশটির পুলিশ। তিনি অভিযোগ করেছেন যে, তার হাতের তালু ঘেমে গেছে।
# 175    গাজায় ইসরায়েলের গণহত্যায় জড়িত থাকার জন্য কানাডার প্রধানমন্ত্রী জাস্টিন ট্রুডোর সরকারকে অভিযুক্ত করেছেন দেশটির একদল হাসপাতালের একজন চিকিৎসক। তিনি বলেছেন, যুদ্ধবিরতির দাবি উপেক্ষা করা হয়েছে।
# 176    অর্ধ শতাব্দীরও বেশি সময়ে নভেম্বরের সবচেয়ে মারাত্মক তুষারঝড়ে ঢেকে গেছে দক্ষিণ কোরিয়ার রাজধানী সিউল। দেশটির কর্তৃপক্ষ বলছে, এই ঝড়টি দেশের বিভিন্ন এলাকায় প্রায় ২০ সেন্টিমিটার (৭.৮ ইঞ্চি)
# 177    মিয়ানমারের সংখ্যালঘু রোহিঙ্গা মুসলিমসহ অন্যান্য সম্প্রদায়ের বিরুদ্ধে সংঘটিত অপরাধের জন্য আদালতে (আইসিসি) দেশটির জান্তা সরকারের প্রধানকে গ্রেপ্তারি পরোয়ানা জারির আবেদন করেছে।
# 178    রাশিয়া বলেছে, মধ্যপ্রাচ্যের পরিস্থিতি স্বাভাবিক অবস্থায় ফিরিয়ে আনার লক্ষ্য অর্জনের পরিবেশ তৈরি করা হবে। এই প্রচেষ্টায় যুক্তরাষ্ট্র সমর্থিত ইসরায়েলের বিরুদ্ধে জাতিসংঘের নিরাপত্তা পরিষদের সিদ্ধান্তগুলো উপেক্ষা করে আসছে।
# 179    বিশ্বের সবচেয়ে বয়স্ক পুরুষ হিসেবে স্বীকৃতি পাওয়া জন আলফ্রেড টিনিসউড মারা গেছেন। তিনি গিনেস বুক অফ রেকর্ডসের শীর্ষস্থানীয় ফুটবল ট্রফি জয়ের মধ্যে একজন।
# 180    ব্রাজিলের সাবেক প্রেসিডেন্ট জইর বলসোনারো ২০২২ সালের নির্বাচনের ফল পাল্টে দিতে একটি অভ্যুত্থান পরিকল্পনার সঙ্গে সরাসরি জড়িত ছিলেন বলে প্রমাণ পেয়েছে দেশটির কেন্দ্রীয় পুলিশ।
# 181    মার্কিন যুক্তরাষ্ট্রে ঘুষকাণ্ডে অভিযুক্ত ভারতীয় ধনকুবের গৌতম আদানিকে সমর্থন থেকে দূরে সরে এসেছে ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদির দল বিজেপি। এরই অংশ হিসেবে কংগ্রেস কর্মীরা বিক্ষোভ করেছে।
# 182    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের মুক্তির দাবিতে রাজধানী ইসলামাবাদে আন্দোলনকারীদের ওপর মধ্যরাতে ব্যাপক ধরপাকড় চালিয়েছে দেশটির সামরিক বাহিনী। এতে অন্তত ৬ জন নিহত হয়েছে বলে জানা গেছে।
# 183    যুক্তরাষ্ট্র ও ফ্রান্সের মধ্যস্থতায় অবশেষে লেবাননের সশস্ত্র সংগঠন হিজবুল্লাহর সঙ্গে ইসরায়েলের যুদ্ধবিরতি শুরু হয়েছে বলে জানিয়েছে দেশটির রাষ্ট্রীয় গণমাধ্যম টাইমস অব ইসরায়েলে।
# 184    লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহর সঙ্গে ইসরায়েলের যুদ্ধবিরতি চুক্তি অনুমোদন করেছে মার্কিন প্রেসিডেন্ট জো বাইডেন এবং ব্রিটিশ প্রধানমন্ত্রী কিয়ার স্টারমার। এর মধ্যে 'সুসংবাদ' বলে অভিহিত করেছেন যুক্তরাজ্য।
# 185    লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহর সঙ্গে যুদ্ধবিরতি চুক্তি অনুমোদন দিয়েছে ইসরায়েলের মন্ত্রিসভা। এ নিয়ে যুক্তরাষ্ট্র ও হোয়াইট হাউসের মধ্যে বক্তব্য দেওয়ার কথা রয়েছে।
# 186    দক্ষিণ কোরিয়ায় ইচ্ছাকৃতভাবে ওজন বাড়িয়ে সামরিক দায়িত্ব এড়ানোর অভিযোগে এক যুবক দোষী সাব্যস্ত হয়েছেন। তিনি স্বাস্থ্য পরীক্ষার আগে অতিরিক্ত খাওয়ার মাধ্যমে তাকে স্থূল হিসেবে চিহ্নিত হন।
# 187    মিয়ানমারের সেনাবাহিনীর বিরুদ্ধে লড়াইরত বিদ্রোহী জোটের অংশ একটি জাতিগত সশস্ত্র বাহিনী জান্তার সঙ্গে আলোচনায় বসতে রাজি হয়েছে। এই ঘোষণা দিয়েছে দেশটির শীর্ষস্থানীয় গণমাধ্যম।
# 188    রাশিয়া বলছে, তারা ইউক্রেনের পূর্বাঞ্চলে বড় ধরনের এলাকা দখল করেছে। এই নিয়ে নতুন এক রেকর্ড গড়ছে যুক্তরাজ্যের সেনা সংস্থা এজেন্টস্টভো। এমনকি গত এক মাসের মধ্যে এটি সবচেয়ে দ্রুত।
# 189    ফিলিপাইনের প্রেসিডেন্ট ফার্দিনান্দ মার্কোস জুনিয়রের বিরুদ্ধে তাকে হত্যার ষড়যন্ত্রে জড়িত থাকার অভিযোগে সমন জারি করেছে দেশটির পররাষ্ট্র মন্ত্রণালয় (এনবিআই) এবং সাবেক স্বৈরশাসক কাজিন সারা দুতার্ত।
# 190    মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের সাম্প্রতিক শুল্ক আরোপের হুমকির প্রেক্ষিতে চীন বলেছে, বাণিজ্যযুদ্ধে কোনো পক্ষই জয়ী হতে পারে না এবং নিজের অধিকার রক্ষায় পিছপা হবে না।
# 191    পাকিস্তানের রাজধানী ইসলামাবাদে বিক্ষোভ করে সরকারবিরোধী দাবিতে উত্তাল পরিস্থিতি সৃষ্টি করেছেন। সাবেক প্রধানমন্ত্রী ইমরান খানের স্ত্রী বুশরা বিবির নেতৃত্বাধীন বিশাল একটি বহর এখনো অবস্থান করছে।
# 192    ভারতের উত্তরপ্রদেশের সামভালে শতাব্দী প্রাচীন একটি মসজিদে সমীক্ষা পরিচালনা ঘিরে সংঘর্ষে নিহতদের সংখ্যা বেড়ে ছয়জনে দাঁড়িয়েছে। এর সঙ্গে জড়িত সন্দেহে ২৫ জনকে গ্রেপ্তার করা হয়েছে।
# 193    পাকিস্তানে সাবেক প্রধানমন্ত্রী ইমরান খানের সমর্থকরা পুলিশ, রেঞ্জার্স এবং সেনাবাহিনীর সব বাধা অতিক্রম করে রাজধানী ইসলামাবাদের মূল কেন্দ্র ডি-চকে পৌঁছেছেন। কিন্তু সেখানে পরিস্থিতির অবনতি হয়েছে।
# 194    ইউরোপীয় ইউনিয়নের (ইইউ) পররাষ্ট্রনীতি প্রধান জোসেপ বোরেল ইসরায়েলকে লেবাননের সঙ্গে প্রস্তাবিত যুদ্ধবিরতির চুক্তিতে সম্মতি জানানোর আহ্বান জানিয়েছেন। এর আগে ইরান-সমর্থিত কট্টরপন্থীদের সমালোচনা করা হচ্ছিল।
# 195    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের ডাকা 'চূড়ান্ত বিক্ষোভে' রাজধানী ইসলামাবাদ কার্যত অচল হয়ে পড়েছে। সেনাবাহিনীর গুলিতে অন্তত পাঁচজন নিহত হয়েছে বলে খবর পাওয়া গেছে। এর মধ্যে পুলিশও আটক হয়েছে।
# 196    ইন্দোনেশিয়ার সুমাত্রা দ্বীপে আকস্মিক বন্যা ও ভূমিধসের ঘটনায় এখন পর্যন্ত ১৬ জনের মৃত্যু হয়েছে এবং আরও ৭ জন নিখোঁজ রয়েছেন। বন্যায় সবচেয়ে বেশি ক্ষতিগ্রস্ত এলাকায় সেনাবাহিনী ও উদ্ধারকর্মীরা মোতায়েন করা হয়েছে।
# 197    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের মুক্তির দাবিতে তেহরিক-ই-ইনসাফ (পিটিআই) পার্টির আহ্বানে বিক্ষোভ কর্মসূচিকে ঘিরে উত্তাল দেশটির বিভিন্ন শহরে সহিংসতার খবর পাওয়া গেছে।
# 198    জাতিসংঘ বলছে, ২০২৩ সালে বিশ্বব্যাপী প্রতিদিন ১৪০ জন নারী তার সঙ্গী বা পরিবারের সদস্যের হাতে হত্যার শিকার হয়েছেন। এই সংখ্যা আগের তুলনায় বেড়েছে বলে তারা মনে করছেন।
# 199    যুক্তরাষ্ট্রের নব-নির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের বিরুদ্ধে দায়ের করা একটি মামলা খারিজ করেছেন দেশটির एकটি আদালত। এর মধ্যে সাবেক এক পর্ণতারকাকে ঘুষ দেয়াও হয়েছে।
# 200    যুদ্ধবিরতির আলোচনার মধ্যেও লেবাননে হামলা অব্যাহত রেখেছে ইসরায়েলি বাহিনী। জাতিসংঘের মতো একাধিক দেশ আশা করছে মঙ্গলবার দেশটির মন্ত্রিসভা হিজুল্লাহর সঙ্গে সংঘর্ষ-বিরতি সম্পন্ন করা সম্ভব হবে।
# 201    পাকিস্তানের ফেডারেল রাজধানী ইসলামাবাদে সংবিধানের অনুচ্ছেদ ২৪৫-এর আওতায় সেনাবাহিনীকে মাঠে নামানো হয়েছে, যাতে অস্থিতিশীলতা এবং সশস্ত্র হামলাকারীদের শক্ত হাতে দমন করা হয়েছে।
# 202    মার্কিন যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প জানুয়ারিতে ক্ষমতা গ্রহণের আগেই বিদেশি শিক্ষার্থী ও কর্মীদেরকে নিজ নিজে ক্যাম্পাসে ফিরে আসার পরামর্শ দিয়েছে দেশটির বিশ্ববিদ্যালয়গুলো। এমন সতর্কবার্তায় অনেকে চিন্তায় পড়েছেন।
# 203    পাকিস্তানের রাজধানী ইসলামাবাদে সাবেক প্রধানমন্ত্রী ইমরান খানের মুক্তি ও সরকারের পদত্যাগের দাবিতে বিক্ষোভকারীদের সঙ্গে সংঘর্ষে অন্তত চারজন নিহত হয়েছে বলে খবর পাওয়া গেছে। এর মধ্যে একজন পুলিশ কর্মকর্তাকে গুলি করে হত্যা করা হয়েছে।
# 204    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের মুক্তি এবং সরকারের পদত্যাগের দাবিতে বিক্ষোভে উত্তাল রাজধানী ইসলামাবাদ। এর আগে থেকেই তাকে 'রেড জোনে' পৌঁছাতে শুরু করেছে পিটিআই নেতাকর্মীরা।
# 205    ইরান সমর্থিত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহর সঙ্গে অবশেষে যুদ্ধবিরতিতে যাচ্ছে ইসরায়েল। এর আগে মার্কিন প্রেসিডেন্ট জো বাইডেন এবং ফরাসি প্রধানমন্ত্রী ইমানুয়েল ম্যাক্রো এই ঘোষণা দেবেন।
# 206    ভারতের উত্তর প্রদেশের সম্ভলের শাহী জামা মসজিদকে ঘিরে তীব্র উত্তেজনার মধ্যে এখনও পর্যন্ত আরও একজনের জীবনের খবর পাওয়া গেছে। এই নিয়ে বিতর্কে অন্তত চারজন মারা গেছেন।
# 207    প্রেসিডেন্ট হিসেবে দায়িত্ব নেওয়ার প্রথমদিনেই চীন, কানাডা ও মেক্সিকোর বিরুদ্ধে ব্যবস্থা নিচ্ছেন বলে অঙ্গীকার করেছেন যুক্তরাষ্ট্রের নব-নির্বাচিত প্রেস কনফারেন্স ডোনাল্ড ট্রাম্প।
# 208    স্পেনে এক নার্সিং অ্যাসিস্টেন্টকে হত্যার দায়ে চারজনকে অভিযুক্ত করেছে দেশটির একটি আদালত। এরপর দেশজুড়ে হেট ক্রাইম চালানোর ঘটনা ঘটেছে বলে জানা যাচ্ছে। এ নিয়ে বিতর্ক শুরু হয়েছে।
# 209    পাকিস্তানের রাজধানী ইসলামাবাদের উপকণ্ঠে নিরাপত্তা বাহিনীর সদস্যদের সঙ্গে সাবেক প্রধানমন্ত্রী ইমরান খানের কর্মী-সমর্থকদের ব্যাপক সংঘর্ষের ঘটনা ঘটেছে। এতে এক পুলিশ ব্যক্তি নিহত হয়েছে।
# 210    মিশরের লোহিত সাগরে একটি পর্যটকবাহী ইয়ট ডুবে অন্তত ১৭ জন নিখোঁজ হয়েছেন বলে জানিয়েছে মিশর কর্তৃপক্ষ। এদের মধ্যে ব্রিটিশ নাগরিকও রয়েছেন। যুক্তরাজ্যসহ বিভিন্ন দেশের ৩১ জনকে উদ্ধার করা হয়েছে।
# 211    ইউক্রেনের কাছে মার্কিন যুক্তরাষ্ট্রের 'এন্টি পার্সনাল' স্থলমানই সরবরাহ করার নতুন হুমকির নিন্দা করেছেন জাতিসংঘের মহাসচিব এন্তোনিও গুতেরেস। ওয়াশিংটনের সঙ্গে কিয়েভে ল্যান্ডমাইন চুক্তির অগ্রগতি পর্যালোচনা
# 212    কুরস্ক অঞ্চলে ইউক্রেনের পক্ষে যুদ্ধ করার সময় এক সাবেক ব্রিটিশ নাগরিককে আটক করেছে রুশ বাহিনী। এই খবর পাওয়া গেছে একটি টেলিগ্রাম ভিডিওতে। সেখানে তিনি চেয়ারে বসে আছেন।
# 213    ইরানের সর্বোচ্চ নেতা আয়াতুল্লাহ আলী খামেনি বলেছেন, গাজা ও লেবাননে ইহুদিবাদী সরকার যে যুদ্ধাপরাধ করেছে, তার জন্য ইসরায়েলের গ্রেপ্তারি পরোয়ানা যথেষ্ট নয় এবং এসব অপরাধী নেতাদের মৃত্যুদণ্ড কার্যকর করতে হবে।
# 214    ফিলিপাইনের প্রেসিডেন্ট ফার্দিনান্দ মার্কোসের স্ত্রী এবং প্রতিনিধি পরিষদের স্পিকারকে 'প্রকাশ্যে হত্যার হুমকি' দেওয়ার পর তাদের মধ্যে উত্তেজনা চরমে পৌঁছেছে বলে অভিযোগ উঠেছে।
# 215    বৈদ্যুতিক গাড়ি নির্মাতা প্রতিষ্ঠান টেসলার প্রধান নির্বাহী কর্মকর্তা ইলন মাস্কের সম্পদ অর্জনের দিক দিয়ে নতুন রেকর্ড গড়েছেন। এতে তার নিট সম্পদের পরিমাণ ৭০০ কোটি ডলার।
# 216    ইসরায়েলি প্রাচীনতম সংবাদমাধ্যম হারেৎজের সঙ্গে সম্পর্ক ছিন্ন এবং সরকারি অর্থায়নকারী সংস্থাগুলোকে পত্রিকাটি নিয়ে যোগাযোগ বা বিজ্ঞাপন দেওয়ার ওপর নিষেধাজ্ঞা আরোপ করেছে দেশটির প্রধানমন্ত্রী বেনিয়ামিন নেতানিয়াহু।
# 217    ভারতের রাজ্যসভার শীতকালীন অধিবেশনের প্রথম দিনই সংসদে ব্যাপক তোলপাড় শুরু হয়েছে। প্রধানমন্ত্রী নরেন্দ্র মোদি বলেছেন, জনগণ যাদের ক্রমাগত প্রত্যাখ্যান করেছে তাদেরাই সংসদকে নিয়ন্ত্রণের চেষ্টা করছে।
# 218    লিথুয়ানিয়ানিয়ার ভিলনিয়াস বিমানবন্দরে অবতরণের সময় একটি বিমান বিধ্বস্ত হয়েছে। এতে অন্তত একজন নিহত হওয়ার পর ফ্লাইটটি মাটিতে আছড়ে পড়ে এবং টুকরো হয়ে গেছে বলে জানিয়েছে পুলিশ।
# 219    ইরান সমর্থিত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহ সঙ্গে ইসরায়েল একটি যুদ্ধবিরতি চুক্তির দিকে অগ্রসর হচ্ছে। কিন্তু এখনও দুই পক্ষের মধ্যে কোনো সবুজ সংকেত দেয়নি।
# 220    ইরান ও মিশর যেমন একে অপরের খুব কাছাকাছি এসেছে, তেমনই আবার সংঘাত ও শত্রুতার পথ বেছে নিয়েছে দুটি দেশের কূটনৈতিক সম্পর্ক। কিন্তু এখনও এই দুইটি বন্ধুত্বের ইতিহাসে একেবারে তলানিতে ঠেকেছে
# 221    লেবাননের দক্ষিণাঞ্চলের বিভিন্ন গ্রামে ও শহরে ব্যাপক বোমা হামলা চালাচ্ছে ইসরায়েলি বাহিনী। এতে অন্তত একজন নিহত হয়েছে বলে জানাচ্ছে দেশটির রাষ্ট্রীয় গণমাধ্যম। এর মধ্যে তেল আবিবে ক্ষয়ক্ষতিও হয়েছে।
# 222    যুক্তরাষ্ট্রের নব-নির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের মনোনীত জাতীয় নিরাপত্তা উপদেষ্টা মাইকেল ওয়াল্টজ বলেছেন, ইউক্রেনে রাশিয়ার সঙ্গে চলমান যুদ্ধের একটি দায়িত্বশীল সমাপ্তি টানা দরকার।
# 223    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের মুক্তির দাবিতে রাজধানী ইসলামাবাদে বিক্ষোভের আয়োজন করার চেষ্টা করে তার সমর্থকরা। গত কয়েকদিন ধরে তিনি এভাবেই সরকারের কাছে পদত্যাগ করছেন।
# 224    ইরানের বিরুদ্ধে হামলার প্রস্তুতি নিচ্ছে ইরান। দেশটির সর্বোচ্চ নেতা আলি লারিজানি বলেছেন, তারা যুক্তরাষ্ট্রের সমর্থনের উপর নির্ভর করছে। কিন্তু তিনি এমন পরিকল্পনা করছেন।
# 225    মানবতা বিরোধী ও যুদ্ধাপরাধের অভিযোগে অভিযুক্ত ইসরায়েলের প্রধানমন্ত্রী বেনিয়ামিন নেতানিয়াহুকে গ্রেপ্তারের ঘোষণা দিয়েছে ব্রিটিশ সরকার। এর মধ্যে যুক্তরাজ্য বলছে, তারা নির্দিষ্ট কোনো মামলা নিয়ে কথা বলবে না।
# 226    ভারতে উত্তরপ্রদেশের সম্ভলে মুঘল যুগের একটি প্রাচীন মসজিদে 'সার্ভে' বা সমীক্ষা করানোর নির্দেশকে ঘিরে স্থানীয় জনতা ও পুলিশের মধ্যে সংঘর্ষের ঘটনায় অন্তত তিন জন নিহত হয়েছেন।
# 227    ইরান সমর্থিত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহ দাবি করেছে, তারা ইসরায়েলের উপকণ্ঠে ব্যাপক হামলা চালিয়েছে। তেল আবিবে ক্ষয়ক্ষতি হয়েছে বলে জানাচ্ছে দেশটির সেনাবাহিনী।
# 228    ব্রাজিলে একটি যাত্রীবাহী বাস খাদে পড়ে অন্তত ২২ জন নিহত হয়েছে বলে দেশটির গণমাধ্যম জানিয়েছে। এর মধ্যে এক নারীসহ অন্তঃসত্ত্বা এক নারীকে মৃত্যুর ঘটনা ঘটেছে বলে জানা যাচ্ছে।
# 229    বাংলাদেশের রাজধানী ঢাকায় যুবদল নেতা শামীম জিয়ার হত্যার ঘটনায় আওয়ামী লীগের দু'জন নেতার রিমান্ড মঞ্জুর করা হয়েছে। গ্রেপ্তার হওয়া তিন জনের বিরুদ্ধে আজ শুনানি শুরু হবে।
# 230    জমকালো আয়োজনে সৌদি আরবের রিয়াদে অনুষ্ঠিত হয়ে গেল বাংলাদেশ কালচারাল উৎসব, যেটি বিশ্বের বিভিন্ন প্রান্তের মানুষকে আকর্ষণ করেছে বলে জানিয়েছে দেশটির মিডিয়া মন্ত্রণালয় এবং জেনারেল এন্টারটেইনমেন্ট অথরিটি।
# 231    ব্রিটেনে মার্কিন বিমান বাহিনীর ব্যবহৃত তিনটি ঘাঁটির ওপর দিয়ে অজ্ঞাত ড্রোন উড়তে দেখা গেছে বলে নিশ্চিত করেছে দেশ দুটি। যুক্তরাষ্ট্র এবং ব্রিটিশ প্রতিরক্ষা মন্ত্রণালয় বলছে, তারা হুমকিকে গুরুত্বের সঙ্গে নিয়েছে।
# 232    পাকিস্তানের উত্তর-পশ্চিমাঞ্চলে তিন দিনের রক্তক্ষয়ী জাতিগত সহিংসতায় কমপক্ষে ৮২ জন নিহত হয়েছে। একই সময়ে আহত হচ্ছে আরও ১৫৬ জন। এদের মধ্যে সুন্নি আর শিয়া।
# 233    ভারতের উত্তরপ্রদেশে মুঘল আমলের সামভাল শাহী জামে মসজিদকে ঘিরে ব্যাপক উত্তেজনা দেখা দিয়েছে। স্থানীয় পুলিশ বলছে, সেখানে গুলি চালিয়ে তিন মুসলিমকে হত্যা করা হয়েছে।
# 234    যুক্তরাষ্ট্রের ক্যালিফোর্নিয়ার ৮৭টি বিশ্ববিদ্যালয় ও উচ্চশিক্ষা প্রতিষ্ঠানের ৪৯ শতাংশ মুসলিম শিক্ষার্থী হয়রানি ও বৈষম্যের শিকার হওয়ার কথা জানিয়েছেন। তারা বলেছেন, তাদের ক্যাম্পাসে স্বাধীনভাবে মতামত প্রকাশ করতে অনিচ্ছুক।
# 235    সরকারি কর্মকর্তাদের কয়েক মিলিয়ন ডলার ঘুষ দেওয়া ও বিনিয়োগকারীদের কাছ থেকে অর্থ নেওয়ার তথ্য গোপনের ঘটনায় অভিযুক্ত ভারতীয় ধনকুবের গৌতম আদানির বিরুদ্ধে সমন জারি করেছে মার্কিন সিকিউরিটিজ অ্যান্ড এক্সচেঞ্জ কমিশন।
# 236    গাজা উপত্যকার উত্তরাঞ্চলে ইসরায়েলি সেনাবাহিনীর হামলায় তাদের দেশের এক নারী জিম্মি নিহত হয়েছেন। যুদ্ধাপরাধী বেনিয়ামিন নেতানিয়াহুর জোট সরকারের পতনের ভয়ে এই ঘটনা ঘটেছে।
# 237    তুরস্কের ঐতিহাসিক অঞ্চল আনাতোলিয়ার কাছে রোমান সম্রাট হাদ্রিয়ানের অধীনে নির্মিত প্রাচীন 'কেস্ট্রোস ফোয়ারা' পুনরুদ্ধার করা হয়েছে। এটি ১৮০০ বছর পর আবার প্রবাহিত হলো।
# 238    দ্বিতীয়বারের মতো নেপালের রাজধানী কাঠমান্ডুতে পবিত্র কোরআন (মুখস্থ) প্রতিযোগিতার আয়োজন করছে সৌদি আরব। ইসলাম বিষয়ক মন্ত্রণালয়ের দাওয়াহ ও গাইডেন্স কর্মকর্তারা এতে অংশ নেবেন।
# 239    ট্রান্সজেন্ডার নিষিদ্ধের পর এবার যেসব দেশে লিঙ্গ পরিবর্তন পদ্ধতি অনুমোদন করা হয়, সেখানে শিশুদের দত্তক দেওয়ার ওপর নিষেধাজ্ঞা দিল রাশিয়া। এর আগে ইউক্রেন সংঘাতের কারণে এ ধরনের বিধিনিষেধ আরোপকারী সব দেশের মধ্যে ট্রা
# 240    লেবানন থেকে ৩০টি রকেট হামলা চালানো হয়েছে বলে জানিয়েছে ইসরায়েলি বাহিনী। এতে অন্তত ২০ জন নিহত হয়েছে এবং আরো কয়েকজন ক্ষতিগ্রস্ত হওয়ার খবর পাওয়া গেছে বলে জানানো হয়েছে।
# 241    বাংলাদেশের সাবেক প্রধানমন্ত্রী ও পাকিস্তান তেহরিক-ই-ইনসাফের (পিটিআই) প্রতিষ্ঠাতা ইমরান খানের মুক্তির দাবিতে যুক্তরাষ্ট্রে নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের বাসভবনের সামনে জড়ো হয়েছেন তার সমর্থকরা।
# 242    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের ডাকা বাঁচা-মরার বিক্ষোভ রুখে দিতে ইসলামাবাদে ১৪৪ ধারা জারি করা হয়েছে। এর মধ্যে বিভিন্ন জায়গায় মোবাইল ও ইন্টারনেট পরিষেবা বন্ধ করে দেওয়া হয়েছে বলে অভিযোগ পাওয়া যাচ্ছে।
# 243    জর্ডানের রাজধানী আম্মানে ইসরায়েলি দূতাবাসের কাছে গোলাগুলি হয়েছে। এতে এক বন্দুকধারীর নিহত হওয়ার পর তিনজন পুলিশ সদস্য আহত হয়েছেন বলে দেশটির নিরাপত্তা বাহিনীর বরাত দিয়ে এই খবর পাওয়া যাচ্ছে।
# 244    সৌদি আরবে গিয়ে ভিক্ষাবৃত্তি ঠেকাতে নিজ নাগরিকদের বিরুদ্ধে কঠোর ব্যবস্থা নিচ্ছে পাকিস্তান। এর মধ্যে একটি হচ্ছে, 'এক্সিট কন্ট্রোল' লিস্টে ৪ হাজার ৩০০ ভিক্ষুক পাঠিয়ে দিয়েছে দেশটি।
# 245    কানাডার মাটিতে শিখ নেতা হরদীপ সিং নিজ্জর হত্যাকাণ্ডের ঘটনায় ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদি ও পররাষ্ট্রমন্ত্রী এস জয়শঙ্করের সংযোগ আছে-এমন খবর প্রকাশের পর নিজ দেশের গোয়েন্দা কর্মকর্তাদের 'ক্রিমিন্যাল' বলেছেন দেশটি।
# 246    ফিলিস্তিনের স্বাধীনতাকামী সশস্ত্র সংগঠন হামাস নিয়ন্ত্রিত গাজায় অবিরাম হামলা চালিয়ে যাচ্ছে ইসরায়েলি বাহিনী। সেইসঙ্গে লেবাননের রাজধানী বৈরুতে একটি অ্যাপার্টমেন্ট ব্লকে বিস্ফোরণ চালানো হয়েছে।
# 247    রাশিয়া ইউক্রেনের দিনিপ্রো শহরে নতুন একটি ক্ষেপণাস্ত্র হামলা চালিয়েছে, যেটি ভীষণ শক্তিশালী বলে বর্ণনা করেছে রুশ প্রেসিডেন্ট ভ্লাদিমির পুতিন। তিনি বলেছেন, এই আক্রমণটি একে আন্তঃমহাদেশীয় ব্যালিস্টিক ক্ষ
# 248    আজারবাইজানের রাজধানী বাকুতে চলমান কপ-২৯ সম্মেলনে জলবায়ু পরিবর্তনের কারণে হুমকিতে থাকা উন্নয়নশীল ও স্বল্পোন্নত দেশ ও দ্বীপরাষ্ট্রগুলোর জন্য বছরে ৩০০ বিলিয়ন ডলার সাহায্য দিতে সম্মত হয়েছে বৃহৎ অর্থনীতির দেশগুলো।
# ...
# 418    ইসরায়েলের ড্রোন আর বিমান হামলা থেকে পালিয়ে পার্শ্ববর্তী মিশরে আশ্রয় নিয়েছেন এক নারী। কিন্তু তার জীবনের সব কিছু বদলে দিয়েছে তিনি। সমুদ্র এখন মৃত্যুর নীরব দর্শক সাক্ষী।
# 419    ভারতের বিনোদন জগতে গত কয়েক মাস ধরে বেশ আলোচনার শীর্ষে থাকেন অনন্ত-রাধিকার জুটি। কিন্তু এবারের এই বিয়ের পর থেকে শোরগোল ফেলেছে ভারতীয় গণমাধ্যম এবং সামাজিক যোগাযোগ মাধ্যমে।
# 420    যুক্তরাষ্ট্রের নব-নির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প বৃহস্পতিবার (১৪ নভেম্বর) বলেছেন, আমার প্রশাসন রাশিয়া-ইউক্রেন যুদ্ধ থামাতে দৃঢ়ভাবে কাজ করবে। এর সঙ্গে যোগ দিয়েছেন আনাদোলু এজেন্সি।
# 421    আমেরিকার টিকাবিরোধী ও চিকিৎসাশাস্ত্রে ষড়যন্ত্রের তাত্ত্বিক হিসেবে পরিচিত রবার্ট এফ কেনেডি জুনিয়রকে মার্কিন স্বাস্থ্য ও মানবিক সেবা দপ্তরের মন্ত্রী নিয়োগ দিয়েছেন নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প।
# 422    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের ট্রানজিশন টিমের সদস্যরা তাদের সামরিক কর্মকর্তাদের বরখাস্তের একটি তালিকা তৈরি করেছেন। এই তালিকায় মার্কিন প্রতিরক্ষা দপ্তরের সাবেক চেয়ারম্যানও থাকতে পারেন।
# 423    জাতিসংঘে নিযুক্ত ইরানের দূতের সঙ্গে দেখা করেছেন মার্কিন ধনকুবের ও নবনির্বাচিত ডোনাল্ড ট্রাম্পের ঘনিষ্ঠ মিত্র ইলন মাস্ক। নিউ ইয়র্ক টাইমসের প্রতিবেদনে এই খবর উঠে এসেছে।
# 424    শীত মৌসুম শুরুর আগেই ভয়াবহ বায়ুদূষণে বিপর্যস্ত হয়ে পড়েছে ভারতের রাজধানী নয়াদিল্লি। ধোঁয়াশায় আচ্ছন্ন দিল্লির পরিস্থিতির উন্নতি ঘটাতে বেশ কিছু পদক্ষেপ নিয়েছে সেখানকার কর্তৃপক্ষ।
# 425    সিরিয়ার রাজধানী দামেস্কের আবাসিক ভবনে অতর্কিত হামলা চালিয়েছে ইসরায়েলি বাহিনী। এতে অন্তত ১৫ জন নিহত হয়েছে। হত্যার সংখ্যা আরও বাড়তে পারে বলে আশঙ্কা প্রকাশ করা হচ্ছে।
# 426    ইরান সমর্থত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহ দাবি করেছে, তারা ইসরায়েলের আরেক সামরিক ঘাঁটিতে হামলা চালিয়েছে। কিন্তু এতে কোন ক্ষয়ক্ষতি বা হতাহতের ঘটনা ঘটেছে।
# 427    গাজায় দখলদার ইসরায়েলি সরকারকে বেআইনিভাবে প্রাণঘাতী অস্ত্র সরবরাহ চালিয়ে যাওয়ার সিদ্ধান্তের নিন্দা জানিয়েছে আন্তর্জাতিক মানবাধিকার সংগঠন আনাদোলুর সংস্থা। যুক্তরাষ্ট্রের পররাষ্ট্র দপ্তর বলেছে, এ ব্যাপারে নীতিগত কোনও পরিবর্তন নেই
# 428    রাশিয়ার প্রেসিডেন্ট ভ্লাদিমির পুতিনকে হত্যার আহ্বানসহ রুশ সেনাদের নিয়ে মিথ্যা তথ্য ছড়ানোর দায়ে এক থিয়েটার পরিচালককে ৮ বছরের কারাদণ্ড দিয়েছে দেশটির সামরিক আদালত।
# 429    মার্কিন প্রেসিডেন্ট নির্বাচনে ডোনাল্ড ট্রাম্পের প্রতি ইলন মাস্কের অকুণ্ঠ সমর্থনের পুরস্কার হিসেবে তাকে প্রশাসনের এক গুরুত্বপূর্ণ পদে নিয়োগ দেওয়ার ঘোষণার পর তিনি বলেছেন, সরকারি ব্যয়, আমলাতন্ত্র ও নিয়ন্ত্রণ কমানোর উদ্দেশ্যে একটি নত
# 430    সৌদি আরবের রিয়াদে একটি জমকালো ফ্যাশন শো অনুষ্ঠিত হয়েছে। সেখানে সেলিন ডিওন, জেনিফার লোপেজ, হ্যালি বেরিদের মতো একঝাঁক তারকাকে নিয়ে হাজির হন মডেলরা।
# 431    যুক্তরাষ্ট্রের সামরিক সহায়তা বন্ধ করে দিলে ইউক্রেন শিগগিরই তাদের দেশে থাকা পরমাণু চুল্লিগুলোতে অপরিশোধিত অস্ত্র তৈরির কাজ শুরু করতে পারে বলে আভাস দিয়েছে দেশটির প্রতিরক্ষা মন্ত্রণালয়।
# 432    যুক্তরাষ্ট্রে নতুন মেয়াদে ডোনাল্ড ট্রাম্প নির্বাচিত হওয়ার পর আগে যে কোন কর্মকর্তাকে বরখাস্ত করা হবে, সেই তালিকা তৈরি করেছেন তার একটি ট্রানজিশন টিম। এই পরিকল্পনাকে সমর্থন করতে যাচ্ছেন তিনি।
# 433    গাজায় ইসরায়েলি সেনাবাহিনীর যুদ্ধের পদ্ধতিকে 'গণহত্যার সঙ্গে সামঞ্জস্যপূর্ণ' বলে মনে করেছে জাতিসংঘের একটি আন্তর্জাতিক মানবিক সংগঠনের একদল কর্মকর্তার এক কমিটি।
# 434    জার্মানির চ্যান্সেলর ওলাফ শলৎস বলেছেন, আগামী বছরের ফেব্রুয়ারিতে নির্বাচনের আগে বেশ কিছু আইন পাস করানোর জন্য আবেদন করেছেন। এর মধ্যে আর্থিক উন্নয়ন এবং শিশুদের সুবিধা পাসের মেয়াদ বৃদ্ধির মতো বিল
# 435    যুক্তরাষ্ট্রের প্রেসিডেন্ট হিসেবে তৃতীয় মেয়াদে প্রতিদ্বন্দ্বিতা করার বিষয়ে মন্তব্য করেছেন নবনির্বাচিত ডোনাল্ড ট্রাম্প। এর জের ধরে তিনি বলেছেন, তার ধারণা আমি আরেক বারের মতো নির্বাচন করতে পারব না।
# 436    মার্কিন প্রেসিডেন্ট নির্বাচনে জয়লাভের পর পাকিস্তানের সাবেক প্রধানমন্ত্রী ও पाकिस्तान-তেহরিক-ই-ইনসাফের (পিটিআই) প্রতিষ্ঠাতা ইমরান খান জেল থেকে চূড়ান্ত আন্দোলনের ডাক দিয়েছেন।
# 437    ইরান সমর্থিত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহর সঙ্গে সংঘর্ষে অন্তত ছয়জন ইসরায়েলি সেনা নিহত হয়েছে। এই নিয়ে গত ৩০ সেপ্টেম্বর থেকে যুদ্ধ শুরু হচ্ছে।
# 438    ইরানের একজন সুপরিচিত মানবাধিকার কর্মী দেশটির সর্বোচ্চ নেতা আয়াতুল্লাহ আলী খামেনির 'স্বৈরতন্ত্র বা ফ্যাসিবাদের' বিরুদ্ধে প্রতিবাদ জানাতে আত্মহত্যা করেছেন। এই ঘটনা ঘটেছে গত কয়েকদিন ধরে।
# 439    যুক্তরাষ্ট্রের গোয়েন্দা সংস্থার পরিচালক হিসেবে সাবেক ডেমোক্র্যাট তুলসী গ্যাবার্ডের নাম বুধবার (১৩ নভেম্বর) ঘোষণা করেছেন নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। তিনি এই প্রথম হিন্দু প্রতিনিধি হতে যাচ্ছেন।
# 440    ব্রাজিলের রাজধানী ব্রাসিলিয়ায় সুপ্রিম কোর্ট এবং কংগ্রেসের কাছে জোড়া বিস্ফোরণের ঘটনা ঘটেছে। এতে অন্তত একজন নিহত হয়েছে বলে খবর পাওয়া যাচ্ছে। হামলার উদ্দেশ্য সম্পর্কে এখন পর্যন্ত জানা যায়নি।
# 441    যুক্তরাষ্ট্রের প্রেসিডেন্ট নির্বাচনে বিজয়ী প্রার্থী ডোনাল্ড ট্রাম্প তার প্রশাসনের গুরুত্বপূর্ণ দায়িত্বের তালিকায় নতুন করে চার হাজার পদে নিয়োগ দেবেন বলে ঘোষণা করেছেন। এর মধ্যে বেশ কয়েকজন কর্মকর্তাও রয়েছেন।
# 442    হোয়াইট হাউজে যুক্তরাষ্ট্রের বিদায়ী প্রেসিডেন্ট জো বাইডেনের সঙ্গে বুধবার (১৩ নভেম্বর) সাক্ষাৎ করেছেন ডোনাল্ড ট্রাম্প। এরপর ওয়াশিংটন ডিসির উদ্দেশে রওনা দেন তিনি।
# 443    মালয়েশিয়ায় সাবেক অর্থমন্ত্রী দাইম জয়নুদ্দিন মারা গেছেন। দেশটির প্রধানমন্ত্রী মাহাথির মোহাম্মদ বলেছেন, তিনি এমন একজন বন্ধুকে হারালাম, যে আমার সঙ্গে জাতি-দেশ ও ধর্মের জন্য লড়াই করেছিল।
# 444    গত মাসে ইরানে ইসরায়েলের ক্ষেপণাস্ত্র হামলার আগে পরিকল্পনার গোপন তথ্য ফাঁসের অভিযোগে বিদেশে যুক্তরাষ্ট্র সরকারের হয়ে কাজ করা এক ব্যক্তিকে আটক করেছে মার্কিন গুপ্তচর সংস্থা এফবিআই।
# 445    ইসরায়েলের বিরুদ্ধে অস্ত্র নিষেধাজ্ঞা সমর্থন করার জন্য রাশিয়া ও চীনের প্রশংসা করেছেন তুরস্কের প্রেসিডেন্ট রিসেপ তাইয়্যেপ এরদোয়ান। তিনি বলেছেন, হামলা বন্ধ থাকলে ফিলিস্তিন ও লেবাননের মানবিক পরিস্থিতির প্রতিদিনই অব
# 446    ইয়েমেন উপকূল থেকে যাত্রা করার সময় ইরান সমর্থিত হুথি যোদ্ধাদের ক্ষেপণাস্ত্র ও ড্রোন হামলার শিকার হয়েছে কয়েকটি মার্কিন যুদ্ধজাহাজ। যুক্তরাষ্ট্রের সামরিক বাহিনীর কর্মকর্তা বলছেন, এই অভিযান সফলভাবে প্রতিহত হয়েছে।
# 447    ইন্টারন্যাশনাল চেম্বার্স অফ কমার্স (কপ-২৯) সম্মেলনে যোগ দেননি ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদি। জলবায়ু পরিবর্তনের কারণে গত দশকে বিশ্বের বিভিন্ন দেশের ক্ষতির পরিমাণ দুই ট্রিলিয়ন ডলারে পৌঁছেছে।
# 448    আন্তর্জাতিক আণবিক শক্তি সংস্থার (আইএইএ) মহাপরিচালক রাফায়েল গ্রসি বলেছেন, ইরানের পারমাণু অস্ত্র তৈরি করার বিষয়টি এমন একটি ভবিষ্যতের ইঙ্গিত, যেখানে হামলার লক্ষ্যবস্তু হয়ে দাঁড়াতে পারে।
# 449    ২০২৪ সালের বুকার পুরস্কার জিতেছেন যুক্তরাজ্যের লেখক সামান্থা হার্ভে। 'অরবিটাল' বইটি মহাকাশ নিয়ে লেখা একটি গল্পের জন্য তিনি এ পুরষ্কারজয়ী ঘোষণা করেছেন।
# 450    পাকিস্তানে বিয়ের অনুষ্ঠান থেকে অতিথিদের বাড়িতে নিয়ে যাওয়ার সময় একটি বাস নদীতে পড়ার পর ডুবে অন্তত ১৪ জন নিহত হয়েছেন বলে দেশটির কর্মকর্তারা জানিয়েছেন। এর মধ্যে একমাত্র নববধূই বেঁচে আছেন।
# 451    মার্কিন যুক্তরাষ্ট্রের নবনিযুক্ত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প নির্বাচনী প্রচারণায় প্রতিশ্রুতি দিয়েছিলেন যে তিনি দেশটির কেন্দ্রীয় সরকারকে ঢেলে সাজাবেন। এই ঘোষণার পর নতুন করে দুই ব্যবসায়ীকে চাকরি বাতিলের দায়িত্ব দিয়েছেন।
# 452    লেবাননে ইসরায়েলি সামরিক বাহিনীর হামলায় কমপক্ষে ২৩ জন নিহত হয়েছে বলে জানিয়েছে দেশটির স্বাস্থ্য মন্ত্রণালয়। এর মধ্যে আরো আটজন আহত হওয়ার খবর নিশ্চিত করেছে সরকারের কর্মকর্তারা।
# 453    সদ্য নির্বাচিত মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প তার নতুন প্রশাসনের 'সরকারি দক্ষতা বিভাগের (ডিওজিই)' নেতৃত্ব দেওয়ার জন্য ইলন মাস্ককে বেছে নিয়েছেন। অন্যদিকে স্পেসএক্সের প্রতিষ্ঠাতা বিবেক রামাস্বামী এবং টেসলার
# 454    সদ্য নির্বাচিত মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প ফক্স নিউজের উপস্থাপক পিট হেগসেথকে প্রতিরক্ষামন্ত্রী হিসেবে ঘোষণা দিয়েছেন। তিনি বলেছেন, যুক্তরাষ্ট্রের সামরিক বাহিনী আবার দুর্দান্ত হবে।
# 455    যুক্তরাষ্ট্রে নবনির্বাচিত রিপাবলিকান প্রেসিডেন্ট ডনাল্ড ট্রাম্প তার প্রথম দিনেই অভিবাসন এবং মেক্সিকো সীমান্তে দেয়াল প্রশ্নে বেশ কিছু নির্বাহী পদক্ষেপ নেবেন বলে ধারণা করা হচ্ছে।
# 456    রাশিয়ায় শীর্ষ ব্যক্তিদের বিরুদ্ধে 'মিথ্যা রায়' দেওয়ার অভিযোগে আন্তর্জাতিক অপরাধ আদালতের (আইসিসি) বিচারক হাইকেল বেন মাহফুদকে গ্রেপ্তারি পরোয়ানা জারি করেছে মস্কোর একটি আদালত।
# 457    গাজা উপত্যকায় ইসরায়েলি বাহিনীর আকস্মিক বিমান হামলায় দুই নবজাতকসহ ছয়জন নিহত হওয়ার পর সেখানকার একটি হাসপাতাল থেকে তাদের মায়েদের বের করে দিয়েছে স্থানীয় একজন সাংবাদিক।
# 458    যুক্তরাষ্ট্রে সোনার দাম প্রায় দুই মাসের মধ্যে সর্বনিম্ন স্তরে নেমে এসেছে। বাজার বিশ্লেষকরা বলছেন, মার্কিন ডলারের মানের মান শক্তিশালী হওয়ার কারণে এই ধাতুটি মূল্যবান।
# 459    জার্মানিতে আগাম নির্বাচন অনুষ্ঠিত হতে যাচ্ছে বলে জানিয়েছে দেশটির চ্যান্সেলর ওলাফ শলৎস। এর আগে গত সপ্তাহে জোট সরকারে ভাঙন দেখা দেওয়ার পর এই নির্বাচনের তারিখ নির্ধারণ করা হয়েছে।
# 460    জেরুজালেমে ফ্রান্স নিয়ন্ত্রিত একটি সম্পত্তিতে সশস্ত্র ইসরায়েলি নিরাপত্তা বাহিনীর প্রবেশ ও কূটনীতিক কর্মকর্তাদের আটক নিয়ে চটেছে ইউরোপের দেশটি। এ ঘটনার পুনরাবৃত্তি করা হবে না।
# 461    চীনের দক্ষিণাঞ্চলে একটি আউটডোর স্পোর্টস সেন্টারের মাঠে শরীরচর্চারত নাগরিকদের ওপর উঠাে গেলে অন্তত ৪০ জনেরও বেশি আহত হয়েছেন। স্থানীয় পুলিশ বলছে, একজন গাড়িচালক তাকে ধরে ফেলেছে।
# 462    পূর্ব আফ্রিকার জাতীয় নির্বাচনে 'অ্যালায়েন্স ফর চেঞ্জ' নামের একটি জোট ভূমিধস জয় পেয়েছে। এর ফলে দেশটির প্রধানমন্ত্রীর প্রত্যাবর্তন ঘটবে বলে আশঙ্কা করা হচ্ছে বলে জানা যাচ্ছে।
# 463    রাশিয়ার সঙ্গে ব্যাপক কৌশলগত অংশীদারিত্ব চুক্তি অনুমোদন করেছে উত্তর কোরিয়া। দুই দেশই ইউক্রেন সংঘাতে যুক্তরাষ্ট্রকে সমর্থন করার প্রতিশ্রুতি রয়েছে এবং যুদ্ধাবস্থায় থাকার ক্ষেত্রে একে অপরকে সহায়তা করবে।
# 464    ভারতের পররাষ্ট্রমন্ত্রী বলেছেন, মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের নেতৃত্বাধীন দুই দেশের মধ্যে শুল্ক যুদ্ধের আশঙ্কা রয়েছে এবং তারা তাদের সঙ্গে কাজ করতে অস্বস্তিতে নেই।
# 465    ভারতের পূর্বাঞ্চলীয় রাজ্য ঝাড়খণ্ডে আগামী ১৩ নভেম্বর বিধানসভা নির্বাচনের ভোটগ্রহণ অনুষ্ঠিত হবার আগে ব্যাপক অভিযান শুরু করেছে দেশটির কেন্দ্রীয় অর্থ মন্ত্রণালয়ের একটি সংস্থা।
# 466    ভারতের উত্তরপূর্বাঞ্চলীয় রাজ্য মণিপুরের জিরিবাম জেলায় অনির্দিষ্টকালের জন্য কারফিউ জারি করেছে সেখানকার প্রশাসন। হিন্দুস্তান টাইমসের এক প্রতিবেদনে বলা হয়েছে, ওই জেলাগুলিতে অন্তত ১০ জন সশস্ত্র গোষ্ঠীর সদস্য নিহত হয়েছেন।
# 467    নিউজিল্যান্ডের প্রধানমন্ত্রী ক্রিস্টোফার লুকসন পার্লামেন্টে অত্যাচার এবং হেনস্থার ঘটনা নিয়ে ক্ষমা চেয়েছেন। তিনি বলেছেন, এই ঘটনাটি আর কখনো ঘটেছে না, সেই দিকে নজর দেওয়া হবে।
# 468    সৌদি আরবের যুবরাজ মোহাম্মদ বিন সালমান ইসরায়েলের বিরুদ্ধে গাজায় গণহত্যার অভিযোগ করেছেন। সেইসঙ্গে ইরানের মাটিতে হামলার ঘটনার সমালোচনা করেছে দেশটির পররাষ্ট্রমন্ত্রী প্রিন্স ফয়সাল বিন ফারহান আল-সৌদ।
# 469    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্প দেশটির নতুন পররাষ্ট্রমন্ত্রী হিসেবে সিনেটর মার্কো রুবিওকে বেছে নিতে পারেন। এর আগে থেকেই এই পদে শোনা যাবে ক্যাপিটল হিলসের নাম।
# 470    ফিলিস্তিনের স্বাধীনতাকামী সশস্ত্র গোষ্ঠী হামাস নিয়ন্ত্রিত গাজায় এবং লেবাননে ইসরায়েলি বাহিনীর আগ্রাসন অবিলম্বে বন্ধের আহ্বান জানিয়েছেন সৌদি আরবের যুবরাজ মোহাম্মদ বিন সালমান।
# 471    সিরিয়ায় বিমান হামলা চালানো হয়েছে বলে যুক্তরাষ্ট্রের সেন্ট্রাল কমান্ড (সেন্টকম) নিশ্চিত করেছে। এর আগে ইরান সমর্থিত সশস্ত্র গোষ্ঠীগুলোর বিরুদ্ধে আক্রমণ চালিয়েছে মার্কিন বাহিনী।
# 472    জাতিসংঘে যুক্তরাষ্ট্রের দূত পদে নিয়োগ দেওয়ার জন্য এলিস স্টেফানিককে বেছে নিয়েছেন নবনির্বাচিত মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। এর আগে হোয়াইট হাউসের 'চিফ অব স্টাফ' হিসেবে সুসি ওয়াইলসকে দায়িত্ব দেওয়া হয়েছিল।
# 473    মহাকাশে উৎক্ষেপণ করা একটি পুরোনো স্যাটেলাইট রহস্যজনকভাবে নির্দিষ্ট অবস্থান থেকে কয়েক হাজার মাইল দূরে চলে গেছে। বিজ্ঞানীরা বলছেন, এটি ইচ্ছাকৃতভাবে সরানো হয়েছে।
# 474    ফিলিস্তিনের স্বাধীনতাকামী সশস্ত্র গোষ্ঠী হামাস নিয়ন্ত্রিত গাজায় অবিরাম হামলা চালিয়ে যাচ্ছে ইসরায়েলি বাহিনী। এতে অন্তত ১০ জন নিহত হয়েছে বলে জানাচ্ছেন স্থানীয় সংবাদমাধ্যম আল-জাজিরা।
# 475    ভারতে ক্ষমতাসীন দল বিজেপি ভারতের ঝাড়খণ্ডে আদিবাসী নারীদের বিয়ে করে তাদের ভাগের সমস্ত সুবিধা ভোগ করছে বলে অভিযোগ উঠেছে। কিন্তু এ নিয়ে কোনও রাজনীতি করা উচিত নয়।
# 476    ভারতের মণিপুর রাজ্যে নিরাপত্তা বাহিনীর সঙ্গে বন্দুকযুদ্ধে অন্তত ১১ জন সন্দেহভাজন কুকি সন্ত্রাসী নিহত হয়েছে বলে স্থানীয় গণমাধ্যমগুলো জানিয়েছে। এই হামলায় সিআরপিএফের এক জওয়ান গুরুতর আহত হবার খবর পাওয়া গেছে।
# 477    ইসরায়েলি প্রধানমন্ত্রী বেনিয়ামিন নেতানিয়াহুর নির্দেশে ইরান-সমর্থিত লেবাননের সশস্ত্র গোষ্ঠী হিজবুল্লাহর বিরুদ্ধে সেপ্টেম্বর মাসে পেজার বিস্ফোরণের ঘটনা ঘটেছে বলে জানিয়েছে তার অফিস।
# 478    সৌদি আরবের যুবরাজ মোহাম্মদ বিন সালমান বলেছেন, ইরানের সার্বভৌমত্বের প্রতি সম্মান দেখানোর জন্য ইসরায়েলকে আহ্বান জানিয়েছেন দেশটির শীর্ষ নেতাদের একটি সম্মেলনে তিনি। কিন্তু এই মন্তব্য করেছেন দেশটি 'গণহত্যা' চালাচ্ছে।
# 479    কুয়েতে একদিনে রেকর্ডসংখ্যক ব্যক্তির নাগরিকত্ব বাতিল করা হচ্ছে, যা দেশটির ইতিহাসে এই প্রথমবারের মতো নতুন করে পরিণত হতে যাচ্ছে বলে খবর পাওয়া গেছে। এর আগে ২০ অক্টোবরের মধ্যে দেশটি সবচেয়ে বেশি অভিবাসী
# 480    সৌদি আরব এবং ইরানের মধ্যে বৈরি সম্পর্ক স্বাভাবিক থাকলে দুই দেশেরই স্বার্থ রক্ষা হতে পারে বলে আশঙ্কা করা হচ্ছে। কিন্তু ইরান বলছে, এখন তারা নতুন এক রাজনৈতিক সূচনা করছে।
# 481    রাশিয়ার সঙ্গে চলমান যুদ্ধের অবসান ঘটানোর জন্য ইউক্রেনের প্রেসিডেন্ট ভলোদিমির জেলেনস্কি কূটনৈতিক প্রচেষ্টার ওপর গুরুত্ব দিয়েছেন। তিনি বলেছেন, এ ধরনের সংঘাতের সমাপ্তি ঘটাতে শক্তির বিষয়টিও সমান হয়ে উঠতে হবে।
# 482    মার্কিন প্রেসিডেন্ট জো বাইডেনকে তার শেষ প্রতিশ্রুতি পূরণের আহ্বান জানিয়েছেন ডেমোক্র্যাটিক পার্টির সাবেক কর্মকর্তা জামাল সিমন্স। তিনি বলেছেন, "এটি একটি বড় পরিবর্তন আনবে, যা যুক্তরাষ্ট্রের রাজনীতির চেহারা পাল্টে দেবে।"
# 483    ডলারের বিপরীতে ভারতীয় রুপির মান সর্বনিম্ন পর্যায়ে নেমে এসেছে। ফরেক্স বিশেষজ্ঞরা বলছেন, বিদেশি তহবিলের প্রবাহ কমে গেলে এই রেকর্ডটি ঠেকাতে পারেনি ভারত।
# 484    গায়ানার প্রধানমন্ত্রী গ্যারি কনিলকে ক্ষমতাচ্যুত করা হয়েছে। দেশটির প্রেসিডেন্ট হিসেবে দায়িত্ব গ্রহণের ছয় মাস পূর্ণ হওয়ার আগেই তাকে স্থলাভিষিক্ত করেছে একটি সাবেক সিনেট প্রার্থী।
# 485    যুক্তরাষ্ট্রে প্রেসিডেন্ট নির্বাচন শেষ হতেই এখন সিনেটের নতুন নেতা  নির্বাচনের নিয়ে তৎপরতা শুরু হয়েছে। এর আগে রিক স্কটের নাম উঠে এসেছে। এবারের ভোটে তিনি আরও এক মেয়াদের জন্য পুন:নির্বাচিত হয়েছেন।
# 486    মার্কিন প্রেসিডেন্ট নির্বাচনে রিপাবলিকান প্রার্থী ডোনাল্ড ট্রাম্প সাবেক পুলিশ ও অভিবাসন কর্মকর্তা টম হোমানকে দেশের সীমান্ত রক্ষার দায়িত্ব দিয়েছেন। এই পদে যোগ দেবেন তিনি।
# 487    উত্তর কোরিয়ার সঙ্গে পারস্পরিক প্রতিরক্ষা সহায়তা সংক্রান্ত একটি কৌশলগত অংশীদারিত্ব চুক্তিকে আইন পরিণত করেছে রাশিয়া। এর ফলে দুই দেশের মধ্যে সম্পর্ক আরও ঘনিষ্ঠ হয়ে উঠেছে।
# 488    রাশিয়ার রাজধানী মস্কোকে লক্ষ্য করে ইউক্রেনের ছোড়া ২৫টি ড্রোন ভূপাতিত করার দাবি করেছে দেশটির প্রেসিডেন্ট এমানুয়েল ম্যাক্রঁ। হামলার ফলে বেশ কয়েকটি বাড়ি আগুনে পুড়ে গেছে।
# 489    প্রবল চাপের মুখে এবার সুর পাল্টালেন জার্মান চ্যান্সেলর ওলাফ শলৎস। শেষমেশ তিনি বড়দিনের আগেই আস্থাভোট নিতে রাজি হয়েছেন। এবং এর আগে থেকেই তাকে ক্ষমতায় সেঁটে বসে থাকতে হবে না।
# 490    গত ৫ নভেম্বরের নির্বাচনের পর থেকে নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের সঙ্গে তিনবার কথা হয়েছে বলে জানিয়েছেন ইসরায়েলের প্রধানমন্ত্রী বেনিয়ামিন নেতানিয়াহু। এই প্রথমবারের মতো তিনি দেশটির ইতিহাসের সবচেয়ে বড় প্রত্যাবর্তন ঘোষণা
# 491    ইরানের দক্ষিণাঞ্চলীয় সিস্তান-বেলুচিস্তান প্রদেশে সীমান্তবর্তী এক ঘাঁটিতে হামলা চালিয়েছে সন্ত্রাসীরা। এতে দেশটির ইসলামিক রেভল্যুশনারি গার্ড কর্পসের পাঁচ সদস্য নিহত হয়েছে।
# 492    রাশিয়ার প্রেসিডেন্ট ভ্লাদিমির পুতিনের সঙ্গে ফোনে কথা বলেছেন যুক্তরাজ্যের নবনির্বাচিত রাষ্ট্রপতি ডোনাল্ড ট্রাম্প। এর আগে কথোপকথনে যোগ দিয়েছিলেন মার্কিন ধনকুবের ইলন মাস্কি।
# 493    যুক্তরাষ্ট্রের প্রেসিডেন্ট পদপ্রার্থী ডোনাল্ড ট্রাম্প বলে থাকেন যে ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদি তার বন্ধু। তিনি দাবি করেন, এই দুজনের সম্পর্ক নিয়ে তারা কতটা আলোচনা করেছেন? তিরিশ দিনের ওপর চালানোর চেষ্টা করা হচ্ছে।
# 494    যুক্তরাষ্ট্রের নবনির্বাচিত প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের নারী ও অভিবাসন নীতির বিরুদ্ধে দেশটির বিভিন্ন স্থানে বিক্ষোভ হয়েছে। এর মধ্যে ছিলেন অ্যাডভোকেসি গ্রুপের কর্মীরা এবং অভিবাসীরা।
# 495    যুক্তরাষ্ট্রের এক দম্পতির ঘরের মধ্যে বড় ধরনের ঝগড়া বাঁধে তাদের বাবা-মাকে। এরপর তারা ছুরি আর গুলির আঘাত করেছিলেন। এ ঘটনা ঘটেছে রান্না ঘরে। সেখানে দুজনই খেলছিলেন ভিডিও গেমস খেলছিল।
# 496    গাজা এবং লেবাননে ইসরাইলের চলমান আগ্রাসনের প্রেক্ষাপটে আরব ও মুসলিম দেশগুলোর নেতারা সোমবার সৌদি আরবে একটি সম্মেলনে মিলিত হওয়ার কথা ঘোষণা করেছে। এর মধ্যে যোগ দেবেন নাইজেরিয়ার প্রেসিডেন্ট বোলা তিনুবু।
# 497    অভাবী শিশুদের জন্য বুকের দুধ দান করে বিশ্ব রেকর্ড করেছেন যুক্তরাষ্ট্রের টেক্সাসের অ্যালিসা ওগলেট্রি নামের এক মা। তিনি বলেছেন, 'আমার হৃদয় অনেক বড়, আর দিন শেষে টাকাপয়সা দিয়ে কাউকে সহায়তা করতে পারি না।'
# 498    গত এক সপ্তাহে সৌদি আরবজুড়ে ২০ হাজারেরও বেশি অবৈধভাবে বসবাস করা প্রবাসী ও সংশ্লিষ্টদের গ্রেপ্তার  করেছে দেশটির স্বরাষ্ট্র মন্ত্রণালয়। এর মধ্যে ইথিওপিয়ান এবং ইয়েমেনি নাগরিকরাও রয়েছেন।
# 499    ক্রিপ্টোকারেন্সি বিটকয়েন ফের (বিটিসি) সর্বকালের সর্বোচ্চ রেট ৮০,০০০ ডলারে পৌঁছেছে। মূল্যবৃদ্ধির এই প্রথম ঘটনা হলেও এটি এখন রেকর্ড গড়েছে।

# %%
df = pd.read_csv('/content/drive/My Drive/Colab/international_zeroshot.csv')

# Display the first few rows to verify the file is loaded properly
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং...
# 1           1  যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2           2  সিরিয়ায় বিদ্রোহীদের সমর্থনের পেছনে যুক্তরাষ্...
# 3           3  জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4           4  পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...
#
#                                         givenSummary  \
# 0  আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং...
# 1  যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2  সিরিয়ায় বিদ্রোহীদের সমর্থনের পেছনে যুক্তরাষ্...
# 3  জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4  পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...
#
#                                       mT5_Test_XLSum
# 0  পৃথিবী, সূর্য এবং বৃহস্পতি গ্রহ একই সরলরেখায় ...
# 1  যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2  সিরিয়ায় আল-কায়েদা সন্ত্রাসী গোষ্ঠীর সমর্থনে...
# 3  জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4  পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...

# %%
df
# Out:
#      Unnamed: 0                                               text  \
# 0             0  আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং...
# 1             1  যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2             2  সিরিয়ায় বিদ্রোহীদের সমর্থনের পেছনে যুক্তরাষ্...
# 3             3  জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4             4  পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...
# ..          ...                                                ...
# 495         495  ঘরের মধ্যে ঝগড়া বাঁধে দুজনের মধ্যে। সেটি রূপ ন...
# 496         496  গাজা এবং লেবাননে ইসরাইলের চলমান আগ্রাসনের প্রে...
# 497         497  অভাবী শিশুদের জন্য বুকের দুধ দান করে বিশ্ব রেক...
# 498         498  গত এক সপ্তাহে সৌদি আরবজুড়ে ২০ হাজারেরও বেশি অ...
# 499         499  শীর্ষস্থানীয় ক্রিপ্টোকারেন্সি বিটকয়েন ফের (ব...
#
#                                           givenSummary  \
# 0    আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং...
# 1    যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2    সিরিয়ায় বিদ্রোহীদের সমর্থনের পেছনে যুক্তরাষ্...
# 3    জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4    পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...
# ..                                                 ...
# 495  ঘরের মধ্যে ঝগড়া বাঁধে দুজনের মধ্যে। সেটি রূপ ন...
# 496  গাজা এবং লেবাননে ইসরাইলের চলমান আগ্রাসনের প্রে...
# 497  অভাবী শিশুদের জন্য বুকের দুধ দান করে বিশ্ব রেক...
# 498  গত এক সপ্তাহে সৌদি আরবজুড়ে ২০ হাজারেরও বেশি অ...
# 499  শীর্ষস্থানীয় ক্রিপ্টোকারেন্সি বিটকয়েন ফের (ব...
#
#                                         mT5_Test_XLSum
# 0    পৃথিবী, সূর্য এবং বৃহস্পতি গ্রহ একই সরলরেখায় ...
# 1    যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া রাজ্যের কিছু অং...
# 2    সিরিয়ায় আল-কায়েদা সন্ত্রাসী গোষ্ঠীর সমর্থনে...
# 3    জলবায়ু পরিবর্তন রোধ করা না হলে, বিশেষ করে গ্র...
# 4    পাকিস্তানের কারাবন্দি সাবেক প্রধানমন্ত্রী ইমরা...
# ..                                                 ...
# 495  যুক্তরাষ্ট্রের এক দম্পতির ঘরের মধ্যে বড় ধরনের...
# 496  গাজা এবং লেবাননে ইসরাইলের চলমান আগ্রাসনের প্রে...
# 497  অভাবী শিশুদের জন্য বুকের দুধ দান করে বিশ্ব রেক...
# 498  গত এক সপ্তাহে সৌদি আরবজুড়ে ২০ হাজারেরও বেশি অ...
# 499  ক্রিপ্টোকারেন্সি বিটকয়েন ফের (বিটিসি) সর্বকাল...
#
# [500 rows x 4 columns]

# %%
# View the original text, given summary, and generated summary for the first row
sample_index = 0  # You can change this to inspect different rows

# Access text, given summary (if available), and generated summary
original_text = df['text'][sample_index]
given_summary = df['givenSummary'][sample_index]  # If present in the CSV
generated_summary = df['mT5_Test_XLSum'][sample_index]

# Print the text and corresponding summaries
print(f"Original Text:\n{original_text}\n")
print(f"Given Summary (if available):\n{given_summary}\n")
print(f"Generated Summary:\n{generated_summary}\n")
# Out:
# Original Text:
# আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং বৃহস্পতি গ্রহ একই সরলরেখায় অবস্থান করবে। ফোর্বস ম্যাগাজিনের এক প্রতিবেদনে এ তথ্য জানানো হয়েছে।
# এতে বলা হয়, শনিবার সারারাত আকাশে দৃশ্যমান থাকবে বৃহস্পতি গ্রহ। এই অবস্থানকে বলা হয় ‘জুপিটারর্স অপজিশন’।
# ফোর্বসের তথ্য অনুযায়ী, শনিবার বৃহস্পতিকে দেখার জন্য এই সময়ের আগে-পরে এক মাস ধরে এই বিস্ময়কর ঘটনা পর্যবেক্ষণের সুযোগ থাকবে। এমনকি একটি ছোট টেলিস্কোপ বা সাধারণ দূরবীন দিয়েও এই গ্রহের সৌন্দর্য উপভোগ করা যাবে।
# এমন বিরল মহাজাগতিক ঘটনা কেবল সৌরজগতের রহস্য ও সৌন্দর্যের প্রতি মানুষের কৌতুহল বাড়ায়।
# বিজ্ঞানীরা বলেছেন, শুক্রবার পৃথিবী থেকে প্রায় ৬১১ মিলিয়ন কিলোমিটার বা ৩৮০ মিলিয়ন মাইল দূরে  থাকবে বৃহস্পতি। এই দূরত্বে বৃহস্পতিকে বেশ উজ্জল দেখাবে।
#
#
# Given Summary (if available):
# আগামীকাল শনিবার (৭ ডিসেম্বর) পৃথিবী, সূর্য এবং বৃহস্পতি গ্রহ একই সরলরেখায় অবস্থান করবে। ফোর্বস ম্যাগাজিনের এক প্রতিবেদনে এ তথ্য জানানো হয়েছে।
#
# Generated Summary:
# পৃথিবী, সূর্য এবং বৃহস্পতি গ্রহ একই সরলরেখায় অবস্থান করবে বলে জানিয়েছে মার্কিন মহাজাগতিক সংস্থা 'ফোর্বস ম্যাগাজিন'। এই ঘটনা পর্যবেক্ষণের জন্য মানুষের কৌতুহল বাড়ছে।

# %% [markdown]
# # **ROGUE SCORE**

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.6)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.9)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.4 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 12.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.6)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=128e51bee435258ee9192ba386a97b5dfab0323381a57c86c1a02ce23b918e1f
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# !pip install rouge

import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from rouge import Rouge
from csv import DictReader
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# 1000
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def rougeScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)
    # return SummaryEv
    urlCSV = '/content/' + columnName + 'CSV.csv'
    SummaryEv.to_csv(urlCSV, index=False)

    with open(urlCSV, 'r') as f:
        dict_reader = DictReader(f)
        SummaryEv_dict = list(dict_reader)

    EvJson = json.dumps(SummaryEv_dict, indent = 4)
    JSON = columnName + 'EvJson.json'
    save_file_at_dir('/content', JSON, EvJson)

    urlJSON = '/content/' + columnName + 'EvJson.json'

    with open(urlJSON) as f:
        SummaryEvData = json.load(f)
    lenS = len(SummaryEvData)
    rscore1r = 0
    rscore1p = 0
    rscore1f = 0
    rscore2r = 0
    rscore2p = 0
    rscore2f = 0
    rscorelr = 0
    rscorelp = 0
    rscorelf = 0
    rouge = Rouge()
    for i in range(lenS):
        score = rouge.get_scores(SummaryEvData[i][columnName], SummaryEvData[i]['givenSummary'])
        rscore1r = rscore1r + score[0]['rouge-1']['r']
        rscore1p = rscore1p + score[0]['rouge-1']['p']
        rscore1f = rscore1f + score[0]['rouge-1']['f']
        rscore2r = rscore2r + score[0]['rouge-2']['r']
        rscore2p = rscore2p + score[0]['rouge-2']['p']
        rscore2f = rscore2f + score[0]['rouge-2']['f']
        rscorelr = rscorelr + score[0]['rouge-l']['r']
        rscorelp = rscorelp + score[0]['rouge-l']['p']
        rscorelf = rscorelf + score[0]['rouge-l']['f']

        # rscore = [[rscore1r/lenS, rscore1p/lenS, rscore1f/lenS],
        #           [rscore2r/lenS, rscore2p/lenS, rscore2f/lenS],
        #           [rscorelr/lenS, rscorelp/lenS, rscorelf/lenS]]

    rscore = {'rouge-1': {'r': rscore1r/lenS,
                        'p': rscore1p/lenS,
                        'f': rscore1f/lenS},
                'rouge-2': {'r': rscore2r/lenS,
                        'p': rscore2p/lenS,
                        'f': rscore2f/lenS},
                'rouge-l': {'r': rscorelr/lenS,
                        'p': rscorelp/lenS,
                        'f': rscorelf/lenS}}
    return rscore

# %%
mx = rougeScore('mT5_Test_XLSum')
mx
# Out:
# {'rouge-1': {'r': 0.452949015792821,
#   'p': 0.499434280865112,
#   'f': 0.463707789101785},
#  'rouge-2': {'r': 0.3351511045819442,
#   'p': 0.37575814362427523,
#   'f': 0.34409960167402437},
#  'rouge-l': {'r': 0.4295132855927926,
#   'p': 0.47202124681964575,
#   'f': 0.4390089115231012}}

# %%
def getScore(m, n, x):
    strs = 'rouge-'+str(n)
    return m[strs][x]

# %%
data = {'columns':['rouge-1 r', 'rouge-1 p', 'rouge-1 f', 'rouge-2 r', 'rouge-2 p', 'rouge-2 f', 'rouge-l r', 'rouge-l p', 'rouge-l f'],
        'mT5_Test_XLSum':[getScore(mx, 1, 'r'), getScore(mx, 1, 'p'), getScore(mx, 1, 'f'), getScore(mx, 2, 'r'), getScore(mx, 2, 'p'), getScore(mx, 2, 'f'), getScore(mx, 'l', 'r'), getScore(mx, 'l', 'p'), getScore(mx, 'l', 'f')],
       }

rougeDf = pd.DataFrame(data)
rougeDf_ = rougeDf
rougeDf = rougeDf.reset_index(drop=True).T
rougeDf = rougeDf.rename(columns=rougeDf.iloc[0]).drop(rougeDf.index[0])
rougeDf.reset_index(inplace=True)
rougeDf = rougeDf.rename(columns = {'index':'Summary'})
rougeDf
# Out:
#           Summary rouge-1 r rouge-1 p rouge-1 f rouge-2 r rouge-2 p rouge-2 f  \
# 0  mT5_Test_XLSum  0.452949  0.499434  0.463708  0.335151  0.375758    0.3441
#
#   rouge-l r rouge-l p rouge-l f
# 0  0.429513  0.472021  0.439009

# %%
import matplotlib.pyplot as plt

# plotting graph
rougeDf.plot(x="Summary",
               y=['rouge-1 r',
                'rouge-1 p',
                'rouge-1 f',
                'rouge-2 r',
                'rouge-2 p',
                'rouge-2 f',
                'rouge-l r',
                'rouge-l p',
                'rouge-l f'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Rouge Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **BLEU SCORE**

# %%
import os
import json
from csv import DictReader

def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

genDf.to_csv('/content/bleuEvCSV.csv', index=False)

with open("/content/bleuEvCSV.csv", 'r') as f:
    dict_reader = DictReader(f)
    bleu_dict = list(dict_reader)
print(len(bleu_dict))

bleuEvJson = json.dumps(bleu_dict, indent = 4)
save_file_at_dir('/content', 'bleuEvJson.json', bleuEvJson)

with open('/content/bleuEvJson.json') as f:
  bleuData = json.load(f)
# Out:
# 500

# %%
import nltk

def bleuCorpass(columnName):
    ble1score = 0
    ble2score = 0
    ble3score = 0
    ble4score = 0
    for i in range(len(bleuData)):
        hypothesis = bleuData[i][columnName].split()
        reference = bleuData[i]['givenSummary'].split()
        references = [reference]
        list_of_references = [references]
        list_of_hypotheses = [hypothesis]
        ble1score = ble1score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(1, 0, 0, 0))
        ble2score = ble2score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.5, 0.5, 0, 0))
        ble3score = ble3score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.33, 0.33, 0.33, 0))
        ble4score = ble4score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.25, 0.25, 0.25, 0.25))

    print("Bleu 1: ", ble1score/len(bleuData),'\n')
    print("Bleu 2: ", ble2score/len(bleuData),'\n')
    print("Bleu 3: ", ble3score/len(bleuData),'\n')
    print("Bleu 4: ", ble4score/len(bleuData),'\n')

    return ble1score/len(bleuData), ble2score/len(bleuData), ble3score/len(bleuData), ble4score/len(bleuData)

# %%
print('mT5_Test_XLSum:', bleuCorpass('mT5_Test_XLSum'))
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Bleu 1:  0.38282051366309205
#
# Bleu 2:  0.33037251511516347
#
# Bleu 3:  0.29152574953197913
#
# Bleu 4:  0.25436890289378417
#
# mT5_Test_XLSum: (0.38282051366309205, 0.33037251511516347, 0.29152574953197913, 0.25436890289378417)

# %% [markdown]
# # **BERTSCORE**

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.46.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
from evaluate import load
bertscore = load("bertscore")
# Out:
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]

# %%
import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from csv import DictReader
# Out:
# 8200
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def bertScore(columnName):
    SummaryEv = genDf.filter(['text', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    bert_precision = 0
    bert_recall = 0
    bert_f1 = 0

    for i in range(lenS):
        results = bertscore.compute(predictions=[SummaryEv[columnName][i]], references=[SummaryEv['text'][i]], lang="bn")

        bert_precision = bert_precision + results['precision'][0]
        bert_recall = bert_recall + results['recall'][0]
        bert_f1 = bert_f1 + results['f1'][0]

    bert_score = {'precision': bert_precision/lenS,
                    'recall': bert_recall/lenS,
                    'f1': bert_f1/lenS}
    return bert_score

# %%
mx = bertScore('mT5_Test_XLSum')
mx
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# {'precision': 0.8372355169057846,
#  'recall': 0.6699233261346818,
#  'f1': 0.7440957123041153}

# %%
def getScore(m, x):
    strs = x
    return m[strs]

# %%
import pandas as pd

data = {'columns':['bert_precision', 'bert_recall', 'bert_f1'],
        'mT5_Test_XLSum':[getScore(mx, 'precision'), getScore(mx, 'recall'), getScore(mx, 'f1')],
       }

bertScoreDf = pd.DataFrame(data)
bertScoreDf_ = bertScoreDf
bertScoreDf = bertScoreDf.reset_index(drop=True).T
bertScoreDf = bertScoreDf.rename(columns=bertScoreDf.iloc[0]).drop(bertScoreDf.index[0])
bertScoreDf.reset_index(inplace=True)
bertScoreDf = bertScoreDf.rename(columns = {'index':'Summary'})
bertScoreDf
# Out:
#           Summary bert_precision bert_recall   bert_f1
# 0  mT5_Test_XLSum       0.837236    0.669923  0.744096

# %%
import matplotlib.pyplot as plt

# plotting graph
bertScoreDf.plot(x="Summary",
               y=['bert_precision',
                'bert_recall',
                'bert_f1'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Bert Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **WIL WER METEOR WITH GIVEN SUMMARY**

# %%
from collections import Counter

class MeteorScore:
    def __init__(self, alpha=0.5, beta=0.5, gamma=0.5):
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma

    def preprocess_sentence(self, sentence):
        words = sentence.split()
        return words

    def ngram_count(self, sentence, n):
        words = self.preprocess_sentence(sentence)
        ngrams = [tuple(words[i:i+n]) for i in range(len(words)-n+1)]
        return Counter(ngrams)

    def compute_precision(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        precision = overlap / sum(hyp_counts.values()) if sum(hyp_counts.values()) > 0 else 0
        return precision

    def compute_recall(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        recall = overlap / sum(ref_counts.values()) if sum(ref_counts.values()) > 0 else 0
        return recall

    def meteor_score(self, hypothesis, reference):
        precision = self.alpha * self.compute_precision(hypothesis, reference, 1) + (1-self.alpha) * self.compute_precision(hypothesis, reference, 2)
        recall = self.beta * self.compute_recall(hypothesis, reference, 1) + (1-self.beta) * self.compute_recall(hypothesis, reference, 2)
        fmean = (1-self.gamma) * precision + self.gamma * recall if (precision != 0 and recall != 0) else 0
        return fmean

# %%
# !pip install jiwer
import jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading jiwer-3.0.5-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.9 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.5 rapidfuzz-3.10.1

# %%
meteor = MeteorScore(alpha=0.5, beta=0.5, gamma=0.5)

def wilWerMeteorScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    wer_score = 0
    meteor_score = 0
    wil_score = 0

    for i in range(lenS):
        wer_result = jiwer.wer(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])
        meteor_result = meteor.meteor_score(SummaryEv[columnName][i], SummaryEv['givenSummary'][i])
        wil_result = jiwer.wil(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])

        wer_score = wer_score + wer_result
        meteor_score = meteor_score + meteor_result
        wil_score = wil_score + wil_result

    wilWerMeteor_score = {'METEOR': meteor_score/lenS,
                    'WER': wer_score/lenS,
                    'WIL': wil_score/lenS}

    return wilWerMeteor_score
    # return spice_score/lenS

# %%
mx = wilWerMeteorScore('mT5_finetuned_test')
mx
# Out:
# {'METEOR': 0.3694995375541737,
#  'WER': 1.1714886828484485,
#  'WIL': 0.8061316430611867}

# %%
import pandas as pd

data = {'columns':['WIL', 'METEOR', 'WER'],
        'mT5_finetuned_test':[getScore(mx, 'WIL'), getScore(mx, 'METEOR'), getScore(mx, 'WER')],
       }

threeScoreDf = pd.DataFrame(data)
threeScoreDf_ = threeScoreDf
threeScoreDf = threeScoreDf.reset_index(drop=True).T
threeScoreDf = threeScoreDf.rename(columns=threeScoreDf.iloc[0]).drop(threeScoreDf.index[0])
threeScoreDf.reset_index(inplace=True)
threeScoreDf = threeScoreDf.rename(columns = {'index':'Summary'})
threeScoreDf
# Out:
#               Summary       WIL  METEOR       WER
# 0  mT5_finetuned_test  0.806132  0.3695  1.171489

# %%
import matplotlib.pyplot as plt

# plotting graph
threeScoreDf.plot(x="Summary",
               y=['WIL', 'METEOR', 'WER'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Three Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a bar chart
plt.figure(figsize=(12, 6))
bar_width = 0.35
x = np.arange(len(metrics))

plt.bar(x, values, width=bar_width, color='skyblue')
plt.xticks(x, metrics, rotation=45, ha='right')
plt.ylabel('Score')
plt.title('Evaluation Metrics for Text Summarization')

# Optionally add a grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a DataFrame
df = pd.DataFrame({'Metric': metrics, 'Score': values})

# Display the table
print(df)

# If you want to export the table to a CSV file
# df.to_csv('/content/summary_evaluation_metrics.csv', index=False)
# Out:
#                    Metric   Score
# 0            ROUGE-1 (F1)  0.1666
# 1            ROUGE-2 (F1)  0.0598
# 2            ROUGE-L (F1)  0.1535
# 3                  BLEU-1  0.1067
# 4                  BLEU-2  0.0529
# 5                  BLEU-3  0.0256
# 6                  BLEU-4  0.0104
# 7   BERTScore (Precision)  0.8277
# 8      BERTScore (Recall)  0.6640
# 9          BERTScore (F1)  0.7366
# 10                 METEOR  0.1642
# 11                    WER  3.1958

# %% [markdown]
# **DATA VISUALIZATION**

# %%
import matplotlib.pyplot as plt

human_lengths = genDf['givenSummary'].apply(lambda x: len(x.split()))
generated_lengths = genDf['mT5_finetuned_test'].apply(lambda x: len(x.split()))

plt.scatter(human_lengths, generated_lengths)
plt.xlabel('Human Summary Length')
plt.ylabel('Generated Summary Length')
plt.title('Human vs. Generated Summary Length')
plt.show()

# %%
gen_length = [len(summary.split()) for summary in genDf["mT5_finetuned_test"]]
ref_length = [len(summary.split()) for summary in genDf["givenSummary"]]

plt.figure(figsize=(10, 6))
plt.scatter(ref_length, gen_length, alpha=0.5)
plt.xlabel("Reference Summary Length (words)")
plt.ylabel("Generated Summary Length (words)")
plt.title("Generated vs. Reference Summary Length")
plt.plot([0, max(ref_length)], [0, max(ref_length)], color='red', linestyle='--')  # Diagonal line
plt.show()

# %% [markdown]
# # **TEST (NOT INCLUDED)**

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from normalizer import normalize  # Assuming you have this installed
import re

# Device setup
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# Load the model and tokenizer
model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Move the model to the correct device (GPU or CPU)
model.to(device)

# Define the whitespace handler
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

# Function to generate a summary
def generate_summary(input_text):
    # Normalize the text (if needed)
    input_text = normalize(input_text)

    # Tokenize the input text
    input_ids = tokenizer(
        [WHITESPACE_HANDLER(input_text)],
        return_tensors="pt",
        padding="max_length",
        max_length=512,
        truncation=True
    )["input_ids"]

    # Generate the summary
    output_ids = model.generate(
        input_ids=input_ids.to(device),
        max_length=400,
        min_length=64,
        no_repeat_ngram_size=2,
        num_beams=4
    )[0]

    # Decode the generated summary
    summary = tokenizer.decode(
        output_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return summary
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
# Example of custom input text
custom_text = """
  'ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়ার গাড়ি, বাড়ি, প্লট, ফ্ল্যাট-কী নেই। রীতিমতো গড়েছেন সম্পদের পাহাড়। শুধু নিজের
  নামেই নয়; স্ত্রী, ছেলে-মেয়ে এবং শ্যালক-শ্যালিকার নামেও গড়েছেন বিপুল সম্পত্তি।\nঅভিযোগ রয়েছে, ডিএমপিতে ‘ঘুষ’ এবং বদলি বাণিজ্যে গড়ে তুলেছেন এসব
  সম্পদ। তার বিপুল সম্পদের বিষয়ে অনুসন্ধান চালাচ্ছে দুর্নীতি দমন কমিশন (দুকক)। যুগান্তরের অনুসন্ধানি প্রতিবেদনে এসব তথ্য ওঠে এসেছে।\nপ্রতিবেদনে জানা যায়,
  রাজধানীর অভিজাত এলাকা সিদ্ধেশ্বরীর ভিকারুননিসা স্কুলের পাশেই রূপায়ণ স্বপ্ন নিলয়। ৫৫/১ হোল্ডিংয়ে আলিশান এ ভবনটি ১১ তলা। এখানে প্রায় সাড়ে ৩ হাজার বর্গফিটের
  একটি ফ্ল্যাট রয়েছে আছাদুজ্জামানের মেয়ে আয়েশা সিদ্দিকার নামে।\nশুক্রবার (২৩ আগস্ট) দুপুরে সেখানে গেলে নিরাপত্তা ইনচার্জ আবুল কালাম আজাদ যুগান্তরকে
   বলেন, তিনি মাস দেড়েক আগে এখানে চাকরি নিয়েছেন। এই ভবনে ১৩০টি ফ্ল্যাট। তাই সব ফ্ল্যাট মালিককে ভালোভাবে চিনেন না। বাড়ির ম্যানেজার সোহেল পারভেজ
    বিস্তারিত বলতে পারবেন বলে জানান তিনি।\nএ বিষয়ে সোহেল পারভেজ জানান, আয়েশা সিদ্দিকার নামে এখানে একটি ফ্ল্যাট আছে। তবে তিনি কখনো এখানে আসেন না।
    এটি ভাড়া দেওয়া আছে।\nধানমন্ডি ১২/এ নম্বর রোডের ৬৯ নম্বর বাড়িতে রয়েছে একটি বিলাসবহুল ফ্ল্যাট। শুক্রবার দুপুরে ওই বাড়িতে যাওয়া হলে ভেতরে প্রবেশের অনুমতি
    মেলেনি। তবে নিজের নাম প্রকাশ না করার শর্তে বাড়ির একজন নিরাপত্তাকর্মী জানান, ধানমন্ডির ১২-এ রোডের ৬৯ নম্বর বাড়ির দ্বিতীয় তলার পুরো ফ্লোরটি সাবেক ডিএমপি
    কমিশনার আছাদুজ্জামান মিয়া কিনেছেন। তবে এটি তার শ্যালকের নামে।\nওই ভবনের তৃতীয় তলার ফ্ল্যাটটি চট্টগ্রাম মেট্রোপলিটন পুলিশের (সিএমপি) সাবেক কমিশনার
    ইকবাল বাহারের। এ বিষয়ে পুলিশ সদর দপ্তরের ডিআইজি কৃষ্ণপদ রায় বলেন, ‘ইকবাল বাহার হলেন আছাদুজ্জামান মিয়ার খুবই ঘনিষ্ঠ। তাই তারা দুজন একই ভবনে
    থাকতেন। আমিও একাধিকবার সেখানে গিয়েছি। আছাদুজ্জামান মিয়া কমিশনার থাকা অবস্থায় ওই ভবনে থাকতেন।’\nশুক্রবার দুপুর আড়াইটায় ইস্কাটন গার্ডেন ১৩/এ
    প্রিয়নীড়ে গিয়ে জানা যায়, সেখানে আছাদুজ্জামানের স্ত্রীর নামে একটি ফ্ল্যাট রয়েছে। বিস্তারিত জানতে চাইলে নিরাপত্তাকর্মী আব্দুস সালাম ও শাহ আলম প্রতিবেদককে
    বলেন, ‘আমরা এখানে নতুন এসেছি, তাই তেমন কিছু জানি না।’\nভবনের ম্যানেজার আজাদ আহমেদ জানান, ১৪ তলা এই ভবনে ৪০টি ফ্ল্যাট আছে। বেশিরভাগ ফ্ল্যাটই
    ২১৩৩ বর্গফুটের। ভবনের ১১ তলায় আছাদুজ্জমানের স্ত্রী আফরোজা জামানের একটি ফ্ল্যাট আছে। তবে সেখানে তিনি থাকেন না। ফ্ল্যাটটি ভাড়া দেওয়া আছে। অভ্যর্থনাকারী
    আবু বকর প্রতি মাসে ভাড়া তুলে আছাদুজ্জামানের কাছে দিয়ে আসেন। ভাড়া বকেয়া পড়লে বা কোনো সমস্যা হলে আমি নিজে স্যারের সঙ্গে (আছাদুজ্জমান) যোগাযোগ
    করেন বলে জানান তিনি।\nখোঁজ নিয়ে জানা যায়, নিকুঞ্জ-১ এর ৮/এ রোডের ৬ নম্বর বাড়িটি আছাদুজ্জামানের ছোট ছেলে আসিফ মাহাদীনের নামে। শুক্রবার বিকালে
    সেখানে যাওয়া হলে বাড়িটি ভেতর থেকে বন্ধ পাওয়া যায়। বেশ কয়েকবার কলিংবেল টিপেও সাড়া পাওয়া যাচ্ছিল না। একপর্যায়ে পাশের চার নম্বর বাড়ির গাড়িচালকের
    সঙ্গে কথা হচ্ছিল এই প্রতিবেদকের। ওই গাড়িচালক জানান, আছাদুজ্জামান সপরিবারে এই বাড়িতে থাকতেন। সরকার পতনের পর তিনি বাড়ি ছেড়ে পালিয়ে গেছেন।
    অনুসন্ধানে আরও জানা যায়, এ ছাড়া বসুন্ধরা আবাসিক এলাকার এল ব্লকের ১ নম্বর রোডের ১৬৬ এবং ১৬৭ নম্বরে ১০ কাঠার ওপর ৬ তলাবিশিষ্ট আলিশান একটি বাড়ি
    আছাদুজ্জামানের স্ত্রী আফরোজা জামানের নামে। পূর্বাচলের নিউ টাউনের ১ নম্বর সেক্টরের ৪০৬/বি নম্বর রোডে ১০ কাঠা জমি রয়েছে আছাদুজ্জামান মিয়ার নামে। ওই জমিতে
     গাড়ি রাখার শেড বানিয়ে রাখা হয়েছে। পূর্বাচলের সেক্টর ৪, রোড ১০৮-এ ৫৩ নম্বর প্লটটি আছাদুজ্জামানের স্ত্রীর নামে ছিল। ৫ কাঠার এই প্লটটি বিক্রি করে দেওয়া হয়েছে।
     আফতাবনগরে ৩ নম্বর সেক্টরে রয়েছে ২১ কাঠা জমি। সেখানে নিজের নামে ১০ কাঠা ও আত্মীয়স্বজনদের নামে রয়েছে বাকি ১১ কাঠা জমি।\nআছাদুজ্জামান
     মিয়ার স্ত্রী আফরোজা জামানের নামে ঢাকা ছাড়াও ফরিদপুর ও নারায়ণগঞ্জে বিপুল সম্পদ রয়েছে। ২০১৮ সালে তিনি রাজউক থেকে বিশেষ কোটায় একটি প্লট বরাদ্দ
     পান। অথচ রাজউকের নীতিমালা অনুযায়ী, স্বামী-স্ত্রী উভয়ের প্লট বরাদ্দ পাওয়ার সুযোগ নেই।\nজানা গেছে, গাজীপুরের কালীগঞ্জ উপজেলার চাঁদখোলা মৌজায় আফরোজা
     জামানের নামে ৬৭ শতাংশ জমি রয়েছে। ২০১৭ সালে এই জমি কেনা হয়। ওই মৌজায় তার নামে ২০১৯ সালের ৫ ফেব্রুয়ারি কেনা হয় আরও ৩৯ শতাংশ জমি। একই নামে
     ২০২০ সালে জোয়ার সাহারা মৌজায় কেনা হয় ১৫ কাঠা জমি। ওই বছর গাজীপুরের চাঁদখোলা মৌজায় ৩১ শতক জমি ক্রয় করেন আফরোজা। আফরোজা ২০১৮ সালে
     নারায়ণগঞ্জের রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ২৮ একর জমি কেনেন। ওই বছর একই মৌজায় আরও ৩২ শতক জমি কেনেন তিনি। ওই বছরই
     রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ৬০ একর জমি তার নামে কেনা হয়। পরে তা বিক্রি করে দেওয়া হয়। ২০১৯ সালে কৈয়ামসাইল-কায়েতপাড়া মৌজায়
     দশমিক ৫৭ একর জমির পাওয়ার অব অ্যাটর্নি পান আছাদুজ্জামানের স্ত্রী। এরপর ওই জমি বিক্রিও করেন।\nঅনুসন্ধানে আছাদুজ্জামান মিয়ার পরিবারের সদস্যদের মালিকানার
     দুটি কোম্পানির খোঁজ পাওয়া গেছে। এর মধ্যে একটি হলো মৌমিতা ট্রান্সপোর্ট লিমিটেড। এর চেয়ারম্যান আছাদুজ্জামানের স্ত্রী আফরোজা। আছাদুজ্জামান ডিএমপি কমিশনার
     থাকাকালীন রাজধানীর রুট পারমিট কমিটির প্রধান ছিলেন। ওই সময় মৌমিতা পরিবহণকে রুট পারমিট দেওয়া হয়। মৌমিতা ট্রান্সপোর্ট লিমিটেডের ভাইস চেয়ারম্যান হারিসুর
     রহমান সোহান হলেন আছাদুজ্জামানের শ্যালক। সোহানের নামে রাজধানীর নিউমার্কেটে আছে স্বর্ণের দোকান।\nআরও জানা যায়, শেপিয়ার্ড কনসোর্টিয়াম লিমিটেড নামে
     আরেকটি কোম্পানির চেয়ারম্যান আফরোজা জামান। এই কোম্পানির পরিচালক আছাদুজ্জামানের বড় ছেলে আসিফ শাহাদাত। আছাদুজ্জামানের শ্যালক নূর আলম ওরফে
     মিলনের নামে গাজীপুরের শ্রীপুরে দেড় একর জমি রয়েছে। ভাগনে কলমের নামেও গাজীপুরে জমি আছে দেড় একর।\nএদিকে আছাদুজ্জামান মিয়ার অবৈধ সম্পদের
     অনুসন্ধান শুরু করেছে দুদক। সংস্থাটির সচিব খোরশেদা ইয়াসমীন গণমাধ্যমকে বলেন, আছাদুজ্জামান মিয়ার বিরুদ্ধে বিভিন্ন অনিয়ম ও দুর্নীতির মাধ্যমে কোটি কোটি
     টাকার অবৈধ সম্পদ অর্জনের অভিযোগ এসেছে। এই অভিযোগ অনুসন্ধানের সিদ্ধান্ত গৃহীত হয়েছে বলে জানান তিনি।\nআওয়ামী লীগ সরকারের পতনের কয়েকদিন আগে
     আছাদুজ্জামান মিয়া জানিয়েছিলেন, তার এবং পরিবারের সদস্যদের কোনো অবৈধ সম্পদ নেই। যেসব সম্পদ আছে সবই আয়কর বিবরণীতে উল্লেখ করা আছে। সরকারের
     কোনো সংস্থা যদি এসব সম্পদের বিষয়ে অনুসন্ধান চালায় তাহলে তিনি ও তার পরিবারের সদস্যরা ওই সংস্থাকে সহযোগিতা করবেন।'
"""

# Generate the summary for the custom input text
generated_summary = generate_summary(custom_text)

# Print the original text and its generated summary
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়া রীতিমতো গড়েছেন বিপুল সম্পত্তি। তার গাড়ি, বাড়ি, প্লট এবং ফ্ল্যাট-কী নেই। অনুসন্ধানে এসব তথ্য উঠে এসেছে।

# %%
custom_text2 = """
বাংলাদেশের অর্থনৈতিক অবস্থা উন্নতির দিকে ধাবিত হচ্ছে, বিশেষ করে গত কয়েক বছরে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।
অর্থনীতিবিদরা মনে করছেন, এই অগ্রগতি ধরে রাখতে পারলে বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার অন্যতম শক্তিশালী অর্থনীতিতে পরিণত হতে পারে।
"""

generated_summary = generate_summary(custom_text2)
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার সবচেয়ে শক্তিশালী দেশগুলোর একটি হিসেবে পরিণত হতে পারে বলে মনে করছেন অর্থনৈতিক বিশ্লেষকরা। এর মধ্যে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।

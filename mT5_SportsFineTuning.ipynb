# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset I

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model

df = pd.read_csv('/content/drive/MyDrive/Colab/sports_categories.csv')
df.head()
# Out:
#   category                                              title  \
# 0   sports  ইউরোপিয়ান সুপার লিগ: 'ফ্যান পাওয়ার' যেভাবে ব...
# 1   sports                                 ধুঁকছে মাশরাফির দল
# 2   sports  সোহাগের ওপর ফিফার নিষেধাজ্ঞা: বাংলাদেশের ফুটবল...
# 3   sports  কনফারেন্স লিগের সেমির প্রথম লেগে নিষিদ্ধ মার্ত...
# 4   sports  ইএসএল: বার্সেলোনা, রেয়াল মাদ্রিদ, লিভারপুল, ম...
#
#                                                 text  \
# 0  ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লি...
# 1  সব শংকা উড়িয়ে মাঠে গড়িয়েছে বাংলাদেশ প্রিমিয়ার ...
# 2  শুক্রবার ১৪ই এপ্রিল ফিফার ওয়েবসাইটে প্রকাশিত এ...
# 3  নিয়মের ফাঁক দিয়ে দুটি হলুদ কার্ড পেয়েও লাল কার...
# 4  ইংল্যান্ডের 'বিগ সিক্স' বলে পরিচিত আর্সেনাল, চ...
#
#                                              summary
# 0   ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ।
# 1  সব শংকা উড়িয়ে মাঠে গড়িয়েছে বাংলাদেশ প্রিমিয়ার ...
# 2  বাংলাদেশের ফুটবল ফেডারেশনের সাধারণ সম্পাদক আবু...
# 3  অলিম্পিয়াকোসের বিপক্ষে প্রথম লেগে আর্জেন্টিনার...
# 4  ইংল্যান্ডের 'বিগ সিক্স' বলে পরিচিত আর্সেনাল, চ...

# %%
df
# Out:
#      category                                              title  \
# 0      sports  ইউরোপিয়ান সুপার লিগ: 'ফ্যান পাওয়ার' যেভাবে ব...
# 1      sports                                 ধুঁকছে মাশরাফির দল
# 2      sports  সোহাগের ওপর ফিফার নিষেধাজ্ঞা: বাংলাদেশের ফুটবল...
# 3      sports  কনফারেন্স লিগের সেমির প্রথম লেগে নিষিদ্ধ মার্ত...
# 4      sports  ইএসএল: বার্সেলোনা, রেয়াল মাদ্রিদ, লিভারপুল, ম...
# ...       ...                                                ...
# 2489   sports            মেসির মায়ামির ১ ম্যাচে প্রয়োজন ২ পয়েন্ট
# 2490   sports   ক্রিকেট ইতিহাসের সফলতম বাঁহাতি স্পিনার এখন সাকিব
# 2491   sports          হকি খেলোয়াড়দের বেতনভুক্ত করার দাবি জিমির
# 2492   sports  মালদ্বীপের হ্যান্ডবল ডেভেলপমেন্ট প্রজেক্ট ডিরে...
# 2493   sports       টি-টোয়েন্টির শীর্ষ অলরাউন্ডার এখন লিভিংস্টোন
#
#                                                    text  \
# 0     ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লি...
# 1     সব শংকা উড়িয়ে মাঠে গড়িয়েছে বাংলাদেশ প্রিমিয়ার ...
# 2     শুক্রবার ১৪ই এপ্রিল ফিফার ওয়েবসাইটে প্রকাশিত এ...
# 3     নিয়মের ফাঁক দিয়ে দুটি হলুদ কার্ড পেয়েও লাল কার...
# 4     ইংল্যান্ডের 'বিগ সিক্স' বলে পরিচিত আর্সেনাল, চ...
# ...                                                 ...
# 2489  কী দারুণ এক বাঁকে এসে দাঁড়িয়ে লিওনেল মেসির ইন্...
# 2490  ড্যানিয়েল ভেট্টোরির চেয়ে ২ উইকেট পিছিয়ে থেকে র...
# 2491  ক্রীড়াঙ্গনে সংস্কারের জন্য গঠিত সার্চ কমিটি ফে...
# 2492  মালদ্বীপের হ্যান্ডবল ডেভেলপমেন্ট প্রজেক্ট ডিরে...
# 2493  জায়গাটি এক সময় ছিল বাংলাদেশের সাকিব আল হাসানের...
#
#                                                 summary
# 0      ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ।
# 1     সব শংকা উড়িয়ে মাঠে গড়িয়েছে বাংলাদেশ প্রিমিয়ার ...
# 2     বাংলাদেশের ফুটবল ফেডারেশনের সাধারণ সম্পাদক আবু...
# 3     অলিম্পিয়াকোসের বিপক্ষে প্রথম লেগে আর্জেন্টিনার...
# 4     ইংল্যান্ডের 'বিগ সিক্স' বলে পরিচিত আর্সেনাল, চ...
# ...                                                 ...
# 2489  কী দারুণ এক বাঁকে এসে দাঁড়িয়ে লিওনেল মেসির ইন্...
# 2490  ড্যানিয়েল ভেট্টোরির চেয়ে ২ উইকেট পিছিয়ে থেকে র...
# 2491  ক্রীড়াঙ্গনে সংস্কারের জন্য গঠিত সার্চ কমিটি ফে...
# 2492  মালদ্বীপের হ্যান্ডবল ডেভেলপমেন্ট প্রজেক্ট ডিরে...
# 2493  জায়গাটি এক সময় ছিল বাংলাদেশের সাকিব আল হাসানের...
#
# [2494 rows x 4 columns]

# %% [markdown]
# # Install and Imports

# %%
# !pip install sentencepiece
# !pip install transformers
# !pip install git+https://github.com/csebuetnlp/normalizer

import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

from normalizer import normalize # pip install git+https://github.com/csebuetnlp/normalizer


from transformers import XLMProphetNetForConditionalGeneration, XLMProphetNetTokenizer


from transformers import MBartForConditionalGeneration, AutoModelForSeq2SeqLM
from transformers import AlbertTokenizer, AutoTokenizer
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-590ys0lr
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-590ys0lr
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from normalizer==0.0.1) (2024.9.11)
# Collecting emoji==1.4.2 (from normalizer==0.0.1)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 14.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy==6.0.3 (from normalizer==0.0.1)
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.13)
# Building wheels for collected packages: normalizer, emoji, ftfy
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6860 sha256=261d863091683baa6e0bf9e6dedbbbb206e64332afa412f2ac0bb5f85a89a90b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oe382x9z/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186455 sha256=7a681256e417bd57859614c9593f107079b7a8512c762903188064d2466144ef
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41931 sha256=8e8d30af6cf25e2a47274d3fb2d294ab2d97b86550b3cd4327c01d79f21d2d74
#   Stored in directory: /root/.cache/pip/wheels/92/8e/16/c1e4d4d65685d71085e4e27b44d6ed880b0559474c9ee4ff66
# Successfully built normalizer emoji ftfy
# Installing collected packages: emoji, ftfy, normalizer
# Successfully installed emoji-1.4.2 ftfy-6.0.3 normalizer-0.0.1

# %%
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ### Functions

# %%
def cleanText(text2clean):
    empty_string = ""

    space = chr(32)
    flag  = 0

    for i in range(len(text2clean)):
        if text2clean[i] != "'" and text2clean[i] != "\n":
            if text2clean[i] == space and flag == 0:
                flag = 1
                empty_string = empty_string + text2clean[i]
            elif text2clean[i] != space:
                empty_string = empty_string + text2clean[i]
                flag = 0
    return empty_string

# %% [markdown]
# # Model Loading

# %% [markdown]
# ### Model Setup

# %%
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

tokenizer_path = "/content/drive/MyDrive/Colab/mT5_Tokenizer_XLSum"
model_path = "/content/drive/MyDrive/Colab/mT5_Model_XLSum"

# Step 4: Load the tokenizer and model from the specified paths
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=250112, bias=False)
# )

# %% [markdown]
# ### Run dataset over the Model

# %%
df.columns
# Out:
# Index(['category', 'title', 'text', 'summary'], dtype='object')

# %%
rows = df.shape[0]
rows
# Out:
# 2494

# %%
# Create empty DataFrame without the "title" column
genDf = pd.DataFrame(columns=["text", "givenSummary", "mT5_Test_XLSum"])

# Load over the dataset
for i in range(rows):
    if i < 1500:  # Adjust the starting index as needed
        article_text = normalize(df['text'][i])

        # Tokenize the input text
        input_ids = tokenizer(
            [WHITESPACE_HANDLER(article_text)],
            return_tensors="pt",
            padding="max_length",
            max_length=512,
            truncation=True
        )["input_ids"]

        # Generate the summary
        output_ids = model.generate(
            input_ids=input_ids.cuda(),
            max_length=400,
            min_length=64,
            no_repeat_ngram_size=2,
            num_beams=4
        )[0]

        # Decode the generated summary
        summary = tokenizer.decode(
            output_ids,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=False
        )

        # Add the text, given summary, and generated summary to the DataFrame
        genDf.loc[i] = [df['text'][i], df['summary'][i], summary]

        # Print the generated summary for verification
        print(i, '  ', summary)

# Save the DataFrame to CSV
genDf.to_csv('/content/drive/My Drive/Colab/sports_finetuned.csv')
# Out:
# 0    "একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ। কিন্তু ইএসএল-এর মৃত্যু ঘণ্টা বেজে গেছে এবং এই প্রজেক্টের অবসানের পেছনে আশাব্যঞ্জক কোন ভবিষ্যৎ থাকবে না।"
# 1    বাংলাদেশ প্রিমিয়ার লিগের ষষ্ঠ আসরে উত্তরবঙ্গের চিটাগং ও রংপুর রাইডার্সের মধ্যে জয় পেয়েছে বাংলাদেশের জাতীয় দলের একাদশ দল। শনিবার রাতে মাঠে নামলো এই দলে।
# 2    আন্তর্জাতিক ফুটবল পরিচালনা সংস্থা ফিফা বাংলাদেশের বাফুফের সাধারণ সম্পাদক আবু নাঈম সোহাগের ওপর দুই বছরের জন্য নিষেধাজ্ঞা দিয়েছে। এর বাইরে কর্তৃপক্ষ এখনো পর্যন্ত নীরবতা বজায় রেখেনি।
# 3    আর্জেন্টিনার উয়েফা কনফারেন্স লিগের সেমি-ফাইনালে গোলরক্ষক এমিলিয়ানো মার্তিনেসকে তিন দফায় হলুদ কার্ড দেখায় এক ম্যাচ নিষিদ্ধ করেছে ইংলিশ ফুটবলার রেফারি ।
# 4    যুক্তরাজ্যের প্রধানমন্ত্রী বরিস জনসন ঘরোয়া ফুটবল টুর্নামেন্টের নতুন পরিকল্পনার সমালোচনা করেছেন এবং এটা নিয়ে বিশ্বের বিভিন্ন দেশে তীব্র প্রতিক্রিয়া দেখা দিয়েছে। এর ফলে এখন পর্যন্ত এমন কোন খবর পাওয়া যায়নি।
# 5    ইউরোপিয়ান চ্যাম্পিয়নশিপে নরওয়ের নারী হ্যাণ্ডবল দলের খেলোয়াড়রা বিকিনি বটম বা বিকিনির নিচের অংশের মত শর্টস পরতে অস্বীকার করেছিলেন। কিন্তু এর পর কী হয়েছিল তার কাহিনি?
# 6    টি ২০ বিশ্বকাপে যে ম্যাচ নিয়ে কারও কোনো আগ্রহ ছিল না, সেটির সৌজন্যেই এক যুগ পর টাই ও সুপার ওভারের রোমাঞ্চ ফিরল আফ্রিকার দেশ নামিবিয়া। এর আগে সবশেষ চার আসরে যা দেখেনি আইসিসি।
# 7    বাংলাদেশ ও ভারতের মধ্যকার সিরিজের অভিষেক ম্যাচে মাঠে নামলেন বাংলাদেশের ক্রিকেটার ইয়াসির আলী রাব্বি, যার হেলমেটে আঘাত হানা শাহীন শাহ আফ্রিদির বল তিনি হেরে গেছেন। কিন্তু আপাতত কোনও ক্ষতি পাওয়া যায়নি।
# 8    সাফ ক্লাব চ্যাম্পিয়নশিপের প্রথম আসরে বাংলাদেশের মোহামেডান টি-টোয়েন্টি দল অংশ নিতে পারবে না বলে জানিয়েছে আয়োজক। তবে টুর্নামেন্ট আয়োজন করলেও দুঃসংবাদ দেয়া হয়েছে।
# 9    বাংলাদেশে বৈষম্য বিরোধী ছাত্র আন্দোলনের কারণে অনেক দিন উত্তাল ছিল বাংলাদেশ। পাকিস্তানের বিপক্ষে দুই ম্যাচের টেস্ট সিরিজ খেলতে যাচ্ছে বাংলাদেশ দল। তবে কোচ চন্ডিকা হাথুরুসিংহে বলেছেন, দেশ আবার স্বাভাবিক অবস্থায় ফিরবে।
# 10    চ্যাম্পিয়নস লিগের শেষ ষোলোর প্রথম লেগের ম্যাচে পিএসজির কাছে ৪-০ ব্যবধানে বিধ্বস্ত হয়ে নিজেদের ডেরায় ফিরতি লন্ডনের দল বার্সেলোনা। এবার সেই ম্যাচের বদলা নেয়নি তারা।
# 11    বিশ্বকাপের সেমিফাইনালে হেরে যাওয়ার পর ভারতের ক্রিকেট দলের অধিনায়ক ভিরাট কোহলি বলছেন, নকআউট পর্বে পরিবর্তন আনা উচিৎ। কিন্তু তিনি বলেছেন এখন নীতি অনুসরণ করতে হবে।
# 12    বাংলাদেশ ও পাকিস্তানের মধ্যকার দ্বিতীয় টেস্ট সিরিজের প্রথম সিরিজে জয় পেয়েছে বাংলাদেশ ক্রিকেট দল। কিন্তু এটি নিয়ে নতুন ইতিহাস লেখার পথে এগিয়ে এসেছে ভারতের বিরুদ্ধে।
# 13    ফুটবলের আঙিনায় লিওনেল মেসি-ক্রিশ্চিয়ানো রোনালদোর দ্বৈরথ চলছেই। এই দুই সুপার স্টারের মধ্যে একটা বড় সমস্যা হলো - তারা কি করতে চান সেটা?
# 14    রোববার রাওয়ালপিন্ডির বিপক্ষে বাংলাদেশ ও পাকিস্তানের মধ্যকার টেস্ট ম্যাচের পঞ্চম দিনে দারুণ বোলিংয়ে রোমাঞ্চ জাগিয়েছে লাল সবুজ প্রতিনিধিদের দল। কিন্তু শেষ দিনের সেশনে ভারতকে ৩ উইকেটে হারিয়েছে বাংলাদেশ।
# 15    জিম্বাবুয়ের বিপক্ষে তিন ম্যাচ সিরিজের তৃতীয় ওয়ানডে ম্যাচে বিশাল রান সংগ্রহ করেছে বাংলাদেশ। তামিম ইকবালকে ছাড়িয়ে নতুন উচ্চতায় পৌঁছেছে জাতীয় দলের দুই তারকা ব্যাটসম্যান।
# 16    চামড়ার বলের সাথে উইলো কাঠের সংযোগে ঠক্ আওয়াজ - হ্যাঁ, দর্শকরা শুনতে পাবেন ল্যামিনেটেড বাঁশের ক্রিকেট ব্যাট। কিন্তু বিজ্ঞানীরা বলছেন, এটি ব্যাটসম্যানদের স্বপ্নকে বাস্তবে রূপ দেবে।
# 17    ক্রিকেট ইতিহাসের সবচেয়ে বেশি রানের টি-টোয়েন্টি ম্যাচ দেখলো স্বাগতিক দক্ষিণ আফ্রিকা। এই ম্যাচে ওয়েস্ট ইন্ডিজের বিপক্ষে যে রান তাড়া করে জয়ের রেকর্ড হয়েছিল, সেটি ছিল ২০০৬ সালে অস্ট্রেলিয়ার সঙ্গে এর আগের ওয়ানডে
# 18    যুক্তরাষ্ট্র-কানাডা ম্যাচ দিয়ে শুরু হয়েছে টি-টোয়েন্টি বিশ্বকাপ ২০২৪। এই আসরে অংশ নিতে যাচ্ছে ১৩টি দল, যার মধ্যে বাংলাদেশ, আফগানিস্তান ও ওয়েস্ট ইন্ডিজের নেতৃত্বে।
# 19    বাংলাদেশ প্রিমিয়ার লিগের নতুন মৌসুমে এবার মাঠে দেখা যাবে না বাংলাদেশ জাতীয় দলের অধিনায়ক জামাল ভূঁইয়াকে। এর আগে তিনবারের চ্যাম্পিয়ন শেখ রাসেল নিজেদের প্রত্যাহার করেছিলেন।
# 20    সৌরভ গাঙ্গুলী ভারতের ক্রিকেট দলের নতুন কোচ হওয়ার জন্য আগ্রহ প্রকাশ করেছেন। কিন্তু এবারের তালিকাতেই তিনি নিজেকে দেখতে চান বলে মনে করছেন অনেকেই। সেই সঙ্গে যোগ দিয়েছেন বেশ কিছু নাম।
# 21    ইংলিশ প্রিমিয়ার লিগের প্রথম রাউন্ডে ম্যানচেস্টার সিটি ও আর্সেনালের মধ্যে লড়াই শুরু হয়ে গেছে বৃহস্পতিবার। কিন্তু শেষ দিকে চাপের সময়টায় ভেঙে পড়েছে দল।
# 22    বাংলাদেশের বিপক্ষে সহজ এক জয়ের পর পাকিস্তান ক্রিকেট দলে খানিকটা স্থিরতা এবং স্বস্তি ফিরে এসেছে। দল গঠনের পেছনে স্বার্থের সংঘাত রয়েছে কি না খতিয়ে দেখার কথা বলেছে দেশটি।
# 23    ইংলিশ প্রিমিয়ার লিগের ক্লাব লেস্টার সিটি তারকা হামজা চৌধুরীকে বাংলাদেশের হয়ে খেলার আগ্রহ প্রকাশ করেছে বাংলাদেশ ফুটবল ফেডারেশন (বাফুফে)। সেই আভাস জানিয়েছেন কোচ হ্যাভিয়ের ক্যাবরেরা।
# 24    বাংলাদেশের জাতীয় ক্রিকেট দলের কোচ মেহেদী হাসান মিরাজের এই প্রতিবেদন নিয়ে বেশ কিছু তথ্য পাওয়া গেছে। এর মধ্যে তিনি কী করছেন? - বিবিসি বাংলার ফেসবুক পাতায় তাকে বিস্তারিত লিখেছেন।
# 25    বাংলাদেশ ও ইংল্যান্ডের মধ্যকার ওয়ানডে সিরিজের প্রথম ম্যাচ আজ মিরপুরের শেরেবাংলা স্টেডিয়ামে শুরু হয়েছে। এই ম্যাচে বাংলাদেশ দলের স্কোয়াড সাজানো হয়েছে সাতজন ব্যাটসম্যানের একাদশ থেকে।
# 26    বাংলাদেশের ক্রিকেট দলের অধিনায়ক সাকিব আল হাসান টুর্নামেন্টের সেমিফাইনালে ওঠার আগে সোমবার সন্ধ্যাতেও দলকে নিয়ে খুব বেশি কিছু আর আশা করতে ভয় পাচ্ছেন - এমনটাই বলছিলেন তিনি।
# 27    বাংলাদেশ ও ভারতের মধ্যকার টেস্ট ম্যাচের দ্বিতীয় দিন শেষ হওয়ার কথা রয়েছে শুবমান গিল ও রিশভ পান্তের ব্যাটে। এই দুই দলই আগের দিনের চেয়ে বেশি রান নিয়ে খেলেছে।
# 28    বাংলাদেশের ক্রিকেট দলের ক্রিকেটাররা আজ থেকে ধর্মঘটে যাওয়ার কথা ঘোষণা করেছেন। তাদের দাবি মেনে না নেয়া পর্যন্ত তারা সব ধরণের প্রতিযোগিতামূলক ম্যাচ ও অনুশীলনে অংশগ্রহণ করবেন।
# 29    চলমান এশিয়া কাপে বাংলাদেশ ও শ্রীলঙ্কা নিজেদের গ্রুপ পর্বের শেষ ম্যাচে আজ মুখোমুখি হচ্ছে। আফগানিস্তানের কাছে হেরে এখন কোণঠাসা পরিস্থিতিতে আছে দুই দলের জন্যই ম্যাচটি।
# 30    টি-টোয়েন্টি সিরিজের প্রথম ম্যাচে ইংল্যান্ডকে ২৮ রানে হারিয়েছে অস্ট্রেলিয়া। আরও একবার ব্যাট হাতে ঝড় তুললেন ট্রাভিস হেডের কাছ থেকে। এরপরও দলটি জয় পেয়েছে।
# 31    গতকাল থেকে শুরু হওয়া বাংলাদেশের জাতীয় অ্যাথলেটিক্স প্রতিযোগিতার ৪৩তম আসরে অ্যাথালটেদের কোন অর্জনজাতীয় রেকর্ড হিসেবে অন্তর্ভুক্ত করা হবে না। কিন্তু এবারের আসর চট্টগ্রামের এম এ আজিজ স্টেডিয়ামে অনুষ্ঠিত হবে।
# 32    ইতালিয়ান জায়ান্ট দল ইন্টার মিলান সিরি আ'র শিরোপা ঘরে তুলেছে। পাঁচ ম্যাচ বাকি থাকতেই সিরিজের শেষ জয় পেয়েছে তারা। কিন্তু এবারের মৌসুমে তাদের দারুণ আধিপত্য ছিল।
# 33    রোববার রাওয়ালপিন্ডিতে পাকিস্তান ও নিউ জিল্যান্ডের মধ্যকার দ্বিতীয় টি-টোয়েন্টি সিরিজে দারুণ জয়ে সমতা ফেরাল নিউজিল্যান্ড। প্রথম ম্যাচের পর তিন উইকেটে জয় পেয়েছে ভারত।
# 34    চলতি অলিম্পিকে প্রথমবারের মতো অন্তর্ভুক্ত হয়েছে ব্রেকিং বা ব্রেকে ড্যান্সিং। ইভেন্টটির অভিষেকে ছেলেদের বিভাগে সোনা জিতে ইতিহাসের সবচেয়ে বড় জয় পেয়েছেন কানাডার ফিল উইজার্ড।
# 35    কাউন্টি প্রথম শ্রেণীর আসরে বাংলাদেশের ১৩ বছর পর ফেরার উপলক্ষ দারুণভাবে রাঙিয়েছেন শীর্ষ অলরাউন্ডাররা। টন্টনে সোমবার রাতের ম্যাচে তিন উইকেট নিয়ে জয় পেয়েছেন তারা।
# 36    করোনাভাইরাসের কারণে এই মাসে দ্বিতীয় সন্তানের বাবা হবেন জাতীয় দলের তারকা ক্রিকেটার মোহাম্মদ মিঠুন। ঢাকা প্রিমিয়ার লিগের এক রাউন্ডের খেলা হওয়ার পর থেকেই তিনি ঘরবন্দি আছেন।
# 37    গত মাসে শচীন টেন্ডুলকারের ছেলে অর্জুন টেন্ডেলের আলোচিত অভিষেকের পর তাকে নিয়ে বিস্তর বিশ্লেষণ হচ্ছে। তিনি ছিলেন বিশ্বের সেরা ক্রিকেটার বলে বিবেচিত এই তরুণ পেস বোলার।
# 38    হ্যারি কেইনের জোড়া গোলে টটেনহাম ৪-০ ব্যবধানে উড়িয়ে দিয়েছে ক্রিস্টাল প্যালেসকে। ইংলিশ প্রিমিয়ার লিগে এই জয়ে পয়েন্ট টেবিলে পঞ্চম স্থান নিয়ে উঠেছে স্পাররা।
# 39    টাকা-পয়সা, গাড়ি-বাড়ি, খ্যাতি-সম্মান জীবনের সবচেয়ে গুরুত্বপূর্ণ জিনিস নয়। এগুলো ভোগ বিলাসের একটি অংশ মাত্র বলে মনে হয় না। ভারতের কিংবদন্তি টেনিস তারকা সানিয়া মির্জা বলেছেন, এটা আমি আমার অভিজ্ঞতা থেকে
# 40    বাংলাদেশের টি টোয়েন্টি কোচ সৌম্য সরকার অস্ট্রেলিয়ার বিপক্ষে চার ম্যাচে ৩৭ বলে ৫১ রানের ইনিংস খেলেন, যার ফলাফল বোল্ড আউট হয়েছেন তিনি। কিন্তু মানসিক চাপের কারণে ব্যাট করতে ভুলে গেছেন দর্শকরা।
# 41    বাংলাদেশ ক্রিকেট দলের সাবেক অধিনায়ক মোহাম্মদ আশরাফুল করোনাভাইরাস মহামারির কারণে জাতীয় দল থেকে বাদ পড়ার পর নতুন বছর শুরু করেছেন। এর আগে থেকেই তার প্রত্যাশা ছিল সেটা ধারাবাহিক অব্যাহত রাখা।
# 42    কে যেন বলেছেন, এবারের টি ২০ বিশ্বকাপে ব্যাটারদের ওপর আধিপত্য বিস্তার করবেন বোলাররা। টুর্নামেন্টের আসরের চতুর্থ ম্যাচেই দক্ষিণ আফ্রিকা ও শ্রীলংকা মিলে রান তুলতে পারেনি।
# 43    ২০১০ সালে দুবাইয়ের সাবেক অধিনায়ক শোয়েব মালিকের সঙ্গে বিয়ে বন্ধনে আবদ্ধ হন ভারতীয় টেনিস তারকা সানিয়া মির্জা। নতুন বছরকে স্বাগত জানিয়ে তিনি বলছেন, 'আমি এখন ধরতে পারছি।'
# 44    ২০১০ থেকে ২০১৯ সাল পর্যন্ত এই দশ বছরের সেরা টি-টোয়েন্টি অলরাউন্ডার হিসেবে পাকিস্তানের তারকা ক্রিকেটার শহীদ আফ্রিদিকে নির্বাচিত করেছেন ভারতীয় সাবেক ক্রিকেটারের আকাশ চোপরা।
# 45    নিউজিল্যান্ডের বিপক্ষে এজবাস্টন টেস্টের দাপটের সাথে জিতে নিলো ইংল্যান্ড ক্রিকেট দলের দলটি। ভারতের কাছে এই টেস্টে ৩৬৫ রানে অলআউট হয়েও জয় পেয়েছে তারা।
# 46    টি ২০ ক্রিকেট বিশ্বকাপে এবারের 'ডি' গ্রুপের পাঁচ দলের মধ্যে বাংলাদেশের চেয়েও বড় হুমকি হয়ে উঠেছে নেদারল্যান্ডস ও দক্ষিণ আফ্রিকা। কিন্তু এই তিন ম্যাচের আগেই বিদায় ঘণ্টা বেজে যেতে পারে নাজমুল ইসলাম।
# 47    শেষ পর্যন্ত আরবি লাইপজিগ ছাড়তে যাচ্ছেন স্প্যানিশ তারকা দানি ওলমো। এই ঘোষণার পর ক্লাবটি ছেড়ে দেয়া হয়েছে তাকে ৩০ বছরেরও বেশি সময়ের মধ্যে চুক্তিতে নেয়া।
# 48    টি-টোয়েন্টি ফরম্যাটের এশিয়া কাপে বাংলাদেশ নিজেদের প্রথম ম্যাচে মাঠে নামছে আজ। আফগানিস্তানকে হারানোর পর বাংলাদেশ সতর্কতা অবলম্বন করছে। কিন্তু এই ম্যাচের আগে কোন দল টসে জিতে নিতে পারবে না।
# 49    ক্রিকেট বিশ্বকাপে বাংলাদেশ-ভারত লড়াই হয়তো অনেকের মনে হতো। একসময় পাকিস্তানের জায়গা দখল করে নিয়েছে বাংলাদেশ। কিন্তু এখন ভারতের সঙ্গে ম্যাচটি যেন অলিখিত কোনো ফাইনাল।
# 50    টি-টোয়েন্টি ফরম্যাটের এশিয়া কাপে বাংলাদেশ নিজেদের প্রথম ম্যাচে মাঠে নামছে আজ। আফগানিস্তানকে হারানোর পর বাংলাদেশ সতর্কতা অবলম্বন করছে। কিন্তু এই ম্যাচের আগে কোন দল টসে জিতে নিতে পারবে না।
# 51    চরম নাটকীয়তা ও শ্বাসরুদ্ধকর ম্যাচে জিতে স্প্যানিশ সুপার কাপের ফাইনালে উঠেছে অ্যাটলেটিকো মাদ্রিদের দল দ্য ইন্ডিয়ানসরা ও বার্সেলোনা। সেই সঙ্গে বিদায় ঘটেছে তারা।
# 52    সৌরভ চতুর্বেদী - কানপুরের গ্রিন পার্ক স্টেডিয়ামের স্কোরার। ১৯৫৯ সালে সেখানে অস্ট্রেলিয়া ও ভারতের টেস্ট ম্যাচে তিনি খেলা দেখেন। কিন্তু সেই ম্যাচটা কীভাবে শেষ হয়ে গেল?
# 53    ভারত ও পাকিস্তান এ বছর সেপ্টেম্বরে মুখোমুখি হবে এশিয়া কাপের আসর। এই আসরে দুই দলকে বাছাইপর্ব পেরিয়ে আসার কথা রয়েছে বাংলাদেশ ও শ্রীলংকা ও আফগানিস্তানের সঙ্গে।
# 54    আল্ট্রা-প্রসেসড ফুড (ইউপিএফ) বা অতি-প্রক্রিয়াজাত খাবার হৃদরোগ, ক্যানসার এবং টাইপ ২ ডায়াবেটিসসহ মানব স্বাস্থ্যের ৩২টি ক্ষতিকারক প্রভাবের সঙ্গে সরাসরি যুক্ত বলে এক গবেষণায় উঠে এসেছে।
# 55    এশিয়া কাপের ফাইনালে কোয়ালিফাই করতে রীতিমত ঘাম ঝরাতে হচ্ছে বাংলাদেশ ক্রিকেট দল। টুর্নামেন্টের মাঝ পর্যায়ে এসে নেট-রান রেট নিয়ে হিসেব-নিকেশ করাটা বাংলাদেশের জন্য নিত্যনৈমিত্তিক ব্যাপার হয়ে দাঁড়িয়েছে।
# 56    গত মাসে কাতারে শিরোপা জয়ের মধ্য দিয়ে ৩৬ বছর পর বিশ্বকাপ খরা কাটায় আর্জেন্টিনা। কিন্তু এখন সে দল ছেড়ে নামা অনিশ্চিত হচ্ছেন লিওনেল মেসির অধিনায়ক অ্যালেক্সিস ম্যাক অ্যালিস্টার।
# 57    বঙ্গবন্ধু টি টোয়েন্টি কাপ ক্রিকেট টুর্নামেন্টের ষষ্ঠ সপ্তাহের শুরুতেই সামাজিক যোগাযোগ মাধ্যমে ক্রীড়াঙ্গন নিয়ে সবচেয়ে আলোচিত বিষয় ছিল খেলার মাঠে মুশফিকুর রহিমের মারমুখী ভঙ্গি এবং জরিমানা।
# 58    করাচির ন্যাশনাল স্টেডিয়ামে এখন চলছে পাকিস্তান-নিউজিল্যান্ড দ্বিতীয় টেস্ট। কিন্তু টি-টোয়েন্টি ক্রিকেটে স্ট্রাইকরেট বাড়ানোর ব্যাপারে গুরুত্ব দিয়েছেন প্রধান নির্বাচক শহীদ আফ্রিদি।
# 59    বাগদত্তা জেসের সঙ্গে তাঁর বিয়ের দিনক্ষণ ঠিক করে রেখেছেন ওলি স্টোন। কিন্তু গোলমাল বাধার ঝামেলা এখনও কাটেনি ইংল্যান্ডের জাতীয় দলের সদস্যদের মধ্যে ।
# 60    ইংলিশ লিগ কাপের ফাইনাল ম্যাচে ম্যানচেস্টার সিটি ও দ্য ব্লুজদের মধ্যে হাড্ডাহাড্ডি লড়াই শেষ হয়ে গেলেও চ্যাম্পিয়ন হলো দলটি। টাইব্রেকারে ৪-৩ গোলে জিতে শিরোপা ঘরে তুলল সিটির।
# 61    চ্যাম্পিয়ন্স লিগ এবং লা লিগার শিরোপা জিতে নিয়েছেন ভিনিসিয়ুস জুনিয়র। এই পুরস্কার পেয়েছেন রিয়াল মাদ্রিদের সাবেক অধিনায়ক রোনালদো নাজারিও। এবারের মৌসুমটা দারুণ কাটিয়েছেন তিনি।
# 62    লিওনেল মেসি তার সম্ভাব্য শেষ ও পঞ্চম বিশ্বকাপ মিশনে গিয়ে জিতলেন আরাধ্য ফিফা শিরোপা, কিন্তু তার চরিত্রে একটা পরিবর্তন এসেছে - যার মানে ছিল 'ডানপিটে বেপরোয়া' হয়ে ওঠার।
# 63    চ্যাম্পিয়ন্স লিগে দুর্বার গতিতে ছুটছে বার্সেলোনা। রোববার রাতে প্রতিপক্ষের মাঠে গিয়েও ৫-১ গোলে জয় পেয়েছে তারা। এই নিয়ে লা লিগায় টানা হয় ম্যাচ জিতল দলটি।
# 64    ঢাকার শেখ ফজলুল হক মনি স্টেডিয়ামে ঈদ উল ফিতরের বিরতির পর শুরু হওয়া লিগের দুই সাবেক চ্যাম্পিয়নের লড়াইয়ে জয় পেয়েছে আবাহনীর ধানমণ্ডি ক্লাবটি।
# 65    রাওয়ালপিন্ডিতে বাংলাদেশ ও পাকিস্তানের মধ্যকার টেস্ট ম্যাচের দ্বিতীয় দিন শেষ করেছে বাংলাদেশ। নতুন বলে শুরুতে ঝাঁজ দেখালেন তাসকিন আহমেদ। ব্যাটে-বলের লড়াই বেশ ভালো।
# 66    খ্রিস্টীয় নতুন বছর ২০২৩-কে বরণ করে নিতে ইনস্টাগ্রামে এক আবেগঘন স্ট্যাটাস দিয়েছেন ফুটবলের জাদুকর ও বিশ্বচ্যাম্পিয়ন লিওনেল মেসি। এতে সবার আগে নিজ পরিবারকে প্রাধান্য দিয়েছিলেন তিনি।
# 67    রাওয়ালপিন্ডি টেস্টে স্মরণীয় সেঞ্চুরি করায় আইসিসি র ্যাঙ্কিংয়ে বড় লাফ দিয়েছেন বাংলাদেশের ব্যাটার লিটন দাস। এই সিরিজে তিনটি টেস্টের ইতিহাসে তিনি সবচেয়ে বেশি রান করেছেন।
# 68    ইংল্যান্ডের জার্সিতে ২০০ উইকেট নিলেন লেগ স্পিনার গ্লেন ম্যাক্সওয়েল ও অ্যাডাম জ্যাম্পাকে বিদায় করার পর এই প্রথমবারের মতো ওয়ানডেতে এমন একটি সেঞ্চুরি শিকার করেছেন তিনি।
# 69    রোববার রাওয়ালপিন্ডিতে পাকিস্তান ও বাংলাদেশের মধ্যে তিন ম্যাচের টেস্ট সিরিজের প্রথম দিনে ড্যানিয়েল ভেট্টোরিকে ছাড়িয়ে চূড়ায় ওঠেন সাকিব আল হাসান। কিন্তু আন্তর্জাতিক ক্রিকেট ইতিহাসের সফলতম বাঁহাতি স্পিনারে পরিণত হলেন বাংলাদেশ
# 70    আইসিসি-র ওয়ানডে বিশ্বকাপ সদ্য শেষ হওয়ার পর ভারত ও অস্ট্রেলিয়ার ক্রিকেটারদের মধ্যে তীব্র সমালোচনার ঝড় উঠেছে। এই টুর্নামেন্টে দুই দলের জয় নিয়ে বেশ আলোচনা হচ্ছে।
# 71    সৌদি আরবে 'এমবিএস ভিশন ২০৩০ ন্যাশনাল ক্রিকেট চ্যাম্পিয়নশীপের' ফাইনালে প্রবাসী বাংলাদেশি টিম গ্রীণ বাংলাকে ১৭ রানে পরাজিত করে টুর্নামেন্টের সেরা দল নির্বাচিত হয়েছে।
# 72    বাংলাদেশে জাতীয় সংসদ নির্বাচনের প্রচারণা শুরু হয়েছে ঢাকা মহানগর উত্তরের মেয়র পদপ্রার্থী আতিকুল ইসলাম। প্রচারে এমপি বা মন্ত্রীদের অংশ নেয়ার ক্ষেত্রে নির্বাচন কমিশনের নিষেধাজ্ঞা রয়েছে।
# 73    বাংলাদেশের প্রতি এক ধরণের আগ্রহ লক্ষ্য করা যাচ্ছে আর্জেন্টিনার গণমাধ্যম এবং সামাজিক মাধ্যমে। এর মধ্যে অন্যতম প্রধান উদ্দেশ্য হচ্ছে নতুন করে দুনিয়ার কূটনৈতিক সম্পর্ক।
# 74    পাকিস্তান সফর সামনে রেখে রোববার থেকে অনুশীলন শুরু করেছে বাংলাদেশ ক্রিকেট দল। সেখানে যাচ্ছেন মাহমুদউল্লাহ বাহিনী। কিন্তু নিরাপত্তা অজুহাতে তাদের সঙ্গে কোনো অসুবিধা নেই।
# 75    বাংলাদেশের কাছে টেস্ট সিরিজে হোয়াইটওয়াশ হওয়া মানতে পারছেন না পাকিস্তানের বাঁহাতি ক্রিকেটার ওয়াসিম আকরাম। কিন্তু ঘরের মাঠে তাদের হার নিয়ে তিনি তীব্র সমালোচনা করছেন।
# 76    বাংলাদেশ-জিম্বাবুয়ে সিরিজের তৃতীয় ম্যাচে মুশফিকুর রহিমকে বাদ দেয়ার সিদ্ধান্ত ঘোষণা করেছে বাংলাদেশ ক্রিকেট বোর্ড (বিসিবি)। কিন্তু ঘটনা হিতে বিপরীতে ঠেকাতে পারেনি।
# 77    চলমান এশিয়া কাপে বাংলাদেশ ও শ্রীলঙ্কা নিজেদের গ্রুপ পর্বের শেষ ম্যাচে আজ মুখোমুখি হচ্ছে। আফগানিস্তানের কাছে হেরে এখন কোণঠাসা পরিস্থিতিতে আছে দুই দলের জন্যই ম্যাচটি।
# 78    ফ্রি ট্রান্সফারে ব্রাজিলের ক্লাব গ্রেমিওতে যোগ দিলেন উরুগুয়ের তারকা ফুটবলার লুইস সুয়ারেজ। এবার তাকে দলে নেবেন লিওনেল মেসি এবং তার বন্ধু লন্ডনের সঙ্গে।
# 79    বাংলাদেশ জাতীয় ক্রিকেট দলের অধিনায়ক হিসেবে রাজশাহী কিংসের অধিনায়কের দায়িত্ব পেয়েছেন মেহেদী হাসান মিরাজ। বৃহস্পতিবার তিনি বলেছেন, এটি আমার জন্য অনেক বড় একটি সুযোগ এবং ভবিষ্যতে বাংলাদেশ দলও তাকিয়ে থাকবে তার দিকে।
# 80    বাংলাদেশ ক্রিকেট দলের মানসিকতা উন্নতি করা প্রয়োজন বলে মনে করেন বাংলাদেশের ক্রিকেটার সাকিব আল হাসান। তিনি বলেছেন, যদি প্ল্যান থাকতো তাহলে খেলা দেখার সুযোগ ছিল না। তবে এটা পরিকল্পনা নেই।
# 81    কল্পনা করুন আপনি একটি ধুসর রঙের ভালুকের সঙ্গে লড়াই করছেন। কে জিতবে বলে মনে হয়? কিন্তু এরকম সম্ভাবনাই বেশি যে, এরা আসলে অতিরিক্ত আত্মবিশ্বাসী।
# 82    কাতার বিশ্বকাপে নিজেদের দ্বিতীয় ম্যাচে সুইজারল্যান্ডকে ১-০ গোলে হারিয়েছে ব্রাজিল। দর্শকদের আনন্দ মিছিলের মাধ্যমে এই জয়ের রেশ ছড়িয়ে পড়ে রাজশাহী বিশ্ববিদ্যালয়ের ক্যাম্পাসেও। এমনকি শহরজুড়েও ফুটবল ভক্তদের সমাগম ঘটেছে।
# 83    পাকিস্তান ক্রিকেট দলের স্কোয়াডে থাকা একমাত্র বিশেষজ্ঞ স্পিনার আবরার আহমেদকে সরিয়ে নিয়েছে দলটি। যার ফলে বাংলাদেশের বিপক্ষে সিরিজের প্রথম টেস্টের আগে প্রস্তুতি শুরু হতে যাচ্ছে।
# 84    বাংলাদেশ ও ভারতের মধ্যকার টেস্ট সিরিজের প্রথম ম্যাচ শুরুর আগেই বাগড়ার হুমকি দিয়েছিল অখিল  ভারতীয় হিন্দু মহাসভা। কিন্তু এখন সেই দলকে সার্বিক নিরাপত্তা দিতে পরিকল্পনা তৈরি করেছে পুলিশ বিভাগ।
# 85    ব্রাজিলকে হারিয়ে ২৮ বছর পর কোন বড় আন্তর্জাতিক শিরোপা জিতলো আর্জেন্টিনা। ২০১৮ সালের বিশ্বকাপের ফাইনালে তারা ১-০ গোলে হেরে গিয়ে জয় নিশ্চিত করেছে। এটি ছিল প্রথমবারের মতো।
# 86    বিশ্বকাপ ক্রিকেটের ইতিহাসের সবচেয়ে বড় দলগুলোর মধ্যে - ভারত, পাকিস্তান, ফ্রান্স, ওয়েস্ট ইন্ডিজ અને ইংল্যান্ড. রাত ৮.৩০ মি.; টি-স্পোর্টস, স্পোর্ট્સ ၁၈
# 87    অস্ট্রেলিয়া ও দক্ষিণ আফ্রিকার মধ্যে সিডনিতে তৃতীয় টেস্টের প্রথম ইনিংসে অসি ক্রিকেটারদের তালিকায় যুগ্মভাবে তিন নম্বরে উঠে আসেন স্টিভ স্মিথ। এই ছাড়াও তিনি সবচেয়ে বেশি রান সেঞ্চুরি করেছেন।
# 88    চ্যাম্পিয়নস লিগে নিজেদের প্রথম ম্যাচে হার দিয়ে শুরু করেছিল বার্সেলোনা। ১০ জন নিয়ে চেষ্টা করেও হার দেয়নি তারা। কিন্তু সেই জয়টাই পেয়েছে হানসি ফ্লিকের দল। আজকের ম্যাচটি শেষ হয়ে গেছে।
# 89    বাংলাদেশ ও জিম্বাবুয়ের মধ্যে সিরিজের তৃতীয় ও শেষ ওয়ানডে ম্যাচ খেলতে নামছে বাংলাদেশ। বিদায়ী নেতা মাশরাফি বিন মুর্তজা এবং নড়াইল এক্সপ্রেস দলের অধিনায়ক মুশফিকুর রহিম।
# 90    যে কোনও মুহূর্তে রাশিয়া ইউক্রেনে আক্রমণ করে বসতে পারে-- এমন হুঁশিয়ারি পেয়ে পশ্চিমা শক্তিধর দেশগুলো তাদের নাগরিকদের ফিরে আসতে বলা হয়েছে। যুক্তরাজ্য, কানাডা ও জার্মানি এই অভিযোগ অস্বীকার করেছে।
# 91    ২০১৯ সালের পর থেকে জাতীয় দলে ডাক পাননি, তবে সম্প্রতি বাংলাদেশ প্রিমিয়ার লিগ- ২০২২ শিরোপা জয়ের পর আবারও আলোচনায় এসেছেন ইমরুল কায়েস। এই দলের বাইরে থাকার পরও তাকে নিয়ে তোলপাড় সৃষ্টি হয়েছে।
# 92    বাংলাদেশের জাতীয় ক্রিকেট দলের অধিনায়ক হিসেবে মাশরাফি বিন মুর্তজা অবসর নিচ্ছেন বলে ঘোষণা দিয়েছেন সাকিব আল হাসান। এই সিদ্ধান্তে নিজেদের অনুভূতি জানিয়েছেন সতীর্থরা এবং প্রিয় মাশরাফির নেতৃত্ব ছাড়ার কথা জানালেন সাংবাদিকরা।
# 93    বাংলাদেশের রাজনীতিতে ভিন্ন মতাদর্শ থাকবে। কিন্তু জাতির পিতা বঙ্গবন্ধু শেখ মুজিবুর রহমান, বাংলাদেশ, স্বাধীনতা, সার্বভৌমত্ব বিশ্বাস করতে পারে না। এমন মন্তব্য করেছেন আওয়ামী লীগের সাবেক সাংগঠনিক সম্পাদক এনামুল হক শামীম
# 94    আরও একবার চাকরি হারালেন পর্তুগিজ কোচ জোসে মরিনিয়ো। লন্ডনের ক্লাব টটেনহ্যাম হটসপার থেকে বিদায় নিলেন তিনি। এবারের মৌসুমে তিনটি লিগ ম্যাচ হেরেছে তারা।
# 95    আইপিএলে সাফল্য অর্জনের পর এবার টি-টোয়েন্টি লিগ নিয়ে আগ্রহী প্রকাশ করেছেন অস্ট্রেলিয়ার ক্রিকেটার প্যাট কামিন্স। কিন্তু শেষ পর্যন্ত ব্যর্থ হন তিনি। সেই সঙ্গে এই লিগের জনপ্রিয়তাও বাড়ছে বলে মনে করা হচ্ছে।
# 96    সাকিব আল হাসানকে নিয়ে ভারতের স্থানীয় সংবাদমাধ্যমে যে খবর ছড়িয়ে পড়েছে, সেই রেশটা আজ সকালের পত্রিকার পাতায়ই চোখে পড়তে শুরু করেছে। কিন্তু তাঁর অবসরের ঘোষণার সঙ্গে দেশে ফেরার শঙ্কার কথাও রয়েছে।
# 97    সৌদি আরবের ক্লাব আল নাসরে ছিল বিশ্ব ফুটবলে অচেনা। ২০১৪ সালে রিয়াল মাদ্রিদের সঙ্গে যোগ দিয়েছিলেন ক্রিশ্চিয়ানো রোনাল্ডো। কিন্তু এই প্রথম তিনি বিশ্বের সবচেয়ে বেশি বেতনভোগী ক্রীড়াবিদ।
# 98    লাসিথ মালিঙ্গার টি-টোয়েন্টি ক্রিকেট থেকে আগেই অবসর নিয়ে ফেলেছেন। কিন্তু শেষ পর্যন্ত টা-টা, বাই-বাই বলতে চান তিনি। সেই লক্ষ্য পূরণ হলেই ক্রিকেটারকে বিদায় বলে দিচ্ছেন।
# 99    গল টেস্টের শেষ দিনে নিউজিল্যান্ডকে ৬৩ রানে হারিয়েছে শ্রীলঙ্কা। কিন্তু এই সিরিজে লঙ্কানদের নায়ক কীভাবে জয় এনে দেন তা দেখতে পারেননি দর্শকরা ।
# 100    অনূর্ধ্ব-১৯ বিশ্বকাপের ১৩তম আসরে সেমিফাইনালে বিদায় নিয়েছে বাংলাদেশ যুব দল। এবারের লড়াইয়ে ওয়েস্ট ইন্ডিজের বিপক্ষে ৩ উইকেটের ব্যবধানে হেরে ট্রফির কাছে গিয়ে হোচট খায় বাংলাদেশ।
# 101    তিন ম্যাচ সিরিজের দ্বিতীয় টি-টোয়েন্টি সিরিজে ১৬ রানে হেরে গেছে সফরকারী লংকান ক্রিকেট দল। কিন্তু ব্যাটিং বিপর্যয়ের কারণে শেষ পর্যন্ত ১৯০/৮ রানের ইনিংস গুটায় ভারত।
# 102    সাত বছর কাটিয়ে নিজেকে সমৃদ্ধ করেছিলেন বার্সেলোনার একাডেমী লা মাসিয়ায়। কিন্তু ক্লাবটির হয়ে খেলতে পারেননি দানি ওলমো। এমন অভিষেকের স্বপ্ন দেখেছিলেন এই অ্যাটাকিং মিডফিল্ডার।
# 103    অস্ট্রেলিয়ার ক্রিকেট তারকা রিকি পন্টিং এবং ভারতের জেমিমাহ রদ্রিগেসের অপেক্ষার তর সইছে না। প্যারিস অলিম্পিকের পর্দা নেমে গেছে। এরই মধ্যে সব অ্যাথলেটদের লক্ষ্য তৈরি হবে লস অ্যাঞ্জেলেস অলিম্পিক ঘিরে
# 104    বাংলাদেশের বরিশাল নগরে এবারের বিশ্বকাপ ফুটবলের নকআউট পর্বে ব্রাজিল ৪-১ গোলে দক্ষিণ কোরিয়াকে হারিয়ে দুর্দান্ত এক জয় পেল গত রাতে। দলটির কোয়ার্টার ফাইনাল নিশ্চিত হয়ে গেছে।
# 105    প্রায় তিন বছর ধরে ব্রেইন টিউমারে আক্রান্ত বাংলাদেশ জাতীয় ক্রিকেট দলের সাবেক ক্রিকেটার মোশাররফ হোসেন রুবেল আজ মারা গেছেন। তার মৃত্যুর খবর নিশ্চিত করেছেন তার সহপাঠী ও বন্ধু।
# 106    চেন্নাইর চিপকের মাঠ মূলত ভারতের ওয়ানডে সিরিজের প্রথম টেস্ট। সেখানে লাল মাটির উইকেট থাকতে পারে বাংলাদেশ। কিন্তু এর মানে নেই যে, এই স্টেডিয়ামে সবচেয়ে বেশি উইকেটে উঠে আসে।
# 107    আফগানিস্তানের বিপক্ষে টি-টোয়েন্টি সিরিজের জন্য ভারত সফরে যাচ্ছেন বাংলাদেশের পেস বোলিং তারকা ইবাদত হোসেন। কিন্তু চোটে ভোগা এই পেসারকে ভারতে পাঠানোর সিদ্ধান্ত নিয়েছে বাংলাদেশ ক্রিকেট বোর্ড।
# 108    গুজরাটের নরেন্দ্র মোদী স্টেডিয়ামে ভারত ও পাকিস্তানের মধ্যকার ম্যাচটি বেশ আলোচনার জন্ম দিয়েছে। কিন্তু দর্শকদের কাছে এটা মনে হয়নি বিশ্বকাপের মতো একটা ইভেন্টের ম্যাচে।
# 109    আর্জেন্টিনার উয়েফা কনফারেন্স লিগের সেমি-ফাইনালে গোলরক্ষক এমিলিয়ানো মার্তিনেসকে তিন দফায় হলুদ কার্ড দেখায় এক ম্যাচ নিষিদ্ধ করেছে ইংলিশ ফুটবলার রেফারি ।
# 110    নিউজিল্যান্ডের বিপক্ষে তৃতীয় টি-টোয়েন্টি সিরিজে প্রথম সারির দল না পাঠিয়ে সমালোচনার জন্ম দিয়েছিল পাকিস্তান। কিন্তু গতকাল লাহোরে চতুর্থ ম্যাচেও ভারতের জাতীয় ক্রিকেট দলের জয় নিয়ে প্রশ্ন উঠেছে।
# 111    সৌদি ফুটবল ক্লাব আল নাসরে যোগ দিয়েছেন পর্তুগালের ফরোল্ড ক্রিশ্চিয়ানো রোনাল্ডো। এ নিয়ে আলোচনা চলছে গত কয়েক দিনের মধ্যে। কিন্তু এ বিষয়ে এখনো কিছু জানা যায়নি।
# 112    টি-টোয়েন্টি বিশ্বকাপে নেদারল্যান্ডস দলকে ৬ উইকেটে হারিয়েছে ডালাস। কিন্তু শেষ পর্যন্ত সেই ম্যাচটি হলো যুক্তরাষ্ট্রের ইংল্যান্ডে। এবারের ম্যাচে নেপালের সমর্থকরা দারুণ বোলিং-ফিল্ডিং ও ফিল্ডিংয়ে বর্ণিল পারফরম্যান্সের
# 113    আগামী মৌসুমে বায়ার্ন মিউনিখের সম্ভাব্য নতুন কোচ হওয়ার দৌড়ে ইউলিয়ান নাগেলসমানের নাম শোনা যাচ্ছিল জোরেশোরে। গত বছরের সেপ্টেম্বরে তাকে বরখাস্ত করা হয়।
# 114    নিউজিল্যান্ডের মাটিতে শুরু হচ্ছে নারী ক্রিকেটের দ্বাদশ বিশ্বকাপ। এই প্রথমবারের মতো বাংলাদেশের নারীদের ওয়ানডে ফরম্যাটের দুটি ম্যাচে অংশগ্রহন করবে দলটির নিয়মিত পর্যবেক্ষকরা।
# 115    টি-টোয়েন্টি বিশ্বকাপ খেলছে কানাডা ক্রিকেট দল। দলের কোনো ক্রিকেটার নেই। কিন্তু ভারতের কোনও দেশে জন্মাতে পারেনি তারা। সেই সঙ্গে যুক্তরাষ্ট্রের দলে খেলেছেন ২২জন ক্রিকটার।
# 116    আগের দিন শেষ বিকেলেই মনে হচ্ছিল বাংলাদেশের ব্যাটারদের সামনে আছে কঠিন চ্যালেঞ্জ। কিন্তু তৃতীয় দিনে পাকিস্তানের বিরুদ্ধে তোলপাড় সৃষ্টি করেছে বাংলাদেশ। আন্তর্জাতিক ক্রিকেট স্টেডিয়ামে এই টেস্টটি শুরু হওয়ার পর থেকেই নতুন করে আল
# 117    ক্রিকেটের বৈশ্বিক আসরে বাংলাদেশ এখনো কোনো শিরোপা অর্জন করতে পারেনি। কিন্তু টি-টোয়েন্টি বিশ্বকাপে বাংলাদেশের সাফল্য নিয়ে আবেগঘন বার্তা দিয়েছেন পেসার শরিফুল মাহমুদউল্লাহ রিয়াদ।
# 118    ক্রিকেট বিশ্বে নতুন বছর শুরু হয়েছে। ২০১৮ সালটি দারুণ কেটেছে বাংলাদেশের দলগত সাফল্যের পাশাপাশি ব্যক্তিগত অর্জনেরও অব্যাহত থাকবে। এ নিয়ে আবারো আলোচনা চলছে ২০১৯ সালে।
# 119    টি ২০ বিশ্বকাপ অভিষেকে চমক দেখানোর স্বপ্ন ছিল আফগানিস্তানের উগায়ান্ডোর তরুণ বোলার ফজলহক ফারুকির। কিন্তু এরই মধ্যে সাত-আটবার হ্যাটট্রিকের সম্ভাবনা জাগিয়েও পারেনি তিনি।
# 120    বাংলাদেশ ক্রিকেট দলের নির্বাচনে সাকিব আল হাসান নিয়মিত যোগ দেবেন বলে জানিয়েছেন বিসিবি প্রধান নির্বাচক গাজী আশরাফ হোসেন লিপু। পাকিস্তান সফরের আগে থেকেই তাকে দলে রাখার কথা রয়েছে।
# 121    ঢাকার মিরপুরে টি-টোয়েন্টি বিশ্বকাপ চ্যাম্পিয়ন ইংল্যান্ডের বিপক্ষে সহজ জয় তুলে নিল বাংলাদেশ। সাকিব আল হাসানের নেতৃত্বে এই দুই ম্যাচ সিরিজ শেষ হওয়ার কথা রয়েছে।
# 122    প্রথমবারের মতো প্যারিস সেইন্ট জার্মেইঁ বা পিএসজির ফুটবলার হিসেবে একটি সংবাদ সম্মেলনে যোগ দিলেন লিওনেল মেসি। তিনি বলছেন, সবকিছু জয়ের জন্যই খেলবেন এবং কোন খেলাই আমার কাছে অগুরুত্বপূর্ণ না।
# 123    দিল্লিতে শ্রীলঙ্কার বিরুদ্ধে বিশ্বকাপের ম্যাচে সোমবার রাতে ৩ উইকেটে জিতে পরের চ্যাম্পিয়ন্স ট্রফিতে খেলার আশা জিইয়ে রাখল বাংলাদেশ। কিন্তু এর আগে কোনও ক্রিকেটারকে দেরি করে ক্রিজে আসার জন্য আউট হতে হয়েছে।
# 124    দিনাজপুরের গোর-এ-শহীদ মাঠে মেয়েদের ফুটবল অনুশীলন শুরু করেন নুর ইসলাম (৪৮)। এরপর তারা গড়ে তোলেন 'নওশীন প্রমিলা ফুটের একাডেমি'।
# 125    বিশ্বকাপ ফুটবলার এএস রোমার হয়ে গত মৌসুমটা দুর্দান্ত কাটালেও এবার কোপা আমেরিকায় আর্জেন্টিনা দলে ছিলেন না পাওলো আর্জেন্টাইন ফরোল্ড দিবালা। নতুন একমাত্র ক্লাবটিও ছেড়ে দিতে যাচ্ছে তাকে।
# 126    অস্ট্রেলিয়ার ব্যাটসম্যান ডেভিড ওয়ার্নার তার শেষ টেস্ট ম্যাচের আগে ওয়ানডে (ওডিআই) ক্রিকেট থেকে অবসরের ঘোষণা দিয়েছেন। এই সিদ্ধান্তটি তিনি ভেবেচিন্তেই নিয়েছেন। তবে এবারের চ্যাম্পিয়ন্স ট্রফিতে খেলার সম্ভাবনা উড়িয়ে দেননি ওয়ার্
# 127    ২০২৬ বিশ্বকাপ বাছাইপর্বের দক্ষিণ আমেরিকা অঞ্চলের ম্যাচে কলম্বিয়ার কাছে ১-২ গোলে হেরেছে আর্জেন্টিনা। ম্যাচটি চলাকালীন স্থানীয় তাপমাত্রা ৩৬ ডিগ্রীর কাছাকাছি।
# 128    বাংলাদেশের ফুটবলের সর্বোচ্চ নিয়ন্ত্রক সংস্থার সভাপতি পদ থেকে পদত্যাগ করেছেন ক্রীড়াবিদ কাজী সালাহউদ্দিন। এর আগে থেকেই তিনি আগের অবস্থানে সরে এসেছেন। তবে গত কয়েকদিন ধরে তার এই পদে পরিবর্তন এসেছে।
# 129    সানিয়া মির্জার সঙ্গে বিবাহবিচ্ছেদের মাস কয়েকের মধ্যেই তৃতীয়বার বিয়ে করলেন পাকিস্তানি ক্রিকেটার শোয়েব মালিক। এই বিয়ের খবর সামাজিক যোগাযোগমাধ্যমে ছড়িয়ে পড়ার পর ভারতের স্কুলেই ছেলেকে ভর্তির সিদ্ধান্ত নিয়েছেন তিনি।
# 130    অস্ট্রেলিয়া ও নিউজিল্যান্ডের বিপক্ষে দুই সিরিজের প্রথম ম্যাচে ৩৪ রান ও ২ উইকেট- বাংলাদেশের ব্যাটিং অলরাউন্ডার সৌম্য সরকারের পারফরম্যান্স নিয়ে বেশ আলোচনা চলছে। কিন্তু তিনি কী করছেন?
# 131    বাংলাদেশ ও পাকিস্তানের মধ্যে সিরিজের প্রথম ম্যাচে তামিম ইকবাল রান আউট হওয়ার পর এখন আলোচনার কেন্দ্রে আছেন বাংলাদেশের সিনিয়র ক্রিকেটারদের একটি অংশ। এই দুই ম্যাচের ফলাফল নিয়ে তোলপাড় চলছে।
# 132    ২০০৩ সালে রাওয়ালপিন্ডিতে পাকিস্তানকে হারানোর পর বাংলাদেশের ইতিহাসে সবচেয়ে বড় টেস্ট ম্যাচটি হয়েছিলো সেদিনের মাঠে। কিন্তু শেষ দিনে ভারতের সাথে তোলপাড় সৃষ্টি হয়নি।
# 133    ভুটানে চলমান সাফ অনূর্ধ্ব-১৭ চ্যাম্পিয়নশিপে সেমিফাইনালে উঠতে যাচ্ছে বাংলাদেশ দল। ভারত ও মালদ্বীপের মধ্যে দুটি ম্যাচ শেষ হওয়ার পর এই লড়াই শুরু হচ্ছে।
# 134    বাংলাদেশ ক্রিকেট বোর্ডের পরিচালনা পর্ষদের আরেকটি জরুরি সভা আহবান করেছে বিসিবি। সাবেক অধিনায়ক নাজমুল হাসান পাপন পদত্যাগ করলেও নতুন পরিচালক হিসেবে দায়িত্ব পালন করেন ফারুক আহমেদ।
# 135    এএফসি অনূর্ধ্ব-২০ এশিয়ান কাপের বাছাইপর্বে অন্তত দুটি জয়ের আশা নিয়ে দেশ ছেড়েছিল বাংলাদেশ দল। ভুটান ও গুয়ামের বিপক্ষে ড্র করার পর শেষ পর্যন্ত জয় পেয়েছে বাংলাদেশ।
# 136    নিউজিল্যান্ড ও শ্রীলঙ্কার মধ্যকার তিনটি টেস্ট সিরিজের প্রথম দিন শুরু হওয়ার পর কিউই বোলাররা এমন একটি দেখা দেখতে পারেন যে সব সময় মেলে না। কিন্তু এটি নিয়ে কোন প্রশ্ন নেই।
# 137    বিপিএল ফাইনালে রাজশাহী রয়েলস ও খুলনা টাইগার্সের বিপক্ষে ১৭০ রানের চ্যালেঞ্জিং স্কোর উপহার দিয়েছে আন্দ্রে রাসেল ও মোহাম্মদ নওয়াজের ব্যাটিং ঝড়ে দলকে ম্যাচে ফেরাতে নেমেছিল রাজশাহীর দক্ষিণ আফ্রিকান অলরা
# 138    বাংলাদেশ ক্রিকেট দল টি-টোয়েন্টি সিরিজের জন্য আগামী ২৪ জানুয়ারি পাকিস্তানের রাজধানী লাহোর কেন্দ্রিক নিরাপত্তা জোরদার করেছে দেশটির সরকার। শনিবার সফরে যাওয়ার কথা রয়েছে টাইগাররা।
# 139    ভারতের সাবেক ওপেনিং ব্যাটসম্যান ওয়াসিম জাফর নিশ্চিত করেছেন যে তিনি অস্ট্রেলিয়ার বিপক্ষে দ্বিতীয় টেস্ট ম্যাচের ব্যাটিং নিয়ে দুশ্চিন্তা প্রকাশ করতে চান। টুইটারে এমন একটি বার্তা পোস্ট করা হয়েছে, যেখানে দেখা গেছে ১৬টি
# 140    লা লিগায় লেভান্তের বিপক্ষে পেনাল্টি থেকে গোল করেছেন রিয়াল মাদ্রিদের দুই তারকা করিম বেনজেমা ও গ্যারেথ বেল। এই ম্যাচে ভিনিসিয়ুস দলকে হারিয়েছে ভিনিসিয়াুস।
# 141    বিশ্ব ফুটবল এগিয়ে চলছে রকেট গতিতে। বাংলাদেশের ইতিহাসের সবচেয়ে বড় দলগুলোর মধ্যে অন্যতম হল নেপালের জামাল ভূঁইয়া। কিন্তু এ বছর ছিল নানা ধরণের ব্যর্থতা।
# 142    বার্সেলোনা জানিয়েছে, ক্লাবের সাথে তার নতুন চুক্তির মেয়াদ শেষ হওয়ার পরও লিওনেল মেসি ক্লাবে থাকছেন না। তিনি এখন ফ্রি এজেন্ট হিসেবে রয়েছেন। এ নিয়ে তীব্র অনুশোচনা চলছে।
# 143    আজ থেকে ঠিক ২০ বছর আগে বাংলাদেশ টেস্ট ক্রিকেটের প্রথম ম্যাচটি খেলার জন্য মাঠে নেমেছিল। ভারতের বিপক্ষে তিনটি ম্যাচে জয় পেয়েছে বাংলাদেশ দল, ড্র করেছে ১৬টি।
# 144    পাকিস্তান ও নিউজিল্যান্ডের মধ্যে করাচিতে দ্বিতীয় টেস্টের প্রথমদিনে কিউইরা চারটি উইকেট হারিয়ে জয় পেয়েছে। তৃতীয় দিনের শেষ সেশনে ৪৫ রানে আঘাত হানল দেশটি।
# 145    শ্লীলতাহানির অভিযোগে ভারতের হরিয়ানা রাজ্যের ক্রীড়ামন্ত্রী সন্দীপ সিং পদত্যাগ করেছেন। এফআইআর দায়ের করে পুলিশ বলেছে, তিনি নিজের ভাবমূর্তি খারাপ করার চেষ্টা করছেন বলে তাকে দায়িত্ব মুখ্যমন্ত্রীর হাতে তুলে দেয়া হয়েছে।
# 146    বাংলাদেশ ও পাকিস্তানের মধ্যকার দ্বিতীয় ওয়ানডে সিরিজের প্রথম দিনে বাংলাদেশের ব্যাটসম্যানরা দুই উইকেটে জয় পেয়েছেন। এই সিরিজে বড় ধরণের বিপর্যয়ের মুখে পড়েছে স্বাগতি করা দল বাংলাদেশ।
# 147    বাংলাদেশের টি-টোয়েন্টি ক্রিকেট দলের অনুশীলন শেষ হওয়ার কয়েকদিন পর এবারের বিশ্বকাপে নিজেদের সতীর্থদের নিয়ে আলাপ করেছেন ক্রিকেটাররা। এই প্রথমবারের মতো এশিয়া কাপের দামামা বেজে গেছে।
# 148    টি-টোয়েন্টি বিশ্বকাপ ২০২৪ এর গ্রুপ-ডি'র গুরুত্বপূর্ণ এক ম্যাচে মুখোমুখি হচ্ছে বাংলাদেশ ও নেদারল্যান্ডস। এই দুই দলেরই একটি করে জয়ের আশা জাগিয়ে হেরে গিয়েছে। এমনকি ওয়ানডে ফরম্যাটে জয় পেয়েছে বাংলাদেশ।
# 149    আগামী ২০৩৪ বিশ্বকাপের আয়োজক হওয়া প্রায় নিশ্চিত করে ফেলেছে সৌদি আরব। কিন্তু কোনো প্রতিদ্বন্দ্বী হিসেবে দৌড়ে টিকে থাকতে পারে দেশটির দল ফিফা। এমনকি নেইমার।
# 150    অলিম্পিক ফুটবল ফাইনালে এবারের দিন ছিল ৫০০ মিটার ক্যানো ডাবল স্প্রিন্ট। এই ইভেন্টে ৩০টি সোনা জিতে নিয়েছে যুক্তরাষ্ট্র ও চীনের মধ্যে শীর্ষে থাকার লড়াই।
# 151    ফুটবল বিশ্বকাপ বাছাইয়ের দ্বিতীয় রাউন্ডের প্রথম লেগে অস্ট্রেলিয়ার বিপক্ষে ড্র করে বাংলাদেশের অবস্থান ২৪ নম্বরে। অন্যদিকে ফিফা ের ্যাঙ্কিংয়ে ১৬৪ স্থানে আছে বাংলাদেশ।
# 152    ক্যারিয়ারের শেষ সময়ে ইউরোপীয় ফুটবল তারকা ক্রিশ্চিয়ানো রোনাল্ডো সৌদি আরবে এসে পৌঁছেছেন। তাকে মঙ্গলবার নিজেদের মাঠে খেলোয়াড় হিসেবে পরিচয় করিয়ে দেবে ক্লাবটি।
# 153    অলিম্পিকের পুরুষ ফুটবলের ফাইনালে ৩-১ লিড নিয়ে বাজিমাত করেছে স্পেন। কিন্তু অতিরিক্ত সময়ের খেলা শেষ পর্যন্ত তারা জয় পেরে উঠবেনি বলে আশঙ্কা তৈরি হয়নি।
# 154    অস্ট্রেলিয়ার কিংবদন্তী স্পিনার শেন কিথ ওয়ার্ন মারা গেছেন। থাইল্যান্ডের কোহ সামুই ভিলাতে তিনি অচেতন অবস্থায় পাওয়া গেছে বলে জানাচ্ছেন তাকে ম্যানেজমেন্ট কোম্পানি ।
# 155    আফ্রো-এশিয়া কাপের দ্বি-বার্ষিক আসরের ধারণা আবার ফেরানোর সম্ভাবনা তৈরি হয়েছে। কিন্তু এই প্রথমবারের মতো এশিয়া একাদশের হয়ে একই জার্সিতে খেলতে দেখা যাচ্ছে না ভারতের মাহেলা জয়াবর্ধনের নেতৃত্বে।
# 156    অস্ট্রেলিয়া বনাম নিউজিল্যান্ড, ঠিক ছয় বছর পর আরও একটি আইসিসি বিশ্ব ইভেন্টের ফাইনালে মুখোমুখি হচ্ছে দুই দেশের ক্রিকেট দল। কিন্তু টি-টোয়েন্টি বিশ্বকাপ কীভাবে শেষ হবে?
# 157    হাসান মাহমুদের চোখ ধাঁধানো স্যুয়িং বোলিংয়ে বাংলাদেশের দারুণ শুরুর পর প্রতিরোধ গড়েছে ভারত। বৃহস্পতিবার চেন্নাইতে প্রথম সেশনে ৩ উইকেটে ৮৮ রান তুলেছে বাংলাদেশ।
# 158    রাওয়ালপিন্ডিতে পাকিস্তানের বিপক্ষে প্রথম টেস্ট সিরিজ খেলতে যাচ্ছে বাংলাদেশ। কিন্তু অতীত রেকর্ড বদলে দেওয়া সহজ না হলেও সম্ভব বলে মনে করেন বাংলাদেশের অধিনায়ক নাজমুল হোসেন শান্ত।
# 159    বাংলাদেশ ক্রিকেট দল ভারতে অবস্থান করবে অক্টোবরের দ্বিতীয় সপ্তাহ পর্যন্ত। কিন্তু টি-টোয়েন্টি সিরিজ থেকে অবসরের ঘোষণা দিয়েছেন সাকিব আল হাসান। সেই সিদ্ধান্তটি কার্যকর?
# 160    মুম্বাইয়ের ওয়াংখেড়েতে বিশ্বকাপ ক্রিকেটের প্রথম সেমিফাইনালে ভারত ৭০ রানে নিউজিল্যান্ডকে হারিয়ে ফাইনালের জন্য নিজেদের জায়গা নিশ্চিত করেছে। এর আগে এই ম্যাচের তৃতীয় ম্যাচে তিনটি উইকেট হারানো হয়েছিল।
# 161    দক্ষিণ আফ্রিকার ক্রিকেট ইতিহাসে কখনো বিশ্বকাপ ফাইনাল খেলা হয়নি যে চাপের মুখে ভেঙ্গে পড়ার কারণে। কিন্তু এই নাটকীয়তার নায়ক রাইলি রুশোর টুইটটি এখন নতুন নয়।
# 162    টি-টোয়েন্টি বিশ্বকাপের প্রথম সেমিফাইনালে বুধবার মুখোমুখি হচ্ছে ইংল্যান্ড ও নিউজিল্যান্ড। এই দুই দলের মধ্যে এবারের দেখায় কে এগিয়ে এবং কে কে পিছিয়ে?
# 163    পর্তুগালের সুপারস্টার ক্রিশ্চিয়ানো রোনালদো ম্যানচেস্টার ইউনাইটেডে দ্বিতীয়বারের মত যোগ দিয়ে তার পছন্দের সাত নম্বর জার্সিই পেতে যাচ্ছেন - নিশ্চিত করেছে যুক্তরাষ্ট্রের ক্লাব কর্তৃপক্ষ।
# 164    'ভাই তাড়াতাড়ি গোল দেন, এ সময়ের মধ্যে জয় দিতে হবে। কিন্তু আজমপুরের কোচের সাথে ম্যাচ গড়াপেটার সঙ্গে জড়িত ছিল- এমন অভিযোগে পদত্যাগ করেছেন ফরাশগঞ্জের ফুটবলার।
# 165    ভারত ও পাকিস্তানের মধ্যে প্রথম টি-টোয়েন্টি ক্রিকেট ম্যাচ রবিবার নিউ ইয়র্কে শুরু হতে যাচ্ছে। কিন্তু কেন সেটা আলোড়ন ফেলছে আমেরিকার মানুষের মতো? তিরিশ বছর আগে থেকেই এই দুই দল ওয়ানডে সিরিজ
# 166    নাসির হোসেনের অলরাউন্ড নৈপূণ্যে ঢাকা ডায়নামাইটস ও দিলশানের মুনাওয়েদের বিপক্ষে বিপিএল নবম আসরের প্রথম ম্যাচে জয় পেয়েছে খুলনা টাইগার্স। শনিবার মিরপুর শেরেবাংলা জাতীয় ক্রিকেট স্টেডিয়ামে ম্যাচটি হয়েছিল
# 167    বিশ্বকাপ ক্রিকেটে বাংলাদেশের প্রথম ম্যাচে নেদারল্যান্ডস ও ইংল্যান্ডের মধ্যে রোমাঞ্চকর লড়াই হয়েছিল ডালাসে, একই দিনে মঙ্গলবার রাতে বার্বাডোজে মুখোমুখি হয়েছিলেন বাংলাদেশ।
# 168    ইংল্যান্ড এবং শ্রীলঙ্কার বিপক্ষে আজ মুখোমুখি হচ্ছে বিশ্বকাপ ক্রিকেটের দল স্কোয়াড। পাকিস্তানের অধিনায়ক বাবর আজমকে দলের প্রধান নির্বাচক ইনজামাম উল হককে পূর্ণ স্বাধীনতা দেয়া হয়েছিল।
# 169    মঙ্গলবার রাওয়ালপিন্ডিতে দুই ম্যাচ টেস্ট সিরিজের দ্বিতীয় ম্যাচে পাকিস্তানকে ৬ উইকেটে হারিয়ে আইসিসি ক্রিকেটের চ্যাম্পিয়নশিপের প্রথম স্থানে উঠে এসেছে বাংলাদেশ দল। কিন্তু শেষ পর্যন্ত ভারতের বিপক্ষে তিনটি জয় পেয়েছে টাইগাররা।
# 170    নিউজিল্যান্ড ও ভারতের মধ্যে দ্বিপাক্ষিক ক্রিকেট সিরিজে অংশ নিতে আগামী বুধবার সফরে রয়েছে বাংলাদেশ দল। কিন্তু এবারের মাঠে নামার আগে আত্মবিশ্বাস চাঙ্গা করেছে কিউইরা।
# 171    চ্যাম্পিয়নস লিগে নিজেদের প্রথম ম্যাচে হার দিয়ে শুরু করেছিল বার্সেলোনা। ১০ জন নিয়ে চেষ্টা করেও হার দেয়নি তারা। কিন্তু সেই জয়টাই পেয়েছে হানসি ফ্লিকের দল। আজকের ম্যাচটি শেষ হয়ে গেছে।
# 172    ২০১৮ সাল নিয়ে বিবিসি ফুটবল বিশ্বকাপের সবচেয়ে বড় গবেষণা প্রতিবেদন। বিষয়টি ছিলো - সর্বকালের সর্বশ্রেষ্ঠ ক্রিকেটার লিওনেল মেসির বিদায়ী বছর এবং স্বাগত-২০১৯।
# 173    লা লিগায় খেলার সময় লিওনেল মেসি ও ক্রিস্টিয়ানো রোনাল্ডোর দ্বৈরথ প্রায়ই দেখা যেত। কিন্তু করোনাভাইরাসের কারণে দুজনের লড়াইয়ের সম্ভাবনা থেকেই এবার আলোচনায় এসেছে।
# 174    এশিয়া কাপে বাংলাদেশের টি টোয়েন্টি ক্রিকেট দল নতুন করে শুরু করতে যাচ্ছে বলে জানিয়েছেন ক্রিকেটার সাকিব আল হাসান। কিন্তু এটা নিয়ে সন্দেহ থেকেই গেছে এই দলের পরিস্থিতি।
# 175    আইসিসি টি ২০ বিশ্বকাপে পাকিস্তানকে নিয়ে বড় স্বপ্ন দেখছেন সাবেক অলরাউন্ডার শহীদ আফ্রিদি। তিনি বলেছেন, 'পাকিস্তানের উচিত বাবরকে সমর্থন দেওয়া, বিশেষ করে সিনিয়ররা।'
# 176    বাংলাদেশ জাতীয় ক্রিকেট দলের নতুন স্পিন বোলিং কোচ হিসেবে নিয়োগ দেওয়া হয়েছে পাকিস্তানের সাবেক লেগস্পিনার এবং বিশ্বকাপজয়ী মুশতাক আহমেদকে। এই দায়িত্বে ছিলেন তিনি।
# 177    কাতার বিশ্বকাপে নিজেদের দ্বিতীয় ম্যাচে সুইজারল্যান্ডকে ১-০ গোলে হারিয়েছে ব্রাজিল। দর্শকদের আনন্দ মিছিলের মাধ্যমে এই জয়ের রেশ ছড়িয়ে পড়ে রাজশাহী বিশ্ববিদ্যালয়ের ক্যাম্পাসেও। এমনকি শহরজুড়েও ফুটবল ভক্তদের সমাগম ঘটেছে।
# 178    সৌদি ফুটবল ক্লাব আল নাসরে যোগ দিয়েছেন পর্তুগালের ফরোল্ড ক্রিশ্চিয়ানো রোনাল্ডো। এ নিয়ে আলোচনা চলছে গত কয়েক দিনের মধ্যে। কিন্তু এ বিষয়ে এখনো কিছু জানা যায়নি।
# 179    জম্মু-কাশ্মীরের পুলওয়ামায় তথাকথিত পাকিস্তানের 'জঙ্গি' হামলায় রাগে-ক্ষোভে ফুঁসছে ভারত। কিন্তু এ নিয়ে মাথা ঘামাতে নারাজ সিএবি প্রেসিডেন্ট সৌরভ গাঙ্গুলি।
# 180    নিউইয়র্কের নাসাউ ক্রিকেট স্টেডিয়ামে আয়ারল্যান্ড দলকে মাত্র ৯৬ রানে অলআউট করে তাদের প্রথম ম্যাচ খেলে তৃতীয়বারের মতো মাঠে নামেছে ভারত। কিন্তু এখন পর্যন্ত টি-টোয়েন্টি ফরম্যাটে দুই ম্যাচে দেখা যায়নি।
# 181    অস্ট্রেলিয়ান ওপেনের ফাইনালে ২-০ তে পিছিয়ে পড়েও শেষ পর্যন্ত ৩-২ সেটে রাশানের টেনিস তারকা দানিল মেদভেদেভকে হারিয়ে শিরোপা জিতেছেন স্পেনের রাফায়েল নাদাল।
# 182    বিশ্বকাপ ক্রিকেটে বাংলাদেশের বিপক্ষে আজ টসে জিতে সেমিফাইনাল নিশ্চিত করেছে ভারত। তবে এই ম্যাচের আলোচনার চারটি দিক কীভাবে দেখছেন ভারতীয় সমর্থক ও সামাজিক যোগাযোগ মাধ্যমে?
# 183    'ভাই তাড়াতাড়ি গোল দেন, এ সময়ের মধ্যে জয় দিতে হবে। কিন্তু আজমপুরের কোচের সাথে ম্যাচ গড়াপেটার সঙ্গে জড়িত ছিল- এমন অভিযোগে পদত্যাগ করেছেন ফরাশগঞ্জের ফুটবলার।
# 184    ভারত ও অস্ট্রেলিয়ার মধ্যে চলমান ক্রিকেট বিশ্বকাপের ফাইনাল ম্যাচটি আজ (মঙ্গলবার) বাংলাদেশের আহমেদাদা স্টেডিয়ামে শুরু হতে যাচ্ছে। কিন্তু এই দুটি দল কীভাবে ফাইনালে উঠেছে?
# 185    বাংলাদেশ ও পাকিস্তানের মধ্যে সিরিজের প্রথম টেস্ট ম্যাচের দ্বিতীয় দিনে তিন উইকেটে হেরে গেছে বাংলাদেশ। এরপর সেখানে তৃতীয় দিনের খেলা শুরু হয় দেরির সঙ্গে, কিন্তু সেটি ছিল দারুণ।
# 186    ইন্ডিয়ান প্রিমিয়ার লিগ আইপিএলের ১৬তম আসর শুরু হচ্ছে শুক্রবার। গতবারের চ্যাম্পিয়ন গুজরাট টাইটান্সের বিপক্ষে মাঠে নামবে চেন্নাই সুপার কিংস। এবার ভারতের ভবিষ্যৎ অধিনায়ক হার্দিক পান্ডিয়া।
# 187    বিশ্বকাপ ক্রিকেটে মোহাম্মদ শামি ভারতের বিপক্ষে তিন ম্যাচের একটি ম্যাচে ৪৪ উইকেট নিয়েছেন, যার মধ্যে সবচেয়ে ভালো বোলিং ফিগার ১৬ রানে পাঁচ উইকেটে শিকার করেছেন।
# 188    বাংলাদেশ ও পাকিস্তানের মধ্যে দ্বিতীয় টেস্ট ম্যাচের প্রথম দিনে দারুণ একটি ইনিংস খেলার পর বাংলাদেশের ব্যাটসম্যান লিটন দাস যখন ব্যাটিংয়ে নামেন তখন রীতিমতো ধ্বংসস্তূপে পরিণত হয়েছে দল।
# 189    রোববার রাওয়ালপিন্ডিতে পাকিস্তানকে ১০ উইকেটে হারিয়ে ঐতিহাসিক জয় পাওয়ার দিন বারবার ফিরে আসছিল ২১ বছর আগের স্মৃতি। কিন্তু এবারের টেস্ট খেলা নিয়ে নতুন করে আলোচনা শুরু হয়েছে।
# 190    বাংলাদেশের বিপক্ষে টেস্ট ম্যাচের দ্বিতীয় দিনে নিউজিল্যান্ডের ব্যাটসম্যান রস টেলরের নাম ঘুরে বেড়াতে শুরু করেছে বাংলাদেশ ক্রিকেট দলের নতুন একটি দল। কিন্তু এই ক্রিকেটারকে নিয়ে কোন বিতর্ক নেই।
# 191    হাঙ্গেরির বুদাপেস্ট সিক্স ডে আন্তর্জাতিক মাস্টার্স দাবা টুর্নামেন্ট শেষে বাংলাদেশের ফিদে ওয়াদিফা আহমেদ নিজের প্রথম মাস্টার নর্ম পেয়েছেন। সেই লক্ষ্যে তিনি চতুর্থ হয়েছেন।
# 192    পাকিস্তান মুসলিম লিগে (পিএমএল-এন) পদোন্নতি পেয়েছেন মরিয়ম নওয়াজ। দলটির গঠনতন্ত্রের প্রদত্ত ক্ষমতাবলে তিনি নতুন প্রেসিডেন্ট হিসেবে নিয়োগ করা হয়েছে বলে জানিয়েছে দেশটির প্রধানমন্ত্রী।
# 193    বাংলাদেশ প্রিমিয়ার লিগের শীর্ষ রান সংগ্রাহকদের তালিকায় আছেন নাজমুল হোসেন শান্ত। বিপিএল-২০২৩ এবং ওয়ানডে ক্রিকেটে তার অবদান সবচেয়ে বড়। কিন্তু এই প্রতিবেদন লেখার সময়েও তিনি ছিলেন অন্যতম সেরা ক্রিকেটার।
# 194    কাতার বিশ্বকাপের ফাইনালে ফ্রান্সের বিপক্ষে টাইব্রেকারে জিতে নেন আর্জেন্টিনার গোলকিপার এমিলিয়ানো মার্টিনেজ। কিন্তু তার কারণেই তাকে 'গোল্ডেন গ্লাভস' হিসেবে দেখা যায়।
# 195    আধুনিক ক্রিকেটের সবচেয়ে বড় তারকা ছিলেন বিরাট কোহলি। কিন্তু ভারতের বিশ্বকাপ দলে তিনি আছেন বিস্তর ফারাক রটা আর ঘটার মাঝে। এমনকি সাবেক অস্ট্রেলিয়ান ওপেনার ম্যাথু হেডেনও বলেছেন, 'কোহলির ওপর
# 196    বিশ্বের সব খেলার সেরা খেলোয়াড়দের মধ্যে সেবা নির্বাচিত হয়েছেন লিওনেল মেসি। ২০১৮ সালের চ্যাম্পিয়ন অব দ্য ওয়ার্ল্ড চম্পিয়নস পুরস্কারটি জিতেছেন মেসির দল লেকিপের সম্পাদকীয় বিভাগের সাংবাদিকরা।
# 197    ইন্ডিয়ান প্রিমিয়ার লিগ বা আইপিএলের শেষ ওভারে পাঁচ বলে ছয় রান তাড়া করার পর ভারতের তরুণ ক্রিকেটার রিঙ্কু সিং এখন টুইটারে বিশ্বব্যাপী ট্রেন্ডিং, বিশ্বের বিভিন্ন দেশের তারকাদের নজর কেড়েছেন।
# 198    নিউজিল্যান্ডের বিপক্ষে তৃতীয় টি-টোয়েন্টি ক্রিকেটে ৩৮ রান করে ভারতের ক্যাপ্টেন মহেন্দ্র সিং ধোনিকে ছাপিয়ে গেলেন বিরাট কোহলি। তিনি এখন বিশ্বের সেরা ওয়ানডে অধিনায়ক।
# 199    চ্যাম্পিয়ন্স লিগের সেমিফাইনালে পৌঁছেছে রিয়াল মাদ্রিদ। কিন্তু কোচ কার্লো আনচেলেত্তির দুর্দান্ত রক্ষণ প্রতিরোধ গড়ে ম্যাচ বের করার কৌশলটি ছিলো দারুণ।
# 200    বাংলাদেশে প্রধান নির্বাচন কমিশনার চাকরি রক্ষার্থে আসন্ন ঢাকা সিটি কর্পোরেশন নির্বাচনে অভিনব ভোট লুটের আয়োজনে ব্যস্ত বলে অভিযোগ করেছে বিএনপির সিনিয়র যুগ্ম-মহাসচিব রুহুল কবির রিজভী।
# 201    আফগানিস্তানের বিপক্ষে টি-টোয়েন্টি সিরিজের জন্য ঘোষিত বাংলাদেশের স্কোয়াডে নাইম শেখের নাম দেখার পর তুমুল সমালোচনা ও প্রশংসার মুখে পড়েছে বাংলাদেশ ক্রিকেট বোর্ডের ক্রিকেটার প্যানেল।
# 202    অলিম্পিকে দেশের প্রথম স্বর্ণ পদক জিতেছেন আফ্রিকা মহাদেশ বোতসোয়ানার ক্রীড়াবিদ তেবেগো। এই অর্জনের জের ধরে দেশটির রাষ্ট্রপতি মকগয়েতসি মাসিসি বলেছেন, তিনি মায়ের জন্ম তারিখ লেখা জুতা পর দৌড়ে সফল হয়েছেন।
# 203    আবুধাবিতে তিন ম্যাচের ওয়ানডে সিরিজের দক্ষিণ আফ্রিকা দলে ছিলেন বাঁহাতি পেসার নান্দ্রে বার্গার। কিন্তু চোটের কারণে তাঁর খেলা বন্ধ হয়ে গেছে। এখন তিনি আবার ফিরে এসেছেন।
# 204    টি ২০ ক্রিকেট বিশ্বকাপের শুরুতেই প্রতিপক্ষ হিসাবে শক্তিশালী ভারতকে পেয়েছে আয়ারল্যান্ড। আজ নিউইয়র্কে তাদের মুখোমুখি হতে যাচ্ছে এই দলের বিপক্ষে। টুর্নামেন্টের গ্রুপ পর্বের পরের তিন ম্যাচের ম্যাচে র ্যাংকিংয়ের শীর্ষ দ
# 205    ভারতের টেনিস সুন্দরী সানিয়া মির্জা তিন বছর ধরে লুকিয়ে থাকার পর আবার বিয়ে করছেন। কিন্তু এই বিচ্ছেদ ঘটলে তারা কীভাবে আগন্তুক হতে পারবেন? সব কিছুই সম্ভব।
# 206    লাহোরের গাদ্দাফি স্টেডিয়ামে পাকিস্তানের বিপক্ষে তিন ম্যাচ সিরিজের দ্বিতীয় টি-টোয়েন্টি ম্যাচে হেরে গেছেন বাংলাদেশ জাতীয় ক্রিকেট দলের অধিনায়ক মাহমুদউল্লাহ রিয়াদ। কিন্তু তিনি এখন সিরিজে ফিরে যাননি।
# 207    অলিম্পিকের পুরুষ ফুটবলের ফাইনালে ৩-১ লিড নিয়ে বাজিমাত করেছে স্পেন। কিন্তু অতিরিক্ত সময়ের খেলা শেষ পর্যন্ত তারা জয় পেরে উঠবেনি বলে আশঙ্কা তৈরি হয়নি।
# 208    করোনাভাইরাসের কারণে ঢাকা প্রিমিয়ার ডিভিশন ক্রিকেট লিগ বন্ধ ঘোষণা করা হয়েছে ৪ এপ্রিল পর্যন্ত। কিন্তু পরিস্থিতি খারাপের দিকে যাচ্ছে বলে জানিয়েছেন বিসিবি সভাপতি নাজমুল হাসান পাপন।
# 209    টি ২০ বিশ্বকাপ ২০২৪ জমকালো স্টাইলে শুরু হয়েছে। এই ম্যাচে রান তাড়া করে জয়ের রেকর্ড গড়িয়েছে মার্কিন যুক্তরাষ্ট্র ও কানাডা। এটাই এখন পর্যন্ত নতুন একটি সফলতম ম্যাচ।
# 210    বাংলাদেশের অ্যাথলিটরা রবিবার থেকে আনুষ্ঠানিকভাবে শুরু হচ্ছে দক্ষিণ এশিয়ান গেমস, যেটি এসএ আসর নামে পরিচিত। কিন্তু প্রস্তুতি নিয়ে সন্তুষ্ট না বাংলাদেশি ভারোত্তোলকরা? কীভাবে এই আসরে অংশ নেবেন তারা?
# 211    এশিয়া কাপ স্টেজ-১ র ্যাংকিং আরচারির রিকার্ভ একক ইভেন্টের ফাইনালে উঠতে ব্যর্থ হয়েছেন বাংলাদেশের আরচর হাকিম আহমেদ। কিন্তু শেষ চারে ভারতের তরুণদ্বীপ রাইয়ের কাছে হেরে যান তিনি।
# 212    টি-টোয়েন্টি বিশ্বকাপে বাংলাদেশ দক্ষিণ আফ্রিকার বিপক্ষে ছয় উইকেটে হেরে গেছে। শেষ পর্যন্ত দুই উইকেটের ব্যবধানে জয় পেয়েছে বাংলাদেশ। এ নিয়ে টানা চার ম্যাচেই বাংলাদেশ হেরেছে।
# 213    বাংলাদেশ প্রিমিয়ার লিগের ষষ্ঠ আসর বঙ্গবন্ধু বিপিএলের ফাইনালি লড়াই দেখতে আজ ঢাকায় আসছেন অস্ট্রেলিয়া ক্রিকেট বোর্ডের প্রধান নির্বাহী কর্মকর্তা (সিইও) কেভিন রবার্টস। এদিন সন্ধ্যায় খুলনা টাইগার্সের মুখোমুখি হবে রাজশাহী
# 214    পাকিস্তানের বিরুদ্ধে তিনটি টি-টোয়েন্টি ম্যাচ খেলতে বাংলাদেশ ক্রিকেট দলের নাম ঘোষণা করেছে বাংলাদেশ क्रिकेट বোর্ড-বিসিবি। এই দলে রয়েছেন অধিনায়ক মুশফিকুর রহিম, সাবেক প্রধানমন্ত্রী শেখ হাসিনা।
# 215    নিউজিল্যান্ড ও শ্রীলঙ্কার মধ্যকার তিনটি টেস্ট সিরিজের প্রথম দিন শুরু হওয়ার পর কিউই বোলাররা এমন একটি দেখা দেখতে পারেন যে সব সময় মেলে না। কিন্তু এটি নিয়ে কোন প্রশ্ন নেই।
# 216    বিশ্বকাপে খেলতে যাওয়া তিনটি দেশের মধ্যে একটি হলো উগান্ডা। ফুটবল সে দেশে জনপ্রিয় খেলা। সেই দেশটিতে ক্রিকেট খেলার পেশা রয়েছে মাত্র ২০টি। কিন্তু তারা খেলে কিনা তা জানেন না?
# 217    উয়েফা চ্যাম্পিয়ন্স লিগের সেমিফাইনালে উঠেছে রিয়াল মাদ্রিদ ও ম্যানচেস্টার সিটি। ম্যাচের শুরুতেই দুই পরাশক্তির মধ্যে দারুণ সমতা তৈরি হয়েছিল। কিন্তু শেষ পর্যন্ত ড্র হয়নি।
# 218    রোমাঞ্চকর, উত্তেজনাপূর্ণ, রুদ্ধশ্বাস- একটি রাউন্ড অফ ১৬ দেখলো ইউরো চ্যাম্পিয়নশিপের দর্শকরা। সেদিন রাতে ২ ম্যাচে মোট ১৪টি গোল হয়েছে, একটা টাইব্রেকারও গড়িয়েছে।
# 219    শনিবার বাংলাদেশের টি-টোয়েন্টি বিশ্বকাপ মিশন শুরু হবে রাত পোহালেই। প্রতিপক্ষ শ্রীলংকা। ইংল্যান্ড-স্কটল্যান্ড ম্যাচটি বৃষ্টিতে ভেসে গেছে। সেই সঙ্গে লংকার বিপক্ষে সিরিজ হেরে যাওয়ার পরও দুই দলের অবস্থা বেশ নাজুক
# 220    গেল বছর স্বপ্নীল এক বিশ্বকাপ কাটিয়েছেন বাংলাদেশের ক্রিকেটার সাকিব আল হাসান। কিন্তু শেষ পর্যন্ত তাকে ঠাঁই দেননি ক্রিকেটের নীতিনির্ধারণী সংস্থা আইসিসির নির্বাচিত বর্ষসেরা ওয়ানডে একাদশ।
# 221    অস্ট্রেলিয়ার বিগ ব্যাশ লিগের প্রথম ম্যাচে হোবার্ট হ্যারিকেন্সের দল মেলবোর্ন রেনেগেডসকে ৬ উইকেটে হারিয়ে জয় পেয়েছে। কিন্তু তিনি মাত্র ১ বলে ১৭ রান খরচ করেন।
# 222    সন্ত্রাসবাদের জেরে দীর্ঘদিন ধরে ঘরের মাঠে আন্তর্জাতিক ক্রিকেট ম্যাচ আয়োজন করতে পারেনি পাকিস্তান। ২০০৯ সালে লাহোরে সফররত সেই শ্রীলংকা দলটি সেখান থেকে নির্বাসনে যায়।
# 223    নাসির হোসেনের অলরাউন্ড নৈপূণ্যে ঢাকা ডায়নামাইটস ও দিলশানের মুনাওয়েদের বিপক্ষে বিপিএল নবম আসরের প্রথম ম্যাচে জয় পেয়েছে খুলনা টাইগার্স। শনিবার মিরপুর শেরেবাংলা জাতীয় ক্রিকেট স্টেডিয়ামে ম্যাচটি হয়েছিল
# 224    বিশ্বকাপ ফুটবল ২০১৯ শুরুর ঘণ্টা দেড়েক আগে বাংলাদেশ ও আর্জেন্টিনার মধ্যে যে আনন্দ উল্লাস হয়েছিল, তা ছিল খুলনা প্রকৌশল ও প্রযুক্তি বিশ্ববিদ্যালয়ের ক্যাম্পাসের ছাত্রছাত্রীদের কাছে। কিন্তু সেই রাতটা যেন কাটেনি।
# 225    ইউরোপীয় চ্যাম্পিয়ন্স লিগের দ্বিতীয় লেগের ম্যাচে শেষ পর্যন্ত ৩-১ গোলের জয় পেয়েছে রেয়াল মাদ্রিদ। কিন্তু তারকাবহুল একাদশ নিয়ে প্যারিস সেইন্ট জার্মেই কোয়ার্টার ফাইনালে বিদায় নিল।
# 226    আফগানিস্তান ও আইরিশদের মধ্যে তিন ম্যাচ টি-টোয়েন্টি সিরিজে ৩২ রানে হেরে সিরিজ নিশ্চিত করে ফেলেছে আয়ারল্যান্ড। এর আগে দাপুটে জয় পেয়েছে এই দল। এবারের ম্যাচে ৩ উইকেটে হেরেছে ভারত।
# 227    নিউজিল্যান্ড এবং দক্ষিণ আফ্রিকার মধ্যে চলমান ওয়ানডে বিশ্বকাপের সেমিফাইনালের লড়াই জমে উঠেছে, দুটি দল আট পয়েন্ট নিয়ে সেরা চারে অবস্থান করছে, আর তিনটি চোট বেদনায় জর্জরিত।
# 228    অস্ট্রেলিয়া বনাম নিউজিল্যান্ড, ঠিক ছয় বছর পর আরও একটি আইসিসি বিশ্ব ইভেন্টের ফাইনালে মুখোমুখি হচ্ছে দুই দেশের ক্রিকেট দল। কিন্তু টি-টোয়েন্টি বিশ্বকাপ কীভাবে শেষ হবে?
# 229    বিশ্বকাপ ক্রিকেটে আজ পর্দা উঠেছে ভারত ও পাকিস্তানের মধ্যে টি ২০ বিশ্ব কাপের নবম আসরের ম্যাচ। এই ম্যাচে দুদেশের খেলোয়াড়রা ভবিষ্যদ্বাণী করছেন, সাবেক অধিনায়ক মিসবাহ-উল-হক এবং ভারতীয় বোলার জাসপ্রিত বুমরা
# 230    তিন ম্যাচ সিরিজের দ্বিতীয় টি-টোয়েন্টি সিরিজে ১৬ রানে হেরে গেছে সফরকারী লংকান ক্রিকেট দল। কিন্তু ব্যাটিং বিপর্যয়ের কারণে শেষ পর্যন্ত ১৯০/৮ রানের ইনিংস গুটায় ভারত।
# 231    পাকিস্তান সফর সামনে রেখে রোববার থেকে অনুশীলন শুরু করেছে বাংলাদেশ ক্রিকেট দল। সেখানে যাচ্ছেন মাহমুদউল্লাহ বাহিনী। কিন্তু নিরাপত্তা অজুহাতে তাদের সঙ্গে কোনো অসুবিধা নেই।
# 232    বাংলাদেশের ক্রিকেটার সাকিব আল হাসান এখন পর্যন্ত টি-টোয়েন্টি বিশ্বকাপের নয়টি আসর মাঠে গড়িয়েছে। কিন্তু আইসিসি এর সব আসরেই খেলছেন তিনি, যাতে ৫০ উইকেটের মাইলফলকে পৌঁছাতে পারবেন।
# 233    বাংলাদেশের বরিশাল নগরে এবারের বিশ্বকাপ ফুটবলের নকআউট পর্বে ব্রাজিল ৪-১ গোলে দক্ষিণ কোরিয়াকে হারিয়ে দুর্দান্ত এক জয় পেল গত রাতে। দলটির কোয়ার্টার ফাইনাল নিশ্চিত হয়ে গেছে।
# 234    পাকিস্তানের কিংবদন্তি ক্রিকেটার ইনজামাম-উল-হক বলেছেন, বাংলাদেশের বিপক্ষে আসন্ন তিন ম্যাচে টি-টোয়েন্টি সিরিজে মোহাম্মদ আমির ও ওয়াহাব রিয়াজের বাদ দেয়া ঠিক হয়নি।
# 235    দুবারের টি-টোয়েন্টি বিশ্বকাপে কোয়ালিফাই করতে পারেনি ওয়েস্ট ইন্ডিজের অধিনায়ক পল পাওয়েল। তিনি বলছেন, তারা গর্বিত এটা দেখতে চান দল উন্নতি করেছে। তার নেতৃত্বে বোর্ডের পরিবর্তন হয়েছে।
# 236    পর্তুগালের তারকা ক্রিশ্চিয়ানো রোনালদোকে বছরে ২১ কোটি মার্কিন ডলার চুক্তিতে দলে নেয় সৌদি আরবের ক্লাব আল নাসের। এ নিয়ে সামাজিক যোগাযোগমাধ্যমে চলছে তুমুল রসিকতা।
# 237    আর্জেন্টিনার জাতীয় দলের সাবেক স্ট্রাইকার হার্নান বার্কোস বাংলাদেশের বসুন্ধরা কিংসের হয়ে খেলতে ঢাকায় পৌঁছেছেন। এই প্রথমবারের মতো তাকে নিয়ে আন্তর্জাতিক ফুটবল চ্যাম্পিয়ন হিসেবে বর্ণনা করা হচ্ছে।
# 238    মঙ্গলবার মুম্বাইয়ের ওয়াংখেড় স্টেডিয়ামে শ্রীলংকার বিপক্ষে শ্বাসরুদ্ধকর ম্যাচে জয় পেয়েছে ভারত। এর আগে তিন ম্যাচের টি-টোয়েন্টি সিরিজে ১-০তে এগিয়ে গেল স্বাগতিক দল।
# 239    মুম্বাই ইন্ডিয়ান্সের কোচ কাইরন পোলার্ড ও ব্যাটার টিম ডেভিডকে আইপিএল ম্যাচে আচরণবিধি ভাঙায় সাজা দিয়েছে ভারতের ক্রিকেট বোর্ড ইএসপিএনক্রিকইনফোর একটি ওয়েবসাইট।
# 240    শেষ পর্যন্ত আরবি লাইপজিগ ছাড়তে যাচ্ছেন স্প্যানিশ তারকা দানি ওলমো। এই ঘোষণার পর ক্লাবটি ছেড়ে দেয়া হয়েছে তাকে ৩০ বছরেরও বেশি সময়ের মধ্যে চুক্তিতে নেয়া।
# 241    ফুটবল বিশ্বের সমর্থকরা যেখানে আইসিসি ক্রিকেট বিশ্বকাপের একেকটি রোমাঞ্চকর ম্যাচের দিকে নজর রাখছেন, ঠিক সেসময়ই ফুটনাদের সমস্ত দলগুলোর মধ্যে এখন চলছে কোয়ার্টার ফাইনালে ওঠার লড়াই।
# 242    সিলেট আন্তর্জাতিক স্টেডিয়ামে বাংলাদেশ ও জিম্বাবুয়ে ওয়ানডে সিরিজের তৃতীয় ও শেষ ম্যাচে মুখোমুখি হয়েছে টাইগারদের দল। সূচনাটি দারুণ করেছে বাংলাদেশ। এবারের ম্যাচের শুরুতে বড় ধরণের রান নিয়েছে তারা।
# 243    বাংলাদেশ ক্রিকেট দলের সেরা ওপেনার তামিম ইকবালের ক্যারিয়ারের ২৩তম সেঞ্চুরির রেকর্ড গড়তে যাচ্ছে শুক্রবার। কিন্তু বৃষ্টির কারণে খেলা বন্ধ রয়েছে এবং তিনি এখন পর্যন্ত মাত্র ২১ রানে ব্যাট করছেন।
# 244    চলতি মৌসুম শেষে বায়ার্ন মিউনিখকে বিদায় বলবেন টমাস টুখেল। এবারের চ্যাম্পিয়ন্স লিগের সেমি-ফাইনালে উঠতে যাচ্ছে জার্মানির ক্লাব বুন্ডেসলিগা। কিন্তু তার সঙ্গে তার সম্পর্ক ছিন্ন করার সিদ্ধান্ত নেয়া হয়েছে।
# 245    বাংলাদেশের বরিশাল নগরে এবারের বিশ্বকাপ ফুটবলের নকআউট পর্বে ব্রাজিল ৪-১ গোলে দক্ষিণ কোরিয়াকে হারিয়ে দুর্দান্ত এক জয় পেল গত রাতে। দলটির কোয়ার্টার ফাইনাল নিশ্চিত হয়ে গেছে।
# 246    বাংলাদেশের ক্রিকেটের সংক্ষিপ্ত ফরম্যাট টি-টোয়েন্টিতে অভিষেকেই হ্যাটট্রিক করেছেন বাংলাদেশ ক্রীড়া শিক্ষা প্রতিষ্ঠান (বিকেএসপি)-এর সাবেক অধিনায়ক মানিক খান। ঢাকা ডায়নামাইটসের হয়ে অভিষেক ম্যাচে হেরে গেলেন প্রাইম দোলেশ্বর।
# 247    দেড় বছরের বেশি সময় পর পাকিস্তানের টি-টোয়েন্টি দলে ফিরলেও এক ম্যাচ পরই বাদ পড়লেন সাবেক ক্রিকেটার হাসান আলী। কিন্তু ক্রিকেটে তার দায়বদ্ধতা মেটাতে পারেনি।
# 248    বিশ্বের বিভিন্ন দেশে দাবা খেলা বাধ্যতামূলক হয়, কিন্তু অনেক দেশেই এই খেলাটি শিশুদের চিন্তাভাবনার ক্ষেত্রে কাজে লাগবে বলে মনে করেন কর্তৃপক্ষের একটি গবেষণা প্রতিবেদন ।
# 249    ভারতের টি ২০ বিশ্বকাপ অভিযান শুরু হচ্ছে আজ। এই প্রথম ম্যাচে আয়ারল্যান্ডের মুখোমুখি হতে যাচ্ছে দলটির ১৩ সদস্যের একাদশ নির্বাচিত করা হবে বলে ঘোষণা করেছে দেশটির ক্রিকেট বোর্ড।
# 250    এশিয়ান কাপের বাছাইয়ের দ্বিতীয় ধাপে ফিলিস্তিনের মুখোমুখি হবে বাংলাদেশ। মঙ্গলবার মাঠে গড়াবে কিংস অ্যারেনা নামে একটি আঙিনায়। এবারের ম্যাচে তিনটি ড্র এবং দুটি ম্যাচের তৃপ্তি পেয়েছে বাংলাদেশ কোচ হাভিয়ের কাবরেরা।
# 251    ঢাকায় জিম্বাবুয়ের বিপক্ষে দুই ম্যাচের টি-টোয়েন্টি দল ঘোষণা করেছে বাংলাদেশ ক্রিকেট বোর্ড। নতুন মুখ হিসেবে ডাক পেয়েছেন নাসুম আহমেদ ও মুশফিকুর রহিম। সেখানে চট্টগ্রাম চ্যালেঞ্জার্সের কোচ পল নিক্সন।
# 252    আসামের গুয়াহাটি শহরে নাগরিকত্ব সংশোধনী আইনের প্রতিবাদে বিক্ষোভ চলছে। সেখানে রোববার ভারত-শ্রীলংকা টি-টোয়েন্টি সিরিজ খেলতে নামবে। এই প্রথম ম্যাচটি হবে আসাম রাজ্যের বর্ষাপাড়া ক্রিকেট স্টেডিয়ামে।
# 253    ব্রাজিলের কিংবদন্তি ফুটবলার এডসন আরান্তেস দো নাসিমেন্তো কালোমানিক পেলের স্মরণে ময়মনসিংহের গৌরীপুরে যুগান্তর স্বজন সমাবেশের উদ্যোগে শোকর্যারলি বের করা হয়।
# 254    বাংলাদেশ ক্রিকেট দলের সাবেক ধারাভাষ্যকার রমিজ রাজা বেশ কয়েক বছর ধরে টাইগারদের কট্টর সমালোচক হিসেবে বর্ণনা করেন। গতকাল লাহোরে পাকিস্তানের বিপক্ষে প্রথম টি-টোয়েন্টি ম্যাচে বাংলাদেশ হেরেছে।
# 255    ঢাকায় আজ থেকে শুরু হচ্ছে ক্রিকেটের সবচেয়ে বড় টিভি চ্যাম্পিয়নশিপের ষষ্ঠ দিন। কিন্তু এখন পর্যন্ত কোন খেলা দেখা যাচ্ছে না - তা নিয়ে নজর রাখুন বিশেষজ্ঞরা।
# 256    বৃহস্পতিবার রাওয়ালপিন্ডি টেস্টের দ্বিতীয় দিনে ৫ উইকেটে ৩৬৭ রান নিয়ে চা-বিরতিতে গেছে পাকিস্তান। ভারতের বিপক্ষে এটি ছিল সবচেয়ে বড় ম্যাচ। সেখানে বাংলাদেশের বিরুদ্ধে লড়াই করেছে বাংলাদেশ।
# 257    ফুটবল দুনিয়ার সবচেয়ে নাটকীয় দলবদলের ঘটনা ছিল কিলিয়ান এমবাপ্পে। কিন্তু এর আগে থেকেই তিনি রিয়াল মাদ্রিদে নাম লেখা শুরু করেছিলেন। এবার তাকে ফ্রি এজেন্ট হিসেবে আনুষ্ঠানিকভাবে ছাড়লেন।
# 258    ফুটবল বিশ্বের সমর্থকরা যেখানে আইসিসি ক্রিকেট বিশ্বকাপের একেকটি রোমাঞ্চকর ম্যাচের দিকে নজর রাখছেন, ঠিক সেসময়ই ফুটনাদের সমস্ত দলগুলোর মধ্যে এখন চলছে কোয়ার্টার ফাইনালে ওঠার লড়াই।
# 259    বাগদত্তা জেসের সঙ্গে তাঁর বিয়ের দিনক্ষণ ঠিক করে রেখেছেন ওলি স্টোন। কিন্তু গোলমাল বাধার ঝামেলা এখনও কাটেনি ইংল্যান্ডের জাতীয় দলের সদস্যদের মধ্যে ।
# ...
# 1415    টোকিওতে চলছে অলিম্পিক গেমস, যেটা গত বছর হবার কথা থাকলেও করোনাভাইরাস মহামারির কারণে একবছরের দেরিতে শুরু হয়েছে। কিন্তু এই সময়ে নারীর প্রতি বৈষম্যের আরেকটি উদাহরণ দেখা গেল ভারতে।
# 1416    চেন্নাইর চিপকের মাঠ মূলত ভারতের ওয়ানডে সিরিজের প্রথম টেস্ট। সেখানে লাল মাটির উইকেট থাকতে পারে বাংলাদেশ। কিন্তু এর মানে নেই যে, এই স্টেডিয়ামে সবচেয়ে বেশি উইকেটে উঠে আসে।
# 1417    ভারত ও বাংলাদেশের মধ্যকার টেস্ট ম্যাচ চলাকালীন বেশ কয়েকটি বানর মাঠে ঢুকে পড়ার পর তাদের সম্প্রচার কাজে নিয়োজিতদের খাবার নিয়ে পালিয়ে গেছে দলটির ক্রু ও ক্যামেরাম্যানরা।
# 1418    বিশ্বকাপ ক্রিকেটে কলকাতার ইডেন গার্ডেন্সে মঙ্গলবার বাংলাদেশ পাকিস্তানকে সাত উইকেটের বড় ব্যবধানে জয়ের লক্ষ্যে পৌঁছেছে। এর আগে এই ম্যাচে বাংলাদেশের স্কোর দুশো পেরোবে।
# 1419    ইংলিশ ফুটবল ক্লাব পিএসজির চ্যাম্পিয়ন্স লিগের সেমি-ফাইনালে ওঠায় বড় ভূমিকা রেখেছেন তারকা কিলিয়ান এমবাপে। এবারের ম্যাচে বার্সেলোনাকে হারিয়ে তিনি সেই স্বপ্ন পূরণ করেছেন।
# 1420    এক ঐতিহাসিক মুহূর্তের সাক্ষী হতে যাচ্ছে টেনিস বিশ্ব। রজার ফেদেরার ও সেরেনা উইলিয়ামস মুখোমুখি হচ্ছেন মিক্সড ডাবলস টুর্নামেন্টের গ্র্যান্ডস্লাম শিরোপা জিতেছেন।
# 1421    ইরানের একমাত্র নারী অলিম্পিক পদকজয়ী কিমিয়া আলীজাদেহ বলেছেন তিনি পক্ষত্যাগ করেছেন। ইসলামিক প্রজাতন্ত্রটি তার সাফল্যকে প্রোপাগান্ডা চালানোর জন্য ব্যবহার করেছে। তবে সরকারের কাছে তাকে কোন গুরুত্ব নেই।
# 1422    বাংলাদেশ ও সৌদি আরবের মধ্যে ক্রিকেট বিষয়ে দ্বিপাক্ষিক সহযোগিতা জোরদার করতে আগ্রহ প্রকাশ করেছে বাংলাদেশের দূতাবাসের সভাপতি প্রিন্স সৈদ বিন মিশাল। এই প্রস্তাবকে ভিত্তিহীন বলে বর্ণনা করা হয়েছে।
# 1423    বাংলাদেশ ক্রিকেট দলের সাবেক অধিনায়ক নাজমুল হোসেন শান্ত এখন বাংলাদেশের সবচেয়ে গুরুত্বপূর্ণ ক্রিকেটারদের একজন। কিন্তু তাকে নিয়ে কড়া সমালোচনার মুখে পড়ে নির্বাচক প্যানেল তাকে বাতিল করে দিয়েছে।
# 1424    সিলেট আন্তর্জাতিক স্টেডিয়ামে বাংলাদেশ-জিম্বাবুয়ে ওয়ানডে সিরিজের তৃতীয় ও শেষ ম্যাচে দারুণ দুর্দান্ত খেলছেন তামিম ইকবাল ও লিটন দাস। এই দুই ম্যাচের দ্বিতীয় ওপেনিং জুটিতে ব্যাট করে জয় পেয়েছে বাংলাদেশ।
# 1425    রাই বেনজামিন টপকাতে পেরেছেন পোডিয়ামের কারস্টেন ওয়ারহোমকে। কিন্তু তার গলায় তিনটি পদক লেগে গেছে। সেই পদকের চেয়েও কম সময় নিয়ে বিশ্বরেকর্ড গড়েছেন তার বাবা উইন্সটন বেঞ্জামিন।
# 1426    লাহোরে বাংলাদেশ ও পাকিস্তানের মধ্যে তিনটি টি-টোয়েন্টি সিরিজের প্রথম ম্যাচে দুই দলই একমাত্র জয়ের লক্ষ্য নিয়ে লড়াই শুরু করেছে। কিন্তু শেষ পর্যন্ত জয় পেয়েছে বাংলাদেশ।
# 1427    অস্ট্রেলিয়ার বিপক্ষে আসন্ন টি-টোয়েন্টি সিরিজকে সামনে রেখে আগামী সপ্তাহে দল ঘোষণা করবে পাকিস্তান। এই সিরিজে বাংলাদেশ দলের মধ্যে তিনজন তারকা ক্রিকেটারের বাদ পড়তে পারে।
# 1428    আড়াই বছর পর বাংলাদেশ টেস্ট সিরিজের প্রথম দিনে পাকিস্তানের বিপক্ষে দারুণ ব্যাটিং করেছে বাংলাদেশ। কিন্তু সেঞ্চুরিতে জয় পেলো দলটি। এবারের ম্যাচের দ্বিতীয় দিনের খেলা শেষে ভারতের বিরুদ্ধে সেমিফাইনালে উঠে এসেছে।
# 1429    খ্রিস্টীয় নতুন বছর ২০২৩-কে বরণ করে নিতে ইনস্টাগ্রামে এক আবেগঘন স্ট্যাটাস দিয়েছেন ফুটবলের জাদুকর ও বিশ্বচ্যাম্পিয়ন লিওনেল মেসি। এতে সবার আগে নিজ পরিবারকে প্রাধান্য দিয়েছিলেন তিনি।
# 1430    টি ২০ বিশ্বকাপ অভিষেকে চমক দেখানোর স্বপ্ন ছিল আফগানিস্তানের উগায়ান্ডোর তরুণ বোলার ফজলহক ফারুকির। কিন্তু এরই মধ্যে সাত-আটবার হ্যাটট্রিকের সম্ভাবনা জাগিয়েও পারেনি তিনি।
# 1431    টেলিভিশনের কল্যাণে ইংলিশ প্রেমিয়ার লিগ এখন পৃথিবীর সবচেয়ে আকর্ষণীয় ফুটবল লিগে পরিণত হয়েছে - যা দেখেন সারা দুনিয়ার কোটি কোটির দর্শক। কিন্তু কেন?
# 1432    গত ছয় বছরের চুক্তিতে বার্সেলোনা যোগ দিয়েছিলেন আরও দুই সপ্তাহ আগে। কিন্তু শেষ পর্যন্ত তাকে নিবন্ধন করতে পেরেছে ক্লাবটি। সেই সুযোগটা করে দিয়েছে আন্দ্রেয়াস ক্রিস্তেনসেন।
# 1433    গল টেস্টের শেষ দিনে নিউজিল্যান্ডকে ৬৩ রানে হারিয়েছে শ্রীলঙ্কা। কিন্তু এই সিরিজে লঙ্কানদের নায়ক কীভাবে জয় এনে দেন তা দেখতে পারেননি দর্শকরা ।
# 1434    আগের দিন শেষ বিকেলেই মনে হচ্ছিল বাংলাদেশের ব্যাটারদের সামনে আছে কঠিন চ্যালেঞ্জ। কিন্তু তৃতীয় দিনে পাকিস্তানের বিরুদ্ধে তোলপাড় সৃষ্টি করেছে বাংলাদেশ। আন্তর্জাতিক ক্রিকেট স্টেডিয়ামে এই টেস্টটি শুরু হওয়ার পর থেকেই নতুন করে আল
# 1435    বাংলাদেশ ক্রিকেট দল ভারতে অবস্থান করবে অক্টোবরের দ্বিতীয় সপ্তাহ পর্যন্ত। কিন্তু টি-টোয়েন্টি সিরিজ থেকে অবসরের ঘোষণা দিয়েছেন সাকিব আল হাসান। সেই সিদ্ধান্তটি কার্যকর?
# 1436    চ্যাম্পিয়ন্স লিগের সেমি-ফাইনালে উঠতে যাচ্ছে বার্সেলোনা। প্রথম লেগে জয়ের আত্মবিশ্বাস সঙ্গী করে ফিরতি ম্যাগে নেমে শুরুতেই এগিয়ে গেল কাতালান দলটি। শেষ পর্যন্ত ৬-৪ গোলের অগ্রগামিতায় পৌঁছেছে পরের ধাপে।
# 1437    বাংলাদেশের টি-টোয়েন্টি ক্রিকেট দলের ক্রিকেটাররা ঈদের ছুটি শেষে মাঠে গড়িয়েছে ডিপিএলের দশম রাউন্ড। কিন্তু ব্যস্ততা বেড়েছে মিরপুর শের-ই বাংলা স্টেডিয়ামেও।
# 1438    টনি ক্রুসের জন্মদিন আজ। তিনি বিশ্বকাপে জার্মানির হয়ে ১০৬ ম্যাচে ১৭ গোল করেছেন। এ নিয়ে আন্তর্জাতিক ফুটবল ইতিহাসের সবচেয়ে বড় দলগুলোর মধ্যে একজন জার্মান মিডফিল্ডার।
# 1439    মোহাম্মদ শামি এবারের বিশ্বকাপ ক্রিকেটে নিজের জায়গা পাঁকা করেছেন বলে মনে হচ্ছে। কিন্তু তিনি এখনও বলছেন, 'শামি চোখের জন্য তৃপ্তিদায়ক'। এমনকি বেন স্টোকসকে যে স্পেল করে নাস্তানাবুদ করেন তা নিয়ে আলোচ
# 1440    আধুনিক ক্রিকেটের সবচেয়ে বড় তারকা ছিলেন বিরাট কোহলি। কিন্তু ভারতের বিশ্বকাপ দলে তিনি আছেন বিস্তর ফারাক রটা আর ঘটার মাঝে। এমনকি সাবেক অস্ট্রেলিয়ান ওপেনার ম্যাথু হেডেনও বলেছেন, 'কোহলির ওপর
# 1441    চলমান টি টোয়েন্টি বিশ্বকাপ ২০২৪ এর ফাইনালিস্টদের তালিকায় যোগ দিয়েছেন সাবেক দুই অস্ট্রেলিয়ান ক্রিকেটার। টুর্নামেন্টের ফাইনাল নিয়ে অনেকেই ভবিষ্যদ্বাণী করছেন।
# 1442    আমেরিকার ডালাসে শ্রীলঙ্কার বিপক্ষে ২০২৪ টি-টোয়েন্টি বিশ্বকাপে নিজেদের প্রথম ম্যাচ খেলতে মাঠে নামবে বাংলাদেশ। কিন্তু বাংলাদেশ ক্রিকেট দল কীভাবে সেমিফাইনালে উঠতে পারবে?
# 1443    বাংলাদেশের ক্রীড়াঙ্গনে সংস্কারের জন্য গঠিত সার্চ কমিটি ফেডারেশনগুলোর সঙ্গে মতবিনিময় শুরু করেছে। সংগঠনটির সাবেক খেলোয়াড় মামুন উর রশিদ বলেছেন, ঘরোয়া হকি অনেক কমে গেছে এবং তাদের উন্নয়নে সম্ভাব্য পদক্ষেপ
# 1444    চীনের একজন টেনিস তারকা বেইজিংয়ে একটি টুর্নামেন্টে অতিথি হিসেবে হাজির হওয়ার পর তাকে নিয়ে উদ্বেগ প্রকাশ করেছে দেশটির গণমাধ্যম এবং সরকারের কর্মকর্তা। এরপর তিনি নিখোঁজ রয়েছেন।
# 1445    আইসিসির ফিউচার ট্যুর প্লান অনুসারে বাংলাদেশের মাঠে দুটি টেস্ট ও তিনটি টি-টোয়েন্টি ম্যাচ খেলার কথা ছিল। কিন্তু নিরাপত্তা নিয়ে শঙ্কিত থাকায় লম্বা সময়ের জন্য পাকিস্তান সফরে যেতে রাজি হয়নি বাংলাদেশ।
# 1446    খেলোয়াড়ি জীবনের ইতি টানার পরও ফুটবলের মায়া ছাড়তে পারেন না অনেকে। তাদেরকে পেশা হিসেবে বেছে নিতে দেখা কোচিংকে। কিন্তু এমন কিছুর পরিকল্পনা নেই অনেক।
# 1447    বাংলাদেশের জাতীয় ক্রিকেট দলের ব্যাকআপ পেসার আবু জায়েদ রাহী এবার নিজের ক্যারিয়ার নিয়ে শঙ্কায় পড়েছেন বলে জানিয়েছেন তিনি। কিন্তু গত চার বছর থেকেই দলে ডাক পাচ্ছিলেন রাহীর।
# 1448    চ্যাম্পিয়নস লিগের শেষ ষোলোয় বায়ার্ন মিউনিখ বনাম ইংলিশ ক্লাব লিভারপুলের মধ্যকার খেলাটি গোলশূন্য ড্র হয়ে গেছে। এবার দ্বিতীয় লেগের ম্যাচে পরীক্ষা দিতে প্রস্তুত হচ্ছে অলরেডসরা।
# 1449    হ্যামস্ট্রিংয়ে চোটের পর এখনও পুরোপুরি ফিট নন আফগানিস্তানের টি-টোয়েন্টি তারকা রশিদ খান। তাই তাকে নিয়ে কোনো ঝুঁকি নিতে চাইছে না দলটি। তবে তিনি এখনো টেস্ট খেলার জন্য উপযুক্ত মনে করা হচ্ছে না।
# 1450    ফুটবল বিশ্বের সমর্থকরা যেখানে আইসিসি ক্রিকেট বিশ্বকাপের একেকটি রোমাঞ্চকর ম্যাচের দিকে নজর রাখছেন, ঠিক সেসময়ই ফুটনাদের সমস্ত দলগুলোর মধ্যে এখন চলছে কোয়ার্টার ফাইনালে ওঠার লড়াই।
# 1451    আজ দক্ষিণ আফ্রিকার মাঠে বাংলাদেশের তৃতীয় ও শেষ ওয়ানডে ম্যাচ, যেখানে স্বাগতিক দলের বিপক্ষে একটি করে জয় পেয়েছে বাংলাদেশ, সেই ম্যাচে ওয়ান্ডারার্সের চেয়ে আগে ব্যাট করাটা স্বস্তিদায়ক।
# 1452    'ভাই তাড়াতাড়ি গোল দেন, এ সময়ের মধ্যে জয় দিতে হবে। কিন্তু আজমপুরের কোচের সাথে ম্যাচ গড়াপেটার সঙ্গে জড়িত ছিল- এমন অভিযোগে পদত্যাগ করেছেন ফরাশগঞ্জের ফুটবলার।
# 1453    গোটা দুনিয়া ভাসছে ফুটবলের উন্মাদনায়। কিন্তু এর মধ্যে নেইমার, মেসি, ড্র, লিওনেল মেসির সফলতা-ব্যর্থতা আর না পাওয়ার গল্প আর বিতর্কের শুরুও হয়নি।
# 1454    বিশ্বকাপ ক্রিকেটের প্রথম ম্যাচে ইংল্যান্ডের বিরুদ্ধে বাংলাদেশের ব্যাটিং লাইন আপ যেমন বিপর্যয়ের মুখে পড়েছিল, তেমনি টাইগারদের বোলিংয়ের দুর্বলতাকে কাজে লাগিয়ে এই ম্যাচটি শেষ হয়ে গেছে।
# 1455    টি ২০ বিশ্বকাপের জন্য যে ভারতীয় দল বেছে নেওয়া হয়েছে, তাতে অভিজ্ঞতা এবং তারুণ্যের মিশেল খুব ভালো হয়েছে বলে মনে করছেন ক্রিকেট তারকা সুনীল গাভাস্কার। তিনি বলেছেন, ভারতের দলে তার জীবনের অভাব রয়েছে।
# 1456    রাওয়ালপিন্ডিতে পাকিস্তানের বিপক্ষে টেস্ট সিরিজের চতুর্থ দিনে বাংলাদেশের সাদা পোশাকের ক্রিকেটে ৫ উইকেট নিয়েছেন টাইগাররা। কিন্তু সংখ্যাটা বেড়েই গেছে তিনজনের মতো। এ নিয়ে নতুন করে আলোচনা শুরু হয়েছে।
# 1457    কাতার বিশ্বকাপ ফুটবলের এক সপ্তাহ কেটে গেছে। ব্রাজিল-আর্জেন্টিনার প্রতিযোগিতা নিয়ে দেশজুড়ে তোলপাড় চলছে, যার মধ্যে একটি হচ্ছে চট্টগ্রাম নগরের কিংস কনফেকশনারি।
# 1458    টি-টোয়েন্টি ক্রিকেট বিশ্বকাপে নিজেদের প্রথম ম্যাচেই ভারত ও পাকিস্তান মুখোমুখি হচ্ছেন। কিন্তু এই দুই প্রতিবেশী দেশের সম্পর্ক নিয়ে এখনো কোনও বিবৃতি পাওয়া যাচ্ছে না।
# 1459    কাতার বিশ্বকাপ ফুটবলের এক সপ্তাহ কেটে গেছে। ব্রাজিল-আর্জেন্টিনার প্রতিযোগিতা নিয়ে দেশজুড়ে তোলপাড় চলছে, যার মধ্যে একটি হচ্ছে চট্টগ্রাম নগরের কিংস কনফেকশনারি।
# 1460    বিশ্বকাপের বাছাইপর্বে ব্রাজিলের জার্সিতে আরও একবার হতাশা উপহার দিয়েছেন রিয়াল মাদ্রিদের ফরোল্ড ভিনিসিয়ুস জুনিয়র। তিনি বলছেন, 'যেকোনো মূল্যে ফুটবল জিততে আসতে পারি না।'
# 1461    বাংলাদেশ ক্রিকেট দল টি ২০ বিশ্বকাপের প্রস্তুতি ম্যাচে যুক্তরাষ্ট্রের কাছে হেরে যাওয়ার পর এই লড়াই শুরু হয়েছে। কিন্তু আশার খবর নেই তানজিদ হাসান ও নাজমুল হোসেন শান্তদের ব্যাটে।
# 1462    বিশ্ব ক্রিকেটের অভিভাবক সংস্থা আইসিসির সদর দফতরে এক জরুরি বৈঠকে বাংলাদেশ এবং পাকিস্তানের মধ্যে তিন ম্যাচ টি-টোয়েন্টি সিরিজ খেলার প্রস্তাব চূড়ান্ত করেছে বিসিবি।
# 1463    কোপা আমেরিকার ফাইনালের পর আর মাঠে নামা হচ্ছিলো না আর্জেন্টিনার তারকা লিওনেল মেসি। গত দুই মাসের মধ্যে তিনি এই ম্যাচে যোগ দিয়েছিলেন ইন্টার মায়ামির কাছ থেকে। সেই ম্যাচের ফল পেয়েছেন মেসির সাবেক সতীর্থ লুইস সুয়ার
# 1464    "আমাদের বাবা-মা ছেলে-মেয়েদের ক্রিকেট খেলা শেখতে চান না। এখন তারা নিজেদেরই ক্রিকেটার তুলে আনার ক্ষেত্রে বোর্ডের অবদান নেই, যা করছে জেলা পর্যায়ের কোচরা করছেন।"
# 1465    বিপিএল সপ্তম আসরের প্লে অফের সমীকরণ প্রায় স্পষ্ট। চট্টগ্রাম চ্যালেঞ্জার্স, ঢাকা প্লাটুন ও রাজশাহী রয়েলস ১১ খেলায় যথাক্রমে ১৬ ও ১৪ পয়েন্ট করে নিয়ে আগেই সুপার ফোরের খেলা নিশ্চিত করেছে।
# 1466    অভিনেত্রী নাতাশা স্টানকোভিচের সঙ্গে সম্প্রতি বাগদান সেরেছেন ভারতের ক্রিকেটার হার্দিক পান্ডিয়া এবং তার স্ত্রী জামাই কে এল রাহুলের প্রেম প্রসঙ্গ নিয়ে এবার মুখ খুললেন সুনীল শেঠি।
# 1467    নতুন বছরে সৌদি আরবের ক্লাব আল নাসরের জার্সিতে মাঠে নামবেন ক্রিশ্চিয়ানো রোনাল্ডো। কিন্তু কীভাবে মুখোমুখি হবেন দুই মহাতারকা? এই প্রশ্ন তুলছেন ফুটবলপ্রেমীরা।
# 1468    বাংলাদেশের বিপক্ষে টেস্ট ম্যাচের দ্বিতীয় দিনে নিউজিল্যান্ডের ব্যাটসম্যান রস টেলরের নাম ঘুরে বেড়াতে শুরু করেছে বাংলাদেশ ক্রিকেট দলের নতুন একটি দল। কিন্তু এই ক্রিকেটারকে নিয়ে কোন বিতর্ক নেই।
# 1469    ক্রিকেটে ভারত-পাকিস্তান ম্যাচ মানেই উত্তুঙ্গ উত্তেজনা। দুদলের মধ্যে যেমন উত্তাপ ছড়িয়ে পড়ে, তেমনি লড়াইয়ের মঞ্চও ছড়ানো শুরু করেছে দলটির সাবেক ক্রিকেটাররা।
# 1470    টি-টোয়েন্টি বিশ্বকাপের নবম আসরে ওয়েস্ট ইন্ডিজের বিপক্ষে বিশাল জয় পেয়েছে আফগানিস্তান এবং নেদারল্যান্ডস। এই লজ্জাজনক রেকর্ডের শীর্ষস্থানে রয়েছে ডাচরা।
# 1471    চ্যাম্পিয়ন্স লিগের কোয়ার্টার-ফাইনালে যেতে পারেনি স্প্যানিশ ক্লাব পিএসজি, তার দারুণ পারফরম্যান্সের কারণে বেশ হতাশ ইলকাই গিন্দোয়ান। তিনি বলছেন, লাল কার্ড ম্যাচের মোড় ঘুরিয়ে দিয়েছে।
# 1472    ২০১০ সালে ভারতীয় ব্যবসায়ী এবং বাল্যবন্ধু সোহরাব মির্জাকে ধোঁকা দিয়ে পাকিস্তানের সাবেক অধিনায়ক শোয়েব মালিককে বিয়ে করেন সানিয়া মির্জা। তারপর থেকে অভিযোগ করা হচ্ছে, ক্রিকেটারদের থেকেও একাধিকবার রসালো মেসেজ পেয়েছেন নাওয়াল সাইদ
# 1473    মুম্বাই ইন্ডিয়ান্সের কোচ কাইরন পোলার্ড ও ব্যাটার টিম ডেভিডকে আইপিএল ম্যাচে আচরণবিধি ভাঙায় সাজা দিয়েছে ভারতের ক্রিকেট বোর্ড ইএসপিএনক্রিকইনফোর একটি ওয়েবসাইট।
# 1474    অস্ট্রেলিয়ার মেলবোর্ন ক্রিকেট গ্রাউন্ডে আগামীকাল মুখোমুখি হতে যাচ্ছে ভারত ও পাকিস্তানের মধ্যকার একটি বিশেষ ম্যাচ, যা নিয়ে অনেকের মনে হচ্ছে না এটা নতুন বিশ্বকাপ টুর্নামেন্ট।
# 1475    টি-টোয়েন্টি বিশ্বকাপ ২০২৪ একটা মজাদার মোড়ে এসে দাঁড়িয়েছে, যেখান থেকে বাদ পড়ে যেতে পারে অন্তত ৫টি দল। যার মধ্যে আছে বর্তমান চ্যাম্পিয়ন ইংল্যান্ড, নিউজিল্যান্ড এবং শ্রীলঙ্কা।
# 1476    চ্যাম্পিয়ন্স লিগের মিশনে আজ রাতেই মাঠে নামছে বার্সেলোনা। প্রতিপক্ষ মোনাকো। তবে স্থানীয় কর্তৃপক্ষের নির্দেশনা অনুসরণ করতে সমর্থকদের জমায়েত হওয়া নিষিদ্ধ করেছে দলটির পুলিশ।
# 1477    ভারত ও শ্রীলংকার মধ্যে তিন ম্যাচের টি-টোয়েন্টি সিরিজের প্রথম ম্যাচে আজ (বৃহস্পতিবার) মাঠে নামবে লন্ডন ও ওয়েস্ট ইন্ডিজের বিপক্ষে। কিন্তু এখন পর্যন্ত দুই ম্যাচা শেষ হচ্ছে।
# 1478    বাংলাদেশের ষষ্ঠ আসর টি-টোয়েন্টি ক্রিকেট টুর্নামেন্ট। সব জল্পনা-কল্পনার অবসান ঘটিয়ে ঘণ্টাখানেক পর মাঠে গড়াচ্ছে এই প্রতিযোগিতাটির নাম রংপুর রাইডার্স ও চিটাগং ভাইকিংস।
# 1479    ৮-৯ বছর আগে দেয়া বর্ণবাদী ও লিঙ্গ বৈষম্যমূলক টুইট নিয়ে চলমান তদন্তের কারণে আন্তর্জাতিক ক্রিকেট থেকে আপাতত বরখাস্ত করা হয়েছে ইংল্যান্ডের হয়ে মাত্র একটি টেস্ট খেলা অলি রবিনসনকে।
# 1480    আফগানিস্তানের বিপক্ষে টি-টোয়েন্টি সিরিজের জন্য ঘোষিত বাংলাদেশের স্কোয়াডে নাইম শেখের নাম দেখার পর তুমুল সমালোচনা ও প্রশংসার মুখে পড়েছে বাংলাদেশ ক্রিকেট বোর্ডের ক্রিকেটার প্যানেল।
# 1481    বাংলাদেশের জাতীয় ক্রিকেট দল ঢাকা প্রিমিয়ার লিগের একটি ম্যাচে আবাহনীর বিপক্ষে ১৩১ রানে অলআউট হয়ে গেছে। এই ম্যাচটি শেষ হওয়ার কয়েক ঘণ্টার মধ্যে বাংলাদেশ ওয়ানডে দলের ডিউটিতে ছিলেন মোসাদ্দেক হোসেন সৈকত।
# 1482    বাংলাদেশ ক্রিকেট দলের সাবেক ধারাভাষ্যকার রমিজ রাজা বেশ কয়েক বছর ধরে টাইগারদের কট্টর সমালোচক হিসেবে বর্ণনা করেন। গতকাল লাহোরে পাকিস্তানের বিপক্ষে প্রথম টি-টোয়েন্টি ম্যাচে বাংলাদেশ হেরেছে।
# 1483    বাংলাদেশের উইকেটকিপার ব্যাটসম্যান মুশফিকুর রহিম আন্তর্জাতিক টি-টোয়েন্টি ক্রিকেট ছেড়ে দেয়ার পর তাকে নিয়ে বাংলাদেশে ক্রিকেটার ও সমর্থকদের মধ্যে আলোচনা চলছে। কিন্তু এই ঘৃণা কতটা বাড়াবাড়ি?
# 1484    আগামী ২০৩৪ বিশ্বকাপের আয়োজক হওয়া প্রায় নিশ্চিত করে ফেলেছে সৌদি আরব। কিন্তু কোনো প্রতিদ্বন্দ্বী হিসেবে দৌড়ে টিকে থাকতে পারে দেশটির দল ফিফা। এমনকি নেইমার।
# 1485    চ্যাম্পিয়ন্স লিগ থেকে বিদায়ের ক্ষত এখনও তাজা। গত সপ্তাহে বার্সেলোনার বিপক্ষে ৩-১ গোলে বিধ্বস্ত হয়ে দলটি ইউরোপ সেরার প্রতিযোগিতায় বিদায় নেয় ম্যানচেস্টার সিটি।
# 1486    বাংলাদেশে ক্ষমতাসীন আওয়ামী লীগের পদত্যাগ ও রদবদলের সঙ্গে রাষ্ট্রীয়, সরকারি, স্বায়ত্তশাসিত প্রতিষ্ঠানের মধ্যে অস্থিরতার হিড়িক শুরু হয়েছে। এরপর থেকেই বিভিন্ন অঙ্গনে নতুন করে বিতর্কের শব্দ উঠেছে।
# 1487    পাকিস্তান ও নিউজিল্যান্ডের মধ্যে ওয়ানডে সিরিজের দলের ঘোষণা নিয়ে নির্বাচক প্যানেলের সঙ্গে আলোচনা চলছে বলে খবর পাওয়া যাচ্ছে। কিন্তু এ বিষয়ে কিছুই জানতে পারেনি অধিনায়ক বাবর আজম।
# 1488    বিশ্বের সবচেয়ে ধনী ফুটবলারদের মধ্যে একটি হল অর্থ। কিন্তু কোন খেলোয়াড়ের বেতন কত, তা নিয়ে অনেকেই আগ্রহী হয়ে উঠেছেন বলে জানাচ্ছেন একদল বিশ্লেষকরা। তবে অর্থনীতির সঙ্গে অর্থের নিবিড় সম্পর্ক রয়েছে।
# 1489    ভারতীয় ক্রিকেটার ঋষভ পন্তের দুর্ঘটনার পর সোশ্যাল মিডিয়ায় তার আরোগ্য কামনায় প্রার্থনা করার অনুরোধ করেছেন উর্বশীর মা মীরাও। ভারতের ক্রিকেট দলের তরুণ উইকেটকিপার সিদ্ধবালিবাবা এই প্রথমবারের মতো তার মায়ের ছবি পোস্ট করে
# 1490    বিপিএল ফাইনালে হেরে যাওয়ার পর দুঃখপ্রকাশ করেছেন খুলনা টাইগার্সের অধিনায়ক মুশফিকুর রহিম। টুর্নামেন্টের আগামী আসরে ভালো দল গঠন করে চ্যাম্পিয়ন হতে চান তিনি।
# 1491    ভারতের এক ক্রিকেটারের মধ্যে এক পা এগিয়ে গিয়ে ছক্কা হাঁকালেন ব্যাটার। পরেই মাটিতে লুটিয়ে পড়লেন এক যুবক। এ ঘটনার ভিডিও সামাজিক যোগাযোগমাধ্যমে ভাইরাল হয়েছে।
# 1492    কাউন্টি চ্যাম্পিয়নশিপে ব্যাটসম্যানের বেঁচে যাওয়া নতুন একটি উপায়। রানআউটের হাত থেকেই বাঁচতে পারেন, যদি ফিল্ডার সেটি ফসকে ফেলেন বা নিশানা ঠিক রাখলেন।
# 1493    টানা দুই ম্যাচ হেরে ইন্ডিয়ান প্রিমিয়ার লিগ আইপিএলের ১৬তম আসর শুরু করলো মুম্বাই ইন্টারন্যাশনাল দলটি। কিন্তু এবারের আসরে কী পরিবর্তন আসতে যাচ্ছে তা নিয়ে প্রশ্ন উঠেছে।
# 1494    আন্তর্জাতিক ক্রিকেট কাউন্সিলের বোলারদের তালিকায় বড় পরিবর্তন এসেছে, যেখানে সেরা দশে জায়গা পেয়েছেন বাংলাদেশের দুই অফস্পিনার ও সাকিব আল হাসানের পয়েন্ট ৪২০। র ্যাংকিং থেকে উন্নতি হয়েছে ১১ ধাপ।
# 1495    বাংলাদেশের ক্রিকেট দলের অধিনায়ক সাকিব আল হাসান টুর্নামেন্টের সেমিফাইনালে ওঠার আগে সোমবার সন্ধ্যাতেও দলকে নিয়ে খুব বেশি কিছু আর আশা করতে ভয় পাচ্ছেন - এমনটাই বলছিলেন তিনি।
# 1496    নিষিদ্ধঘোষিত মাদক গ্রহণের দায়ে গত ফেব্রুয়ারিতে চার বছরের জন্য নিষেদ্ধ হন ফ্রান্সের তারকা ফুটবলার পল পগবা। কিন্তু সেই শাস্তির মাথায় তাঁর স্বস্তি নিশ্বাস ফেলা হয়েছে।
# 1497    ত্রিশ বছর ধরে কোনো লিগ শিরোপা জেতেনি যে দল, সেই লিভারপুল এখন অপেক্ষা করছে ইংলিশ প্রিমিয়ার লিগের কবে নিশ্চিত করবে? এই প্রশ্নের উত্তরে রয়েছে দারুণ কিছু প্রশ্ন।
# 1498    বাংলাদেশের পুনেতে একটি টিম হোটেলে সংবাদ সংগ্রহ করতে আসা সাংবাদিকদের হোটেল থেকে বের করে দেয়ার অভিযোগের জের ধরে বাংলাদেশ ক্রিকেট দলের শীর্ষ ক্রিকেটার লিটন কুমার দাস দুঃখ প্রকাশ করেছেন।
# 1499    বাংলাদেশে মেয়েদের টি-টোয়েন্টি বিশ্বকাপ অনুষ্ঠিত হতে যাচ্ছে না, এমন একটি গুঞ্জন অনেকদিন ধরেই প্রচলিত ছিল। কিন্তু শেষ পর্যন্ত বাংলাদেশ থেকে এই আসর সরে যাওয়ার সিদ্ধান্ত নিয়েছে আন্তর্জাতিক ক্রিকেট সংস্থা আইসিসি।

# %%
import os
os.listdir('/content/gdrive/My Drive/Colab')
# Out:
# ['Test_XLSUM.ipynb', 'custom_dataset.csv', 'mt5_finetuned.csv']

# %%
genDf.to_csv('mT5_finetuned_local.csv')  # Saves locally in the Colab environment

# %%
from google.colab import files
files.download('mT5_finetuned_local.csv')

# %%
import os

save_path = '/content/gdrive/My Drive/Colab'
os.makedirs(save_path, exist_ok=True)  # Create the directory if it doesn't exist

# Now save the file
genDf.to_csv(f'{save_path}/mT5_finetuned.csv')

# %%
import os
os.listdir('/content/gdrive/My Drive/Colab')
# Out:
# ['Test_XLSUM.ipynb',
#  'custom_dataset.csv',
#  'mt5_finetuned.csv',
#  'mT5_finetuned.csv']

# %%
df = pd.read_csv('/content/drive/My Drive/Colab/sports_finetuned.csv')

# Display the first few rows to verify the file is loaded properly
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লি...
# 1           1  সব শংকা উড়িয়ে মাঠে গড়িয়েছে বাংলাদেশ প্রিমিয়ার ...
# 2           2  শুক্রবার ১৪ই এপ্রিল ফিফার ওয়েবসাইটে প্রকাশিত এ...
# 3           3  নিয়মের ফাঁক দিয়ে দুটি হলুদ কার্ড পেয়েও লাল কার...
# 4           4  ইংল্যান্ডের 'বিগ সিক্স' বলে পরিচিত আর্সেনাল, চ...
#
#                                         givenSummary  \
# 0   ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ।
# 1  সব শংকা উড়িয়ে মাঠে গড়িয়েছে বাংলাদেশ প্রিমিয়ার ...
# 2  বাংলাদেশের ফুটবল ফেডারেশনের সাধারণ সম্পাদক আবু...
# 3  অলিম্পিয়াকোসের বিপক্ষে প্রথম লেগে আর্জেন্টিনার...
# 4  ইংল্যান্ডের 'বিগ সিক্স' বলে পরিচিত আর্সেনাল, চ...
#
#                                       mT5_Test_XLSum
# 0  "একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ। কিন...
# 1  বাংলাদেশ প্রিমিয়ার লিগের ষষ্ঠ আসরে উত্তরবঙ্গে...
# 2  আন্তর্জাতিক ফুটবল পরিচালনা সংস্থা ফিফা বাংলাদে...
# 3  আর্জেন্টিনার উয়েফা কনফারেন্স লিগের সেমি-ফাইনা...
# 4  যুক্তরাজ্যের প্রধানমন্ত্রী বরিস জনসন ঘরোয়া ফু...

# %%
df
# Out:
#       Unnamed: 0                                               text  \
# 0              0  ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লি...
# 1              1  সব শংকা উড়িয়ে মাঠে গড়িয়েছে বাংলাদেশ প্রিমিয়ার ...
# 2              2  শুক্রবার ১৪ই এপ্রিল ফিফার ওয়েবসাইটে প্রকাশিত এ...
# 3              3  নিয়মের ফাঁক দিয়ে দুটি হলুদ কার্ড পেয়েও লাল কার...
# 4              4  ইংল্যান্ডের 'বিগ সিক্স' বলে পরিচিত আর্সেনাল, চ...
# ...          ...                                                ...
# 1495        1495  দক্ষিণ আফ্রিকার বিরুদ্ধে ম্যাচের আগে সোমবার স...
# 1496        1496  নিষিদ্ধঘোষিত মাদক গ্রহণের দায়ে গত ফেব্রুয়ারিতে...
# 1497        1497  ত্রিশ বছর ধরে কোনো লিগ শিরোপা জেতেনি যে দল, সে...
# 1498        1498  সাংবাদিকদের সাথে ঘটে যাওয়া এক ঘটনায় লিটন কুমার...
# 1499        1499  সাম্প্রতিক সময়ে দেশের অস্থিতিশীল পরিস্থিতির জন...
#
#                                            givenSummary  \
# 0      ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ।
# 1     সব শংকা উড়িয়ে মাঠে গড়িয়েছে বাংলাদেশ প্রিমিয়ার ...
# 2     বাংলাদেশের ফুটবল ফেডারেশনের সাধারণ সম্পাদক আবু...
# 3     অলিম্পিয়াকোসের বিপক্ষে প্রথম লেগে আর্জেন্টিনার...
# 4     ইংল্যান্ডের 'বিগ সিক্স' বলে পরিচিত আর্সেনাল, চ...
# ...                                                 ...
# 1495  দক্ষিণ আফ্রিকার বিরুদ্ধে ম্যাচের আগে সোমবার স...
# 1496  নিষিদ্ধঘোষিত মাদক গ্রহণের দায়ে গত ফেব্রুয়ারিতে...
# 1497  ত্রিশ বছর ধরে কোনো লিগ শিরোপা জেতেনি যে দল, সে...
# 1498  সাংবাদিকদের সাথে ঘটে যাওয়া এক ঘটনায় লিটন কুমার...
# 1499  সাম্প্রতিক সময়ে দেশের অস্থিতিশীল পরিস্থিতির জন...
#
#                                          mT5_Test_XLSum
# 0     "একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ। কিন...
# 1     বাংলাদেশ প্রিমিয়ার লিগের ষষ্ঠ আসরে উত্তরবঙ্গে...
# 2     আন্তর্জাতিক ফুটবল পরিচালনা সংস্থা ফিফা বাংলাদে...
# 3     আর্জেন্টিনার উয়েফা কনফারেন্স লিগের সেমি-ফাইনা...
# 4     যুক্তরাজ্যের প্রধানমন্ত্রী বরিস জনসন ঘরোয়া ফু...
# ...                                                 ...
# 1495  বাংলাদেশের ক্রিকেট দলের অধিনায়ক সাকিব আল হাসা...
# 1496  নিষিদ্ধঘোষিত মাদক গ্রহণের দায়ে গত ফেব্রুয়ারি...
# 1497  ত্রিশ বছর ধরে কোনো লিগ শিরোপা জেতেনি যে দল, সে...
# 1498  বাংলাদেশের পুনেতে একটি টিম হোটেলে সংবাদ সংগ্রহ...
# 1499  বাংলাদেশে মেয়েদের টি-টোয়েন্টি বিশ্বকাপ অনুষ্...
#
# [1500 rows x 4 columns]

# %%
# View the original text, given summary, and generated summary for the first row
sample_index = 0  # You can change this to inspect different rows

# Access text, given summary (if available), and generated summary
original_text = df['text'][sample_index]
given_summary = df['givenSummary'][sample_index]  # If present in the CSV
generated_summary = df['mT5_Test_XLSum'][sample_index]

# Print the text and corresponding summaries
print(f"Original Text:\n{original_text}\n")
print(f"Given Summary (if available):\n{given_summary}\n")
print(f"Generated Summary:\n{generated_summary}\n")
# Out:
# Original Text:
# ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ।
# বহু বিতর্কিত ইউরোপিয়ান সুপার লিগের অকাল মৃত্যুকে এভাবেই ব্যাখ্যা করা চলে।
# যে ১২টি ক্লাব নিজেদের মধ্যে একটি ফুটবল কার্টেল তৈরির চেষ্টা করেছিল, তা মুখ থুবড়ে পড়েছে ৪৭ ঘণ্টা ৪৪ মিনিটের মধ্যে।
# মঙ্গলবার রাতে যখন 'বিগ সিক্স' নামে পরিচিত ছ'টি ইংলিশ ক্লাব -- আর্সেনাল, লিভারপুল, চেলসি, ম্যানচেস্টার সিটি, ম্যানচেস্টার ইউনাইটেড আর টটেনেহাম হটস্পার -- যখন একে একে নিজেদের প্রত্যাহার করে নেয়ার ঘোষণা করলো, তখনই বোঝা গিয়েছিল এই ইএসএল-এর মৃত্যু ঘণ্টা বেজে গেছে।
# কিন্তু বিশ্ব সেরা ক্লাবগুলোর মধ্যে একটা নিয়মিত আয়োজনের এই উদ্যোগ কেন ভেস্তে গেল? ইএসএল-এর ধারণাটি কী ভুল ছিল?
# প্রজেক্ট ইএসএল-এর অবসানের পেছনে ফুটবল পণ্ডিতরা বেশ কয়েকটি কারণ দেখতে পাচ্ছেন: ফ্যানদের প্রতিবাদ, সরকারি পদক্ষেপের ভয় আর আর্থিক লোকসানের সম্ভাবনা।
# "ইএসএল-এর কর্ণধাররা মোটেই টের পাননি যে ফ্যানরা, বিশেষভাবে ইংলিশ ফ্যানরা, এভাবে প্রতিক্রিয়া দেখাবেন," বলছেন ফুটবল বিশ্লেষক ফিল মিনসুল, "এসব ফ্যান নিজেদের ফুটবলের রক্ষক এবং ফুটবলিং ঐতিহ্যের ধারক-বাহক বলে মনে করেন।"
# তিনি বলছেন, ফ্যানরা দেখলেন এই সুপার লিগ গঠনের মধ্য দিয়ে ফুটবলের ধারাবাহিকতা বিনষ্ট হবে এবং ছোট ছোট ক্লাবগুলোর সামনে আশাব্যঞ্জক কোন ভবিষ্যৎ থাকবে না।
# ইএসএল-এর উদ্যোক্তাদের ভুলটা হয়েছিল এখানেই, বলছেন তিনি, তারা ভেবেছিলেন ছোট ছোট ক্লাবগুলো টাকার লোভে পড়বে এবং ইএসএল পক্ষে কথা বলবে।
# বিশ্বের সবচেয়ে স্বল্পস্থায়ী ফুটবল টুর্নামেন্ট নিয়ে টুইট:
# ইএসএল  নিয়ে হৈচৈ শুরু হয় রোববার ঠিক যে মুহূর্তে ব্রিটেনের সানডে টাইমস পত্রিকায় এই প্রকল্পের রূপরেখা ফাঁস হয়ে যায়।
# ঐ প্রস্তাবে বলা হয়েছিল ইউরোপের এলিট ক্লাবগুলোকে নিয়ে একটি বিশেষ ফুটবল লিগ চালু করা হবে। উদ্দেশ্য: সেরা ক্লাবগুলির মধ্যে নিয়মিতভাবে ম্যাচের আয়োজন করা।
# পনেরটি প্রতিষ্ঠাতা ক্লাব থাকবে ইএসএল-এর স্থায়ী সদস্য। বারোটি ক্লাবের নাম তাৎক্ষণিকভাবে প্রকাশ করা হয়, এবং বলা হয় আরও তিনটি ক্লাব এতে যোগ দেবে।
# এর বাইরে প্রতি মৌসুমে আরও পাঁচটি টিম এই লিগে অংশ নেবে। তবে তাদের যোগ্যতা কীভাবে নির্ধারিত হবে তার বিস্তারিত জানা যায়নি।
# আর এই প্রকল্পটিতে অর্থায়ন করবে আর্থিক প্রতিষ্ঠান জেপি মর্গান। শুধুমাত্র এই লিগের সদস্য হওয়ার সুবাদেই প্রতিষ্ঠাতা ক্লাবগুলো পাবে ৪২৫ মিলিয়ন ডলার। ২০২০ সালে চ্যাম্পিয়ান্স লিগ জিতেছিল যে দলটি, এটা তার আয়ের চারগুণ বেশি।
# কিন্তু ইএসএল-এর উদ্যোক্তারা তাদের চিন্তাভাবনাগুলো গুছিয়ে ব্যাখ্যা করতে এবং স্টেকহোল্ডারদের আগে থেকে সময় নিয়ে এব্যাপারে প্রস্তুত করতে পারেননি বলে মনে করছেন ক্রীড়া ভাষ্যকার মিহির বোস।
# "ফুটবল ফ্যানরা যে আমেরিকান এনএফএল কিংবা এনবিএর মতো একটা এক্সক্লুসিভ টুর্নামেন্ট ধাঁচের আয়োজন মেনে নেবে না সেটাও তারা বুঝতে পারেননি।"
# ইউরোপীয় ফুটবলের মেরিট-ভিত্তিক পিরামিড ব্যবস্থার সাথে এটা সাংঘর্ষিক, বলছেন তিনি।
# সুপার লিগের উদ্যোক্তাদের মধ্যে যেসব ইংলিশ ক্লাব রয়েছে তার প্রধান তিনটি ক্লাব - আর্সেনাল, লিভারপুল এবং ম্যানচেস্টার ইউনাইটেডের মালিক আমেরিকান। মার্কিন সংবাদমাধ্যমের খবর অনুযায়ী, এই মালিকদের হাতে নানা ধরনের আমেরিকান ক্লাব রয়েছে।
# করোনাভাইরাস মহামারিতে প্রবল লোকসানের মুখোমুখি হয়ে তারা যে তাদের আয় বাড়াতে ইএসএল-এর মতো উদ্যোগে সমর্থন জানাবে তা স্বাভাবিক।
# ফুটবল বিশ্লেষক ফিল মিনসুল মনে করছেন, ইএসএল-এর উদ্যোক্তাদের অঙ্কের হিসেবে আরেকটি বড় ভুল ছিল ইউয়েফার প্রতিক্রিয়া।
# "এরা ভেবেছিলেন ইউয়েফার প্রতিক্রিয়া হবে খুবই নরম গোছের," বলছেন তিনি, "কিন্তু ইউয়েফা ইএসএল-বিরুদ্ধে যেরকম কঠোর বক্তব্য দেবে এবং কঠোর শাস্তির হুমকি দেবে, তারা এতটা আশা করেনি।"
# বিতর্কটা যখন ফুটবল মাঠ ছাড়িয়ে বাইরে চলে যায় এবং রাজনীতিকরা তাতে যোগদান শুরু করে, তখন ইএসএল ভবিষ্যৎ আরো নড়বড়ে হয়ে পড়ে।
# ব্রিটিশ প্রধানমন্ত্রী বরিস জনসন মঙ্গলবার ফুটবল এসোসিয়েশন, প্রিমিয়ার লিগ এবং ফ্যানক্লাবগুলোর প্রতিনিধিদের সাথে বৈঠক করেন।
# এরপর ডাউনিং স্ট্রিট থেকে যে বিবৃতি জারি করা হয় তাতে বলা হয় হাতে গোনা ক‌'জন  ক্লাব মালিক যা করছে তাতে সরকার হাত গুটিয়ে বসে থাকবে না।
# "প্রধানমন্ত্রী পরিষ্কার ভাষায় বলেছেন, এটা ঠেকানোর জন্য সরকার আইনে পরিবর্তনসহ সম্ভাব্য সব ধরনের পদক্ষেপ গ্রহণ করবে।"
# ব্রিটিশ সরকারের কাছ থেকে এরকম সরাসরি হুমকি পুরো পরিস্থিতিকে পাল্টে দেয় বলে বলছেন মিহির বোস।
# ইএসএল-এর বিরুদ্ধে সম্ভাব্য পদক্ষেপ হিসেবে জাতীয় দল থেকে প্লেয়ারদের বাদ দেয়া, বিদেশি প্লেয়ারদের ওয়ার্ক পারমিট বাতিল করার পাশাপাশি ক্লাবগুলোর জন্য কর মওকুফসহ নগদ অর্থের ব্যবস্থার কথা ভাবা হচ্ছিল।
# "প্রশাসনের নানা ধরনের সাহায্য-সহযোগিতা নিয়েই বড় ক্লাবগুলোকে চলতে হয়", বলছেন তিনি, "সরকার চাইলে ক্লাব এবং প্লেয়ারদের জন্য নানা ধরনের সমস্যা সৃষ্টি করতে পারে।"
# তবে মিহির বোস এবং ফিল মিনসুলের মতো বিশ্লেষকরা মনে করছেন, ইএসএল-এর স্বপ্ন আপাতত ভঙ্গ হলেও এটা মানুষের মন থেকে একেবারে দূর হয়ে যাবে না।
# কারণ ইউয়েফা এবং ফিফার মতো প্রতিষ্ঠানগুলিতে যেসব সমস্যা রয়েছে, সেগুলোর সুরাহা না করলে ইএসএল-এর দাবি আবার মাথাচাড়া দিয়ে উঠবে।
# মিহির বোস বলছেন, ইউয়েফা এবং ফিফা মূলত বাণিজ্যিক প্রতিষ্ঠান। ফলে স্বাভাবিকভাবেই এদের সমস্যা দূর করতে হলে সরকারকে ফুটবল জগতের বাইরে থেকে নিয়ন্ত্রক নিয়োগ করতে হবে।
# ফুটবলের বিবর্তনের ধারাকে এই দুটি প্রতিষ্ঠান একেবারেই অস্বীকার করতে পারে না বলে তিনি উল্লেখ করেন।
#
#
# Given Summary (if available):
# ফুটবলে একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ।
#
# Generated Summary:
# "একটিও কিক না মেরেই শেষ হয়ে গেল একটি লিগ। কিন্তু ইএসএল-এর মৃত্যু ঘণ্টা বেজে গেছে এবং এই প্রজেক্টের অবসানের পেছনে আশাব্যঞ্জক কোন ভবিষ্যৎ থাকবে না।"

# %% [markdown]
# # **ROGUE SCORE**

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.6)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.0 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 33.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.8 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.6)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=3ebee62726cedff0c8c99b88d66208c392645f87199900d6d408a805392babf5
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# !pip install rouge

import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from rouge import Rouge
from csv import DictReader
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# 1000
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def rougeScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)
    # return SummaryEv
    urlCSV = '/content/' + columnName + 'CSV.csv'
    SummaryEv.to_csv(urlCSV, index=False)

    with open(urlCSV, 'r') as f:
        dict_reader = DictReader(f)
        SummaryEv_dict = list(dict_reader)

    EvJson = json.dumps(SummaryEv_dict, indent = 4)
    JSON = columnName + 'EvJson.json'
    save_file_at_dir('/content', JSON, EvJson)

    urlJSON = '/content/' + columnName + 'EvJson.json'

    with open(urlJSON) as f:
        SummaryEvData = json.load(f)
    lenS = len(SummaryEvData)
    rscore1r = 0
    rscore1p = 0
    rscore1f = 0
    rscore2r = 0
    rscore2p = 0
    rscore2f = 0
    rscorelr = 0
    rscorelp = 0
    rscorelf = 0
    rouge = Rouge()
    for i in range(lenS):
        score = rouge.get_scores(SummaryEvData[i][columnName], SummaryEvData[i]['givenSummary'])
        rscore1r = rscore1r + score[0]['rouge-1']['r']
        rscore1p = rscore1p + score[0]['rouge-1']['p']
        rscore1f = rscore1f + score[0]['rouge-1']['f']
        rscore2r = rscore2r + score[0]['rouge-2']['r']
        rscore2p = rscore2p + score[0]['rouge-2']['p']
        rscore2f = rscore2f + score[0]['rouge-2']['f']
        rscorelr = rscorelr + score[0]['rouge-l']['r']
        rscorelp = rscorelp + score[0]['rouge-l']['p']
        rscorelf = rscorelf + score[0]['rouge-l']['f']

        # rscore = [[rscore1r/lenS, rscore1p/lenS, rscore1f/lenS],
        #           [rscore2r/lenS, rscore2p/lenS, rscore2f/lenS],
        #           [rscorelr/lenS, rscorelp/lenS, rscorelf/lenS]]

    rscore = {'rouge-1': {'r': rscore1r/lenS,
                        'p': rscore1p/lenS,
                        'f': rscore1f/lenS},
                'rouge-2': {'r': rscore2r/lenS,
                        'p': rscore2p/lenS,
                        'f': rscore2f/lenS},
                'rouge-l': {'r': rscorelr/lenS,
                        'p': rscorelp/lenS,
                        'f': rscorelf/lenS}}
    return rscore

# %%
mx = rougeScore('mT5_Test_XLSum')
mx
# Out:
# {'rouge-1': {'r': 0.36259373094608344,
#   'p': 0.38894865708599724,
#   'f': 0.35272295361068384},
#  'rouge-2': {'r': 0.22713477838120325,
#   'p': 0.23684191032724952,
#   'f': 0.21590029781509482},
#  'rouge-l': {'r': 0.32295465393007444,
#   'p': 0.3376866142807335,
#   'f': 0.31054854402238863}}

# %%
def getScore(m, n, x):
    strs = 'rouge-'+str(n)
    return m[strs][x]

# %%
data = {'columns':['rouge-1 r', 'rouge-1 p', 'rouge-1 f', 'rouge-2 r', 'rouge-2 p', 'rouge-2 f', 'rouge-l r', 'rouge-l p', 'rouge-l f'],
        'mT5_finetuned_test':[getScore(mx, 1, 'r'), getScore(mx, 1, 'p'), getScore(mx, 1, 'f'), getScore(mx, 2, 'r'), getScore(mx, 2, 'p'), getScore(mx, 2, 'f'), getScore(mx, 'l', 'r'), getScore(mx, 'l', 'p'), getScore(mx, 'l', 'f')],
       }

rougeDf = pd.DataFrame(data)
rougeDf_ = rougeDf
rougeDf = rougeDf.reset_index(drop=True).T
rougeDf = rougeDf.rename(columns=rougeDf.iloc[0]).drop(rougeDf.index[0])
rougeDf.reset_index(inplace=True)
rougeDf = rougeDf.rename(columns = {'index':'Summary'})
rougeDf
# Out:
#               Summary rouge-1 r rouge-1 p rouge-1 f rouge-2 r rouge-2 p  \
# 0  mT5_finetuned_test  0.362594  0.388949  0.352723  0.227135  0.236842
#
#   rouge-2 f rouge-l r rouge-l p rouge-l f
# 0    0.2159  0.322955  0.337687  0.310549

# %%
import matplotlib.pyplot as plt

# plotting graph
rougeDf.plot(x="Summary",
               y=['rouge-1 r',
                'rouge-1 p',
                'rouge-1 f',
                'rouge-2 r',
                'rouge-2 p',
                'rouge-2 f',
                'rouge-l r',
                'rouge-l p',
                'rouge-l f'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Rouge Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **BLEU SCORE**

# %%
import os
import json
from csv import DictReader

def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

genDf.to_csv('/content/bleuEvCSV.csv', index=False)

with open("/content/bleuEvCSV.csv", 'r') as f:
    dict_reader = DictReader(f)
    bleu_dict = list(dict_reader)
print(len(bleu_dict))

bleuEvJson = json.dumps(bleu_dict, indent = 4)
save_file_at_dir('/content', 'bleuEvJson.json', bleuEvJson)

with open('/content/bleuEvJson.json') as f:
  bleuData = json.load(f)
# Out:
# 1500

# %%
import nltk

def bleuCorpass(columnName):
    ble1score = 0
    ble2score = 0
    ble3score = 0
    ble4score = 0
    for i in range(len(bleuData)):
        hypothesis = bleuData[i][columnName].split()
        reference = bleuData[i]['givenSummary'].split()
        references = [reference]
        list_of_references = [references]
        list_of_hypotheses = [hypothesis]
        ble1score = ble1score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(1, 0, 0, 0))
        ble2score = ble2score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.5, 0.5, 0, 0))
        ble3score = ble3score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.33, 0.33, 0.33, 0))
        ble4score = ble4score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.25, 0.25, 0.25, 0.25))

    print("Bleu 1: ", ble1score/len(bleuData),'\n')
    print("Bleu 2: ", ble2score/len(bleuData),'\n')
    print("Bleu 3: ", ble3score/len(bleuData),'\n')
    print("Bleu 4: ", ble4score/len(bleuData),'\n')

    return ble1score/len(bleuData), ble2score/len(bleuData), ble3score/len(bleuData), ble4score/len(bleuData)

# %%
print('mT5_Test_XLSum Bleu:', bleuCorpass('mT5_Test_XLSum'))
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Bleu 1:  0.2706476850247998
#
# Bleu 2:  0.20923067855131827
#
# Bleu 3:  0.16770452974506056
#
# Bleu 4:  0.13464743538420493
#
# mT5_Test_XLSum Bleu: (0.2706476850247998, 0.20923067855131827, 0.16770452974506056, 0.13464743538420493)

# %% [markdown]
# # **BERTSCORE**

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.46.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.20.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
from evaluate import load
bertscore = load("bertscore")
# Out:
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]

# %%
import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from csv import DictReader
# Out:
# 8200
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def bertScore(columnName):
    SummaryEv = genDf.filter(['text', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    bert_precision = 0
    bert_recall = 0
    bert_f1 = 0

    for i in range(lenS):
        results = bertscore.compute(predictions=[SummaryEv[columnName][i]], references=[SummaryEv['text'][i]], lang="bn")

        bert_precision = bert_precision + results['precision'][0]
        bert_recall = bert_recall + results['recall'][0]
        bert_f1 = bert_f1 + results['f1'][0]

    bert_score = {'precision': bert_precision/lenS,
                    'recall': bert_recall/lenS,
                    'f1': bert_f1/lenS}
    return bert_score

# %%
mx = bertScore('mT5_Test_XLSum')
mx
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# {'precision': 0.8145309563477834,
#  'recall': 0.6470363418658575,
#  'f1': 0.7208741148312886}

# %%
def getScore(m, x):
    strs = x
    return m[strs]

# %%
import pandas as pd

data = {'columns':['bert_precision', 'bert_recall', 'bert_f1'],
        'mT5_Test_XLSum':[getScore(mx, 'precision'), getScore(mx, 'recall'), getScore(mx, 'f1')],
       }

bertScoreDf = pd.DataFrame(data)
bertScoreDf_ = bertScoreDf
bertScoreDf = bertScoreDf.reset_index(drop=True).T
bertScoreDf = bertScoreDf.rename(columns=bertScoreDf.iloc[0]).drop(bertScoreDf.index[0])
bertScoreDf.reset_index(inplace=True)
bertScoreDf = bertScoreDf.rename(columns = {'index':'Summary'})
bertScoreDf
# Out:
#           Summary bert_precision bert_recall   bert_f1
# 0  mT5_Test_XLSum       0.814531    0.647036  0.720874

# %%
import matplotlib.pyplot as plt

# plotting graph
bertScoreDf.plot(x="Summary",
               y=['bert_precision',
                'bert_recall',
                'bert_f1'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Bert Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **WIL WER METEOR WITH GIVEN SUMMARY**

# %%
from collections import Counter

class MeteorScore:
    def __init__(self, alpha=0.5, beta=0.5, gamma=0.5):
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma

    def preprocess_sentence(self, sentence):
        words = sentence.split()
        return words

    def ngram_count(self, sentence, n):
        words = self.preprocess_sentence(sentence)
        ngrams = [tuple(words[i:i+n]) for i in range(len(words)-n+1)]
        return Counter(ngrams)

    def compute_precision(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        precision = overlap / sum(hyp_counts.values()) if sum(hyp_counts.values()) > 0 else 0
        return precision

    def compute_recall(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        recall = overlap / sum(ref_counts.values()) if sum(ref_counts.values()) > 0 else 0
        return recall

    def meteor_score(self, hypothesis, reference):
        precision = self.alpha * self.compute_precision(hypothesis, reference, 1) + (1-self.alpha) * self.compute_precision(hypothesis, reference, 2)
        recall = self.beta * self.compute_recall(hypothesis, reference, 1) + (1-self.beta) * self.compute_recall(hypothesis, reference, 2)
        fmean = (1-self.gamma) * precision + self.gamma * recall if (precision != 0 and recall != 0) else 0
        return fmean

# %%
# !pip install jiwer
import jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading jiwer-3.0.5-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.9 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.5 rapidfuzz-3.10.1

# %%
meteor = MeteorScore(alpha=0.5, beta=0.5, gamma=0.5)

def wilWerMeteorScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    wer_score = 0
    meteor_score = 0
    wil_score = 0

    for i in range(lenS):
        wer_result = jiwer.wer(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])
        meteor_result = meteor.meteor_score(SummaryEv[columnName][i], SummaryEv['givenSummary'][i])
        wil_result = jiwer.wil(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])

        wer_score = wer_score + wer_result
        meteor_score = meteor_score + meteor_result
        wil_score = wil_score + wil_result

    wilWerMeteor_score = {'METEOR': meteor_score/lenS,
                    'WER': wer_score/lenS,
                    'WIL': wil_score/lenS}

    return wilWerMeteor_score
    # return spice_score/lenS

# %%
mx = wilWerMeteorScore('mT5_finetuned_test')
mx
# Out:
# {'METEOR': 0.3694995375541737,
#  'WER': 1.1714886828484485,
#  'WIL': 0.8061316430611867}

# %%
import pandas as pd

data = {'columns':['WIL', 'METEOR', 'WER'],
        'mT5_finetuned_test':[getScore(mx, 'WIL'), getScore(mx, 'METEOR'), getScore(mx, 'WER')],
       }

threeScoreDf = pd.DataFrame(data)
threeScoreDf_ = threeScoreDf
threeScoreDf = threeScoreDf.reset_index(drop=True).T
threeScoreDf = threeScoreDf.rename(columns=threeScoreDf.iloc[0]).drop(threeScoreDf.index[0])
threeScoreDf.reset_index(inplace=True)
threeScoreDf = threeScoreDf.rename(columns = {'index':'Summary'})
threeScoreDf
# Out:
#               Summary       WIL  METEOR       WER
# 0  mT5_finetuned_test  0.806132  0.3695  1.171489

# %%
import matplotlib.pyplot as plt

# plotting graph
threeScoreDf.plot(x="Summary",
               y=['WIL', 'METEOR', 'WER'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Three Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a bar chart
plt.figure(figsize=(12, 6))
bar_width = 0.35
x = np.arange(len(metrics))

plt.bar(x, values, width=bar_width, color='skyblue')
plt.xticks(x, metrics, rotation=45, ha='right')
plt.ylabel('Score')
plt.title('Evaluation Metrics for Text Summarization')

# Optionally add a grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a DataFrame
df = pd.DataFrame({'Metric': metrics, 'Score': values})

# Display the table
print(df)

# If you want to export the table to a CSV file
# df.to_csv('/content/summary_evaluation_metrics.csv', index=False)
# Out:
#                    Metric   Score
# 0            ROUGE-1 (F1)  0.1666
# 1            ROUGE-2 (F1)  0.0598
# 2            ROUGE-L (F1)  0.1535
# 3                  BLEU-1  0.1067
# 4                  BLEU-2  0.0529
# 5                  BLEU-3  0.0256
# 6                  BLEU-4  0.0104
# 7   BERTScore (Precision)  0.8277
# 8      BERTScore (Recall)  0.6640
# 9          BERTScore (F1)  0.7366
# 10                 METEOR  0.1642
# 11                    WER  3.1958

# %% [markdown]
# **DATA VISUALIZATION**

# %%
import matplotlib.pyplot as plt

human_lengths = genDf['givenSummary'].apply(lambda x: len(x.split()))
generated_lengths = genDf['mT5_finetuned_test'].apply(lambda x: len(x.split()))

plt.scatter(human_lengths, generated_lengths)
plt.xlabel('Human Summary Length')
plt.ylabel('Generated Summary Length')
plt.title('Human vs. Generated Summary Length')
plt.show()

# %%
gen_length = [len(summary.split()) for summary in genDf["mT5_finetuned_test"]]
ref_length = [len(summary.split()) for summary in genDf["givenSummary"]]

plt.figure(figsize=(10, 6))
plt.scatter(ref_length, gen_length, alpha=0.5)
plt.xlabel("Reference Summary Length (words)")
plt.ylabel("Generated Summary Length (words)")
plt.title("Generated vs. Reference Summary Length")
plt.plot([0, max(ref_length)], [0, max(ref_length)], color='red', linestyle='--')  # Diagonal line
plt.show()

# %% [markdown]
# # **TEST (NOT INCLUDED)**

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from normalizer import normalize  # Assuming you have this installed
import re

# Device setup
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# Load the model and tokenizer
model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Move the model to the correct device (GPU or CPU)
model.to(device)

# Define the whitespace handler
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

# Function to generate a summary
def generate_summary(input_text):
    # Normalize the text (if needed)
    input_text = normalize(input_text)

    # Tokenize the input text
    input_ids = tokenizer(
        [WHITESPACE_HANDLER(input_text)],
        return_tensors="pt",
        padding="max_length",
        max_length=512,
        truncation=True
    )["input_ids"]

    # Generate the summary
    output_ids = model.generate(
        input_ids=input_ids.to(device),
        max_length=400,
        min_length=64,
        no_repeat_ngram_size=2,
        num_beams=4
    )[0]

    # Decode the generated summary
    summary = tokenizer.decode(
        output_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return summary
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
# Example of custom input text
custom_text = """
  'ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়ার গাড়ি, বাড়ি, প্লট, ফ্ল্যাট-কী নেই। রীতিমতো গড়েছেন সম্পদের পাহাড়। শুধু নিজের
  নামেই নয়; স্ত্রী, ছেলে-মেয়ে এবং শ্যালক-শ্যালিকার নামেও গড়েছেন বিপুল সম্পত্তি।\nঅভিযোগ রয়েছে, ডিএমপিতে ‘ঘুষ’ এবং বদলি বাণিজ্যে গড়ে তুলেছেন এসব
  সম্পদ। তার বিপুল সম্পদের বিষয়ে অনুসন্ধান চালাচ্ছে দুর্নীতি দমন কমিশন (দুকক)। যুগান্তরের অনুসন্ধানি প্রতিবেদনে এসব তথ্য ওঠে এসেছে।\nপ্রতিবেদনে জানা যায়,
  রাজধানীর অভিজাত এলাকা সিদ্ধেশ্বরীর ভিকারুননিসা স্কুলের পাশেই রূপায়ণ স্বপ্ন নিলয়। ৫৫/১ হোল্ডিংয়ে আলিশান এ ভবনটি ১১ তলা। এখানে প্রায় সাড়ে ৩ হাজার বর্গফিটের
  একটি ফ্ল্যাট রয়েছে আছাদুজ্জামানের মেয়ে আয়েশা সিদ্দিকার নামে।\nশুক্রবার (২৩ আগস্ট) দুপুরে সেখানে গেলে নিরাপত্তা ইনচার্জ আবুল কালাম আজাদ যুগান্তরকে
   বলেন, তিনি মাস দেড়েক আগে এখানে চাকরি নিয়েছেন। এই ভবনে ১৩০টি ফ্ল্যাট। তাই সব ফ্ল্যাট মালিককে ভালোভাবে চিনেন না। বাড়ির ম্যানেজার সোহেল পারভেজ
    বিস্তারিত বলতে পারবেন বলে জানান তিনি।\nএ বিষয়ে সোহেল পারভেজ জানান, আয়েশা সিদ্দিকার নামে এখানে একটি ফ্ল্যাট আছে। তবে তিনি কখনো এখানে আসেন না।
    এটি ভাড়া দেওয়া আছে।\nধানমন্ডি ১২/এ নম্বর রোডের ৬৯ নম্বর বাড়িতে রয়েছে একটি বিলাসবহুল ফ্ল্যাট। শুক্রবার দুপুরে ওই বাড়িতে যাওয়া হলে ভেতরে প্রবেশের অনুমতি
    মেলেনি। তবে নিজের নাম প্রকাশ না করার শর্তে বাড়ির একজন নিরাপত্তাকর্মী জানান, ধানমন্ডির ১২-এ রোডের ৬৯ নম্বর বাড়ির দ্বিতীয় তলার পুরো ফ্লোরটি সাবেক ডিএমপি
    কমিশনার আছাদুজ্জামান মিয়া কিনেছেন। তবে এটি তার শ্যালকের নামে।\nওই ভবনের তৃতীয় তলার ফ্ল্যাটটি চট্টগ্রাম মেট্রোপলিটন পুলিশের (সিএমপি) সাবেক কমিশনার
    ইকবাল বাহারের। এ বিষয়ে পুলিশ সদর দপ্তরের ডিআইজি কৃষ্ণপদ রায় বলেন, ‘ইকবাল বাহার হলেন আছাদুজ্জামান মিয়ার খুবই ঘনিষ্ঠ। তাই তারা দুজন একই ভবনে
    থাকতেন। আমিও একাধিকবার সেখানে গিয়েছি। আছাদুজ্জামান মিয়া কমিশনার থাকা অবস্থায় ওই ভবনে থাকতেন।’\nশুক্রবার দুপুর আড়াইটায় ইস্কাটন গার্ডেন ১৩/এ
    প্রিয়নীড়ে গিয়ে জানা যায়, সেখানে আছাদুজ্জামানের স্ত্রীর নামে একটি ফ্ল্যাট রয়েছে। বিস্তারিত জানতে চাইলে নিরাপত্তাকর্মী আব্দুস সালাম ও শাহ আলম প্রতিবেদককে
    বলেন, ‘আমরা এখানে নতুন এসেছি, তাই তেমন কিছু জানি না।’\nভবনের ম্যানেজার আজাদ আহমেদ জানান, ১৪ তলা এই ভবনে ৪০টি ফ্ল্যাট আছে। বেশিরভাগ ফ্ল্যাটই
    ২১৩৩ বর্গফুটের। ভবনের ১১ তলায় আছাদুজ্জমানের স্ত্রী আফরোজা জামানের একটি ফ্ল্যাট আছে। তবে সেখানে তিনি থাকেন না। ফ্ল্যাটটি ভাড়া দেওয়া আছে। অভ্যর্থনাকারী
    আবু বকর প্রতি মাসে ভাড়া তুলে আছাদুজ্জামানের কাছে দিয়ে আসেন। ভাড়া বকেয়া পড়লে বা কোনো সমস্যা হলে আমি নিজে স্যারের সঙ্গে (আছাদুজ্জমান) যোগাযোগ
    করেন বলে জানান তিনি।\nখোঁজ নিয়ে জানা যায়, নিকুঞ্জ-১ এর ৮/এ রোডের ৬ নম্বর বাড়িটি আছাদুজ্জামানের ছোট ছেলে আসিফ মাহাদীনের নামে। শুক্রবার বিকালে
    সেখানে যাওয়া হলে বাড়িটি ভেতর থেকে বন্ধ পাওয়া যায়। বেশ কয়েকবার কলিংবেল টিপেও সাড়া পাওয়া যাচ্ছিল না। একপর্যায়ে পাশের চার নম্বর বাড়ির গাড়িচালকের
    সঙ্গে কথা হচ্ছিল এই প্রতিবেদকের। ওই গাড়িচালক জানান, আছাদুজ্জামান সপরিবারে এই বাড়িতে থাকতেন। সরকার পতনের পর তিনি বাড়ি ছেড়ে পালিয়ে গেছেন।
    অনুসন্ধানে আরও জানা যায়, এ ছাড়া বসুন্ধরা আবাসিক এলাকার এল ব্লকের ১ নম্বর রোডের ১৬৬ এবং ১৬৭ নম্বরে ১০ কাঠার ওপর ৬ তলাবিশিষ্ট আলিশান একটি বাড়ি
    আছাদুজ্জামানের স্ত্রী আফরোজা জামানের নামে। পূর্বাচলের নিউ টাউনের ১ নম্বর সেক্টরের ৪০৬/বি নম্বর রোডে ১০ কাঠা জমি রয়েছে আছাদুজ্জামান মিয়ার নামে। ওই জমিতে
     গাড়ি রাখার শেড বানিয়ে রাখা হয়েছে। পূর্বাচলের সেক্টর ৪, রোড ১০৮-এ ৫৩ নম্বর প্লটটি আছাদুজ্জামানের স্ত্রীর নামে ছিল। ৫ কাঠার এই প্লটটি বিক্রি করে দেওয়া হয়েছে।
     আফতাবনগরে ৩ নম্বর সেক্টরে রয়েছে ২১ কাঠা জমি। সেখানে নিজের নামে ১০ কাঠা ও আত্মীয়স্বজনদের নামে রয়েছে বাকি ১১ কাঠা জমি।\nআছাদুজ্জামান
     মিয়ার স্ত্রী আফরোজা জামানের নামে ঢাকা ছাড়াও ফরিদপুর ও নারায়ণগঞ্জে বিপুল সম্পদ রয়েছে। ২০১৮ সালে তিনি রাজউক থেকে বিশেষ কোটায় একটি প্লট বরাদ্দ
     পান। অথচ রাজউকের নীতিমালা অনুযায়ী, স্বামী-স্ত্রী উভয়ের প্লট বরাদ্দ পাওয়ার সুযোগ নেই।\nজানা গেছে, গাজীপুরের কালীগঞ্জ উপজেলার চাঁদখোলা মৌজায় আফরোজা
     জামানের নামে ৬৭ শতাংশ জমি রয়েছে। ২০১৭ সালে এই জমি কেনা হয়। ওই মৌজায় তার নামে ২০১৯ সালের ৫ ফেব্রুয়ারি কেনা হয় আরও ৩৯ শতাংশ জমি। একই নামে
     ২০২০ সালে জোয়ার সাহারা মৌজায় কেনা হয় ১৫ কাঠা জমি। ওই বছর গাজীপুরের চাঁদখোলা মৌজায় ৩১ শতক জমি ক্রয় করেন আফরোজা। আফরোজা ২০১৮ সালে
     নারায়ণগঞ্জের রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ২৮ একর জমি কেনেন। ওই বছর একই মৌজায় আরও ৩২ শতক জমি কেনেন তিনি। ওই বছরই
     রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ৬০ একর জমি তার নামে কেনা হয়। পরে তা বিক্রি করে দেওয়া হয়। ২০১৯ সালে কৈয়ামসাইল-কায়েতপাড়া মৌজায়
     দশমিক ৫৭ একর জমির পাওয়ার অব অ্যাটর্নি পান আছাদুজ্জামানের স্ত্রী। এরপর ওই জমি বিক্রিও করেন।\nঅনুসন্ধানে আছাদুজ্জামান মিয়ার পরিবারের সদস্যদের মালিকানার
     দুটি কোম্পানির খোঁজ পাওয়া গেছে। এর মধ্যে একটি হলো মৌমিতা ট্রান্সপোর্ট লিমিটেড। এর চেয়ারম্যান আছাদুজ্জামানের স্ত্রী আফরোজা। আছাদুজ্জামান ডিএমপি কমিশনার
     থাকাকালীন রাজধানীর রুট পারমিট কমিটির প্রধান ছিলেন। ওই সময় মৌমিতা পরিবহণকে রুট পারমিট দেওয়া হয়। মৌমিতা ট্রান্সপোর্ট লিমিটেডের ভাইস চেয়ারম্যান হারিসুর
     রহমান সোহান হলেন আছাদুজ্জামানের শ্যালক। সোহানের নামে রাজধানীর নিউমার্কেটে আছে স্বর্ণের দোকান।\nআরও জানা যায়, শেপিয়ার্ড কনসোর্টিয়াম লিমিটেড নামে
     আরেকটি কোম্পানির চেয়ারম্যান আফরোজা জামান। এই কোম্পানির পরিচালক আছাদুজ্জামানের বড় ছেলে আসিফ শাহাদাত। আছাদুজ্জামানের শ্যালক নূর আলম ওরফে
     মিলনের নামে গাজীপুরের শ্রীপুরে দেড় একর জমি রয়েছে। ভাগনে কলমের নামেও গাজীপুরে জমি আছে দেড় একর।\nএদিকে আছাদুজ্জামান মিয়ার অবৈধ সম্পদের
     অনুসন্ধান শুরু করেছে দুদক। সংস্থাটির সচিব খোরশেদা ইয়াসমীন গণমাধ্যমকে বলেন, আছাদুজ্জামান মিয়ার বিরুদ্ধে বিভিন্ন অনিয়ম ও দুর্নীতির মাধ্যমে কোটি কোটি
     টাকার অবৈধ সম্পদ অর্জনের অভিযোগ এসেছে। এই অভিযোগ অনুসন্ধানের সিদ্ধান্ত গৃহীত হয়েছে বলে জানান তিনি।\nআওয়ামী লীগ সরকারের পতনের কয়েকদিন আগে
     আছাদুজ্জামান মিয়া জানিয়েছিলেন, তার এবং পরিবারের সদস্যদের কোনো অবৈধ সম্পদ নেই। যেসব সম্পদ আছে সবই আয়কর বিবরণীতে উল্লেখ করা আছে। সরকারের
     কোনো সংস্থা যদি এসব সম্পদের বিষয়ে অনুসন্ধান চালায় তাহলে তিনি ও তার পরিবারের সদস্যরা ওই সংস্থাকে সহযোগিতা করবেন।'
"""

# Generate the summary for the custom input text
generated_summary = generate_summary(custom_text)

# Print the original text and its generated summary
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়া রীতিমতো গড়েছেন বিপুল সম্পত্তি। তার গাড়ি, বাড়ি, প্লট এবং ফ্ল্যাট-কী নেই। অনুসন্ধানে এসব তথ্য উঠে এসেছে।

# %%
custom_text2 = """
বাংলাদেশের অর্থনৈতিক অবস্থা উন্নতির দিকে ধাবিত হচ্ছে, বিশেষ করে গত কয়েক বছরে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।
অর্থনীতিবিদরা মনে করছেন, এই অগ্রগতি ধরে রাখতে পারলে বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার অন্যতম শক্তিশালী অর্থনীতিতে পরিণত হতে পারে।
"""

generated_summary = generate_summary(custom_text2)
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার সবচেয়ে শক্তিশালী দেশগুলোর একটি হিসেবে পরিণত হতে পারে বলে মনে করছেন অর্থনৈতিক বিশ্লেষকরা। এর মধ্যে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।

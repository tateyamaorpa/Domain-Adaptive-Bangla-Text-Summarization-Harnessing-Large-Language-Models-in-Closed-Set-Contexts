# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset I

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model

df = pd.read_csv('/content/drive/MyDrive/Colab/international_categories.csv')
df.head()
# Out:
#         category                                              title  \
# 0  international    ব্রিটিশ এম্পায়ার মেডেল পেলেন রেহানা খানম রহমান
# 1  international  কুয়ালালামপুরে মিয়ানমার ও বাংলাদেশিদের ১৮ প্রতি...
# 2  international  মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত ২ বাংলাদেশির প...
# 3  international  ঢাকা-আবুধাবি রুটে বন্ধ হচ্ছে ইতিহাদ এয়ারওয়েজের...
# 4  international    ২০২৩ সালে দেশে এসেছে রেকর্ড ৪৫৫২ প্রবাসীর মরদেহ
#
#                                                 text  \
# 0  ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্...
# 1  মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরি...
# 2  মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত তিন বাংলাদেশির...
# 3  সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4  পরিবারের দারিদ্র ঘোচাতে ২০১৯ সালে শ্রমিক হিসেব...
#
#                                              summary
# 0  ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্...
# 1  মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরি...
# 2  মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত তিন বাংলাদ...
# 3  সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4  পরিবারের দারিদ্র ঘোচাতে ২০১৯ সালে শ্রমিক হিসেব...

# %%
df
# Out:
#            category                                              title  \
# 0     international    ব্রিটিশ এম্পায়ার মেডেল পেলেন রেহানা খানম রহমান
# 1     international  কুয়ালালামপুরে মিয়ানমার ও বাংলাদেশিদের ১৮ প্রতি...
# 2     international  মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত ২ বাংলাদেশির প...
# 3     international  ঢাকা-আবুধাবি রুটে বন্ধ হচ্ছে ইতিহাদ এয়ারওয়েজের...
# 4     international    ২০২৩ সালে দেশে এসেছে রেকর্ড ৪৫৫২ প্রবাসীর মরদেহ
# ...             ...                                                ...
# 4153  international  বাংলাদেশে সহিংসতার ঘটনার পূর্ণাঙ্গ, নিরপেক্ষ ত...
# 4154  international  বাড়তে থাকা যুদ্ধের ছায়ায় অক্টোবর হামলার বর্ষপূ...
# 4155  international  যুক্তরাষ্ট্রের আইআরআই প্রতিনিধিদলের সঙ্গে এবি ...
# 4156  international              এক বছরে গাজার ৪০ হাজার স্থাপনায় হামলা
# 4157  international        মসজিদুল আকসা রক্ষায় ঢাকায় \nআলোচনা অনুষ্ঠান
#
#                                                    text  \
# 0     ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্...
# 1     মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরি...
# 2     মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত তিন বাংলাদেশির...
# 3     সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4     পরিবারের দারিদ্র ঘোচাতে ২০১৯ সালে শ্রমিক হিসেব...
# ...                                                 ...
# 4153  বাংলাদেশে বড় একটি রাজনৈতিক বিক্ষোভের আগে সাংবা...
# 4154  ইসরায়েলে ফিলিস্তিনের প্রতিরোধ সংগঠন হামাসের নজ...
# 4155  যুক্তরাষ্ট্রভিত্তিক বেসরকারি সংস্থা ইন্টারন্যা...
# 4156  গত এক বছরে ফিলিস্তিনের গাজা উপত্যকায় ৪০ হাজারে...
# 4157  ইসরায়েলি হামলায় ধ্বংসস্তূপে পরিণত ফিলিস্তিনের ...
#
#                                                 summary
# 0     ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্...
# 1     মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরি...
# 2     মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত তিন বাংলাদ...
# 3     সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4     পরিবারের দারিদ্র ঘোচাতে ২০১৯ সালে শ্রমিক হিসেব...
# ...                                                 ...
# 4153  বাংলাদেশে বড় একটি রাজনৈতিক বিক্ষোভের আগে সাংবা...
# 4154  ইসরায়েলে ফিলিস্তিনের প্রতিরোধ সংগঠন হামাসের নজ...
# 4155  যুক্তরাষ্ট্রভিত্তিক বেসরকারি সংস্থা ইন্টারন্যা...
# 4156  গত এক বছরে ফিলিস্তিনের গাজা উপত্যকায় ৪০ হাজারে...
# 4157  ইসরায়েলি হামলায় ধ্বংসস্তূপে পরিণত ফিলিস্তিনের ...
#
# [4158 rows x 4 columns]

# %% [markdown]
# # Install and Imports

# %%
# !pip install sentencepiece
# !pip install transformers
# !pip install git+https://github.com/csebuetnlp/normalizer

import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

from normalizer import normalize # pip install git+https://github.com/csebuetnlp/normalizer


from transformers import XLMProphetNetForConditionalGeneration, XLMProphetNetTokenizer


from transformers import MBartForConditionalGeneration, AutoModelForSeq2SeqLM
from transformers import AlbertTokenizer, AutoTokenizer
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-3ebo4kma
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-3ebo4kma
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from normalizer==0.0.1) (2024.9.11)
# Collecting emoji==1.4.2 (from normalizer==0.0.1)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy==6.0.3 (from normalizer==0.0.1)
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.13)
# Building wheels for collected packages: normalizer, emoji, ftfy
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6860 sha256=14e51ed4dbd079a79b8acaae631864688688710a883c25c01f1323390a1421fc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6asq5_yk/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186455 sha256=7b28b6a28e5c33cb0447aec9b9348cc8ef8b5ded31dbb59db35488af01cc456c
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41931 sha256=c8066ec8e5d7b1dd7dbb03b077629026da5f497b9d6b9f63f708584f87b81fc9
#   Stored in directory: /root/.cache/pip/wheels/92/8e/16/c1e4d4d65685d71085e4e27b44d6ed880b0559474c9ee4ff66
# Successfully built normalizer emoji ftfy
# Installing collected packages: emoji, ftfy, normalizer
# Successfully installed emoji-1.4.2 ftfy-6.0.3 normalizer-0.0.1

# %%
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ### Functions

# %%
def cleanText(text2clean):
    empty_string = ""

    space = chr(32)
    flag  = 0

    for i in range(len(text2clean)):
        if text2clean[i] != "'" and text2clean[i] != "\n":
            if text2clean[i] == space and flag == 0:
                flag = 1
                empty_string = empty_string + text2clean[i]
            elif text2clean[i] != space:
                empty_string = empty_string + text2clean[i]
                flag = 0
    return empty_string

# %% [markdown]
# # Model Loading

# %% [markdown]
# ### Model Setup

# %%
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

tokenizer_path = "/content/drive/MyDrive/Colab/mT5_Tokenizer_XLSum"
model_path = "/content/drive/MyDrive/Colab/mT5_Model_XLSum"

# Step 4: Load the tokenizer and model from the specified paths
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=250112, bias=False)
# )

# %% [markdown]
# ### Run dataset over the Model

# %%
df.columns
# Out:
# Index(['category', 'title', 'text', 'summary'], dtype='object')

# %%
rows = df.shape[0]
rows
# Out:
# 4158

# %%
# Create empty DataFrame without the "title" column
genDf = pd.DataFrame(columns=["text", "givenSummary", "mT5_Test_XLSum"])

# Load over the dataset
for i in range(rows):
    if i < 2000:  # Adjust the starting index as needed
        article_text = normalize(df['text'][i])

        # Tokenize the input text
        input_ids = tokenizer(
            [WHITESPACE_HANDLER(article_text)],
            return_tensors="pt",
            padding="max_length",
            max_length=512,
            truncation=True
        )["input_ids"]

        # Generate the summary
        output_ids = model.generate(
            input_ids=input_ids.cuda(),
            max_length=400,
            min_length=64,
            no_repeat_ngram_size=2,
            num_beams=4
        )[0]

        # Decode the generated summary
        summary = tokenizer.decode(
            output_ids,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=False
        )

        # Add the text, given summary, and generated summary to the DataFrame
        genDf.loc[i] = [df['text'][i], df['summary'][i], summary]

        # Print the generated summary for verification
        print(i, '  ', summary)

# Save the DataFrame to CSV
genDf.to_csv('/content/drive/My Drive/Colab/international_finetuned.csv')
# Out:
# 0    ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্ডার অব the ব্রিটিশ এম্পায়ার' পদকে ভূষিত হয়েছেন রেহানা খানম রহমান। লন্ডন শহরে বসবাস করছেন তিনি বাংলাদেশি নাগরিক।
# 1    মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরিচালিত ১৮টি ব্যবসাপ্রতিষ্ঠান সিলগালা করেছে সিটি করপোরেশনের এনফোর্সমেন্ট ডিপার্টমেন্ট। এর মধ্যে ১৭টি প্রতিষ্ঠানকে জরিমানাও করা হয়েছে।
# 2    মালয়েশিয়ায় রোববার রাতে ট্রেনের ধাক্কায় নিহত তিন বাংলাদেশির মধ্যে দুই জনের পরিচয় মিলেছে বলে বাংলাদেশ হাইকমিশন জানিয়েছে। এই দুর্ঘটনার ঘটনা ঘটে সেলাঙ্গর রাজ্যের কাজাং কেটিএম পুনচাক উতামা জেড হিল ট্র্যাকে।
# 3    সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা রুটে ফ্লাইট পরিচালনা স্থগিত করার ঘোষণা দিয়েছে ইতিহাদ এয়ারওয়েজ। আগামী ২৯ অক্টোবর এই সিদ্ধান্ত কার্যকর হবে।
# 4    বাংলাদেশে অভিবাসী শ্রমিকদের সবচেয়ে বড় গন্তব্যস্থল মধ্যপ্রাচ্যে। বিশেষ করে, বাংলাদেশি শ্রমিকরা এখন স্বপ্ন নিয়ে বিদেশে যান। কিন্তু তাদের অনেককেই দেশে ফিরতে হয় লাশ হয়ে।
# 5    অস্ট্রেলিয়ার সিডনির একটি শপিং সেন্টারে গণহত্যার শিকারদের সম্মান জানাতে সবচেয়ে আইকনিক স্থাপত্যের ল্যান্ডমার্ক কালো ফিতা দিয়ে আলোকিত হয়েছে। শনিবার ভয়ঙ্কর ছুরিকাঘাতে ৬ জন মারা গেছেন।
# 6    সংযুক্ত আরব আমিরাতের উম্মুল কুয়াইনে গাড়ির ধাক্কায় এক বাংলাদেশি নিহত হয়েছেন। তার স্বজন জানিয়েছেন, তার মরদেহ বর্তমানে হাসপাতালের মর্গে রয়েছে। তিনি চট্টগ্রামের হাটহাজারীতে।
# 7    মালয়েশিয়ার সারওয়াক রাজ্যের কুচিংয়ের জালান গম্বিরের ভাসমান মসজিদের পাশের একটি নদী থেকে একজন বাংলাদেশি শিক্ষার্থীের মরদেহ উদ্ধার করা হয়েছে। স্থানীয় পুলিশের কাছে তাকে হস্তান্তর করেছে।
# 8    কোটা সংস্কারের দাবিতে চলমান আন্দোলনের সঙ্গে সংহতি প্রকাশ করে অস্ট্রেলিয়ার সিডনিতে বাংলাদেশি শিক্ষার্থীরা প্রতিবাদ সমাবেশ ও মিছিল করেছেন। এর মধ্যে যুক্ত বাংলাদেশের লেখক, সাংবাদিক এবং সাবেক প্রধানমন্ত্রী শেখ হাসিনাও যোগ দেন।
# 9    জাপান প্রবাসী বাংলাদেশি হিন্দু কমিউনিটিতে আশার আলো দেখা যাচ্ছে। অবশেষে জাপানে নতুন পূজা উদযাপন কমিটি ঘোষণা করা হয়েছে। সাবেক উপদেষ্টাদের নামে অগণতান্ত্রিক প্রক্রিয়ায় সব কার্যক্রমকে অবৈধ করার আহ্বান জানিয়েছে কমিশন।
# 10    সংযুক্ত আরব আমিরাত থেকে বাংলাদেশিদের জন্য শ্রম ভিসা পাওয়ার পথ বন্ধ করে দিয়েছে দেশটির কর্তৃপক্ষ। গত তিন দিন ধরে এই পদ্ধতিতে সার্টিফিকেট জমা দেয়া হচ্ছে না বলে একাধিক বাংলাদেশি ট্রাভেল এজেন্সির সূত্রে জানা গেছে।
# 11    মালয়েশিয়ার রাজধানী কুয়ালালামপুরের একটি নির্মাণ স্থাপনা থেকে ২৪ জন বাংলাদেশিকে আটক করা হয়েছে। এদের মধ্যে বাংলাদেশি নাগরিকও রয়েছেন। এর সঙ্গে যোগ দেওয়া হয়েছে ভারতের তিনজনকে।
# 12    ভেনিস পৃথিবীর এক ইউনিক শহর। পানির ওপর ভাসমান এই শহরে জীবনযাপন ব্যাপক ব্যয়বহুল। তবু ভ্রমণ পিয়াসীদের কাছে ভেনিসের আকর্ষণ অনেকেই মানতে পছন্দ করেন।
# 13    পবিত্র শবে কদরের রাতে ধর্মপ্রাণ মুসলমানরা আল্লাহর অশেষ রহমত ও নেয়ামত বর্ষিত করার জন্য নফল নামাজ আদায় করেছেন। ইসলামের ধর্মীয় বয়ানের মধ্য দিয়ে এই রাত শুরু হয়েছে।
# 14    আন্তর্জাতিক মাতৃভাষা দিবস উপলক্ষে সংযুক্ত আরব আমিরাতের বাণিজ্যিক শহর দুবাইয়ে ভাষা শহীদদের প্রতি শ্রদ্ধা নিবেদন করেছে বাংলাদেশের বিভিন্ন সামাজিক-সাংস্কৃতিক ও রাজনৈতিক ৬০টি সংগঠন।
# 15    বাংলাদেশের গাজায় ইসরাইল-হামাস যুদ্ধে নিহত ফিলিস্তিনি শরণার্থীদের জন্য মিশরীয় ঐতিহ্যবাহী খাবার 'সামাক সাইয়ীদিয়াত'র সঙ্গে নীল নদের মাছ দিয়ে রান্না করা হচ্ছে।
# 16    অস্ট্রেলিয়ার সাবেক ছয় প্রধানমন্ত্রী ইসরায়েল ও ফিলিস্তিনিদের মধ্যে যুদ্ধ বন্ধ করার আহ্বান জানিয়েছেন। তারা বলেছেন, হামাসের হাতে আটক জিম্মিদের নিঃশর্ত মুক্তির জন্য সবাইকে সতর্ক করেছেন।
# 17    সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবিতে স্পিডবোট দুর্ঘটনায় মুহাম্মদ মোক্তার হোসেন নামে এক বাংলাদেশি নিহত হয়েছেন। স্থানীয় কমিউনিটিতে শোকের ছায়া নেমে আসছে। আরও দুইজন আহত হবার খবর পাওয়া যাচ্ছে।
# 18    ইসরায়েলের সমালোচনা করে পোস্ট দেওয়ায় অস্ট্রেলিয়ায় শীর্ষস্থানীয় সংবাদমাধ্যম এবিসি থেকে সাংবাদিক আন্তোয়েনেট লাট্টুফকে বরখাস্ত করা হয়েছে। সংস্থাটির বিরুদ্ধে মামলা করার পর তিনি হতাশা প্রকাশ করেছেন।
# 19    মালয়েশিয়ার রাজধানী কুয়ালালামপুরের একটি শপিং মল থেকে বাংলাদেশিসহ ৪৬ অবৈধ অভিবাসীকে গ্রেপ্তার করেছে ইমিগ্রেশন পুলিশ। এদের মধ্যে বেশ কয়েকজন স্থানীয় নিয়োগকর্তাও রয়েছেন।
# 20    জাপানে মহান শহীদ দিবস ও আন্তর্জাতিক মাতৃভাষা দিব ২০২৪ পালিত হয়েছে। বাংলাদেশের রাষ্ট্রদূত শাহাবুদ্দিন আহমেদ দূতাবাসের প্রাঙ্গণে একুশের প্রভাতফেরিতে পুষ্পস্তবক অর্পণ করেন।
# 21    ট্রাফিক জরিমানা, পানি ও বিদ্যুৎ বিলের পর এবার মোবাইল বিল পরিশোধ বাধ্যতামূলক করতে যাচ্ছে কুয়েত সরকার। নতুন আইন অনুযায়ী প্রবাসীদের বিভিন্ন পরিষেবা নিয়ে বিমানবন্দরে গিয়ে তাদের পরিষ্কার করা যাবে।
# 22    অস্ট্রেলিয়ার সিডনিতে গত শুক্রবার গাড়ির নিয়ন্ত্রণ হারিয়ে বাংলাদেশি বংশোদ্ভূত কিশোর মাহিউদ্দিন মাহী (১৭) নিহত হওয়ার পর তার বোন চালকদের সতর্ক থাকার অনুরোধ জানিয়েছেন। মাহীর পরিবারের সঙ্গে আলাপকালে তিনি বলেছেন, 'আমরা তাকে আজীবন ম
# 23    জাতিসংঘের মানবাধিকার বিষয়ক হাইকমিশনার ভলকার তুর্ক মালয়েশিয়ায় প্রবাসী কর্মী ও শরণার্থীদের প্রতি বিদ্বেষমূলক বক্তব্য ও বিভ্রান্তিমূলকের প্রচারণা বন্ধ করার আহ্বান জানিয়েছেন।
# 24    মালয়েশিয়ার জোহর প্রদেশে ১৭১ বাংলাদেশি বৈধ অভিবাসী কর্মীকে আটকের ঘটনার নিন্দা জানিয়েছে দেশটির শ্রমিক সংগঠন। তারা বলছে, বিদেশি কর্মীদের আটকে পুলিশ ও ইমিগ্রেশনের ভুমিকায় হতবাক।
# 25    বাংলাদেশে পুলিশ হেফাজতে একটি মৃত্যুর ঘটনা নিয়ে অস্ট্রেলিয়ার অন্যতম প্রধান গণমাধ্যম এবিসির অনলাইন সংস্করণে গতকাল মঙ্গলবার বাংলাদেশের দ্বাদশ সংসদ নির্বাচনে ভোট দেননি বাংলাদেশি যুবক মোহাম্মদ সজল হোসেন।
# 26    গ্লোবাল পিস ফাউন্ডেশন জাপানের আয়োজনে বহুদেশীয় এবং বহুমাত্রিক সাংস্কৃতিক উৎসব ২০২৩ যেন হয়ে উঠেছিল এক টুকরো বাংলাদেশ। এবারের অনুষ্ঠানে অংশ নিয়েছেন বাংলাদেশি শিল্পীরা।
# 27    জাপানের হানেদা বিমানবন্দরে অবতরণ করছিল জাপান এয়ারলাইনসের একটি উড়োজাহাজ। এতে ৩৭৯ জন যাত্রী ও ক্রুকে সরিয়ে নেওয়া সম্ভব হয়েছে। কিন্তু যাত্রীদের প্রাণ রক্ষায় সাহায্য করেছে আধুনিক প্রযুক্তি।
# 28    মালয়েশিয়ার রাজধানী কুয়ালালামপুরের একটি বিলাসবহুল কনডোমিনিয়াম থেকে বাংলাদেশি এক কিশোরীর মরদেহ উদ্ধার করা হয়েছে। স্থানীয় পুলিশ বলছে, এ ঘটনায় 'আকস্মিক মৃত্যু' হিসেবে শ্রেণিবদ্ধ হয়েছে মামলা।
# 29    অস্ট্রেলিয়ার বিভিন্ন শহরে ক্রোনুলা দাঙ্গার প্রতিবাদে আজ রোববার কয়েক হাজার ফিলিস্তিনিপন্থী বিক্ষোভকারীরা সমাবেশ করেছে। কিন্তু পুলিশের বাধা উপেক্ষা করে প্রতিবাদকারীদের রাস্তায় নেমে আসে।
# 30    মালয়েশিয়ায় প্লাইউড নিয়ে বিরোধের জেরে ছুরির আঘাতে এক বাংলাদেশি শ্রমিক নিহত হওয়ার ঘটনায় ইন্দোনেশিয়ান নাগরিককে গ্রেপ্তার করে রিমান্ডে নিয়েছে কিশোরগঞ্জের কুয়ালা মুদা জেলা পুলিশ।
# 31    বাংলাদেশের কুয়েতে জাতির জনক বঙ্গবন্ধু শেখ মুজিবুর রহমানের ১০৪তম জন্মবার্ষিকী ও জাতীয় শিশু দিবস উপলক্ষে বাংলাদেশ দূতাবাসের আয়োজন করেছে চিত্রাঙ্কন ও রচনা প্রতিযোগিতা। এর মধ্যে অন্যতম হলো মুক্তিযুদ্ধ ও বাংলাদেশ।
# 32    মালয়েশিয়ায় একটি রেল ট্র্যাকে ট্রেনের ধাক্কায় ৩ প্রবাসী বাংলাদেশি মারা গেছেন। এ ঘটনায় নিহতদের মধ্যে দু'জন বাংলাদেশিও রয়েছেন বলে খবর পাওয়া গেছে। এরপর থেকে তারা উদ্ধার করা হয়েছে।
# 33    গ্রিসে উদযাপিত হয়েছে হিন্দু সম্প্রদায়ের অন্যতম প্রধান উৎসব শ্রীকৃষ্ণের জন্মতিথি শুভ জন্মাষ্টমী। এ উপলক্ষে বাংলাদেশের দূতাবাসের শ্রম সচিব বিশ্বজিৎ কুমার পালসহ অনেকেই অংশ নিয়েছেন।
# 34    বাংলাদেশে যাত্রী নিয়ে ঢাকার উদ্দেশে দুবাই ছাড়ার পর বিমান বাংলাদেশ এয়ারলাইনসের একটি উড়োজাহাজের উইন্ডশিল্ডে ফাটল দেখা দেওয়ায় ফ্লাইটটি আবার দোহা ফিরে গেছে। এর আগে চলতি বছরের ফেব্রুয়ারিতে চট্টগ্রাম থেকে আবুধাবিগামী বি
# 35    মালয়েশিয়ায় পলাতক ঢাকার আন্ডারওয়ার্ল্ডের শীর্ষ সন্ত্রাসী খোন্দকার তানভীর ইসলাম জয় কুয়ালালামপুরে মারা গেছেন। ময়নাতদন্তের জন্য তার স্বজনের কাছে মরদেহ হস্তান্তর করা হয়েছে।
# 36    দুর্নীতির অভিযোগে নিজের চিফ অব স্টাফ গ্রেপ্তার হওয়ার কয়েক ঘণ্টার মধ্যে পদত্যাগ করেছেন পর্তুগালের প্রধানমন্ত্রী আন্তোনিও কস্তা। তিনি বলেছেন, 'আমি আইনের ঊর্ধ্বে নই।'
# 37    মেক্সিকোতে যথাযথ মর্যাদা, গভীর শ্রদ্ধা ও ভাবগাম্ভীর্যের সঙ্গে জাতির পিতা বঙ্গবন্ধু শেখ মুজিবুর রহমানের ৪৮তম শাহাদাত বার্ষিকী ও জাতীয় শোক দিবস পালিত হয়েছে।
# 38    মিশরের রাজধানী কায়রো থেকে ৭০০ কিলোমিটার দক্ষিণে নীলনদ উপত্যকায় ঐতিহাসিক লোক্সর শহরে অবস্থিত ফেরাউনের রাজ প্রাসাদ ও উপাসনালয় 'কারনেক টেম্পল'।
# 39    কুয়েতের আল-মাতলা এলাকায় ৩ সপ্তাহ আগে ছুরিকাঘাতে এক বাংলাদেশি নাগরিককে হত্যার অভিযোগে ১ জনকে এখন গ্রেপ্তার করা হয়েছে। তবে পঞ্চম সন্দেহভাজন এখনো পলাতক।
# 40    মালয়েশিয়া পেরাক রাজ্যের কাম্পার এলাকার সড়ক দুর্ঘটনায় আহত আরও এক বাংলাদেশি মারা গেছেন। এ নিয়ে দেশটির পুলিশের তদন্তে জানা যাচ্ছে, বৃহস্পতিবার রাত ১২টার দিকে একটি লরির ধাক্কায় তিনজন নিহত হন।
# 41    দীর্ঘ প্রতীক্ষার পর অবশেষে কুয়েতে অবৈধ অভিবাসীদের জন্য সাধারণ ক্ষমা ঘোষণা করেছে দেশটির সরকার। এর আগে করোনা মহামারির মধ্যে দেশটিতে বসবাসরত প্রবাসী বাংলাদেশিদের বিরুদ্ধে কঠোর ব্যবস্থা নেওয়া হয়েছিল।
# 42    অস্ট্রেলিয়ার সিডনিতে বাংলাদেশ কনস্যুলেটের উদ্যোগে দুই দিনব্যাপী মহান স্বাধীনতা দিবস ও জাতীয় দিবসের সূচনা করেছে। নিউ সাউথ ওয়েলস রাজ্যের কনস্যুলেট জেনারেল মো. সাখাওয়াত হোসেন।
# 43    জাপানের পশ্চিমাঞ্চলে শক্তিশালী ভূমিকম্পে মৃতের সংখ্যা বেড়ে ৪৮ জনে দাঁড়িয়েছে। এখনো নিখোঁজ আছেন ১৩৭ জন। এর মধ্যে আহত হয়েছেন আরো অনেক মানুষ। আফটারশক হচ্ছে।
# 44    মালয়েশিয়ার পার্লিসে ৪৫ বাংলাদেশিসহ ৪৯ অবৈধ অভিবাসীকে আটক করেছে রাজ্যের অভিবাসন বিভাগ। বৃহস্পতিবার গভীর রাতে অভিযানের সময় জঙ্গলে ও খাটের নিচে লুকিয়েও শেষ রক্ষা হয়নি।
# 45    বাংলাদেশের ২১ ফেব্রুয়ারি ভাষা আন্দোলনের কেন্দ্রীয় শহীদ মিনার আনুষ্ঠানিকভাবে উদ্বোধন করেছে মেক্সিকোতে নিযুক্ত বাংলাদেশ দূতাবাসের সচিব নেলি মিনার্ভা। এর আগে ঢাকায় ফিতা কেটে পালিত এই ভাষায় যোগ দেয়া হয়।
# 46    মিশরে শ্রদ্ধা-ভালোবাসায় উদযাপিত হলো স্বাধীন বাংলাদেশের স্থপতি, জাতির পিতা বঙ্গবন্ধু শেখ মুজিবুর রহমানের ১০৪তম জন্মবার্ষিকী ও জাতীয় শিশু দিবসের কর্মসূচির অংশ।
# 47    গাজায় ইসরায়েলি সেনাদের বিরুদ্ধে মানবিক যুদ্ধবিরতির আহ্বান জানিয়ে অস্ট্রেলিয়া বলছে, 'আতঙ্কিত' এবং আশঙ্কা প্রকাশ করেছে তারা। জাতিসংঘের উদ্বাস্তু কর্মসূচিতে ৬৬ দশমিক ৫ মিলিয়ন ডলারের বেশি জরুরি সহায়তা দে
# 48    অস্ট্রেলিয়ার দক্ষিণ-পশ্চিম সিডনির ক্যান্টারবেরি-ব্যাঙ্কটাউন কাউন্সিল গাজায় ইসরায়েলের যুদ্ধবিরতি ঘোষণা না হওয়া পর্যন্ত ফিলিস্তিনি পতাকা ওড়ানোর পক্ষে সর্বসম্মতিক্রমে ভোট দিয়েছে।
# 49    কুয়েতে সড়ক দুর্ঘটনায় আব্দুল আলিম (২৫) নামে এক প্রবাসী বাংলাদেশি নিহত হয়েছেন। স্থানীয় গণমাধ্যম এখনো নিশ্চিত করেছে যে তিনি দেশে ফিরবেন বলে ধারণা করা হচ্ছিল।
# 50    মালয়েশিয়ার সমুদ্রসৈকতে ঢেউয়ের কবলে পড়ে নিখোঁজ হওয়া এক বাংলাদেশীর মরদেহ উদ্ধার করা হয়েছে বলে জানিয়েছে দেশটির স্থানীয় পুলিশ। ময়নাতদন্তের জন্য হাসপাতালে রাখা হয়েছে।
# 51    ওমরাহ হজ পালন করতে যাওয়ার পথে সৌদি আরবের রিয়াদে সড়ক দুর্ঘটনায় দুজন বাংলাদেশি মা-মেয়ে নিহত হয়েছেন। এর মধ্যে চট্টগ্রামের রাউজান থানার নোয়াপাড়ার বাসিন্দা।
# 52    অস্ট্রেলিয়ার সিডনিতে বাংলাদেশ দূতাবাসের উদ্যোগে 'সর্বজনীন পেনশন স্কিম-২০২৩' বিষয়ের স্থানীয় প্রবাসীদের অবহিতকরণ ও উদ্বুদ্ধকরণ সভা অনুষ্ঠিত হয়েছে। এই সভায় সব শ্রেণির মানুষের সামাজিক সুরক্ষা নিশ্চিত করা সম্ভব
# 53    মালয়েশিয়ায় কর্মসংস্থান নিশ্চিত করতে গিয়ে প্রতারণার শিকার হওয়া ১০৪ জন বাংলাদেশিকে রাজধানী কুয়ালালামপুরের চেরাসের একটি বাসায় আটক করেছে ব্রিটিশ শ্রম অধিকার কর্মীরা। তারা বলেছেন, তাদের ঋণে পড়তে হয়েছে।
# 54    ইতালি সরকার ঘোষিত সাড়ে চার লাখ নতুন শ্রমিক আমদানি প্রক্রিয়ার প্রথম ধাপের আবেদনগ্রহণ শেষ হয়েছে। নূল্যা ওয়াস্তা বা এনওসি কোটা পরিমাণ না পাওয়ার সম্ভাবনা রয়েছে।
# 55    মালয়েশিয়ার পেরাক রাজ্যের ইপোহ শহরের রাজা মনজিৎ সিং হাসপাতাল মর্গে এক প্রবাসী বাংলাদেশির মরদেহ পড়ে আছে। মৃতের পরিবার ও স্বজনদের খুঁজে পাওয়া পর্যন্ত ওই বাংলাদেশি দেশে পাঠানো যাচ্ছে না বলে জানিয়েছে বাংলাদেশ হাইকমিশন।
# 56    যুক্তরাষ্ট্রের নিউইয়র্কে দার্শনিক আরজ আলী মাতুব্বরের ১২৩তম জন্মবার্ষিকী উদযাপন অনুষ্ঠানে অংশগ্রহণকারীরা আরজের মতাদর্শ বিশ্বব্যাপী ছড়িয়ে দেওয়ার প্রত্যয় ব্যক্ত করেন। এর মধ্যে অনেকে সত্যের সন্ধানে সারাটি জীবন অতিবাহিত করেছেন
# 57    লিবিয়ায় ঘূর্ণিঝড় ড্যানিয়েলের প্রভাবে দেশটির পূর্বাঞ্চলের দারনা শহরে বসবাসরত অন্তত ৬ বাংলাদেশি নাগরিক মারা গেছেন। বন্যায় নিহতের সংখ্যাও বাড়ছে বলে আশঙ্কা করছে বাংলাদেশ দূতাবাস।
# 58    মালয়েশিয়ার মেলাকা প্রদেশের একটি নাইট ক্লাবে অভিযান চালিয়ে ৫ বাংলাদেশিসহ ৪৫ অভিবাসীকে গ্রেপ্তার করেছে দেশটির ইমিগ্রেশন পুলিশ। এদের মধ্যে বেশ কয়েকজন থাইল্যান্ডের নাগরিক।
# 59    মালয়েশিয়ার জহুর রাজ্যের একটি পাম বাগানে অভিযান চালিয়ে ৫৫ বাংলাদেশিকে আটক করেছে দেশটির ইমিগ্রেশন পুলিশ। এদের মধ্যে বাংলাদেশি নাগরিকদের বয়স ১৯ থেকে ৬৯ বছর রয়েছে।
# 60    অস্ট্রেলিয়ার বাণিজ্য নগরী সিডনির বাংলাদেশ কনস্যুলেট জেনারেলে শহীদ ও আন্তর্জাতিক মাতৃভাষা দিবস উপলক্ষ্যে দিনব্যাপী অনুষ্ঠানের আয়োজন করা হয়েছে। এর মধ্যে বাংলাদেশের স্বাধীনতা অর্জনের মূল উদ্দেশ্য ছিল ভাষা আন্দোলন।
# 61    বাঙালির জীবন ও সংস্কৃতির এক অবিচ্ছেদ্য অংশ হিসেবে শীতের পিঠা ব্রাহ্মণবাড়িয়ার ঐতিহ্যকে টিকিয়ে রাখতে এবং পরবর্তী প্রজন্মের কাছে তা ছড়িয়ে দিতে পেরেছেন তারা।
# 62    কাতারে শ্রদ্ধা ও ভালোবাসায় জাতির পিতা বঙ্গবন্ধু শেখ মুজিবুর রহমানের ৪৮তম শাহাদত বার্ষিকী ও জাতীয় শোক দিবস পালন করা হয়েছে। বাংলাদেশ দূতাবাসে এই কর্মসূচি সূচনা করেন বাংলাদেশের রাষ্ট্রদূত মো. নজরুল ইসলাম।
# 63    মালয়েশিয়ায় ২৫২ বাংলাদেশিসহ ৫৬৭ জন অনিবন্ধিত অভিবাসীকে আটক করেছে দেশটির অভিবাসন বিভাগ। তারা বলছেন, দেশটিতে বসবাসের বৈধ কাগজপত্র দেখাতে না পারায় এখন পর্যন্ত ৬০ জনের মধ্যে ৪২ জন নাগরিক রয়েছেন।
# 64    বাংলাদেশের শ্রেষ্ঠ চিত্রকর্ম নিয়ে নিউইয়র্কের ম্যানহাটনে আয়োজিত 'কালার্স অব ফ্রিডম' শীর্ষক ৫ দিনব্যাপি আন্তর্জাতিক चित्रপ্রদর্শনী শেষ হয়েছে। এই প্রদর্শনীর কিউরেটর হিসেবে ছিলেন জিয়াউল করিম।
# 65    অস্ট্রেলিয়ান পরিসংখ্যান ব্যুরো প্রকাশিত তথ্য অনুযায়ী, এক বছরে বিদেশে জন্মগ্রহণকারী জনসংখ্যা প্রায় ৫ লাখ বেড়েছে। এর মধ্যে ভারত, চীন এবং নিউজিল্যান্ডের সংখ্যাও সবচেয়ে বেশি।
# 66    অস্ট্রেলিয়ার বাণিজ্যনগরী সিডনির বন্ডাই জংশনে ওয়েস্টফিল্ড শপিং সেন্টারে বেশ কয়েকজনকে ছুরিকাঘাত করেন একজন। এ ঘটনায় পুলিশ কর্মকর্তার ভূমিকায় অনেক মানুষের জীবন বেঁচেছে।
# 67    অস্ট্রেলিয়ার সিডনি অপেরা হাউসে বাংলাদেশের বাসভূমি উৎসবের ২০ বছর পূর্তি উপলক্ষ্যে একটি সাংস্কৃতিক সন্ধ্যার আয়োজন করা হয়। এরপর নতুন প্রজন্মের সারস বেহালার সুরে জাতীয় সংগীত পরিবেশন করে।
# 68    অস্ট্রেলিয়ার বাণিজ্যনগরী সিডনির বন্ডাই জংশনে ওয়েস্টফিল্ড শপিং সেন্টারে ছুরিকাঘাতে ছয় জনকে হত্যা ও নয়জনকে আহতকারীর পরিচয় পাওয়া গেছে। এ ঘটনায় জড়িত ব্যক্তির নাম জোয়েল কাউচি।
# 69    পশ্চিম অস্ট্রেলিয়ার প্রত্যন্ত অঞ্চলে ২০ জনেরও বেশি বাংলাদেশি ও পাকিস্তানিকে আটক করার পর কর্তৃপক্ষ তাদের বিরুদ্ধে কঠোর সীমান্ত সুরক্ষা নীতির বিরোধিতা করেছে। এর মধ্যে প্রধানমন্ত্রী অ্যান্থনি আলবানিজ এবং বিরোধী নেতা পিটার ডাটন এই ঘোষণা
# 70    মালয়েশিয়ায় এক বাংলাদেশিকে কুপিয়ে হত্যা করেছেন আরেক বাংলাদেশি। এ ঘটনায় পাঁচজনকে জিজ্ঞাসাবাদের জন্য আটক করেছে দেশটির পুলিশ। এরপর তাদের রিমান্ডে নেওয়ার কথা রয়েছে বলে স্থানীয় গণমাধ্যম জানিয়েছে।
# 71    বাংলাদেশে শ্রম আইন লঙ্ঘন মামলায় শান্তিতে নোবেল পুরস্কারজয়ী অধ্যাপক ড. মুহাম্মদ ইউনূসকে ছয় মাসের কারাদণ্ড দিয়েছেন ঢাকার শ্রم আদালত। এই রায়ের পর আন্তর্জাতিক সংবাদমাধ্যমগুলো তাকে রাজনৈতিক উদ্দেশ্যপ্রণোদ
# 72    মালয়েশিয়ায় অবৈধ অভিবাসীদের বিরুদ্ধে অভিযান শুরু করেছে দেশটির অভিবাসন বিভাগ। গ্রেপ্তারদের মধ্যে বাংলাদেশি, নেপাল ও পাকিস্তানি রয়েছে বলে অভিযোগ উঠেছে বলে জানা যাচ্ছে, যাদের বয়স ১ থেকে ৫০ বছর বয়সী তারা।
# 73    প্রাচীন সভ্যতার দেশ মিশরের রাজধানীর নিউ কায়রোর আন্তর্জাতিক প্রদর্শনী কেন্দ্রে শুরু হয়েছে পক্ষকালব্যাপী ৫৫তম কারেরো বইমেলা। বই বিক্রির মাধ্যমে শিক্ষা, সাহিত্য ও সংস্কৃতির নানা বর্ণাঢ্য আয়োজন অনুষ্ঠিত হচ্ছে।
# 74    মালয়েশিয়ার রাজধানী কুয়ালালামপুর থেকে প্রায় ৩০০ কিলোমিটার দূরে পেনাং রাজ্যে নির্মাণাধীন ভবন ধসের ঘটনায় নিখোঁজ পাওয়া ৪ বাংলাদেশি কর্মীকে আটক করেছে পুলিশ। এরপর উদ্ধার অভিযান স্থগিত করা হয়েছে।
# 75    মালয়েশিয়ার রাজধানী কুয়ালালামপুরের একটি হোটেল থেকে অস্ত্রসহ এক ব্যক্তিকে গ্রেপ্তার করেছে দেশটির পুলিশ। তিনি সিঙ্গাপুরে ইসরাইলি দূতাবাসের সঙ্গে সম্পর্ক রয়েছে বলে ধারণা করা হচ্ছে।
# 76    মালয়েশিয়ায় স্বদেশিকে হত্যার দায়ে এক প্রবাসী বাংলাদেশিকে ৩৩ বছরের কারাদণ্ড দিয়েছে দেশটির একটি আদালত। মৃত্যুদণ্ডপ্রাপ্ত আসামি হাইকোর্ড সোহেল এবং তার আইনজীবী আমিরুল জামালুদ্দিনের বিরুদ্ধে আপিল করার অনুমতি দেওয়া হয়েছে।
# 77    কুয়েতে একজন প্রবাসী বাংলাদেশি কর্মীকে মারধরের ঘটনায় দেশটির স্বরাষ্ট্র মন্ত্রণালয়ের এক কর্মকর্তাকে ৭ বছরের কারাদণ্ড দিয়েছে ফৌজদারি আদালত। এরপর অভিযুক্ত ব্যক্তির শাস্তি কমিয়ে সাতবছর।
# 78    মালদ্বীপে মহান বিজয় দিবস উদযাপন করেছে বাংলাদেশ হাইকমিশন। অনুষ্ঠানে রাষ্ট্রপতি, প্রধানমন্ত্রী, পররাষ্ট্র মন্ত্রী ও প্রতিমন্ত্রীর বাণী পাঠ করেন হাই কমিশনার রিয়ার এডমিরাল এস এম আবুল কালাম আজাদ।
# 79    মালয়েশিয়ায় অভিবাসীদের ব্যবসাপ্রতিষ্ঠান থেকে অর্থ চুরির অভিযোগে আটক তিন পুলিশ সদস্যের রিমান্ডে নেওয়ার মেয়াদ বাড়িয়ে দিয়েছে দেশটির ইমিগ্রেশন বিভাগের একজন কর্মকর্তা। এর আগে তারা অভিযুক্ত হয়েছিলেন।
# 80    মালয়েশিয়ায় পুলিশের সাথে বন্দুকযুদ্ধে তিন বিদেশি ডাকাত নিহত হওয়ার খবর পাওয়া গেছে। এদের মধ্যে এক বাংলাদেশি নাগরিকও রয়েছে বলে জানিয়েছে দেশটির রাষ্ট্রীয় গণমাধ্যম। কিন্তু তারা বলছেন, দেশটিতে বেশ কয়েকটি সোনার দোকানে ডাকাতি ও
# 81    স্পেনে যথাযথ মর্যাদা, গভীর শ্রদ্ধা ও ভাবগাম্ভীর্যের সঙ্গে জাতির পিতা বঙ্গবন্ধু শেখ মুজিবুর রহমানের ৪৮তম শাহাদাত বার্ষিকী ও জাতীয় শোক দিবস পালিত হয়েছে।
# 82    কুয়েত বিমানবন্দরে অসুস্থ হয়ে এক প্রবাসী বাংলাদেশির মৃত্যু হয়েছে বলে জানিয়েছেন তার স্ত্রী ও ভাইরাল হাসপাতালের কর্মকর্তারা। এর আগে তিনি স্ট্রোক করে বা হৃদরোগে আক্রান্ত হয়ে মারা গেছেন বলে জানা গেছে।
# 83    গাজায় ইসরায়েলের হামলায় শিশুসহ বেসামরিক মানুষ নিহতের প্রতিবাদে দক্ষিণ আফ্রিকার বড় ও গুরুত্বপূর্ণ শহরগুলোতে বিক্ষোভ ও প্রতিবাদ করেছে স্থানীয় ও বিভিন্ন দল। শনিবার দেশটির প্রিটোরিয়াস্থ কূটনীতিক এলাকাগুলোতে বেশ কয়েক হাজার
# 84    গুপ্তচরবৃত্তির অভিযোগে আটক অস্ট্রেলিয়ান লেখক ইয়াং হেনজুনকে বেইজিংয়ের একটি আদালত মৃত্যুদণ্ডের রায় দিয়েছে। এই রায়ে চীনের রাষ্ট্রদূতকে ফোন করার নির্দেশ দেয়া হয়েছে।
# 85    ইসরাইল আগ্রাসন ও ফিলিস্তিনিদের হত্যার প্রতিবাদে আজ রোববার জাপানের টোকিওতে ইসরাইলি দূতাবাসের সামনে বিক্ষোভ প্রদর্শন করেছেন বিভিন্ন দেশ থেকে আসা মুসলমান অভিবাসীরা। তারা বলেছেন, এ হামলা মানবতার বিরুদ্ধে।
# 86    অস্ট্রেলিয়ার ক্ষমতাসীন দল লেবার পার্টি থেকে পদত্যাগ করেছেন সিনেটর ফাতিমা পেম্যান। তিনি বলেছেন, ফিলিস্তিনিদের স্বীকৃতি এবং মুক্তি এমন একটি বিষয়, যেখানে বিবেকের সঙ্গে আপস করা সম্ভব ছিল না।
# 87    পবিত্র রমজান মাসের চাঁদ দেখা না যাওয়ায় আগামীকাল সোমবার থেকে জাপানে রোজা শুরু হচ্ছে না। এর মধ্যে প্রবাসী বাংলাদেশি নাগরিকও রয়েছে জাপানতে এই রোজার অনুমতি দিয়েছেন।
# 88    বছরের প্রথমদিনে মধ্য-পশ্চিম জাপানের ইশিকাওয়া জেলায় মারাত্মক ভূমিকম্পের পর উদ্ধার অভিযান এখনো চলছে। এর ফলে যাত্রাপথ নিরাপদ হতে পারে বলে আশঙ্কা করা হচ্ছে।
# 89    মালদ্বীপের আসন্ন প্রেসিডেন্ট নির্বাচনে প্রতিদ্বন্দ্বিতা করতে পারবেন না দেশটির সাবেক প্রধানমন্ত্রী আবদুল্লাহ ইয়ামিন। নির্বাচন কমিশনের সিদ্ধান্তের বিরুদ্ধে আপিল করেছিলেন তিনি। তবে আদালত তাকে ক্ষমা না করা পর্যন্ত দোষী সাব্যস্ত করেছে।
# 90    কুয়েতে সড়ক দুর্ঘটনায় এক বাংলাদেশি নিহত হওয়ার ঘটনা সিলেটের দক্ষিণ সুরমা উপজেলার মোগলা বাজার ইউনিয়নের মতিচর গ্রামের আব্দুল জলিলের ছেলে বলেছেন তার স্বজনরা। মৃতের মরদেহ দ্রুত দেশে পাঠানো হবে বলে তারা জানিয়েছেন।
# 91    যুক্তরাষ্ট্রের নিউইয়র্ক অঙ্গরাজ্যের সিনেট সপ্তমবারের মতো বাংলাদেশি অভিবাসী দিবস পালনের প্রস্তাব পাস করেছে। এ উপলক্ষে আগামী ২২ ও ২৩ সেপ্টেম্বরের হিলটন মিডটাউন হোটেলে আয়োজন করা হবে।
# 92    আদর্শ লিপির এই কথাগুলো নিয়েই আমরা শিখেছিলাম ভাষাকে রপ্ত করতে। কিন্তু এর আগে থেকেই ভাষার শহীদদের স্মরণে ভারতের নয়াদিল্লিতে সাউথ এশিয়ান ইউনিভার্সিটির একদল বাংলাদেশি গবেষক শিক্ষার্থী আটটি দেশের শিক্ষকদের সঙ্গ
# 93    মালদ্বীপ প্রবাসী টাঙ্গাইলের জলিল মিয়াকে অপহরণ করে রাজধানী মালেতে আটকে রাখার ৫ দিন পর বাংলাদেশ দূতাবাস ও স্থানীয় নাগরিকদের সহায়তায় উদ্ধার করেছে দেশটির পুলিশ। জলিলের পরিবার অনলাইনে অপহরণের কাছ থেকে ৬ লাখ টিকা
# 94    মালয়েশিয়ায় একটি কনডোমিনিয়ামে অভিযান চালিয়ে বাংলাদেশিসহ ১৩৬ অভিবাসীকে আটক করেছে দেশটির অভিবাসন বিভাগ। বৃহস্পতিবার রাত থেকে ইমিগ্রেশনের প্রাথমিক তদন্তে দেখা গেছে, বিদেশি নাগরিকদের মধ্যে বেশ কয়েকজন বাংলাদেশিও র
# 95    গাজায় ফিলিস্তিনিদের ওপর ইসরায়েলের গণহত্যা চালানোর প্রতিবাদে অস্ট্রেলিয়ার পার্লামেন্টের এক লেবার সিনেটর দুটি পররাষ্ট্র বিষয়ক কমিটি থেকে পদত্যাগ করেছেন। এর আগে তিনি প্রধানমন্ত্রীসহ তার সহকর্মীদের জিজ্ঞাসা করেছিলেন।
# 96    মালয়েশিয়ায় কর্মহীন বাংলাদেশি অভিবাসীদের অবস্থা নিয়ে উদ্বেগ প্রকাশ করেছেন জাতিসংঘের মানবাধিকার কাউন্সিলের বিশেষজ্ঞরা। তারা বলেছেন, বাংলাদেশিদের সঙ্গে প্রতারণা করা হচ্ছে এবং এর ফলে তাদের নির্বাসনের ঝুঁকিতে পড়তে হয়।
# 97    সিডনির ওয়েস্টফিল্ড বন্ডাই শপিং সেন্টারে হামলার সময় সাহসী ভূমিকার জন্য এক ফরাসি নাগরিককে অস্ট্রেলিয়ায় স্থায়ীভাবে বসবাসের প্রস্তাব দিয়েছে দেশটির অভিবাসন মন্ত্রী। তাকে 'বোলার্ড ম্যান' নামে পরিচিত এক ব্যক্তিকে বহিষ্কার করা
# 98    ইতালির ভেনিস শহরে ফিলিস্তিনিদের সমর্থন জানিয়ে বিশাল মিছিল ও সমাবেশ অনুষ্ঠিত হয়েছে। এর মধ্যে বাংলাদেশিসহ অন্যান্য মুসলিম অভিবাসীদেরও অংশ নিতে দেখা গেলেও সেখানে যানজটের সৃষ্টি হয়।
# 99    নিউইয়র্কের ম্যানহাটনে শেষ হয়েছে দুই দিনব্যাপী বাংলাদেশ অভিবাসী দিবস এবং বাণিজ্য মেলার আয়োজন। এই মেলায় অংশ নিয়েছিলেন প্রবাসী বাংলাদেশিদের প্রতিনিধি দল, ব্যবসায়ী ও উদ্যোক্তা। এদের মধ্যে বাংলাদেশি নাগরিকদের সমস্যা ও সুবিধার কথা আলোচনা কর
# 100    যুক্তরাষ্ট্রের নিউইয়র্কে প্রবাসী সংগঠন এস্টোরিয়া ওয়েলফেয়ার সোসাইটির উদ্যোগে করোনা মহামারির কারণে ক্ষতিগ্রস্তদের মাঝে বিনামূল্যে শীতবস্ত্র বিতরণ করা হয়েছে বলে জানিয়েছে দেশটির রাষ্ট্রীয় গণমাধ্যম।
# 101    দশ হাজারের বেশি মানুষের উপস্থিতিতে নিউইয়র্কের টাইমস স্কয়ারে বরণ করে নেওয়া হয়েছে ১৪৩১ বঙ্গাব্দকে। এই প্রথমবারের মতো সহস্র কণ্ঠে বাংলা নতুন বছরকে বরাদ্দ করেছেন বাঙালি অভিবাসীরা।
# 102    অস্ট্রেলিয়ায় ফিলিস্তিনপন্থী বিক্ষোভের আয়োজকরা আগামী রোববার সিডনিতে আরেকটি মিছিল ও সমাবেশের ঘোষণা দিয়েছেন। তবে ইহুদি সম্প্রদায়ের অনুরোধে নিউ সাউথ ওয়েলস পুলিশ তাদের আবেদন প্রত্যাখ্যান করেছে।
# 103    সংযুক্ত আরব আমিরাতের দুবাইয়ের একটি কারখানায় কর্মস্থলে দুর্ঘটনায় এক বাংলাদেশি কর্মী নিহত হওয়ার খবর নিশ্চিত করেছে তার স্বজন ও ভাই ও দুই বোনের মধ্যে একজনের মৃত্যুর ঘটনা।
# 104    মালয়েশিয়ায় ভুয়া ভিসা তৈরির অভিযোগে এক বাংলাদেশি ও তার ইন্দোনেশিয়ান স্ত্রীকে গ্রেপ্তার করেছে ইমিগ্রেশন পুলিশ। এই অভিযানে বেশ কয়েকজন এজেন্টকে জব্দ করা হয়েছে।
# 105    সিডনির পোর্ট বোটানিতে অস্ট্রেলিয়ার সামরিক বাহিনীর জন্য অস্ত্র বহনকারী ইসরায়েলি জাহাজ আসার প্রতিবাদ জানিয়েছে ফিলিস্তিনপন্থিরা। বন্দরে প্রবেশের পথ অবরুদ্ধ করায় বিক্ষোভকারীদের মধ্যে ১৯ জনকে গ্রেপ্তার করা হয়েছে।
# 106    নীলনদ আর পিরামিডের দেশ মিশরে যথাযোগ্য মর্যাদায় ও উৎসবমুখর পরিবেশে মহান বিজয় দিবস উদযাপন করেছেন প্রবাসী বাংলাদেশিরা। জাতিসংঘের কর্মকর্তা ও কর্মচারীদের মধ্যে বিপুল সংখ্যক বাংলাদেশি অংশগ্রহণ করে।
# 107    'সরকারের ভবিষ্যৎ গঠন' প্রতিপাদ্যে সংযুক্ত আরব আমিরাতের দুবাইয়ে শুরু হয়েছে ওয়ার্ল্ড গভর্নমেন্ট সামিট-২০২৪। এই শীর্ষ সম্মেলনে বাংলাদেশের প্রতিনিধিত্ব করছেন প্রবাসীকল্যাণ ও বৈদেশিক কর্মসংস্থান প্রতিমন্ত্রী শফিকুর রহমান চৌধুরী।
# 108    জাপানের রাজধানী টোকিওতে যথাযোগ্য মর্যাদায় বাংলাদেশের মহান স্বাধীনতা ও জাতীয় দিবস উদযাপন করা হয়েছে। শনিবার সকালে দূতাবাসের ভবন প্রাঙ্গণে বাংলাদেশী কর্মকর্তা-কর্মচারীদের উপস্থিতিতে এক মিনিট নীরবতা উপলক্ষে পুষ্পস্তবক অর্পণ
# 109    স্পেনে বাংলাদেশি কমিউনিটির সূচনা হয় প্রায় ৩৪ বছর আগে। ইউরোপে বাংলাদেশিদের বসবাসের দিক থেকে দ্বিতীয় স্পেন। গত রোববার মাদ্রিদের ঐতিহ্যবাহী মনক্লোয়া হসপিটালে যোগ দিয়েছেন জুমা আক্তার কালাম।
# 110    অস্ট্রেলিয়ার জর্জেস রিভারে পানিতে ডুবে মারা যাওয়া বাংলাদেশি বংশোদ্ভূত ২৬ বছর বয়সী শহিদুল হক আজ বুধবার তার জানাজা অনুষ্ঠিত করবেন বলে জানিয়েছেন তার পরিবার। তিনি নৌকা চালাচ্ছিলেন।
# 111    গ্রিসের থেসালিনিকির ঐতিহাসিক ইয়েনি যামি মসজিদে ১০০ বছর আগে নামাজ আদায় বন্ধ করে দেওয়া হয়েছে। সেখানে মুসলিমরা ঈদুল ফিতরের নাজায় অংশ নিচ্ছেন।
# 112    কুয়েতে অনুপ্রবেশের অভিযোগে পাঁচ বাংলাদেশিকে গ্রেপ্তার করেছে দেশটির একটি মানবাধিকার সংগঠন। তারা বলছে, তাদের বিরুদ্ধে আইনি ব্যবস্থা নেওয়া হচ্ছে। এদের মধ্যে কোন বাংলাদেশি নেই।
# 113    সংযুক্ত আরব আমিরাতে ভারী বর্ষণের কারণে সে দেশের দুবাই ও শারজাহ থেকে ঢাকাগামী মোট নয়টি ফ্লাইট বাতিল করা হয়েছে বলে জানিয়েছে যাত্রীবাহী বিমানবন্দর কর্তৃপক্ষের একজন কর্মকর্তা।
# 114    বাংলাদেশে সিরাতুন্নবী উদযাপন উপলক্ষে জাপানে বয়সভিত্তিক 'ইসলামিক কুইজ প্রতিযোগিতা ২০২৩' অনুষ্ঠিত হয়েছে। এর আগে বাংলাদেশসহ অন্যান্য দেশের মুসলিম প্রবাসী এবং তাদের সন্তানরা অংশ নেন।
# 115    মালয়েশিয়ার জোহর রাজ্যে পাঁচ বাংলাদেশিসহ ৩৮ 'অবৈধ' অভিবাসীকে আটক করেছে অভিবাসন বিভাগ। এর মধ্যে আছেন আরো তিনজন বাংলাদেশী নাগরিক, যাদের বয়স ২১ থেকে ৫৮ বছর।
# 116    লন্ডনে বাংলাদেশ হাইকমিশনের মিনিস্টার (পলিটিকাল) নাসরিন মুক্তি মারা গেছেন। যুক্তরাজ্যে নিযুক্ত বাংলাদেশের হাইকমিশনে যোগ দেওয়ার আগে তিনি সরকারের বিভিন্ন গুরুত্বপূর্ণ মন্ত্রণালয়ের কর্মকর্তা হিসেবে দায়িত্ব পালন করেছিলেন।
# 117    ইউরোপীয় ইউনিয়নের পরিসংখ্যানে দেখা গেছে, অভিবাসীদের অবৈধ প্রবেশ ঠেকাতে প্রতিনিয়তই ইউরোপে যেতে আবেদন করেন বাংলাদেশিরা। এর মধ্যে বাংলাদেশি নাগরিকদের সংখ্যা ৪০ হাজারেরও বেশি।
# 118    আফ্রিকার দেশ সুইজারল্যান্ডে বিভিন্ন জাতীয় দিবস ও নববর্ষকে ঘিরে আতশবাজির উৎসব করা হয়। দেশটির ৩২ শতাংশ খামারির অভিযোগ, যার মধ্যে তিনটি বনে কয়টি শেয়াল মারা যায়।
# 119    মালয়েশিয়ায় কুয়ালালামপুরগামী এক্সপ্রেস যাত্রীবাহী বাস দুর্ঘটনায় একজন বাংলাদেশি নিহত হয়েছেন এবং আরও অন্তত সাত জন আহত হওয়ার খবর নিশ্চিত করেছে দেশটির পুলিশ। মৃতের সংখ্যাও বাড়ছে।
# 120    যুক্তরাষ্ট্রের মিশিগান অঙ্গরাজ্যের হ্যামট্রামেক সিটির সাধারণ নির্বাচনে টানা চতুর্থবারের মতো কাউন্সিলর নির্বাচিত হয়েছেন বাংলাদেশি আমেরিকান মোহাম্মদ কামরুল হাসান। তিনি বর্তমান সিটি প্রশাসনের মেয়র প্রোটেম হিসেবে দায়িত্বে আছেন
# 121    যুক্তরাষ্ট্রের নিউইয়র্কে পুলিশে কর্মরত বাংলাদেশি-আমেরিকানদের সংগঠন 'ঢাকা-আন্তর্জাতিক অ্যাওয়ার্ড ডিনার' (বাপা)-এর নির্বাচিত হয়েছেন সেখানকার ম্যান অব দ্য ইয়ার ও ডেপুটি কমিশনার টিএম আনোয়ারুল কাদির।
# 122    ভূমধ্যসাগরীয় বিভিন্ন পথ দিয়ে ইউরোপে বাংলাদেশিদের অবৈধ অভিবাসন বেড়েছে। জাতিসংঘের শরণার্থী সংস্থার তথ্য অনুযায়ী, চলতি বছরের প্রথম ৮ মাসে এই পরিস্থিতি বেশ ভালো হয়ে উঠেছে।
# 123    মালয়েশিয়া বলছে, ৩১ মার্চের পর থেকে বাংলাদেশ ও ইন্দোনেশিয়ার সবজি শ্রমিকদের কোটা বাতিল করবে দেশটির সরকার। এ ঘাটতির কারণে এই বছরের মে বা জুন থেকেই দেশে ফিরে যাওয়ার প্রস্তুতি নিতে শুরু করেছে দেশটি।
# 124    মালদ্বীপের রাজধানী মালেতে হাজার বছরের শ্রেষ্ঠ বাঙালি জাতির পিতা বঙ্গবন্ধু শেখ মুজিবুর রহমানের ৪৮তম শাহাদাত বার্ষিকী ও জাতীয় শোক দিবস পালিত হয়েছে। এই দিবসের আয়োজন প্রবাসী বাংলাদেশিদের একযোগে কাজ করার আহ্বান জানিয়েছে
# 125    মিশরের সুউচ্চ মিনারের প্রাচীন মসজিদ আল-আজহারে বাংলাদেশসহ বিশ্বের বিভিন্ন দেশের ৩৫ হাজারেরও বেশি আন্তর্জাতিক শিক্ষার্থী পড়াশুনা করেন। তাদের মধ্যে বেশিরভাগই বাংলাদেশি।
# 126    বাংলাদেশ সফরের আমন্ত্রণে কুয়েতের নতুন আমির শেখ মেশাল আল আহমাদ আল জাবের আল সাবাহকে পৌঁছে দিয়েছেন বাংলাদেশের পররাষ্ট্রমন্ত্রী ড. এ কে আব্দুল মোমেন। এর জবাবে ইতিবাচক সাড়া দেন তিনি।
# 127    মালয়েশিয়ায় আগামীকাল ঈদুল ফিতর উদযাপিত হবে বলে ঘোষণা দিয়েছে দেশটির একজন শীর্ষস্থানীয় নেতা। তিনি বলেছেন, সরকারি ছুটি থাকবে শুক্রবার ও বৃহস্পতিবারের মধ্যে ।
# 128    সংযুক্ত আরব আমিরাতের দুবাইয়ে এনআরবি ওয়ার্ল্ড ও বিজনেস আমেরিকান ম্যাগাজিনের আয়োজনে গ্লোবাল বিজনের কনফারেন্স অনুষ্ঠিত হয়েছে। বাংলাদেশের ব্যবসায়ীরা বলেছেন, 'দেশে বিনিয়োগের মাধ্যমে দেশকে এগিয়ে নিতে বেশি সময় লাগবে না।'
# 129    ফ্রান্সে ২১ ফেব্রুয়ারি মহান ভাষা ও আন্তর্জাতিক মাতৃভাষা দিবস উপলক্ষে স্থায়ী শহীদ মিনার উদ্বোধন করা হয়েছে। এর মধ্যে একটি স্মৃতিস্তম্ভ তৈরির উদ্যোগও রয়েছে।
# 130    ভাষার মাস উপলক্ষে সংযুক্ত আরব আমিরাতে বাংলাদেশের বিলুপ্তপ্রায় আঞ্চলিক ভাষা তুলে ধরা ও বহির্বিশ্বে ভিনদেশি শিক্ষা প্রতিষ্ঠানে বাংলা পাঠদানকারী বাংলাদেশি শিক্ষকদের সম্মাননা দেওয়া হয়েছে। এর আগে কোনো সামাজিক, রাজনৈতিক বা সেবামূলক সংগঠন বাংলাদেশ
# 131    মালদ্বীপে বসবাসরত অবৈধ অভিবাসী সমস্যা সমাধানে অভিযানের সিদ্ধান্ত নিয়েছে দেশটির ইমিগ্রেশন বিভাগ। এর ফলে অভিবাসন আইন লঙ্ঘন করার অভিযোগ ওঠার কথা ঘোষণা করা হয়েছে।
# 132    কুয়েতে করোনাভাইরাসের সংক্রমণ ঠেকাতে ৪২ হাজারেরও বেশি প্রবাসীকে দেশটি থেকে ফেরত পাঠানো হয়েছে বলে জানিয়েছে দেশটির স্বরাষ্ট্র মন্ত্রণালয়। এই সংখ্যা প্রায় তিন লাখ ছাড়িয়ে গেছে বলে জানা যাচ্ছে।
# 133    কান চলচ্চিত্র উৎসবে স্থান পাওয়া বাংলাদেশি ফ্যাশন ডিজাইনার ও জুয়েলারি শিল্পী নিহারিকা মমতাজের ব্যতিক্রমী জুয়োরি পণ্য প্রদর্শিত হয়েছে দুবাইয়ে। এই প্রথমবারের মতো বাংলাদেশের ঐতিহ্য তুলে ধরা হয়েছে।
# 134    বাংলাদেশের ৫৪তম মহান স্বাধীনতা দিবস উপলক্ষে ভেনিস বাংলাদেশ প্রেসক্লাব আলোচনা ও ইফতারের আয়োজন করে। এই অনুষ্ঠানে ফিলিস্তিনিদের ওপর ইসরায়েলের গণহত্যাকে স্তম্ভিত করেছেন প্রধান উপদেষ্টা পলাশ রহমান।
# 135    ইতালি প্রবাসী বাংলাদেশিদের জন্য ই-পাসপোর্ট কার্যক্রম চালু করেছে বাংলাদেশের রাষ্ট্রদূত মো. শামীম আহসান। গত সপ্তাহে দেশটির প্রধানমন্ত্রী শেখ হাসিনা ঘোষিত স্মার্ট বাংলাদেশ তৈরি অংশ হিসেবে এই ব্যবস্থা নিয়েছেন।
# 136    কুয়েতে পৃথক সড়ক দুর্ঘটনায় দুই প্রবাসী বাংলাদেশি নিহত হয়েছে। এর মধ্যে ঢাকা ও মৌলভীবাজারের বাসিন্দাও রয়েছেন। আহতদের পরিচিত তিনজনের পরিচিতি পাওয়া গেছে।
# 137    মালয়েশিয়ায় মাটিচাপা পড়ে মারা যাওয়া ৩ জন বাংলাদেশি শ্রমিকের মরদেহ উদ্ধারের জন্য এক ঘণ্টারও বেশি সময় নিয়েছে পুলিশ। মৃতদের মেজো ভাইরাল বলছেন, তারা মাটির নিচে চাপা পড়া ছিলেন।
# 138    নিউইয়র্কে চার দিনব্যাপী আন্তর্জাতিক বাংলা বইমেলা শুরু হচ্ছে ২৪ মে। এই বইমেলায় অংশ নেবে বাংলাদেশ ও পশ্চিমবঙ্গের বাইরে বাংলা ভাষা ও সংস্কৃতির বৃহত্তম প্রকাশকরা।
# 139    যুক্তরাষ্ট্রের মিশিগান অঙ্গরাজ্যে এক ভয়াবহ সড়ক দুর্ঘটনায় মারা গেছেন সিলেটের ব্যবসায়ী জাহাঙ্গীর আলী সাজু (৫০)। হাসপাতালে চিকিৎসাধীন আছেন তার মেয়ে সানজিদা মুমু।
# 140    ড্রাগন-শো ও জমকালো উৎসবের মধ্য দিয়ে মালয়েশিয়ায় শুরু হয়েছে চীনা নববর্ষ উদযাপন। শনিবার সকালে উইসমা শহরে এটি যোগ দেন, প্রধানমন্ত্রী আনোয়ার ইব্রাহিম।
# 141    যুক্তরাষ্ট্রে বসবাসরত দ্বিতীয় প্রজন্মের সন্তানদের মাঝে বাংলা ভাষার অবস্থা পর্যবেক্ষণের জন্য একটি গবেষণা কার্যক্রম পরিচালনায় ১০ হাজার ডলার ব্যয় করা হবে বলে জানিয়েছেন আন্তর্জাতিক মাতৃভাষা ইনস্টিটিউট।
# 142    'ব্লু গ্রাস' বা নীলচে ঘাসের শহর কেন্টাকির লেক্সিংটন। সেখানে আমরা যে কয়জন বাংলাদেশি শিক্ষার্থী সবুজের প্রতিনিধিত্ব করছি, তাদের উপস্থিতিতে গান দিয়েছে রবীন্দ্রনাথের গানের সুর।
# 143    মালয়েশিয়ায় অবৈধভাবে অবস্থানরত ২৫২ বাংলাদেশিসহ ৪২৫ অভিবাসীকে আটক করেছে দেশটির ইমিগ্রেশন বিভাগ। তারা বলছেন, রেসিডেন্ট পারমিটের অপব্যবহারসহ বিভিন্ন অপরাধের অভিযোগে তাদের বিরুদ্ধে অভিযান অব্যাহত রেখা হয়েছে।
# 144    ফিলিস্তিনের গাজাবাসীদের জন্য আবারও উপহার পাঠাল বাংলাদেশিরা। আজ সোমবার রাফার উদ্দেশে যাত্রা করা একটি লরির মাধ্যমে এটি গাজার মানুষের কাছে পৌঁছাতে যাচ্ছে বলে আশ ফাউন্ডেশন জানিয়েছে।
# 145    সংযুক্ত আরব আমিরাতের ফুজাইরায় সড়ক দুর্ঘটনায় এক বাংলাদেশি নিহত হয়েছেন। তিনি চট্টগ্রামের রাউজানের মধ্যম কদলপুর ইউনিয়নের ছেলে। তার ভাই জানিয়েছেন, তারা তাকে নিবিড় পরিচর্যা কেন্দ্রে (আইসিইউ) পাঠিয়েছেন।
# 146    তীব্র গরমে কুয়েতে পাঁচ ঘণ্টা উন্মুক্ত জায়গায় কাজে নিষেধাজ্ঞা দিয়েছে দেশটির সরকার। এর আগে বিশ্বের তৃতীয় সর্বোচ্চ তাপমাত্রায় প্রথম স্থানে আছে এই দেশ।
# 147    মালয়েশিয়ায় বৈধ হতে নিবন্ধন করেছেন ৭ লাখেরও বেশি অবৈদ অভিবাসী। এর মধ্যে বাংলাদেশি নাগরিকও রয়েছেন। এদের বেশির ভাগই বাংলাদেশী, কিন্তু নথিপত্র নেই এমন কর্মীদের গ্রেপ্তার করা হবে বলে জানিয়েছে দেশটির অভিবাসন বিভাগ।
# 148    ইসরায়েলের ওপর হামলার ঘৃণ্য আক্রমণে আটকে পড়া অস্ট্রেলিয়ানদের কল্যাণ নিশ্চিত করার চেষ্টা করছে। আজ সোমবার যুক্তরাষ্ট্রের প্রধানমন্ত্রী ও বিরোধীদলীয় নেতা পিটার ডাটনের সমর্থন প্রদর্শন হচ্ছে।
# 149    ইরানের রাজধানী তেহরানে অনুষ্ঠিত বিশ্ব কোরআন প্রতিযোগিতায় প্রথম স্থান অর্জন করেছে বাংলাদেশি কিশোর বশির আহমাদ। গত ১০ দিন আগে ঢাকার মারকাজুত তাহফিজ ইন্টারন্যাশনাল মাদরাসার অধ্যক্ষ নেছার আহমদ-আন-নাছিরী
# 150    মালয়েশিয়ার একটি আদালত সাত শতাধিক বাংলাদেশি কর্মীকে চাকরি দেওয়ার নামে তাদের সঙ্গে প্রতারণা করার অভিযোগে নিয়োগকর্তাকে বকেয়া বেতনের অর্ধেক পরিশোধের নির্দেশ দিয়েছে। এর মধ্যে তারা কর্মসংস্থান নিশ্চিত করতে রাজি হয়েছেন।
# 151    অস্ট্রেলিয়ায় দুই বন্ধুর হত্যাকাণ্ডের প্রায় এক সপ্তাহ পর আজ মঙ্গলবার তাদের মরদেহ উদ্ধার করা হয়েছে। মৃতদেহের অবস্থান সম্পর্কে গোয়েন্দা সুপারিনটেনডেন্ট ড্যানি ডোহার্টি গণমাধ্যমকে জানিয়েছেন।
# 152    মালয়েশিয়ায় দ্বিতীয় নিবাস গড়ার 'মালয়শিয়া মাই সেকেন্ড হোম' কর্মসূচিতে অংশগ্রহণকারীদের তালিকায় চতুর্থ অবস্থানে রয়েছে বাংলাদেশিরা, যাদের মধ্যে দক্ষিণ কোরিয়ার প্রথম বাংলাদেশি।
# 153    কুয়েতে থেকে দেশে সফরে যাওয়ার আগে প্রত্যেক প্রবাসীকে ট্রাফিক জরিমানা থাকলে সেটি পরিশোধ করতে হবে বলে একটি নতুন আইন জারি করেছে দেশটির সরকার। কিন্তু এই আইনের সঙ্গে সংযুক্ত ব্যক্তিদের মধ্যে যোগাযোগ নেই।
# 154    মালয়েশিয়ায় ১৩ বছরের সৎ মেয়েকে ধর্ষণের দায়ে বাবুল হোসেন নামে এক প্রবাসী বাংলাদেশিকে ২২বছর জেল ও ১৫টি বেত্রাঘাতের সাজা দিয়েছেন সেখাকার আদালত। এই অভিযোগে গ্রেপ্তার হয়েছেন তারা।
# 155    যথাযোগ্য মর্যাদা ও বিপুল উৎসাহ উদ্দীপনার মধ্য দিয়ে মহান স্বাধীনতা যুদ্ধের বিজয় দিবস উদযাপন করেছে জাপানে বাংলাদেশ দূতাবাস। এ উপলক্ষে বাংলাদেশের রাষ্ট্রপতি, প্রধানমন্ত্রী ও পররাষ্ট্রমন্ত্রীর প্রদত্ত বাণী পাঠ করা হয়।
# 156    মিশরের রাজধানী কায়রো এবং ভূমধ্যসাগরীয় শহর আলেকজান্দ্রিয়ায় সড়ক সংঘর্ষের ঘটনায় অন্তত ৩৫ জন নিহত হয়েছে বলে দেশটির সরকারি তথ্য অনুযায়ী। এতে আহত হচ্ছে ৫০ জনের বেশি।
# 157    বাংলাদেশের প্রবাসীদের দেশে ফেরাতে বিমানের ফ্রি টিকিট দিয়েছে বঙ্গবন্ধু ফাউন্ডেশন মালয়েশিয়া শাখা। সংগঠনের নেতাদের পক্ষে হাইকমিশনের মিনিস্টার নাজমুস সাদাত সেলিমকে ফুলেল শুভেচ্ছা জানানো হয়েছে।
# 158    ভারত মহাসাগরের দেশ মালদ্বীপের নতুন প্রেসিডেন্ট হওয়ার পথে এগিয়ে আছেন মোহাম্মদ মুইজ্জোর রাজনৈতিক দল প্রোগ্রেসিভি পার্টি অব দ্য মাল দ্বীপ (পিপিএম) নেতৃত্বাধীন জোট।
# 159    ইসরাইল-ফিলিস্তিন যূদ্ধে গাজায় কয়েক হাজার মানুষের মৃত্যুতে সহমর্মিতা জানাতে মার্কিন যুক্তরাষ্ট্রের মিশিগান রাজ্যের একটি রাস্তা 'প্যালেস্টাইন অ্যাভিনিউ' নামে নামকরণ করা হয়েছে।
# 160    মালয়েশিয়ায় মাদক বহনের দায়ে মৃত্যুদণ্ড থেকে রেহাই পেয়েছেন এক বাংলাদেশি নাগরিক। এই মামলায় আরো দুই জনের সাজা কমিয়ে রায় দিয়েছে দেশটির আপিল বিভাগ। এদের মধ্যে একজনের বিরুদ্ধে আনা অভিযোগ ত্রুটি ছিল।
# 161    অস্ট্রেলিয়া ফিলিস্তিনিদের ৮৬০টি অস্থায়ী মানবিক ভিসা দিয়েছে বলে জানিয়েছেন দেশটির পররাষ্ট্রমন্ত্রী পেনি ওং। এর মধ্যে ইসরায়েলের সঙ্গে সংঘর্ষে অন্তত ৬৭ জন নিরাপদে বেরিয়ে এসেছেন।
# 162    প্রবাসে পাঠক আগ্রহ সৃষ্টি ও মানসম্পন্ন লেখক তৈরির লক্ষ্যে সংযুক্ত আরব আমিরাতে ৩ দিনব্যাপী 'বাংলাদেশ বইমেলা ও বিজয় উৎসব'র দ্বিতীয় দিনে জমে উঠেছে মেলা। দর্শনার্থীদের ভিড় বেড়েছে।
# 163    মালয়েশিয়ার পেনাং রাজ্যে একটি নির্মাণাধীন ভবন ধসে নিহত বাংলাদেশি শ্রমিকের পরিচয় পাওয়া গেছে। এ ঘটনায় আহত হয়েছেন আরেকজন হাসপাতালে চিকিৎসা দেওয়া হচ্ছে বলে জানিয়েছে বাংলাদেশ হাইকমিশন।
# 164    শ্রদ্ধা, ভালোবাসা এবং রাষ্ট্রীয় মর্যাদায় স্বাধীন বাংলাদেশের স্থপতি জাতির পিতা বঙ্গবন্ধু শেখ মুজিবুর রহমানের ১০৪তম জন্মবার্ষিকী ও জাতীয় শিশু দিবস উদযাপিত হয়েছে। জাতিসংঘের প্রতিষ্ঠাতা রাষ্ট্রদূত শাহাবুদ্দিন আহমেদ এই বক্তব্যের ক
# 165    গাজা উপত্যকায় মার্কিন আণবিক বোমা হামলার বার্ষিকী পালনের অনুষ্ঠানে জাপানে নিযুক্ত ইসরায়েলি রাষ্ট্রদূতকে আমন্ত্রণ না জানানোর সিদ্ধান্ত নিয়েছে নাগাসাকি শহরের মেয়র সুযুকি শিরো।
# 166    ফিলিস্তিন-ইসরায়েল যুদ্ধে গাজার লাখো মানুষ ঈদের উপহার ও আর্থিক সহায়তা পেয়েছে মিশরে অধ্যয়নরত বাংলাদেশি শিক্ষার্থীদের পরিচালিত ওয়ার্ল্ড ওয়ান উম্মাহ ফাউন্ডেশনের সভাপতি হুজাইফা খান।
# 167    মালয়েশিয়ার রাজধানী কুয়ালালামপুর পাইকারি বাজারে অভিযান চালিয়ে ১৯ বাংলাদেশিসহ ১০৬ জন অবৈধ অভিবাসীকে আটক করা হয়েছে। শনিবার ভোরে পুলিশের জেনারেল অপারেশন ফোর্স এবং ফেডারেল রিজার্ভ ইউনিট (এফআরইউ) ও ইমিগ্রেশন বি
# 168    সৌদি আরবে সড়ক দুর্ঘটনায় বাংলাদেশি একটি পরিবারের ৩ সদস্য নিহত হয়েছেন। রিয়াদে বাংলাদেশ দূতাবাস নিশ্চিত করেছে, তারা এখন চিকিৎসাধীন অবস্থায় রয়েছেন বলে জানিয়েছে স্থানীয় গণমাধ্যম।
# 169    'শেখ রাসেল দীপ্তিময়, নির্ভীক নির্মল দুর্জয়, এই অনুভূতিকে সামনে রেখে জাতির পিতা বঙ্গবন্ধু শেখ মুজিবুর রহমানের ছোট ছেলে শেখে রাসেলের ৬০তম জন্মবার্ষিকী' পালিত হয়েছে মিশরে।
# 170    দক্ষিণ আফ্রিকায় সড়ক দুর্ঘটনায় এক বাংলাদেশি ব্যবসায়ী নিহত হয়েছেন। স্থানীয়রা বলছেন, তিনি এখনো জীবিত রয়েছেন বলে আশঙ্কা করা হচ্ছে বলে তারা জানাচ্ছেন বলে জানা গেছে। এ ঘটনার পর তাকে দ্রুত হাসপাতালে চিকিৎসা দেয়া হয়েছে।
# 171    মালয়েশিয়ার রাজধানী কুয়ালালামপুর থেকে ৩৩০ জন অবৈধ অভিবাসীকে আটক করেছে দেশটির ইমিগ্রেশন পুলিশ। এদের মধ্যে বেশ কয়েকজন নারী ও পুরুষও রয়েছেন। তারা নিজ দেশে ব্যবসা করছেন।
# 172    আগামী ৩০ জুন সিডনিতে অনুষ্ঠিত হতে যাচ্ছে অস্ট্রেলিয়াভিত্তিক বাংলা মিডিয়া সংস্থা বাসভূমির ২০ বছর পূর্তি উৎসব। কিন্তু আয়োজকরা বলছেন, এই অনুষ্ঠানে অংশগ্রহণ করবেন প্রায় ৭০ জন স্থানীয় বাংলাদেশি শিল্পী।
# 173    বাংলাদেশে বঙ্গবন্ধু শেখ হাসিনাকে নিয়ে স্বরচিত কবিতা আবৃত্তি করেন সুহৃদ সোহান হক। তিনি বলেছেন, 'প্রবাসীরা বাংলাদেশের অর্থনীতিতে একটি গুরুত্বপূর্ণ ভূমিকা পালন করছেন।'
# 174    ঘুষের বিনিময়ে বাংলাদেশি কর্মী ও পর্যটকদের ভিসা দেওয়ার অভিযোগে সন্দেহভাজন ২ জনকে গ্রেপ্তার করেছে মালয়েশিয়ার দুর্নীতি দমন কমিশন। তাদের ৪ দিনের রিমান্ড মঞ্জুর করা হয়েছে।
# 175    বিপুল বিনিয়োগের বিনিময়ে বিদেশিদের স্থায়ী বসবাসের অনুমতি, অর্থাৎ 'গোল্ডেন ভিসা' কর্মসূচি বাতিলের সিদ্ধান্ত নিয়েছে অস্ট্রেলিয়া। এর ফলে দেশটির অভিবাসন ব্যবস্থায় কার্যকরী কোনো ভূমিকা ছিল না।
# 176    দক্ষিণ আফ্রিকার নর্থওয়েস্ট প্রদেশের ব্রিটস এলাকায় স্থানীয় এক ব্যক্তির ছুরিকাঘাতে এক বাংলাদেশি ব্যবসায়ী নিহত হওয়ার ঘটনায় প্রবাসীদের মধ্যে বাকবিতণ্ডা তৈরি হয়েছে বলে জানা গেছে।
# 177    বাংলাদেশের লেখক ও সাংবাদিক হাসান ফেরদৌসের ৩৩তম 'নিউইয়র্ক আন্তর্জাতিক বাংলা বইমেলার' আহ্বায়ক নির্বাচন করা হয়েছে। মেলাটি বাংলাদেশ ও ভারতের অন্তত ৪০টি প্রকাশনা সংস্থা এই মেলায় অংশ নেবে।
# 178    বাংলাদেশের রাজধানী লিসবনে মনোজ্ঞ সাংস্কৃতিক সন্ধ্যা, স্মৃতিচারণ ও অতিথিদের ফুল দিয়ে বরণের মাধ্যমে অনুষ্ঠিত হয়েছে পর্তুগাল বাংলা প্রেসক্লাবের নবগঠিত ৩য় কমিটি (২০২৩-২০২৪) এর অভিষেক অনুষ্ঠান।
# 179    মালয়েশিয়ায় অবৈধ অভিবাসীদের বিরুদ্ধে অভিযানের অংশ হিসেবে আজ বৃহস্পতিবার বাংলাদেশিসহ অন্তত ৫০০ বিদেশিকে গ্রেপ্তার করা হয়েছে বলে জানিয়েছে দেশটির পুলিশ। এর মধ্যে কোন দেশের কতজন নাগরিক রয়েছে তা নিয়ে এখনো কিছু জানা যায়নি
# 180    অস্ট্রেলিয়ায় প্রবাসী বাংলাদেশিদের সাংবাদিক সংগঠন 'অস্ট্রেলিয়া বাংলাদেশ জার্নালিস্ট অ্যাসোসিয়েশন' সিডনির হার্স্টভিল এন্টারটেইনমেন্ট সেন্টারে মহান বিজয় দিবস উদযাপন করেছে। এই অনুষ্ঠানে অতিথিদের মধ্যে নতুন প্রজন্মের এক কিশোরের বে
# 181    অস্ট্রেলিয়ার সিডনিতে গত শনিবার হামলাকারীর ছুরিকাঘাতে ছয় জন নিহতের ঘটনায় পুলিশ গণমাধ্যমকে বলেছে, হত্যাকারী পুরুষদের এড়ানো নারীদের লক্ষ্যবস্তু করেছে।
# 182    যুক্তরাষ্ট্রের মিশিগানে ওয়ারেন সিটি পুলিশের গুলিতে এক বাংলাদেশি তরুণ নিহত হয়েছেন। স্থানীয় গণমাধ্যমে এ ঘটনা নিয়ে তদন্ত শুরু হচ্ছে বলে জানা যাচ্ছে। ওই তরুণের পরিবারের পক্ষ থেকে ফোন করে তাকে মৃত ঘোষণা করা হয়েছে।
# 183    কেন্টাকির লেক্সিংটন শহরে আমার পরবর্তী উচ্চশিক্ষার জন্য ২২ মাসের একটি ফ্লাইট ধরে নিচ্ছি। এই যাত্রাপথের সুখস্মৃতিগুলো জমিয়ে রাখা হয়েছে এক বাঙ্গালি শিক্ষানবিশের সঙ্গে।
# 184    কিরগিজস্তানের রাজধানী বিশকেকে বাংলাদেশ, ভারত ও পাকিস্তানের শিক্ষার্থীদের ওপর সহিংস জনতা হামলা চালিয়েছে বলে খবর পাওয়া গেছে। শনিবার সন্ধ্যায় ইউএনবিকে বলেছে, এখন তারা তাদের নিরাপত্তার জন্য সহায়তা চেয়েছেন।
# 185    যুক্তরাষ্ট্রের মিশিগান অঙ্গরাজ্যের হ্যামট্রামিক সিটির প্রাইমারি নির্বাচনে ৩ জন বাংলাদেশি-আমেরিকান বিজয়ী হয়েছেন। এর মাধ্যমে তারা আগামী ৭ নভেম্বর অনুষ্ঠেয় সাধারণ বা চূড়ান্ত নির্বাচন করার যোগ্যতা অর্জন করেছেন।
# 186    মালয়েশিয়ায় বাংলাদেশিসহ ১৫৮ জন অভিবাসীকে আটক করেছে দেশটির অভিবাসন বিভাগ। তাদের মধ্যে বেশ কয়েকজন বাংলাদেশিও রয়েছেন। তারা তিনটি দেশের নাগরিক বলে মনে করা হচ্ছে। তবে কোন দেশে বসবাস করতে পারেননি।
# 187    সৌদি আরবের রাজধানী রিয়াদে জাতির জনক বঙ্গবন্ধু শেখ মুজিবুর রহমানের ৪৮তম শাহাদত বার্ষিকী ও জাতীয় শোক দিবস পালিত হয়েছে। জাতিসংঘের রাষ্ট্রদূত মোহাম্মদ জাবেদ পাটোয়ারী বলেছেন, 'জাতির পিতা ছিলেন বাঙালি জাতি
# 188    অস্ট্রেলিয়ার পররাষ্ট্রমন্ত্রী পেনি ওং ইসরায়েলকে গাজায় বোমাবর্ষণ বন্ধের আহ্বান জানিয়েছেন। তিনি বলেছেন, সেখানে ক্রমবর্ধমান মৃতের সংখ্যা সত্ত্বেও আপনারা বৈধতা প্রবেশের জন্য প্রস্তুত।
# 189    অস্ট্রেলিয়ার বাণিজ্যনগরী সিডনির বন্ডাই জংশনে ওয়েস্টফিল্ড শপিং সেন্টারে হামলাকারীর ছুরিকাঘাতে মারাত্মক আহত হন এক নারী এবং তার ছোট্ট মেয়েকে বাঁচানোর জন্য আপ্রাণ চেষ্টা করেছিলেন অ্যাশলি গুড।
# 190    মিশরে আশ্রয় নেওয়া ফিলিস্তিনি শরণার্থী শিশুদের নিয়ে ঈদ আনন্দ উদযাপন করেছেন বাংলাদেশি শিক্ষার্থীরা, যাদের পরিবারগুলোকে আর্থিক সহায়তার মাধ্যমে তাদের পছন্দের খাবার ও পানীয় দিয়ে আপ্যায়ন করা হয়।
# 191    মালয়েশিয়া ইমিগ্রেশনের মহাপরিচালক রুসলিন জুসোহ বলেছেন, বিদেশি শ্রমিকরা মালয় নারীদের বিয়ে করলে তাদের বিতাড়িত করা হবে। এমনকি অমুসলিম দম্পতিদের বিবাহবিচ্ছেদ বাতিল করতে হবে বলে সিভিল হাইকোর্টের মাধ্যমে নিষ্পত্তি
# 192    মালয়েশিয়ায় একটি সড়ক দুর্ঘটনায় তিনজন বাংলাদেশি নিহত হয়েছেন। আরেকজন গুরুতর আহত হওয়ার খবর নিশ্চিত করেছে দেশটির পুলিশ। এর মধ্যে একজন আরো মারা যাচ্ছেন বলে জানা গেছে।
# 193    বাংলাদেশের রাজধানী এথেন্সের ওমোনিয়ায় হিন্দু ধর্মাবলম্বীদের শারদীয় দুর্গাপূজা উদযাপনের উদ্দেশ্যে সবাইকে শুভেচ্ছা জানিয়েছেন গ্রিসপ্রবাসী বাংলাদেশি মুসলিমদের সংগঠন 'হিন্দু কমিউনিটি ইন্টারন্যাশনাল'।
# 194    দক্ষিণ এশীয় আঞ্চলিক সহযোগিতা সংস্থার (সার্ক) মহাসচিব হিসেবে দায়িত্ব গ্রহণ করেছেন বাংলাদেশ সরকারের রাষ্ট্রদূত মো. গোলাম সারোয়ার। এর আগে তিনি আন্তর্জাতিক ফোরামে বাংলাদেশের প্রতিনিধিত্ব করেন।
# 195    প্রতি বছরের মতো এবারও জাপানে মুন্সিগঞ্জ-বিক্রমপুর সোসাইটির ইফতার মাহফিল অনুষ্ঠিত হয়েছে। এতে অংশ নেওয়া প্রবাসীদের সঙ্গে একাত্মতা জানিয়েছে জাপান দূতাবাস। এর আগে বাংলাদেশের রাষ্ট্রদূত শাহাবুদ্দিন আহমেদ সস্ত্রীক এবং বাংলাদেশি
# 196    মালয়েশিয়ার জোহর রাজ্যের অভিবাসন বিভাগ ৩৯ বাংলাদেশিকে ফেরত পাঠিয়েছে। অপরাধের সাজা শেষে তাদের সরাসরি কুয়ালালামপুর বিমানবন্দরে নিয়ে যাওয়া হয়েছিল বলে জানিয়েছে তারা। তবে সেখানে নিষেধাজ্ঞা আরোপ করা হয়েছে।
# 197    বাংলাদেশের গণতন্ত্র এবং মানবাধিকার বিষয়ক একটি আন্তর্জাতিক সেমিনার অনুষ্ঠিত হয়েছে ইউরোপীয় পার্লামেন্টে। এই সেমিনারে বক্তব্য দেন বেশ কয়েকজন শীর্ষ নীতিনির্ধারক ও আইনজীবী।
# 198    গ্রিসের উত্তরাঞ্চলে ৪ দিন ধরে জ্বলতে থাকা বনের ভেতর থেকে ১৮ জনের মরদেহ উদ্ধার করা হয়েছে। এদের মধ্যে বেশ কয়েকজন ইভ্রোস অঞ্চলের বাসিন্দা রয়েছেন।
# 199    বাংলাদেশে আগামীকাল ৭ জানুয়ারি রোববার অনুষ্ঠিত হচ্ছে দ্বাদশ জাতীয় সংসদ নির্বাচনে প্রবাসী বাংলাদেশিরা তাদের নিজ নির্বাচনী এলাকায় ভোট দেয়ার বিষয়ে তেমন আগ্রহী নেই বলে জানিয়েছেন সরকারের কর্মকর্তারা।
# 200    ঢাকা-কুয়ালালামপুর রুটে আজ শুক্রবার সন্ধ্যা সোয়া ৭টায় বিশেষ অতিরিক্ত ফ্লাইট পরিচালনা করবে বিমান বাংলাদেশ এয়ারলাইনস। যাত্রীদের সুবিধার কথা বিবেচনা করে বিমানে টিকেট কেনা যাবে।
# 201    কুয়েতের দক্ষিণাঞ্চলীয় মানগাফ শহরে একটি আবাসিক ভবনে অগ্নিকাণ্ডে ৪১ জন নিহত হয়েছেন। পুলিশ বলছে, ভবনটিতে কোনো বাংলাদেশি কর্মী থাকার ব্যাপারে এখন পর্যন্ত তথ্য নেই।
# 202    অস্ট্রেলিয়ার জনসংখ্যা গত ১২ মাসের মধ্যে সবচেয়ে বেশি বৃদ্ধি পেয়েছে বলে দেশটির সরকারের একটি প্রতিবেদনে উল্লেখ করা হয়েছে। এই প্রথম পরিসংখ্যান প্রকাশিত হওয়ার পর থেকেই নতুন করে উঠে এসেছিলো।
# 203    যথাযোগ্য মর্যাদায় ফিনল্যান্ডে উদযাপিত হলো মহান শহীদ দিবস ও আন্তর্জাতিক মাতৃভাষা দিবসের। জাতিসংঘের দাপ্তরিক ভাষা হিসেবে প্রচলন করার দাবি জানিয়েছেন বিবিসি নিউজ।
# 204    অস্ট্রেলিয়ার সিডনিতে আজ শনিবার ফিলিস্তিনের পক্ষে বিক্ষোভ সমাবেশ অনুষ্ঠিত হয়েছে। গত সপ্তাহে গাজায় ইসরায়েলের গণহত্যাকে সমর্থন করে তারা এবার একটি প্রতিবাদ মিছিলে যোগ দেন।
# 205    বাংলাদেশি প্রবাসীদের আঞ্চলিক সংগঠন মুন্সীগঞ্জ-বিক্রমপুর সোসাইটি, জাপানের ঈদ পুনর্মিলনী অনুষ্ঠিত হয়েছে। স্থানীয় দূতাবাসের ঊর্ধ্বতন কর্মকর্তারা সপরিবারে অনুষ্ঠানে অংশ নেন।
# 206    অস্ট্রেলিয়ার সিডনিতে গাড়ির নিয়ন্ত্রণ হারিয়ে বাংলাদেশি বংশোদ্ভূত এক কিশোর নিহত হয়েছে। এ ঘটনায় প্রাণ হারান একজন প্যারামেডিক নাগরিক। এরপর তাকে হত্যা করা হয়েছে বলে অভিযোগ উঠেছে।
# 207    আন্তর্জাতিক মাতৃভাষা দিবস উপলক্ষে অস্ট্রেলিয়া বাংলাদেশ জার্নালিস্ট অ্যাসোসিয়েশনের আয়োজন করা একটি অনুষ্ঠানে ফিলিস্তিনে নিহত সাংবাদিকদের মৃত্যুতে শোক প্রস্তাব করেছে সংগঠনের সহ-সভাপতি মোহাম্মদ আব্দুল মতিন।
# 208    করোনাভাইরাসের সংক্রমণ ঠেকাতে প্রবাসীরা যেন নিজ মাতৃভাষায় সতর্কতামূলক নির্দেশিকা দেখতে পারেন, সেটা নিয়ে তীব্র প্রতিক্রিয়া দেখা দিয়েছে জাপানের কিতা সিটি কর্তৃপক্ষ।
# 209    বাংলাদেশে ১৯৭৫ সালের ১৫ আগস্ট বঙ্গবন্ধু শেখ মুজিবুর রহমানের হত্যাকাণ্ডের ইতিহাসের সবচেয়ে গুরুত্বপূর্ণ ঘটনাগুলোর একটি হিসেবে পরিণত হয়েছে সংযুক্ত আরব আমিরাতে ।
# 210    অস্ট্রেলিয়ার সিডনিতে দ্বিতীয় বাৎসরিক জাতীয় কোরআন তেলাওয়াত প্রতিযোগিতা ২০২৪ এ প্রথম হয়েছে বাংলাদেশি বংশোদ্ভূত ওয়েস্টার্ন কিশোর ফারহান জাহিন। এরপর তিন হাজার ডলারের পুরস্কার বিতরণী অনুষ্ঠানও অনুষ্ঠিত হয়েছে।
# 211    বাংলাদেশের উত্তর-পূর্বাঞ্চলীয় জেলা সেলাঙ্গর রাজ্যের পুলিশ বলছে, কমলার জুস খাওয়া নিয়ে দ্বন্দ্বের জেরে বাংলাদেশি সহকর্মীকে ছুরিকাঘাতে হত্যার অভিযোগ উঠেছে এক পাকিস্তানির বিরুদ্ধে।
# 212    অবৈধভাবে মালয়েশিয়ায় প্রবেশের অভিযোগে ২০ বাংলাদেশিসহ ৩৬ বিদেশিকে গ্রেপ্তার করেছে দেশটির ইমিগ্রেশন বিভাগ। তাদের মধ্যে কয়েকজনকে আগের অপরাধের জন্য কালো তালিকাভুক্ত করা হয়েছিল।
# 213    'যত বই, তত প্রাণ' স্লোগান নিয়ে অনুষ্ঠিত হতে যাচ্ছে ৩৩তম নিউইয়র্ক আন্তর্জাতিক বাংলা বইমেলা। এই মেলায় অংশগ্রহণ করবেন লেখক সাহিত্যিক হাসান ফেরদৌস এবং কবি কাজী নজরুল ইসলাম।
# 214    'গণগ্রেপ্তারের কারণে প্রধানমন্ত্রী শেখ হাসিনাকে তার পঞ্চম মেয়াদে ক্ষমতায় বসানোর নিশ্চয়তা দিতে নির্বাচন হচ্ছে বাংলাদেশে। প্রধান বিরোধী দল বিএনপি দাবি করছে যে তারা সরকারের বিরুদ্ধে মানবাধিকার লঙ্ঘনের অভিযোগ রয়েছে।'
# 215    মালয়েশিয়ার তেরেঙ্গানু রাজ্যে জালিয়াতির মাধ্যমে বিয়ে করে স্থানীয় নারীদের বিদেশিরা শোষণ করছে বলে অভিযোগ পেয়েছে রাজ্যের ইমিগ্রেশন বিভাগ। এ ঘটনায় বিদেশি পুরুষদের সঙ্গে বিবাহ বন্ধনে আবদ্ধ হওয়া দম্পতিদের সামাজিক ভিজিট পাস পু
# 216    অস্ট্রেলিয়ার সিডনি নগরীতে গতকালের সন্ধ্যাটি ছিল শুধুই বাংলাদেশিদের। হাছন রাজার জীবনীভিত্তিক নাটিকা 'পিঞ্জিরা'-এর সঙ্গে স্থানীয় শিল্পী দীপ্তি রাজবংশীর অনন্য পরিবেশনা দর্শকদের মুগ্ধ করেছে।
# 217    বাংলাদেশে পবিত্র রমজান মাসে অতিথিদের উপস্থিতির জন্য অস্ট্রেলিয়া-বাংলাদেশ বিজনেস কাউন্সিলের উদ্যোগে ইফতার ও নৈশভোজের অনুষ্ঠানের সমাপ্তি ঘোষণা করেছে সংগঠনটির সভাপতি ড. মুনিরুজ্জমান জয়।
# 218    মালয়েশিয়ায় অব্যবহৃত বাংলাদেশি কর্মীদের নিয়োগে বন্ধ হচ্ছে সিন্ডিকেট প্রথা। আরও বিদেশি শ্রমিকদের দেশে প্রবেশের নিয়ম শিথিল করছে দেশটির সরকার। নতুন কোটা বাতিল করেছে পুত্রজায়া।
# 219    ইউরোপের দেশ আলবেনিয়া থেকে সীমান্ত পাড়ি দিয়ে গ্রিসে অনুপ্রবেশের সময় এক বাংলাদেশি অভিবাসীর মৃত্যু হয়েছে বলে জানিয়েছে সুনামগঞ্জের জগন্নাথপুর উপজেলার গুতগাঁও গ্রামের একজন ব্যক্তি। গত ২৩ এপ্রিল তার মরদেহ আলবেনিয়ার মাদার তেরেসা হাসপাতালের
# 220    বর্ণাঢ্য অনুষ্ঠানের মাধ্যমে গতকাল সিডনিতে আন্তর্জাতিক নারী দিবস পালন করেছে উইমেন কাউন্সিল অস্ট্রেলিয়া। বৃহত্তর বাংলাদেশি কমিউনিটিতে বিশেষ অবদান রাখার জন্য ৬ জনকে ক্রেস্ট দেওয়া হয়েছে।
# 221    বাংলাদেশের চট্টগ্রাম বিশ্ববিদ্যালয়ের ছাত্র নেওয়াজ মোহাম্মদ সাইফুল্লাহ রুমন অস্ট্রেলিয়ার উলংগং সমুদ্র সৈকতে মৃত্যুর পর উদ্ধার করা হয়েছে তার মরদেহ। এ ঘটনা ঘটেছে নিউ সাউথ ওয়েলসের উপকূল থেকে।
# 222    জাপানের প্রধানমন্ত্রী কিশিদা ফুমিও মন্ত্রিপরিষদে রদবদলের ঘোষণা দিয়েছেন। দেশটির প্রধান ক্ষমতাসীন দল ডেমোক্রেটিক পার্টির সাথে সম্পর্কিত একটি রাজনৈতিক তহবিল কেলেঙ্কারিতে জড়িত থাকার অভিযোগে তাকে অপসারণ করেছেন তিনি।
# 223    দীর্ঘ এক মাস সিয়াম সাধনার পর মুসলিম বিশ্বে আনন্দের বার্তা নিয়ে হাজির হয়েছে পবিত্র ঈদুল ফিতর। এই ধর্মীয় উৎসবকে ঘিরে মিশরে বসবাসরত প্রবাসী বাংলাদেশিদের সঙ্গে যোগ দেন মিশরীয় মুসল্লিরা।
# 224    দক্ষিণ আফ্রিকার জোহান্সবার্গে ডাকাতের গুলিতে গুরুতর আহত এক প্রবাসী বাংলাদেশি মৃত্যুর পর তাকে দেশে পাঠানোর ব্যবস্থা করা হচ্ছে বলে জানিয়েছে মানবাধিকার সংগঠন বুড্ডিস্ট কমিউনিটি।
# 225    মালয়েশিয়ায় বসবাসরত প্রবাসী বাংলাদেশিদের সহজ ও দ্রুততর সময়ে পাসপোর্ট প্রদানের জন্য উন্নত অনেক দেশের আদলে আউটসোর্সিং চালু করার সিদ্ধান্ত নিয়েছে বাংলাদেশের হাইকমিশন ও এক্সপ্যাট সার্ভিসেস লিমিটেড।
# 226    মালয়েশিয়ার নতুন রাজা হিসেবে ইব্রাহিম সুলতান ইস্কান্দারের নাম ঘোষণা করেছে দেশটির রয়্যাল সিলের রক্ষক। এর আগে সিংহাসনে বসেছিলেন জোহর দারুল তাজিমের ভাই।
# 227    করোনাভাইরাস মহামারির বিপর্যয় থেকে অর্থনীতি সচল করতে বাংলাদেশসহ ১৫টি দেশের জন্য ২০২২ সালে মালয়েশিয়ার শ্রমবাজার পুনরায় খুলে দেওয়া ছিল আনন্দের খবর। কিন্তু বাংলাদেশের অভিবাসী শ্রমিকদের ভাগ্যান্বেষণে আসা অনেকেই এখন বেকার, বেতন নেই
# 228    পবিত্র রমজান মাসের তৃতীয় দিনে অসহায় গাজবাসীদের সাহায্যার্থে 'হেল্প গাজা' প্রচারাভিযানের ধারাবাহিকতায় বাংলাদেশসহ বিশ্বের ৮০টি দেশ থেকে ত্রাণ সামগ্রী পাঠানোর উদ্যোগ নিয়েছে বাংলাদেশ।
# 229    কিরগিজস্তানের রাজধানী বিশকেকে বাংলাদেশি, ভারতীয় ও পাকিস্তানিসহ বিদেশি শিক্ষার্থীদের ওপর সহিংস জনতার হামলার ঘটনায় বাংলাদেশিদের নিজে নিজ আবাসস্থলের ভেতরে থাকার পরামর্শ দিয়েছে পররাষ্ট্র মন্ত্রণালয়।
# 230    বাংলাদেশের স্বাধীনতা অর্জনের ৪৮তম বার্ষিকী পালন উপলক্ষে মালয়েশিয়ায় আয়োজন করা হয়েছে জাতীয় শোক দিবসের আলোচনা সভায় বঙ্গবন্ধু শেখ মুজিবুর রহমানের ওপর নির্মিত বিশেষ প্রামাণ্যচিত্র প্রদর্শন।
# 231    মালয়েশিয়ার জোহর রাজ্যে পৃথক এক অভিযানে ৮৫ বাংলাদেশিকে আটক করেছে অভিবাসন বিভাগ, যাদের বেশ কয়েকটি খাদ্য ও বিভিন্ন প্রাঙ্গণে একই সঙ্গে ইমিগ্রেশন অফিসারদের সমন্বয়ে চালানো হয়েছে।
# 232    জাপানের আকাশে মঙ্গলবার শাওয়াল মাসের চাঁদ দেখা যায়নি এবং আগামীকাল বুধবার ঈদুল ফিতর উদযাপন করবে জাপান। এর আগে থেকেই এ ঘোষণা দেওয়া হয়েছিল যে, এবারের উল্টো দিনের ছুটি শেষ হবে।
# 233    কানাডার অন্টারিওর ওয়েন সাউন্ড শহরে দুর্বৃত্তের হামলায় এক বাংলাদেশি-কানাডিয়ান রেস্টুরেন্ট ব্যবসায়ী নিহত হয়েছেন। সিসিটিভি ফুটেজ দেখা গেছে তাকে হাসপাতালে ভর্তি করতে হয়েছে।
# 234    মিশরে প্রতি বছর ফেরাউনিক ঐতিহ্য ঋতুরাজ 'শাম-এল-ন্যাসিম' (বাতাসের সুঘ্রাণ) নামে একটি উৎসব উদযাপন করা হয়। এই দিনে সূর্য ওঠার সঙ্গে মিশরীয় পরিবারগুলো ফেশিখ বা রিংগা মাছ,
# 235    কুয়েতে এক সড়ক দুর্ঘটনায় এক বাংলাদেশি নিহত হয়েছেন। মৃত্যুর খবর নিশ্চিত করেছে তার নিকটাত্মীয়রা। এ ঘটনার পর তিনি দ্রুত দেশে পাঠানো হবে বলে আশঙ্কা করা হচ্ছে বলে তারা জানিয়েছেন।
# 236    মালয়েশিয়ায় পাসের অপব্যবহার, অতিরিক্ত অবস্থান এবং কোনো বৈধ ভ্রমণ নথিপত্র না থাকার অপরাধে জড়িত ২৪৫ জন অভিবাসীকে গ্রেপ্তার করেছে দেশটির অভিবাসন বিভাগ ।
# 237    অস্ট্রেলিয়াকে ইসরায়েলের সঙ্গে সম্পর্ক ছিন্ন করার দাবি জানিয়েছে 'ফিলিস্তিন অ্যাকশন গ্রুপ'। তারা সিডনি এবং মেলবোর্ন জুড়ে বেশ কয়েকটি গুরুত্বপূর্ণ সরকারি ভবনে মিছিল করেছে।
# 238    'যেকোনো নাগরিককে বয়স বা লিঙ্গ নির্বিশেষে তাদের পাসপোর্ট ও আইডি কার্ড দিয়ে সম্পূর্ণ সজ্জিত ও বসবাসের জন্য প্রস্তুত এমন ৮০ লাখ পরিত্যক্ত বাড়ি বিনামূল্য কিংবা নামমাত্র মূল্যে দিচ্ছে জাপান সরকার।'
# 239    অস্ট্রেলিয়ায় সংবাদ সেবা বন্ধ করার সিদ্ধান্ত নিয়েছে ফেসবুক। এই ঘোষণায় সরকার ক্ষোভ প্রকাশ করেছে এবং সামাজিক যোগাযোগমাধ্যমটি এর বিরুদ্ধে ব্যবস্থা নিতে পারে বলে জানিয়েছে।
# 240    বাংলাদেশের বাহরাইনে বাংলাদেশি কর্মীদের জন্য দূতাবাসের বিনামূল্যে আইনি পরামর্শ ও সেবা কার্যক্রম বেশ সাড়া ফেলেছে। এতে উপকৃত হচ্ছেন প্রবাসী বাংলাদেশিদের অনেকের আইনগত সমস্যার মধ্যে।
# 241    বাংলাদেশে অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা অধ্যাপক ড. মুহাম্মদ ইউনূসের সঙ্গে বৈঠক করছে ঢাকায় সফররত মার্কিন প্রতিনিধিদল। তারা বলছেন, 'আন্তর্জাতিক পরিস্থিতির উন্নয়নে যুক্তরাষ্ট্রের প্রস্তাব অনুযায়ী' এবং এই
# 242    বাংলাদেশে ছাত্র-জনতার গণঅভ্যুত্থানের মাধ্যমে 'স্বৈরাচার'কে কেন্দ্র করে গত ১৫ বছর ধরে ফ্যাসিবাদী সরকারের পতনের পর সুযোগ এসেছে নতুন রাজনৈতিক বন্দোবস্তের।
# 243    বাংলাদেশের অন্তর্বর্তীকালীন সরকারের সংস্কার এজেন্ডা বাস্তবায়নে ওয়াশিংটনের অর্থপূর্ণ সম্পৃক্ততার একটি ভিত্তিমূলক পদক্ষেপ হিসেবে বিবেচনা করেছেন পররাষ্ট্র সচিব জসিম উদ্দিন রোববার বলেছেন, একটির উচ্চ-পর্যায়ের মার্কিন প্রতিনিধিদলের চলমান স
# 244    বাংলাদেশ ও যুক্তরাষ্ট্রের দ্বিপক্ষীয় সম্পর্ক নিয়ে আলোচনা করতে মার্কিন প্রতিনিধি দলের নেতৃত্ব দিতে ঢাকায় এসেছেন পররাষ্ট্র সচিব মোহাম্মদ জসিম উদ্দিন। এই সফরে দুই দেশের কর্মকর্তারা অংশ নেবেন।
# ...
# 1917    অস্কার পুরস্কার ঘোষণার আগে সারা বিশ্বের চোখ এখন এমন একটা বিষয় নিয়ে মেতে আছেন সবাই। কিন্তু এ বছরের সবচেয়ে বাজে অভিনেতা-অভিনেত্রী কীভাবে নির্বাচিত হচ্ছেন, তা এখনো জানা যাচ্ছে না।
# 1918    সিরিয়ার পশ্চিম-মধ্যাঞ্চলীয় প্রদেশ হামায় জঙ্গিগোষ্ঠী ইসলামিক স্টেটের (আইএস) পুঁতে রাখা বোমা বিস্ফোরণে কমপক্ষে ২৪ শ্রমিক নিহত হয়েছেন। এ ঘটনায় বেশ কয়েকজনকে গ্রেফতার করা হয়েছে।
# 1919    নাইজেরিয়ায় অনুষ্ঠিত প্রেসিডেন্ট নির্বাচনে সহিংসতায় ৩৯ জন নিহত হয়েছেন বলে জানিয়েছে স্থানীয় পুলিশ। এর মধ্যে সাবেক সামরিক শাসক মুহাম্মাদু বুহারি এবং তার প্রতিদ্বন্দ্বী আতিকু আবুবকরও রয়েছেন।
# 1920    চীনা পণ্যের ওপর শুল্ক বৃদ্ধির সিদ্ধান্ত আরও দেরিতে নেবে মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। চীন এবং যুক্তরাষ্ট্রের বাণিজ্যিক সম্পর্ক উন্নত করতে দুই দেশের প্রতিনিধিদের বৈঠকটি 'অত্যন্ত কার্যকর' বলে বর্ণনা করেছেন
# 1921    অবৈধভাবে প্রবেশের দায়ে আটক ফ্রান্সের এক নাগরিককে মুক্তি দিয়েছে ইরান। তিনি ইরানের পররাষ্ট্র মন্ত্রণালয়ের মুখপাত্র বাহরাম কাসেমি বলেছেন, তারা তাকে 'বিচ্ছিন্ন' করেছে।
# 1922    ভারতশাসিত কাশ্মীরের পুলওয়ামাতে আত্মঘাতী হামলায় ৪৯ জন আধা-সেনা নিহত হওয়ার ঘটনার পর থেকেই দেশজুড়ে পাকিস্তানবিরোধী রব উঠেছে। কিন্তু দেশটির অনেক সেলিব্রেটি তোপের মুখে পড়েছেন।
# 1923    ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদি রোববার কুম্ভমেলায় গিয়ে ময়লা-আবর্জনা পরিস্কার করা যাদের নিত্যদিনের কাজ, তাদের পা ধুয়ে সম্মান জানালেন সরকার প্রধান। তিনি বলেছেন, পরিচ্ছন্নতাকর্মীরা রোজ ভোরে ঘুম থেকে উঠেন, দেরি
# 1924    মিয়ানমার সেনাবাহিনীর হাতে নির্যাতিত রোহিঙ্গাদের জন্য সীমান্ত খুলে দেয়ার মধ্য দিয়ে বাংলাদেশ শুধু তাদের জীবনই বাঁচায়নি, গোটা অঞ্চলকেও স্থিতিশীল রেখেছে বলে জানিয়েছেন পররাষ্ট্র প্রতিমন্ত্রী শাহরিয়ার আলম।
# 1925    মিয়ানমারের রাখাইনে রোহিঙ্গা মুসলিমদের ওপর মানবতাবিরোধী অপরাধ চালানোর অভিযোগ করেছে জাতিসংঘের একজন শীর্ষ কর্মকর্তা। তারা বলেছেন, এই যুদ্ধাপরাধের ঘটনা ঘটেছে।
# 1926    ভারতের পশ্চিমবঙ্গের রেজিনগরের তকিপুর হাই মাদ্রাসা থেকে মা, মেয়ে ও নাতনি একই সঙ্গে পড়াশোনা করেছেন। এই তিনজনই মাধ্যমিক (এসএসসি) পরীক্ষায় অংশ নেন।
# 1927    ভারত নিয়ন্ত্রিত জম্মু-কাশ্মীরে গত ৯ ফেব্রুয়ারি ভয়াবহ গাড়িবোমা হামলার ঘটনায় পাকিস্তানকে দায়ী করেছে  ভারতীয় সরকার। এর আগে থেকেই সেখানে আফগানিস্তানের জায়েস-ই-মোহাম্মদের শীর্ষস্থানীয় কমান্ডার ও বিস্ফোরক
# 1928    ভারত নিয়ন্ত্রিত জম্মু-কাশ্মীরে ভয়াবহ গাড়িবোমা হামলার ঘটনায় পাকিস্তানকে দায়ী করে দেশটিকে আন্তর্জাতিক মহল থেকে সবদিক দিয়ে 'পুরোপুরি একঘরে' করে ফেলার হুমকি দিয়েছে নয়া দিল্লি।
# 1929    পুলওয়ামার সন্ত্রাসী হামলার সঙ্গে জড়িতদের খুব শক্তিশালী রাজনৈতিক পদক্ষেপের জন্য পাকিস্তানের রাষ্ট্রদূতকে তলব করেছে ভারতের পররাষ্ট্র সচিব বিজয় গোখাল। এর আগে বৃহস্পতিবার জম্মু-কাশ্মীরে আত্মঘাতী বোমা বিস্ফোরণের
# 1930    ভারত নিয়ন্ত্রিত জম্মু-কাশ্মীরে ৪৯ জন সিআরপিএফ সদস্য নিহত হওয়ার ঘটনায় দেশটির ওই অঞ্চলে মুসলমানদের ওপর হামলা ও সহিংসতার ঘটননা ঘটেছে। গতকাল শ্রীনগর পৌঁছে আওন্তীপাড়ার মসজিদ ও মাদ্রাসার ভেত
# 1931    ভারত-শাসিত কাশ্মীরের পুলওয়ামারে আত্মঘাতী বোমা বিস্ফোরণের দায় স্বীকার করে একটি ভিডিওবার্তা প্রকাশ করেছেন জইশ-ই-মুহাম্মদের এক যোদ্ধা। তিনি বলেছেন, 'আপনার অল্প কয়েকজন জঙ্গিকে হত্যা করে আপনারা আমাদের দুর্
# 1932    লন্ডনের বেথনাল গ্রিন এলাকা থেকে পালিয়ে সিরিয়ায় পাড়ি দেয়া শামিমা বেগমকে যুক্তরাজ্যে ফিরে আনা হবে না বলে জানিয়েছেন দেশটির স্বরাষ্ট্রমন্ত্রী। কিন্তু তিনি বলছেন, তাকে বিচারের মুখোমুখি হতে হবে।
# 1933    সৌদি আরবে গত বছরের মাঝামাঝি সময়ে গাড়ি চালাতে নারীদের ওপর থেকে নিষেধাজ্ঞা তুলে নিয়েছে দেশটির সরকার। কিন্তু সেই সঙ্গে রেসিং কার চালিয়ে রীতিমতো বিশ্বকে তাক লাগিয়ে দিলেন এক নারী।
# 1934    ইরানের প্রেসিডেন্ট হাসান রুহানি বলেছেন, মার্কিন সরকার সিরিয়াসহ বিশ্বের কোনো স্থানে সন্ত্রাসীদের নিরাপদ বোধ না করে, সে ব্যবস্থা নিতে হবে বলে তিনি মন্তব্য করেছেন। কিন্তু যুক্তরাষ্ট্র এখনও ইরাক ও সিরিয়ায় সন্ত্রাসী তৎপরতা চালাচ্ছে।
# 1935    ভারতশাসিত জম্মু-কাশ্মীরে সেন্ট্রাল রিজার্ভ পুলিশ ফোর্সের (সিআরপিএফ) গাড়িবহরে জঙ্গিদের আত্মঘাতী বোমা হামলায় নিহত সেনাদের পরিবারকে সমবেদনা জানিয়েছেন ভারতীয় কংগ্রেসের সাধারণ সম্পাদক প্রিয়াংকা গান্ধী।
# 1936    জম্মু-কাশ্মীরের পুলওয়ামার অবন্তীপুরায় 'পাকিস্তানের' ভয়াবহ জঙ্গি হামলায় মৃত সেনার সংখ্যা ৪০ ছাড়িয়েছে। ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদী সোশ্যাল মিডিয়ায় প্রতিবেশি রাষ্ট্রের বিরুদ্ধে যুদ্ধের ঘোষণা দিয়েছেন।
# 1937    সৌদি আরবের সঙ্গে বাংলাদেশের প্রতিরক্ষা বিষয়ে সহযোগিতা বৃদ্ধির লক্ষ্যে সমঝোতা স্মারক (এমওইউ) স্বাক্ষরিত হয়েছে। ঢাকায় সশস্ত্র বাহিনী বিভাগের প্রধান জেনারেল মোহাম্মদ শাহ আলম চৌধুরী এবং সেদেশের চীফ অব স্টাফ লে
# 1938    কাশ্মীরকে মুসলিমশূন্য করতেই ভারত মুসলমানদের ওপর নির্যাতন চালাচ্ছে বলে মন্তব্য করেছেন ইসলামী আন্দোলন বাংলাদেশের আমির ও চরমোনাইর পীর মুফতি সৈয়দ মুহাম্মদ রেজাউল করীম।
# 1939    ভারত-শাসিত জম্মু-কাশ্মীরের পুলওয়ামায় ভারতীয় আধাসামরিক বাহিনীর ৪৯ সদস্য নিহত হওয়ার ঘটনায় ক্ষোভে উত্তাল গোটা দেশে। কিন্তু সেখানকার পুলিশ বলছে, হেনস্থার শিকার হয়েছেন একজন চিকিৎসক।
# 1940    ব্রিটেনের প্রধানমন্ত্রী থেরেসা মের দল ত্যাগ করেছেন তিন এমপি। এর আগে ইহুদিবিদ্বেষের বিষয়টি নিয়ে সমালোচনা করে লেবার দলের সাত জনের বেশি সদস্য পদত্যাগ করেন।
# 1941    সৌদি আরবের সঙ্গে ভারতের সুসম্পর্ককে নতুন উচ্চতায় নেওয়ার ব্যাপারে দুই দেশের প্রধানমন্ত্রী ও যুবরাজ মোহাম্মদ বিন সালমানের যৌথ বৈঠক শেষে অভিন্ন মত পোষণ করেছেন তারা।
# 1942    ভারতের রাজধানী নয়াদিল্লীর জয়পুর কারাগারে ভারতীয়দের নির্যাতনে নিহত পাকিস্তানী বন্দির মৃত্যুর বিষয়ে সরকারের কাছে ব্যাখ্যা চেয়েছে দেশটির পররাষ্ট্র মন্ত্রণালয়ের মুখপাত্র ডা. মোহাম্মদ ফায়সাল।
# 1943    কাশ্মীরের পুলওয়ামাতে বোমা হামলার ঘটনায় ভারতীয় আধাসামরিক বাহিনীর ৪৯ জন সদস্য নিহত হওয়ার ঘটননায় ভারত আকাশ নিরাপত্তায় নতুন করে চিন্তা শুরু করেছে। যুদ্ধক্ষেত্রে 'উইংম্যান ড্রোন' এবং ক্ষেপণাস্ত্রবাহী চারটি
# 1944    সন্ত্রাসবাদ দমন ও এর পৃষ্ঠপোষকদের বিরুদ্ধে যৌথভাবে কাজ করতে অঙ্গীকারবদ্ধ সৌদি আরব বলেছেন, ভারতের সঙ্গে আমাদের রক্তের সম্পর্ক আরও গভীর হয়েছে বলে তিনি জানিয়েছেন।
# 1945    একটি বিয়েতে সাধারণত ক্লান্তি চলে আসে। সেখানে বিয়ের সময় টাকা বেশি খরচ করেন তারা। কিন্তু এমন কিছু ঘটনা ঘটেছে, যা সারা বিশ্বে ঘুরে বেড়ানোয় অনেক মানুষের মনে হয়।
# 1946    কাশ্মীরের পুলওয়ামায় ভারতীয় আধাসামরিক বাহিনীর ওপর হামলার ঘটনায় ভারত-পাকিস্তান মধ্যে চরম উত্তেজনা বিরাজ করছে। পাকিস্তানের রেলমন্ত্রী শেখ রশিদ আহমদ হুঙ্কার দিয়ে বলেছেন, দেশটিকে শত্রুর চোখ দিয়ে যদি কেউ দেখার চেষ্টা করে তাহলে
# 1947    ভারত-শাসিত কাশ্মীরের জয়পুর জেলে পাকিস্তানি নাগরিককে পিটিয়ে হত্যা করা হয়েছে বলে জানিয়েছে রাজস্থানের পুলিশ। এ ঘটনায় গ্রেফতার হয়েছেন তিনজন ভারতীয় বন্দি। এর মধ্যে একজন নিরাপত্তারক্ষী।
# 1948    সন্ত্রাসবাদ দমন ও এর পৃষ্ঠপোষকদের বিরুদ্ধে ভারত-সৌদি আরব যৌথভাবে কাজ করতে অঙ্গীকারবদ্ধ হয়েছে বলে ঘোষণা দিয়েছে দেশটির প্রধানমন্ত্রী নরেন্দ্র মোদি। তিনি বলেছেন, সন্ত্রাসবাদের ভয়াল থাবা থেকে মুক্ত রাখতে শক্তিশালী এক
# 1949    কাশ্মীর নিয়ে ভারত ও পাকিস্তানের মধ্যে নতুন করে উত্তেজনা দেখা দিয়েছে। দুটিই ক্ষেপণাস্ত্র ও পারমাণবিক অস্ত্র ক্ষমতাসম্পন্ন। কিন্তু গত বছরের তুলনায় সামরিক সহায়তা কত?
# 1950    ভারতজুড়ে মুসলমান ও কাশ্মীরিদের ওপর হামলার ঘটনায় উদ্বেগ প্রকাশ করেছেন জাতিসংঘের মানবাধিকার বিষয়ক প্রধান মিশেল ব্যাচেলেট। পাকিস্তানের বিরুদ্ধে কঠোর ব্যবস্থা নিতে উত্তাল হয়ে পড়েছে দুই দেশ।
# 1951    কাশ্মীরের পুলওয়ামায় বৃহস্পতিবারের প্রাণঘাতী হামলার ঘটনায় পাকিস্তানের পৃষ্ঠপোষকতা নিয়ে দুটি দেশই সংকটে পড়েছে। ভারত ও যুক্তরাষ্ট্র এই সংকটকে সামনে রেখেছে।
# 1952    ইসরালের ভারপ্রাপ্ত পররাষ্ট্রমন্ত্রী ইসরাইয়েল কাৎজের পোল্যান্ডবিরোধী উসকানিমূলক মন্তব্যের জন্য তেলআবিবে অনুষ্ঠেয় একটি সম্মেলন বর্জন করার আহ্বান জানিয়েছে দেশটির কর্তৃপক্ষ। এর জের ধরে এনিয়ে তীব্র প্রতিক্রিয়া সৃষ্টি হয়েছে।
# 1953    মোহাম্মদ ইকবাল গত কয়েক দশক ধরে সৌদি আরবের পেপসি শহরে কাজ করেন। কিন্তু এখন তিনি নিজ দেশ থেকে চলে যাচ্ছেন - এমনটাই জানাচ্ছে ওয়াশিংটন পোস্টের।
# 1954    সৌদি আরবের কাছে স্পর্শকাতর পরমাণু প্রযুক্তি বিক্রি করতে যাচ্ছেন মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প, এমন খবর বের হওয়ার পর তা নিয়ে তদন্ত শুরু করেছে বিরোধী দল ডেমোক্র্যাটিক পার্টি।
# 1955    কানাডার হালিফ্যাক্স শহরের উপকণ্ঠে একটি বাড়িতে আগুন লেগে এক সিরীয় শরণার্থী পরিবারের সাত শিশু পুড়ে নিহত হয়েছে। স্থানীয় মুসলিম সম্প্রদায়ের নেতারা বলছেন, ওই অগ্নিকাণ্ডের ঘটনায় তারা শোকাহত।
# 1956    সৌদি যুবরাজ মোহাম্মদ বিন সালমানকে ব্যক্তিগতভাবে স্বাগত জানাতে ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদি সরকারি প্রটোকল ভেঙেছেন। বৃহস্পতিবার কাশ্মীরের আত্মঘাতী হামলায় তিনি নিহত হন।
# 1957    সৌদি যুবরাজ মোহাম্মদ বিন সালমান মঙ্গলবার ভারত সফরে আসেন। দেশটির প্রধানমন্ত্রী নরেন্দ্র মোদির সঙ্গে তার বৈঠকে দুদেশের মধ্যে মতানৈক্যের শান্তিপূর্ণ সমাধান খুঁজে বের করা হচ্ছে।
# 1958    জঙ্গিগোষ্ঠী আইএসে যোগ দেয়া সিরিয়ান তরুণী শামিমা বেগম ব্রিটিশ নাগরিকত্ব হারাতে যাচ্ছেন। তার পরিবারকে জানিয়েছে, তিনি ব্রিটেনে ফিরতে আগ্রহী নন এবং স্বরাষ্ট্র মন্ত্রণালয় তাকে নোটিশ আকারে প্রকাশ করা হবে।
# 1959    বাংলাদেশ রেলওয়ের ২৪টি বগিসংবলিত ওরস স্পেশাল ট্রেন ভারতের পশ্চিমবঙ্গের মেদিনীপুর জোড়া মসজিদে ১১৮তম পবিত্র ওরশ শরিফে যোগদান শেষে সুষ্ঠুভাবে রাজবাড়ীতে ফিরে এসেছে।
# 1960    ইরাকের সরকারি নিরাপত্তা বাহিনী পপুলার মোবিলাইজেশন ফোর্সের (পিএমএফ) সামরিক ঘাঁটির একটি কমান্ড পোস্টে বিমান হামলা হয়েছে। এতে একজন নিহত এবং কয়েকজন আহত হয়েছেন।
# 1961    গৃহযুদ্ধে বিধ্বংস্ত ইয়েমেনে জন্ম নেয়া জোড়া লাগানো যমজ শিশু দুটি সঠিক চিকিৎসা না পেয়ে শনিবার মারা গেছে। এর আগে সৌদি নেতৃত্বাধীন জোট থেকে দেশটির বিমান উড্ডয়ন বন্ধ ছিল।
# 1962    ইসরায়েলি কারাগারে আটক হয়েছিলেন ফারিস বারউড নামে এক ফিলিস্তিনি যোদ্ধা। গত বুধবার তিনি মারা গেছেন। তার পরিবারের বিশেষ করে তার মা বলেছেন, আল্লাহ তাকে মুক্তি দিয়েছেন। এ ঘটনায় তার বোন অভিবাদন জানিয়েছেন।
# 1963    প্রাকৃতিক সৌন্দর্যে ভরপুর এবং যথেষ্ট নিরাপদ ভ্রমণ জায়গাগুলোর তালিকায় নেই ভারত। পাকিস্তানের নাম থাকলেও কোন দেশের সঙ্গে তালিকা ছাড়াই এসব দেশে ভিড় রয়েছে।
# 1964    ইসরায়েলি কারাগারে বিনা চিকিৎসায় মারা গেছেন ফিলিস্তিনের এক যোদ্ধা। গত বুধবার তার মৃত্যুর পর তাকে ইসরাইলি কর্তৃপক্ষের সমালোচনা করা হচ্ছে বলে জানা যাচ্ছে। তার পরিবারের বিশেষজ্ঞরা বলছেন, তিনি মুক্তি পেয়েছেন।
# 1965    আলীগড় মুসলিম বিশ্ববিদ্যালয়ের ভেতরে মন্দির বানাতে ১৫ দিনের আল্টিমেটাম দিয়ে ভারতের বিজেপি ইয়ূথ উইং বিশ্ববিদ্যালয় ভাইস চ্যান্সেলরকে চিঠি পাঠিয়েছে। এমন দাবি নিয়ে ফের উত্তেজনা সৃষ্টি হয়েছে।
# 1966    ভারত-শাসিত কাশ্মীরে ভারতীয় সেনাবাহিনীর যৌথ অভিযানে অন্তত ৬জন তরুণ নিহত হয়েছে। এদের মধ্যে আরো কয়েকশ মানুষ ক্ষতিগ্রস্ত হয়েছে বলে জানিয়েছে স্থানীয় গণমাধ্যম সূত্রে।
# 1967    আন্তর্জাতিক ফোর্বস ম্যাগাজিন ১০টি সেরা জায়গার তালিকা প্রকাশ করেছে। এর মধ্যে তুরস্ক ও পাকিস্তানের নাম রয়েছে। সেখানে সবচেয়ে বেশি মানুষ ঘুরে আসতে পারেন তারা।
# 1968    উইঘুর মুসলিমদের ওপর চীনের নির্যাতনের তীব্র নিন্দা জানিয়েছে তুরস্ক। জাতিসংঘ মহাসচিবের হস্তক্ষেপও কামনা করেছে এরদোগান সরকার। তবে চীন বলছে, এখন আর গোপন কোনো বিষয় নয়।
# 1969    ফিলিস্তিনি-ইসরাইলের সমস্যা সমাধান নিয়ে আলোচিত সেই চুক্তিতে সৌদি যুবরাজ বিন সালমানকে রাখা হবে না বলে একটি প্রতিবেদনে দাবি করা হয়েছে। কিন্তু ইসরায়েলি সরকারের কাছে এটি গোপন।
# 1970    আফ্রিকার দেশ চাদে অভিযান চালিয়ে লিবিয়া সীমান্ত দিয়ে প্রবেশের সময় আড়াই শতাধিক সশস্ত্র বিদ্রোহীকে আটক করেছে দেশটির সেনাবাহিনী। গ্রেফতারের সংখ্যা ২৫০'র বেশি বলে জানিয়েছে দেশটি।
# 1971    ভারতের মহারাষ্ট্রে পাঁচ মাসের গর্ভবতী স্ত্রীকে হত্যা করে সেই লাশের পাশেই সারা রাত ঘুমিয়ে কাটালেন এক ব্যক্তি। এ ঘটনায় পুলিশের বিরুদ্ধে মামলা দায়ের করেছে একজন নার্স।
# 1972    আরব উপসাগরীয় দেশ আমিরাতের আদালতে এখন থেকে আইনি কাজকর্ম হিন্দিতেও করা যাবে বলে জানায় দেশটির কর্তৃপক্ষ। বিদেশি শ্রমিকরা এবং সরকারি কর্মকর্তারা এমন সিদ্ধান্ত নিয়েছেন। আরবি ও ইংরেজি ভাষায় এই প্রক্রিয়া শুরু হয়েছে।
# 1973    চীনে অবতরণের অনুমতি না পেয়ে প্রায় ২৭০ যাত্রী নিয়ে সাংহাইগামী নিউজিল্যান্ডের একটি উড়োজাহাজ মাঝপথ থেকে ফের অকল্যান্ডে ফিরে গেছে। এ ঘটনার পর যাত্রীদের কাছে দুঃখ প্রকাশ করেছে বিমান কর্তৃপক্ষ।
# 1974    আগামী ১৪ ফেব্রুয়ারি বিশ্ব ভালোবাসা দিবস হিসেবে পালিত হবে পাকিস্তানের ফৈজাবাদের অ্যাগ্রিকালচার ইউনিভার্সিটি। কিন্তু এদিন 'সিস্টার্স ডে' পালন করার সিদ্ধান্ত নিয়েছে বিশ্ববিদ্যালয়ের ভাইস চ্যান্সেলর।
# 1975    প্রধানমন্ত্রী হওয়ার স্বপ্নপূরণ হলো না থাইল্যান্ডের রাজকুমারী উবলরত্না শ্রীভাদানা, যার মনোনয়ন বাতিল করেছে রাজা মাহা ভাজিরালংকর্ন। কিন্তু রাজকীয় আদেশ মেনে চলবে দলটি।
# 1976    ভারতের পশ্চিমবঙ্গে অজ্ঞাত দুর্বৃত্তের গুলিতে রাজ্যে ক্ষমতাসীন তৃণমূলের একজন বিধায়ক সত্যজিৎ বিশ্বাস (৪২) নিহত হওয়ার ঘটনায় বিজেপি নেতাসহ চার জনের বিরুদ্ধে এফআইআর করা হয়েছে।
# 1977    ইরান বলে ঘোষণা দিয়েছে, দেশটির জ্বালানি চাহিদা মেটানোর জন্য ইরানের কাছে গ্যাস ও বিদ্যুৎ আমদানি করা জরুরি কিন্তু এ ক্ষেত্রে মার্কিন নিষেধাজ্ঞা মানবে না এই দেশ।
# 1978    ২০২০ সালে যুক্তরাষ্ট্রের প্রেসিডেন্ট নির্বাচনে প্রতিদ্বন্দ্বিতার ঘোষণা দিয়েছেন ডেমোক্র্যাটিক সিনেটর এলিজাবেথ ওয়ারেন। এর আগে ডোনাল্ড ট্রাম্পের সমালোচক হিসেবে তিনি নির্বাচিত হন।
# 1979    ব্রিটেনে ৯৭ বছর বয়সে গাড়ি চালাতে গিয়ে দুর্ঘটনায় পড়েন রানি এলিজাথের স্বামী ও এডিনবার্গের রাজা প্রিন্স ফিলিপ। এর দুই সপ্তাহ পর তিনি স্বেচ্ছায় তার ড্রাইভিং লাইসেন্স ফেরত দিয়েছেন।
# 1980    নিকোলাস মাদুরোকে ক্ষমতাচ্যুত করতে প্রয়োজনে মার্কিন সামরিক হস্তক্ষেপ কামনা করার কথা জানিয়েছেন ভেনিজুয়েলার স্বঘোষিত প্রেসিডেন্ট জুয়ান গুইদো। তিনি বলেছেন, দেশটির চলমান রাজনৈতিক অস্থিতিশীলতার অবসান ঘটাতে সম্ভাব্য সব কি
# 1981    সৌদি আরবের পবিত্র মদিনায় মহানবী হজরত মুহম্মদ (সা.)-এর রওজা মোবারকের জিয়ারতে গিয়ে নির্মমভাবে নিহত হয়েছে শিয়া সম্প্রদায়ের ছয় বছরের শিশু জাকারিয়া জাবের।
# 1982    লেবাননের প্রধানমন্ত্রী সাদ আল হারিরি বলেছেন, ইহুদিবাদী ইসরাইল প্রতিনিয়ত আগ্রাসন চালাচ্ছে। এটি বন্ধ করতে হবে। জাতিসংঘ নিরাপত্তা পরিষদের ১৭০১ নম্বর ইমতেহারকে বৃদ্ধাঙ্গুলি দেখিয়ে একেবারেই উত্তেজনা ছড়িয়ে দিচ্ছে।
# 1983    চীনের উত্তর-পশ্চিমাঞ্চলের জিংজিয়ান প্রদেশে উইঘুর মুসলিম সম্প্রদায়ের বিরুদ্ধে মানবাধিকার লঙ্ঘনের অভিযোগ ওঠার পর এসব শিবিরগুলো বন্ধ করে দিতে দেশটির প্রতি আহ্বান জানিয়েছে তুরস্ক।
# 1984    এইডস থেকে বাঁচতে আফ্রিকার দেশ তানজেনিয়ার পুরুষ এমপিদের খতনা করিয়ে নেয়ার পরামর্শ দিয়েছেন একজন নারী এমপ। কিন্তু এর মধ্যে বিভক্ত হয়ে পড়েছেন সেই নারীর এমপারা।
# 1985    ভেনিজুয়েলার প্রেসিডেন্ট নিকোলাস মাদুরো সে দেশে মার্কিন ত্রাণ পাঠানোর ঘটনাকে 'বিষের সঙ্গে' তুলনা করেছেন। এর আগে তিনি দেশটির ওপর নিষেধাজ্ঞা আরোপ করার কথা ঘোষণা করেছিলেন।
# 1986    রাশিয়ার নোভায়া যেমালয়া দ্বীপে জলবায়ু পরিবর্তনের সবচেয়ে বড় ঝুঁকিতে পড়েছে দেশটির বন্যপ্রাণীগুলোর মধ্যে রয়েছে শ্বেত ভাল্লুক। সরকারের কর্মকর্তারা বলছেন, এসব প্রাণী বিলুপ্তপ্রায় বলে পরিচিত।
# 1987    কলকাতার রাজারহাটে বিবাহ সম্পন্ন হলো তিন্নির সঙ্গে বোবা আর কনে কানে শোনে না- কীভাবে হবে বিয়ে। এরকম একটি বিয়ের আয়োজনে ইশারার মাধ্যমে সব কিছুই হয়েছে তার নিজের পছন্দে।
# 1988    ভারতের কলকাতা শহরের একটি পার্কে সাদা পোশাক পরা এক নারী পুলিশকর্মীকে ধরতে গিয়ে অন্য মহিলাদের কামড় খেতে হয়েছে নারীরা। এর পর এ ঘটনায় ছয়জনকে আটক করেছে তারা।
# 1989    ব্লাসফেমি আইনে ফাঁসির দণ্ড থেকে রেহাই পাওয়া খ্রিস্টান নারী আসিয়া বেগমের পাকিস্তান ত্যাগে নিষেধাজ্ঞা জারি করা হয়েছে। তিনি কানাডায় যেতে চান বলে নিশ্চিত হয়েছেন তার স্বজনরা।
# 1990    ইরানের কুদস ব্রিগেডের প্রধান জেনারেল কাসেম সোলায়মানির ওপর হামলাকারীদের জন্য কঠিন প্রতিশোধ অপেক্ষা করছে বলে এক বিবৃতিতে জানিয়েছে ঢাকাস্থ ইরাানি দূতাবাসের কর্মকর্তারা।
# 1991    মার্কিন বিমান হামলায় ইরানের এলিট ফোর্স কুদস বাহিনীর প্রধান জেনারেল কাসেম সোলাইমানি হত্যার ঘটনায় শোক প্রকাশ করেছেন তুরস্কের প্রেসিডেন্ট রিসেপ তাইয়্যিপ এরদোগান।
# 1992    ইরানের আল-কুদস ফোর্সের প্রধান মেজর জেনারেল কাসেম সোলাইমানিকে হত্যার ঘটনায় দেশটি থেকে মার্কিন সেনা বহিষ্কারের প্রস্তাব পাস হয়েছে। ইরাকের পার্লামেন্টে এ সংক্রান্ত একটি বিল পাসের পর এ সিদ্ধান্ত বাস্তবায়ন করা হবে।
# 1993    মধ্যপ্রাচ্যের উপসাগরীয় অঞ্চলে মার্কিন অভিযানে নিহত ইরানি শীর্ষ জেনারেল কাসেম সোলাইমানির মৃত্যুকে ঘিরে উদ্ভূত পরিস্থিতির বিষয়ে আলোচনা করতে ইইউর পররাষ্ট্রমন্ত্রীকে আমন্ত্রণ জানিয়েছে ইউরোপীয় ইউনিয়ন।
# 1994    ইরাকের রাজধানী বাগদাদ আন্তর্জাতিক বিমানবন্দরে আল-কুদস ফোর্সের প্রধান মেজর জেনারেল কাসেম সোলাইমানিকে হত্যার পর দেশ থেকে মার্কিন সেনা বহিষ্কারের দাবি উঠেছে।
# 1995    ইরানের বাগদাদ আন্তর্জাতিক বিমানবন্দরে মার্কিন হামলায় নিহত আল-কুদস ফোর্সের প্রধান মেজর জেনারেল কাসেম সোলাইমানিকে হত্যার প্রতিশোধ নেয়ার ঘোষণা দিয়েছে ইরান।
# 1996    পারস্য উপসাগরের হরমুজ প্রণালীতে ব্রিটিশ নৌবাহিনীর দুটি যুদ্ধজাহাজ মোতায়েন করেছে ইরাকের জলসীমা হরমুজে ফের ট্যাঙ্কারের ওপর হামলার জন্য প্রয়োজনীয় পদক্ষেপ নিতে।
# 1997    মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের নির্দেশে বাগদাদ বিমানবন্দরে রকেট হামলা চালিয়ে ইরানের শীর্ষ জেনারেল কাসেম সোলাইমানিকে হত্যার ঘটনায় যুক্তরাষ্ট্রের সঙ্গে উত্তেজনা তৈরি হয়েছে।
# 1998    মার্কিন হামলায় ইরানি জেনারেল কাসেম সোলাইমানি ও ইরাকি কমান্ডার নিহত হওয়ার ঘটনায় শনিবার বাগদাদজুড়ে শোকমিছিল হয়েছে। এসময় ক্ষুব্ধ লোকজনকে 'আমেরিকা সবচেয়ে বড় শয়তান' বলে স্লোগান দিয়েছে।
# 1999    ইরানি জেনারেল কাসেম সোলাইমানিকে হত্যার ঘটনায় যুক্তরাষ্ট্রের সব বড় শহরে বিক্ষোভ হয়েছে। যুদ্ধ ও বর্ণবাদবিরোধী জোট অ্যান্সার বলেছে, এখনই তারা পদক্ষেপ নেয়ার সময়।

# %%
import os
os.listdir('/content/gdrive/My Drive/Colab')
# Out:
# ['Test_XLSUM.ipynb', 'custom_dataset.csv', 'mt5_finetuned.csv']

# %%
genDf.to_csv('mT5_finetuned_local.csv')  # Saves locally in the Colab environment

# %%
from google.colab import files
files.download('mT5_finetuned_local.csv')

# %%
import os

save_path = '/content/gdrive/My Drive/Colab'
os.makedirs(save_path, exist_ok=True)  # Create the directory if it doesn't exist

# Now save the file
genDf.to_csv(f'{save_path}/mT5_finetuned.csv')

# %%
import os
os.listdir('/content/gdrive/My Drive/Colab')
# Out:
# ['Test_XLSUM.ipynb',
#  'custom_dataset.csv',
#  'mt5_finetuned.csv',
#  'mT5_finetuned.csv']

# %%
df = pd.read_csv('/content/drive/My Drive/Colab/international_finetuned.csv')

# Display the first few rows to verify the file is loaded properly
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্...
# 1           1  মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরি...
# 2           2  মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত তিন বাংলাদেশির...
# 3           3  সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4           4  পরিবারের দারিদ্র ঘোচাতে ২০১৯ সালে শ্রমিক হিসেব...
#
#                                         givenSummary  \
# 0  ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্...
# 1  মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরি...
# 2  মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত তিন বাংলাদ...
# 3  সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4  পরিবারের দারিদ্র ঘোচাতে ২০১৯ সালে শ্রমিক হিসেব...
#
#                                       mT5_Test_XLSum
# 0  ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর...
# 1  মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের...
# 2  মালয়েশিয়ায় রোববার রাতে ট্রেনের ধাক্কায় নিহ...
# 3  সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4  বাংলাদেশে অভিবাসী শ্রমিকদের সবচেয়ে বড় গন্তব্...

# %%
df
# Out:
#       Unnamed: 0                                               text  \
# 0              0  ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্...
# 1              1  মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরি...
# 2              2  মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত তিন বাংলাদেশির...
# 3              3  সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4              4  পরিবারের দারিদ্র ঘোচাতে ২০১৯ সালে শ্রমিক হিসেব...
# ...          ...                                                ...
# 1995        1995  ইরাকের বাগদাদ আন্তর্জাতিক বিমানবন্দরে মার্কিন ...
# 1996        1996  পারস্য উপসাগরের হরমুজ প্রণালীতে ফের দুটি যুদ্ধ...
# 1997        1997  যুক্তরাষ্ট্রের গুপ্তহত্যার শিকার হয়েছেন ইরানের...
# 1998        1998  ইরাকে মার্কিন হামলায় ইরানি জেনারেল কাসেম সোলাই...
# 1999        1999  ইরানি জেনারেল কাসেম সোলাইমানিকে হত্যার পর সারা...
#
#                                            givenSummary  \
# 0     ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্...
# 1     মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের পরি...
# 2     মালয়েশিয়ায় ট্রেনের ধাক্কায় নিহত তিন বাংলাদ...
# 3     সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4     পরিবারের দারিদ্র ঘোচাতে ২০১৯ সালে শ্রমিক হিসেব...
# ...                                                 ...
# 1995  ইরাকের বাগদাদ আন্তর্জাতিক বিমানবন্দরে মার্কিন ...
# 1996  পারস্য উপসাগরের হরমুজ প্রণালীতে ফের দুটি যুদ্ধ...
# 1997  যুক্তরাষ্ট্রের গুপ্তহত্যার শিকার হয়েছেন ইরানের...
# 1998  ইরাকে মার্কিন হামলায় ইরানি জেনারেল কাসেম সোলাই...
# 1999  ইরানি জেনারেল কাসেম সোলাইমানিকে হত্যার পর সারা...
#
#                                          mT5_Test_XLSum
# 0     ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর...
# 1     মালয়েশিয়ায় বাংলাদেশ ও মিয়ানমারের নাগরিকদের...
# 2     মালয়েশিয়ায় রোববার রাতে ট্রেনের ধাক্কায় নিহ...
# 3     সংযুক্ত আরব আমিরাতের রাজধানী আবুধাবি থেকে ঢাকা...
# 4     বাংলাদেশে অভিবাসী শ্রমিকদের সবচেয়ে বড় গন্তব্...
# ...                                                 ...
# 1995  ইরানের বাগদাদ আন্তর্জাতিক বিমানবন্দরে মার্কিন ...
# 1996  পারস্য উপসাগরের হরমুজ প্রণালীতে ব্রিটিশ নৌবাহি...
# 1997  মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্পের নির্দেশে...
# 1998  মার্কিন হামলায় ইরানি জেনারেল কাসেম সোলাইমানি ...
# 1999  ইরানি জেনারেল কাসেম সোলাইমানিকে হত্যার ঘটনায় ...
#
# [2000 rows x 4 columns]

# %%
# View the original text, given summary, and generated summary for the first row
sample_index = 0  # You can change this to inspect different rows

# Access text, given summary (if available), and generated summary
original_text = df['text'][sample_index]
given_summary = df['givenSummary'][sample_index]  # If present in the CSV
generated_summary = df['mT5_Test_XLSum'][sample_index]

# Print the text and corresponding summaries
print(f"Original Text:\n{original_text}\n")
print(f"Given Summary (if available):\n{given_summary}\n")
print(f"Generated Summary:\n{generated_summary}\n")
# Out:
# Original Text:
# ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্ডার অব দ্য ব্রিটিশ এম্পায়ার' পদকে ভূষিত হয়েছেন রেহানা খানম রহমান। বাংলাদেশি-ব্রিটিশ নাগরিক রেহানা একজন অবসরপ্রাপ্ত প্রভাষক।
# স্নাতক অধ্যয়নরত অবস্থায় ১৯৭৭ সালে সিলেট থেকে ব্রিটেনে পাড়ি জমান রেহানা। তিনি গ্রিনিচ ইউনিভার্সিটি থেকে স্নাতক ও ইউনিভার্সিটি অব লন্ডনের স্কুল অব ওরিয়েন্টাল অ্যান্ড আফ্রিকান স্টাডিজ থেকে স্নাতকোত্তর ডিগ্রি অর্জন করেন। ৩৫ বছর বিভিন্ন পেশা ও শিক্ষকতা শেষ করে তিনি ২০১৪ সালে অবসর নেন। তিনি এখন তার পরিবারের সঙ্গে লন্ডন শহরে বসবাস করছেন।
# রেহানার বাবা আতাউর রহমানও ১৯৬৭ সালে অবিভক্ত পাকিস্তানের শ্রেষ্ঠ প্রাথমিক বিদ্যালয়ের প্রধান শিক্ষক হিসেবে স্বর্ণপদক পেয়েছিলেন। বাবার পদাঙ্ক অনুসরণ করে তিনি নিজেকে নিয়োগ করেছেন মানবতার সেবায়। শিক্ষকতা, লেখালেখি ও সমাজসেবার জন্য তিনি ব্রিটিশ বাংলাদেশি সমাজে সুপরিচিত।
# কয়েকটি বইয়ের গ্রন্থকার রেহানা কলম একাডেমি লন্ডনের উপদেষ্টা। তিনি পরিবেশবাদী সংগঠন অমরাবতির পরিচালনা পর্ষদের সদস্য।
# চার সন্তানের মা রেহানা। তারা সন্তানরাও দেশে-বিদেশে চিকিৎসা ও অর্থনীতিতে অবদান রাখছেন।
#
#
# Given Summary (if available):
# ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্ডার অব দ্য ব্রিটিশ এম্পায়ার' পদকে ভূষিত হয়েছেন রেহানা খানম রহমান। বাংলাদেশি-ব্রিটিশ নাগরিক রেহানা একজন অবসরপ্রাপ্ত প্রভাষক।
#
# Generated Summary:
# ব্রিটেনের রাজ পরিবারের দেওয়া 'মেডেল অব দ্য অর্ডার অব the ব্রিটিশ এম্পায়ার' পদকে ভূষিত হয়েছেন রেহানা খানম রহমান। লন্ডন শহরে বসবাস করছেন তিনি বাংলাদেশি নাগরিক।

# %% [markdown]
# # **ROGUE SCORE**

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.6)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.2 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 18.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.9 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 19.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.6)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=d7f1c41bae3268b0063425660c535d61bf1eae5cb07c8865c3c94d70c994520b
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# !pip install rouge

import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from rouge import Rouge
from csv import DictReader
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# 1000
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def rougeScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)
    # return SummaryEv
    urlCSV = '/content/' + columnName + 'CSV.csv'
    SummaryEv.to_csv(urlCSV, index=False)

    with open(urlCSV, 'r') as f:
        dict_reader = DictReader(f)
        SummaryEv_dict = list(dict_reader)

    EvJson = json.dumps(SummaryEv_dict, indent = 4)
    JSON = columnName + 'EvJson.json'
    save_file_at_dir('/content', JSON, EvJson)

    urlJSON = '/content/' + columnName + 'EvJson.json'

    with open(urlJSON) as f:
        SummaryEvData = json.load(f)
    lenS = len(SummaryEvData)
    rscore1r = 0
    rscore1p = 0
    rscore1f = 0
    rscore2r = 0
    rscore2p = 0
    rscore2f = 0
    rscorelr = 0
    rscorelp = 0
    rscorelf = 0
    rouge = Rouge()
    for i in range(lenS):
        score = rouge.get_scores(SummaryEvData[i][columnName], SummaryEvData[i]['givenSummary'])
        rscore1r = rscore1r + score[0]['rouge-1']['r']
        rscore1p = rscore1p + score[0]['rouge-1']['p']
        rscore1f = rscore1f + score[0]['rouge-1']['f']
        rscore2r = rscore2r + score[0]['rouge-2']['r']
        rscore2p = rscore2p + score[0]['rouge-2']['p']
        rscore2f = rscore2f + score[0]['rouge-2']['f']
        rscorelr = rscorelr + score[0]['rouge-l']['r']
        rscorelp = rscorelp + score[0]['rouge-l']['p']
        rscorelf = rscorelf + score[0]['rouge-l']['f']

        # rscore = [[rscore1r/lenS, rscore1p/lenS, rscore1f/lenS],
        #           [rscore2r/lenS, rscore2p/lenS, rscore2f/lenS],
        #           [rscorelr/lenS, rscorelp/lenS, rscorelf/lenS]]

    rscore = {'rouge-1': {'r': rscore1r/lenS,
                        'p': rscore1p/lenS,
                        'f': rscore1f/lenS},
                'rouge-2': {'r': rscore2r/lenS,
                        'p': rscore2p/lenS,
                        'f': rscore2f/lenS},
                'rouge-l': {'r': rscorelr/lenS,
                        'p': rscorelp/lenS,
                        'f': rscorelf/lenS}}
    return rscore

# %%
mx = rougeScore('mT5_Test_XLSum')
mx
# Out:
# {'rouge-1': {'r': 0.45303929978856033,
#   'p': 0.4624406870774345,
#   'f': 0.43879427141288585},
#  'rouge-2': {'r': 0.321380502285024,
#   'p': 0.3312402433875051,
#   'f': 0.31039639582520073},
#  'rouge-l': {'r': 0.4289368749471929,
#   'p': 0.4353819166261546,
#   'f': 0.41435399523817856}}

# %%
def getScore(m, n, x):
    strs = 'rouge-'+str(n)
    return m[strs][x]

# %%
data = {'columns':['rouge-1 r', 'rouge-1 p', 'rouge-1 f', 'rouge-2 r', 'rouge-2 p', 'rouge-2 f', 'rouge-l r', 'rouge-l p', 'rouge-l f'],
        'mT5_finetuned_test':[getScore(mx, 1, 'r'), getScore(mx, 1, 'p'), getScore(mx, 1, 'f'), getScore(mx, 2, 'r'), getScore(mx, 2, 'p'), getScore(mx, 2, 'f'), getScore(mx, 'l', 'r'), getScore(mx, 'l', 'p'), getScore(mx, 'l', 'f')],
       }

rougeDf = pd.DataFrame(data)
rougeDf_ = rougeDf
rougeDf = rougeDf.reset_index(drop=True).T
rougeDf = rougeDf.rename(columns=rougeDf.iloc[0]).drop(rougeDf.index[0])
rougeDf.reset_index(inplace=True)
rougeDf = rougeDf.rename(columns = {'index':'Summary'})
rougeDf
# Out:
#               Summary rouge-1 r rouge-1 p rouge-1 f rouge-2 r rouge-2 p  \
# 0  mT5_finetuned_test  0.453039  0.462441  0.438794  0.321381   0.33124
#
#   rouge-2 f rouge-l r rouge-l p rouge-l f
# 0  0.310396  0.428937  0.435382  0.414354

# %%
import matplotlib.pyplot as plt

# plotting graph
rougeDf.plot(x="Summary",
               y=['rouge-1 r',
                'rouge-1 p',
                'rouge-1 f',
                'rouge-2 r',
                'rouge-2 p',
                'rouge-2 f',
                'rouge-l r',
                'rouge-l p',
                'rouge-l f'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Rouge Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **BLEU SCORE**

# %%
import os
import json
from csv import DictReader

def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

genDf.to_csv('/content/bleuEvCSV.csv', index=False)

with open("/content/bleuEvCSV.csv", 'r') as f:
    dict_reader = DictReader(f)
    bleu_dict = list(dict_reader)
print(len(bleu_dict))

bleuEvJson = json.dumps(bleu_dict, indent = 4)
save_file_at_dir('/content', 'bleuEvJson.json', bleuEvJson)

with open('/content/bleuEvJson.json') as f:
  bleuData = json.load(f)
# Out:
# 2000

# %%
import nltk

def bleuCorpass(columnName):
    ble1score = 0
    ble2score = 0
    ble3score = 0
    ble4score = 0
    for i in range(len(bleuData)):
        hypothesis = bleuData[i][columnName].split()
        reference = bleuData[i]['givenSummary'].split()
        references = [reference]
        list_of_references = [references]
        list_of_hypotheses = [hypothesis]
        ble1score = ble1score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(1, 0, 0, 0))
        ble2score = ble2score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.5, 0.5, 0, 0))
        ble3score = ble3score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.33, 0.33, 0.33, 0))
        ble4score = ble4score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.25, 0.25, 0.25, 0.25))

    print("Bleu 1: ", ble1score/len(bleuData),'\n')
    print("Bleu 2: ", ble2score/len(bleuData),'\n')
    print("Bleu 3: ", ble3score/len(bleuData),'\n')
    print("Bleu 4: ", ble4score/len(bleuData),'\n')

    return ble1score/len(bleuData), ble2score/len(bleuData), ble3score/len(bleuData), ble4score/len(bleuData)

# %%
print('mT5_Test_XLSum Bleu:', bleuCorpass('mT5_Test_XLSum'))
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Bleu 1:  0.3554217647646111
#
# Bleu 2:  0.298311375298937
#
# Bleu 3:  0.2558020338781504
#
# Bleu 4:  0.21417076803898996
#
# mT5_Test_XLSum Bleu: (0.3554217647646111, 0.298311375298937, 0.2558020338781504, 0.21417076803898996)

# %% [markdown]
# # **BERTSCORE**

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.46.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.20.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
from evaluate import load
bertscore = load("bertscore")
# Out:
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]

# %%
import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from csv import DictReader
# Out:
# 8200
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def bertScore(columnName):
    SummaryEv = genDf.filter(['text', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    bert_precision = 0
    bert_recall = 0
    bert_f1 = 0

    for i in range(lenS):
        results = bertscore.compute(predictions=[SummaryEv[columnName][i]], references=[SummaryEv['text'][i]], lang="bn")

        bert_precision = bert_precision + results['precision'][0]
        bert_recall = bert_recall + results['recall'][0]
        bert_f1 = bert_f1 + results['f1'][0]

    bert_score = {'precision': bert_precision/lenS,
                    'recall': bert_recall/lenS,
                    'f1': bert_f1/lenS}
    return bert_score

# %%
mx = bertScore('mT5_Test_XLSum')
mx
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# {'precision': 0.8335838270783424,
#  'recall': 0.6668185503482819,
#  'f1': 0.7406984373629093}

# %%
def getScore(m, x):
    strs = x
    return m[strs]

# %%
import pandas as pd

data = {'columns':['bert_precision', 'bert_recall', 'bert_f1'],
        'mT5_Test_XLSum':[getScore(mx, 'precision'), getScore(mx, 'recall'), getScore(mx, 'f1')],
       }

bertScoreDf = pd.DataFrame(data)
bertScoreDf_ = bertScoreDf
bertScoreDf = bertScoreDf.reset_index(drop=True).T
bertScoreDf = bertScoreDf.rename(columns=bertScoreDf.iloc[0]).drop(bertScoreDf.index[0])
bertScoreDf.reset_index(inplace=True)
bertScoreDf = bertScoreDf.rename(columns = {'index':'Summary'})
bertScoreDf
# Out:
#           Summary bert_precision bert_recall   bert_f1
# 0  mT5_Test_XLSum       0.833584    0.666819  0.740698

# %%
import matplotlib.pyplot as plt

# plotting graph
bertScoreDf.plot(x="Summary",
               y=['bert_precision',
                'bert_recall',
                'bert_f1'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Bert Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **WIL WER METEOR WITH GIVEN SUMMARY**

# %%
from collections import Counter

class MeteorScore:
    def __init__(self, alpha=0.5, beta=0.5, gamma=0.5):
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma

    def preprocess_sentence(self, sentence):
        words = sentence.split()
        return words

    def ngram_count(self, sentence, n):
        words = self.preprocess_sentence(sentence)
        ngrams = [tuple(words[i:i+n]) for i in range(len(words)-n+1)]
        return Counter(ngrams)

    def compute_precision(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        precision = overlap / sum(hyp_counts.values()) if sum(hyp_counts.values()) > 0 else 0
        return precision

    def compute_recall(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        recall = overlap / sum(ref_counts.values()) if sum(ref_counts.values()) > 0 else 0
        return recall

    def meteor_score(self, hypothesis, reference):
        precision = self.alpha * self.compute_precision(hypothesis, reference, 1) + (1-self.alpha) * self.compute_precision(hypothesis, reference, 2)
        recall = self.beta * self.compute_recall(hypothesis, reference, 1) + (1-self.beta) * self.compute_recall(hypothesis, reference, 2)
        fmean = (1-self.gamma) * precision + self.gamma * recall if (precision != 0 and recall != 0) else 0
        return fmean

# %%
# !pip install jiwer
import jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading jiwer-3.0.5-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.9 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.5 rapidfuzz-3.10.1

# %%
meteor = MeteorScore(alpha=0.5, beta=0.5, gamma=0.5)

def wilWerMeteorScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    wer_score = 0
    meteor_score = 0
    wil_score = 0

    for i in range(lenS):
        wer_result = jiwer.wer(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])
        meteor_result = meteor.meteor_score(SummaryEv[columnName][i], SummaryEv['givenSummary'][i])
        wil_result = jiwer.wil(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])

        wer_score = wer_score + wer_result
        meteor_score = meteor_score + meteor_result
        wil_score = wil_score + wil_result

    wilWerMeteor_score = {'METEOR': meteor_score/lenS,
                    'WER': wer_score/lenS,
                    'WIL': wil_score/lenS}

    return wilWerMeteor_score
    # return spice_score/lenS

# %%
mx = wilWerMeteorScore('mT5_finetuned_test')
mx
# Out:
# {'METEOR': 0.3694995375541737,
#  'WER': 1.1714886828484485,
#  'WIL': 0.8061316430611867}

# %%
import pandas as pd

data = {'columns':['WIL', 'METEOR', 'WER'],
        'mT5_finetuned_test':[getScore(mx, 'WIL'), getScore(mx, 'METEOR'), getScore(mx, 'WER')],
       }

threeScoreDf = pd.DataFrame(data)
threeScoreDf_ = threeScoreDf
threeScoreDf = threeScoreDf.reset_index(drop=True).T
threeScoreDf = threeScoreDf.rename(columns=threeScoreDf.iloc[0]).drop(threeScoreDf.index[0])
threeScoreDf.reset_index(inplace=True)
threeScoreDf = threeScoreDf.rename(columns = {'index':'Summary'})
threeScoreDf
# Out:
#               Summary       WIL  METEOR       WER
# 0  mT5_finetuned_test  0.806132  0.3695  1.171489

# %%
import matplotlib.pyplot as plt

# plotting graph
threeScoreDf.plot(x="Summary",
               y=['WIL', 'METEOR', 'WER'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Three Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a bar chart
plt.figure(figsize=(12, 6))
bar_width = 0.35
x = np.arange(len(metrics))

plt.bar(x, values, width=bar_width, color='skyblue')
plt.xticks(x, metrics, rotation=45, ha='right')
plt.ylabel('Score')
plt.title('Evaluation Metrics for Text Summarization')

# Optionally add a grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a DataFrame
df = pd.DataFrame({'Metric': metrics, 'Score': values})

# Display the table
print(df)

# If you want to export the table to a CSV file
# df.to_csv('/content/summary_evaluation_metrics.csv', index=False)
# Out:
#                    Metric   Score
# 0            ROUGE-1 (F1)  0.1666
# 1            ROUGE-2 (F1)  0.0598
# 2            ROUGE-L (F1)  0.1535
# 3                  BLEU-1  0.1067
# 4                  BLEU-2  0.0529
# 5                  BLEU-3  0.0256
# 6                  BLEU-4  0.0104
# 7   BERTScore (Precision)  0.8277
# 8      BERTScore (Recall)  0.6640
# 9          BERTScore (F1)  0.7366
# 10                 METEOR  0.1642
# 11                    WER  3.1958

# %% [markdown]
# **DATA VISUALIZATION**

# %%
import matplotlib.pyplot as plt

human_lengths = genDf['givenSummary'].apply(lambda x: len(x.split()))
generated_lengths = genDf['mT5_finetuned_test'].apply(lambda x: len(x.split()))

plt.scatter(human_lengths, generated_lengths)
plt.xlabel('Human Summary Length')
plt.ylabel('Generated Summary Length')
plt.title('Human vs. Generated Summary Length')
plt.show()

# %%
gen_length = [len(summary.split()) for summary in genDf["mT5_finetuned_test"]]
ref_length = [len(summary.split()) for summary in genDf["givenSummary"]]

plt.figure(figsize=(10, 6))
plt.scatter(ref_length, gen_length, alpha=0.5)
plt.xlabel("Reference Summary Length (words)")
plt.ylabel("Generated Summary Length (words)")
plt.title("Generated vs. Reference Summary Length")
plt.plot([0, max(ref_length)], [0, max(ref_length)], color='red', linestyle='--')  # Diagonal line
plt.show()

# %% [markdown]
# # **TEST (NOT INCLUDED)**

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from normalizer import normalize  # Assuming you have this installed
import re

# Device setup
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# Load the model and tokenizer
model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Move the model to the correct device (GPU or CPU)
model.to(device)

# Define the whitespace handler
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

# Function to generate a summary
def generate_summary(input_text):
    # Normalize the text (if needed)
    input_text = normalize(input_text)

    # Tokenize the input text
    input_ids = tokenizer(
        [WHITESPACE_HANDLER(input_text)],
        return_tensors="pt",
        padding="max_length",
        max_length=512,
        truncation=True
    )["input_ids"]

    # Generate the summary
    output_ids = model.generate(
        input_ids=input_ids.to(device),
        max_length=400,
        min_length=64,
        no_repeat_ngram_size=2,
        num_beams=4
    )[0]

    # Decode the generated summary
    summary = tokenizer.decode(
        output_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return summary
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
# Example of custom input text
custom_text = """
  'ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়ার গাড়ি, বাড়ি, প্লট, ফ্ল্যাট-কী নেই। রীতিমতো গড়েছেন সম্পদের পাহাড়। শুধু নিজের
  নামেই নয়; স্ত্রী, ছেলে-মেয়ে এবং শ্যালক-শ্যালিকার নামেও গড়েছেন বিপুল সম্পত্তি।\nঅভিযোগ রয়েছে, ডিএমপিতে ‘ঘুষ’ এবং বদলি বাণিজ্যে গড়ে তুলেছেন এসব
  সম্পদ। তার বিপুল সম্পদের বিষয়ে অনুসন্ধান চালাচ্ছে দুর্নীতি দমন কমিশন (দুকক)। যুগান্তরের অনুসন্ধানি প্রতিবেদনে এসব তথ্য ওঠে এসেছে।\nপ্রতিবেদনে জানা যায়,
  রাজধানীর অভিজাত এলাকা সিদ্ধেশ্বরীর ভিকারুননিসা স্কুলের পাশেই রূপায়ণ স্বপ্ন নিলয়। ৫৫/১ হোল্ডিংয়ে আলিশান এ ভবনটি ১১ তলা। এখানে প্রায় সাড়ে ৩ হাজার বর্গফিটের
  একটি ফ্ল্যাট রয়েছে আছাদুজ্জামানের মেয়ে আয়েশা সিদ্দিকার নামে।\nশুক্রবার (২৩ আগস্ট) দুপুরে সেখানে গেলে নিরাপত্তা ইনচার্জ আবুল কালাম আজাদ যুগান্তরকে
   বলেন, তিনি মাস দেড়েক আগে এখানে চাকরি নিয়েছেন। এই ভবনে ১৩০টি ফ্ল্যাট। তাই সব ফ্ল্যাট মালিককে ভালোভাবে চিনেন না। বাড়ির ম্যানেজার সোহেল পারভেজ
    বিস্তারিত বলতে পারবেন বলে জানান তিনি।\nএ বিষয়ে সোহেল পারভেজ জানান, আয়েশা সিদ্দিকার নামে এখানে একটি ফ্ল্যাট আছে। তবে তিনি কখনো এখানে আসেন না।
    এটি ভাড়া দেওয়া আছে।\nধানমন্ডি ১২/এ নম্বর রোডের ৬৯ নম্বর বাড়িতে রয়েছে একটি বিলাসবহুল ফ্ল্যাট। শুক্রবার দুপুরে ওই বাড়িতে যাওয়া হলে ভেতরে প্রবেশের অনুমতি
    মেলেনি। তবে নিজের নাম প্রকাশ না করার শর্তে বাড়ির একজন নিরাপত্তাকর্মী জানান, ধানমন্ডির ১২-এ রোডের ৬৯ নম্বর বাড়ির দ্বিতীয় তলার পুরো ফ্লোরটি সাবেক ডিএমপি
    কমিশনার আছাদুজ্জামান মিয়া কিনেছেন। তবে এটি তার শ্যালকের নামে।\nওই ভবনের তৃতীয় তলার ফ্ল্যাটটি চট্টগ্রাম মেট্রোপলিটন পুলিশের (সিএমপি) সাবেক কমিশনার
    ইকবাল বাহারের। এ বিষয়ে পুলিশ সদর দপ্তরের ডিআইজি কৃষ্ণপদ রায় বলেন, ‘ইকবাল বাহার হলেন আছাদুজ্জামান মিয়ার খুবই ঘনিষ্ঠ। তাই তারা দুজন একই ভবনে
    থাকতেন। আমিও একাধিকবার সেখানে গিয়েছি। আছাদুজ্জামান মিয়া কমিশনার থাকা অবস্থায় ওই ভবনে থাকতেন।’\nশুক্রবার দুপুর আড়াইটায় ইস্কাটন গার্ডেন ১৩/এ
    প্রিয়নীড়ে গিয়ে জানা যায়, সেখানে আছাদুজ্জামানের স্ত্রীর নামে একটি ফ্ল্যাট রয়েছে। বিস্তারিত জানতে চাইলে নিরাপত্তাকর্মী আব্দুস সালাম ও শাহ আলম প্রতিবেদককে
    বলেন, ‘আমরা এখানে নতুন এসেছি, তাই তেমন কিছু জানি না।’\nভবনের ম্যানেজার আজাদ আহমেদ জানান, ১৪ তলা এই ভবনে ৪০টি ফ্ল্যাট আছে। বেশিরভাগ ফ্ল্যাটই
    ২১৩৩ বর্গফুটের। ভবনের ১১ তলায় আছাদুজ্জমানের স্ত্রী আফরোজা জামানের একটি ফ্ল্যাট আছে। তবে সেখানে তিনি থাকেন না। ফ্ল্যাটটি ভাড়া দেওয়া আছে। অভ্যর্থনাকারী
    আবু বকর প্রতি মাসে ভাড়া তুলে আছাদুজ্জামানের কাছে দিয়ে আসেন। ভাড়া বকেয়া পড়লে বা কোনো সমস্যা হলে আমি নিজে স্যারের সঙ্গে (আছাদুজ্জমান) যোগাযোগ
    করেন বলে জানান তিনি।\nখোঁজ নিয়ে জানা যায়, নিকুঞ্জ-১ এর ৮/এ রোডের ৬ নম্বর বাড়িটি আছাদুজ্জামানের ছোট ছেলে আসিফ মাহাদীনের নামে। শুক্রবার বিকালে
    সেখানে যাওয়া হলে বাড়িটি ভেতর থেকে বন্ধ পাওয়া যায়। বেশ কয়েকবার কলিংবেল টিপেও সাড়া পাওয়া যাচ্ছিল না। একপর্যায়ে পাশের চার নম্বর বাড়ির গাড়িচালকের
    সঙ্গে কথা হচ্ছিল এই প্রতিবেদকের। ওই গাড়িচালক জানান, আছাদুজ্জামান সপরিবারে এই বাড়িতে থাকতেন। সরকার পতনের পর তিনি বাড়ি ছেড়ে পালিয়ে গেছেন।
    অনুসন্ধানে আরও জানা যায়, এ ছাড়া বসুন্ধরা আবাসিক এলাকার এল ব্লকের ১ নম্বর রোডের ১৬৬ এবং ১৬৭ নম্বরে ১০ কাঠার ওপর ৬ তলাবিশিষ্ট আলিশান একটি বাড়ি
    আছাদুজ্জামানের স্ত্রী আফরোজা জামানের নামে। পূর্বাচলের নিউ টাউনের ১ নম্বর সেক্টরের ৪০৬/বি নম্বর রোডে ১০ কাঠা জমি রয়েছে আছাদুজ্জামান মিয়ার নামে। ওই জমিতে
     গাড়ি রাখার শেড বানিয়ে রাখা হয়েছে। পূর্বাচলের সেক্টর ৪, রোড ১০৮-এ ৫৩ নম্বর প্লটটি আছাদুজ্জামানের স্ত্রীর নামে ছিল। ৫ কাঠার এই প্লটটি বিক্রি করে দেওয়া হয়েছে।
     আফতাবনগরে ৩ নম্বর সেক্টরে রয়েছে ২১ কাঠা জমি। সেখানে নিজের নামে ১০ কাঠা ও আত্মীয়স্বজনদের নামে রয়েছে বাকি ১১ কাঠা জমি।\nআছাদুজ্জামান
     মিয়ার স্ত্রী আফরোজা জামানের নামে ঢাকা ছাড়াও ফরিদপুর ও নারায়ণগঞ্জে বিপুল সম্পদ রয়েছে। ২০১৮ সালে তিনি রাজউক থেকে বিশেষ কোটায় একটি প্লট বরাদ্দ
     পান। অথচ রাজউকের নীতিমালা অনুযায়ী, স্বামী-স্ত্রী উভয়ের প্লট বরাদ্দ পাওয়ার সুযোগ নেই।\nজানা গেছে, গাজীপুরের কালীগঞ্জ উপজেলার চাঁদখোলা মৌজায় আফরোজা
     জামানের নামে ৬৭ শতাংশ জমি রয়েছে। ২০১৭ সালে এই জমি কেনা হয়। ওই মৌজায় তার নামে ২০১৯ সালের ৫ ফেব্রুয়ারি কেনা হয় আরও ৩৯ শতাংশ জমি। একই নামে
     ২০২০ সালে জোয়ার সাহারা মৌজায় কেনা হয় ১৫ কাঠা জমি। ওই বছর গাজীপুরের চাঁদখোলা মৌজায় ৩১ শতক জমি ক্রয় করেন আফরোজা। আফরোজা ২০১৮ সালে
     নারায়ণগঞ্জের রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ২৮ একর জমি কেনেন। ওই বছর একই মৌজায় আরও ৩২ শতক জমি কেনেন তিনি। ওই বছরই
     রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ৬০ একর জমি তার নামে কেনা হয়। পরে তা বিক্রি করে দেওয়া হয়। ২০১৯ সালে কৈয়ামসাইল-কায়েতপাড়া মৌজায়
     দশমিক ৫৭ একর জমির পাওয়ার অব অ্যাটর্নি পান আছাদুজ্জামানের স্ত্রী। এরপর ওই জমি বিক্রিও করেন।\nঅনুসন্ধানে আছাদুজ্জামান মিয়ার পরিবারের সদস্যদের মালিকানার
     দুটি কোম্পানির খোঁজ পাওয়া গেছে। এর মধ্যে একটি হলো মৌমিতা ট্রান্সপোর্ট লিমিটেড। এর চেয়ারম্যান আছাদুজ্জামানের স্ত্রী আফরোজা। আছাদুজ্জামান ডিএমপি কমিশনার
     থাকাকালীন রাজধানীর রুট পারমিট কমিটির প্রধান ছিলেন। ওই সময় মৌমিতা পরিবহণকে রুট পারমিট দেওয়া হয়। মৌমিতা ট্রান্সপোর্ট লিমিটেডের ভাইস চেয়ারম্যান হারিসুর
     রহমান সোহান হলেন আছাদুজ্জামানের শ্যালক। সোহানের নামে রাজধানীর নিউমার্কেটে আছে স্বর্ণের দোকান।\nআরও জানা যায়, শেপিয়ার্ড কনসোর্টিয়াম লিমিটেড নামে
     আরেকটি কোম্পানির চেয়ারম্যান আফরোজা জামান। এই কোম্পানির পরিচালক আছাদুজ্জামানের বড় ছেলে আসিফ শাহাদাত। আছাদুজ্জামানের শ্যালক নূর আলম ওরফে
     মিলনের নামে গাজীপুরের শ্রীপুরে দেড় একর জমি রয়েছে। ভাগনে কলমের নামেও গাজীপুরে জমি আছে দেড় একর।\nএদিকে আছাদুজ্জামান মিয়ার অবৈধ সম্পদের
     অনুসন্ধান শুরু করেছে দুদক। সংস্থাটির সচিব খোরশেদা ইয়াসমীন গণমাধ্যমকে বলেন, আছাদুজ্জামান মিয়ার বিরুদ্ধে বিভিন্ন অনিয়ম ও দুর্নীতির মাধ্যমে কোটি কোটি
     টাকার অবৈধ সম্পদ অর্জনের অভিযোগ এসেছে। এই অভিযোগ অনুসন্ধানের সিদ্ধান্ত গৃহীত হয়েছে বলে জানান তিনি।\nআওয়ামী লীগ সরকারের পতনের কয়েকদিন আগে
     আছাদুজ্জামান মিয়া জানিয়েছিলেন, তার এবং পরিবারের সদস্যদের কোনো অবৈধ সম্পদ নেই। যেসব সম্পদ আছে সবই আয়কর বিবরণীতে উল্লেখ করা আছে। সরকারের
     কোনো সংস্থা যদি এসব সম্পদের বিষয়ে অনুসন্ধান চালায় তাহলে তিনি ও তার পরিবারের সদস্যরা ওই সংস্থাকে সহযোগিতা করবেন।'
"""

# Generate the summary for the custom input text
generated_summary = generate_summary(custom_text)

# Print the original text and its generated summary
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়া রীতিমতো গড়েছেন বিপুল সম্পত্তি। তার গাড়ি, বাড়ি, প্লট এবং ফ্ল্যাট-কী নেই। অনুসন্ধানে এসব তথ্য উঠে এসেছে।

# %%
custom_text2 = """
বাংলাদেশের অর্থনৈতিক অবস্থা উন্নতির দিকে ধাবিত হচ্ছে, বিশেষ করে গত কয়েক বছরে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।
অর্থনীতিবিদরা মনে করছেন, এই অগ্রগতি ধরে রাখতে পারলে বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার অন্যতম শক্তিশালী অর্থনীতিতে পরিণত হতে পারে।
"""

generated_summary = generate_summary(custom_text2)
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার সবচেয়ে শক্তিশালী দেশগুলোর একটি হিসেবে পরিণত হতে পারে বলে মনে করছেন অর্থনৈতিক বিশ্লেষকরা। এর মধ্যে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।

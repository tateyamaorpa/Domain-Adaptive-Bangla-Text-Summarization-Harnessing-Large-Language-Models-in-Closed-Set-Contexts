# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset I

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model

df = pd.read_csv('/content/drive/MyDrive/Colab/updatedstate.csv')
df.head()
# Out:
#                                                title  \
# 0  ‘সংবাদপত্রের ওপর আক্রমণ অত্যন্ত নিন্দনীয় ও শঙ্...
# 1             অক্টোবরে ৪৫২ সড়ক দুর্ঘটনায় নিহত ৪৭৫ জন
# 2  জলবায়ু ঝুঁকিপূর্ণ দেশগুলোর জন্য পর্যাপ্ত সহায়ত...
# 3     আমরা শুধু ফ্যাসিলিটেটর, কোনো শাসক না: ড. ইউনূস
# 4  বাংলাদেশ-ভারত সচিব পর্যায়ের আলোচনা ৯ বা ১০ ডিস...
#
#                                                 text  \
# 0  স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...
# 1  অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...
# 2  সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...
# 3  দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...
# 4  পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...
#
#                                              summary category
# 0  স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...    state
# 1  অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...    state
# 2  সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...    state
# 3  দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...    state
# 4  পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...    state

# %%
df
# Out:
#                                                  title  \
# 0    ‘সংবাদপত্রের ওপর আক্রমণ অত্যন্ত নিন্দনীয় ও শঙ্...
# 1               অক্টোবরে ৪৫২ সড়ক দুর্ঘটনায় নিহত ৪৭৫ জন
# 2    জলবায়ু ঝুঁকিপূর্ণ দেশগুলোর জন্য পর্যাপ্ত সহায়ত...
# 3       আমরা শুধু ফ্যাসিলিটেটর, কোনো শাসক না: ড. ইউনূস
# 4    বাংলাদেশ-ভারত সচিব পর্যায়ের আলোচনা ৯ বা ১০ ডিস...
# ..                                                 ...
# 473       ৬ ঘণ্টা পর ঢাকার সঙ্গে রেল যোগাযোগ স্বাভাবিক
# 474  জামালপুরে ছাত্র ইউনিয়নের সম্মেলনে হামলা, ডেইলি...
# 475  সংস্কারের আগে নির্বাচন কমিশন গঠনের প্রতিবাদ জা...
# 476  চিন্ময় কৃষ্ণ দাসের মুক্তির দাবিতে টাঙ্গাইল ও ব...
# 477  মহাসড়কে গুলিবিদ্ধ নারীর মরদেহ: ভোলা থেকে গ্রেপ...
#
#                                                   text  \
# 0    স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...
# 1    অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...
# 2    সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...
# 3    দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...
# 4    পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...
# ..                                                 ...
# 473  ঢাকার সঙ্গে সারাদেশের রেল যোগাযোগ স্বাভাবিক হয়...
# 474  জামালপুরে বাংলাদেশ ছাত্র ইউনিয়ন সরিষাবাড়ী উপজে...
# 475  নতুন নির্বাচন কমিশন (ইসি) প্রত্যাখ্যান এবং যে ...
# 476  বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ...
# 477  মুন্সীগঞ্জের শ্রীনগরে ঢাকা-মাওয়া মহাসড়ক থেকে ন...
#
#                                                summary category
# 0    স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...    state
# 1    অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...    state
# 2    সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...    state
# 3    দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...    state
# 4    পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...    state
# ..                                                 ...      ...
# 473  ঢাকার সঙ্গে সারাদেশের রেল যোগাযোগ স্বাভাবিক হয়...    state
# 474  জামালপুরে বাংলাদেশ ছাত্র ইউনিয়ন সরিষাবাড়ী উপজে...    state
# 475  নতুন নির্বাচন কমিশন (ইসি) প্রত্যাখ্যান এবং যে ...    state
# 476  বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ...    state
# 477  মুন্সীগঞ্জের শ্রীনগরে ঢাকা-মাওয়া মহাসড়ক থেকে ন...    state
#
# [478 rows x 4 columns]

# %%
# Move the 'category' column to the first position
columns = ['category'] + [col for col in df.columns if col != 'category']
df = df[columns]

# Save the updated DataFrame if needed
df.to_csv("updated_state_dataset.csv", index=False)

# %%
df
# Out:
#     category                                              title  \
# 0      state  ‘সংবাদপত্রের ওপর আক্রমণ অত্যন্ত নিন্দনীয় ও শঙ্...
# 1      state             অক্টোবরে ৪৫২ সড়ক দুর্ঘটনায় নিহত ৪৭৫ জন
# 2      state  জলবায়ু ঝুঁকিপূর্ণ দেশগুলোর জন্য পর্যাপ্ত সহায়ত...
# 3      state     আমরা শুধু ফ্যাসিলিটেটর, কোনো শাসক না: ড. ইউনূস
# 4      state  বাংলাদেশ-ভারত সচিব পর্যায়ের আলোচনা ৯ বা ১০ ডিস...
# ..       ...                                                ...
# 473    state       ৬ ঘণ্টা পর ঢাকার সঙ্গে রেল যোগাযোগ স্বাভাবিক
# 474    state  জামালপুরে ছাত্র ইউনিয়নের সম্মেলনে হামলা, ডেইলি...
# 475    state  সংস্কারের আগে নির্বাচন কমিশন গঠনের প্রতিবাদ জা...
# 476    state  চিন্ময় কৃষ্ণ দাসের মুক্তির দাবিতে টাঙ্গাইল ও ব...
# 477    state  মহাসড়কে গুলিবিদ্ধ নারীর মরদেহ: ভোলা থেকে গ্রেপ...
#
#                                                   text  \
# 0    স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...
# 1    অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...
# 2    সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...
# 3    দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...
# 4    পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...
# ..                                                 ...
# 473  ঢাকার সঙ্গে সারাদেশের রেল যোগাযোগ স্বাভাবিক হয়...
# 474  জামালপুরে বাংলাদেশ ছাত্র ইউনিয়ন সরিষাবাড়ী উপজে...
# 475  নতুন নির্বাচন কমিশন (ইসি) প্রত্যাখ্যান এবং যে ...
# 476  বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ...
# 477  মুন্সীগঞ্জের শ্রীনগরে ঢাকা-মাওয়া মহাসড়ক থেকে ন...
#
#                                                summary
# 0    স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...
# 1    অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...
# 2    সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...
# 3    দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...
# 4    পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...
# ..                                                 ...
# 473  ঢাকার সঙ্গে সারাদেশের রেল যোগাযোগ স্বাভাবিক হয়...
# 474  জামালপুরে বাংলাদেশ ছাত্র ইউনিয়ন সরিষাবাড়ী উপজে...
# 475  নতুন নির্বাচন কমিশন (ইসি) প্রত্যাখ্যান এবং যে ...
# 476  বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ...
# 477  মুন্সীগঞ্জের শ্রীনগরে ঢাকা-মাওয়া মহাসড়ক থেকে ন...
#
# [478 rows x 4 columns]

# %% [markdown]
# # Install and Imports

# %%
# !pip install sentencepiece
# !pip install transformers
# !pip install git+https://github.com/csebuetnlp/normalizer

import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

from normalizer import normalize # pip install git+https://github.com/csebuetnlp/normalizer


from transformers import XLMProphetNetForConditionalGeneration, XLMProphetNetTokenizer


from transformers import MBartForConditionalGeneration, AutoModelForSeq2SeqLM
from transformers import AlbertTokenizer, AutoTokenizer
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-wb4pwlql
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-wb4pwlql
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from normalizer==0.0.1) (2024.9.11)
# Collecting emoji==1.4.2 (from normalizer==0.0.1)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy==6.0.3 (from normalizer==0.0.1)
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.13)
# Building wheels for collected packages: normalizer, emoji, ftfy
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6860 sha256=9c8014e56f29862b3cc2c39f1380363ed935565ad51f1fed51c1c704e655a50f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d_zj88nv/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186455 sha256=331832dfb4ebaa3bf8c16fc17e73ffc6d9c9cd16a3aa95010ff6cdea87f841e0
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41931 sha256=2f9e68e912e278c703b39e3077dd08d23a34f4e3e0c42d1d0a932297f86e10a3
#   Stored in directory: /root/.cache/pip/wheels/92/8e/16/c1e4d4d65685d71085e4e27b44d6ed880b0559474c9ee4ff66
# Successfully built normalizer emoji ftfy
# Installing collected packages: emoji, ftfy, normalizer
# Successfully installed emoji-1.4.2 ftfy-6.0.3 normalizer-0.0.1

# %%
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ### Functions

# %%
def cleanText(text2clean):
    empty_string = ""

    space = chr(32)
    flag  = 0

    for i in range(len(text2clean)):
        if text2clean[i] != "'" and text2clean[i] != "\n":
            if text2clean[i] == space and flag == 0:
                flag = 1
                empty_string = empty_string + text2clean[i]
            elif text2clean[i] != space:
                empty_string = empty_string + text2clean[i]
                flag = 0
    return empty_string

# %% [markdown]
# # Model Loading

# %% [markdown]
# ### Model Setup

# %%
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

tokenizer_path = "/content/drive/MyDrive/Colab/mT5_Tokenizer_XLSum"
model_path = "/content/drive/MyDrive/Colab/mT5_Model_XLSum"

# Step 4: Load the tokenizer and model from the specified paths
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=250112, bias=False)
# )

# %% [markdown]
# ### Run dataset over the Model

# %%
df.columns
# Out:
# Index(['category', 'title', 'text', 'summary'], dtype='object')

# %%
rows = df.shape[0]
rows
# Out:
# 478

# %%
# Create empty DataFrame without the "title" column
genDf = pd.DataFrame(columns=["text", "givenSummary", "mT5_Test_XLSum"])

# Load over the dataset
for i in range(rows):
        article_text = normalize(df['text'][i])

        # Tokenize the input text
        input_ids = tokenizer(
            [WHITESPACE_HANDLER(article_text)],
            return_tensors="pt",
            padding="max_length",
            max_length=512,
            truncation=True
        )["input_ids"]

        # Generate the summary
        output_ids = model.generate(
            input_ids=input_ids.cuda(),
            max_length=400,
            min_length=64,
            no_repeat_ngram_size=2,
            num_beams=4
        )[0]

        # Decode the generated summary
        summary = tokenizer.decode(
            output_ids,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=False
        )

        # Add the text, given summary, and generated summary to the DataFrame
        genDf.loc[i] = [df['text'][i], df['summary'][i], summary]

        # Print the generated summary for verification
        print(i, '  ', summary)

# Save the DataFrame to CSV
genDf.to_csv('/content/drive/My Drive/Colab/state_zeroshot.csv')
# Out:
# 0    বাংলাদেশে স্বাধীন সাংবাদিকতার ওপর যে আক্রমণ হচ্ছে, এটা অত্যন্ত নিন্দনীয় ও শঙ্কাজনক বলে উল্লেখ করেছেন দ্য ডেইলি স্টার সম্পাদক ও প্রকাশক মাহফুজ আনাম। গত সরকারের তিনটি নির্বাচন যে একেবারেই অগ্রহণযোগ্য ছিল, সেই
# 1    বাংলাদেশে অক্টোবর মাসে সড়ক দুর্ঘটনায় নিহতের সংখ্যা ৪৭৫ জনে দাঁড়িয়েছে। এর মধ্যে রেলপথে বড় গর্ত সৃষ্টি হওয়ার কারণে যানবাহন চলাচলে ঝুঁকি বেড়েছে বলে জানিয়েছে বাংলাদেশ যাত্রীকল্যাণ সমিতি।
# 2    বাংলাদেশ জলবায়ু পরিস্থিতি মোকাবেলায় আন্তর্জাতিক ক্লাইমেট ক্লাবের সঙ্গে কাজ করতে ইচ্ছুক বলে মন্তব্য করেছেন অন্তর্বর্তী সরকারের একজন প্রধান উপদেষ্টা। তিনি বলেছেন, উষ্ণতা এক দশমিক পাঁচ ডিগ্রি সেলসিয়াসে সীমাবদ্ধ কর
# 3    শান্তিতে নোবেলজয়ী অধ্যাপক ড. মুহাম্মদ ইউনূস বাংলাদেশের প্রধান উপদেষ্টা হিসেবে আজ (বুধবার) প্রকাশিত হয়েছে দ্য ডেইলি স্টারের একান্ত সাক্ষাৎকার। এরপর তিনি বলেছেন, সরকারের কথা হলো না।
# 4    বাংলাদেশ ও ভারতের মধ্যে পররাষ্ট্র সচিব পর্যায়ের ফরেন অফিস কনসালটেশন (এফওসি) আগামী ১০ ডিসেম্বর ঢাকায় অনুষ্ঠিত হতে পারে বলে আশা করা হচ্ছে। এই আলোচনার প্রস্তুতি সমন্বয়ের জন্য আজ বুধবার একটি আন্ত:মন্ত্রণালয় ব
# 5    ভারতের ত্রিপুরার আগরতলায় বাংলাদেশের সহকারী হাইকমিশনের ভিসা ও কনস্যুলার সেবা কার্যক্রম বন্ধ ঘোষণা করা হয়েছে। হামলার ঘটনায় জড়িত থাকা ৭ জনকে বরখাস্ত করেছে ভারতীয় কর্তৃপক্ষ।
# 6    বাংলাদেশে বিরোধী দল বিএনপির মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর বলেছেন, 'আন্তহরণের কাজ থেকে সরে আসুন। গণতন্ত্রকে একটি প্রাতিষ্ঠানিক রূপ দেওয়ার জন্য সহযোগিতা করুন'।
# 7    বাংলাদেশে কোটা সংস্কার আন্দোলনের সময় রমিজ উদ্দিন আহমেদ রূপ ও মো. আল শাহরিয়ারের মৃত্যুর ঘটনায় আওয়ামী লীগের উপদেষ্টা পরিষদের সদস্য আমীর হোসেন আমুসহ পাঁচজনকে গ্রেপ্তার দেখানোর আদেশ দিয়েছে ঢাকা মহানগর হাকিম।
# 8    সরকারি প্রাথমিক বিদ্যালয়ের সহকারী শিক্ষক পদে তৃতীয় ধাপে উত্তীর্ণ ছয় হাজার ৫৩১ জন প্রার্থীকে নিয়োগপত্র দেওয়া স্থগিত করেছেন হাইকোর্ট। আদালত আজ মঙ্গলবার এই আদেশ দিয়েছেন।
# 9    বাংলাদেশ-ভারত ফরেন অফিস কনসালটেশনের (এফওসি) পরবর্তী রাউন্ডে যোগ দিতে ভারতীয় প্রতিনিধি দল ডিসেম্বরের মাঝামাঝিতে ঢাকা সফরে আসছেন বলে জানিয়েছেন পররাষ্ট্র মন্ত্রণালয়ের একজন কর্মকর্তা।
# 10    বাংলাদেশের স্বাধীনতা আন্দোলনের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস আজ রোববার জাতির উদ্দেশে ভাষণ দেবেন বলে জানিয়েছে সরকারের প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। তিনি বলেছেন, 'আন্তর্জাতিক সম্প্রদায়কে বিভ্রান্ত করার জন্য আমরা সবচেয়ে ব
# 11    বিশ্বব্যাপী 'চ্যালেঞ্জ ও জটিলতা' মোকাবিলা করতে সবাইকে একযোগে কাজ করার ওপর গুরুত্বারোপ করেছেন বাংলাদেশের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস। এই আহ্বান জানিয়েছেন তিনি।
# 12    বাংলাদেশে পুলিশ বাহিনীর সদস্যের দুর্নীতি, অসদাচরণ বা শৃঙ্খলা ভঙ্গের ঘটনার ক্ষেত্রে কোনো ছাড় দেওয়া হবে না, বলে জানিয়েছেন ঢাকার মহাপরিদর্শক বাহারুল আলম। তিনি বলেছেন, এই আন্দোলনের জের ধরে ফ্যাসিবাদি সরকারের স্বার্থ
# 13    বাংলাদেশের বগুড়া কারাগারে সোমবার দিবাগত রাতে চিকিৎসাধীন অবস্থায় এক আওয়ামী লীগ নেতার মৃত্যু হয়েছে। জেল সুপার ফারুক আহমেদ জানিয়েছেন, তিনি মৃত ছিলেন বলে জানাচ্ছেন জেলা আওয়ার সম্পাদক শহিদুল ইসলাম রতন।
# 14    ভারত বাংলাদেশের সঙ্গে একটি স্থায়ী, স্থিতিশীল ও গঠনমূলক সম্পর্ক চায় বলে মন্তব্য করেছেন বাংলাদেশে নিযুক্ত  ভারতীয় হাইকমিশনার প্রণয় ভার্মা। তিনি বলেছেন, দুই দেশের আন্তঃনির্ভরতাগুলো পারস্পরিক কল্যাণের ভিত্তিতে এগিয়ে নিতে আগ্রহী
# 15    বাংলাদেশে বিরোধী দল বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমানের বিরুদ্ধে রাষ্ট্রদ্রোহিতার দুটি মামলা খারিজ করে দিয়েছেন আদালত। এর মধ্যে বঙ্গবন্ধু শেখ মুজিবকে নিয়ে কটূক্তি করার অভিযোগ উঠেছে।
# 16    ব্রাহ্মণবাড়িয়ার বাঞ্ছারামপুরে বিএনপির সম্মেলন বন্ধের দাবিতে একটি পক্ষের বিক্ষোভ মিছিলে হামলা ওপাল্টা-হামলার ঘটনা ঘটেছে। এতে অন্তত ৫৪ জন আহত হয়েছেন।
# 17    বাংলাদেশে অন্তর্বর্তী সরকারের উপদেষ্টা পরিষদে কতজন থাকবেন, এসব বিষয়ে দেশের রাজনৈতিক দলগুলোর সঙ্গে সমন্বয়ের প্রয়োজন নেই বলে মন্তব্য করেছে বিএনপির মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর।
# 18    বাংলাদেশের পররাষ্ট্র মন্ত্রণালয় বলছে, চিন্ময় কৃষ্ণ দাসকে গ্রেপ্তারের বিষয়ে ভারতের বিবৃতি 'তথ্যগত বিভ্রান্তিকর' এবং বাংলাদেশ সরকারের প্রতিশ্রুতি ও প্রচেষ্টাকে প্রতিফলিত করে না।
# 19    বাংলাদেশে বকেয়া বেতন পরিশোধ, কারখানা চালু ও শ্রমিক ছাঁটাই বন্ধের দাবিতে বিক্ষোভ করেছেন গাজীপুরের চারটি কারখানায় শ্রমিকরা। এরপর থেকে ঢাকা-টাঙ্গাইল মহাসড়ক অবরোধ করেছে তারা।
# 20    পুলিশের সদ্য সাবেক মহাপরিদর্শক (আইজিপি) মো. ময়নুল ইসলামকে রাষ্ট্রদূত হিসেবে বদলি করা হয়েছে। অপরদিকে, প্রশাসনে বড় পরিবর্তন এনে চার অতিরিক্ত সচিবকে বিভাগীয় কমিশনার নিয়োগ দিয়েছে জনপ্রশাসন মন্ত্রণালয়।
# 21    বাংলাদেশের স্বাধীনতার স্বপ্নদ্রষ্টা মওলানা আবদুল হামিদ খান ভাসানীর মৃত্যুর ৪৮তম বার্ষিকী আজ। তার স্মৃতিচিহ্নগুলো জরুরি রক্ষণাবেক্ষণ এবং যত্ন প্রয়োজন।
# 22    বাংলাদেশের প্রধান নির্বাচন কমিশনার (সিইসি) এএমএম নাসির উদ্দীন জাতিসংঘকে জানিয়েছেন, তারা বর্তমান নির্বাচনে স্বচ্ছতা বজায় রাখতে দৃঢ়প্রতিজ্ঞ এবং তাদের প্রতি অন্তর্বর্তী সরকারের সমর্থন পাবে।
# 23    বাংলাদেশে বিএনপি চেয়ারপারসন খালেদা জিয়া এবং তারেক রহমানের বিরুদ্ধে দায়ের করা মামলার কার্যক্রম বাতিল করেছে হাইকোর্ট। এর আগে ২০১৬ সালে প্রধানমন্ত্রী শেখ হাসিনাকে হত্যার হুমকি দেয়া হয়েছিল।
# 24    বাংলাদেশের সেনাবাহিনী শিল্পাঞ্চলে অবৈধ ব্যবসা বা অনৈতিক সুযোগ-সুবিধা পাওয়ার চেষ্টা করলে তাদের বিরুদ্ধে আইনানুগ ব্যবস্থা গ্রহণের জন্য অভিযোগ প্রদানের অনুরোধ জানিয়েছে দেশটির সেনা কর্মকর্তাদের কাছে।
# 25    বাংলাদেশের নারায়ণগঞ্জের সোনারগাঁও উপজেলায় বসুন্ধরা গ্রুপের বশুরর্রা পেপার মিলস লিমিটেড কারখানায় বিস্ফোরণের ঘটনায় অন্তত ১০ শ্রমিক দগ্ধ হয়েছেন। তারা হাসপাতালে ভর্তি আছেন।
# 26    বাংলাদেশের খুলনা বিশ্ববিদ্যালয়ের (খুবি) শিক্ষার্থী ও মোটর শ্রমিকদের মধ্যে ধাওয়াপাল্টা-ধাওয়ার ঘটনা ঘটেছে। এতে কয়েকজন ছাত্র আহত হয়েছে বলে নিশ্চিত করেছে বিশ্ববিদ্যালয়টির সমন্বয়ক মো. মুহিবুল্লাহ।
# 27    বাংলাদেশের দুর্নীতি দমন কমিশনের প্রধান উপদেষ্টার প্রেস সচিব শফিকুল আলম বলেছেন, পতিত স্বৈরাচারী সরকার তাদের পতনের কিছুদিন আগে ৬০ হাজার টাকা ছাপিয়েছিল এস আলমের গ্রুপকে পাচারে সাহায্য করার জন্য।
# 28    বাংলাদেশের ছাত্র-জনতার অভূতপূর্ব অভ্যুত্থানের ভেতর দিয়ে নব ইতিহাসের সাক্ষী হওয়া 'নতুন বাংলাদেশে' বিস্ময়ির বিরুদ্ধে স্মৃতির লড়াই জারি রাখার আহ্বান এসেছে ইংরেজি দৈনিক দ্য ডেইলি স্টারের এক প্রদর্শনী থেকে।
# 29    বাংলাদেশে চট্টগ্রামে আইনজীবী হত্যার নিন্দা জানিয়ে তদন্ত ও যথাযথ আইনি প্রক্রিয়ার নির্দেশ দিয়েছেন সরকারের প্রধান উপদেষ্টা অধ্যাপক মুহাম্মদ ইউনূস। এর মধ্যে একজন আদালত কর্মকর্তাকে কুপিয়ে হত্যা করা হয়েছে।
# 30    বাংলাদেশের চট্টগ্রাম নগরীতে মেয়াদোত্তীর্ণ প্রায় ১৩ হাজার সিএনজিচালিত অটোরিকশার স্ক্র্যাপ গ্যাস সিলিন্ডার নিয়ে বিপাকে পড়েছে বাংলাদেশ সড়ক পরিবহন কর্তৃপক্ষের (বিআরটিএ) বিভাগীয় অফিস।
# 31    বাংলাদেশে বিরোধী দল বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমান বলেছেন, বিতাড়িত স্বৈরাচার দেশে সাম্প্রদায়িক পরিস্থিতি তৈরির অপেক্ষায় লিপ্ত হয়েছে কি না সরকারকে এ বিষয়ে গভীরভাবে খতিয়ে দেখতে হবে।
# 32    বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমান আয়কর ফাঁকি দেওয়ার অভিযোগে করা মামলা থেকে অব্যাহতি পেয়েছেন বলে আদেশ দিয়েছে ঢাকার বিশেষ জজ আদালত। এর আগে তারেকের বিরুদ্ধে অর্থ আত্মসাতের অপরাধ ঘোষণা করেছে জাতীয় রাজস্ব বোর্ড।
# 33    বাংলাদেশে অমর একুশে বইমেলার জন্য সোহরাওয়ার্দী উদ্যান বরাদ্দ দেয়নি গৃহায়ণ ও গণপূর্ত মন্ত্রণালয়। কিন্তু আগামী বইমেলা শুধু বাংলা একাডেমি প্রাঙ্গণেই আয়োজিত হবে।
# 34    বাংলাদেশে বিরোধী দল বিএনপি মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর বলেছেন, বর্তমান সরকারকে সব সমস্যাকে রাজনীতিকভাবে না দেখে আলোচনার মাধ্যমে সমাধান করতে হবে বলে তিনি এই মন্তব্য করেছেন।
# 35    চুক্তির শর্ত লঙ্ঘনের অভিযোগে বেসরকারিভাবে পরিচালিত ২৪ ট্রেনের লিজ বাতিলের সিদ্ধান্ত নিয়েছে বাংলাদেশ রেলওয়ের মহাপরিচালক সরদার শাহাদাত আলী দ্য ডেইলি স্টার। এর আগে থেকেই তারা নতুন করে টেন্ডার ছাড়াই তাদের কার্যক্রম শুরু
# 36    বাংলাদেশে ইসকনের সাবেক নেতা চিন্ময় কৃষ্ণ দাসকে গ্রেপ্তারের প্রতিবাদে ভারতের ত্রিপুরা রাজ্যের আগরতলায় হিন্দু সনাতন নাগরিক সমাজ ও অন্যান্য সংগঠনের কর্মীরা বিক্ষোভ করেছেন।
# 37    ১৯ জুলাই রাত ১২টার পরের কথা। ঢাকায় কারফিউ ঘোষণা হওয়ার পর থেকে সেটা দেখার সুযোগ হাতছাড়া করতে চাইনি। আজ রাতে বের হলাম খিলগাঁও ফ্লাইওভারের উপর।
# 38    বাংলাদেশের কুষ্টিয়া জেলার জগতি রেলস্টেশনের আধুনিকায়নসহ ছয় দফা দাবিতে বেনাপোল এক্সপ্রেস ট্রেন আটকে দেওয়ার পর ঢাকার উদ্দেশে ছেড়ে গেছে। এর আগে দুই ঘণ্টা পর আন্তঃনগর ટ્રેন ছাড়ে।
# 39    বাংলাদেশে প্রতিবেশী দেশের গণমাধ্যম বাংলাদেশের বিভিন্ন বিষয়ে মিথ্যা সংবাদ প্রচার করে উসকানি দিচ্ছে বলে অভিযোগ করেছেন স্বরাষ্ট্র উপদেষ্টা লেফটেন্যান্ট জেনারেল (অব.) জাহাঙ্গীর আলম চৌধুরী।
# 40    বাংলাদেশে রাজধানী ঢাকার রাস্তায় ব্যাটারিচালিত রিকশা ও অটোরিকশার চলাচল বন্ধে হাইকোর্টের দেওয়া আদেশ স্থগিত চেয়ে সুপ্রিম কোর্টের আপিল বিভাগে আবেদন করতে যাচ্ছে সরকার।
# 41    বাংলাদেশের নৌ পরিবহন এবং শ্রম ও কর্মসংস্থান মন্ত্রণালয় বলেছে, পার্শ্ববর্তী দেশ ভারত আমাদের নিয়ে তাদের মিডিয়াতে নানা অপপ্রচার চালাচ্ছে। কিন্তু এসব করার কোনো কারণ নেই বলে তারা বলছেন।
# 42    বাংলাদেশের রাঙ্গামাটি জেলার বাঘাইছড়ি উপজেলায় দুই আঞ্চলিক গ্রুপের মধ্যে গোলাগুলির ঘটনার পর বুধবার সাজেক হিল ভিউ কটেজের ভ্রমণে পর্যটকদের নিরুৎসাহিত করেছে জেলা প্রশাসন।
# 43    আওয়ামী লীগ সমর্থকদের ওপর হামলার ঘটনায় কর্তৃপক্ষকে দ্রুত ও নিরপেক্ষভাবে তদন্ত করে অপরাধীদের জবাবদিহিতার আনতে হবে বলে আহ্বান জানিয়েছে মানবাধিকার সংস্থা অ্যামনেস্টি ইন্টারন্যাশনাল।
# 44    বাংলাদেশের রাজধানী ঢাকায় ব্যাটারি রিকশা বন্ধের সিদ্ধান্তের প্রতিবাদে আগারগাঁওয়ে সড়ক অবরোধ করেছেন বিক্ষোভকারীরা। তারা বলছেন, তাদের দাবি পূরণ না হওয়া পর্যন্ত রাস্তা ছাড়বেন না।
# 45    বাংলাদেশে বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমান ও সাবেক স্বরাষ্ট্র প্রতিমন্ত্রী লুৎফুজ্জামান বাবরসহ আসামিদের সবাইকে খালাস দেওয়ার ঘটনাকে বিজয়ের মাসের প্রথম দিনের 'সুসংবাদ' হিসেবে অভিহিত করেছেন দলের জ্যেষ্ঠ নেতা।
# 46    বাংলাদেশের আইনশৃঙ্খলা বিষয়ক প্রধান উপদেষ্টার প্রেস সচিব শফিকুল আলম বলেছেন, গত বছরের অক্টোবরের তুলনায় এবছরে দেশে হত্যার ঘটনা কমেছে বলে তিনি জানিয়েছেন।
# 47    চাঁদাবাজির বিরুদ্ধে শক্ত অবস্থান নেওয়ার ঘোষণা দিয়েছেন ঢাকা মহানগর পুলিশের (ডিএমপি) নবনিযুক্ত কমিশনার শেখ মো. সাজ্জাত আলী। তিনি বলেছেন, এ ধরনের চাাঁদাবাজি আর সহ্য করা হবে না।
# 48    বাংলাদেশের পররাষ্ট্র বিষয়ক উপদেষ্টা তৌহিদ হোসেন বলেছেন, রোহিঙ্গা সংকট সমাধানে বাংলাদেশ তার প্রধান প্রতিবেশী দেশগুলোর কাছ থেকে আশানুরূপ সমর্থন পায়নি। কিন্তু এটি বাকি বিশ্বের জন্য সমস্যা হয়ে উঠবে বলে তিনি মনে করেন না।
# 49    ভারতের আদানি গ্রুপের সঙ্গে করা একতরফা বিদ্যুৎ চুক্তি পর্যালোচনা অথবা বাতিলের নির্দেশনা চেয়ে হাইকোর্টে রিট আবেদন করেছেন সুপ্রিম কোর্টের একজন আইনজীবী। এর আগে আদানি (ঝাড়খণ্ড) লিমিটেডের যোগ দেয়া একটি
# 50    ভারতের আগরতলায় বাংলাদেশ সহকারী হাইকমিশনে হামলা এবং পশ্চিমবঙ্গের কলকাতার উপহাইকমিশনের সামনে বিক্ষোভের পর দুই মিশনের প্রধানকে ঢাকায় ফিরতে বলা হয়েছে। এই ঘটনার প্রেক্ষাপটে তাদের দেশে ফেরার কথা রয়েছে।
# 51    ঢাকা ও নয়াদিল্লির মধ্যে দ্বিপক্ষীয় সম্পর্ক উন্নয়নের জন্য ভারতকে বাংলাদেশের দীর্ঘদিনের উদ্বেগ নিরসন করতে হবে বলে মন্তব্য করেছেন পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন। তিনি বলেছেন, তিস্তার পানিবণ্টন চুক্তি বা সীমান্তে হত্যার ম
# 52    রাজধানীতে ব্যাটারিচালিত রিকশা ও অটোরিকশার চলাচল বন্ধে হাইকোর্টের আদেশ এক মাসের জন্য স্থগিত করেছেন সুপ্রিম কোর্টে চেম্বার জজ আদালত। ঢাকার রাস্তায় এসব যানবাহনের কার্যক্রম চলবে আগামীকাল থেকে।
# 53    বাংলাদেশে দিনব্যাপী অনুষ্ঠানের মাধ্যমে আজ রোববার মৌলভীবাজারে গারোদের ঐতিহ্যবাহী উৎসব ওয়ানগালা উদযাপিত হয়েছে। যার মূল আকর্ষণ ছিল নতুন ফসলের আগমন।
# 54    বাংলাদেশে জাতীয় সংসদে সংরক্ষিত নারী আসন বাড়িয়ে সেগুলোতে সরাসরি ভোটের মাধ্যমে জনপ্রতিনিধি নির্বাচনের জন্য সুপারিশ করেছেন বিভিন্ন গণমাধ্যমের সম্পাদকরা। নির্বাচন ব্যবস্থা সংস্কার কমিশনের সঙ্গে মতবিনিময় সভায় তারা এমন সুপারেিশ করছেন।
# 55    বাংলাদেশের রাজধানী ঢাকায় ব্যাটারিচালিত রিকশা বন্ধের সিদ্ধান্তের প্রতিবাদে আজও আন্দোলনে নেমেছেন রিজেন্ট হাসপাতালের কর্মী ও যাত্রীরা। এর মধ্যে বনানী বিমানবন্দরের তীব্র যানজট সৃষ্টি হয়েছে।
# 56    নারায়ণগঞ্জের সোনারগাঁয়ে মেঘনা গ্রুপের টিস্যু কারখানার আগুন ১৩ ঘণ্টায়ও পুরোপুরি নেভেনি বলে জানিয়েছে ফায়ার সার্ভিস। এ ঘটনায় এখন পর্যন্ত হতাহতের কোনো খবর পাওয়া যায়নি।
# 57    বাংলাদেশে কোটা সংস্কার আন্দোলনে নিহত ভোলার নয়ন বাড়িতে ফিরে আসার দাবিকে ঘিরে ফেসবুকে বিভিন্ন ব্যক্তির ছবি পোস্ট করে গুজব ছড়ানো হচ্ছে। এর মধ্যে একজন সাবেক বিধবা স্ত্রীর সাথে হাসিমুখে থাকা নয়নের ছেলে
# 58    চট্টগ্রাম শাহ আমানত আন্তর্জাতিক বিমানবন্দরের বহির্গমন লাউঞ্জ থেকে ৫০ লাখ টাকা মূল্যের বিদেশি মুদ্রা জব্দ ও এক যাত্রীকে আটক করেছেন কাস্টমস ও জাতীয় নিরাপত্তা সংস্থার কর্মকর্তারা।
# 59    বাংলাদেশে ২০০৪ সালের ২১শে আগস্টের গ্রেনেড হামলার ঘটনায় নতুন করে শুনানি শুরু করেছে ঢাকার নিম্ন আদালত। কিন্তু দণ্ডিতদের আপিল রায়ের অপেক্ষায় রয়েছে হাইকোর্ট।
# 60    বাংলাদেশে আন্তর্জাতিক অপরাধ (ট্রাইব্যুনাল) অধ্যাদেশ ২০২৪ এর খসড়ার অনুমোদন দিয়েছে অন্তর্বর্তী সরকারের উপদেষ্টা পরিষদ। এই খবরে রাজনৈতিক দলের বিধান রাখা হয়েছে না।
# 61    বাংলাদেশের চট্টগ্রামে আইনশৃঙ্খলা রক্ষাকারী বাহিনীর সঙ্গে বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র চিন্ময় কৃষ্ণ দাসের অনুসারীদের সংঘর্ষের ঘটনা ঘটেছে। এর মধ্যে আহত হয়েছেন সাংবাদিকসহ অন্তত ১০ জন।
# 62    বাংলাদেশে গণমাধ্যম ও সামাজিক মাধ্যমে শেখ হাসিনার বিদ্বেষপূর্ণ বক্তব্য প্রচারে নিষেধাজ্ঞা চেয়ে আন্তর্জাতিক অপরাধ ট্রাইব্যুনালে আবেদন করেছে রাষ্ট্রপক্ষ। এর আগে দেশে সংঘটিত গণহত্যার অভিযোগের তদন্ত শেষ করা হয়েছে।
# 63    ফেনীর সাবেক সংসদ সদস্য নিজাম উদ্দিন হাজারী ও জেলা আওয়ামী লীগের সাধারণ সম্পাদক শাখাওয়াত হোসেন ভূঁঞাসহ ৬৮ জনের বিরুদ্ধে হত্যাচেষ্টার মামলার তদন্ত শুরু করেছে ফেনী সদর উপজেলা আমলী আদালতের বিচারক।
# 64    বাংলাদেশে সাংবাদিক মুন্নী সাহাকে শর্ত সাপেক্ষে ছেড়ে দিয়েছে পুলিশ। ঢাকার তেজগাঁও থানায় তাকে আটক করা হয়েছিল এবং সাধারণ মানুষের কাছে মুচলেকা নিয়ে তিনি উপস্থিত হবেন।
# 65    ২০০৪ সালের ২১ আগস্ট ঢাকার বঙ্গবন্ধু অ্যাভিনিউয়ে আওয়ামী লীগের সমাবেশে গ্রেনেড হামলার ঘটনায় বিএনপির সাবেক স্বরাষ্ট্র প্রতিমন্ত্রী লুৎফুজ্জামান বাবরসহ ১৯ জনকে যাবজ্জীবন কারাদণ্ড দেওয়া হয়েছে।
# 66    ২০১৬ সালের ৫ জুন চট্টগ্রামে স্ত্রী মাহমুদা খানম মিতুকে হত্যা মামলায় সাবেক পুলিশ সুপার বাবুল আক্তারকে অন্তর্বর্তীকালীন জামিন দিয়েছেন হাইকোর্ট। এরপর তাকে জেল থেকে মুক্তি দেওয়া হবে না।
# 67    বাংলাদেশের রাজধানী ঢাকায় কয়েকটি কলেজের শিক্ষার্থীদের মধ্যে সংঘর্ষের ঘটনায় সরকার ছাত্র-ছাত্রীদের কোনো ধরনের সংঘাতের প্রতি নজর রাখার আহ্বান জানিয়েছে বলে প্রধান উপদেষ্টার প্রেস সচিব শফিকুল আলম জানিয়েছেন।
# 68    বাংলাদেশে রাষ্ট্রদ্রোহের মামলায় গ্রেপ্তার সনাতনী জাগরণ জোটের মুখপাত্র চিন্ময় কৃষ্ণ দাস ব্রহ্মচারীর জামিন আবেদনের শুনানি আগামী ২ জানুয়ারি ধার্য করেছে চট্টগ্রামের একটি আদালত।
# 69    বাংলাদেশে হজে যেতে ইচ্ছুক ব্যক্তিদের জন্য প্রাথমিক নিবন্ধনের সময় আগামী ১৫ ডিসেম্বর পর্যন্ত বাড়ানোর সিদ্ধান্ত ঘোষণা করেছে দেশটির ধর্ম মন্ত্রণালয়। এর মধ্যে তিন লাখ টাকা জমা দিয়ে চূড়ান্ত নিবন্ধন করা যাবে।
# 70    বাংলাদেশের সুন্দরবনে অস্ত্রের মুখে দুই জেলেকে অপহরণ করা হয়েছে বলে অভিযোগ পাওয়া গেছে। বনবিভাগের কর্মকর্তারা বলছেন, অপহরণের শিকার দুইজনের সন্ধান মেলেনি বলে তারা জানাচ্ছেন। এ ঘটনায় পুলিশের পক্ষ থেকে তদন্ত শুরু হয়েছে।
# 71    বাংলাদেশের চট্টগ্রামে পুলিশের ওপর হামলা ও কাজে বাধাদানের মামলায় গ্রেপ্তার আটজনকে রিমান্ডে পাঠানোর আদেশ দিয়েছে আদালত। এর মধ্যে তিনজন পরিছন্নতাকর্মীও রয়েছেন।
# 72    বাংলাদেশের প্রধান উপদেষ্টা অধ্যাপক ড. মুহাম্মদ ইউনূস দক্ষিণ এশিয়ার দেশগুলোর অভিন্ন স্বার্থে আঞ্চলিক সংস্থা সার্ককে পুনরুজ্জীবিত করার আহ্বান জানিয়েছেন। তিনি বলেছেন, এটি পুরো অঞ্চলের মানুষের কল্যাণ বয়ে আনবে।
# 73    বাংলাদেশে রাজধানীর ট্রাফিক ব্যবস্থা উন্নয়নে সেনা, নৌ, বিমান বাহিনীসহ বিভিন্ন আইনশৃঙ্খলাবাহিনী থেকে অবসরপ্রাপ্ত সদস্যদের নিয়ে কমিউনিটি পুলিশ গঠনের পরিকল্পনা করছে সরকার।
# 74    বাংলাদেশের সনাতন জাগরণ মঞ্চের চিন্ময় কৃষ্ণ দাসের গ্রেপ্তারকে ভুলভাবে ব্যাখ্যা করা হচ্ছে বলে জাতিসংঘের জেনেভায় জানিয়েছে বাংলাদেশ। এর মধ্যে 'অতিরঞ্জিত, ভিত্তিহীন ও বানোয়াট প্রতিবেদন এবং বিভ্রান্তির ছড়াছড়ি'
# 75    গাজীপুরের শ্রীপুরে পিকনিক বাস বিদ্যুতায়িত হয়ে ইসলামিক ইউনিভার্সিটি অব টেকনোলজির (আইইউটি) তিন শিক্ষার্থী মারা যাওয়ার ঘটনায় চার সদস্যের তদন্ত কমিটি গঠন করা হয়েছে।
# 76    বাংলাদেশে সংখ্যালঘু ইস্যু নিয়ে ব্যাপক প্রোপাগান্ডা চালানো হচ্ছে বলে জানিয়েছে সরকার ঢাকায় অবস্থানরত বিদেশি কূটনীতিকদের জানানো হয়েছে, বাংলাদেশের সমাজ বরাবরই সাম্প্রদায়িক সম্প্রীতি বজায় রেখে এসেছে।
# 77    লালমনিরহাটের পাটগ্রাম উপজেলায় অটোরিকশাচালক হাসানুর রহমান (২৯) মারা গেছেন। তার স্বজনের দাবি, স্থানীয় বাসিন্দাদের মারধরে আহত হয়ে তার মৃত্যু হয়েছে। তিনি কোনোদিনই চুরির সঙ্গে জড়িত ছিলেন না।
# 78    বাংলাদেশে শিক্ষার্থী-জনতার গণঅভ্যুত্থানে ক্ষমতাচ্যুত প্রধানমন্ত্রী শেখ হাসিনার বিরুদ্ধে জুলাই-আগস্টের 'গণহত্যা' মামলার তদন্ত আগামী এক মাসে শেষ করার নির্দেশ দিয়েছেন আন্তর্জাতিক অপরাধ ট্রাইব্যুনাল।
# 79    বাংলাদেশে রাজধানীর সরকারি তিতুমীর কলেজকে বিশ্ববিদ্যালয় করার দাবিতে মহাখালীতে রেললাইন অবরোধ করেছেন শিক্ষার্থীরা। এর আগে কলেজের প্রথম বর্ষে স্লোগান দেওয়ার পর তারা সড়কে নেমে বিক্ষোভ শুরু করেন।
# 80    বাংলাদেশের অন্যতম বৃহত্তম ইসলামী ব্যাংক এস আলম গ্রুপের বিরুদ্ধে ১ হাজার ৯৬৪ কোটি টাকার ঋণখেলাপি মামলা দায়ের করেছে জনতা ব্যাঙ্কের চৌমুহনী করপোরেট শাখা।
# 81    বাংলাদেশের পঞ্চগড়ের সদর উপজেলার মোমিনপাড়া সীমান্তের বাংলাদেশ অংশে এক বাংলাদেশি যুবকের মরদেহ পাওয়া গেছে। সেখানে ভারতীয় সীমান্তরক্ষী বাহিনীর (বিএসএফ) চানাকিয়া ক্যাম্পের সদস্যরা তাদের ধাওয়া দেয়।
# 82    বাংলাদেশে বিএনপির ভাইস চেয়ারম্যান আলতাফ হোসেন চৌধুরীকে দুর্নীতির মামলা থেকে খালাস দিয়েছে ঢাকার একটি আদালত। তাকে ন্যায়বিচার দেয়া হয়েছে বলে সাবেক স্বরাষ্ট্রমন্ত্রী বলেছেন।
# 83    বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র চিন্ময় কৃষ্ণ দাসের গ্রেপ্তার এবং তার জামিন নামঞ্জুরের পর সংঘর্ষে আইনজীবী সাইফুল ইসলাম হত্যার ঘটনায় সামাজিক যোগাযোগমাধ্যমে নানা ধরনের অপতথ্য ছড়িয়েছে বলে জানিয়েছে ফ্যাক্ট
# 84    বাংলাদেশে পুলিশ সংস্কার কমিশনের এক জরিপে প্রথম অবস্থানে রয়েছে রাজনৈতিক প্রভাবমুক্ত ও দুর্নীতিমুক্ত। অন্যদিকে ভুয়া বা গায়েবি মামলার অপসংস্কৃতির মাধ্যমে আর্থিক লেনদেন বন্ধে আইনগত ক্ষমতা প্রদান সমর্থন করেছেন শতকরা ৯৫
# 85    বাংলাদেশের সাবেক মেজর জেনারেল ও ন্যাশনাল টেলিকমিউনিকেশন মনিটরিং সেন্টারের (এনটিএমসি) প্রধান জিয়াউল আহসান বলেছেন, আয়নাঘর নামে পরিচিতি পাওয়া গোপন বন্দিশালার সঙ্গে তার কোনো সম্পৃক্ততা নেই।
# 86    বাংলাদেশে নির্দলীয় তত্ত্বাবধায়ক সরকার ব্যবস্থা প্রবর্তন করে আনা সংবিধানের ত্রয়োদশ সংশোধনী বাতিলের রায় পুনর্বিবেচনা (রিভিউ) চেয়ে তিনটি আবেদনের ওপর শুনানির দিন হিসেবে ১৯ জানুয়ারি ধার্য করেছে আপিল বিভাগ।
# 87    বাংলাদেশে হজের প্রাথমিক নিবন্ধনের সময় আর বাড়ানো হচ্ছে না বলে ধর্ম মন্ত্রণালয়ের একটি চিঠি জারি করেছে হজ এজেন্সি ও সংশ্লিষ্টরা। এর আগে ৩০ নভেম্বরের মধ্যেই শেষ করতে হবে হজে গমনেচ্ছুদের ৩ লাখ টাকা ব্যাংকে জমা দিয়ে নিবন্ধন
# 88    বাংলাদেশে ঝড়, বন্যা, জলোচ্ছ্বাসসহ বিভিন্ন প্রাকৃতিক দুর্যোগে বরগুনার পাথরঘাটা এলাকায় গত ৩০ বছরে কমপক্ষে ১৮৮ জন জেলে নিখোঁজ হওয়ার খবর পাওয়া গেছে।
# 89    চট্টগ্রামের রাউজান উপজেলায় বিএনপির দুই পক্ষের সংঘর্ষ ও গুলি বন্ধে গ্রামের নারীরা এগিয়ে এসেছেন। পুরো এলাকায় শান্তি-শৃঙ্খলা ফিরিয়ে আনার আহ্বান জানিয়েছেন তারা।
# 90    বাংলাদেশে ছাত্র-জনতার অদম্য সাহস, দৃঢ়তা ও ত্যাগের প্রতি শ্রদ্ধার নিদর্শন হিসেবে সেই সময়ের আলোকচিত্র, ভিডিও ও সংবাদ প্রতিবেদন নিয়ে '৩৬ জুলাই: নির্ভীকদের অভিবাদন' শীর্ষক প্রদর্শনী করেছে দ্য ডেইলি স্টার।
# 91    ঢাকার যাত্রাবাড়ী বিমানবন্দরে শেখ হাসিনা সরকারকে কবর দেওয়ার পর সেখানে ছিল আবু ইসহাকের মরদেহ। কিন্তু সেই মানুষের রক্তে রঞ্জিত সাদামাঠা ধূসর চেক শার্ট।
# 92    বাংলাদেশে পানি সরবরাহকারী সংস্থা চট্টগ্রাম ওয়াসার সিস্টেম লস বেড়েছে ৩০ শতাংশের বেশি। গত এক দশকে দেশটির সবচেয়ে বড় এবং বৃহৎ পানির অপচয় করা দেশের অন্যতম।
# 93    বাংলাদেশের সুপ্রিম কোর্ট থেকে সাবেক প্রধান বিচারপতি রুহুল আমিনের মৃত্যুর পর আপিল বিভাগ ও হাও কোর্টি বিভাগে সব বিক্ষোভের কার্যক্রম স্থগিত করেছে দ্য ডেইলি স্টার ।
# 94    বাংলাদেশে অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূসকে জাতীয় ঐক্য গড়ে তোলার আহ্বান জানিয়েছেন বিএনপি মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর। বিএনপিকে বলেছেন, প্রয়োজনীয় সংস্কার করে নির্বাচনের রোডম্যাপ
# 95    বাংলাদেশের সাবেক খাদ্যমন্ত্রী কামরুল ইসলাম ও আমির হোসেন আমুকে আজ আন্তর্জাতিক অপরাধ ট্রাইব্যুনালের আদালত প্রাঙ্গনে নিয়ে আসা হয়েছে। তারা গ্রেপ্তার করা হয়েছে বলে জানিয়েছেন প্রধান কৌঁসুলি।
# 96    বাংলাদেশ-ভারত সীমান্তে যেকোনো ধরনের অনাকাঙ্ক্ষিত পরিস্থিতি রোধে বর্ডার গার্ড বাংলাদেশ (বিজিবি) প্রস্তুত ও সতর্ক আছে বলে জানিয়েছে বিজিবি সদর দপ্তর। এর সঙ্গে যোগ দিয়েছে বাংলাদেশের বিমান পরিবহন বাহিনী।
# 97    কিশোরগঞ্জের ঐতিহাসিক পাগলা মসজিদের দানবাক্স থেকে মিলেছে রেকর্ড ২৯ বস্তা টাকাসহ বিপুল পরিমাণ স্বর্ণালংকার ও বৈদেশিক মুদ্রা। এই খবর পাওয়া যাচ্ছে শনিবার।
# 98    জুলাই-আগস্টে ছাত্র-জনতার অভ্যুত্থানে একাত্মতা পোষণ করে এবং হত্যা ও নিপীড়নের বিরুদ্ধে সংযুক্ত আরব আমিরাতে মিছিল-বিক্ষোভ করায় আটক আরও ৭৫ প্রবাসী বাংলাদেশিকে মুক্তি দিয়েছে দেশটির সরকার।
# 99    থাইল্যান্ড, মিয়ানমার, লাওস, ভিয়েতনাম ও কম্বোডিয়ায় যাওয়ার বিষয়ে বাংলাদেশি নাগরিকদের সতর্ক করেছে প্রবাসী কল্যাণ ও বৈদেশিক কর্মসংস্থান মন্ত্রণালয়। এসব দেশে কম্পিউটার পরিচালনা সংক্রান্ত নিয়োগ বিজ্ঞপ্তি প্রচার করছে এমন এনজিওসহ
# 100    বাংলাদেশে বিরোধী দল বিএনপি আজ সন্ধ্যায় অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূসের সঙ্গে বৈঠক করবেন। বিএনপির মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর।
# 101    বাংলাদেশের চট্টগ্রামের রাউজান উপজেলায় একদল মুখোশধারীর হামলায় ১৫ জন গুলিবিদ্ধ হয়েছেন। তাদের মধ্যে ১১ জন হাসপাতালে চিকিৎসাধীন। বাকিদের পরিচয় এখনো জানানো সম্ভব হয়নি।
# 102    বাংলাদেশে গুম ও নির্যাতনের মামলায় র ্যাবের সাবেক দুই কর্মকর্তাকে কারাগারে পাঠানোর আদেশ দিয়েছে আন্তর্জাতিক অপরাধ ট্রাইব্যুনাল (আইসিটি), যাদের মধ্যে একজন পুলিশ কর্মকর্তা।
# 103    বাংলাদেশের লালমনিরহাট সদর উপজেলায় অবৈধভাবে সার মজুত করায় স্থানীয় আওয়ামী লীগ নেতা রবিউল ইসলামকে (৫৭) আটক করেছে আইন-শৃঙ্খলা রক্ষাকারী বাহিনী।
# 104    বাংলাদেশে সরকার পরিচালনায় অদক্ষতা দেখলে জনগণ সহজভাবে মেনে নেবে না বলে মন্তব্য করেছেন বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমান। 'আহতদের মধ্যে কারও অঙ্গহানি হয়েছে বা কারাও চোখ নষ্ট হয়েছে।'
# 105    বাংলাদেশের রাজধানী ঢাকার ধানমন্ডিতে নিজ বাসায় ছুরিকাঘাতে যুক্তরাজ্য প্রবাসী এক ব্যক্তি নিহত হওয়ার ঘটনায় আহত হয়েছেন তার স্ত্রী। স্থানীয় একটি হাসপাতালে তাকে উদ্ধার করা হয়েছে।
# 106    বাংলাদেশের রাজধানী গাজীপুরের শ্রীপুর-কাপাসিয়া আঞ্চলিক সড়কে লরি-মোটরসাইকেল সংঘর্ষে একজন নিহত ও দুইজন আহত হয়েছেন। হত্যার ঘটনায় কর্তব্যরত চিকিৎসককে উদ্ধার করা হয়েছে।
# 107    বাংলাদেশের ব্যাংক বসুন্ধরা গ্রুপের চেয়ারম্যান আহমেদ আকবর সোবহান এবং তার পরিবারের সদস্যদের বিদেশে থাকা সম্পদ জব্দ করার আদেশ দিয়েছেন ঢাকার একটি আদালত। এদের মধ্যে আছে তিনজনের পরিবার।
# 108    বাংলাদেশে সংবিধানের পঞ্চদশ সংশোধনী আইনের সাংবিধানিকতাকে চ্যালেঞ্জ করে পাঁচ নাগরিকের দায়ের করা দুটি আবেদনের ওপর আজ রায় ঘোষণা করেছে হাইকোর্ট। এর আগামী ১৭ ডিসেম্বর হাইকোর্টের নিম্নকক্ষ বিচারপতির সমন্বয়ে গ
# 109    বাংলাদেশে সেন্টার ফর পলিসি ডায়ালগের (সিপিডি) ৩০ বছরের দীর্ঘ যাত্রায় দেশ-বিদেশে স্বনামধন্য থিঙ্ক ট্যাঙ্ক হিসেবে পরিচিতি পেয়েছে বলে জানিয়েছেন দেশের অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস।
# 110    বাংলাদেশের রাজস্ব বোর্ডের অটোমেটেড সিস্টেম ফর কাস্টম ডেটা (অ্যাসাইকুডা) সার্ভারে ভুয়া ঘোষণার মাধ্যমে আমদানি করা ছয় কোটি টাকার বিদেশি সিগারেট খালাসের শুল্ক প্রক্রিয়া শেষ করেছেন মোহাম্মদ জাকারিয়া।
# 111    বাংলাদেশের অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. আবদুল হামিদ বলেছেন, সংখ্যালঘুদের ওপর অত্যাচারের ঘটনায় তিনি খুশি হয়েছেন। কিন্তু এখনও তাদের পার্থক্য থাকলেও, আমরা কেউ কারও শত্রু নই।
# 112    বাংলাদেশের পাবনা জেলার হেমায়েতপুরে স্থানীয় বিএনপির দুই গ্রুপের সংঘর্ষে একজন নিহত ও তিনজন আহত হয়েছেন। এর মধ্যে ইসলামী জলসা আয়োজন নিয়ে ইউনিয়নের সাবেক চেয়ারম্যান মুন্তাজ আলীর ছেলে এবং বিএনপি কর্মী।
# 113    বাংলাদেশের কুয়াকাটা ও সুন্দরবনের দুবলার চরে পুণ্যস্নানের মধ্য দিয়ে শেষ হয়েছে হিন্দু ধর্মাবলম্বীদের রাস উৎসব। শনিবার ভোরে সূর্যোদয়ের আগে জোয়ারের পানিতে স্নান করে ঐতিহ্যকে সমুন্নত রাখা হয়।
# 114    'তোমরা সবাই বড় হও, চারিদিকে তোমাদের আলোর ঝরনাধারা ছড়িয়ে পড়ুক। জীবনকে মূল্যবান ভেবো। প্রতিটা মিনিট এই পৃথিবীকে উপহার দাও।' - বিশ্বসাহিত্য কেন্দ্রের প্রতিষ্ঠাতা অধ্যাপক আবদুল্লাহ আবু সায়ীদ
# 115    বাংলাদেশে সেনা, নৌ ও বিমান বাহিনীর কর্মকর্তাদের ম্যাজিস্ট্রেসি ক্ষমতা আরও ৬০ দিন বাড়িয়েছে সরকার। এর আগে 'সেনাবাহিনী' শব্দটি যোগ করা হয়েছিল। তবে গত ১৭ সেপ্টেম্বর থেকে সেনাবাহিনী, কোস্টগার্ড ও বিজিবিতে প্রেষণে কর্ম
# 116    জাতিসংঘের ফিলিস্তিনি বিষয়ক প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস বাংলাদেশের প্রতি দৃঢ় সমর্থনের কথা পুনর্ব্যক্ত করেছেন। এর আগে ইসরায়েলের দখলকে অবৈধ ঘোষণা করা হয়।
# 117    বাংলাদেশে মাধ্যমিক ও উচ্চ শিক্ষা বিভাগের সচিব হিসেবে বদলি করা হয়েছে বলে জানিয়েছে জনপ্রশাসন মন্ত্রণালয়। এর মধ্যে একজন নতুন সরকারি কর্মকর্তাও যোগ দিয়েছে বলে জানা যাচ্ছে তারা।
# 118    বাংলাদেশে পত্রিকা অফিসে ভাঙচুর বা প্রকাশিত সংবাদপত্র বন্ধের জন্য চাপ প্রয়োগ সহ্য করা হবে না বলে জানিয়েছেন সরকারের তথ্য উপদেষ্টা নাহিদ ইসলাম। এ ধরনের ঘটনায় যারা জড়িত, তাদের বিরুদ্ধে অবশ্যই আইনগত ব্যবস্থা নেওয়া হবে।
# 119    বাংলাদেশে পত্রিকা ডেইলি স্টার ও দৈনিক প্রথম আলোর কার্যালয়ের সামনে বিক্ষোভ ও হামলার ঘটনায় গভীর উদ্বেগ জানিয়েছেন ৩৪ জন নাগরিক। বিবৃতি দিয়েছেন মানবাধিকার সংগঠনগুলো।
# 120    বাংলাদেশে এক কিশোর হত্যা মামলায় সাবেক সংসদ সদস্য মোহাম্মদ সোলাইমান সেলিমকে কারাগারে পাঠানোর আদেশ দিয়েছে ঢাকার একটি আদালত। গ্রেপ্তার এড়াতে আত্মগোপনে চলে যান তিনি।
# 121    বাংলাদেশে শিক্ষার্থীদের যেকোনো যৌক্তিক দাবি সরকার মেনে নেবে, তাদের সমাধানের আশ্বাস দেওয়ায় অনেকে তাদেরকে আন্দোলন প্রত্যাহার করেছে বলে জানিয়েছেন ঢাকার শিক্ষা উপদেষ্টা ড. ওয়াহিদউদ্দিন মাহমুদ।
# 122    বাংলাদেশে ক্ষমতাসীন আওয়ামী লীগের চেয়ারপারসন খালেদা জিয়া অসুস্থ বলে জানিয়েছেন দলটির শীর্ষ নেতারা। বিএনপির মহাসচিব বলেছেন, 'বিএনপি রাজনীতি করবে কি না তা জনগণ ঠিক করেছে।'
# 123    বাংলাদেশের রাজধানী গাজীপুরের টঙ্গীতে মাসকোটেক্স কারখানার ঝুট ব্যবসার নিয়ন্ত্রণ নিয়ে বিএনপির দুই পক্ষের সংঘর্ষ হয়েছে। এর মধ্যে স্থানীয় আওয়ামী লীগের সাধারণ সম্পাদক মাহমুদুল হাসান মিরনের সমর্থকদের সঙ্গে সমঝোতা করে ঝ
# 124    বাংলাদেশের দক্ষিণাঞ্চলীয় জেলা বরিশালের কাশিপুর এলাকার একটি কারখানায় কয়েক দশক ধরে হাতে বিড়ি তৈরি করছেন ডালিয়া বেগম (৬৫)। তার স্বামী যক্ষ্মায় মারা গিয়েছিলেন তিনি।
# 125    বাংলাদেশে সারাদেশে বিভিন্ন ইস্যুতে যে উত্তেজনা চলছে, এসব নিয়ে সব রাজনৈতিক দল ও অংশীজনদের সঙ্গে বসে সমাধান করা হবে বলে বিএনপির প্রধান উপদেষ্টা মাহফুজ আলম জানিয়েছেন।
# 126    নির্বাচন কমিশন (ইসি) সচিব শফিউল আজিমকে তার পদ থেকে সরিয়ে দিয়েছে অন্তর্বর্তী সরকার। তাকে জাতীয় পরিচয় নিবন্ধন অনুবিভাগের মহাপরিচালক (ডিজি) হিসেবে নিয়োগ দেওয়া হয়েছে।
# 127    জনপ্রশাসন মন্ত্রণালয়ে শতাধিক কর্মচারী ক্ষুব্ধ প্রতিক্রিয়া দেখিয়ে হট্টগোল করেছেন। গতকাল মঙ্গলবার সচিব জিয়াউর রহমানের সঙ্গে আপত্তিকর আচরণ করলে তিনি অজ্ঞান হয়ে গেছেন।
# 128    রাজধানীর সোহরাওয়ার্দী উদ্যানেই অমর একুশে বইমেলা হবে বলে জানিয়েছেন সংস্কৃতিবিষয়ক উপদেষ্টা মোস্তফা সরয়ার ফারুকী। 'আশা করা যায়, বইলে যেখানে হতো সেখানেই হবে এবং সুন্দর আয়োজনে হবে, কোনো ঝামেলা হবে না।'
# 129    বাংলাদেশে জুলাই-আগস্ট গণঅভ্যুত্থানে আহতদের উন্নত চিকিৎসা ও পুনর্বাসনের দাবিতে রাজধানীর পঙ্গু হাসপাতালের সামনে অবস্থান নিয়েছিলেন স্থানীয় সরকারের অন্তর্বর্তীকালীন চার উপদেষ্টা।
# 130    বাংলাদেশের বগুড়ার দুপাচাঁচিয়ায় গৃহবধূ সালমা খাতুন হত্যাকাণ্ডের তদন্তে কোনো র ্যাব সদস্যের গাফিলতি বা তথ্যগত ভুল পাওয়া গেলে তাদের বিরুদ্ধে যথাযথ ব্যবস্থা নেওয়া হবে বলে জানিয়েছে e ্যাপিড অ্যাকশন ব্যাটালিয়ন।
# 131    বাংলাদেশের কুমিল্লা জেলার বুড়িচং উপজেলায় ট্রেনের ধাক্কায় ব্যাটারিচালিত অটোরিকশার সাত যাত্রী নিহত হয়েছেন। এ ঘটনায় আরও তিনজন আহত হওয়ার খবর নিশ্চিত করেছে রেলওয়ে পুলিশ।
# 132    বাংলাদেশের সুপ্রিম কোর্ট প্রাঙ্গণে বুধবার ঘটে যাওয়া নজিরবিহীন ঘটনায় গভীর উদ্বেগ প্রকাশ করেছে প্রধান বিচারপতির কার্যালয়। এর মধ্যে জেলা জজ ও ম্যাজিস্ট্রেসিতে ব্যাপক ব্যবস্থা গ্রহণ করা হয়েছে।
# 133    বাংলাদেশের অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস বলেছেন, দেশের জন্য যে ভঙ্গুর অর্থনৈতিক পরিস্থিতি রেখে গিয়েছে তাতে রাজস্ব আদায়ে গতি আনতে তিনি নিশ্চয়তা দিয়েছেন সকল প্রকার সীমাবদ্ধতা সত্ত্বেও বাংলাদেশকে একটা মজ
# 134    বাংলাদেশে গণমাধ্যমের স্বাধীনতা নিয়ে সরকারের কোনো চাপ নেই বলে মন্তব্য করেছেন তথ্য ও সম্প্রচার মন্ত্রণালয়ের উপদেষ্টা মো. নাহিদ ইসলাম। তিনি বলেছেন, বর্তমান অন্তর্বর্তী শাসনের সঙ্গে যোগাযোগের ক্ষেত্রে সাংবাদিকদের কার্যকর ভূমিকা
# 135    বাংলাদেশের বিভিন্ন স্থানে চলমান শ্রমিক অসন্তোষের যৌক্তিক সমাধান করা হবে বলে জানিয়েছেন শ্রম ও কর্মসংস্থান মন্ত্রণালয়ের উপদেষ্টা ড. এম সাখাওয়াত হোসেন। সরকারের ঘোষিত নিম্নতম মজুরি বাস্তবায়ন না করলে আইনানুগ ব্যবস্থা গ্রহণের নির্দেশনা দিয়েছেন
# 136    বাংলাদেশের বগুড়া জেলা আওয়ামী লীগের সাংগঠনিক সম্পাদক শাহাদত আলম ঝুনু কারা হেফাজতে মারা গেছেন। জেল কর্তৃপক্ষ তাকে শজিমেক মেডিকেল কলেজ হাসপাতালে চিকিৎসাধীন অবস্থায় ঢাকায় নেওয়ার চেষ্টা করেছে।
# 137    বাংলাদেশে কোটা সংস্কার আন্দোলনে সাবেক আইনমন্ত্রী আনিসুল হক, কামরুল ইসলাম এবং আওয়ামী লীগের এমপি মোহাম্মদ সোলাইমান সেলিমকে বিভিন্ন মেয়াদে রিমান্ডে পাঠিয়েছেন আদালত।
# 138    ভারতের ত্রিপুরার আগরতলায় বাংলাদেশ সহকারী হাইকমিশনে নিরাপত্তা বেষ্টনী ভেঙে জোরপূর্বক প্রবেশ করে হামলার ঘটনার প্রতিবাদে বিক্ষোভের ডাক দিয়েছে বৈষম্যবিরোধী ছাত্র আন্দোলন। এর মধ্যে সংখ্যালঘুদের গ্রেপ্তার এবং ইসকনের সাবেক
# 139    বাংলাদেশে রাজধানীর খিলগাঁও এলাকায় পারিবারিক দ্বন্দ্বের জেরে মেজ ভাইয়ের কাঁচির আঘাতে ছোট বোন নিহত হয়েছেন। এর আগে দুই সপ্তাহ ধরে তাদের মধ্যে ঝগড়া ছিল।
# 140    বাংলাদেশের গাজীপুরের কাশিমপুর এলাকায় গ্যাস লিকেজ থেকে বিস্ফোরণে এক নারীসহ চারজন দগ্ধ হয়েছেন। এদের মধ্যে একজন ঢাকার ন্যাশনাল ইনস্টিটিউট অব বার্ন অ্যান্ড প্লাস্টিক সার্জারি ইন্স্টিটাউটে চিকিৎসাধীন।
# 141    বাংলাদেশে জুলাই-আগস্ট বিপ্লবের আহতদের এক লাখ টাকা ক্ষতিপূরণ যথেষ্ট নয় বলে জানিয়েছেন মৎস্য ও প্রাণিসম্পদ মন্ত্রণালয়ের একজন ঊর্ধ্বতন কর্মকর্তা। সরকারের পক্ষ থেকে ভুল-ত্রুটি হয়েছে বলেই তারা চিকিৎসাধীন আছেন।
# 142    ভারতের আগরতলা শহরে বাংলাদেশের সহকারী হাইকমিশনে হিন্দু সংঘর্ষ সমিতির হামলা, ভাঙচুর ও জাতীয় পতাকায় আগুন দেওয়ার ঘটনায় তিন জন পুলিশ কর্মকর্তাকে বরখাস্ত করেছে ভারতীয় কর্তৃপক্ষ।
# 143    বাংলাদেশে বিরোধী দল বিএনপি মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর বলেছেন, ভারতের পত্র-পত্রিকাগুলোতে এমনভাবে লেখা হচ্ছে যেন বাংলাদেশের মাথার উপর খড়গ আছে এবং চতুর্দিকে তারা চেষ্টা করছে আবার অন্ধকারে নিয়ে যাওয়ার
# 144    বাংলাদেশে নির্বাচন সংস্কার কমিশনের প্রধান ড. বদিউল আলম মজুদার বলেছেন, রাজনৈতিক দলগুলোর সঙ্গে সংলাপে বসবে অন্তর্বর্তী সরকার। এ প্রক্রিয়ায় একটি বাচনের রোডম্যাপ তৈরি হবে।
# 145    বাংলাদেশের সাতক্ষীরায় অপদ্রব্য পুশ করা এক হাজার ১২২ কেজি বাগদা চিংড়ি জব্দ করে আগুনে পুড়িয়ে বিনষ্ট করেছে বিশেষ টাস্কফোর্স। এর মধ্যে একজনকে তিন মাসের কারাদণ্ড দিয়েছে ভ্রাম্যমাণ আদালত।
# 146    ভারতে বাংলাদেশ মিশনে হামলা এবং বাংলাদেশের পতাকাকে অবমাননার প্রতিবাদ জানিয়ে রাজধানীর শাহবাগে বিক্ষোভ সমাবেশ করেছে জাতীয় নাগরিক কমিটি। ভারতের এই চেষ্টা এদেশের হিন্দু-মুসলিম ঐক্যের মাধ্যমে মোকাবিলার আহ্বান জানিয়েছে।
# 147    বাংলাদেশে বিনিয়োগকারীদের কাছ থেকে চার হাজার ২০০ কোটি টাকা অর্থ পাচারের মামলায় ডেসটিনি গ্রুপের ব্যবস্থাপনা পরিচালক (এমডি) রফিকুল আমীনসহ ১৯ জনের বিরুদ্ধে রায় ঘোষণার জন্য আগামী ১৫ জানুয়ারি দিন ধার্য করেছেন আদালত।
# 148    ভারতে হিন্দুত্ববাদী শক্তি ও সাম্প্রদায়িকতার বিরুদ্ধে দেশটির জনগণকে রুখে দাঁড়ানোর আহ্বান জানিয়েছেন দেশের বিভিন্ন ক্ষেত্রের ১৪৫ জন নাগরিক। ভারত ও বাংলাদেশের কূটনৈতিক সম্পর্ক শোচনীয় অবস্থায়।
# 149    বাংলাদেশে সব ভারতীয় টিভি চ্যানেলের সম্প্রচার নিষিদ্ধ করতে হাইকোর্টের একটি রিট দাখিল করেছে হাইকোর্ট। ভারতের দ্য ডেইলি স্টার এবং বাংলাদেশের জাতীয় সংবাদ মাধ্যমগুলো বাংলাদেশ নিয়ে অপপ্রচারের অভিযোগ করছে।
# 150    বাংলাদেশের সঙ্গে ইউরোপীয় ইউনিয়নের কূটনীতিকদের মধ্যে একত্রিত আলোচনার নতুন ক্ষেত্র অনুসন্ধান করা হবে বলে জানিয়েছে পররাষ্ট্র মন্ত্রণালয়ের একটি সূত্রে জানা গেছে। এর আগে কখনোই বাংলাদেশ সরকারের সাথে একত্রে আলাপনায় বসেনি।
# 151    ভারতের আগরতলায় বাংলাদেশের সহকারী হাইকমিশনে হামলা এবং ফেনীর বিলোনীয়া স্থলবন্দরে বিক্ষোভ মিছিল ও অবস্থান কর্মসূচি পালন করেছে ছাত্র-জনতা। সীমান্তের ৩০০ মিটারের মধ্যে না আসার অনুরোধ জানিয়েছে আইনশৃঙ্খলা বাহিনী।
# 152    বাংলাদেশের অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস বলেছেন, সাধারণ নির্বাচনের আগে বাংলাদেশ অর্থনীতি, শাসনব্যবস্থা, আমলাতন্ত্র এবং বিচারব্যবস্থায় সর্বাত্মক সংস্কার করতে হবে।
# 153    বাংলাদেশে জাতীয় নাগরিকপঞ্জী বা সিপিডির বাস্তবায়নে ব্যর্থতা ও নীতি নির্ধারণ প্রক্রিয়ায় সরকারের সদিচ্ছা নিয়ে আলোচনা হওয়া উচিত বলে মন্তব্য করেছেন সেন্টার ফর পলিসি ডায়ালগের চেয়ারম্যান অধ্যাপক রেহমান সোবহান।
# 154    বাংলাদেশে দুর্নীতি দমন কমিশনের বিরুদ্ধে দায়ের করা মামলায় বিএনপির স্থায়ী কমিটির সদস্য খন্দকার মোশাররফ হোসেনকে খালাস দিয়েছে ঢাকার বিশেষ জজ আদালত। সাবেক স্বাস্থ্যমন্ত্রী এবং তার স্ত্রী বিলকিসকে যাবজ্জীবন কার্যক্রম বাতিল করে
# 155    বেসামরিক প্রশাসনকে সহায়তা দিতে সেনাবাহিনী কত দিন মাঠে থাকবে সেটা সরকারের সিদ্ধান্ত বলে মন্তব্য করেছেন সেনাসদরের কর্মকর্তা স্টাফ কর্নেল ইন্তেখাব হায়দার। 'মানবাধিকার লঙ্ঘন বা বিচারবহির্ভূত হত্যা প্রতিরোধ করার ব্যাপারে আমরা
# 156    ২০১৮ সালে মাত্র ১০ বছর বয়সে ধর্ষণের ভয়াবহতার শিকার হন মরিময় (ছদ্মনাম), যিনি বস্তিতে থাকতেন। কিন্তু সেই ঘটনার বিচার না চেয়ে 'সামাজিক অসম্মানে'র কথা চিন্তা করে চুপ ছিলেন।
# 157    বরিশালের মুলাদীতে সড়ক দুর্ঘটনায় শিক্ষা মন্ত্রণালয়ের উপসচিব মো. ফরহাদ হোসেন নিহত হয়েছেন। তাকে উদ্ধার করে স্থানীয় একটি হাসপাতালে নিয়ে গেলে তিনি মাথায় গুরুতর আঘাত পেয়েছেন।
# 158    নিষিদ্ধ ঘোষিত ছাত্র সংগঠন ছাত্রলীগ পটুয়াখালীতে আজ ঝটিকা মিছিল করেছে। সেখানে প্রধান উপদেষ্টার ছবিতে আগুন ধরিয়ে দেওয়া হয়েছে। এ ঘটনায় আইনগত ব্যবস্থা নেওয়া হচ্ছে।
# 159    বাংলাদেশের বান্দরবান জেলায় সেনাবাহিনীর সঙ্গে বন্দুকযুদ্ধে কুকি-চিন ন্যাশনাল ফ্রন্ট-এর তিন সন্ত্রাসী নিহত হওয়ার কথা জানিয়েছে আন্তঃবাহিনী জনসংযোগ পরিদপ্তর (আইএসপিআর)।
# 160    বাংলাদেশে 'নতুন বাংলাদেশ' বিনির্মাণের পথে সম্ভাবনাময় অগ্রযাত্রার পাশাপাশি কিছু ক্ষেত্রে চ্যালেঞ্জ আছে বলে মনে করে ট্রান্সপারেন্সি ইন্টারন্যাশনাল বাংলাদেশ (টিআইবি)। কিন্তু এ নিয়ে কতটা নেতিবাচক পদক্ষেপ নিয়েছে অন্তর্বর্তী সরকার?
# 161    বাংলাদেশের রাজধানী ঢাকার শনির আখড়া এলাকায় ছাত্র-জনতার অভ্যুত্থানে একজন নিহতের ঘটনায় দায়ের মামলায় বরিশালের সাবেক অতিরিক্ত পুলিশ সুপারের দুই দিনের রিমান্ড মঞ্জুর করেছেন আদালত।
# 162    বাংলাদেশ পুলিশের মহাপরিদর্শক (আইজিপি) হিসেবে নিয়োগ পেয়েছেন বাহারুল আলম। এর মধ্যে মো. ময়নুল ইসলামের স্থলাভিষিক্ত হবার পর তাকে দুই বছর মেয়াদে নিয়োজিত করা হয়েছে।
# 163    বাংলাদেশে সাংবাদিকদের প্রেস অ্যাক্রিডিটেশন কার্ডের বিরুদ্ধে সুনির্দিষ্ট অভিযোগ ও অপরাধের প্রমাণ ছাড়া এ ধরনের ঢালাও পদক্ষেপ গ্রহণ থেকে বিরত থাকার আহ্বান জানিয়েছে বাংলাদেশের গণমাধ্যম সম্পাদক পরিষদ।
# 164    নাটোর-পাবনা মহাসড়কের কদমচিলান এলাকায় ব্যাটারিচালিত ভ্যানে ট্রাকের ধাক্কায় চালকদের দুইজনই নিহত হয়েছেন। বনপাড়া থানার ধানাইদহ গ্রামের এছারুদ্দিন ছেলে এবং ট্রাকচালক মোস্তাকিনের মৃত্যু হয়েছে।
# 165    বাংলাদেশে সরকারি কর্মকর্তা-কর্মচারীদের সম্পদ বিবরণীর তথ্য সিলগালা খামে সংশ্লিষ্ট কর্তৃপক্ষের কাছে জমা দেওয়ার সময়সীমা আরো বাড়িয়েছে। এর আগে, এই বিধান কঠোরভাবে অনুসরণ করা হয়েছিল।
# 166    ভয়মুক্ত একটি নতুন বাংলাদেশের স্বপ্ন দেখার কথা বলেছেন অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস। তিনি বলছেন, বাংলাদেশ যদি এমন একটা দেশ গড়ে তুলতে পারি, তাহলে এটি সফল দেশ হবে।
# 167    বাংলাদেশে আওয়ামী লীগের শাসনামলে গুম ও নির্যাতনের অভিযোগের সত্যতা প্রাথমিকভাবে পেয়েছে আন্তর্জাতিক অপরাধ ট্রাইব্যুনালের তদন্ত সংস্থা র ্যাবের দুই সাবেক কর্মকর্তার বিরুদ্ধে।
# 168    কুড়িগ্রামের রৌমারী উপজেলা মুক্তিযোদ্ধা কমপ্লেক্স চত্বরে জামায়াতে ইসলামী সংগঠনের নেতাকর্মীদের ওপর হামলার ঘটনায় নিন্দা জানিয়ে বিবৃতি দিয়েছেন দেশের ৬২ জন নাগরিক।
# 169    বাংলাদেশে স্বাস্থ্য সেবা বিভাগের সিনিয়র সচিব এম এ আকমল হোসেন আজাদকে তার পদ থেকে সরিয়ে দিয়েছে অন্তর্বর্তী সরকার। এর মধ্যে এনজিও বিষয়ক ব্যুরোর মহাপরিচালক (গ্রেড-১) মো. আব্দুর রউফকে দায়িত্ব দেয়া হয়েছে।
# 170    বাংলাদেশে বিরোধী দল বিএনপির জ্যেষ্ঠ নেতারা বৃহস্পতিবার রাজধানী ঢাকায় বিজয় দিবস উপলক্ষে একটি বড় জনসমাবেশ করার সিদ্ধান্ত নিয়েছে। এই সমাবেশের মাধ্যমে নির্বাচন আয়োজনের সুস্পষ্ট রোডম্যাপ উপস্থাপনের জন্য দলের কর্মী-সমর্থ
# 171    বাংলাদেশের চট্টগ্রামে আইনজীবী সাইফুল ইসলাম আলিফ হত্যার ৪৮ ঘণ্টা পার হলেও এখন পর্যন্ত কোনো হত্যা মামলা দায়ের করা হয়নি বলে পুলিশ নিশ্চিত করেছে। এ নিয়ে টানা দ্বিতীয় দিনের মতো আদালতের কার্যক্রম স্থগিত রেখেছেন বিক্ষোভকারীরা
# 172    চট্টগ্রামে সাবেক ইসকন নেতা চিন্ময় কৃষ্ণ দাসের গ্রেপ্তার ও জামিন শুনানিকে কেন্দ্র করে আদালত প্রাঙ্গণ এবং আশপাশের উদ্ভূত পরিস্থিতি নিয়ে বিদেশি সংবাদমাধ্যম রয়টার্স পুলিশের সঙ্গে কথা না বলেই মনগড়া বক্তব্য দিয়ে প্রতি
# 173    বাংলাদেশের চট্টগ্রাম আদালতের আইনজীবী অ্যাডভোকেট সাইফুল ইসলাম আলিফকে হত্যা মামলার প্রধান আসামি চন্দনকে গ্রেপ্তার করেছে পুলিশ। এই ঘটনায় আদালত প্রাঙ্গণে সংঘর্ষের সময় তাকে পিটিয়ে ও কুপিয়ে হত্যার অভিযোগ উঠেছে।
# 174    বাংলাদেশের চট্টগ্রাম থেকে ফেরার পথে বৈষম্যবিরোধী ছাত্র আন্দোলনের নেতা হাসনাত আব্দুল্লাহ ও সারজিস আলমের বহরের একটি গাড়ি সড়ক দুর্ঘটনার কবলে পড়েছে। এতে কেউ হতাহত হয়নি।
# 175    বাংলাদেশে বিরোধী দল বিএনপি বলেছে, দেশের জনগণ আর ফ্যাসিবাদ-আধিপত্য মেনে নেবে না। ভোট দেওয়ার পরিবেশ সৃষ্টি করতে হবে, যাকে খুশি তাকে দেয়া হবে। নির্বাচনী রোডম্যাপ দেবে জাতির জন্য মঙ্গল।
# 176    ভারত থেকে ক্ষমতাচ্যুত সাবেক প্রধানমন্ত্রী শেখ হাসিনাকে ফিরিয়ে আনার চেষ্টা করবে বাংলাদেশ, এমন একটি পরিকল্পনার কথা জানিয়েছেন সরকারের একজন শীর্ষ কর্মকর্তা। তিনি বলেছেন, বাংলাদেশের সঙ্গে সম্পর্ক নিয়ে তার কোনো আপত্তি নেই।
# 177    বাংলাদেশের চট্টগ্রামে জলাবদ্ধতা নিরসন প্রকল্প ও সামগ্রিক কার্যক্রম নিয়ে আয়োজিত মতবিনিময় সভায় সাবেক প্রধানমন্ত্রী শেখ হাসিনার ছবি ও ভিডিও প্রদর্শন করার জন্য তোপের মুখে পড়েছেন স্থানীয় কর্মকর্তারা।
# 178    বাংলাদেশে ১৯৭৫ সালের ১৫ আগস্ট জাতীয় শোক দিবস এবং সরকারি ছুটি ঘোষণা করে হাইকোর্টের দেওয়া রায়ে স্থগিতাদেশ দিয়েছে সুপ্রিম কোর্টে আপিল বিভাগ। এর আগে বাংলাদেশের স্বাধীনতা সংগ্রামে বঙ্গবন্ধু শেখ মুজিবুর রহমানের অবদানের স্ব
# 179    বাংলাদেশে ঢালাও মামলার প্রবণতা দেখা দিয়েছে, যা বিব্রতকর বলে মন্তব্য করেছেন অন্তর্বর্তী সরকারের আইন উপদেষ্টা আসিফ নজরুল। বিচার বিভাগ সংস্কার কমিশনের কাজের অগ্রগতি জানতে চেয়েছেন তিনি।
# 180    প্রায় ছয় ঘণ্টার প্রচেষ্টায় গাজীপুরের ইন্টারপ্যাক লিমিটেডের প্যাকেজিং কারখানার ভয়াবহ আগুন নিয়ন্ত্রণে এনেছে ফায়ার সার্ভিস। স্থানীয় সূত্রে জানা গেছে, কারখানা সংলগ্ন বৈদ্যুতিক খুঁটির ট্রান্সফরমারে স্পার্ক হয়েছে।
# 181    বাংলাদেশে অন্তর্বর্তীকালীন সরকারকে ভারত অস্থিতিশীল করার চেষ্টা করছে বলে অভিযোগ করেছে বিরোধী দল বিএনপির একজন শীর্ষ নেতৃত্বের একটি কমিটি। তিনি বলেছেন, হিন্দু সম্প্রদায়ের সদস্য এখন কী ধরনের সমস্যা তৈরি করছেন এবং সারা বিশ্বে
# 182    বাংলাদেশের টাঙ্গাইল জেলার সকল ধর্মাবলম্বীদের নিয়ে সম্প্রীতি র ্যালি ও সমাবেশ অনুষ্ঠিত হয়েছে। এর মধ্যে দেশি-বিদেশি সব চক্রান্ত প্রতিহত করতে ইস্পাত কঠিন ঐক্য গড়ে তোলার আহ্বান জানিয়েছে জেলা পুলিশ।
# 183    যুক্তরাজ্যের ইন্দো-প্যাসিফিক বিষয়ক মন্ত্রী ক্যাথরিন ওয়েস্ট বলেছেন, বাংলাদেশের অন্তর্বর্তীকালীন সরকার জাতীয় ঐক্য ত্বরান্বিত করতে প্রতিশ্রুতিবদ্ধ এবং তাদের পূর্ণ সমর্থন রয়েছে।
# 184    বাংলাদেশে নতুন নির্বাচন কমিশন গঠনে যোগ্য ব্যক্তি খুঁজতে অন্তর্বর্তী সরকারের একজন সাবেক সচিব এ এম এম নাসির উদ্দীনকে নিয়োগ দিয়েছে মন্ত্রিপরিষদ বিভাগের পক্ষ থেকে।
# 185    বাংলাদেশের দক্ষিণাঞ্চলীয় জেলা বরিশালে কীর্তনখোলা নদীতে বাল্কহেডের সঙ্গে মুখোমুখি সংঘর্ষে একটি স্পিডবোট ডুবে গেছে। এ ঘটনায় তিনজন নিখোঁজ রয়েছেন।
# 186    বাংলাদেশের রাজধানী ঢাকার যাত্রাবাড়ী এলাকায় আওয়ামী লীগ ও যুবলীগ নেতাদের মধ্যে সংঘর্ষের ঘটনা ঘটেছে। গত সপ্তাহে সেখানে পুলিশের সঙ্গে আন্দোলনকারীদের ব্যাপক সংঘার্ষ হয়েছে।
# 187    বাংলাদেশের বামপন্থী লেখক, গবেষক ও রাজনীতিবিদ বদরুদ্দীন উমর নিউইয়র্কে এক সাক্ষাৎকারে জানিয়েছেন, ১৯৬৯ সালে তৎকালীন পূর্ব পাকিস্তানে সংঘটিত গণঅভ্যুত্থানের সময়কার চেয়েও বেশি।
# 188    বাংলাদেশের রাজধানী ঢাকার সাভারে বাসের সঙ্গে মুখোমুখি সংঘর্ষে প্রাইভেটকারের তিন যাত্রী নিহত হয়েছেন। দুইজন গুরুতর আহত হওয়ার খবর নিশ্চিত করেছে স্থানীয় গণমাধ্যম।
# 189    বাংলাদেশে অন্তর্বর্তীকালীন সরকার দায়িত্ব গ্রহণের পরও প্রতিটি ক্ষেত্রে দখল ও আধিপত্য বিস্তারের সংস্কৃতি এখনো চলমান রয়েছে বলে জানিয়েছে ট্রান্সপারেন্সি ইন্টারন্যাশনাল বাংলাদেশ (টিআইবি)।
# 190    বেনাপোল বন্দর পরিদর্শন শেষে বাংলাদেশের নৌ-পরিবহন এবং শ্রম ও কর্মসংস্থান উপদেষ্টা ব্রিগেডিয়ার জেনারেল (অব.) এম সাখাওয়াত হোসেন বলেছেন, ভারতের অপতথ্য প্রচারে আমাদের কোনো ক্ষতি নেই।
# 191    বাংলাদেশের রাজধানী ঢাকায় ব্যাটারিচালিত রিকশার চলাচল তিন দিনের মধ্যে বন্ধ করার নির্দেশের প্রতিবাদে আজ সকাল থেকে মহাখালীতে ও আগারগাঁওসহ বিভিন্ন সড়কে বিক্ষোভ শুরু হয়েছে।
# 192    পার্শ্ববর্তী দেশ ভারতের মিডিয়া বাংলাদেশ সম্পর্কে মিথ্যা প্রচারণা চালাচ্ছে বলে মন্তব্য করেছেন অন্তর্বর্তি সরকারের স্বরাষ্ট্র উপদেষ্টা লেফটেন্যান্ট জেনারেল (অব.) জাহাঙ্গীর আলম। আবু সাঈদ হত্যা মামলার শুনানি দ্রুত শুরু হবে।
# 193    বাংলাদেশে চলমান নানা ইস্যুতে আলোচনার জন্য আজ বিভিন্ন রাজনৈতিক দলের নেতাদের সঙ্গে বৈঠকে বসছেন অন্তর্বর্তীকালীন সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস। এর মধ্যে ছাত্র আন্দোলনের অংশও রয়েছে।
# 194    বাংলাদেশে গণঅভ্যুত্থানের মুখে গত ৫ আগস্ট মাথায় গুলিবিদ্ধ হয়ে আহত অবস্থায় চিকিৎসাধীন এক শিক্ষার্থী মারা গেছেন বলে জানিয়েছেন ঢাকার সরকারি শহীদ সোহরাওয়ার্দী মেডিকেল কলেজ হাসপাতালের বাবা।
# 195    বাংলাদেশে নির্বাচন কমিশনার নির্বাচনের তারিখ ঘোষণা করা হয়নি বলে জানিয়েছে প্রধান উপদেষ্টার প্রেস উইং। এর মধ্যে রাজনৈতিক দল নাম প্রস্তাব করেছিল। তাদের কাছে আইন মেনে সার্চ কমিটি গঠন করেছে সরকার।
# 196    বাংলাদেশে দুর্নীতি মামলায় বিমান বাংলাদেশ এয়ারলাইনসের বর্তমান ও সাবেক পাঁচ কর্মকর্তাকে কারাগারে পাঠানোর আদেশ দিয়েছেন ঢাকার একটি আদালত। গ্রেপ্তারি পরোয়ানা জারি করা হয়েছে। এদের মধ্যে তিনজন ইঞ্জিনিয়ারও রয়েছেন।
# 197    বাংলাদেশের রাজধানী ঢাকায় ব্যাটারিচালিত রিকশাচালকদের সড়ক অবরোধে তীব্র যানজট তৈরি হয়েছে। বিক্ষোভকারীরা মহাখালী, মোহাম্মদপুর, মিরপুর ও গাবতলী এলাকায় তিন রাস্তা মোড়ে জড়ো হয়েছেন।
# 198    আশুলিয়ায় জীবিত স্বামীকে মৃত দেখিয়ে করা মামলার বাদী স্ত্রীসহ তিনজনকে পুলিশ হেফাজতে নেওয়া হয়েছে। এর আগে ঢাকার আশুলিয়া থানার ভারপ্রাপ্ত কর্মকর্তা (ওসি) আবু বকর সিদ্দিক এসব তথ্য নিশ্চিত করেছেন।
# 199    বাংলাদেশে বিরোধী দল বিএনপির ব্রাহ্মণবাড়িয়ায় দ্বি-বার্ষিক কাউন্সিলের বিরোধিতা করে বিক্ষোভের ঘটনায় সেনাবাহিনী ঘটনাস্থলে পৌঁছে যান চলাচল স্বাভাবিক করেছে বলে জানা গেছে।
# 200    বাংলাদেশের রাষ্ট্রপতি শেখ মুজিবুর রহমানের ছবি সরানো উচিত হয়নি বলে মত প্রকাশ করেছিলেন বিএনপির জ্যেষ্ঠ যুগ্ম মহাসচিব রুহুল কবির রিজভী। দলটির পক্ষ থেকে সংশোধনী পাঠানো হয়েছে।
# 201    বাংলাদেশে বিরোধী দল বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমান বলেছেন, দয়া করে আমার নামের সঙ্গে কেউ দেশনায়ক বা রাষ্ট্রনায়কের জাতীয় শব্দ ব্যবহার করবেন না। তিনি এই মন্তব্য করেছেন 'দলের নেতাকর্মীদের উদ্দেশে।'
# 202    বাংলাদেশের দক্ষিণাঞ্চলীয় জেলা গাজীপুরের সাতখামাইর পশ্চিমপাড়া এলাকায় কমলা চাষ করে সফল হয়েছেন চার উদ্যোক্তা। বাগানের প্রবেশমুখে অনেকে কমলার ছিঁড়ে খাওয়ার অনুভূতি স্বপ্নের মতো দেখা গেছে।
# 203    বাংলাদেশের হাইকোর্ট জিয়া চ্যারিটেবল ট্রাস্ট দুর্নীতি মামলায় বিএনপি চেয়ারপারসন খালেদা জিয়ার সাজা ও কারাদণ্ড স্থগিত করেছে এবং তাকে ১০ লাখ টাকা জরিমানা করার অনুমতি দিয়েছে।
# 204    নোয়াখালীর দ্বীপ উপজেলা হাতিয়ায় বঙ্গোপসাগরে ধাক্কা লাগার পর স্রোতের তোড়ে একটি মাছ ধরার ট্রলার ডুবে গেছে। এ ঘটনায় দুইজন জেলে নিখোঁজ রয়েছেন।
# 205    নেপাল ও ভুটানে উৎপাদিত জলবিদ্যুতের জন্য দক্ষিণ এশিয়ার গ্রিড তৈরির আহ্বান জানিয়েছেন বাংলাদেশের অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস। তিনি বলেছেন, পানি ব্যবস্থাপনাকে সর্বোচ্চ অগ্রাধিকার দিয়েছে বাংলাদেশ।
# 206    বাংলাদেশের ঢাকার ধামরাইয়ে সড়কের পাশে একটি বিকল কাভার্ডভ্যানে ট্রাকের ধাক্কায় কাভার্চুয়ালের দুই সহকারী নিহত হয়েছেন। এ ঘটনায় ট্রাকটি আটক করেছে থানা পুলিশের একজন কর্মকর্তা।
# 207    বাংলাদেশে অন্তর্বর্তী সরকারের ১০০ দিনের কর্মকাণ্ড তুলে ধরার পর আইন, বিচার ও সংসদ বিষয়ক মন্ত্রণালয়ের অধীনে ব্যাপক কার্যক্রম গ্রহণ করা হয়েছে। কিন্তু অতি প্রয়োজনীয় কিছু সংস্কার করে যত দ্রুত সম্ভব নির্বাচন দেওয়া হবে বলে জানিয়েছেন আই
# 208    বাংলাদেশের চট্টগ্রামে আইনজীবী সাইফুল ইসলাম আলিফ নিহতের ঘটনায় দোষীদের গ্রেপ্তার ও বিচারের দাবিতে বিক্ষোভ করছেন স্থানীয়রা। এর মধ্যে চিন্ময় কৃষ্ণের অনুসারীদের সংঘর্ষে আদালত চত্বরে মসজিদ মাঠে এবং পুলিশের
# 209    বাংলাদেশে গণমাধ্যমসহ সব ধরনের প্রতিষ্ঠানে মব-জাস্টিস কঠোর হস্তে দমনের আহ্বান জানিয়েছে সম্পাদক পরিষদ। এরই মধ্যে নিউজপেপার ওনার্স অ্যাসোসিয়েশন অব বাংলাদেশ (নোয়াব) এমন ঘটনার নিন্দা জানাচ্ছে।
# 210    বাংলাদেশের সুপ্রিম কোর্ট নির্বাচন কমিশনারের শপথ অনুষ্ঠানের জন্য নতুন একজন সাবেক সচিবকে নিয়োগ দিয়েছে। এর সঙ্গে তিনজনের নাম ঘোষণা করা হয়েছে বলে জানিয়েছে প্রধান বিচারপতি সৈয়দ রেফাত আহমেদ।
# 211    ছয় বছর পর প্রথমবারের মতো আগামীকাল বৃহস্পতিবার জনসমক্ষে আসছেন সাবেক প্রধানমন্ত্রী বিএনপি চেয়ারপারসন খালেদা জিয়া। ঢাকার সেনাকুঞ্জে সশস্ত্র বাহিনী দিবস উপলক্ষে আয়োজিত অনুষ্ঠানে অংশ নিবেন তিনি।
# 212    বাংলাদেশের প্রধান নির্বাচন কমিশনার (সিইসি) এ এম এম নাসির উদ্দীন বলেছেন, আমরা একটি অবাধ, সুষ্ঠু ও  নির্বাচনের আয়োজনে প্রতিশ্রুতিবদ্ধ। এমন একটা লেভেল প্লেয়িং ফিল্ড তৈরি করে দেবো।
# 213    ঢাকা-ময়মনসিংহ রেলরুটে বিমানবন্দর ও টঙ্গী স্টেশনের মাঝামাঝি জয়নাল মার্কেট এলাকায় একটি মালবাহী ট্রেন লাইনচ্যুত হওয়ার ঘটনা ঘটেছে বলে নিশ্চিত করেছে বৃহস্পতিবার রাত ১০টা থেকে।
# 214    বাংলাদেশের রাজধানী ঢাকার পল্লবী এলাকায় দুই শিশু সন্তানকে হত্যার অভিযোগ উঠেছে বাবার বিরুদ্ধে। এ ঘটনায় আহত হয়েছেন তাদের বাবা, যাদের মৃত্যুর পেছনে কী কারণ থাকতে পারে তা নিয়ে তদন্ত শুরু করেছে পুলিশ।
# 215    বাংলাদেশের চট্টগ্রাম নগর যুবলীগের সহ-সভাপতি ও 'সুচিন্তা বাংলাদেশ' ফাউন্ডেশনের বিভাগীয় সদস্য দেবাশীষ পাল দেবুকে গ্রেপ্তার করেছে পুলিশ। তার বিরুদ্ধে মামলা দায়ের করা হয়েছে।
# 216    বাংলাদেশের ঝিনাইদহ জেলার সাবেক অতিরিক্ত অ্যাটর্নি জেনারেল মোহাম্মদ মেহেদী হাসান চৌধুরীকে হাইকোর্টের দেওয়া জামিন স্থগিত করেছেন আপিল বিভাগ। এর আগে ঢাকায় তাকে গ্রেপ্তার করা হয়।
# 217    বাংলাদেশে সংখ্যালঘু সনাতন ধর্মাবলম্বীদের সুরক্ষা দিতে বাংলাদেশের অন্তর্বর্তী সরকারের প্রতি আহ্বান জানিয়েছেন যুক্তরাষ্ট্রের কংগ্রেস সদস্য ব্র্যাড শেরমান। জাতিসংঘের মানবাধিকার বিষয়ক হাইকমিশনার ফলকার টুর্কের উত্থাপন করা অভিযোগের তদ
# 218    বাংলাদেশে নিত্যপ্রয়োজনীয় দ্রব্যমূল্যের ঊর্ধ্বগতি নিয়ন্ত্রণ ও সাধারণ মানুষকে স্বস্তি দিতে সরকারের ব্যর্থতার সমালোচনা করেছেন বিএনপির জ্যেষ্ঠ যুগ্ম মহাসচিব রুহুল কবির রিজভী।
# 219    ঢাকার বিমানবন্দরসংলগ্ন এলাকায় ৩৩ একর জমির ওপর আশিয়ান সিটি ডেভেলপমেন্ট লিমিটেডের আবাসন প্রকল্পের কাজ চালু রাখার অনুমতি দেওয়ার রায় বহাল রেখেছেন সুপ্রিম কোর্টের আপিল বিভাগ।
# 220    বাংলাদেশে অন্তর্বর্তী সরকারের প্রথম ১০০ দিন উপলক্ষে প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূসের বক্তব্যে আশাহত হয়েছেন বলে জানিয়েছেন বিএনপি মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর।
# 221    বাংলাদেশের আইন মন্ত্রণালয়ের সলিসটর বিভাগ ২০০৯ সালের ৬ জানুয়ারি থেকে ২০২৪ সাল পর্যন্ত রাজনৈতিক নেতা-কর্মী ও অন্যান্যদের বিরুদ্ধে দায়ের করা হয়রানিমূলক মামলার তালিকা চেয়েছে।
# 222    বাংলাদেশে শীতে বিভিন্ন দেশ থেকে আসা আন্তর্জাতিক ফ্লাইট ঘন কুয়াশার কারণে ঢাকায় না নামতে পারলে সিলেট ও চট্টগ্রামের শাহ আমানত বিমানবন্দর ব্যবহার করবে বলে জানিয়েছে বেসামরিক বিমান চলাচল কর্তৃপক্ষ।
# 223    বাংলাদেশের জনপ্রিয় চিত্রনায়ক রুবেল মাদারীপুরের একটি সড়ক দুর্ঘটনায় আহত হয়েছেন। নায়কের ব্যবহৃত প্রাইভেটকারটি দুমড়ে-মুচড়ে গেছে বলে তিনি নিশ্চিত করেছেন। এ ঘটনার পর তাকে ঢাকায় পাঠানো হয়েছে।
# 224    বাংলাদেশে নতুন নির্বাচন কমিশন গঠনের জন্য প্রার্থীদের সুপারিশের দায়িত্বপ্রাপ্ত সার্চ কমিটি আজ সন্ধ্যায় রাষ্ট্রপতি মোহাম্মদ সাহাবুদ্দিনের সঙ্গে দেখা করার কথা জানিয়েছে দেশটির রাষ্ট্রীয় গণমাধ্যম।
# 225    শান্তিতে নোবেলজয়ী বাংলাদেশের প্রধান উপদেষ্টা অধ্যাপক মুহাম্মদ ইউনূস আজারবাইজানের রাজধানী বাকুতে অনুষ্ঠিত বার্ষিক জলবায়ু সম্মেলনের ফাঁকে প্রেসিডেন্ট ও প্রধানমন্ত্রীদের সঙ্গে বৈঠক করেছেন।
# 226    বাংলাদেশে বিরোধী দল বিএনপির নেতারা বলছেন, অন্তর্বর্তীকালীন সরকারের কিছু কর্মকাণ্ড ও বিবৃতি নিয়ে তাদের আপত্তি ও অসন্তোষ সত্ত্বেও দলের ইতিবাচক ভাবমূর্তি বৃদ্ধি এবং আস্থা তৈরির জন্য সাংঘর্ষিক রাজনীতি পরিহার করে রাজনৈতিক
# 227    বাংলাদেশে সংবাদমাধ্যমের স্বাধীনতা চরম আক্রমণের মুখে বলে মন্তব্য করেছে সংবাদপত্রের মালিকদের সংগঠন নিউজপেপার ওনার্স অ্যাসোসিয়েশন অব বাংলাদেশ (নোয়াব)। এরই মধ্যে প্রথম আলো, ডেইলি স্টারসহ সব ধরনের প্রতিষ্ঠানে মব জাস্টিস কঠ
# 228    বাংলাদেশের শীর্ষ ঋণ খেলাপি আশিকুর রহমান লস্কর ও তার দুই সহযোগীর বিরুদ্ধে গ্রেপ্তারি পরোয়ানা জারি করেছে চট্টগ্রাম অর্থঋণের আদালত। এই আদেশ দেয়া হয়েছে আসামির ওপর।
# 229    বাংলাদেশের জনপ্রশাসন মন্ত্রণালয় প্রধান উপদেষ্টার কার্যালয়ের প্রেস উইংয়ের সিনিয়র সহকারী প্রেসিডেন্ট হিসেবে নিয়োগ পেয়েছেন সাংবাদিক ফয়েজ আহম্মদ। এই পদে যোগদানের তারিখ ঘোষণা করা হয়েছে।
# 230    বাংলাদেশের রাজধানী ঢাকায় নিউমার্কেট এলাকায় ব্যবসায়ী আব্দুল ওয়াদুদ নিহতের ঘটনায় দায়ের করা মামলায় সাবেক খাদ্যমন্ত্রী কামরুল ইসলামকে আট দিনের রিমান্ডে পাঠিয়েছে আদালত। রিমান্ড বাতিল ও জামিন চেয়ে আবেদন করেছেন আসামিরা।
# 231    ঢাকা ডিগ্রি কলেজের ছাত্র ফয়জুল ইসলাম রাজন (১৮) হত্যামামলায় সাবেক প্রধানমন্ত্রী শেখ হাসিনাসহ ২৩ জনের বিরুদ্ধে তদন্ত প্রতিবেদন আগামী ৫ জানুয়ারির মধ্যে জমা দিতে বলেছে আদালত।
# 232    বাংলাদেশের চট্টগ্রাম সিটি করপোরেশনে (চসিক) জাল সনদ দিয়ে চাকরি নেওয়ার অভিযোগ উঠেছে এক প্রকৌশলীর বিরুদ্ধে। স্থানীয় সরকার বিভাগের উপসচিব খন্দকার ফরহাদ আহমেদ এ আদেশ দিয়েছেন।
# 233    বাংলাদেশের রাজধানী আজিমপুরে বাসায় ডাকাতির পর কন্যাশিশুকে অপহরণের ঘটনায় একজনকে আটক করেছে র ্যাপিড অ্যাকশন ব্যাটালিয়ন। এর আগে বৃহস্পতিবার রাতে সাবলেট হিসেবে উঠেছিলেন এক নারী।
# 234    বাংলাদেশের নরসিংদীর পলাশ উপজেলায় ইটবাহী ট্রলির ধাক্কায় দুই মোটরসাইকেল আরোহীর মৃত্যুর ঘটনায় একজন নিহত হয়েছে। অন্যজন গুরুতর আহত হওয়ার খবর নিশ্চিত করেছে পুলিশ।
# 235    বাংলাদেশে অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস বলেছেন, যুক্তরাষ্ট্রের রিপাবলিকান পার্টির শীর্ষ নেতাদের বাংলাদেশ সফরের আহ্বান জানিয়েছেন তিনি। নতুন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প প্রশাসনের সঙ্গে বাংলাদেশ ঘনিষ্ঠভাবে কাজ করতে চ
# 236    বাংলাদেশে নিযুক্ত ভারতের হাইকমিশনার প্রণয় কুমার ভার্মা বলেছেন, বাংলাদেশ-ভারত সম্পর্ক কোনো একটি এজেন্ডা বা এক ইস্যুতে আটকে থাকতে পারে না এবং তা রাজনৈতিক অবস্থার পরিবর্তন হলেও বারবার সামনে চলে আসবে।
# 237    আজারবাইজানের রাজধানী বাকুতে অনুষ্ঠিত জলবায়ু সম্মেলনে যোগদান শেষে দেশে ফিরেছেন জাতিসংঘের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস। ঢাকায় পৌঁছেছেন তিনি।
# 238    বাংলাদেশের প্রধানমন্ত্রী শেখ হাসিনার পতনের পর থেকে ভারতের গণমাধ্যমে উসকানিমূলক মন্তব্য ও অপপ্রচারের মুখে দেশবাসীকে সর্বোচ্চ সংযম দেখানোর আহ্বান জানিয়েছেন বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমান।
# 239    ফেসবুকে ধর্মীয় অনুভূতিতে আঘাতের অপরাধে শাস্তি বাড়িয়ে মৃত্যুদণ্ড বা যাবজ্জীবন কারাদণ্ডের পরামর্শ দিয়েছেন বাংলাদেশের হাইকোর্ট। এর আগে সেলিম খানের বিরুদ্ধে দায়ের করা মামলার তদন্তকারী কর্মকর্তা ২৫ লাখ টাকা ব্যাংকে জমা দেওয়ার
# 240    বিএনপির মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর বলেছেন, একটি রাজনৈতিক দলকে নিষিদ্ধ করার ব্যাপারে মতামত দেওয়াটা সমীচীন নয় এবং জাতি হিসেবে অনেক বড় বিপদ ফেস করবে।
# 241    সশস্ত্র বাহিনী দিবস উপলক্ষে আজ বৃহস্পতিবার ঢাকা সেনানিবাসে যানবাহন চলাচল সীমিত করা হয়েছে। এর মধ্যে সড়ক পরিবহণ ও সেতু পরিস্থিতি নিয়েও ব্যবস্থা নেয়া হচ্ছে।
# 242    বাংলাদেশের অন্তর্বর্তী সরকারের তথ্য উপদেষ্টা নাহিদ ইসলাম বলেছেন, পরিকল্পিতভাবে শিক্ষার্থীদের বিতর্কিত করার চেষ্টা করা হচ্ছে বলে মন্তব্য করেছেন প্রধানমন্ত্রী শেখ হাসিনার একজন ঊর্ধ্বতন কর্মকর্তা।
# 243    বাংলাদেশে অন্তর্বর্তী সরকার সাইবার নিরাপত্তা আইনের পরিবর্তে প্রস্তাবিত সাইবা সুরক্ষা আইন নিয়ে আসতে চলেছে বলে জানিয়েছেন আইণ উপদেষ্টা আসিফ নজরুল। 'সংশোধিত আন্তর্জাতিক অপরাধ ট্রাইব্যুনাল আইনকে মন্ত্রিসভায় গৃহীত হওয়ার জন্য প্রস্ত
# ...
# 397    বাংলাদেশে বিরোধী দল বিএনপি বলেছে, ৫ আগস্টের চেতনাকে ধারণ করতে পারছেন না, তাই বিভিন্ন জায়গায় স্বৈরাচারের দোসরদের বসিয়ে রেখেছেন বিএনপির সিনিয়র যুগ্ম-মহাসচিব রুহুল কবির রিজভী।
# 398    বাংলাদেশে ২০২৪ সালে ছাত্র-জনতার অভ্যুত্থানের মাধ্যমে ১৯৭১ সালের মুক্তিযুদ্ধের নবায়ন হয়েছে বলে মন্তব্য করেছেন সংস্কৃতি মন্ত্রণালয়ের একজন উপদেষ্টা মোস্তফা সরয়ার ফারুকী। তিনি বলেছেন, 'বিদ্বেষের চেতনা ছিল আমি আমার মতো করে দেশটা
# 399    বাংলাদেশের বর্তমান অন্তর্বর্তী সরকার ছাত্র-জনতার গণঅভ্যুত্থানের মধ্য দিয়ে প্রতিষ্ঠা হয়েছে, তাদের ষড়যন্ত্র সবাই মিলে মোকাবিলা করা হবে বলে মন্তব্য করেছেন বিএনপির প্রধান উপদেষ্টা ড. খন্দকার মোশাররফ হোসেন।
# 400    বাংলাদেশে নতুন প্রধান নির্বাচন কমিশনার হিসেবে নিয়োগ পাওয়া অবসরপ্রাপ্ত সচিব এ এম এম নাসির উদ্দীন বলেছেন তিনি জাতিকে একটি অবাধ, সুষ্ঠু ও গ্রহণযোগ্য  নির্বাচনের উপহার দিতে চান।
# 401    নারায়ণগঞ্জের জেলা প্রশাসক মোহাম্মদ মাহমুদুল হক আজ সন্ধ্যায় নিজ কার্যালয়ে এক সংবাদ সম্মেলনে বাস ভাড়া কমানোর ঘোষণা দিয়েছেন। এর আগে ঢাকার বাইরেও সিএনজিচালিত বাস চালু করা হয়েছিল।
# 402    বাংলাদেশের কিশোরগঞ্জের ব্রাহ্মণকচুরি গ্রামে হিন্দু বাড়িতে হামলা ও লুটপাটের অভিযোগে দায়ের করা মামলার প্রধান আসামি ইদ্রিস মিয়াকে (৪০) গ্রেপ্তার করেছে র ্যাপিড অ্যাকশন ব্যাটালিয়ন (র
# 403    সুনামগঞ্জের তাহিরপুর উপজেলা কৃষি অফিস সংশ্লিষ্টরা বলছেন, বন্যার হাত থেকে রক্ষা পেতে হাওর অঞ্চলে দেশি প্রজাতির বিভিন্ন জাতের বোরো ধানের আবাদ হচ্ছে।
# 404    বাংলাদেশে হিন্দু নারীদের ধর্ষণ ও হত্যার অভিযোগ উঠেছে ভারতের সামাজিক যোগাযোগমাধ্যমে। কিন্তু এটি বাংলাদেশের কোনো ঘটনা নয় বলে জানিয়েছে ফ্যাক্টচেকিং প্ল্যাটফর্ম রিউমর স্ক্যানার বাংলাদেশ।
# 405    বাংলাদেশে জাতিসংঘের শান্তিরক্ষী পাঠানো নিয়ে পশ্চিমবঙ্গের মুখ্যমন্ত্রী মমতা ব্যানার্জির বক্তব্য বাংলাদেশের স্বাধীনতা-সার্বভৌমত্বের প্রতি হুমকিস্বরূপ বলে মন্তব্য করেছেন বিএনপি মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর।
# 406    বাংলাদেশে গাজীপুরে বাসদের (বাংলাদেশের সমাজতান্ত্রিক দল) প্রতিষ্ঠাবার্ষিকী অনুষ্ঠানের সভায় হামলা ও ভাঙচুরের অভিযোগ উঠেছে বিএনপির বিরুদ্ধে। স্থানীয় বিএনপি নেতাকর্মীরা মঞ্চ ভেঙচুর করে বলে অভিযুক্ত হয়েছেন।
# 407    বাংলাদেশের হাইকোর্ট অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা অধ্যাপক ড. মুহাম্মদ ইউনূসের বিরুদ্ধে ছয়টি মামলা বাতিল করে দেওয়া হাইকোর্টের রায় প্রকাশ করেছে। ২০১১ এবং ২০১৯ সালে গ্রামীণ টেলিকমিউনিকেশনের চেয়ারম্যান থাকাকালীন
# 408    বাংলাদেশের প্রধানমন্ত্রী শেখ হাসিনার বিরুদ্ধে গণমাধ্যম ও সামাজিক মাধ্যমে বক্তব্য প্রচারে নিষেধাজ্ঞা দিয়েছে আন্তর্জাতিক অপরাধ ট্রাইব্যুনাল। এর মধ্যে অন্যতম প্রধান বিরোধী দল বিএনপির প্রেসিডেন্ট ডোনাল্ড ট্রাম্প।
# 409    বাংলাদেশের গাজীপুরের জয়দেবপুরে বাসে অগ্নিসংযোগের ঘটনায় করা মামলায় বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমানসহ ৬০ জনকে অব্যাহতি দিয়েছেন আদালত। এদের মধ্যে অন্যতম প্রধান আসামি ছিলেন মো. হোসেন আলী।
# 410    বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ও পুণ্ডরীক ধামের অধ্যক্ষ চিন্ময় কৃষ্ণ দাস ব্রহ্মচারী ও তাদের মালিকানাধীন প্রতিষ্ঠানের নাম পরিচালিত হিসাব ব্যতীত লেনদেন স্থগিত করার নির্দেশনা জারি করেছে বাংলাদেশের কেন্দ্রীয় ব্যাংক।
# 411    বাংলাদেশে অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস বলেছেন, প্রয়োজনীয় ও অত্যাবশ্যকীয় কিছু সংস্কার শেষ করেই তারা নির্বাচনের আয়োজন করবে। ততদিন পর্যন্ত দেশের জনগণকে ধৈর্য ধারণের অনুরোধ জানিয়েছেন।
# 412    বিএনপি মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর বলেছেন, দেশের পরিস্থিতি নিয়ে কোনোদিনই সাফল্য অর্জন করা যায় না। এরকম চেহারা বেরিয়ে আসতে শুরু করেছে এই তিন মাসের মধ্যেই।
# 413    গাজীপুরের শ্রীপুরে পিকনিক বাস বিদ্যুতায়িত হয়ে ইসলামিক ইউনিভার্সিটি অব টেকনোলজির (আইইউটি) তিন শিক্ষার্থী মারা যাওয়ার ঘটনায় সাতজনকে সাময়িকভাবে বরখাস্ত করেছে বাংলাদেশ পল্লী বিদ্যুৎায়ন বোর্ড।
# 414    ১৯৭১ সালের মুক্তিযুদ্ধের সময় সারা বাংলাদেশে একাধিক আঞ্চলিক বাহিনী গড়ে উঠেছিল। এর মধ্যে একটি ছিল রফিক, আরেকটি বেঙ্গল রেজিমেন্টের সাব সেক্টরের অধীনে প্রশিক্ষণপ্রাপ্ত।
# 415    বাংলাদেশে সহিংসতা ও উসকানির ঘটনা বাড়ছে এবং এটা মিডিয়ার বাড়াবাড়ি হিসেবে উড়িয়ে দেওয়া যায় না বলে মন্তব্য করেছে ভারতের পররাষ্ট্র মন্ত্রণালয়। এর মধ্যে ইসকনের সাবেক নেতা চিন্ময় কৃষ্ণ দাসের স্বচ্ছ ও ন্যায়বিচারের আশা প্রকাশ
# 416    বাংলাদেশে জনতা ব্যাংকের ৮৫ কোটি ৮৭ লাখ টাকা আত্মসাতের অভিযোগে করা মামলায় হলমার্ক গ্রুপের চেয়ারম্যান জেসমিন ইসলামকে জামিন দিয়েছেন সুপ্রিম কোর্ট। তিন মাসের মধ্যে তদন্ত প্রতিবেদন আদালতে দাখিল করতে আদালত নির্দেশ দিয়েছে।
# 417    বাংলাদেশে ১৯৭১ সালের গণ-অভ্যুত্থানের শহীদ ও আহতদের চিকিৎসা সেবা ও পুনর্বাসন পরিকল্পনা থেকে বাদ যাবে না বলে জানিয়েছেন অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস।
# 418    বাংলাদেশে উদ্যোক্তাদের একটি প্রজন্ম তৈরি করতে হলে দেশের শিক্ষাব্যবস্থা এমন হতে হবে যাতে সৃজনশীলতার বিকাশ ঘটে। শিক্ষা মন্ত্রণালয়ের প্রধান উপদেষ্টা অধ্যাপক ড. মুহাম্মদ ইউনূস বলেছেন, এটি একটির ত্রুটিপূর্ণ শিক্ষা ব্যবস্থা।
# 419    বাংলাদেশের রাজধানী ঢাকা ও চট্টগ্রামে আইনশৃঙ্খলা পরিস্থিতি নিয়ন্ত্রণে ১০ প্লাটুন বর্ডার গার্ড বাংলাদেশ (বিজিবি) সদস্যদের মোতায়েন করা হয়েছে বলে জানিয়েছে বিজিবির জনসংযোগ কর্মকর্তা শরিফুল ইসলাম দ্য ডেইলি স্টার।
# 420    চোখের সেবা সম্প্রসারণে অলাভজনক প্রতিষ্ঠান অরবিস ইন্টারন্যাশনালের সঙ্গে সম্পর্ক অব্যাহত রাখতে বাংলাদেশের আগ্রহ জানিয়েছেন অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস।
# 421    বাংলাদেশে আগামী বছরের ফেব্রুয়ারির মধ্যে একটি রাজনৈতিক দল গঠন ও পরবর্তী জাতীয় নির্বাচনে অংশ নেওয়ার পরিকল্পনা করছে ছাত্রনেতারা। নতুন এই দলের নেতৃত্বে থাকবেন নাগরিক কমিটি এবং বৈষম্যবিরোধী ছাত্র আন্দোলন।
# 422    যুদ্ধবিধ্বস্ত লেবানন থেকে নিরাপদে দেশে ফিরে এসেছেন আরও ১০৫ বাংলাদেশি। তারা সেখানে আটকা ছিলেন এবং চলমান সংঘর্ষের মধ্যে তাদের প্রত্যাবাসনের জন্য প্রচেষ্টা অব্যাহত রেখেছে।
# 423    ভারতের উত্তর-পূর্বাঞ্চলীয় রাজ্য ত্রিপুরায় ভ্রমণকালে হয়রানি ও হেনস্তার শিকার হওয়ার অভিযোগ করেছেন দেশটিতে ইতোমধ্যে অবস্থানরত বাংলাদেশিরা। গতকাল থেকে সেখানে কোনো বাংলাদেশি হোটেল বুকিং নেওয়া হচ্ছে না।
# 424    বাংলাদেশে ঢাকা-নারায়ণগঞ্জ রুটে বাসভাড়া কমানো এবং শিক্ষার্থীদের অর্ধেক ভাড়া বাস্তবায়নের দাবিতে আগামী রোববার নারায়ণেরগঞ্জ শহরে অংশ নেওয়ার আহ্বান করেছে নারাদ্দগঞ্জ যাত্রী অধিকার ফোরাম।
# 425    বাংলাদেশে সাংবাদিক কামাল আহমেদকে প্রধান করে ১১ সদস্যদের গণমাধ্যম সংস্কার কমিশন গঠন করেছে সরকার। তাদের প্রতিবেদন জমা দেয়া হবে আগামী ৯০ দিনের মধ্যে। এর আগে নির্বাচনী কার্যক্রম শুরু হবে।
# 426    বাংলাদেশের কক্সবাজার জেলার টেকনাফ থেকে দুটি ট্রলার ও ছয়জন সেন্ট মার্টিনের স্টাফ অপহরণের শিকার হওয়ার খবর পাওয়া গেছে বলে জানাচ্ছেন বিশেষ বাহিনীর একজন কর্মকর্তা। তারা বলছেন, তাদের অপহরণ করা হয়েছে মিয়ানমারের সশস্ত্র গোষ্ঠী আরাকান
# 427    বাংলাদেশের মন্ত্রিপরিষদ বিভাগের প্রধান উপদেষ্টা হিসেবে শপথ নেওয়ার পর প্রথমবারের মতো একটি বৈঠকে অংশ নিতে সচিবালয়ে যাচ্ছেন ড. মুহাম্মদ ইউনুস। তবে দর্শনার্থী প্রবেশ নিয়ন্ত্রণ করা হয়েছে।
# 428    বাংলাদেশে ভারতীয় স্যাটেলাইট চ্যানেলগুলোর সম্প্রচার বন্ধ করা হয়েছে - এমন একটি তথ্য সামাজিক যোগাযোগমাধ্যমে ছড়িয়ে পড়লেও তা সঠিক নয় বলে জানিয়েছে ফ্যাক্টচেকিং প্ল্যাটফর্ম রিউমর স্ক্যানার বাংলাদেশ।
# 429    বাংলাদেশে বিরোধী দল বিএনপি চেয়ারপারসন বেগম খালেদা জিয়া ঢাকায় যুক্তরাষ্ট্র দূতাবাসে গেছেন। কিন্তু তিনি কেন সেখানে যাচ্ছেন, তা নিয়ে কোন তথ্য জানানো হয়নি বলে জানিয়েছেন বিএনপির একজন কর্মী।
# 430    বাংলাদেশে ছাত্র-জনতার অভ্যুত্থানে গত ৫ আগস্ট রিকশাচালক আল আমিন (২১) হত্যা ও লাশ গুমের অভিযোগে দায়ের করা মামলায় সাবেক রেলমন্ত্রী নূরুল ইসলামের জামিন আবেদন নামঞ্জুর করে কারাগারে পাঠানোর আদেশ দিয়েছে পঞ্চগড়ের একটি আ
# 431    বাংলাদেশে বৈষম্য বিরোধী ছাত্র আন্দোলনের অন্যতম আসামি আলী আজম মুকুলকে আটক করেছে র ্যাপিড অ্যাকশন ব্যাটালিয়ন। তাকে গ্রেপ্তার করা হয়েছে আরো দু'জনকে বলেছে আদালত।
# 432    বাংলাদেশে আওয়ামী ফ্যাসিবাদের পুনর্বাসন ঠেকাতে এবং শিক্ষাপ্রতিষ্ঠানগুলোতে চলমান অস্থিরতা নিরসনে আগামী এক সপ্তাহ 'জাতীয় ছাত্র সংহতি সসপ্তাহে' পালন করবে ছাত্রসংগঠনগুলো।
# 433    বাংলাদেশে অন্তর্বর্তী সরকারে প্রথম একশ দিনের দায়িত্ব পালনের বিষয়ে নিজেকে দশের মধ্যে চার দেবেন বলে জানিয়েছেন আইন উপদেষ্টা আসিফ নজরুল। তিনি বলেছেন, কোনোদিনও সন্তুষ্ট না আমার কাজে।
# 434    সাইবার নিরাপত্তা আইন বাতিলের সিদ্ধান্তের প্রেক্ষাপটে গণমাধ্যম সংস্কারের উদ্যোগ নেওয়া হবে বলে জানিয়েছেন ডাক, টেলিযোগাযোগ ও তথ্যপ্রযুক্তি মন্ত্রণালয় উপদেষ্টা নাহিদ ইসলাম। এর মধ্যে ইউনেস্কো ও ইউএনডিপির সহযোগিতাও রয়েছে।
# 435    বাংলাদেশ থেকে পাচারকৃত অর্থ ফিরিয়ে আনতে এবং অতীতের স্বৈরাচারী শাসনের কারণে ভঙ্গুর অবস্থায় পড়া অর্থনীতি সচল রাখতে যুক্তরাজ্যের সহায়তা চেয়েছেন অন্তর্বর্তীকালীন সরকারের উপদেষ্টা মাহফুজ আলম।
# 436    গাজীপুরের শ্রীপুরে উচ্ছেদ অভিযানে যাওয়া উপজেলা নির্বাহী কর্মকর্তার (ইউএনও) গাড়ি ভাঙচুরের ঘটনা ঘটেছে। বন বিভাগের জমি অবৈধ দখলের বিরুদ্ধে যৌথ বাহিনীর অভিযোগ শেষে ফিরে যাওয়ার সময় দুর্বৃত্তরা এ হামলা করে
# 437    বাংলাদেশে ইসলামিক ফাউন্ডেশনের দুর্নীতির শ্বেতপত্র প্রকাশ করার সিদ্ধান্ত নিয়েছে দেশটির বোর্ড অব গভর্নরস ও ধর্ম উপদেষ্টার একজন অবসরপ্রাপ্ত বিচারককে প্রধান করে একটি কমিটি গঠন করা হয়েছে।
# 438    বাংলাদেশে অনিয়ম ও দুর্নীতির অভিযোগ ওঠায় সুপ্রিম কোর্টের হাইকোর্ট বিভাগের তিন বিচারপতি পদত্যাগ করেছেন। রাষ্ট্রপতি শেখ আবু তাহের স্বাক্ষরিত প্রজ্ঞাপনে এই খবর উঠে এসেছে। এর আগে থেকেই হাইকোর্টে নিয়োগ পেয়েছেন তারা।
# 439    বাংলাদেশের হযরত শাহজালাল আন্তর্জাতিক বিমানবন্দরে আজ যাত্রীদের জন্য ওয়েটিং লাউঞ্জ উদ্বোধন করবেন প্রধান উপদেষ্টা ড. মুহাম্মদ ইউনূস। বৃহস্পতিবার সন্ধ্যায় দেশে ফেরার কথা রয়েছে তিনি।
# 440    বাংলাদেশে সংবিধান সংস্কারের বিষয়ে বিরোধী দল বিএনপির পক্ষ থেকে লিখিত প্রস্তাব পাওয়ার পর তা নিয়ে আলোচনা অব্যাহত রাখা হয়েছে বলে জানিয়েছেন সংবিধানের সংস্কার কমিশনের প্রধান অধ্যাপক আলী রীয়াজ।
# 441    বাংলাদেশের অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা অধ্যাপক ড. মুহাম্মদ ইউনূস বলেছেন, দেশের স্বাধীনতা অনেকের কাছে পছন্দ হচ্ছে না। নানাভাবে দেশকে নতুন করে অস্থির করার চেষ্টা চলছে।
# 442    বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ও আন্তর্জাতিক কৃষ্ণভাবনামৃত সংঘের (ইসকন) সাবেক নেতার গ্রেপ্তার করাকে কেন্দ্র করে বিশৃঙ্খল পরিস্থিতির পেছনে দেশের বাইরে থেকে ইন্ধন থাকতে পারে বলে মন্তব্য করেছেন অন্তর্বর্তীকাল
# 443    বিশ্ব দরবারে মানবিক ও কল্যাণকর রাষ্ট্র হিসেবে সমাদৃত বাংলাদেশ গড়ার অঙ্গীকার ব্যক্ত করে বাংলাদেশের অন্তর্বর্তী সরকারের প্রধান উপদেষ্টা বলেছেন, এ নতুন দেশে আমাদের দায়িত্ব সব মানুষকে এক বৃহত্তর পরিবারের বন্ধনে আবদ্ধ করা।
# 444    বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ও আন্তর্জাতিক কৃষ্ণভাবনামৃত সংঘের (ইসকন) সাবেক নেতা চিন্ময় கிருஷ்ண দাসের জামিন নামঞ্জুর করে তাকে কারাগারে পাঠানোর আদেশ দিয়েছেন চট্টগ্রামের এক আদালত।
# 445    বাংলাদেশের গাজীপুরের শ্রীপুরে বকেয়া বেতনের দাবিতে জৈনা বাজার কাওরাইদ আঞ্চলিক সড়ক অবরোধ করে বিক্ষোভ করছে কারখানার শ্রমিকরা। তারা বলছেন, এখন পর্যন্ত বেতন পায়নি।
# 446    নারায়ণগঞ্জের বন্দরে উপজেলায় মুক্তিযোদ্ধা কমপ্লেক্সে ভাঙচুর চালিয়েছেন যুবদল নেতাকর্মীরা। সেখানে সাবেক প্রধানমন্ত্রী শেখ হাসিনার ছবি এবং কিছু ঐতিহাসিক বই ছিল।
# 447    বাংলাদেশে ছাত্র-জনতার গণঅভ্যুত্থানের মুখে শেখ হাসিনা পদত্যাগ করে পালিয়ে যাওয়ার পর দেশের রাজনীতি ও সার্বিক পরিস্থিতি বদলে গেছে বলে বিবিসি বাংলার দ্য ডেইলি স্টার প্রতিবেদন জানিয়েছে।
# 448    বাংলাদেশ-ভারত সম্পর্ক কোনো উদ্বেগজনক পরিস্থিতিতে নেই বলে মন্তব্য করেছেন বাংলাদেশের অন্তর্বর্তীকালীন সরকারের স্বরাষ্ট্র উপদেষ্টা লেফটেন্যান্ট জেনারেল (অব.) জাহাঙ্গীর আলম চৌধুরী।
# 449    বাংলাদেশের রাজধানী ঢাকার ধামরাইয়ে একটি সড়ক দুর্ঘটনায় চার শ্রমিক নিহত হওয়ার ঘটনার প্রতিবাদে সাধারণ ছুটি ঘোষণা করা হয়েছে। এরপরও মহাসড়কের শ্রীরামপুর এলাকায় বিক্ষোভ করেছেন শ্রমিকরা।
# 450    বাংলাদেশের চট্টগ্রাম বন্দরে জেটিতে থাকা একটি জাহাজের ক্রেনের হুক ছিঁড়ে কনটেইনার পড়ে দুই শ্রমিক আহত হওয়ার খবর নিশ্চিত করেছে বন্দর কর্তৃপক্ষ। এই দুর্ঘটনার ঘটনা ঘটেছে।
# 451    গাজীপুরের ইসলামিক ইউনিভার্সিটি অব টেকনোলজির শিক্ষার্থী মীর মোজাম্মেল হোসেন নাঈম গতকাল শনিবার বনভোজনের বাস বিদ্যুতায়িত হয়ে মৃত্যুর পর তার মরদেহ উদ্ধার করা হয়েছে।
# 452    ভারত আওয়ামী লীগের চোখ দিয়ে বাংলাদেশকে দেখে বলে মন্তব্য করেছেন বৈষম্যবিরোধী ছাত্র আন্দোলনের আহ্বায়ক হাসনাত আবদুল্লাহ। তিনি বলেছেন, বাংলাদেশের সব নাগরিক সাম্য ও মানবিক মর্যাদার ভিত্তিতে বসবাস করছে এবং এখানে যে সম্প্রীতি আছে তা যেন
# 453    র ্যাপিড অ্যাকশন ব্যাটালিয়নের বিরুদ্ধে মানবাধিকার লঙ্ঘনের অভিযোগ আষ্টেপেৃষ্ঠে জড়িয়ে থাকার পর এই বাহিনীকে 'সরকারি ডেথ স্কোয়াড' হিসেবে বর্ণনা করা হচ্ছে।
# 454    বাংলাদেশের গাজীপুরের টঙ্গীতে একটি তৈরি পোশাক কারখানায় অগ্নিকাণ্ডের ঘটনা ঘটেছে। আগুন নিয়ন্ত্রণে আসে বলে জানিয়েছেন কর্মকর্তারা। ধারণা করা হচ্ছে, এতে কোনো শ্রমিক হতাহত হননি।
# 455    বাংলাদেশে গণঅভ্যুত্থানে নিহত পোশাক শ্রমিক ফজলুল করিম হত্যা মামলায় পুলিশের সাবেক মহাপরিদর্শক চৌধুরী আবদুল্লাহ আল-মামুনকে তিন দিনের রিমান্ড দিয়েছে ঢাকার একটি আদালত।
# 456    বাংলাদেশে অন্তর্বর্তী সরকারের অর্থ উপদেষ্টা ড. সালেহউদ্দিন আহমেদ বলেছেন, তারা চেষ্টা করছেন ভালো কিছু করার। কিন্তু নতুন একটি রাজনৈতিক সংস্কারের জন্য প্রয়োজনীয় ফুটপ্রিন্ত রেখে যাবে।
# 457    ভূমি সংস্কার সুষ্ঠুভাবে সম্পন্ন করা গেলে পার্বত্য চট্টগ্রাম চুক্তি বহুলাংশে সার্থক হবে বলে মন্তব্য করেছেন বাংলাদেশের রাষ্ট্রদূত (অব.) সুপ্রদীপ চাকমা। তিনি বলেছেন, সবার সুপরামর্শে আমরা মিলেমিশে থাকতে চাই।
# 458    বাংলাদেশে দুর্নীতিবিষয়ক অনুসন্ধানী সাংবাদিকতা পুরস্কার ২০২৪ পেয়েছেন পত্রিকা দ্য ডেইলি স্টারের সিনিয়র রিপোর্টার জায়মা ইসলাম। অন্যদিকে টেলিভিশনের অনুষ্ঠান 'তালাশ' পুরষ্কার জিতেছে ঢাকার একুশে।
# 459    বাংলাদেশে পুলিশের নতুন মহাপরিদর্শক বাহারুল আলম বলেছেন, 'আন্দোলনে অংশগ্রহণকারী সবার বীরোচিত ভূমিকার জন্যই জনগণ মুক্ত বাতাসে নিঃশ্বাস নিচ্ছেন।' এর আগে ঢাকায় গণঅভ্যুত্থানের ঘটনায় আহতদের চিকিৎসার
# 460    দিনাজপুরের বীরগঞ্জে যাত্রীবাহী বাস ও ধানবোঝাই ট্রাকের মুখোমুখি সংঘর্ষে চালকসহ তিনজন নিহত হয়েছেন। আহতদের মধ্যে কয়েকজন বাসযাত্রীও রয়েছে বলে জানা গেছে।
# 461    বাংলাদেশের প্রথম দিককার রেলস্টেশন জগতিতে আবারও আন্তঃনগর ট্রেন থামানো ও স্টেশন আধুনিকায়নসহ ছয় দাবিতে ঢাকাগামী বেনাপোল এক্সপ্রেস ટ્રેন আটকে বিক্ষোভ করছেন স্থানীয়রা।
# 462    গাজীপুরের টিএনজেড গ্রুপের বেসিক নীটওয়্যার লিমিটেডের এক পরিচালক আব্দুল হালিমকে গ্রেপ্তারের পর চট্টগ্রামের বাসন থানা পুলিশের কাছে হস্তান্তর করেছে সেনা টহল দল।
# 463    বাংলাদেশের নারায়ণগঞ্জ উপজেলায় একটি পত্রিকার সাংবাদিকের বাড়িতে হামলা চালিয়েছে দুর্বৃত্তরা। এতে জড়িত কয়েকজনকে গ্রেফতার করা হয়েছে বলে অভিযোগ ওঠে পুলিশের একজন কর্মকর্তা।
# 464    বাংলাদেশে ঢাকা-৭ আসনের সাবেক সংসদ সদস্য সোলাইমান সেলিমকে হত্যা মামলায় গ্রেপ্তার করেছে আইনশৃঙ্খলা বাহিনী। তাকে গুলশানের একটি বাসা থেকে গত রাত সাড়ে ১২টার দিকে গুলি করে পুলিশ।
# 465    বাংলাদেশে রাজধানীর সোহরাওয়ার্দী উদ্যান ঘেঁষে নতুন করে শাহবাগ থানা নির্মাণের প্রস্তাব অনুমোদন করেছে মন্ত্রিপরিষদ উপদেষ্টা পরিষদের একটি বৈঠক। এর আগে ঢাকায় 'সাকুরা বার'-এর পেছনে নয়, সোশ্যাল মিডিয়ায় বি
# 466    বাংলাদেশের রাজবাড়ীতে ওল্ড ছাত্রলীগের সাবেক সাধারণ সম্পাদক মো. তানভীর শেখকে (২২) কুপিয়ে হত্যা করেছে দুর্বৃত্তরা। হত্যার পর তাকে ফরিদপুর মেডিকেল কলেজ হাসপাতালে ভর্তি করা হয়েছে।
# 467    বাংলাদেশের নির্বাচন কমিশনার ব্রিগেডিয়ার জেনারেল (অব.) আবুল ফজল মো. সানাউল্লাহ বলেছেন, নির্বাচনের ব্যবস্থার প্রতি জনগণের আস্থাহীনতা সবচেয়ে বড় ঘাটতি বলে মনে করেন তিনি।
# 468    বাংলাদেশে নতুন প্রধান নির্বাচন কমিশনার (সিইসি) এ এম এম নাসির উদ্দীন এবং চারজন সাবেক সচিব শপথ নিয়েছেন। আজ রোববার দুপুরে সুপ্রিম কোর্টের জাজেস লাউঞ্জে তাদের শপের কার্যক্রম শুরু হয়েছে।
# 469    বাংলাদেশে আন্তর্জাতিক অপরাধ ট্রাইব্যুনালের (আইসিটি) প্রধান প্রসিকিউটরের কাছে অভিযোগ দায়ের করেছেন সংস্থাটির সাবেক কর্মকর্তাসহ ৯ জনের বিরুদ্ধে র ্যাবের গুলিতে পা হারানো লিমন হোসেন।
# 470    রাজধানীর সায়েন্সল্যাব এলাকায় ঢাকা কলেজ ও সিটি কলেজের শিক্ষার্থীদের মধ্যে সংঘর্ষের ঘটনা ঘটেছে। এতে আহত হয়েছেন কয়েকজন। পুলিশ ও সেনা সদস্যরা সেখানে অবস্থান করছেন।
# 471    বাংলাদেশের চট্টগ্রামে আদালত চত্বরে সংঘর্ষের সময় আইনজীবী সাইফুল ইসলাম আলিফ হত্যাকাণ্ডে জড়িত সন্দেহে আরও একজনকে গ্রেপ্তার করেছে পুলিশ। এর মধ্যে প্রধান উপদেষ্টার কার্যালয়ে ভাঙচুর হামলার অভিযোগও পাওয়া গেছে।
# 472    বাংলাদেশে সম্প্রতি দেশের আইন-শৃঙ্খলা পরিস্থিতি অস্থিরিশীল করার পেছনে ইন্ধনদাতাদের খুঁজে বের করা হবে বলে জানিয়েছে সেনাবাহিনী। এর আগে ছাত্ররাই আন্দোলন করে বাংলাদেশের বর্তমান পরিবেশ এনেছে।
# 473    বাংলাদেশের রাজধানী ঢাকার সঙ্গে পৌনে ১০টা থেকে দেশের অধিকাংশ এলাকার মধ্যে রেল যোগাযোগ বন্ধ হয়ে গেলেও সব ট্রেন শিডিউল বিপর্যয় হয়েছে বলে জানা গেছে। এর আগে সরকারি তিতুমীর কলেজকে বিশ্ববিদ্যালয় করার দাবিতে রিকশাচালকদের অব
# 474    জামালপুরে বাংলাদেশ ছাত্র ইউনিয়নের সরিষাবাড়ী উপজেলা শাখার সম্মেলনে দুর্বৃত্তরা হামলা চালিয়ে একজন সাংবাদিককে মারধর করেছে বলে নিশ্চিত করেছেন স্থানীয় থানা কর্মকর্তা (ওসি) ওসি।
# 475    বাংলাদেশে নির্বাচন কমিশন সংস্কারের প্রস্তাব পর্যালোচনা করে সিদ্ধান্ত নিয়েছে জাতীয় নাগরিক কমিটি। এর আগে ছাত্র-জনতার অভ্যুত্থানের পর আওয়ামী লীগ সরকার ওই আইন প্রত্যাখ্যান করেছিল।
# 476    বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ও আন্তর্জাতিক কৃষ্ণভাবনামৃত সংঘের (ইসকন) সাবেক নেতা চিন্ময়  শ্রেষ্ঠীর মুক্তির দাবিতে টাঙ্গাইল ও বরিশালে বিক্ষোভ মিছিল ও প্রতিবাদ সভা হয়েছে।
# 477    মুন্সীগঞ্জের শ্রীনগরে গুলিবিদ্ধ মরদেহ উদ্ধারের ঘটনায় ভোলা থেকে তৌহিদ শেখ তন্ময় নামে এক যুবককে গ্রেপ্তার করেছে মুন্সিগঞ্জ ডিবি পুলিশ। শনিবার সকালে ঢাকা-মাওয়া এক্সপ্রেসওয়েতে সাহেদা বেগম নামের এক তরুণ

# %%
df = pd.read_csv('/content/drive/My Drive/Colab/state_zeroshot.csv')

# Display the first few rows to verify the file is loaded properly
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...
# 1           1  অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...
# 2           2  সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...
# 3           3  দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...
# 4           4  পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...
#
#                                         givenSummary  \
# 0  স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...
# 1  অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...
# 2  সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...
# 3  দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...
# 4  পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...
#
#                                       mT5_Test_XLSum
# 0  বাংলাদেশে স্বাধীন সাংবাদিকতার ওপর যে আক্রমণ হচ...
# 1  বাংলাদেশে অক্টোবর মাসে সড়ক দুর্ঘটনায় নিহতের ...
# 2  বাংলাদেশ জলবায়ু পরিস্থিতি মোকাবেলায় আন্তর্জা...
# 3  শান্তিতে নোবেলজয়ী অধ্যাপক ড. মুহাম্মদ ইউনূস ব...
# 4  বাংলাদেশ ও ভারতের মধ্যে পররাষ্ট্র সচিব পর্যায়...

# %%
df
# Out:
#      Unnamed: 0                                               text  \
# 0             0  স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...
# 1             1  অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...
# 2             2  সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...
# 3             3  দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...
# 4             4  পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...
# ..          ...                                                ...
# 473         473  ঢাকার সঙ্গে সারাদেশের রেল যোগাযোগ স্বাভাবিক হয়...
# 474         474  জামালপুরে বাংলাদেশ ছাত্র ইউনিয়ন সরিষাবাড়ী উপজে...
# 475         475  নতুন নির্বাচন কমিশন (ইসি) প্রত্যাখ্যান এবং যে ...
# 476         476  বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ...
# 477         477  মুন্সীগঞ্জের শ্রীনগরে ঢাকা-মাওয়া মহাসড়ক থেকে ন...
#
#                                           givenSummary  \
# 0    স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক...
# 1    অক্টোবর মাসে সারাদেশে ৪৫২টি সড়ক দুর্ঘটনায় ৪৭৫ ...
# 2    সীমিত ডিকার্বনাইজেশন সক্ষমতা সম্পন্ন বেশিরভাগ ...
# 3    দেশের মানুষের নানা প্রত্যাশার মধ্যে যে অন্তর্ব...
# 4    পররাষ্ট্র উপদেষ্টা মো. তৌহিদ হোসেন আজ জানিয়েছে...
# ..                                                 ...
# 473  ঢাকার সঙ্গে সারাদেশের রেল যোগাযোগ স্বাভাবিক হয়...
# 474  জামালপুরে বাংলাদেশ ছাত্র ইউনিয়ন সরিষাবাড়ী উপজে...
# 475  নতুন নির্বাচন কমিশন (ইসি) প্রত্যাখ্যান এবং যে ...
# 476  বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ...
# 477  মুন্সীগঞ্জের শ্রীনগরে ঢাকা-মাওয়া মহাসড়ক থেকে ন...
#
#                                         mT5_Test_XLSum
# 0    বাংলাদেশে স্বাধীন সাংবাদিকতার ওপর যে আক্রমণ হচ...
# 1    বাংলাদেশে অক্টোবর মাসে সড়ক দুর্ঘটনায় নিহতের ...
# 2    বাংলাদেশ জলবায়ু পরিস্থিতি মোকাবেলায় আন্তর্জা...
# 3    শান্তিতে নোবেলজয়ী অধ্যাপক ড. মুহাম্মদ ইউনূস ব...
# 4    বাংলাদেশ ও ভারতের মধ্যে পররাষ্ট্র সচিব পর্যায়...
# ..                                                 ...
# 473  বাংলাদেশের রাজধানী ঢাকার সঙ্গে পৌনে ১০টা থেকে ...
# 474  জামালপুরে বাংলাদেশ ছাত্র ইউনিয়নের সরিষাবাড়ী ...
# 475  বাংলাদেশে নির্বাচন কমিশন সংস্কারের প্রস্তাব পর...
# 476  বাংলাদেশ সম্মিলিত সনাতনী জাগরণ জোটের মুখপাত্র ...
# 477  মুন্সীগঞ্জের শ্রীনগরে গুলিবিদ্ধ মরদেহ উদ্ধারের...
#
# [478 rows x 4 columns]

# %%
# View the original text, given summary, and generated summary for the first row
sample_index = 0  # You can change this to inspect different rows

# Access text, given summary (if available), and generated summary
original_text = df['text'][sample_index]
given_summary = df['givenSummary'][sample_index]  # If present in the CSV
generated_summary = df['mT5_Test_XLSum'][sample_index]

# Print the text and corresponding summaries
print(f"Original Text:\n{original_text}\n")
print(f"Given Summary (if available):\n{given_summary}\n")
print(f"Generated Summary:\n{generated_summary}\n")
# Out:
# Original Text:
# স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক্রমণ হচ্ছে, এটা অত্যন্ত নিন্দনীয় ও শঙ্কাজনক বলে উল্লেখ করেছেন দ্য ডেইলি স্টার সম্পাদক ও প্রকাশক মাহফুজ আনাম।
# আজ বৃহস্পতিবার নিউজপেপার ওনার্স অ্যাসোসিয়েশন অব বাংলাদেশ (নোয়াব) আয়োজিত আক্রমণের মুখে স্বাধীন সাংবাদিকতা ও গণমাধ্যম প্রতিষ্ঠান' শীর্ষক এক মতবিনিময় সভায় এ কথা বলেন তিনি।
# তিনি বলেন, 'আমরা অন্তর থেকে উপলব্ধি করি যে, রাজনৈতিক দল স্বাধীন সাংবাদিকতার বিরাট সহায়ক শক্তি। যারা রাজনীতি করবেন, তারা উপলব্ধি করবেন আপনাদের সহায়ক শক্তি স্বাধীন সাংবাদিকতা—মত প্রকাশের একটা নিরবচ্ছিন্ন পরিবেশ। সেই আকাঙ্ক্ষা থেকে আপনাদের বলা যে, স্বাধীন সাংবাদিকতা এখন হুমকির মুখে এবং আপনাদের সাহায্য আমাদের খুব দরকার।'
# তিনি আরও বলেন, 'আমরা—সম্পাদক পরিষদ এবং সাংবাদিকরা সব সময় সুষ্ঠু নির্বাচনের পক্ষে কাজ করে এসেছি। গত সরকারের তিনটি নির্বাচন যে একেবারেই অগ্রহণযোগ্য ছিল, সেটারও আমরা মত প্রকাশের মাধ্যমে, এডিটোরিয়ালের মাধ্যমে প্রতিবাদ জানিয়েছি। সামনে যে নির্বাচন হবে এবং সামনে নতুন গণতান্ত্রিক পরিবেশ আসবে, সেখানেও আমি আন্তরিকভাবে বলতে চাই, আমরা সংবাদপত্র সম্পূর্ণভাবে সেই গণতান্ত্রিক পরিবেশ সৃষ্টি করার জন্য, গণতন্ত্রকরণের যে প্রক্রিয়া সেটার সঙ্গে থাকব।'
# 'আপনারা যারা রাজনৈতিক দল করেন, তাদের মতপ্রকাশে আমরা হচ্ছি মাধ্যম। আমরা আপনাদের মত প্রকাশ করব, আবার আপনাদের সমালোচনাও করব। সমালোচনা করতে দেয়নি বলেই আমি মনে করি, হাসিনা সরকারের পতন হয়েছে। সংবাদপত্র, ভিন্ন মত, বিশেষ সমালোচনামূলক তথ্য এবং মতামত নিলে উপকৃত হতো। আমরা সেই ধরনের পরিবেশ চাচ্ছি এবং আপনাদের সহযোগিতা চাচ্ছি। সামনে গণতন্ত্র উন্মেষের যে বিরাট সম্ভাবনা, সেখানে রাজনৈতিক দলই মূল শক্তি। সেই শক্তির সহায়ক হিসেবে স্বাধীন সাংবাদিকতা,' যোগ করেন তিনি।
#
#
# Given Summary (if available):
# স্বাধীন সাংবাদিকতার ওপর, সংবাদপত্রের ওপর যে আক্রমণ হচ্ছে, এটা অত্যন্ত নিন্দনীয় ও শঙ্কাজনক বলে উল্লেখ করেছেন দ্য ডেইলি স্টার সম্পাদক ও প্রকাশক মাহফুজ আনাম।
#
# Generated Summary:
# বাংলাদেশে স্বাধীন সাংবাদিকতার ওপর যে আক্রমণ হচ্ছে, এটা অত্যন্ত নিন্দনীয় ও শঙ্কাজনক বলে উল্লেখ করেছেন দ্য ডেইলি স্টার সম্পাদক ও প্রকাশক মাহফুজ আনাম। গত সরকারের তিনটি নির্বাচন যে একেবারেই অগ্রহণযোগ্য ছিল, সেই

# %% [markdown]
# # **ROGUE SCORE**

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.6)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.9)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.2 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 15.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.6 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.6)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=e1401a9389161c429e232d83c28cb98bb861f741ce3a6d5a1e1ac0cd9200d1e2
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# !pip install rouge

import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from rouge import Rouge
from csv import DictReader
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# 1000
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def rougeScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)
    # return SummaryEv
    urlCSV = '/content/' + columnName + 'CSV.csv'
    SummaryEv.to_csv(urlCSV, index=False)

    with open(urlCSV, 'r') as f:
        dict_reader = DictReader(f)
        SummaryEv_dict = list(dict_reader)

    EvJson = json.dumps(SummaryEv_dict, indent = 4)
    JSON = columnName + 'EvJson.json'
    save_file_at_dir('/content', JSON, EvJson)

    urlJSON = '/content/' + columnName + 'EvJson.json'

    with open(urlJSON) as f:
        SummaryEvData = json.load(f)
    lenS = len(SummaryEvData)
    rscore1r = 0
    rscore1p = 0
    rscore1f = 0
    rscore2r = 0
    rscore2p = 0
    rscore2f = 0
    rscorelr = 0
    rscorelp = 0
    rscorelf = 0
    rouge = Rouge()
    for i in range(lenS):
        score = rouge.get_scores(SummaryEvData[i][columnName], SummaryEvData[i]['givenSummary'])
        rscore1r = rscore1r + score[0]['rouge-1']['r']
        rscore1p = rscore1p + score[0]['rouge-1']['p']
        rscore1f = rscore1f + score[0]['rouge-1']['f']
        rscore2r = rscore2r + score[0]['rouge-2']['r']
        rscore2p = rscore2p + score[0]['rouge-2']['p']
        rscore2f = rscore2f + score[0]['rouge-2']['f']
        rscorelr = rscorelr + score[0]['rouge-l']['r']
        rscorelp = rscorelp + score[0]['rouge-l']['p']
        rscorelf = rscorelf + score[0]['rouge-l']['f']

        # rscore = [[rscore1r/lenS, rscore1p/lenS, rscore1f/lenS],
        #           [rscore2r/lenS, rscore2p/lenS, rscore2f/lenS],
        #           [rscorelr/lenS, rscorelp/lenS, rscorelf/lenS]]

    rscore = {'rouge-1': {'r': rscore1r/lenS,
                        'p': rscore1p/lenS,
                        'f': rscore1f/lenS},
                'rouge-2': {'r': rscore2r/lenS,
                        'p': rscore2p/lenS,
                        'f': rscore2f/lenS},
                'rouge-l': {'r': rscorelr/lenS,
                        'p': rscorelp/lenS,
                        'f': rscorelf/lenS}}
    return rscore

# %%
mx = rougeScore('mT5_Test_XLSum')
mx
# Out:
# {'rouge-1': {'r': 0.6498269501768964,
#   'p': 0.5005249645447575,
#   'f': 0.5508495918971733},
#  'rouge-2': {'r': 0.5139033509383442,
#   'p': 0.3937956923262278,
#   'f': 0.43279335011263975},
#  'rouge-l': {'r': 0.6283029889338604,
#   'p': 0.4834779160755384,
#   'f': 0.5324042107051824}}

# %%
def getScore(m, n, x):
    strs = 'rouge-'+str(n)
    return m[strs][x]

# %%
data = {'columns':['rouge-1 r', 'rouge-1 p', 'rouge-1 f', 'rouge-2 r', 'rouge-2 p', 'rouge-2 f', 'rouge-l r', 'rouge-l p', 'rouge-l f'],
        'mT5_Test_XLSum':[getScore(mx, 1, 'r'), getScore(mx, 1, 'p'), getScore(mx, 1, 'f'), getScore(mx, 2, 'r'), getScore(mx, 2, 'p'), getScore(mx, 2, 'f'), getScore(mx, 'l', 'r'), getScore(mx, 'l', 'p'), getScore(mx, 'l', 'f')],
       }

rougeDf = pd.DataFrame(data)
rougeDf_ = rougeDf
rougeDf = rougeDf.reset_index(drop=True).T
rougeDf = rougeDf.rename(columns=rougeDf.iloc[0]).drop(rougeDf.index[0])
rougeDf.reset_index(inplace=True)
rougeDf = rougeDf.rename(columns = {'index':'Summary'})
rougeDf
# Out:
#           Summary rouge-1 r rouge-1 p rouge-1 f rouge-2 r rouge-2 p rouge-2 f  \
# 0  mT5_Test_XLSum  0.649827  0.500525   0.55085  0.513903  0.393796  0.432793
#
#   rouge-l r rouge-l p rouge-l f
# 0  0.628303  0.483478  0.532404

# %%
import matplotlib.pyplot as plt

# plotting graph
rougeDf.plot(x="Summary",
               y=['rouge-1 r',
                'rouge-1 p',
                'rouge-1 f',
                'rouge-2 r',
                'rouge-2 p',
                'rouge-2 f',
                'rouge-l r',
                'rouge-l p',
                'rouge-l f'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Rouge Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **BLEU SCORE**

# %%
import os
import json
from csv import DictReader

def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

genDf.to_csv('/content/bleuEvCSV.csv', index=False)

with open("/content/bleuEvCSV.csv", 'r') as f:
    dict_reader = DictReader(f)
    bleu_dict = list(dict_reader)
print(len(bleu_dict))

bleuEvJson = json.dumps(bleu_dict, indent = 4)
save_file_at_dir('/content', 'bleuEvJson.json', bleuEvJson)

with open('/content/bleuEvJson.json') as f:
  bleuData = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-32-2747d9667f75> in <cell line: 12>()
#      12 with open("/content/bleuEvCSV.csv", 'r') as f:
#      13     dict_reader = DictReader(f)
# ---> 14     bleu_dict = list(dict_reader)
#      15 print(len(bleu_dict))
#      16
#
# /usr/lib/python3.10/csv.py in __next__(self)
#     109             # Used only for its side effect.
#     110             self.fieldnames
# --> 111         row = next(self.reader)
#     112         self.line_num = self.reader.line_num
#     113
#
# Error: field larger than field limit (131072)

# %%
import csv
import os
import json
from csv import DictReader

# Increase the CSV field size limit
csv.field_size_limit(10**6)  # Adjust the value as needed, e.g., 1MB

def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

genDf.to_csv('/content/bleuEvCSV.csv', index=False)

with open("/content/bleuEvCSV.csv", 'r') as f:
    dict_reader = DictReader(f)
    bleu_dict = list(dict_reader)
print(len(bleu_dict))

bleuEvJson = json.dumps(bleu_dict, indent=4)
save_file_at_dir('/content', 'bleuEvJson.json', bleuEvJson)

with open('/content/bleuEvJson.json') as f:
    bleuData = json.load(f)
# Out:
# 478

# %%
import nltk

def bleuCorpass(columnName):
    ble1score = 0
    ble2score = 0
    ble3score = 0
    ble4score = 0
    for i in range(len(bleuData)):
        hypothesis = bleuData[i][columnName].split()
        reference = bleuData[i]['givenSummary'].split()
        references = [reference]
        list_of_references = [references]
        list_of_hypotheses = [hypothesis]
        ble1score = ble1score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(1, 0, 0, 0))
        ble2score = ble2score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.5, 0.5, 0, 0))
        ble3score = ble3score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.33, 0.33, 0.33, 0))
        ble4score = ble4score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.25, 0.25, 0.25, 0.25))

    print("Bleu 1: ", ble1score/len(bleuData),'\n')
    print("Bleu 2: ", ble2score/len(bleuData),'\n')
    print("Bleu 3: ", ble3score/len(bleuData),'\n')
    print("Bleu 4: ", ble4score/len(bleuData),'\n')

    return ble1score/len(bleuData), ble2score/len(bleuData), ble3score/len(bleuData), ble4score/len(bleuData)

# %%
print('mT5_Test_XLSum:', bleuCorpass('mT5_Test_XLSum'))
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Bleu 1:  0.4719267311213409
#
# Bleu 2:  0.41621018041349545
#
# Bleu 3:  0.37212243555854935
#
# Bleu 4:  0.3252893865161492
#
# mT5_Test_XLSum: (0.4719267311213409, 0.41621018041349545, 0.37212243555854935, 0.3252893865161492)

# %% [markdown]
# # **BERTSCORE**

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.46.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
from evaluate import load
bertscore = load("bertscore")
# Out:
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]

# %%
import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from csv import DictReader
# Out:
# 8200
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def bertScore(columnName):
    SummaryEv = genDf.filter(['text', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    bert_precision = 0
    bert_recall = 0
    bert_f1 = 0

    for i in range(lenS):
        results = bertscore.compute(predictions=[SummaryEv[columnName][i]], references=[SummaryEv['text'][i]], lang="bn")

        bert_precision = bert_precision + results['precision'][0]
        bert_recall = bert_recall + results['recall'][0]
        bert_f1 = bert_f1 + results['f1'][0]

    bert_score = {'precision': bert_precision/lenS,
                    'recall': bert_recall/lenS,
                    'f1': bert_f1/lenS}
    return bert_score

# %%
mx = bertScore('mT5_Test_XLSum')
mx
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# {'precision': 0.84232414479535,
#  'recall': 0.6773455404836264,
#  'f1': 0.7505269805008398}

# %%
def getScore(m, x):
    strs = x
    return m[strs]

# %%
import pandas as pd

data = {'columns':['bert_precision', 'bert_recall', 'bert_f1'],
        'mT5_Test_XLSum':[getScore(mx, 'precision'), getScore(mx, 'recall'), getScore(mx, 'f1')],
       }

bertScoreDf = pd.DataFrame(data)
bertScoreDf_ = bertScoreDf
bertScoreDf = bertScoreDf.reset_index(drop=True).T
bertScoreDf = bertScoreDf.rename(columns=bertScoreDf.iloc[0]).drop(bertScoreDf.index[0])
bertScoreDf.reset_index(inplace=True)
bertScoreDf = bertScoreDf.rename(columns = {'index':'Summary'})
bertScoreDf
# Out:
#           Summary bert_precision bert_recall   bert_f1
# 0  mT5_Test_XLSum       0.842324    0.677346  0.750527

# %%
import matplotlib.pyplot as plt

# plotting graph
bertScoreDf.plot(x="Summary",
               y=['bert_precision',
                'bert_recall',
                'bert_f1'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Bert Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **WIL WER METEOR WITH GIVEN SUMMARY**

# %%
from collections import Counter

class MeteorScore:
    def __init__(self, alpha=0.5, beta=0.5, gamma=0.5):
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma

    def preprocess_sentence(self, sentence):
        words = sentence.split()
        return words

    def ngram_count(self, sentence, n):
        words = self.preprocess_sentence(sentence)
        ngrams = [tuple(words[i:i+n]) for i in range(len(words)-n+1)]
        return Counter(ngrams)

    def compute_precision(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        precision = overlap / sum(hyp_counts.values()) if sum(hyp_counts.values()) > 0 else 0
        return precision

    def compute_recall(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        recall = overlap / sum(ref_counts.values()) if sum(ref_counts.values()) > 0 else 0
        return recall

    def meteor_score(self, hypothesis, reference):
        precision = self.alpha * self.compute_precision(hypothesis, reference, 1) + (1-self.alpha) * self.compute_precision(hypothesis, reference, 2)
        recall = self.beta * self.compute_recall(hypothesis, reference, 1) + (1-self.beta) * self.compute_recall(hypothesis, reference, 2)
        fmean = (1-self.gamma) * precision + self.gamma * recall if (precision != 0 and recall != 0) else 0
        return fmean

# %%
# !pip install jiwer
import jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading jiwer-3.0.5-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.9 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.5 rapidfuzz-3.10.1

# %%
meteor = MeteorScore(alpha=0.5, beta=0.5, gamma=0.5)

def wilWerMeteorScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    wer_score = 0
    meteor_score = 0
    wil_score = 0

    for i in range(lenS):
        wer_result = jiwer.wer(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])
        meteor_result = meteor.meteor_score(SummaryEv[columnName][i], SummaryEv['givenSummary'][i])
        wil_result = jiwer.wil(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])

        wer_score = wer_score + wer_result
        meteor_score = meteor_score + meteor_result
        wil_score = wil_score + wil_result

    wilWerMeteor_score = {'METEOR': meteor_score/lenS,
                    'WER': wer_score/lenS,
                    'WIL': wil_score/lenS}

    return wilWerMeteor_score
    # return spice_score/lenS

# %%
mx = wilWerMeteorScore('mT5_finetuned_test')
mx
# Out:
# {'METEOR': 0.3694995375541737,
#  'WER': 1.1714886828484485,
#  'WIL': 0.8061316430611867}

# %%
import pandas as pd

data = {'columns':['WIL', 'METEOR', 'WER'],
        'mT5_finetuned_test':[getScore(mx, 'WIL'), getScore(mx, 'METEOR'), getScore(mx, 'WER')],
       }

threeScoreDf = pd.DataFrame(data)
threeScoreDf_ = threeScoreDf
threeScoreDf = threeScoreDf.reset_index(drop=True).T
threeScoreDf = threeScoreDf.rename(columns=threeScoreDf.iloc[0]).drop(threeScoreDf.index[0])
threeScoreDf.reset_index(inplace=True)
threeScoreDf = threeScoreDf.rename(columns = {'index':'Summary'})
threeScoreDf
# Out:
#               Summary       WIL  METEOR       WER
# 0  mT5_finetuned_test  0.806132  0.3695  1.171489

# %%
import matplotlib.pyplot as plt

# plotting graph
threeScoreDf.plot(x="Summary",
               y=['WIL', 'METEOR', 'WER'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Three Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a bar chart
plt.figure(figsize=(12, 6))
bar_width = 0.35
x = np.arange(len(metrics))

plt.bar(x, values, width=bar_width, color='skyblue')
plt.xticks(x, metrics, rotation=45, ha='right')
plt.ylabel('Score')
plt.title('Evaluation Metrics for Text Summarization')

# Optionally add a grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a DataFrame
df = pd.DataFrame({'Metric': metrics, 'Score': values})

# Display the table
print(df)

# If you want to export the table to a CSV file
# df.to_csv('/content/summary_evaluation_metrics.csv', index=False)
# Out:
#                    Metric   Score
# 0            ROUGE-1 (F1)  0.1666
# 1            ROUGE-2 (F1)  0.0598
# 2            ROUGE-L (F1)  0.1535
# 3                  BLEU-1  0.1067
# 4                  BLEU-2  0.0529
# 5                  BLEU-3  0.0256
# 6                  BLEU-4  0.0104
# 7   BERTScore (Precision)  0.8277
# 8      BERTScore (Recall)  0.6640
# 9          BERTScore (F1)  0.7366
# 10                 METEOR  0.1642
# 11                    WER  3.1958

# %% [markdown]
# **DATA VISUALIZATION**

# %%
import matplotlib.pyplot as plt

human_lengths = genDf['givenSummary'].apply(lambda x: len(x.split()))
generated_lengths = genDf['mT5_finetuned_test'].apply(lambda x: len(x.split()))

plt.scatter(human_lengths, generated_lengths)
plt.xlabel('Human Summary Length')
plt.ylabel('Generated Summary Length')
plt.title('Human vs. Generated Summary Length')
plt.show()

# %%
gen_length = [len(summary.split()) for summary in genDf["mT5_finetuned_test"]]
ref_length = [len(summary.split()) for summary in genDf["givenSummary"]]

plt.figure(figsize=(10, 6))
plt.scatter(ref_length, gen_length, alpha=0.5)
plt.xlabel("Reference Summary Length (words)")
plt.ylabel("Generated Summary Length (words)")
plt.title("Generated vs. Reference Summary Length")
plt.plot([0, max(ref_length)], [0, max(ref_length)], color='red', linestyle='--')  # Diagonal line
plt.show()

# %% [markdown]
# # **TEST (NOT INCLUDED)**

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from normalizer import normalize  # Assuming you have this installed
import re

# Device setup
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# Load the model and tokenizer
model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Move the model to the correct device (GPU or CPU)
model.to(device)

# Define the whitespace handler
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

# Function to generate a summary
def generate_summary(input_text):
    # Normalize the text (if needed)
    input_text = normalize(input_text)

    # Tokenize the input text
    input_ids = tokenizer(
        [WHITESPACE_HANDLER(input_text)],
        return_tensors="pt",
        padding="max_length",
        max_length=512,
        truncation=True
    )["input_ids"]

    # Generate the summary
    output_ids = model.generate(
        input_ids=input_ids.to(device),
        max_length=400,
        min_length=64,
        no_repeat_ngram_size=2,
        num_beams=4
    )[0]

    # Decode the generated summary
    summary = tokenizer.decode(
        output_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return summary
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
# Example of custom input text
custom_text = """
  'ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়ার গাড়ি, বাড়ি, প্লট, ফ্ল্যাট-কী নেই। রীতিমতো গড়েছেন সম্পদের পাহাড়। শুধু নিজের
  নামেই নয়; স্ত্রী, ছেলে-মেয়ে এবং শ্যালক-শ্যালিকার নামেও গড়েছেন বিপুল সম্পত্তি।\nঅভিযোগ রয়েছে, ডিএমপিতে ‘ঘুষ’ এবং বদলি বাণিজ্যে গড়ে তুলেছেন এসব
  সম্পদ। তার বিপুল সম্পদের বিষয়ে অনুসন্ধান চালাচ্ছে দুর্নীতি দমন কমিশন (দুকক)। যুগান্তরের অনুসন্ধানি প্রতিবেদনে এসব তথ্য ওঠে এসেছে।\nপ্রতিবেদনে জানা যায়,
  রাজধানীর অভিজাত এলাকা সিদ্ধেশ্বরীর ভিকারুননিসা স্কুলের পাশেই রূপায়ণ স্বপ্ন নিলয়। ৫৫/১ হোল্ডিংয়ে আলিশান এ ভবনটি ১১ তলা। এখানে প্রায় সাড়ে ৩ হাজার বর্গফিটের
  একটি ফ্ল্যাট রয়েছে আছাদুজ্জামানের মেয়ে আয়েশা সিদ্দিকার নামে।\nশুক্রবার (২৩ আগস্ট) দুপুরে সেখানে গেলে নিরাপত্তা ইনচার্জ আবুল কালাম আজাদ যুগান্তরকে
   বলেন, তিনি মাস দেড়েক আগে এখানে চাকরি নিয়েছেন। এই ভবনে ১৩০টি ফ্ল্যাট। তাই সব ফ্ল্যাট মালিককে ভালোভাবে চিনেন না। বাড়ির ম্যানেজার সোহেল পারভেজ
    বিস্তারিত বলতে পারবেন বলে জানান তিনি।\nএ বিষয়ে সোহেল পারভেজ জানান, আয়েশা সিদ্দিকার নামে এখানে একটি ফ্ল্যাট আছে। তবে তিনি কখনো এখানে আসেন না।
    এটি ভাড়া দেওয়া আছে।\nধানমন্ডি ১২/এ নম্বর রোডের ৬৯ নম্বর বাড়িতে রয়েছে একটি বিলাসবহুল ফ্ল্যাট। শুক্রবার দুপুরে ওই বাড়িতে যাওয়া হলে ভেতরে প্রবেশের অনুমতি
    মেলেনি। তবে নিজের নাম প্রকাশ না করার শর্তে বাড়ির একজন নিরাপত্তাকর্মী জানান, ধানমন্ডির ১২-এ রোডের ৬৯ নম্বর বাড়ির দ্বিতীয় তলার পুরো ফ্লোরটি সাবেক ডিএমপি
    কমিশনার আছাদুজ্জামান মিয়া কিনেছেন। তবে এটি তার শ্যালকের নামে।\nওই ভবনের তৃতীয় তলার ফ্ল্যাটটি চট্টগ্রাম মেট্রোপলিটন পুলিশের (সিএমপি) সাবেক কমিশনার
    ইকবাল বাহারের। এ বিষয়ে পুলিশ সদর দপ্তরের ডিআইজি কৃষ্ণপদ রায় বলেন, ‘ইকবাল বাহার হলেন আছাদুজ্জামান মিয়ার খুবই ঘনিষ্ঠ। তাই তারা দুজন একই ভবনে
    থাকতেন। আমিও একাধিকবার সেখানে গিয়েছি। আছাদুজ্জামান মিয়া কমিশনার থাকা অবস্থায় ওই ভবনে থাকতেন।’\nশুক্রবার দুপুর আড়াইটায় ইস্কাটন গার্ডেন ১৩/এ
    প্রিয়নীড়ে গিয়ে জানা যায়, সেখানে আছাদুজ্জামানের স্ত্রীর নামে একটি ফ্ল্যাট রয়েছে। বিস্তারিত জানতে চাইলে নিরাপত্তাকর্মী আব্দুস সালাম ও শাহ আলম প্রতিবেদককে
    বলেন, ‘আমরা এখানে নতুন এসেছি, তাই তেমন কিছু জানি না।’\nভবনের ম্যানেজার আজাদ আহমেদ জানান, ১৪ তলা এই ভবনে ৪০টি ফ্ল্যাট আছে। বেশিরভাগ ফ্ল্যাটই
    ২১৩৩ বর্গফুটের। ভবনের ১১ তলায় আছাদুজ্জমানের স্ত্রী আফরোজা জামানের একটি ফ্ল্যাট আছে। তবে সেখানে তিনি থাকেন না। ফ্ল্যাটটি ভাড়া দেওয়া আছে। অভ্যর্থনাকারী
    আবু বকর প্রতি মাসে ভাড়া তুলে আছাদুজ্জামানের কাছে দিয়ে আসেন। ভাড়া বকেয়া পড়লে বা কোনো সমস্যা হলে আমি নিজে স্যারের সঙ্গে (আছাদুজ্জমান) যোগাযোগ
    করেন বলে জানান তিনি।\nখোঁজ নিয়ে জানা যায়, নিকুঞ্জ-১ এর ৮/এ রোডের ৬ নম্বর বাড়িটি আছাদুজ্জামানের ছোট ছেলে আসিফ মাহাদীনের নামে। শুক্রবার বিকালে
    সেখানে যাওয়া হলে বাড়িটি ভেতর থেকে বন্ধ পাওয়া যায়। বেশ কয়েকবার কলিংবেল টিপেও সাড়া পাওয়া যাচ্ছিল না। একপর্যায়ে পাশের চার নম্বর বাড়ির গাড়িচালকের
    সঙ্গে কথা হচ্ছিল এই প্রতিবেদকের। ওই গাড়িচালক জানান, আছাদুজ্জামান সপরিবারে এই বাড়িতে থাকতেন। সরকার পতনের পর তিনি বাড়ি ছেড়ে পালিয়ে গেছেন।
    অনুসন্ধানে আরও জানা যায়, এ ছাড়া বসুন্ধরা আবাসিক এলাকার এল ব্লকের ১ নম্বর রোডের ১৬৬ এবং ১৬৭ নম্বরে ১০ কাঠার ওপর ৬ তলাবিশিষ্ট আলিশান একটি বাড়ি
    আছাদুজ্জামানের স্ত্রী আফরোজা জামানের নামে। পূর্বাচলের নিউ টাউনের ১ নম্বর সেক্টরের ৪০৬/বি নম্বর রোডে ১০ কাঠা জমি রয়েছে আছাদুজ্জামান মিয়ার নামে। ওই জমিতে
     গাড়ি রাখার শেড বানিয়ে রাখা হয়েছে। পূর্বাচলের সেক্টর ৪, রোড ১০৮-এ ৫৩ নম্বর প্লটটি আছাদুজ্জামানের স্ত্রীর নামে ছিল। ৫ কাঠার এই প্লটটি বিক্রি করে দেওয়া হয়েছে।
     আফতাবনগরে ৩ নম্বর সেক্টরে রয়েছে ২১ কাঠা জমি। সেখানে নিজের নামে ১০ কাঠা ও আত্মীয়স্বজনদের নামে রয়েছে বাকি ১১ কাঠা জমি।\nআছাদুজ্জামান
     মিয়ার স্ত্রী আফরোজা জামানের নামে ঢাকা ছাড়াও ফরিদপুর ও নারায়ণগঞ্জে বিপুল সম্পদ রয়েছে। ২০১৮ সালে তিনি রাজউক থেকে বিশেষ কোটায় একটি প্লট বরাদ্দ
     পান। অথচ রাজউকের নীতিমালা অনুযায়ী, স্বামী-স্ত্রী উভয়ের প্লট বরাদ্দ পাওয়ার সুযোগ নেই।\nজানা গেছে, গাজীপুরের কালীগঞ্জ উপজেলার চাঁদখোলা মৌজায় আফরোজা
     জামানের নামে ৬৭ শতাংশ জমি রয়েছে। ২০১৭ সালে এই জমি কেনা হয়। ওই মৌজায় তার নামে ২০১৯ সালের ৫ ফেব্রুয়ারি কেনা হয় আরও ৩৯ শতাংশ জমি। একই নামে
     ২০২০ সালে জোয়ার সাহারা মৌজায় কেনা হয় ১৫ কাঠা জমি। ওই বছর গাজীপুরের চাঁদখোলা মৌজায় ৩১ শতক জমি ক্রয় করেন আফরোজা। আফরোজা ২০১৮ সালে
     নারায়ণগঞ্জের রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ২৮ একর জমি কেনেন। ওই বছর একই মৌজায় আরও ৩২ শতক জমি কেনেন তিনি। ওই বছরই
     রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ৬০ একর জমি তার নামে কেনা হয়। পরে তা বিক্রি করে দেওয়া হয়। ২০১৯ সালে কৈয়ামসাইল-কায়েতপাড়া মৌজায়
     দশমিক ৫৭ একর জমির পাওয়ার অব অ্যাটর্নি পান আছাদুজ্জামানের স্ত্রী। এরপর ওই জমি বিক্রিও করেন।\nঅনুসন্ধানে আছাদুজ্জামান মিয়ার পরিবারের সদস্যদের মালিকানার
     দুটি কোম্পানির খোঁজ পাওয়া গেছে। এর মধ্যে একটি হলো মৌমিতা ট্রান্সপোর্ট লিমিটেড। এর চেয়ারম্যান আছাদুজ্জামানের স্ত্রী আফরোজা। আছাদুজ্জামান ডিএমপি কমিশনার
     থাকাকালীন রাজধানীর রুট পারমিট কমিটির প্রধান ছিলেন। ওই সময় মৌমিতা পরিবহণকে রুট পারমিট দেওয়া হয়। মৌমিতা ট্রান্সপোর্ট লিমিটেডের ভাইস চেয়ারম্যান হারিসুর
     রহমান সোহান হলেন আছাদুজ্জামানের শ্যালক। সোহানের নামে রাজধানীর নিউমার্কেটে আছে স্বর্ণের দোকান।\nআরও জানা যায়, শেপিয়ার্ড কনসোর্টিয়াম লিমিটেড নামে
     আরেকটি কোম্পানির চেয়ারম্যান আফরোজা জামান। এই কোম্পানির পরিচালক আছাদুজ্জামানের বড় ছেলে আসিফ শাহাদাত। আছাদুজ্জামানের শ্যালক নূর আলম ওরফে
     মিলনের নামে গাজীপুরের শ্রীপুরে দেড় একর জমি রয়েছে। ভাগনে কলমের নামেও গাজীপুরে জমি আছে দেড় একর।\nএদিকে আছাদুজ্জামান মিয়ার অবৈধ সম্পদের
     অনুসন্ধান শুরু করেছে দুদক। সংস্থাটির সচিব খোরশেদা ইয়াসমীন গণমাধ্যমকে বলেন, আছাদুজ্জামান মিয়ার বিরুদ্ধে বিভিন্ন অনিয়ম ও দুর্নীতির মাধ্যমে কোটি কোটি
     টাকার অবৈধ সম্পদ অর্জনের অভিযোগ এসেছে। এই অভিযোগ অনুসন্ধানের সিদ্ধান্ত গৃহীত হয়েছে বলে জানান তিনি।\nআওয়ামী লীগ সরকারের পতনের কয়েকদিন আগে
     আছাদুজ্জামান মিয়া জানিয়েছিলেন, তার এবং পরিবারের সদস্যদের কোনো অবৈধ সম্পদ নেই। যেসব সম্পদ আছে সবই আয়কর বিবরণীতে উল্লেখ করা আছে। সরকারের
     কোনো সংস্থা যদি এসব সম্পদের বিষয়ে অনুসন্ধান চালায় তাহলে তিনি ও তার পরিবারের সদস্যরা ওই সংস্থাকে সহযোগিতা করবেন।'
"""

# Generate the summary for the custom input text
generated_summary = generate_summary(custom_text)

# Print the original text and its generated summary
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়া রীতিমতো গড়েছেন বিপুল সম্পত্তি। তার গাড়ি, বাড়ি, প্লট এবং ফ্ল্যাট-কী নেই। অনুসন্ধানে এসব তথ্য উঠে এসেছে।

# %%
custom_text2 = """
বাংলাদেশের অর্থনৈতিক অবস্থা উন্নতির দিকে ধাবিত হচ্ছে, বিশেষ করে গত কয়েক বছরে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।
অর্থনীতিবিদরা মনে করছেন, এই অগ্রগতি ধরে রাখতে পারলে বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার অন্যতম শক্তিশালী অর্থনীতিতে পরিণত হতে পারে।
"""

generated_summary = generate_summary(custom_text2)
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার সবচেয়ে শক্তিশালী দেশগুলোর একটি হিসেবে পরিণত হতে পারে বলে মনে করছেন অর্থনৈতিক বিশ্লেষকরা। এর মধ্যে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।

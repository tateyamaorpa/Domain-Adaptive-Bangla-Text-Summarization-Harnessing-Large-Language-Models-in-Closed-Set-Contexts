# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset I

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model

df = pd.read_csv('/content/drive/MyDrive/Colab/updated_ittefaq_sports.csv')
df.head()
# Out:
#   category                                             title  \
# 0   sports    পাকিস্তানকে উড়িয়ে এশিয়া কাপের ফাইনালে বাংলাদেশ
# 1   sports                যুব বিশ্বকাপ হকিতেও টক্কর দিতে চান
# 2   sports                             এমন ম্যাচেও হারা যায়!
# 3   sports  লাহোরকে হারিয়ে গ্লোবাল সুপার লিগের ফাইনালে রংপুর
# 4   sports                    কী যন্ত্রণা বয়ে বেড়াতেন সাদিয়া
#
#                                                 text  \
# 0  দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনা...
# 1  বিমান বন্দর থেকে তেজগাঁওয়ে বিমান বাহিনীর ফ্যাল...
# 2  সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ...
# 3  ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচ। ফাইনাল খেলতে...
# 4  সাদিয়াকে কখনো কেউ গোমড়া মুখে দেখেনি। সব সময় হা...
#
#                                              summary
# 0  দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনা...
# 1  বিমান বন্দর থেকে তেজগাঁওয়ে বিমান বাহিনীর ফ্যাল...
# 2  সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ...
# 3  ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচ। ফাইনাল খেলতে...
# 4  সাদিয়াকে কখনো কেউ গোমড়া মুখে দেখেনি। সব সময় হা...

# %%
df
# Out:
#     category                                             title  \
# 0     sports    পাকিস্তানকে উড়িয়ে এশিয়া কাপের ফাইনালে বাংলাদেশ
# 1     sports                যুব বিশ্বকাপ হকিতেও টক্কর দিতে চান
# 2     sports                             এমন ম্যাচেও হারা যায়!
# 3     sports  লাহোরকে হারিয়ে গ্লোবাল সুপার লিগের ফাইনালে রংপুর
# 4     sports                    কী যন্ত্রণা বয়ে বেড়াতেন সাদিয়া
# ..       ...                                               ...
# 495   sports  আবারও পুরোনো ঠিকানায় থাকছেন মাহমুদউল্লাহ-মাশরাফি
# 496   sports    অবশেষে দল পেলেন শান্ত, দ্বিতীয় সেটে কে কোন দলে
# 497   sports      রাজশাহীতে তাসকিন, ঢাকায় লিটন, মাশরাফি সিলেটে
# 498   sports                     নারী বিশ্বকাপে জমে উঠেছে লড়াই
# 499   sports                        ঢাকার হেলস হয়ে গেল রংপুরের
#
#                                                   text  \
# 0    দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনা...
# 1    বিমান বন্দর থেকে তেজগাঁওয়ে বিমান বাহিনীর ফ্যাল...
# 2    সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ...
# 3    ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচ। ফাইনাল খেলতে...
# 4    সাদিয়াকে কখনো কেউ গোমড়া মুখে দেখেনি। সব সময় হা...
# ..                                                 ...
# 495  বিপিএলের একাদশ আসরের জন্য প্লেয়ার্স ড্রাফটের প...
# 496  শুরু হয়েছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) এ...
# 497  শুরু হয়েছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) এ...
# 498  একটি ম্যাচ জয়ের লক্ষ্য নিয়ে নবম নারী টি-টোয়েন্...
# 499  শুরু হয়ে গেছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল...
#
#                                                summary
# 0    দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনা...
# 1    বিমান বন্দর থেকে তেজগাঁওয়ে বিমান বাহিনীর ফ্যাল...
# 2    সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ...
# 3    ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচ। ফাইনাল খেলতে...
# 4    সাদিয়াকে কখনো কেউ গোমড়া মুখে দেখেনি। সব সময় হা...
# ..                                                 ...
# 495  বিপিএলের একাদশ আসরের জন্য প্লেয়ার্স ড্রাফটের প...
# 496  শুরু হয়েছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) এ...
# 497  শুরু হয়েছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) এ...
# 498  একটি ম্যাচ জয়ের লক্ষ্য নিয়ে নবম নারী টি-টোয়েন্...
# 499  শুরু হয়ে গেছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল...
#
# [500 rows x 4 columns]

# %% [markdown]
# # Install and Imports

# %%
# !pip install sentencepiece
# !pip install transformers
# !pip install git+https://github.com/csebuetnlp/normalizer

import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

from normalizer import normalize # pip install git+https://github.com/csebuetnlp/normalizer


from transformers import XLMProphetNetForConditionalGeneration, XLMProphetNetTokenizer


from transformers import MBartForConditionalGeneration, AutoModelForSeq2SeqLM
from transformers import AlbertTokenizer, AutoTokenizer
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-0sh2v_mb
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-0sh2v_mb
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from normalizer==0.0.1) (2024.9.11)
# Collecting emoji==1.4.2 (from normalizer==0.0.1)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy==6.0.3 (from normalizer==0.0.1)
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.13)
# Building wheels for collected packages: normalizer, emoji, ftfy
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6860 sha256=324ac9dbc8ea773d22d65630163f5ab50a0368fb51b62f175d93aa6b4441ec70
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooja6q6p/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186455 sha256=a28d1b9c21535a3db5c931dc4f3829fa7b9d304617d9569e9bd885bfdbb97050
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41931 sha256=00774a63c86a1932a4883f21c5f56527058609a30f5ef9d03964a7906faf81d6
#   Stored in directory: /root/.cache/pip/wheels/92/8e/16/c1e4d4d65685d71085e4e27b44d6ed880b0559474c9ee4ff66
# Successfully built normalizer emoji ftfy
# Installing collected packages: emoji, ftfy, normalizer
# Successfully installed emoji-1.4.2 ftfy-6.0.3 normalizer-0.0.1

# %%
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ### Functions

# %%
def cleanText(text2clean):
    empty_string = ""

    space = chr(32)
    flag  = 0

    for i in range(len(text2clean)):
        if text2clean[i] != "'" and text2clean[i] != "\n":
            if text2clean[i] == space and flag == 0:
                flag = 1
                empty_string = empty_string + text2clean[i]
            elif text2clean[i] != space:
                empty_string = empty_string + text2clean[i]
                flag = 0
    return empty_string

# %% [markdown]
# # Model Loading

# %% [markdown]
# ### Model Setup

# %%
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

tokenizer_path = "/content/drive/MyDrive/Colab/mT5_Tokenizer_XLSum"
model_path = "/content/drive/MyDrive/Colab/mT5_Model_XLSum"

# Step 4: Load the tokenizer and model from the specified paths
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=250112, bias=False)
# )

# %% [markdown]
# ### Run dataset over the Model

# %%
df.columns
# Out:
# Index(['category', 'title', 'text', 'summary'], dtype='object')

# %%
rows = df.shape[0]
rows
# Out:
# 500

# %%
# Create empty DataFrame without the "title" column
genDf = pd.DataFrame(columns=["text", "givenSummary", "mT5_Test_XLSum"])

# Load over the dataset
for i in range(rows):
        article_text = normalize(df['text'][i])

        # Tokenize the input text
        input_ids = tokenizer(
            [WHITESPACE_HANDLER(article_text)],
            return_tensors="pt",
            padding="max_length",
            max_length=512,
            truncation=True
        )["input_ids"]

        # Generate the summary
        output_ids = model.generate(
            input_ids=input_ids.cuda(),
            max_length=400,
            min_length=64,
            no_repeat_ngram_size=2,
            num_beams=4
        )[0]

        # Decode the generated summary
        summary = tokenizer.decode(
            output_ids,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=False
        )

        # Add the text, given summary, and generated summary to the DataFrame
        genDf.loc[i] = [df['text'][i], df['summary'][i], summary]

        # Print the generated summary for verification
        print(i, '  ', summary)

# Save the DataFrame to CSV
genDf.to_csv('/content/drive/My Drive/Colab/sports_zeroshot.csv')
# Out:
# 0    অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনালে দ্বিতীয়বারের মতো জায়গা করে নিয়েছে বাংলাদেশ। পাকিস্তানকে ৭ উইকেটের বড় ব্যবধানে হারিয়ে শিরোপার আরও একধাপ কাছে পৌঁছেছে লাল-সবুজের যুবারা।
# 1    যুব বিশ্বকাপ জুনিয়র হকিতে বাংলাদেশের অবস্থান তৈরি করতে আজ মৌলভীবাজারে বিমান বাহিনীর ফ্যালকন হলে খেলোয়াড়রা এসে গেছেন। এই প্রথমবারের মতো বাংলাদেশ ইতিহাস সৃষ্টি করে ফিরেছে।
# 2    সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ম্যাচে আয়ারল্যান্ডকে ৩-০ গোলে হারিয়েছে বাংলাদেশ নারী ক্রিকেট দল। ওয়ানডে সিরিজে জয় পাওয়ার সুবর্ণ সুযোগ ছিল দুই দলের অধিনায়ক নিগার সুলতানা জ্যোতিদের।
# 3    গায়ানার প্রভিডেন্স স্টেডিয়ামে বাংলাদেশের রংপুর রাইডার্স ও পাকিস্তানের লাহোর লান্দার্স ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচে জয় এবং নেট রান রেট উভয় সমীকরণ মিলিয়ে ফাইনালে উঠেছে বাংলাদেশ।
# 4    সাদিয়া সুলতানাকে কখনো কেউ গোমড়া মুখে দেখেনি। মাঠে-ময়দানের নিয়মিত মুখ ছিল তার। কিন্তু সেই যন্ত্রণা নিয়েই মাকে খুঁজে ফিরেছেন তার বাবা-মা, স্বামী আর ফুটফুটে দুটি ছেলে।
# 5    ১৯৮৫ সালে ঢাকায় বঙ্গবন্ধু স্টেডিয়ামে এশিয়া কাপ হকির আসর বসেছিল। ভারত ও পাকিস্তান খেলছিল ঘাসের মাঠে। সেই উত্তেজনার পরও দেশের খেলাধুলার প্রসার ঘটেছে। এত জনপ্রিয়তা পেতে পারেনি বাংলাদেশ।
# 6    অস্ট্রেলিয়ার সিডনিতে একটি টুপি বিক্রি হলো বাংলাদেশি মুদ্রায় ৩ কোটি ৭৩ লক্ষ্য ১১ হাজার টাকা। এর ভিত্তি মূল্য ধরা হয়েছিলো ৪ লাখ ৭০ হোয়াটসঅ্যাস্ট্রেলিয়ান ডলার।
# 7    বিশ্বকাপ ক্রিকেটের ফাইনাল ম্যাচে স্বাগতিক পাকিস্তানকে ৩ উইকেটে হারিয়ে ফাইনালে উঠে এসেছে বাংলাদেশ। ভারতের বিপক্ষে হেরেছে লাল- সবুজের প্রতিনিধিরা। এদিকে হাতছোঁয়া দূরত্ব থেকে ফিরতে হয়েছে বাংলাদেশকে।
# 8    বাংলাদেশের কাটার মাস্টার মোস্তাফিজুর রহমানের ঘরে আশীর্বাদ হয়ে একটি পুত্র সন্তানের বাবা হয়েছে। বাচ্চা ও মা দুজনেই সুস্থ আছে বলে তিনি জানিয়েছেন এই খবরের আনুষ্ঠানিক উদ্বোধন করেছেন।
# 9    জ্যামাইকায় চলমান দ্বিতীয় টেস্টের প্রথম ইনিংসে বাংলাদেশ পুড়েছে ক্যারিবিয়ানদের পেস তাণ্ডবে। বাংলাদেশের গতির প্রদর্শনীতে সব আকর্ষণ নিজের দিকে নিয়ে নেন টাইগার তরুণ পেসার নাহিদ রানা।
# 10    মঙ্গলবার রাতে জাঁকজমকপূর্ণ আয়োজনে উন্মোচিত হয় বাংলাদেশ প্রিমিয়ার লিগের থিম সং। গানটি গেয়েছেন মুজা, র ্যাপার হান্নান হোসাইন এবং রায়েফ আল হাসান রাফা। অফিশিয়াল গানের দুটি লাইনও লিখেছেন প্রধান উপদেষ্টা ডক্টর
# 11    বাংলাদেশ ও ওয়েস্ট ইন্ডিজের মধ্যে দ্বিতীয় টেস্ট সিরিজের চতুর্থ দিনের প্রথম সেশনেই ৩ উইকেট হারিয়ে শেষ করেছে বাংলাদেশ। এই ম্যাচে জয় পেয়েছে লাল-সবুজ দলের প্রতিনিধিরা। এবারের ম্যাচটি ছিল জ্যামাইকা টেস্টে।
# 12    জ্যামাইকা টেস্টে ওয়েস্ট ইন্ডিজের বিপক্ষে ৫ উইকেট নিয়ে তৃতীয় দিন শেষ করেছিল বাংলাদেশ। এই টেস্টের চতুর্থ দিনের প্রথম সেশনেই ১৬৪ রানে অলআউট হয়েছিল টাইগাররা।
# 13    জ্যামাইকা টেস্টে ওয়েস্ট ইন্ডিজের বিপক্ষে তৃতীয় দিন শেষ করেছে বাংলাদেশ। প্রথম ইনিংসে ১৬৪ রানে অলআউট হয় বাংলাদেশ ও দলীয় ১৭৩ রান সংগ্রহ করে ৩ উইকেট হারিয়ে ৩-১ ব্যবধানে জয় পেয়েছে টাইগাররা।
# 14    আয়ারল্যান্ডের বিপক্ষে তিন ম্যাচের একটি ওয়ানডে সিরিজে ৩-০ ব্যবধানে জয় পেয়েছে বাংলাদেশ। এই প্রথমবারের মতো বাংলাদেশের সেই রেকর্ড গড়েছে লাল-সবুজ টাইগ্রেসের প্রতিনিধিরা।
# 15    বাংলাদেশ ও ওয়েস্ট ইন্ডিজের মধ্যকার জ্যামাইকা টেস্টের প্রথম ও শেষ টেস্টে ১৬৪ রানে অলআউট হয়েছে বাংলাদেশ। এরপর টাইগাররা ১৮ রানের লিড নিয়ে চা-বিরতির মুখোমুখি হয়েছেন।
# 16    জ্যামাইকা টেস্টে তৃতীয় দিনের প্রথম সেশনে ওয়েস্ট ইন্ডিজ ও বাংলাদেশের মধ্যে লড়াই শুরু হয়েছে। দলটির ১৩৬ রান নিয়ে নিয়ন্ত্রন নেয় বাংলাদেশ ও স্বাগতিকরা। তবে ১৮ রানের লিড পেয়েছে বাংলাদেশ।
# 17    জ্যামাইকা টেস্টে তৃতীয় দিনের প্রথম সেশনে ওয়েস্ট ইন্ডিজের বিপক্ষে ১৬৪ রানে অলআউট হয়েছে বাংলাদেশ। এই টেস্টের দ্বিতীয় দিন শেষ করেছে বাংলাদেশ ও ওয়েস্টেডিজ। এবারের দিনে দলটি তিন উইকেট হারিয়েছে।
# 18    প্রায় এক যুগ ধরে অনেকটা অন্তরালে ছিলেন সোনাজয়ী শুটার সাদিয়া সুলতানা। ২০১৭ সালে আগুনে পুড়ে অসুস্থ হন দীর্ঘদিন। এখন তিনি মারা যান হাসপাতালে আইসিইউতে ।
# 19    বাংলাদেশের জাতীয় ক্রিকেট দল সেন্ট কিটসের বিপক্ষে তিন ম্যাচের ওয়ানডে সিরিজের প্রথম সিরিজে খেলতে যাচ্ছেন তারা। এবারের ওযাড শেষ হতে চললো ৮ ডিসেম্বর। এরপর থেকে এই সিরিজ খেলবে ওয়েস্ট ইন্ডিজ।
# 20    বাংলাদেশ ও ওয়েস্ট ইন্ডিজের মধ্যকার দ্বিতীয় টেস্টের প্রথম দিনে স্যাবাইনা পার্কে দুই উইকেটের ব্যবধানে হেরেছে বাংলাদেশ। এর আগে আফগানিস্তানের বিপক্ষে ৩ উইকেটে হেরে গেলেও বাংলাদেশের দলের এই ফরম্যাটে একটি নতুন রেকর্ড ছিলো
# 21    বাংলাদেশে জুলাই বিপ্লবের যেসব হত্যাকান্ড হয়েছে তার প্রতিক হিসাবে তুলে ধরা হয়েছে ক্রীড়া মন্ত্রণালয়ের অফিসিয়াল মাসকট। সেখানে লেখা রয়েছে 'এসো দেশ বদলাই, পৃথিবী بدلলাই'।
# 22    জ্যামাইকা টেস্টে আরও একবার ব্যর্থ হয়েছে বাংলাদেশের ব্যাটারদের ব্যাটিং লাইন। এই টেস্টের দ্বিতীয় দিন শেষ করেছে বাংলাদেশ সফরকারীরা। তবে দলীয় ৮৩ থেকে ৯৮ রানের মধ্যে ৪ উইকেট হারিয়ে বিপর্যয়ে পড়েছে বাংলাদেশ।
# 23    বাংলাদেশের একাদশ টি-টোয়েন্টি টুর্নামেন্ট বিপিএলের মাসকট 'ডানা ৩৬' উন্মোচন করেছে বাংলাদেশ ক্রিকেট বোর্ড (বিসিবি) এবং এই প্রথমবারের মতো নতুন একটি উৎসব।
# 24    পাকিস্তানের মাটিতে ২০২৫ সালের চ্যাম্পিয়নস ট্রফি আয়োজন নিয়ে তৈরি হয়েছে রাজনৈতিক ধোঁয়াশা। দুই বোর্ডই নিজেদের সরকারের সিদ্ধান্তের ওপর অনড় অবস্থানে রয়েছে। কিন্তু আইসিসির হেড অফিসে বৈঠকে বসেছে বিসিসিআই এব
# 25    বাংলাদেশের জাতীয় ফুটবলের কাউন্সিলর নির্বাচনের পূর্ণাঙ্গ ফলাফল ঘোষণা করেছে নির্বাহী কমিটি। ২১ জনের মধ্যে ১টি সদস্য পদ অমীমাংসিত হয়ে গেছে। সেখানে একজনের প্রতিদ্বন্দ্বী এখলাছ উদ্দীন বিজয়ী হয়েছেন।
# 26    ওয়েস্ট ইন্ডিজের বিপক্ষে প্রথম একটি টেস্ট ম্যাচে দিন শেষ করেছে বাংলাদেশ। তৃতীয় সেশনে দুই উইকেটে ৬৯ রান সংগ্রহ করে সেমিফাইনালে উঠে এসেছে টাইগার ওপেনার দল টিম ইন্টারন্যাশনাল।
# 27    বাংলাদেশ ও ওয়েস্ট ইন্ডিজের মধ্যকার দ্বিতীয় টেস্ট ম্যাচ জ্যামাইকাতে অনুষ্ঠিত হয়েছে। টসে জিতে ব্যাট করার সিদ্ধান্ত নিয়েছেন বাংলাদেশ অধিনায়ক মেহেদী হাসান মিরাজ। এবারের ম্যাচে দুই দফা হেরেছে টাইগাররা।
# 28    ঘরের মাঠে আয়াল্যান্ডের বিপক্ষে ওয়ানডে সিরিজে যেন রেকর্ডের সিরিজ বানিয়ে ফেলেছে বাংলাদেশ নারী দল, তাতে থামতে চান না টাইগ্রেস অধিনায়ক নিগার সুলতানা জ্যোতি।
# 29    ২৪ ঘণ্টাও হয়নি জমকালো আয়োজনে ক্লাব প্রতিষ্ঠার ১২৫তম বার্ষিকী উদযাপন করেছে বার্সেলোনা। এর মধ্যে লাস পালমাসের কাছে হেরে গেছে কাতালান শিষ্যদের দল হান্সি ফ্লিক।
# 30    ওয়েস্ট ইন্ডিজের বিপক্ষে সিরিজের দ্বিতীয় ও শেষ ম্যাচে মাঠে নামবে বাংলাদেশ। কিন্তু বৃষ্টির কারণে খেলা শুরু হতে দেরি হচ্ছে বলে ধারণা করা হচ্ছিল টাইগাররা। এখনও টস অনুষ্ঠিত হয়নি।
# 31    এক ম্যাচ হাতে রেখেই আয়ারল্যান্ডের বিপক্ষে ওয়ানডে সিরিজ জিতেছে বাংলাদেশ নারী ক্রিকেট দল। এরপর টাইগ্রেসকে ৫ উইকেটে হারিয়েছে স্বাগতিকরা। এ নিয়ে বেশ অবাক হয়েছেন বাংলাদেশের অধিনায়ক নিগার সুলতানা জ্যোতি।
# 32    আয়ারল্যান্ডকে টানা দুই ম্যাচে হারিয়ে এক ম্যাচ হাতে রেখেই সিরিজ জিতেছে বাংলাদেশের নারী ক্রিকেট দলের মেয়েরা। এবারের ওয়ানডে সিরিজে ভারতকে ৫ উইকেটে হারিয়েছে বাংলাদেশ। এর আগে পাকিস্তানকে ২২৪ রানের লক্ষ্য তাড়া করে জয়ের রেকর্ড গড়িয়েছে
# 33    ভারতের মুম্বাইয়ের ওয়াংখেড়ে স্টেডিয়ামে এক নজিরবিহীন ঘটনাই ঘটেছে। টি-টোয়েন্টি ক্রিকেটে প্রথমবারের মতো দলের ১১ জন খেলোয়াড় হাত ঘুড়িয়েছেনে। এমনকি দক্ষিণ আফ্রিকার বিপক্ষে অ্যান্টিগা টেস্টের দ্বিতীয় ইনিংসে দ
# 34    সৌদি আরবের দামাকের বিপক্ষে মুখোমুখি হয়েছেন ক্রিস্টিয়ানো রোনালদোর আল নাসর। এবারের ম্যাচেও আল নাসরকে জেতালেন তিনি। এর আগে দ্বিতীয়বার জোড়া গোল করেন এই তারকা।
# 35    স্যাবাইনা পার্কে আজ রাতে মুখোমুখি হবে বাংলাদেশ ও ক্যারিবিয়ানদের মধ্যে টেস্ট সিরিজের দ্বিতীয় ম্যাচ। কিন্তু এর আগে বাংলাদেশের বিপক্ষে দুই ম্যাচে হেরেছে ক্যারিয়ার দল মিরাজ বাহিনী।
# 36    বাংলাদেশের টেস্ট ও টি-টোয়েন্টি ক্রিকেট থেকে অবসর নেননি সাকিব আল হাসান। আফগানিস্তানের বিপক্ষে তিন ওয়ানডে সিরিজে তাকে ছাড়া দল ঘোষণা করতে যাচ্ছে বিসিবি। এর আগে শারজায় অনুষ্ঠিত হওয়া ত্রিপাক্ষিক সিরিজেও তার খেল
# 37    অনূর্ধ্ব-১৯ এশিয়া কাপ ক্রিকেট টুর্নামেন্টের উদ্বোধনী ম্যাচে আফগানিস্তানকে ৩ উইকেটে হারিয়ে মিশন শুরু করেছে বাংলাদেশ। এই ম্যাচটি শেষ হয়ে গেছে শুক্রবার (২৯ নভেম্বর)।
# 38    ভারত ক্রিকেট দল আয়োজক দেশ পাকিস্তানে যাবে না বলার পর থেকে অচলাবস্থায় পড়ে ২০২৫ চ্যাম্পিয়নস ট্রফি। কিন্তু 'হাইব্রিড মডেল' প্রত্যাখ্যান করা নিয়ে আইসিসির সভা মাত্র ২০ মিনিটেই পণ্ড হয়ে গেছে।
# 39    ভারত ও দক্ষিণ আফ্রিকার কাছে দুই ম্যাচের টেস্ট সিরিজ এবং ২০১ রানের বড় হার দিয়ে ওয়েস্ট ইন্ডিজের বিপক্ষে টানা পাঁচ ম্যাচে হেরেছে বাংলাদেশ। কিন্তু শেষ পর্যন্ত মাঠে নামবে টাইগাররা।
# 40    বাংলাদেশের মিরপুরে তিন ম্যাচ ওয়ানডে সিরিজের প্রথম ম্যাচে আয়ারল্যান্ডকে হারিয়েছে বাংলাদেশ নারী ক্রিকেট দল। শেষ পর্যন্ত দুই দলের কোনো অনুশীলন ছিল না। তবে ঐ ম্যারে টাইগ্রেসদের পরিকল্পনা নিয়ে মাঠে নামতে হবে।
# 41    ক্রিকেটের নিয়ন্ত্রক সংস্থা আইসিসিকে বলেছে, ২০২৫ সালের আসন্ন চ্যাম্পিয়নস ট্রফির জন্য ভারতের 'হাইব্রিড মডেল'কে বাদ দিয়ে বিকল্প যা বাস্তবায়নযোগ্য তেমন প্রস্তাব দেওয়া হবে।
# 42    আফগানিস্তানের বিপক্ষে বড় পুঁজি পেতে ব্যর্থ হয়েছে বাংলাদেশ। শেষ পর্যন্ত নির্ধারিত ৫০ ওভারে ৯ উইকেট হারিয়ে ২২৮ রান সংগ্রহ করেছে দলটি। তবে অধিনায়ক আজিজুল হাকিম তামিমের সেঞ্চুরির পরও নতুন করে সেমিফাইনালে উঠ
# 43    গাজীপুরের ফুটবল দর্শকরা আজ একটা ঐতিহাসিক ম্যাচ দেখতে পারবেন। এই দুই দলের মধ্যে ঢাকা ওয়ান্ডারার্স এবং মোহামেডানকে নিয়ে লড়াই করছেন আলফাজ আহমেদ।
# 44    বাংলাদেশের প্রিমিয়ার ফুটবল লিগ আজ শুরু হবে। অথচ দর্শককে ছন্দময় খেলা উপহার দেওয়ার মানসিকতা নেই। এখন ক্লাব কর্মকর্তাদের মধ্যে নতুন ভাবনা থাকবে না। সবচেয়ে আকর্ষণীয় কিছু থাকুক, না থাকু।
# 45    বর্ষসেরা ফুটবলারের পুরস্কার 'দ্য বেস্ট'-২০২৪-এর মনোনয়ন প্রকাশ করেছে ফিফা। ছেলেদের খেলোয়াড়ের সঙ্গে আছে এ নিয়ে আরও ১০টি পুরষ্কার দেওয়া হবে এই প্রথমবারের মতো।
# 46    ওয়েস্ট ইন্ডিজের বিপক্ষে তিন ম্যাচের ওয়ানডে সিরিজের প্রথম ম্যাচে রয়েছে বাংলাদেশের জাতীয় দলের অধিনায়ক মেহেদী হাসান মিরাজ ও তাওহীদ হৃদয়। কিন্তু চোটে আক্রান্ত হওয়া এই ব্যাটারকে নিয়ে চিন্তার ভাঁজ আরও গভীর করেছেন
# 47    সংযুক্ত আরব আমিরাতে আজ থেকে শুরু হয়েছে বয়সভিত্তিক অনূর্ধ্ব-১৯ এশিয়া কাপ। এই টুর্নামেন্টে এবারের চ্যাম্পিয়নদের মধ্যে রয়েছে বাংলাদেশের যুবা টাইগাররা। এখন পর্যন্ত সেখানে খেলবে তিনটি ম্যাচ।
# 48    ডারবান টেস্টে দক্ষিণ আফ্রিকার বিপক্ষে নিজেদের প্রথম ইনিংসে মাত্র ৪২ রানে অলআউট হয়েছে শ্রীলঙ্কা। কিন্তু স্বাগতিকরা এই ইনিংসটি হেরেছে বলে জানিয়েছেন লঙ্কানরা।
# 49    চ্যাম্পিয়নস লিগের ম্যাচে লস ব্লাঙ্কোদের কাছে ২-০ গোলে হেরেছে রিয়াল মাদ্রিদ। কিন্তু ইংলিশ মিডফিল্ডার কিলিয়ান এমবাপ্পেকে নিয়ে উচ্ছ্বাসের কমতি ছিল না।
# 50    ইতালির ক্রীড়া সংবাদমাধ্যম টাট্টোস্পোর্টের দেওয়া 'গোল্ডেন বয়' পুরস্কার জিতেছেন বার্সেলোনা তারকা ফুটবলার লামিনে ইয়ামাল। এই পুরষ্কারটি পেয়েছেন ১৭ বছরের কমবয়সী খেলোয়াড়।
# 51    ভারতের স্বাগতিক দল বসুন্ধরা কিংসকে কেন্দ্র করে স্মোক ফ্লেয়ার ছুড়ে মেরে খেলা বন্ধ করে দিয়েছে তাদের সমর্থকরা। সেই ঘটনা নিয়ে বাফুফের কাছে প্রতিবাদ জানিয়েছে মোহামেডান।
# 52    ২০০৪ সালের গ্লোবাল সুপার লিগের প্রথম ম্যাচে বাংলাদেশের রংপুর রাইডার্স হ্যাম্পশায়ারের কাছে হেরে গেছে। এই ম্যাচটি ছিল শেষ পর্যন্ত টাই করে টি-টোয়েন্টি টুর্নামেন্টে উড়ন্ত শুরু পেতে পারতো বাংলাদেশ।
# 53    ওয়েস্ট ইন্ডিজ সফরে দুই ম্যাচ টেস্ট সিরিজের প্রথম ম্যাচে অ্যান্টিগায় কোনো রকম লড়াই না করেই হেরেছে বাংলাদেশ। তবে বাংলাদেশের ব্যাটাররা বলছেন, সিরিজে ঘুরে দাঁড়াতে হলে কষ্ট করতে হবে টাইগারদের।
# 54    আয়ারল্যান্ডের বিপক্ষে তিন ম্যাচের সিরিজের জন্য বাংলাদেশ জাতীয় দলের পরিবর্তিত স্কোয়াড ঘোষণা করেছে দলটির সাবেক অধিনায়ক শারমিন আক্তার সুপ্তা। কিন্তু চোটের কারণে তাকে নিয়ে দেখা দিয়েছে অনিশ্চয়তা।
# 55    আর্জেন্টাইন ফুটবল তারকা কিলিয়ান এমবাপ্পে চ্যাম্পিয়নস লিগের ম্যাচে লস ব্লাঙ্কোদের বিপক্ষে ২-০ গোলে জয় পেয়েছে রিয়াল মাদ্রিদ। কিন্তু এর আগে থেকেই তাকে নিয়ে উচ্ছ্বাস ছিল না।
# 56    আর্জেন্টাইন ফুটবল তারকা লিওনেল মেসি প্রায় দুই দশক ধরে নিজের ক্যারিয়ারের যাত্রা শুরু করেছেন। কিন্তু তার জন্মস্থান এখন যুক্তরাষ্ট্রের ইন্টার মায়ামির অনূর্ধ্ব-১৩ বয়সভিত্তিক দলে।
# 57    গায়ানার প্রভিডেন্স স্টেডিয়ামে বৃহস্পতিবার ম্যাচটি ছিল গ্লোবাল সুপার লিগ, আর এমন নাটকীয় হার দিয়ে বাংলাদেশের ফ্র্যাঞ্চাইজিটি হেরেছে রংপুর রাইডার্স। কিন্তু লন্ডনের হ্যাম্পশায়ারকে হারিয়েছে তারা।
# 58    আন্তর্জাতিক ক্রিকেট কাউন্সিল বা আইসিসির আচরণবিধি ভঙ্গের কারণে একটি ডিমেরিট পয়েন্ট পেয়েছেন জিম্বাবুয়ের অল রাউন্ডার শন উইলিয়ামস। তার বিরুদ্ধে আনুষ্ঠানিক শুনানির প্রয়োজন হয়নি।
# 59    পাকিস্তানের সাবেক প্রধানমন্ত্রী ইমরান খানের মুক্তি ও সরকারের পদত্যাগের দাবিতে উত্তাল ইসলামাবাদের ক্রিকেট বোর্ড সিরিজের দ্বিতীয় ম্যাচ বাতিল করার সিদ্ধান্ত নিয়েছে দলটি। কিন্তু রাজনৈতিক বিক্ষোভের কারণে দুই দেশের দু'টি দলের মধ্যে সি
# 60    আয়ারল্যান্ডের বিপক্ষে ওয়ানডে সিরিজের প্রথম ম্যাচে মাত্র ৪ রানের জন্য সেঞ্চুরি করতে পারলেন না বাংলাদেশি নারী ক্রিকেটার শারমিন আক্তার সুপ্তা। কিন্তু এই ব্যাটারের ব্যাপারে কোন সন্দেহ নেই।
# 61    গ্যাবি হলিস লুইস বাংলাদেশের ক্রিকেট দলে প্রথমবারের মতো অভিষেক হয়েছিল। তার নেতৃত্বে বাংলাদেশে এসেছে আয়ারল্যান্ড নারী দলের ক্রিকেটার হ্যারি টেক্টর। তবে তিনি এখন দলটির অধিনায়ক।
# 62    ওয়েস্ট ইন্ডিজের বিপক্ষে বাংলাদেশ টেস্ট সিরিজের প্রথম ম্যাচ শেষে ব্যাটারদের ব্যর্থতায় ভরাডুবি করেছেন বাংলাদেশের অধিনায়ক মেহেদী হাসান মিরাজ। তিনি বলেছেন, 'আমাদের উন্নতি করতে হবে এবং পরের ম্যাচে শক্তিশালী হয়ে ফিরে আসার সুযোগ আছে
# 63    আইপিএল নিলামের একদিন পেরিয়ে গেল। কিন্তু নাম উঠল না কোনও বাংলাদেশি ক্রিকেটার। ক্রিকেটারদের তালিকা থেকে নাম তোলা হয়নি। সেটা ছিল সৌদি আরবের জেদ্দায় অনুষ্ঠিত এই নিলোমে।
# 64    অ্যান্টিগা টেস্টের চতুর্থ দিনে ওয়েস্ট ইন্ডিজের বিপক্ষে ২০১ রানের বড় ব্যবধানে হেরে সিরিজ শুরু করেছে বাংলাদেশ। এই সিরিজে ১-০ তে এগিয়ে গেল ক্যারিবিয়ানরা। সেই জয়ের জের ধরে ইনিংস ঘোষণা করা হয়েছে বাংলাদেশকে।
# 65    জিম্বাবুয়ের বিপক্ষে তিন ম্যাচের ওয়ানডে সিরিজে সমতা এনেছে পাকিস্তান। কিন্তু এবারের ম্যাচে জয় পেয়েছে মোহাম্মদ রিজওয়ানের দল। সেখানে সেমিফাইনালে পৌঁছেছে ভারত।
# 66    শেষ হয়েছে দুই দিনব্যাপী আইপিএলের মেগা নিলাম। দল পেয়ে ইতিহাস গড়েছেন ১৩ বছর বয়সী ক্রিকেটার বৈভব সূর্যবংশী। বয়স নিয়ে তোলপাড় চলছে ক্রিকেট বিশ্বে।
# 67    বাংলাদেশের জাতীয় ক্রিকেট দলের সঙ্গে সম্পৃক্ত থাকার দোষে দোষী বানানোর ফাঁদে বিএনপির রাজনৈতিক ট্যাগ লাগিয়ে ক্রীড়াঙ্গন থেকে বহু সংগঠককে সরিয়ে দেওয়ার রেওয়াজ প্রচলিত ছিল গত দেড়যুগে।
# 68    বাংলাদেশের টি-টোয়েন্টি ক্রিকেট দলে লেগ স্পিনার বোলার রিশাদ হোসেনের অভাব ছিল না। কিন্তু এই অপূর্ণতা ঘোচানোর চেষ্টা করছেন ক্রিকেটার ফাহিমা আক্তার, নারী দলের ভক্তরা।
# 69    জাতীয় ক্রিকেট লিগের ষষ্ঠ রাউন্ডের শেষ দিনে সিলেট বিভাগকে হারিয়ে শিরোপার কাছাকাছি চলে গিয়েছিল বরিশাল আন্তর্জাতিক স্টেডিয়াম। কিন্তু সেই উৎসব ছিল দারুণ উল্লাসে মাতানো।
# 70    বাংলাদেশের বিপক্ষে প্রথম বারের মতো দ্বিপক্ষীয় সিরিজ খেলতে আয়ারল্যান্ড নারী দলটি আজ মিরপুরের একটি স্টেডিয়ামে অনুশীলন করেছে। এই সিরিজে জয় পেয়েছে অস্ট্রেলিয়ার সঙ্গে।
# 71    শেষ হয়েছে দুই দিনব্যাপী আইপিএলের মেগা নিলাম। দল পেয়েছেন ১৩ বছর বয়সী ক্রিকেটার বৈভব সূর্যবংশী এবং রাজস্থান রয়্যালস। তাদের মূল্য ছিল ১ কোটি ১০ লাখ রুপি।
# 72    অ্যান্টিগা টেস্টের চতুর্থ দিনে ওয়েস্ট ইন্ডিজের বিপক্ষে ৪ উইকেট নিয়ে বড় হারের শঙ্কায় রয়েছে বাংলাদেশ। শেষ দিনের খেলা শুরু হওয়ার আগে টাইগারদের লক্ষ্য ছিল ৩৩৪ রান।
# 73    ইন্ডিয়ান প্রিমিয়ার লিগ বা আইপিএলের মেগা নিলামে দলগুলো তাদের খেলোয়াড়দের স্কোয়াড গুছিয়ে নিয়েছে। কিন্তু শেষ পর্যন্ত কেমন হল ১০ ফ্র্যাঞ্চাইজি? এমন কিছু তথ্য জানিয়েছে ক্রিকেটাররা।
# 74    লিভারপুলের বিপক্ষে ঘুরে দাঁড়ানোর লড়াইয়ে দলের সবচেয়ে নির্ভরযোগ্য ফরোল্ড ভিনিসিউস জুনিয়রকে হারালো রিয়াল মাদ্রিদ। এই ম্যাচে প্রায় এক মাস মাঠে নামতে পারবেন না তারকা ফুটবলার।
# 75    অ্যান্টিগা টেস্টের চতুর্থ দিনে ওয়েস্ট ইন্ডিজকে ৩৩৪ রানের টার্গেট দিয়েছে বাংলাদেশ। শেষ দিনের ব্যাট শুরুর আগেই দলীয় ১ উইকেটে উইকেট হারিয়ে বড় হারে জয়ের আশঙ্কা তৈরি হয়েছে।
# 76    অ্যান্টিগা টেস্টের চতুর্থ দিনে বাংলাদেশকে ৩৩৪ রানের টার্গেট দিয়েছে ওয়েস্ট ইন্ডিজ। সেইসঙ্গে বড় হার চোখ রাঙিয়েছে টাইগাররা। দলীয় ১ রানেই উইকেট হারিয়েছে বাংলাদেশ। এমনকি ১৭ ওভারে ৪৯ রান সংগ্রহ করেছে বাংলাদেশ。
# 77    অ্যান্টিগা টেস্টে ওয়েস্ট ইন্ডিজের বিপক্ষে ৪৫০ রানে ইনিংস ঘোষণা করেছে বাংলাদেশ। আথানাজে ও হজ মিলে প্রতিরোধ গড়িয়েছে তারা। এরপর তিন উইকেট হারিয়ে হেরেছে বাংলাদেশের দল।
# 78    অ্যান্টিগা টেস্টে ওয়েস্ট ইন্ডিজের বিপক্ষে দ্বিতীয় ইনিংসে ৪৫০ রানে ইনিংস ঘোষণা করেছে বাংলাদেশ। আথানাজে ও হজ মিলে প্রতিরোধ গড়েছে তারা। এরপর তিন উইকেট হারিয়ে মধ্যাহ্ন বিরতিতে গেছে স্বাগতিকরা।
# 79    সৌদি আরবের জেদ্দায় চলছে দুই দিনব্যাপী আইপিএলের মেগা নিলাম। দল পেয়েছেন ১৩ বছর বয়সী ক্রিকেটার বৈভব সূর্যবংশী, যার মূল্য ছিল ১ কোটি ১০ লাখ রুপি।
# 80    অ্যান্টিগা টেস্টে ওয়েস্ট ইন্ডিজের বিপক্ষে তৃতীয় দিনের খেলা শেষ হওয়ার পর ৪৫০ রানে ইনিংস ঘোষণা করেছে বাংলাদেশ। এই টেস্টের চতুর্থ দিন ১৮১ রানের মধ্যে এগিয়ে থেকে দ্বিতীয় ইনিংসে ব্যাট শুরু করেছিল টাইগাররা।
# 81    সৌদি আরবের জেদ্দায় চলছে দুই দিনব্যাপী আইপিএলের মেগা নিলাম। সেখানে ক্রিকেটারদের মূল্য ছিল ৮০ লাখ রুপি। যার ভিত্তিমূল্যের বেশিরভাগ আগ্রাহ দেখায়নি কোনো দল।
# 82    মিরপুরে আয়ারল্যান্ডের বিপক্ষে আসন্ন ওয়ানডে সিরিজে মুখোমুখি হবে বাংলাদেশ জাতীয় ক্রিকেট দল। এই সিরিজকে সামনে রেখে দুই দলের প্রস্তুতি ভালো হচ্ছে বলে জানিয়েছে টাইগার টি-টোয়েন্টি ক্রিকেটাররা।
# 83    আন্তর্জাতিক টি-টোয়েন্টি ক্রিকেটে সর্বনিম্ন রানের রেকর্ড গড়লো নাইজেরিয়া ও আইভরিকোস্ট। কিন্তু এই রান তাড়া করতে নেমে মাঠ ছেড়ে দিয়েছে তারা। এমন একটি ম্যাচের মাত্র ১০ উইকেটে প্রতিপক্ষ দলটি হেরেছে।
# 84    অ্যান্টিগা টেস্টে ওয়েস্ট ইন্ডিজের বিপক্ষে ৪৫০ রানে ইনিংস ঘোষণা করেছে বাংলাদেশ। এই টেস্টের দ্বিতীয় দিন শেষে লাল-সবুজের প্রতিনিধিদের ব্যাটে ফলোঅন এড়াতে পারেনি টাইগাররা।
# 85    অ্যান্টিগা টেস্টে ওয়েস্ট ইন্ডিজের বিপক্ষে তৃতীয় দিনের ম্যাচে ৪৫০ রানে ইনিংস ঘোষণা করেছে বাংলাদেশ। এই ম্যাচের দ্বিতীয় দিন শেষে টাইগাররা ৬ উইকেট হারিয়ে জয় পেয়েছে।
# 86    সৌদি আরবের জেদ্দায় শুরু হয়েছে আইপিএলের মেগা নিলাম। সেখানে সবচেয়ে বেশি দামে বিক্রি হন ভারতীয় উইকেটরক্ষক ব্যাটার ঋঝভ পন্থ। তার সঙ্গে অবিক্রিত থেকে গেছেন অস্ট্রেলিয়ার স্পিনার জনি বেয়ারস্টোরও।
# 87    অ্যান্টিগা টেস্টে ওয়েস্ট ইন্ডিজের বিপক্ষে ৪৫০ রানে ইনিংস ঘোষণা করেছে বাংলাদেশ। এই টেস্টের দ্বিতীয় দিন শেষে টাইগাররা তিন উইকেট হারিয়ে মধ্যাহ্ন বিরতিতে গেছে বলে জানিয়েছে দলটি।
# 88    সৌদি আরবের জেদ্দায় চলছে ক্রিকেটের ওয়ানডে সিরিজের মেগা নিলাম। সেখানে অস্ট্রেলিয়ার অলরাউন্ডার গ্লেন ম্যাক্সওয়েল এবং লখনউ সুপার জায়ান্টসকে দলে ভিড়িয়েছে পাঞ্জাব কিংস।
# 89    সৌদি আরবের জেদ্দায় চলছে আইপিলের মেগা নিলাম। সেখানে দুই অস্ট্রেলিয়ান ক্রিকেটারকে দলে ভিড়িয়েছে কলকাতা নাইট রাইডার্স। অন্যদিকে ভারতীয় এই উইকেটরক্ষক শ্রেয়াস আইয়ারকে পেতে নামে ব্যাঙ্গালুরু।
# 90    ওপেনার যশ্বসী জয়সওয়াল ও বিরাট কোহলির জোড়া সেঞ্চুরিতে অস্ট্রেলিয়ার বিপক্ষে সিরিজের প্রথম টেস্টের তৃতীয় দিন শেষে জয়ের সুবাতাস পাচ্ছে সফরকারী  ভারতীয় ক্রিকেট বোর্ড।
# 91    সৌদি আরবের জেদ্দায় চলছে ইন্ডিয়ান প্রিমিয়ার লিগ বা আইপিএলের মেগা নিলাম। যার দাম ছিল ২৬ কোটি রুপি। এটাই এবারের আইপিল ইতিহাসে কোনো ক্রিকেটারের সর্বোচ্চ পারিশ্রমিকের রেকর্ড।
# 92    আইপিএলের ইতিহাসে সবচেয়ে দামি খেলোয়াড় হলেন ঋষভ পন্থ। তাকে ২৭ কোটি টাকায় কিনে নিল চেন্নাই সুপার কিংস আর কলকাতা নাইট রাইডার্স। পান্তকে কিনতে ঝাঁপিয়ে পড়ে লখনউ সুপারে জায়ান্টস।
# 93    এক যুগেরও বেশি সময় পরে দেশের ক্রিকেটে আবারও শুরু হলো এনসিএল টি-টোয়েন্টি টুর্নামেন্ট। ২০১০ সালে প্রথমবারের মতো এই আসর অনুষ্ঠিত হয়েছিল ময়মনসিংহ ও ঢাকা মেট্রো।
# 94    আন্তর্জাতিক ক্রিকেট লিগ ২০২৫-এর মেগা নিলামে এবার জায়গা পেয়েছেন ৫৭৫ জন খেলোয়াড়। এর মধ্যে ভারতীয়, বিদেশি ও অস্ট্রেলিয়ার দলগুলোও আছেন। সেই সঙ্গে আবারো ঘুরে এলো আইপিএল।
# 95    বাংলাদেশ ও আয়ারল্যান্ডের মধ্যে তিনটি ওয়ানডে সিরিজের আনুষ্ঠানিক অনুশীলন শুরু করেছে ঢাকার শের-ই-বাংলা স্টেডিয়াম। কিন্তু এই সিরিজে মুখোমুখি হবে নারী ক্রিকেট দলগুলো।
# 96    ওয়েস্ট ইন্ডিজের বিপক্ষে ত্রিদেশীয় সিরিজের প্রথম দিনের খেলা শেষ করেছে বাংলাদেশ। দ্বিতীয় দিন থেকেই সেমিফাইনালে উঠে এসেছে টাইগাররা। কিন্তু এখনও দলটি পিছিয়ে আছে ক্যারিবিয়ান শিবিরে।
# 97    ওয়েস্ট ইন্ডিজের বিপক্ষে হায়দ্রাবাদ টেস্টের দ্বিতীয় দিনের খেলা শুরু হয়েছে। দলটির প্রথম ওভারে ৫ উইকেটে ৪৫০ রান সংগ্রহ করে ইনিংস ঘোষণা করেছে টাইগাররা। এ দিন শেষ করেছিল তারা।
# 98    ওয়েস্ট ইন্ডিজের বিপক্ষে হায়দ্রাবাদ টেস্টের দ্বিতীয় দিনের খেলা শুরু হওয়ার পর স্টিন গ্রেভস ও জশুয়া ডি সিলভারের মধ্যে সেঞ্চুরিতে বিশাল সংগ্রহের পথে আছে ক্যারিবিয়ানরা।
# 99    হায়দ্রাবাদে ওয়েস্ট ইন্ডিজের বিপক্ষে তৃতীয় দিনের ম্যাচের দ্বিতীয় দিন শেষ করেছে দলটি। এই ম্যাচে তিন উইকেট হারিয়ে মধ্যাহ্ন বিরতিতে গেছে ক্যারিবিয়ান শিবিরের সাথে।
# 100    বাংলাদেশ ও ওয়েস্ট ইন্ডিজের মধ্যকার টেস্ট ম্যাচের দ্বিতীয় দিন শেষ হওয়ার পর বাংলাদেশি বোলার হাসান মাহমুদ দুই উইকেট তুলে নিয়েছেন নতুন এক রেকর্ড গড়েছেন এই টাইগার পেসারের দখলে।
# 101    বাংলাদেশ ও ওয়েস্ট ইন্ডিজের মধ্যকার ওয়ানডে সিরিজের দ্বিতীয় দিনের খেলা শুরু করেছে বাংলাদেশ। দলীয় ২৬১ রানে ৩ উইকেট হারিয়ে ২৭৩ রান সংগ্রহ করে দিন শেষে হেরেছে ক্যারিবিয়ানরা।
# 102    অস্ট্রেলিয়া ও ভারতের মধ্যে বর্ডার-গাভাস্কার সিরিজের প্রথম টেস্টের দ্বিতীয় দিন শেষে টিম ইন্ডিয়ার বিপক্ষে ১৩ উইকেটে হেরে গিয়েছে দলটি। কিন্তু তৃতীয় দিনের ম্যাচে তিন উইকেটের ব্যবধানে এগিয়ে রয়েছে স্বাগত
# 103    ঢাকা তৃতীয় বিভাগ ক্রিকেট লিগে আচরণবিধি লঙ্ঘনের দায়ে আট ক্রিকেটার ও এক কর্মকর্তাকে এক বছরের জন্য নিষিদ্ধ ঘোষণা করা হয়েছে। এরপর জরিমানাও করেছে বিসিবি।
# 104    বাংলাদেশের পার্বত্য চট্টগ্রামে সাফ নারী চ্যাম্পিয়নশিপ বিজয়ী পাহাড়ের তিন ফুটবলকন্যা, মনিকা চাকমা ও রূপনা চাকমাকে জাঁকজমকপূর্ণ আয়োজনে রাঙামাটিতে গণসংবর্ধনা দেওয়া হয়েছে।
# 105    ইসরায়েলের টানা সামরিক হামলায় লেবানন ফুটবলার মৃত্যুর সঙ্গে লড়ছেন একজন নারী। কিন্তু সেটা আর হয়ে ওঠেনি বলে আশঙ্কা করা হচ্ছিল সেদেশের সেনাবাহিনীর বিরুদ্ধে।
# 106    ইন্ডিয়ান প্রিমিয়ার লিগের মেগা নিলামের আগে দুঃসংবাদ পেলেন ভারতীয় দুই ক্রিকেটার মানীশ পান্ডে ও সৃজিত কৃষ্ণ। বোলিং অ্যাকশনের কারণে নিষিদ্ধ হলেন তারা। এমন খবর জানিয়েছে ক্রিকেট বোর্ড বিসিসিআই।
# 107    ব্যাট হাতে সময়টা ভালো না কাটলেও সময়ের সেরা ব্যাটারদের তালিকায় বিরাট কোহলিকে রাখতেই হবে। ভারতের টায়ার নির্বাচনে অস্ট্রেলিয়ার বিপক্ষে এই প্রথমবারের মতো তাকে নিয়ে ব্যাপক আলোড়ন তৈরি হয়েছে।
# 108    বিশ্বকাপ ক্রিকেটে বৃহস্পতিবার রাতে ওয়েস্ট ইন্ডিজের বিপক্ষে দুই উইকেটের ব্যবধানে ৫ উইকেটে হেরেছে টাইগাররা। দলীয় ২২৪ রানে জয় পেয়েছে তারা। এ নিয়ে দারুণ পরিস্থিতি তৈরি হয়েছে এই ম্যাচ।
# 109    ওয়েস্ট ইন্ডিজের বিপক্ষে বৃহস্পতিবার হায়দ্রাবাদে অনুষ্ঠিত একটি ম্যাচে দলীয় ৫৪ ওভারে ৩ উইকেট হারিয়ে চা-বিরতিতে গেছে ক্যারিবিয়ানরা। এই ম্যাচের দ্বিতীয় দিনটি ছিল রবিবার।
# 110    ওয়েস্ট ইন্ডিজের বিপক্ষে দুই ম্যাচ টেস্ট সিরিজের প্রথমটিতে মাঠে নেমেছে বাংলাদেশ। এরপর থেকে মধ্যাহ্ন বিরতিতে গেছে স্বাগতিকরা। তবে শেষ পর্যন্ত তৃতীয় ম্যাচে তিন উইকেটের ব্যবধানে জয় পেয়েছে বাংলাদেশ。
# 111    ভারতের ফুটবলের নতুন টুর্নামেন্ট চ্যালেঞ্জ কাপের প্রথম আসরে মুখোমুখি হয়েছিল বসুন্ধরা কিংস ও ব্রাজিলিয়ান মিগুয়েল ফেরেইরা। কিন্তু শেষ পর্যন্ত মোহামেডানকে ৩-১ গোলে হারিয়ে শিরোপা নিজেদের করে নেয় দল।
# 112    শৈশব থেকে শুরু করে নিজের সেরা সময় বার্সেলোনাতে কাটিয়েছেন আর্জেন্টাইন ফুটবলার লিওনেল মেসি। বর্তমানে ক্লাবটি ছেড়ে প্যারিসের পিএসজিতে পাড়ি জমান এই সুপারস্টারকে।
# 113    ভারত ও দক্ষিণ আফ্রিকার বিপক্ষে দুই ম্যাচ টেস্ট সিরিজের প্রথমটিতে মাঠে নামছে বাংলাদেশ। টাইগার বাহিনীর এই সিরিজে জয়েই চোখ রাখতে শুরু করেছে ওয়েস্ট ইন্ডিজের দল।
# 114    ইউটিউবে ৩৩১ মিলিয়নের বেশি সাবস্ক্রাইবার নিয়ে বিশ্বের সবার ওপরে আছেন পর্তুগিজ সুপারস্টার ক্রিশ্চিয়ানো রোনালদো। কিন্তু তারকা এখনো অনেক দূর যাওয়া বাকি বলে জানিয়েছেন।
# 115    ঘরের মাটিতে দক্ষিণ আফ্রিকার বিপক্ষে টেস্ট সিরিজ হারের পর আবারও মাঠে নামছে বাংলাদেশ। এই সিরিজে তৃতীয় পক্ষ হিসেবে হাজির হয়েছে ওয়েস্ট ইন্ডিজের কোচ আন্দ্রে কুলি ও উইন্ডিজ ক্রিকেটার ক্রেইগ ব্র্যাথওয়েট।
# 116    তৃতীয় বিভাগ ক্রিকেট লিগে আচরণবিধি লঙ্ঘনের অভিযোগে ৮ খেলোয়াড় এবং একজন টিম অফিশিয়ালকে এক বছরের জন্য নিষিদ্ধ করেছে বিসিবি। এ ছাড়া ৫০ হাজার টাকা জরিমানা আরোপ করা হয়েছে।
# 117    বাংলাদেশের ফুটবল ইতিহাসে সবচেয়ে গুরুত্বপূর্ণ ম্যাচগুলোর একটি হচ্ছে ঘরোয়া মৌসুম। এটি শুরু হয় একটা ম্যাচে, আরেকটি খেলায়। অন্যদিকে আন্দোলনে নিহত শহিদদের স্মরণ করা হবে।
# 118    চলতি মাসেই সংযুক্ত আরব আমিরাতে অনুষ্ঠিত হবে অনূর্ধ্ব-১৯ এশিয়া কাপ। টুর্নামেন্টের উদ্বোধনী দিনেই আফগানিস্তানের দুবাই ও শারজাহতে খেলবে বাংলাদেশ যুবারা ও জুনিয়র টাইগাররা।
# 119    জাতীয় ক্রিকেট লিগে (এনসিএল) শৃঙ্খলাভঙ্গের দায়ে দুই ম্যাচের জন্য নিষিদ্ধ হয়েছেন রংপুর বিভাগের অধিনায়ক আকবর আলি। কিন্তু এবারের আসরে তাকে দেখা যাবে না।
# 120    অস্ট্রেলিয়ার বিপক্ষে পাঁচ ম্যাচের টেস্ট সিরিজের প্রথম ম্যাচে ভারতকে হারিয়ে দিয়েছে দলটি। কিন্তু চোটের কারণে শেষ পর্যন্ত দু'দলের স্কোয়াডে পরিবর্তন আনতে হচ্ছে অন্য একজন বাঁহাতি পেসার।
# 121    দীর্ঘ ক্যারিয়ারে প্রতিপক্ষের সবচেয়ে কঠিন ফুটবলার হিসেবে মেসি-রোনালদো নয়, বরং নেইমারকে বেছে নিয়েছেন ইতালি ও জুভেন্টাসের কিংবদন্তি গোলরক্ষক জিয়ানলুইজি বুফন।
# 122    আগামী ২৪ ও ২৫ নভেম্বর সৌদি আরবের জেদ্দায় অনুষ্ঠিত হবে আইপিএলের মেগা নিলাম। কিন্তু ভারতের সাবেক ক্রিকেটার রবিন উথাপ্পা মনে করেন, এই রেকর্ড ভেঙ্গে দেবেন ঋষভ পান্থ।
# 123    বাংলাদেশের ঘরোয়া ক্রিকেটের তৃতীয় বিভাগের খেলায় মারামারির ঘটনায় সিসি টিভির ভিডিও ফুটেজ দেখে বিসিবির নজরদারি নিয়ে প্রশ্ন ওঠার পর টেকনিক্যাল কমিটির কাছে শাস্তির সুপারিশ করা হয়েছে।
# 124    পাকিস্তানের মতো আরও একটি টেস্ট সিরিজ হবে ওয়েস্ট ইন্ডিজের বিপক্ষে, কিন্তু দলটির নির্বাচন নিয়ে চলছে তুমুল আলোচনা। যার মধ্যে রয়েছে জাতীয় দলের ক্রিকেটার নির্বাচনের বিষয়টি।
# 125    মঙ্গলবার ডেভিস কাপের নকআউট পর্বের প্রথম ম্যাচে রাফায়েল নাদালকে হারিয়ে টুর্নামেন্ট থেকে বিদায় জানানো হয়েছিল স্পেনের টেনিসের কিংবদন্তি। কিন্তু শেষ পর্বে আয়োজকরা সেই ঘোষণা দেননি।
# 126    ইউটিউবে নিজের চ্যানেল খোলার পর ঝড় বইয়ে দেন পর্তুগিজ সুপারস্টার ক্রিশ্চিয়ানো রোনালদো। এই ঘোষণার পর থেকেই তার নতুন অতিথি হিসেবে আসছিলেন না লিওনেল মেসি।
# 127    ক্রিকেটে অসামান্য অবদান রাখায় সম্মানসূচক ডক্টরেট ডিগ্রি পেয়েছেন সাবেক ইংলিশ অলরাউন্ডার মঈন আলী। তিনি বলেছেন, 'আমি খেলাধুলায় সত্যিকারের সাফল্য পেয়েছি।'
# 128    বাংলাদেশের ওয়ানডে ক্রিকেট দলের সাবেক অধিনায়ক সাকিব আল হাসান অবসর না নিয়েও এক রকম বাধ্যতামূলক অবসরে গেছেন। ইচ্ছে থাকার পরও তিনি খেলতে পারেননি আফগানিস্তানে।
# 129    আর্জেন্টিনার বিভিন্ন শিরোপা জয়ের নায়ক আনহেল দি মারিয়া বলছেন, নিজের ভবিষ্যৎ নিয়ে তিনি কোচিং করতে শুরু করেছেন। কিন্তু এখনো এমন কিছু নেই, যদি প্রয়োজন হয়।
# 130    বিশ্বকাপ বাছাইপর্বের পয়েন্ট তালিকার পাঁচে নেমে গেছে ব্রাজিল ও উরুগুয়ে। বছরের শেষ ম্যাচটা জয় দিয়ে အဆုံးသတ် করতে পারল না সেলেসাও দল। কিন্তু এবারের ম্যাচেও ড্র করেছে দরিভাল।
# 131    প্যারাগুয়ের বিপক্ষে আগের ম্যাচে হতাশাজনক হারের পর এবার পেরুকে ১-০ গোলে উড়িয়ে দিয়ে জয়ে ফিরেছে আর্জেন্টিনা। এই জয়ের পর দক্ষিণ আমেরিকান অঞ্চলের টেবিলের শীর্ষে অবস্থান করেছে লিওনেল স্কালোনি।
# 132    আইপিএলের নিলামে বাংলাদেশের সাকিব আল হাসানকে কিনে নেয় কলকাতা নাইট রাইডার্স। কিন্তু গোপালগঞ্জে তাঁর নাম বেশ পরিচিত হয়ে উঠেছে - যার মূল্য বেড়েছে ৩০ লাখ রুপি।
# 133    চলতি মাসের ২১ নভেম্বর শ্রীলঙ্কা সফরে যাবে বাংলাদেশ অনূর্ধ্ব-১৭ ক্রিকেট দল। এই সিরিজের জন্য ১৬জন ক্রিকেটার নিয়োগ পাবেন টাইগার দলের কোচ হিসেবে তুষার ইমরান।
# 134    ভারতের ওয়ানডে সিরিজ আইপিএলের প্রথম ম্যাচে সানরাইজার্স হায়দরাবাদের ঘরের ছেলে ডেভিড ওয়ার্নারকে দেখা যাচ্ছে সামাজিক যোগাযোগমাধ্যমে ভাইরাল হওয়া একটি ভিডিওতে।
# 135    বিশ্বকাপ বাছাইয়ের আগে সাধারণ ক্রিকেট এবং ফুটবলে শেষ মুহূর্তে একাদশ ঘোষণা করেছে দলগুলো। কিন্তু সবচেয়ে গুরুত্বপূর্ণ এই ম্যাচের আগেই সে পথে হেঁটেছে আর্জেন্টিনা।
# 136    ব্রাজিলের তারকা ফুটবলার নেইমার নতুন করে আলোচনায় এসেছেন দুবাইয়ের এক বিলাসবহুল রেসিডেন্সে ৫ কোটি ৪৫ লাখ ডলার দিয়ে এক পেন্ট হাউস (ভবনের ওপরের কক্ষ) কিনছেন।
# 137    চলতি আমেরিকার ২০২৬ ফুটবল বিশ্বকাপের বাছাই পর্বের লড়াই জমে উঠেছে আগামীকাল বুয়েন্স আইরেসের মাঠে। যেখানে মুখোমুখি হবে স্বাগতিক আর্জেন্টিনা ও উরুগুয়ে। কিন্তু দুই দলের মধ্যে নেই কোনো সুখকর স্মৃতি।
# 138    বাংলাদেশের স্বাধীন বাংলা ফুটবল দলের সাবেক অধিনায়ক জাকারিয়া পিন্টু মারা গেছেন মঙ্গলবার (১৯ নভেম্বর) ঢাকার ঐতিহ্যবাহী মোহামেডান ক্লাব প্রাঙ্গনের মাঠে। তিনি ছিলেন ১৯৭১ সালে পাকিস্তানের ইতিহাসের সবচেয়ে সুপরিচিত
# 139    ২০১১ সালের ১১ মার্চ। চট্টগ্রামের মাঠে ইংল্যান্ডকে হারিয়ে বাংলাদেশের ওয়ানডে ক্রিকেট দলের সাবেক অধিনায়ক ইমরুল কায়েস স্মৃতিচারণ করেছেন দশম বিশ্বকাপের একটি ঘটনা নিয়ে।
# 140    ওয়েস্ট ইন্ডিজের বিপক্ষে টেস্টের আগে দুই দিনের প্রস্তুতি ম্যাচে মাঠে নামে বাংলাদেশ। ম্যাচের প্রথম দিনে ৯ উইকেট হারিয়ে দিন শেষ করেছে ক্যারিবিয়ানরা। কিন্তু হ্যাটট্রিক করে সব আলো নিজের করে নিয়েছেন স্পিনার হাসান মুরাদ।
# 141    নিউজিল্যান্ড-আফগানিস্তান সিরিজের প্রথম টেস্ট সিরিজে ব্যাট হাতে বাজে সময় পার করেছেন ভারতীয় ক্রিকেট দলের তারকা ব্যাটার বিরাট কোহলি। সাবেক অজি পেসার গ্লেন ম্যাকগ্রা বলেছেন, 'প্রথমেই ভালো বোলিং করে তাকে ফিরিয়ে দিতে পারে অস্
# 142    বাংলাদেশের কিংবদন্তী ক্রীড়াবিদ জাকারিয়া পিন্টুর জীবন নিয়ে বিবিসি বাংলা একটি 'শ্রোতা জরিপ'-এর আয়োজন করে। এর মধ্যে রক্ষণভাগের খেলোয়াড় এবং ইস্ট পাকিস্তান জোনে চ্যাম্পিয়ন হবার ক্ষেত্রে তার ভূমিকা কী?
# 143    হুট করে পাকিস্তানের সাদা বলের কোচের দায়িত্ব ছাড়ছে গ্যারি কার্স্টেন। এই পদে যোগ দিচ্ছেন সাবেক পাক পেসার আকিব জাভেদ এবং নতুন করে জিম্বাবুয়ে সফরে থাকছেন তিনি।
# 144    ঘরের মাঠে অস্ট্রেলিয়ার বিপক্ষে তিন ম্যাচের ওয়ানডে সিরিজ হাতছাড়া করেছে পাকিস্তান। কিন্তু টি-টোয়েন্টিতে এবারের ম্যাচে বড় ব্যবধানে জয় নিশ্চিত করলো স্বাগতিকরা দল।
# 145    ফুটবল বিশ্বকাপ বাছাইতে বেশ ব্যর্থ হয়ে উঠেছে ব্রাজিল দল। কোপা আমেরিকান কোচ তিতের কাছ থেকে বাদ পড়ার পর থেকেই সেখানকার সবচেয়ে বড় রদবদলের ঘটনা ঘটেছে।
# 146    বাংলাদেশের বিপক্ষে টেস্ট সিরিজের প্রথম ম্যাচে ৩৯টি ম্যাচ খেলেন বাংলাদেশ দলের বাঁহাতি ব্যাটসম্যান ইমরুল কায়স। বিদায়ের ঘোষণাটা আগেই দিয়েছিলেন ইতি টানলেন ১৭ বছরের দীর্ঘ ক্যারিয়ারের।
# 147    স্প্যানিশ শহর মালাগারে মঙ্গলবার (১৯ নভেম্বর) থেকে শুরু হবে ডেভিস কাপের ১১২তম আসর। এই আসরের প্রথম ইভেন্টের কোয়ার্টার ফাইনাল ম্যাচে মাঠে নামবে নাদালের দল।
# 148    ২০২৩ সালের ওয়ানডে বিশ্বকাপে ভরাডুবি হয়েছিল বাংলাদেশের জাতীয় দলে। কিন্তু সে সময় এই দলের পারফরম্যান্স নিয়ে নানা আলোচনা হলেও এ বিষয়ে কোনো প্রতিক্রিয়া দেখা যায়নি। তবে গত এক বছর ধরে এসব ঘটনা ঘটেছে।
# 149    বাংলাদেশ ক্রিকেট দলের সাবেক অধিনায়ক ইমরুল কায়েস দীর্ঘ ১৭ বছরের ক্যারিয়ারের শেষ ম্যাচটি রাঙাতে ব্যর্থ হওয়ার পর আজ মিরপুরের শের-ই-বাংলা জাতীয় স্টেডিয়ামে তার বিদায়ী সংবর্ধনা দেওয়া হবে।
# 150    বাংলাদেশের স্বাধীন বাংলা ফুটবল দলের গর্বিত অধিনায়ক জাকারিয়া পিন্টু মারা গেছেন। তিনি কিডনির সমস্যার কারণে হাসপাতালে ভর্তি হওয়ার পর শেষ নিঃশ্বাস ত্যাগ করেছেন। তার ছেলে তানভীর হাজরা জানিয়েছেন।
# 151    বাংলাদেশে অন্তর্বর্তী সরকারের ১০০ দিন পূর্তি উপলক্ষ্যে নতুন করে তুলে ধরেছেন ক্রিকেট বোর্ডের সাবেক পরিচালক আসিফ মাহমুদ সজীব ভুঁইয়া। সেই সঙ্গে বলেছেন আগামী তিন মাসে এর দ্বিগুণ কাজ করতে পারবেন বলে আশাবাদ ব্যক্ত করেছেন তিনি।
# 152    যুক্তরাষ্ট্রের কিংবদন্তী বক্সার মাইক টাইসন বলেছেন, বয়সের ভারে তিনি কত টাকা পেয়েছেন, তা নিয়ে আলোচনা শুরু হয়েছে। এই লড়াই থেকে ৪০ মিলিয়ন মার্কিন ডলার উপার্জন করেছেন তাকে।
# 153    বাংলাদেশের লেগ স্পিনিং অলরাউন্ডার রিশাদ হোসেন বলেছেন, আইপিএলে পারফর্ম করার ব্যাপারে তিনি আত্মবিশ্বাসী এবং মানুষের ভালো দিন হতে পারে, তবে পরিস্থিতি দেখে সিদ্ধান্ত নেবেন।
# 154    বাংলাদেশ ক্রিকেট বোর্ডে (বিসিবি) গত ৫ আগস্ট সরকার পতনের পর রদবদল হয়েছে। এখনও বেশ কয়েকটি পদে এসেছে পরিবর্তন। নতুন পরিচালক নিয়োগের মাধ্যমে স্থবিরতা কাটানোর চেষ্টা চলছে বলে মন্তব্য করেছেন সাবেক অধিনায়ক আমিনুল ইসলাম বুল
# 155    আন্তর্জাতিক ফুটবলের জার্সিতে সবচেয়ে বেশি ম্যাচ জয়ের রেকর্ড নিজের করে নিয়েছেন পর্তুগিজ সুপারস্টার ক্রিশ্চিয়ানো রোনালদো। এর আগে থেকেই তিনি নিজেই বলছিলেন, 'এখন শুধু খেলা উপভোগ করতে চাই।'
# 156    ২০২৬ বিশ্বকাপ বাছাইপর্বে দল থেকে বেশ কয়েকজন ক্রিকেটার ছিটকে গেছেন। চোটের কারণে তাদের স্কোয়াডে নতুন করে যোগ দিয়েছে আর্জেন্টিনার ১৩জন খেলোয়াড় ও তারকা।
# 157    বিশ্বকাপ বাছাইয়ের ম্যাচে প্যারাগুয়ের বিপক্ষে অপ্রত্যাশিত হারের রাতে নিজের ছায়া হয়ে ছিলেন আর্জেন্টিনার সুপারস্টার লিওনেল মেসি। কিন্তু সেই ঘটনা নিয়ে তিনি তীব্র সমালোচনা করেছেন।
# 158    বাংলাদেশের টেস্ট ক্রিকেট দলের স্কোয়াড কিছুটা অনভিজ্ঞ, তবে এবারের দলটা ভালো খেলতে মুখিয়ে আছেন বলে জানিয়েছেন কোচ সালাউদ্দিন। তিনি বলেছেন, 'আশা করি এই ছেলেরা আগের চেয়ে এগিয়ে থাকবে।'
# 159    বাংলাদেশ ফুটবল দলের প্রথম কোনো ম্যাচ মাঠে বসে দেখতে পেয়েছে দেশটির সাবেক অধিনায়ক তামিম ইকবাল। এ দিন গ্যালারিতে উপস্থিত থেকে খেলা দেখেছেন বাংলাদেশ ক্রিকেট দল এর আগে দ্বিতীয় ম্যাচে মালদ্বীপকে হারিয়েছে বাংলাদেশ।
# 160    ভুটানের বিপক্ষে ২-১ গোলে জয়ের পর বাংলাদেশের স্প্যানিশ কোচ হ্যাভিয়ের কাবরেরা বলছেন, 'আমরা ভালো খেলেও জিততে পারিনি। আমরা সবাই দুশ্চিন্তায় পড়ে যাচ্ছি। এটা আমাদের দরকার ছিল।'
# 161    ওয়ানডে সিরিজে অস্ট্রেলিয়ার মাটিতে স্বাগতিকদের হারিয়ে ২২ বছর পর অজিদের বিপক্ষে সিরিজ জয়ের স্বাদ পেল পাকিস্তান। এবারের টি-টোয়েন্টি সিরিজের দ্বিতীয় ম্যাচে স্বাগতিকরা ১৩ রানে মাঠ ছাড়লো।
# 162    বাংলাদেশের জাতীয় ক্রিকেট দলের সাবেক অধিনায়ক ইমরুল কায়েস সাগর শনিবার বিদায়ি ম্যাচ খেলতে নেমেছেন। দলীয় ফটোসেশনেও দেখা গেছে তাকে সম্মাননা স্মারক তুলে দেওয়া হয়েছে।
# 163    ফ্রেইবুর্গে বসনিয়াকে ৭-০ গোলে বিধ্বস্ত করে জার্মানি গ্রুপ চ্যাম্পিয়ন হিসেবে নকআউট পর্বে পা রাখলো নেদারল্যান্ডস। এবারের ম্যাচে রেকর্ড গড়ে ম্যাচ জিতলো জার্মাননি।
# 164    মালদ্বীপের কাছে বাংলাদেশের বিপক্ষে দ্বিতীয় ম্যাচে একমাত্র গোলে জয় নিয়ে মাঠ ছেড়েছে লাল-সবুজ টি-টোয়েন্টি দল। ম্যাচের অতিরিক্ত সময়ে পাপন সিংয়ের গোল করে বাংলাদেশ সমতা আনে।
# 165    মালদ্বীপের বিপক্ষে দুই ম্যাচ সিরিজের দ্বিতীয় ম্যাচে মাঠে নেমেছে বাংলাদেশ। শেষ পর্যন্ত ১-১ গোলে সমতায় থেকে বিরতির মুহূর্তে সমতা আনে লাল-সবুজ দল। এমনকি সমতার মুখোমুখি হয়েছে বাংলাদেশের জাতীয় দলের প্রতিনিধিরা।
# 166    বাংলাদেশে প্রথমবারের মতো আয়োজন হতে যাচ্ছে গ্লোবাল সুপার লিগ। বাংলাদেশের একমাত্র ফ্র্যাঞ্চাইজি হিসেবে টুর্নামেন্টটিতে অংশ নিয়েছে রংপুর রাইডার্স। এর আগে দেশ ছাড়ার কথা জানিয়েছে বাংলাদেশ ক্রিকেট বোর্ড বিসিবি।
# 167    বাংলাদেশ অলিম্পিক এসোসিয়েশনের (বিওএ) নতুন সভাপতি নির্বাচিত সেনাপ্রধান জেনারেল ওয়াকার উজ জামানকে এক কোটি টাকা পুরস্কার দেয়া হয়েছে। এছাড়া সাফ চ্যাম্পিয়ন নারী ফুটবল দলকে যৌথভাবে সংবর্ধনা প্রদান করা হবে।
# 168    আমিনুল ইসলাম বুলবুল জাতীয় ক্রিকেট দলে কাজ করার আগ্রহ প্রকাশ করেছেন কিছু দিন আগেই। কিন্তু বিসিবি থেকে তাকে ডাকের অপেক্ষায় রয়েছেন সাবেক অধিনায়ক শেখ জামাল খান।
# 169    বাংলাদেশ ক্রিকেট বোর্ডের সিদ্ধান্ত অনুযায়ী আসন্ন ওয়েস্ট ইন্ডিজ সিরিজে সাকিব আল হাসান দলে থাকবেন কিনা তা নিয়ে শঙ্কা তৈরি হয়েছে বাংলাদেশের মিরপুরের শহীদ ফারহান ফাইয়াজ খেলার মাঠে।
# 170    বাংলাদেশের বিপক্ষে দুই ম্যাচের টেস্ট সিরিজের জন্য দল ঘোষণা করেছে ওয়েস্ট ইন্ডিজ। কিন্তু চোটের কারণে দলে নেই কেভিন সিনক্লেয়ার ও মিকাইল লুইস। সেই পরিবর্তন করেছেন তারা।
# 171    বাংলাদেশে জুলাই-আগস্ট অভ্যুত্থানে হওয়া 'শহীদদের' নামে উপজেলা পর্যায়ে ২২০টির বেশি স্টেডিয়াম স্থাপনের নীতিগত সিদ্ধান্ত নিয়েছে যুব ও ক্রীড়া মন্ত্রণালয়। এছাড়া আগামী ২০২৫ সালের পাঠ্যবইতে শহীদের স্মৃতিকথা লেখা
# 172    বাংলাদেশ-মালদ্বীপের মধ্যকার প্রথম ম্যাচে বাংলাদেশ লজ্জার হার হেরেছে। সেই দলটি আজ ঢাকায় এসেছে, যেখানে তারা খেলছে। কিন্তু কীভাবে বাংলাদেশকে হারিয়ে দিল সেটা এখন জানা যাচ্ছে।
# 173    ভারতীয় ক্রিকেটে ১৩ বছর বয়সে সবচেয়ে বেশি সেঞ্চুরি করেছেন ভারতের রানধির বৈভব সূর্যবংশী। কিন্তু আইপিএল নিলামে উঠতে যাওয়া ক্রিকেটারদের চূড়ান্ত তালিকা প্রকাশ করেছে কর্তৃপক্ষ।
# 174    ঢাকার মিরপুরের শের-ই- বাংলা জাতীয় ক্রিকেট স্টেডিয়ামে আজ বিশেষ দিন কাটাচ্ছেন বাংলাদেশের বাঁহাতি ব্যাটসম্যান ইমরুল কায়েস। গতকাল ভক্তদের আহ্বান করেছেন তিনি, যাদের ভালোবাসায় ভর করে এগিয়ে গেছে তার পুরো যাত্রা।
# 175    আফগানিস্তানের লেগ স্পিনার রশিদ খান বলেছেন, ঘরোয়া ক্রিকেটে বাংলাদেশের জন্য সবচেয়ে বড় সম্পদ হতে পারে সে দেশের ক্রিকেটাররা। কিন্তু এই প্রশংসায় পঞ্চমুখ তিনি।
# 176    ক্রিশ্চিয়ানো রোনালদোর জোড়া গোল করার ম্যাচে পোল্যান্ডকে ৫-১ গোলে উড়িয়ে দিয়েছে পর্তুগাল। এবারের নেশন্স লিগের কোয়ার্টার ফাইনালে জায়গা নিশ্চিত করে গ্রুপ সেরা দল হলো।
# 177    রোনালদোর ক্যারিয়ারের গোধূলি লগ্নে এসে এখনো ফুটবলের প্রতি যে নিবেদন করা হয়, তা প্রত্যেকের জন্য অনুপ্রেরণা। কিন্তু এই মহাতারকা সম্পর্কে দারুণ এক তথ্য দিয়েছেন তার সতীর্থ ব্রুনো ফার্নান্দেস।
# 178    এবারের ইন্ডিয়ান প্রিমিয়ার লিগের (আইপিএল) মেগা নিলাম বসবে সৌদি আরবের জেদ্দায়। কিন্তু কোন ক্রিকেটারের চূড়ান্ত তালিকায় বাংলাদেশি ক্রিকেটার কতটা জায়গা পেয়েছেন তা জানিয়েছে আইসিসির কর্তৃপক্ষ।
# 179    উন্মোচিত হয়েছে নতুন মোড়কে ফিফা ক্লাব বিশ্বকাপের ট্রফি। ২০২৫ সালের জুনে যুক্তরাষ্ট্রে শুরু হচ্ছে এই আসরের ফাইনালের আগে ফিফার ২১১ সহযোগী দেশের নাম খোদাই করা হয়েছে।
# 180    স্প্যানিশ টেনিস তারকা রাফায়েল নাদালকে বিদায় জানাতে টুর্নামেন্ট কর্তৃপক্ষ বিশেষ পরিকল্পনা করছে বলে জানা গেছে। এর আগে তিনি ঘোষণা দিয়েছিলেন চলতি মৌসুম শেষে তার ক্যারিয়ারে সমাপ্তি করতে যাচ্ছেন।
# 181    বার্সেলোনা ও এসি মিলানের কাছে টানা দুই ম্যাচ হারের পর ওসাসুনাকে ৪-০ গোলে উড়িয়ে আন্তর্জাতিক বিরতিতে গিয়েছে রিয়াল মাদ্রিদের জাতীয় দলের একাদশ। কিন্তু ক্লাবের দায়িত্ব সেরে মাদ্রিদে ফিরতে পারবে না খেলোয়াড়রা।
# 182    বাংলাদেশের জাতীয় ক্রিকেট দল রংপুর রাইডার্স এবার নীল জার্সিতে হাজির হয়েছে। বিপিএলের সাবেক তারকা ক্রিকেটার মোহাম্মদ আশরাফুল এই প্রথমবারের মতো কোচ হিসেবে কাজ করছেন।
# 183    বিশ্বকাপ বাছাইপর্বের প্রথম ম্যাচে ভেনেজুয়েলার সঙ্গে ১-১ গোলে ড্র করে মাঠ ছাড়ে ব্রাজিলের অধিনায়ক সেলেসাওরা রাফিনিয়া। এরপর থেকে তিনি বলছেন, জয়ের আশা জাগিয়েও তাদের পরিশ্রম করে যেতে হবে।
# 184    বাংলাদেশের সাফ নারী চ্যাম্পিয়ন বাংলাদেশ দলকে সংবর্ধনা দিয়েছে সাউথইস্ট ব্যাংক। গতকাল দুপুরে দিলকুশায় প্রতিষ্ঠানের প্রধান কার্যালয়ে অনুষ্ঠানে খেলোয়াড়দের ফুলেল শুভেচ্ছা জানানো হয়। এ নিয়ে বেশ কয়েকজন ঊর্ধ্বতন কর্মকর্তা এবং কো
# 185    নিউজিল্যান্ডের ক্রিকেট ইতিহাসের অন্যতম সেরা পেসার টিম সাউদি বিন সালমান জানিয়েছেন, তিনি টেস্ট ক্যারিয়ারের থেকে অবসরে যাচ্ছেন এবং 'আমার হৃদয়ে বিশেষ স্থান আছে'।
# 186    বাংলাদেশ জাতীয় ফুটবলের ফেডারেশন অভিভাকহীনতায় ভুগছে। শনিবার দ্বিতীয় প্রীতি ম্যাচে মালদ্বীপের বিপক্ষে বাংলাদেশকে হারিয়ে বলেছেন ৪৭ বছরের ইতিহাসে এটা তাদের ঐতিহাসিক জয় বাংলাদেশের মাটিতে।
# 187    বিশ্বকাপ বাছাইপর্বে নিজেদের ১১তম ম্যাচে দূর্বল ভেনেজুয়েলার বিপক্ষে ড্র করেছে ব্রাজিল। সেলেসাও দলকে ৩-১ ব্যবধানে হারিয়ে তিন ম্যাচের মতো জয় পেয়েছে তারা।
# 188    বিশ্বকাপ বাছাইয়ের একটি সংস্করণে আফগানিস্তানকে ২-১ গোলে হারিয়েছে আর্জেন্টিনা। এ নিয়ে দ্বিতীয়বার মাঠ ছেড়েছে ব্রাজিল ও লিওনেল স্কালোনির দল। কিন্তু লজ্জার পরাজয় কাটিয়ে এই দুই দলের মধ্যে এবারের মতো
# 189    ব্রিসবেনে বৃষ্টি বিঘ্নিত প্রথম টি-টোয়েন্টি সিরিজে পাকিস্তানকে ২৯ রান করে হেরেছে অস্ট্রেলিয়া। এই জয়ে তিন ম্যাচের একটি ওয়ানডে সিরিজের দ্বিতীয় ম্যাচে জয় পেয়েছে নিউজিল্যান্ড।
# 190    চোটের কারণে একের পর এক জর্জরিত হয়ে গেছে ব্রাজিল ফুটবলের সেলেসাও দল। গত এক বছর ধরে এই দলের চ্যাম্পিয়নদের দুই ম্যাচের মধ্যে দুটি ম্যাচে হেরেছে তারা।
# 191    বাংলাদেশের জাতীয় ক্রিকেট দল গত কয়েক দিন ধরেই মিরপুর শের-ই-বাংলা স্টেডিয়ামে নিয়মিত দেখা যাচ্ছে তামিম ইকবাল। কিন্তু এবারের বিপিএলের আগেই মাঠে ফিরতে চলেছেন তিনি।
# 192    ক্রিকেটের সব ফরম্যাটের অলরাউন্ডার তালিকায় ওপরের দিকে নাম থাকতো সাকিব আল হাসানের। ওয়ানডে র ্যাংকিং থেকে নাম সরিয়ে ফেলা হয় এই সংস্থার নিয়মের কারণেই তিনি এখনো খেলেননি।
# 193    বিশ্বকাপ ফুটবল বাছাই পর্বের লড়াই শুরু হচ্ছে আর্জেন্টাইন ও আর্জেন্টিনার মধ্যে। কিন্তু এই দুই প্রতিদ্বন্দ্বিকে নিয়ে এখন নতুন করে আলোচনা চলছে বিশ্বের সবচেয়ে বড় ম্যাচগুলোর একটি।
# 194    বাংলাদেশের দাবার ইতিহাসের অন্যতম সেরা দাবাড়ু গ্র্যান্ডমাস্টার জিয়াউর রহমান মারা গেছেন শনিবার রাতে ঢাকার একটি হাসপাতালে। মৃত্যুর পর থেকেই তাকে নিয়ে আলোচনা শুরু হয়েছে।
# 195    বাংলাদেশের জাতীয় ক্রিকেট দলের হয়ে আগামী ১৬ নভেম্বর ঢাকা বিভাগের বিপক্ষে সাদা পোশাকে নিজের শেষ ম্যাচ খেলতে নামলেন ইমরুল কায়েস। কিন্তু তিনি এবার এই সিদ্ধান্ত নিয়েছেন।
# 196    বাংলাদেশের জাতীয় ফুটবল দল গতকাল রাতে মালদ্বীপের কাছে লজ্জার হার হেরে দেশকে আরও একবার হতাশায় ডুবিয়েছে। নতুন কমিটির প্রথম আন্তর্জাতিক ম্যাচের শেষ দিকে বাংলাদেশকে প্রেরণা দেয়া হয়েছে।
# 197    আসন্ন চ্যাম্পিয়ন্স ট্রফিতে খেলতে আয়োজক দেশ পাকিস্তানে যেতে চায় না ভারত। টুর্নামেন্টটি আয়োজন করতে যাচ্ছে এই দুই প্রতিবেশী দেশের মধ্যে রাজনৈতিক বৈরিতার কারণে।
# 198    আফগানিস্তানের বিপক্ষে টেস্ট সিরিজের প্রথম তিন ম্যাচে জয় পেয়েছে বাংলাদেশ ক্রিকেট দল। কিন্তু সেখানে বোলিং-ফিল্ডিং যেন করাল স্রোতে বিলীন হয়ে গেছে, সেই ভাঙন থেকে বের হতে পারছে না টাইগার বাহিনী।
# 199    সাফ নারী চ্যাম্পিয়ন বাংলাদেশের ফুটবলাররা এখনো ক্যাম্পে রয়েছেন। তাদেরকে ছুটি দেওয়া হয়নি। কারণ নানা জায়গা থেকে ডাক আসছে। কেনাকাটা নিয়ে ব্যস্ত হয়ে উঠেছে তারা।
# 200    ওয়েস্ট ইন্ডিজের বিপক্ষে তিন ম্যাচের টেস্ট সিরিজের জন্য বাংলাদেশের জাতীয় দলের স্কোয়াড ঘোষণা করেছে বিসিবি। এরপর থেকে ডাক পাননি টাইগার অধিনায়ক জাকির রহমান দীপুর।
# 201    গত সেপ্টেম্বরে ৯০০ গোলের মাইলফলক ছুঁয়ে পৌঁছানোর প্রত্যয় ঝরেছিল পর্তুগিজ জাতীয় দলের সুপারস্টার ক্রিশ্চিয়ানো রোনালদোর মুখে। কিন্তু এখনও মনে হচ্ছে তিনিই ইতিহাসের সর্বোচ্চ গোলদাতা।
# 202    বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) একাদশ আসরের সূচি ঘোষণা করেছে বাংলাদেশ ক্রিকেট বোর্ড। এবারের আসর শুরু হবে আগামী ৩০ ডিসেম্বর। এর আগে থেকেই দরজায় কড়া নাড়ছে এই টুর্নামেন্ট।
# 203    বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) গত কয়েকদিন ধরে বেশ বিতর্কের মুখে পড়েছে বাংলাদেশ ক্রিকেট বোর্ড এবং এর সঙ্গী ছিল বিশ্বব্যাপী সবচেয়ে বড় দলগুলোর প্রতিনিধিত্বকারী সংগঠন ডব্লিউসিএ।
# 204    বাংলাদেশের জাতীয় ক্রিকেট দলের সাবেক অধিনায়ক সাকিব আল হাসানকে ঘিরে বেশ কয়েকদিন ধরে উচ্ছ্বসিত ভক্তের জটলা দেখা গেছে তার ফেসবুক অ্যাকাউন্ট থেকে। গত বছর তিনি ভারতের বিপক্ষে টেস্ট সিরিজ খেলেন।
# 205    গতি দিয়েই সবার নজর কেড়েছিলেন বাংলাদেশের তরুণ পেসার নাহিদ রানা। প্রথম স্পেলে ৪০ রানে ২ উইকেট নিয়েছিলেন তিনি। এরপর আফগানিস্তানের বিরুদ্ধে সিরিজের অভিষেক ম্যাচে জয় পেয়েছে বাংলাদেশ।
# 206    পাকিস্তানের হয়ে ২০২৩ সালের ২৪ জুলাই সবশেষ টেস্ট খেলেছিলেন স্পিনার নোমান আলী। এরপর তিনি আইসিসির অক্টোবরের মাসসেরা খেলোয়াড় হওয়া দৌড়ে পেছনে ফেলেছেন নিউজিল্যান্ডের কাগিসো রাবাদাকে।
# 207    লা লিগা কিংবা চ্যাম্পিয়নস লিগে হ্যান্সি ফ্লিকের অধীনে চলতি মৌসুমে রীতিমতো উড়ছিল বার্সেলোনা। কিন্তু এ দিন রিয়াল সোসিয়েদাদাদের বিপক্ষে মাঠে নামতে পারেনি বার্সা।
# 208    আন্তর্জাতিক জলবায়ু সম্মেলনে (কপ-২৯) যোগ দিতে বাংলাদেশের প্রধান উপদেষ্টা অধ্যাপক মুহাম্মদ ইউনূসের আমন্ত্রণ গ্রহণ করেছেন ফিফা প্রেসিডেন্ট জিয়ান্নি ইনফান্তিনো। এর আগে সোমবার আজারবাইজানে রাষ্ট্রীয় সফরের ফাঁকে
# 209    চ্যাম্পিয়নস ট্রফির নবম আসরের প্রস্তুতি সেরে ফেলেছে ভারত, কিন্তু পাকিস্তানের সঙ্গে আলোচনা করার সিদ্ধান্ত নিয়েছে আন্তর্জাতিক ক্রিকেট বোর্ড বা পিসিবি। কেননা এই টুর্নামেন্টের ভবিষ্যৎ ঘোলাটে হচ্ছে।
# 210    ওয়েস্ট ইন্ডিজের বিপক্ষে তিন ম্যাচের ওয়ানডে সিরিজের জন্য প্রস্তুতি নিচ্ছে বাংলাদেশ ক্রিকেট দল। কিন্তু নিয়মিত অধিনায়ক নাজমুল হোসেন শান্তের অসুস্থতার কারণে এই সিরিজে উড়াল দেয়া হচ্ছে না।
# 211    বিশ্বকাপ ফুটবল বাছাইয়ের প্রথম রাউন্ডের খেলার জন্য বাংলাদেশের সঙ্গে মালদ্বীপের খেলোয়াড়দের অভ্যর্থনা জানিয়েছে বাফুফ। দলটি আজ উত্তরার বসুন্ধরা কিংসের মাঠে অনুশীলন করবে।
# 212    সংযুক্ত আরব আমিরাতের শারজাহ স্টেডিয়ামে আফগানিস্তানের সাথে তিন ম্যাচ সিরিজের দ্বিতীয় ম্যাচে হেরেছে বাংলাদেশ। এই সিরিজে বড় হারে জয় পেয়েছে টাইগাররা। এমনটাই শেষবারের মতো।
# 213    বাংলাদেশ ও আফগানিস্তান মধ্যকার ওয়ানডে সিরিজের প্রথম ম্যাচে বাংলাদেশের বিপক্ষে ১৩ ওভারে ১ উইকেট হারিয়ে ৬০ রান সংগ্রহ করেছে বাংলাদেশ। এই ম্যাচটি শেষ হওয়ার কথা রয়েছে ঢাকায়।
# 214    সংযুক্ত আরব আমিরাতের বিপক্ষে তিন ম্যাচের সিরিজের প্রথম ম্যাচে আফগানিস্তানের বিরুদ্ধে লড়াই করেছে বাংলাদেশ। দলটি ২৪৫ রানে হেরে গেছে। সেখান থেকে জয় পেয়েছে লাল-সবুজ।
# 215    আফগানিস্তানের বিপক্ষে তিন ম্যাচ সিরিজের প্রথম ম্যাচে ৩ উইকেটে হেরে গেছে বাংলাদেশ। কিন্তু শেষ পর্যন্ত দলটি হেরেছে বলে ধারণা করা হচ্ছিল লাল-সবুজের অধিনায়ক মাহমুদউল্লাহ রিয়াদ ও মেহেদী হাসান মিরাজ।
# 216    আফগানিস্তানের বিপক্ষে তিন ম্যাচ সিরিজের প্রথম ম্যাচে ৩ উইকেটে হেরেছে বাংলাদেশ। এরপর থেকেই দারুণ ভালো শুরু পায় বাংলাদেশের অধিনায়ক মেহেদী হাসান মিরাজ ও মাহমুদউল্লাহ।
# 217    বাংলাদেশে এশিয়ান হকির কংগ্রেসের কর্মকাণ্ড যেন থমথমে চলছে, তা নিয়ে প্রশ্ন উঠছে। ফেডারেশনে কোনো কিছুই জানানো হয়নি, কোথায় প্রতিনিধি হিসেবে কোন দল গেছে তা এখনো জানতে পারেনি।
# 218    সংযুক্ত আরব আমিরাতের শারজাহ স্টেডিয়ামে আফগানিস্তানের বিরুদ্ধে ওয়ানডে সিরিজের দ্বিতীয় ম্যাচে বাংলাদেশ ৫৮ রান করে অলিখিত ফাইনাল হতে যাচ্ছে। এই সিরিজে জয় পেয়েছে বাংলাদেশ।
# 219    বাংলাদেশের নারী ফুটবল বোর্ড বাফুফের নবনির্বাচিত কমিটির প্রথম বৈঠকে মাহফুজা আক্তার কিরন চেয়ারম্যান হিসেবে দায়িত্ব পালন করবেন বলে জানিয়েছে সংগঠনটির সূত্রগুলো। বর্তমান প্রধান নির্বাহী তাবিথ আউয়ালের ওপর আস্থা রাখছেন
# 220    সংযুক্ত আরব আমিরাতের কাছে তিন ম্যাচের ওয়ানডে সিরিজের প্রথম ও শেষ ম্যাচে আফগানিস্তানকে হারিয়ে অলিখিত ফাইনাল হিসেবে সিদ্ধান্ত নিয়েছে বাংলাদেশ ক্রিকেট দলের দল টাইগাররা।
# 221    কুঁচকির চোটে আফগানিস্তানের বিপক্ষে তৃতীয় ওয়ানডে থেকে ছিটকে গেছেন বাংলাদেশ ক্রিকেট দলের অধিনায়ক নাজমুল হোসেন শান্ত। কিন্তু এবার তার অবস্থা নিয়ে প্রশ্ন তুলেছেন চিকিৎসকরা।
# 222    বাংলাদেশের জাতীয় ক্রিকেট দলের সিনিয়র সহকারী কোচ মোহাম্মদ সালাউদ্দিন বলেছেন, মানসিকতা পরিবর্তনের বিষয়টি শুরু থেকেই করতে পারলে তাকে কিছু শিখিয়ে দিতে হবে না। যে কোনো অবস্থায় সে নিয়ন্ত্রণ রাখবে তিনি।
# 223    আফগানিস্তানের বিপক্ষে দ্বিতীয় ওয়ানডে সিরিজের নিয়ন্ত্রণ নিয়েছে বাংলাদেশ। শেষ পর্যন্ত ৪ উইকেটের ব্যবধানে ৩২ রানের লক্ষ্য নিয়ে ম্যাচটি শুরু হয়েছিল শনিবার। তবে এই প্রথমবারের মতো টি-টোয়েন্টি সিরিজে বাংলাদেশ জয় পেয়েছে।
# 224    আফগানিস্তানের বিপক্ষে আজ বাংলাদেশ টেস্ট সিরিজের ফাইনালে উঠেছে টাইগাররা। এই সিরিজে প্রথম দুই ম্যাচ হেরে দল থেকে ছিটকে পড়েছেন নাজমুল হোসেন শান্ত। এবারের ম্যাচে তিনি খেলতে পারবেন না।
# 225    বাংলাদেশ ক্রিকেট দলের পেসার মোস্তাফিজুর রহমানের বাবা হতে চলছেন। কিন্তু এখনও কোনো সিদ্ধান্ত নেইনি দলটির ক্রিকেটার ক্রিকবাজ মাহবুবুর আক্তার। বিসিবির এক কর্মকর্তা বলেছেন, এখনো সময় আছে তার সঙ্গে কথা বলতে।
# 226    বাংলাদেশ জাতীয় ক্রিকেট দলের সিনিয়র সহকারী কোচ মোহাম্মদ সালাউদ্দিন বলেছেন, ছেলেদের যে মোটিভেশন নাই সেটা বলা যাবে না। নতুন খেলোয়াড়দের যোগাযোগ নিয়ে তিনি বেশ আশাবাদী।
# 227    পাকিস্তান ও অস্ট্রেলিয়ার মধ্যে দ্বিপাক্ষিক ওয়ানডে সিরিজের শেষ ম্যাচটি ছিল অলিখিত ফাইনাল। এর আগে দুই দল তিনটি ম্যাচে হেরেছে - যার ফরম্যাটে এই সিরিজে জয় নিশ্চিত করেছে তারা।
# 228    লাহোর স্টেডিয়ামে অনুষ্ঠিত হওয়া এশিয়া কাপের চ্যাম্পিয়নস ট্রফিতে খেলতে যেতে চায় না ভারত। টুর্নামেন্টটি আয়োজক দেশ পাকিস্তানে থাকলেও তাদের ম্যাচের সূচি এখনো নিশ্চিত হয়নি।
# 229    বাংলাদেশের ফুটবল সংস্থা বাফুফের নবনির্বাচিত কমিটির প্রথম সভায় বিভিন্ন কমিটকেনের দায়িত্ব বণ্টন হয়ে গেছে। এর মধ্যে ছিলেন না সিনিয়র সহ-সভাপতি ইমরুল হাসান।
# 230    যেমনটি ধারণা করা হচ্ছিল সেটি হতে যাচ্ছে, আসন্ন চ্যাম্পিয়নস ট্রফিতে খেলতে আয়োজক দেশ পাকিস্তানে খেলতেই যেতে চায় না ভারত। কিন্তু এবার সেই গুঞ্জন আরও ভারি করে সামনে নিয়ে এসেছে।
# 231    ঘরের মাঠে বার্সেলোনার কাছে ৪-০ গোলে হারে রিয়াল মাদ্রিদ এবং চ্যাম্পিয়নস লিগে কার্লো আনচেলত্তির শিষ্যরা টানা দুই ম্যাচের ব্যবধানে হেরেছে লস ব্লাঙ্কোরা।
# 232    বিশ্বকাপ ফুটবল কাপের প্রথম ম্যাচে ইন্টার মায়ামির দল আটলান্টাকে ৩-২ গোলে হারিয়েছে ইউনাইটেড। ম্যাচের শুরুতেই মায়ামিকে সমতায় ফেরান রোহাস ও চিয়াহ। শেষ পর্যন্ত হেরে বিদায় নিয়েছে আটালান্ট।
# 233    ঢাকায় আফগানিস্তানের বিপক্ষে তিন ম্যাচের টেস্ট সিরিজের প্রথম ম্যাচে বড় পরাজয়ে জয়ের সম্ভাবনা জাগিয়েও ভয়াবহ ব্যাটিং ধসের মধ্যে আশার আলো জাগেছিল বাংলাদেশের অধিনায়ক নাজমুল হোসেন শান্ত।
# 234    সংযুক্ত আরব আমিরাতের শারজাহ স্টেডিয়ামে আফগানিস্তানের বিরুদ্ধে তিন ম্যাচের সিরিজের দ্বিতীয় ম্যাচে হেরেছে বাংলাদেশ। এই সিরিজে জয় পেয়েছে লাল-সবুজের একটি প্রতিনিধিদল।
# 235    বাংলাদেশ ও আফগানিস্তানের মধ্যে তিন ম্যাচ ওয়ানডে সিরিজের দ্বিতীয় ম্যাচে জয় পেয়েছে বাংলাদেশ। পাওয়ার প্লের ১০ ওভার শেষে ১ উইকেট হারিয়ে ৪০ রান সংগ্রহ করেছে বাংলাদেশ。 এরপর স্বাগতিকরা ৩ উইকেটে উঠে এসেছে।
# 236    সংযুক্ত আরব আমিরাতের শারজাহ স্টেডিয়ামে বাংলাদেশ ও আফগানিস্তান মধ্যকার ওয়ানডে সিরিজের দ্বিতীয় ম্যাচে তিন উইকেট হারিয়ে সিরিজে জয়ের লক্ষ্য রয়েছে বাংলাদেশের সফরকারীরা। এরপর থেকেই এই ম্যাচটি শুরু করেছে বাংলাদেশ।
# 237    বাংলাদেশ সুইমিং ফেডারেশনের ব্যবস্থাপনায় ও ম্যাক্স গ্রুপের পৃষ্ঠপোষকতায় ৩৩তম জাতীয় সাঁতার, ডাইভিং ও ওয়াটার পোলো প্রতিযোগিতা শুরু হয়েছে। এর আগে বাংলাদেশ নৌবাহিনী ও সেনাবাহিনীর মধ্যে নতুন রেকর্ড সৃষ্টি হয়।
# 238    ফরাসি ফুটবল ইতিহাসে এবারের ব্যালন ডি'অর পুরস্কারের ভোট গণনা শুরু হয়েছিল। কিন্তু শেষ পর্যন্ত তা উঠেছে রিয়াল মাদ্রিদ ও ম্যানচেস্টার সিটির মিডফিল্ডার রদ্রি রদ্রির হাতে।
# 239    বাংলাদেশ ও আফগানিস্তানের মধ্যকার দ্বিতীয় ওয়ানডে সিরিজের প্রথম ম্যাচে ২৯ ওভার শেষে দুই উইকেট হারিয়ে ১৪০ রান সংগ্রহ করেছে বাংলাদেশ। এই সিরিজে টিকে থাকতে টিগারদের বিকল্প নেই।
# 240    আফগানিস্তানের বিপক্ষে তিন ম্যাচ সিরিজের দ্বিতীয় ম্যাচে ৩ উইকেট হারিয়ে ৬৯ রান সংগ্রহ করেছে বাংলাদেশ। যার মধ্যে অন্যতম বড় লক্ষ্য ছিল টি-টোয়েন্টি ক্রিকেট দল ।
# 241    মাত্র ১৬ বছর বয়সে পেশাদার ফুটবলে অভিষেকের পর থেকেই নিয়মিত মুখ পাউ বার্সেলোনার ডিফেন্ডার লিওনেল কুবারসি। কিন্তু অসুস্থ অবস্থাতেই মাঠে নামতে অনড় তিনি।
# 242    ছেলেদের ক্রিকেটে এশিয়া কাপ থেকে শুরু করে বিশ্বকাপের শিরোপা হাতে তুলেছে বাংলাদেশ অনূর্ধ্ব-১৯ দল। এই টুর্নামেন্টের মূল উদ্বোধনী দিনে মাঠে নামবে বাংলাদেশের যুবারা।
# 243    আফগানিস্তানের বিপক্ষে তিন ম্যাচ সিরিজের দ্বিতীয় ম্যাচে মাঠে নামছে বাংলাদেশ। এই সিরিজে টিকে থাকার বিকল্প নেই লাল-সবুজ প্রতিনিধিদলের সামনে। এমনকি অপরিবর্তিত একাদশ নিয়ে নতুন করে দল গঠন করেছে টাইগাররা।
# 244    বাংলাদেশের সাফ চ্যাম্পিয়ন নারী ফুটবল দলকে দেড় কোটি টাকা পুরস্কারের ঘোষণা দিয়েছে বাংলাদেশ ফুটেবল ফেডারেশন (বাফুফে)। এর আগে দেশে ফেরার পর এই দলের অধিনায়ক সাবিনা খাতুনের হাতে এক কোটিরও বেশি পুরষ্কার প্রদান করা হয়েছে।
# 245    বাংলাদেশের নারী সাফ ফাইনালে মনিকা-ঋতুপর্ণার জয়সূচক সাবিনা হোসেন, কৃষ্ণা রহমান ও সানজিদা আক্তার আজ ঢাকায় ফিরে গেছেন। এই প্রথমবারের মতো দেশে ফিরেছেন তারা।
# 246    সংযুক্ত আরব আমিরাতে আজ আন্তর্জাতিক বেসবল ক্লাসিক টুর্নামেন্ট শুরু হচ্ছে। আফগানিস্তানকে হারিয়েছে বাংলাদেশ। এই জয়টি আলোচনায় উঠেছে বাংলাদেশের 'বেসবলের' দল নিয়ে।
# 247    কবি শামসুর রাহমান ছিলেন বাংলাদেশের একজন সুপরিচিত ক্রিকেটার। কিন্তু এর আগে থেকেই তিনি লিখতেন যে, 'আফগানিস্তানের বিপক্ষে হেরেছি, এখনো দুইটি ম্যাচ রয়েছে।'
# 248    অস্ট্রেলিয়া ও পাকিস্তানের মধ্যে চলমান তিন ম্যাচের সিরিজের দ্বিতীয় ম্যাচে জয় পেয়েছে দলটি। এই সিরিজে বড় ব্যবধানে জয়ের বিকল্প ছিল না সফরকারীরা। এমনকি ভারতের কাছেও হেরে গেছে।
# 249    বার্বাডোজে ওয়ানডে সিরিজের তৃতীয় ম্যাচে বোলিং করতে আসেন ওয়েস্ট ইন্ডিজের পেসার আলজারি জোসেফ। অধিনায়কের ওপর ক্ষোভ দেখিয়ে মাঠ ছেড়ে বেরিয়ে যান তিনি। কিন্তু এরকম আচরণ করার জন্য তাকে দুই ম্যাচের নিষেধাজ্ঞা
# 250    সাকিব আল হাসান, তামিম ইকবাল, মুশফিকুর রহিমদের প্রজন্ম বাংলাদেশের ক্রিকেটকে একটি পর্যায়ে নিয়ে গেছে বলে মনে করেন জাতীয় দলের সিনিয়র সহকারী কোচ মোহাম্মদ সালাউদ্দিন। কিন্তু এখন তরুণ ক্রিকেটাররা মেন্টালি, ফিজিক্যালি ও
# 251    ওয়ানডে ক্রিকেট থেকে অবসরের সিদ্ধান্ত নিয়েছেন আফগানিস্তানের অলরাউন্ডার মোহাম্মদ নবি। চ্যাম্পিয়নস ট্রফির পর এই ক্যারিয়ার শেষ করতে তিনি ইঙ্গিত দিয়েছেন টি-টোয়েন্টিতে খেলা চালিয়ে যাওয়ার।
# 252    আফগানিস্তানের বিপক্ষে তিন ম্যাচের টেস্ট সিরিজ শেষ হওয়ার পর বাংলাদেশ ক্রিকেট দল যেন ভুলতেই ভুলে গেছে। পাকিস্তানের পরে বাংলাদেশের প্রথম ওয়ানডে সিরিজে সেই ব্যর্থতা দেখা যায় কেবল ব্যাটসম্যানদের হাতে।
# 253    চোটের কারণ দেখিয়ে অক্টোবরের আন্তর্জাতিক বিরতির সময়ে ফ্রান্স দলে ছিলেন না রিয়াল মাদ্রিদের তারকা স্ট্রাইকার কিলিয়ান এমবাপ্পে। তবে ঘোষিত স্কোয়াডে জায়াগা হয়নি ফরোয়ার্ডের।
# 254    কানপুরের একটি স্টেডিয়ামে ভারতের বিপক্ষে টেস্ট সিরিজের দ্বিতীয় ম্যাচটি এক বছরের জন্য নিষিদ্ধ করেছে ক্রিকেটের সর্বোচ্চ নিয়ন্ত্রক সংস্থা (আইসিসি)। কিন্তু আউট ফিল্ড ভেজা থাকার কারণেই সেটি আয়োজন থেকে বহাল থাকবে।
# 255    বাংলাদেশের প্রথম ওয়ানডে সিরিজে ২৩৬ রানের ব্যবধানে ২ উইকেটে ১২০ রান তুলতে ৭ উইকেটের পতন, এর থেকে মহাপতন আর কী আছে? এই প্রশ্নের উত্তর খুঁজে পাওয়া যাচ্ছে।
# ...
# 417    নেপালের আর্মি হেড কোয়ার্টার মাঠে সাবিনা, শিউলী আজিম, ঋতুপর্না ও কৃষ্ণা রানী অনুশীলন করেছেন। কিন্তু সেখানে সংবাদমাধ্যমের সঙ্গে কথা বলতে দেওয়া হয়নি।
# 418    সাবেক উরুগুয়ের কোচ দিয়েগো ফোরলান আন্তর্জাতিক ফুটবলে অভিষেক হতে যাচ্ছে পেশাদার টেনিস ক্লাব টেনিসে। এবার তার নাম ঘোষণা করা হচ্ছে এই দলটির নতুন প্রধান।
# 419    মিরপুরে টেস্টের তৃতীয় দিনে হানা দিয়েছে বৃষ্টি। ৬৫ রানের লিড পেয়েছে বাংলাদেশ। ৮০ ওভারে ৭ উইকেট হারিয়ে ২৬৭ রান সংগ্রহ করেছে টাইগাররা। এর মধ্যে তিন উইকেটে হেরেছে দল।
# 420    সান্তিয়াগো বার্নাব্যুর ৯০ মিনিট অনেক লম্বা, আর সেই গল্পের মহানায়ক ভিনিসিয়ুস জুনিয়র করেছেন অসাধারণ হ্যাটট্রিক। এরপরও বরুশিয়া ডর্টমুন্ডকে ৫-২ গোলে হারিয়েছে কার্লো আনচেলত্তির শিষ্যরা।
# 421    ঢাকার কাঠমান্ডুর স্টেডিয়ামে তৃতীয় দিন ব্যাট করতে নেমে স্বাগতিকরা দুই উইকেট হারিয়ে মধ্যাহ্ন বিরতিতে গেছে বাংলাদেশ। এই ম্যাচের দ্বিতীয় দিনে টাইগাররা ১০১ রান করেছে।
# 422    প্রিয় ফুটবলারকে দেখতে অনেক রকম পাগলামী করে থাকেন ভক্তরা। যার সঙ্গে ম্যাচ চলাকালীন মাঠে ঢুকে পড়ার ঘটনা অবাক করেছে সবাইকে। তবে সেই ঘটনাটি ঘটেছে ক্রিশ্চিয়ানো রোনালদোর।
# 423    মুমিনুল হক বাংলাদেশের ওয়ানডে ক্রিকেট দলের সেরা খেলোয়াড়। কিন্তু টেস্ট ফরম্যাটে এই ব্যক্তির ব্যাটিং লাইনআপে কোনো পরিবর্তন হয়নি। এমনকি মিরপুর টেস্টেও তিনি নিজের নামে ফিরে এসেছেন।
# 424    সাফ নারী চ্যাম্পিয়নশিপে বাংলাদেশ-ভারত দ্বৈরথ আজ। ভারত আর বাংলাদেশের মধ্যে লড়াই নিয়ে অনেকটা আলোচনা চলছে। এবারের ম্যাচে মুখোমুখি হবে নেপাল। সেমিফাইনালে উঠে যাবে বাংলাদেশ।
# 425    টেস্টে প্রথম বাংলাদেশি ক্রিকেটার হিসেবে ৬ হাজার রানের মাইলফলক স্পর্শ করেছেন মুশফিকুর রহিম। এই কীর্তি গড়েছেন মিস্টার ডিপেন্ডেবল ও সাকিব আল হাসান - এমনকি তামিম ইকবালও।
# 426    মিরপুর টেস্টে বাংলাদেশ ও দক্ষিণ আফ্রিকার মধ্যকার টেস্ট ম্যাচের দ্বিতীয় দিন শেষ চালকের আসনে রয়েছে টাইগাররা। তৃতীয় দিনে দুই উইকেট হারিয়ে জয় চোখ রাঙিয়েছে বাংলাদেশকে।
# 427    আসন্ন ঢাকা প্রথম, দ্বিতীয় এবং তৃতীয় বিভাগ ক্রিকেট লিগের জন্য এক কোটি টাকার স্পন্সর পেয়েছে বাংলাদেশ क्रिकेट বোর্ড (বিসিবি)। মেঘনা ব্যাংকের সঙ্গে এক বছরের চুক্তি করেছে দেশের সর্বোচ্চ সংস্থাটি।
# 428    মিরপুর টেস্টে ব্যাটারদের ব্যর্থতায় নিজেদের প্রথম ইনিংসে ১০৬ রানে অলআউট হয়ে দক্ষিণ আফ্রিকাকে হারিয়ে চা-বিরতিতে গেছে বাংলাদেশ। এই টেস্টের দ্বিতীয় ম্যাচে বড় লিড পায় প্রোটিয়ারা।
# 429    'আপনি চলে যেতে পারবেন না। ফুটবল নির্বাচন করতে এসেছেন। সংগঠক আরও বেশি সংখ্যায় দরকার। দেশের ক্রীড়াঙ্গন ফিরিয়ে আনতে আপনার মতো কিছু কোচ না থাকলে আরেকটি কলুষিত হয়ে যাবে।'
# 430    মিরপুর টেস্টের প্রথম দিনে দক্ষিণ আফ্রিকার বিপক্ষে ১০৬ রানে অলআউট হয়েছিল বাংলাদেশ। দলটি নিউজিল্যান্ডের কাছে ৫ উইকেট নিয়ে লড়াই করেছে। তবে ব্যাটারদের ব্যর্থতায় ১০০ রানের বড় লিড নিয়েছে তারা।
# 431    নেপালে নারী সাফ খেলতে পাকিস্তানের বিপক্ষে ১-১ গোলে ড্র করতে হতো না। কিন্তু সেটা ভালো হয়নি বলে স্বীকার করে নিয়েছেন বাংলাদেশের সেরা খেলোয়াড় মনিকা চাকমা এবং ভারতের কাছে হেরে যাওয়ার শঙ্কা ছিল।
# 432    চট্টগ্রামের এম এ আজিজ স্টেডিয়ামকে ফুটবলের জন্য ডেডিকেটেড করার কথা জানিয়েছেন বাফুফের যুব ও ক্রীড়া উপদেষ্টা আসিফ মাহমুদ সজীব ভূঁইয়া। তিনি বলেছেন, এটি খেলার মূল প্রতিবন্ধকতা।
# 433    মিরপুর টেস্টের প্রথম দিনে দক্ষিণ আফ্রিকার বিপক্ষে ১০৬ রানে অলআউট হয়েছে বাংলাদেশ। বড় লিডের পথেই আছে এই দল। এবারের মধ্যাহ্ন বিরতিতে যাওয়ার কথা রয়েছে প্রোটিয়ারা।
# 434    ক্যারিয়ারের একটা বড় অংশ মাঠের বাইরে অপেক্ষা করেই পার করেছেন ব্রাজিলিয়ান ফুটবলের পোস্টার বয় নেইমার জুনিয়র। গত বছর তার হাঁটুর চোটে আঘাত পেয়েছিলেন তিনি।
# 435    ঢাকায় মিরপুর টেস্টের প্রথম দিন শেষে দক্ষিণ আফ্রিকাকে ৩৪ রানের ব্যবধানে হারিয়েছে বাংলাদেশ। কিন্তু সেখানে নিজেদের চেনা আঙ্গিনা, চেনার উইকেট দেখা যায়। সেই ব্যর্থতা দেখে বাংলাদেশের চোখে হাস্যোজ্জ্বল।
# 436    নিরাপত্তাজনিত কারণে চলমান মিরপুর টেস্টে খেলতে পারছেন না বাংলাদেশের ক্রিকেটার সাকিব আল হাসান। এই টেস্টের জন্য তাকে নিয়ে হওয়া আলোচনা-সমালোচনার একটি ভিডিও সামাজিক মাধ্যমে ভাইরাল হয়েছে।
# 437    বাংলাদেশ ও দক্ষিণ আফ্রিকার মধ্যকার মিরপুর টেস্টের প্রথম দিনে ব্যাটারদের ব্যর্থতায় ১০৬ রানে অলআউট হয়েছে বাংলাদেশ। দলীয় ১০৮ রানের ব্যবধানে ১৪০ রান সংগ্রহ করে শেষ করেছে তারা।
# 438    বাংলাদেশের মেয়েদের টি-টোয়েন্টি ক্রিকেটে এবারের বিশ্বকাপ থেকে বিদায় নিয়েছে নিগার সুলতানার দল। পাওয়ার হিটিংয়ে বাউন্ডারি মারায় পিছিয়ে আছে বাংলাদেশ। এই ফরম্যাটে খেলাই সেরা অর্জন।
# 439    মিরপুরে চলছে বাংলাদেশ-দক্ষিণ আফ্রিকার মধ্যকার টেস্ট ম্যাচ। এ দিন স্টেডিয়ামে বিনা টিকিটে খেলা দেখতে আসে স্কুল-কলেজের শিক্ষার্থীরা। তবে ব্যর্থ হয়েছে তারা। বিসিবি এবার তা দিচ্ছে না।
# 440    মিরপুর টেস্টে ব্যাটিং বিপর্যয়ে নিজেদের প্রথম ইনিংসে ১০৬ রানে অলআউট হয়েছে বাংলাদেশ। ১৬ ওভারে ২ উইকেট হারিয়ে চা-বিরতিতে গেছে প্রোটিয়ারা। তবে দলীয় ৫০ রানের জুটিতে স্টাবসকে আউট করে বাংলাদেশকে দ্বিতীয় সাফল্য এনে দিয়েছে তা
# 441    নেপালের দশরথে রঙ্গশালার মাঠে অনুষ্ঠানরত নারী সাফ চ্যাম্পিয়নশিপে নিজেদের প্রথম খেলায় পাকিস্তানের বিপক্ষে ১-১ গোলে ড্র করেছে বাংলাদেশ। সেমিফাইনালে ওঠার সম্ভাবনা ঝুলে থাকল।
# 442    মিরপুর টেস্টে বাংলাদেশ ও স্বাগতিকরা মধ্যাহ্ন বিরতিতে যাওয়ার পর এই টেস্টটি পুরো দুই সেশনও ব্যাট করতে পারলো না বাংলাদেশ। এরপর থেকেই বিপর্যয় সামাল দেওয়ার চেষ্টা করা হয়েছে টাইগাররা।
# 443    দক্ষিণ আফ্রিকার বিপক্ষে দুই ম্যাচ সিরিজের প্রথম টেস্টে মাঠে নেমেছে বাংলাদেশ। মিরপুর টেস্টকে ঘিরে নিরাপত্তার শঙ্কা আরও বাড়িয়ে দেয় সেনাবাহিনী। এ নিয়ে বিতর্ক শুরু হয়েছে ঢাকায়।
# 444    দক্ষিণ আফ্রিকার বিপক্ষে দুই ম্যাচ টেস্ট সিরিজের প্রথম ম্যাচে মাঠে নেমেছে বাংলাদেশ। এরপর থেকে মধ্যাহ্ন বিরতিতে গেছে টাইগার অধিনায়ক নাজমুল হোসেন শান্ত ও মাহমুদু জয়।
# 445    বাংলাদেশের জাতীয় ফুটবল দলের বাফুফের সভাপতি পদে নির্বাচন করার হাঁকডাক দিয়ে মনোনয়ন পত্রটাই তোলেননি তরফদার রুহুল আমিন। ইমরুল হাসানের পথ থেকে সরে যাওয়ার সময় তিনি বলেছিলেন, তাবিথকে সমর্থন দিচ্ছেন না।
# 446    দক্ষিণ আফ্রিকার বিপক্ষে দুই ম্যাচ টেস্ট সিরিজের প্রথম ম্যাচে মাঠে নেমেছে বাংলাদেশ। দলীয় ২১ রানের মধ্যে ৩ উইকেট হারিয়ে বিপর্যয়ে পড়েছে টাইগার অধিনায়ক নাজমুল হোসেন শান্ত।
# 447    বাংলাদেশ ও দক্ষিণ আফ্রিকার মধ্যে তিনটি টেস্ট সিরিজের দ্বিতীয় সিরিজে হেরেছে ভারতের বিপক্ষে। কিন্তু সেখানে কোনো ইতিহাস গড়তে পারেনি বাংলাদেশ। সেই পরিসংখ্যান বলছে, এবারের ম্যাচটি কীভাবে শেষ হবে?
# 448    ২০২৩ নারী টি-টোয়েন্টি বিশ্বকাপ ফাইনালে অস্ট্রেলিয়ার মেয়েদের কাছে হেরে শিরোপা হাতছাড়া করেছে দক্ষিণ আফ্রিকা। নিউজিল্যান্ডকে ৩২ রানে হারিয়ে প্রথমবারের মতো চ্যাম্পিয়ন হয়েছে দলটি।
# 449    উইমেন্স সাফ চ্যাম্পিয়নশিপে 'এ' গ্রুপের ম্যাচে অতিরিক্ত সময়ে গোল করে হার এড়ালো বাংলাদেশ। ফলে টুর্নামেন্ট থেকেও বিদায় নেয়ার শঙ্কা তৈরি হতে পারেনি লাল-সবুজের প্রতিনিধিরা।
# 450    দক্ষিণ আফ্রিকার বিপক্ষে মিরপুরে সিরিজের শেষ টেস্ট খেলতে চেয়েছিলেন সাকিব আল হাসান। কিন্তু নিরাপত্তাজনিত কারণে তার খেলা হচ্ছে না বলে জানিয়েছেন তার কোচ এইডেন মার্করাম। তবে বাংলাদেশের জন্য কঠিন চ্যালেঞ্জ অপেক্ষা করছে।
# 451    বাংলাদেশ ক্রিকেট দলের অধিনায়ক সাকিব আল হাসানকে দেশে ফিরিয়ে এনে সম্মানের সঙ্গে অবসর গ্রহণের সুযোগ দেওয়ার দাবিতে আন্দোলনে নেমেছেন তার ভক্তরা। মিরপুর শেরেবাংলা স্টেডিয়ামের বাইরে নিরাপত্তা আরও জোরদার করা হয়েছে।
# 452    দক্ষিণ আফ্রিকার বিপক্ষে মিরপুরে প্রথম টেস্ট খেলে সাদা পোশাকের ক্রিকেটকে বিদায় বলতে চেয়েছিলেন সাকিব আল হাসান। তবে শেষ মুহূর্তে নিরাপত্তার কারণ দেখিয়ে তাকে দেশে না ফেরার পরামর্শ দেন যুব ও ক্রীড়া উপদেষ্টা আসিফ মাহমুদ
# 453    দক্ষিণ আফ্রিকার বিপক্ষে দুই ম্যাচ টেস্ট সিরিজের প্রথম ম্যাচে আগামীকাল মাঠে নামছে বাংলাদেশ। কিন্তু সাকিব আল হাসানকে বিদায় দিতে না পারা নিয়ে কোনো ক্রিকেটারকে প্রতিবাদ জানানো হয়নি।
# 454    দক্ষিণ আফ্রিকার বিপক্ষে মিরপুরে প্রথম টেস্ট খেলে সাদা পোশাকের ক্রিকেটকে বিদায় বলতে চেয়েছিলেন সাকিব আল হাসান। কিন্তু শেষ মুহূর্তে নিরাপত্তার কারণ দেখিয়ে তাকে দেশে না ফেরার পরামর্শ দেন যুব ও ক্রীড়া উপদেষ্টা।
# 455    ১৯৮৮ সালে ভারতের মাটিতে সবশেষ টেস্ট জিতেছিল নিউজিল্যান্ড। স্বাগতিকদের ৮ উইকেটে হারিয়েছে স্বাগতিকরা। কিন্তু শেষ পর্যন্ত এই ম্যাচের জয় পায় তারা। এবারের ম্যাচে তিনটি উইকেট নিয়ে লড়াই করা হয়।
# 456    দক্ষিণ আফ্রিকার বিপক্ষে মিরপুরে প্রথম টেস্ট খেলে সাদা পোশাকের ক্রিকেটকে বিদায় বলতে চেয়েছিলেন সাকিব আল হাসান। কিন্তু শেষ মুহূর্তে নিরাপত্তার কারণ দেখিয়ে তাকে দেশে না ফেরার পরামর্শ দিয়েছেন যুব ও ক্রীড়া উপদেষ্টা।
# 457    নেপালের কাঠমান্ডুর দশরথ রঙ্গশালা স্টেডিয়ামে আজ বাংলাদেশ-পাকিস্তান মুখোমুখি হবে। পাকিস্তানের বিপক্ষে কম্পিটিটিভ ম্যাচ হবে বলে ধারণা করা হচ্ছে। এবারের সাফ চ্যাম্পিয়ন বাংলাদেশের অবস্থান অনন্য উচ্চতায়।
# 458    বাংলাদেশের ফুটবল বোর্ড বা বাফুফের সহ-সভাপতি পদে নির্বাচন না করার সিদ্ধান্ত নিয়েছেন মো. নাসের শাহরিয়ার জাহেদী। কিন্তু তার কাছে প্রাণবন্ত মনে হচ্ছে না। তাদের মধ্যে কিছু ঘটনা ঘটেছে।
# 459    চলমান নারী টি-টোয়েন্টি বিশ্বকাপের ফাইনালে লড়াই করবে দক্ষিণ আফ্রিকা ও নিউজিল্যান্ড। এই টুর্নামেন্টে শিরোপা জিতেছে দুই দল। আর কোনো চ্যাম্পিয়ন দেখবে ক্রিকেট বিশ্ব।
# 460    আর্জেন্টিনার ফুটবল তারকা লিওনেল মেসি মাত্র ৩ দিনের ব্যবধানে আবার হ্যাটট্রিক করলেন। যুক্তরাষ্ট্রের মেজর লিগ সকারে (এমএলএস) নিউ ইংল্যান্ডকে ৬-২ ম্যাচে হারিয়েছে ফ্লোরিডার দলটি।
# 461    গতকাল শনিবার টাইগারদের দায়িত্ব নেওয়ার পর প্রথমবার গণমাধ্যমের মুখোমুখি হন ক্যারিবিয়ান কোচ ফিল সিমন্স। কিন্তু তিনি কি নিজের কাজের লক্ষ্য তুলে ধরেছেন? এই প্রশ্নটি নিয়ে বিস্ময় তৈরি হয়েছে।
# 462    বর্ণাঢ্য ক্যারিয়ারের একটা সময় স্প্যানিশদের তল্লাটে কাটিয়েছেন আর্জেন্টাইন অধিনায়ক লিওনেল মেসি। এক যুগের বেশি সময় ধরে খেলেছেন জাতীয় দল বার্সেলোনার হয়ে। কিন্তু তার মধ্যে নেই দেশপ্রেম।
# 463    নেপালে সাফ চ্যাম্পিয়নশিপ শুরু হবার আগে থেকেই ঠান্ডায় হাঁচি দিচ্ছেন বাংলাদেশি ফুটবলাররা। কিন্তু এখনও তাদের মধ্যে কোনো সমস্যা নেই। সেই আশায় উড়িয়ে দেওয়ার সুযোগ রয়েছে।
# 464    বাংলাদেশ ও দক্ষিণ আফ্রিকার মধ্যকার টেস্ট সিরিজের প্রথম দিন থেকেই ঘরের মাটিতে চোখে পড়েছে বাংলাদেশের টাইগার বাহিনী। কিন্তু এই যাত্রায় কয়েকটি কারণে গুরুত্বপূর্ণ কাজটি চলছে।
# 465    জাতীয় দলের ক্রিকেটারের সঙ্গে অসদাচরণ ও আচরণেবিধি ভাঙার দায়ে বাংলাদেশের প্রধান কোচের পদ থেকে বরখাস্ত করা হয়েছে চন্ডিকা হাথুরুসিংহেকে। এর আগে থেকেই তিনি নিজের বিরুদ্ধে ওঠা অভিযোগের জবাব দিয়েছেন।
# 466    ওমানে ইমার্জিং এশিয়া কাপের আসরের উদ্বোধনী ম্যাচেই হংকং জাতীয় দলকে হারিয়েছে বাংলাদেশ। ভারতের বিপক্ষে ৫ উইকেটের ব্যবধানে জয় পেয়েছে বাংলাদেশ, যা এই প্রথম টি-টোয়েন্টি ম্যাচ।
# 467    সাকিব আল হাসান, মাশরাফি বিন মর্তুজা এবং তামিম ইকবালের বর্তমান পরিস্থিতি নিয়ে সাধারণ ক্রিকেটপ্রেমীদের মধ্যে ক্ষোভ ছড়িয়ে পড়ার পর তাদের 'ছোটবেলার কোচ' হিসেবে পরিচিত মোহাম্মদ সালাউদ্দিন বলেছেন, দেশের প্রতি কেন যে
# 468    বাংলাদেশে ছাত্র-জনতার প্রতিবাদের মুখে দেশের মাটিতে টেস্ট খেলা হলো না সাকিব আল হাসানের। সরকারের একজন ঊর্ধ্বতন কর্মকর্তা বলেছেন, 'সাকিবের মতো ক্রিকেটার বাংলাদেশের ইতিহাসে আর আসেনি।'
# 469    বাংলাদেশের দক্ষিণ আফ্রিকার বিপক্ষে প্রথম টেস্টের দল থেকে সাকিব আল হাসানের বদলে হাসান মুরাদকে দলে নিয়েছে বাংলাদেশ। এরই মধ্যে বৈষম্যবিরোধী ছাত্র আন্দোলনের বিরুদ্ধে তাকে বাদ দেয়া হয়েছে।
# 470    পাকিস্তান ও ইংল্যান্ডের মধ্যে মুলতানের মাঠে তৃতীয় দিনের টেস্ট ম্যাচটি শেষ করেছে আফগানিস্তান। কিন্তু এই ম্যাচে জয় পেয়েছে ভারত ও ওয়েস্ট ইন্ডিজের অধিনায়ক সাজিদ খান।
# 471    ২০১৮ সালে নিজেদের ইতিহাসে দ্বিতীয় বারের মতো বিশ্বকাপ জিতেছিল ফ্রান্স। কিন্তু সেই ইতালির ফুটবলার পল পগবাকে ডোপিং কাণ্ডের জন্য চার বছর নিষিদ্ধ করা হয়েছে।
# 472    বাংলাদেশের টেস্ট ক্রিকেট দল দক্ষিণ আফ্রিকাকে পা রাখার পর দিনই নেমেছে অনুশীলনে। আজ থেকে শুরু হচ্ছে নতুন কোচ ফিল সিমন্সকে নিয়ে এই প্রথম ম্যাচে বাংলাদেশ স্টেডিয়ামে।
# 473    চন্ডিকা হাথুরুসিংহেকে কারণ দর্শানোর নোটিশ দিয়েছিল বাংলাদেশ ক্রিকেট বোর্ড (বিসিবি) এবং তাকে চাকরিচ্যুত করেছে বাংলাদেশ জাতীয় দলের সাবেক কোচ ফিল সিমন্স। গতকাল ঢাকায় বিসিবির কার্যালয়ে পরিচালকদের এক সভা অনুষ্ঠিত হয়।
# 474    বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) ড্রাফট থেকে মাশরাফি বিন মোর্ত্তজাকে দলে ভিড়িয়েছিল সিলেট স্ট্রাইকার্স। দলটি ছিল বাংলাদেশের প্রথম ওয়ানডে ফাইনালে উঠেছিল গত বছর।
# 475    চরম নাটকীয়তার পর দেশে ফেরার পরিকল্পনা থেকে সরে এসেছেন বাংলাদেশের ওয়ানডে ক্রিকেট দলের অধিনায়ক সাকিব আল হাসান। কিন্তু একটি ভিডিওতে তাকে ভালোবাসুন কিংবা ঘৃণা করুন, সেটার পরোয়া নেই তার।
# 476    বাংলাদেশ ক্রিকেট বোর্ডের সাবেক অধিনায়ক সাকিব আল হাসানকে যুক্তরাষ্ট্র থেকে বাংলাদেশের উদ্দেশে ফ্লাইট বাতিল করার পরামর্শ দিয়েছে বাংলাদেশ টেস্ট বিভাগ (বিসিবি)। কিন্তু পরিস্থিতি বিবেচনায় তিনি দেশে ফিরছেন না।
# 477    দক্ষিণ আফ্রিকার বিপক্ষে ঢাকা টেস্টের স্কোয়াড ঘোষণা করেছিলো বাংলাদেশ ক্রিকেট বোর্ড (বিসিবি)। তবে নিরাপত্তার ঝুঁকির কারণে তাকে নিয়েই মিরপুরে বিদায়ী টেস্টে খেলতে আসবেন না সাকিব আল হাসান।
# 478    বাংলাদেশ ক্রিকেট দলের নতুন হেড কোচ হিসেবে ফিল সিমন্সকে পেছনে ফেলেছে ওয়েস্ট ইন্ডিজের সাবেক প্রধান গর্ডন গ্রিনিজ ও কোর্টনি ওয়ালশ। দায়িত্ব সামলানো হচ্ছেন চন্ডিকা হাথুরুসিংহে।
# 479    বাংলাদেশ ক্রিকেট দলের অধিনায়ক সাকিব আল হাসান বলেছেন, তিনি হয়তো যুক্তরাষ্ট্রে ফিরতে পারবেন না। কিন্তু নিরাপত্তা ইস্যু থাকায় এখন তার দেশে ফেরার সম্ভাবনা নেই বলে জানাচ্ছেন দেশটির অনলাইন গণমাধ্যম।
# 480    বাংলাদেশ ক্রিকেট বোর্ড বিসিবি জানিয়েছে, সাকিব আল হাসান দক্ষিণ আফ্রিকার বিপক্ষে প্রথম টেস্ট খেলতে ঢাকায় ফিরছেন। কিন্তু নিরাপত্তা পেলেই তাকে দেশে ফেরত পাঠানো হচ্ছে বলে জানা গেছে।
# 481    দক্ষিণ আফ্রিকার বিপক্ষে প্রথম টেস্টের জন্য ১৫ সদস্যের দল ঘোষণা করেছে বাংলাদেশ ক্রিকেট বোর্ড। সেই স্কোয়াডে রয়েছেন ক্রিকেটার সাকিব আল হাসান। তার দেশে ফেরা নিয়ে শেষ মুহূর্তে জটিলতা দেখা দিয়েছে।
# 482    বাংলাদেশ ও দক্ষিণ আফ্রিকার মধ্যকার দুই ম্যাচের টেস্ট সিরিজের জন্য দল ঘোষণা করেছে বাংলাদেশ ক্রিকেট বোর্ড (বিসিবি)। এই সিরিজে যোগ হবে চট্টগ্রামের জহুর আহমেদ চৌধুরী স্টেডিয়ামে।
# 483    নিরাপত্তা ইস্যুতে আশ্বস্ত হয়ে বিদায়ী টেস্ট খেলতে ঢাকায় ফিরছেন সাকিব আল হাসান। আগামী ২১ অক্টোবর থেকে ঘরের মাঠে শুরু হবে সিরিজের প্রথম টেস্টে। কিন্তু এই ম্যাচের পর তার লাভ ইমোজি জুড়ে দিয়েছেন ক্রিকেটাররা।
# 484    সংযুক্ত আরব আমিরাতে চলমান নারী টি-টোয়েন্টি বিশ্বকাপের নবম আসরের গ্রুপ পর্বের খেলা শেষ হয়েছে গতকাল। তবে কোনো এশিয়ান দল ছাড়াই মাঠে গড়াতে যাচ্ছে সেমিফাইনালের ম্যাচ।
# 485    বাংলাদেশের প্রধান কোচ হাথুরুসিংহকে কারণ দর্শানোর নোটিশ জারি করেছে বাংলাদেশ ক্রিকেট বোর্ড (বিসিবি)। এ ঘটনায় সাবেক ক্রিকেটার নাজমুল হাসান পাপন বলেছিলেন, 'আমি জানিনি'।
# 486    বাংলাদেশের বিপক্ষে দুই ম্যাচের টেস্ট সিরিজের জন্য ঢাকায় পৌছেছে দক্ষিণ আফ্রিকা দল। নতুন কোচ ফিল সিমন্সের নিয়োগ ঘোষণার পর এই সিরিজে থাকবে বিশেষ নজর।
# 487    বিশ্বকাপ বাছাইয়ের ম্যাচে বলিভিয়ার বিপক্ষে ৬-০ গোলের বিশাল জয় পেয়েছে বর্তমান বিশ্বচ্যাম্পিয়ন আর্জেন্টিনা। এই জয়ের নায়ক লিওনেল মেসি এবং ব্রাজিলও কম যায়নি। ব্রাসিলিয়ায় বাংলাদেশ সময় বুধবার সকালে পেরুকে ৪-० গোলে হারিয়েছে
# 488    ওয়েস্ট ইন্ডিয়ান ফিল সিমন্সকে অন্তর্বর্তীকালীন টাইগারদের নতুন হেড কোচ হিসেবে ঘোষণা করেছে বাংলাদেশ ক্রিকেট বোর্ড (বিসিবি)। এর আগে চন্ডিকা হাথুরাসিংহকে বরখাস্ত করা হয়েছে।
# 489    বাংলাদেশ ক্রিকেট বোর্ডের সাবেক সভাপতি ফারুক আহমেদ জানিয়েছেন, চন্ডিকা হাথুরুসিংহকে বরখাস্ত করার আগে তাকে নিয়ম মেনে শোকজ নোটিশ করেছেন তিনি। এরপর সাসপেন্ড করা হলো এই কোচকে।
# 490    বাংলাদেশের ওয়ানডে সিরিজের প্রথম আসর বিপিএলে ঢাকা ক্যাপিটালস নামে একটি দল ঘোষণা করেছে। এবারের আসরে পরিবর্তন হয়েছে বাংলাদেশ ক্রিকেট দলের মালিকানা। ড্রাফট থেকে বেশ কিছু ক্রিকেটার দলে ভিড়িয়েছেন।
# 491    সাফ নারী ফুটবল চ্যাম্পিয়নশিপে খেলতে বাংলাদেশ দল আজ সকালে নেপালে যাচ্ছে। কিন্তু ট্রফি ধরে রাখার মিশন নিয়ে শঙ্কা উড়িয়ে দেওয়া যায় না। কারণ একটা করে ম্যাচ খেলে এগিয়ে যেতে চায় না সাবিনারা।
# 492    বাংলাদেশের ক্রিকেটার সাকিব আল হাসানের ফেরা নিয়ে মানুষের মধ্যে বেশ কয়েকদিন ধরে সংশয় তৈরি হয়েছিল। কিন্তু শেষ পর্যন্ত তাকে দলে নিতে কোনো চুক্তিগত জটিলতা ছিল না।
# 493    বাংলাদেশ ক্রিকেট স্টেডিয়ামে গত বছরের মতো এবারও অংশ নেবে তিনটি ফ্র্যাঞ্চাইজি। নতুন করে নাম ও মালিকানা বদল হয়েছে ঢাকা ক্যাপিটালস ও চট্টগ্রাম কিংস নামের দলগুলো। বিপিএলের প্লেয়ার্স ড্রাফট শুরু হয়েছে সোমবার।
# 494    বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) একাদশ আসরের প্লেয়ার্স ড্রাফটের কার্যক্রম শুরু করেছে ঢাকা ক্যাপিটালস এবং ফরচুন বরিশাল। তৃতীয় সেটের প্রথম রাউন্ডে তামিম-মুশফিককে দলে ভিড়িয়েছে এবাদত হোসেন।
# 495    বাংলাদেশ প্রিমিয়ার লীগের একাদশ আসরের জন্য ঢাকায় প্লেয়ার্স ড্রাফটের প্রথম পর্বে দুই অভিজ্ঞ ক্রিকেটার মাহমুদউল্লাহ রিয়াদ ও মাশরাফি বিন মুর্তজা তাদের পুরোনো দল পেয়েছেন।
# 496    বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) একাদশ আসরের প্লেয়ার্স ড্রাফট শুরু হয়েছে সোমবার (১৪ অক্টোবর) রাজধানীর একটি পাঁচ তারকা হোটেলে সকাল ১১টা থেকে। সেটে এসে অবশেষে জাতীয় দলের অধিনায়ক নাজমুল হোসেন শান্তকে দলে ভিড়িয়েছে
# 497    বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) একাদশ আসরের প্লেয়ার্স ড্রাফট শুরু হয়েছে সোমবার (১৪ অক্টোবর) রাজধানীর একটি পাঁচ তারকা হোটেলে। এরপর ঢাকা ক্যাপিটালস থেকে শামীম হোসেন পাটোওয়ারীকে দলে নেয় চিটাগাং কিংস।
# 498    একটি ম্যাচ জয়ের লক্ষ্য নিয়ে নবম নারী টি-টোয়েন্টি বিশ্বকাপ শুরু করেছিল বাংলাদেশ। এরপর তিন ম্যাচে জয় পেয়েছে লাল-সবুজের প্রতিনিধিরা। তবে সেটি ছিল 'এ' গ্রুপ থেকে।
# 499    বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) একাদশ আসরের রোমাঞ্চ শুরু হয়ে গেছে বাংলাদেশের রাজধানী ঢাকার ও রংপুর রাইডার্স। এরই মাঝে ইংল্যান্ডের ব্যাটার অ্যালেক্স হেলসকে নিয়ে ঘটেছে নাটকীয়তা।

# %%
df = pd.read_csv('/content/drive/My Drive/Colab/sports_zeroshot.csv')

# Display the first few rows to verify the file is loaded properly
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনা...
# 1           1  বিমান বন্দর থেকে তেজগাঁওয়ে বিমান বাহিনীর ফ্যাল...
# 2           2  সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ...
# 3           3  ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচ। ফাইনাল খেলতে...
# 4           4  সাদিয়াকে কখনো কেউ গোমড়া মুখে দেখেনি। সব সময় হা...
#
#                                         givenSummary  \
# 0  দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনা...
# 1  বিমান বন্দর থেকে তেজগাঁওয়ে বিমান বাহিনীর ফ্যাল...
# 2  সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ...
# 3  ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচ। ফাইনাল খেলতে...
# 4  সাদিয়াকে কখনো কেউ গোমড়া মুখে দেখেনি। সব সময় হা...
#
#                                       mT5_Test_XLSum
# 0  অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনালে দ্বিতীয়বারের...
# 1  যুব বিশ্বকাপ জুনিয়র হকিতে বাংলাদেশের অবস্থান ...
# 2  সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথ...
# 3  গায়ানার প্রভিডেন্স স্টেডিয়ামে বাংলাদেশের রংপ...
# 4  সাদিয়া সুলতানাকে কখনো কেউ গোমড়া মুখে দেখেনি।...

# %%
df
# Out:
#      Unnamed: 0                                               text  \
# 0             0  দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনা...
# 1             1  বিমান বন্দর থেকে তেজগাঁওয়ে বিমান বাহিনীর ফ্যাল...
# 2             2  সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ...
# 3             3  ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচ। ফাইনাল খেলতে...
# 4             4  সাদিয়াকে কখনো কেউ গোমড়া মুখে দেখেনি। সব সময় হা...
# ..          ...                                                ...
# 495         495  বিপিএলের একাদশ আসরের জন্য প্লেয়ার্স ড্রাফটের প...
# 496         496  শুরু হয়েছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) এ...
# 497         497  শুরু হয়েছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) এ...
# 498         498  একটি ম্যাচ জয়ের লক্ষ্য নিয়ে নবম নারী টি-টোয়েন্...
# 499         499  শুরু হয়ে গেছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল...
#
#                                           givenSummary  \
# 0    দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনা...
# 1    বিমান বন্দর থেকে তেজগাঁওয়ে বিমান বাহিনীর ফ্যাল...
# 2    সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথম ...
# 3    ম্যাচটি ছিল লিগ পর্বের শেষ ম্যাচ। ফাইনাল খেলতে...
# 4    সাদিয়াকে কখনো কেউ গোমড়া মুখে দেখেনি। সব সময় হা...
# ..                                                 ...
# 495  বিপিএলের একাদশ আসরের জন্য প্লেয়ার্স ড্রাফটের প...
# 496  শুরু হয়েছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) এ...
# 497  শুরু হয়েছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) এ...
# 498  একটি ম্যাচ জয়ের লক্ষ্য নিয়ে নবম নারী টি-টোয়েন্...
# 499  শুরু হয়ে গেছে বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল...
#
#                                         mT5_Test_XLSum
# 0    অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনালে দ্বিতীয়বারের...
# 1    যুব বিশ্বকাপ জুনিয়র হকিতে বাংলাদেশের অবস্থান ...
# 2    সিলেটের লাক্কাতুরায় টি-টোয়েন্টি সিরিজের প্রথ...
# 3    গায়ানার প্রভিডেন্স স্টেডিয়ামে বাংলাদেশের রংপ...
# 4    সাদিয়া সুলতানাকে কখনো কেউ গোমড়া মুখে দেখেনি।...
# ..                                                 ...
# 495  বাংলাদেশ প্রিমিয়ার লীগের একাদশ আসরের জন্য ঢাক...
# 496  বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) একাদশ আসরের...
# 497  বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) একাদশ আসরের...
# 498  একটি ম্যাচ জয়ের লক্ষ্য নিয়ে নবম নারী টি-টোয়...
# 499  বাংলাদেশ প্রিমিয়ার লিগের (বিপিএল) একাদশ আসরের...
#
# [500 rows x 4 columns]

# %%
# View the original text, given summary, and generated summary for the first row
sample_index = 0  # You can change this to inspect different rows

# Access text, given summary (if available), and generated summary
original_text = df['text'][sample_index]
given_summary = df['givenSummary'][sample_index]  # If present in the CSV
generated_summary = df['mT5_Test_XLSum'][sample_index]

# Print the text and corresponding summaries
print(f"Original Text:\n{original_text}\n")
print(f"Given Summary (if available):\n{given_summary}\n")
print(f"Generated Summary:\n{generated_summary}\n")
# Out:
# Original Text:
# দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনালে জায়গা করে নিয়েছে বাংলাদেশ। সেমিফাইনালে পাকিস্তানকে ৭ উইকেটের বড় ব্যবধানে হারিয়ে শিরোপার আরও একধাপ কাছে পৌঁছেছে লাল-সবুজের যুবারা।
# দুবাই আন্তর্জাতিক ক্রিকেট স্টেডিয়ামে টস জিতে পাকিস্তানকে ব্যাটিংয়ে পাঠায় বাংলাদেশ। শুরু থেকেই প্রতিপক্ষের ব্যাটিং লাইনআপে চাপ সৃষ্টি করেন পেসার মারুফ মৃধা। দলীয় ২ রানের মাথায় ওপেনার উসমান খান ও তার পরের ওভারে শাহজাইব খানকেও শূন্য রানে ফিরিয়ে দেন তিনি।
# পাকিস্তানের অধিনায়ক সাদ বেগ ও মোহাম্মদ রিয়াজুল্লাহ কিছুটা প্রতিরোধের চেষ্টা করলেও পেসার ইকবাল হোসেন ইমন তাদের আউট করেন। এরপর আর কেউই বড় ইনিংস গড়তে পারেনি। ফারহান ইউসুফের ৩২ রানের ইনিংস ছাড়া ব্যাটিং অর্ডার ছিল ধসে পড়া দেয়ালের মতো।
# পাকিস্তান ৩৭ ওভারে মাত্র ১১৬ রানে অলআউট হয়। ইকবাল হোসেন ২৪ রান দিয়ে ৪ উইকেট নেন, আর মারুফ মৃধা শিকার করেন ২৩ রানে ২ উইকেট।   ১১৭ রানের লক্ষ্য তাড়া করতে নেমে শুরুতেই বিপাকে পড়ে বাংলাদেশ। ওপেনার কামাল সিদ্দিকী শূন্য রানে আউট হন, আর জাওয়াদ আবরার ২৫ বলে ১৭ রান করে বিদায় নেন। দলীয় স্কোর তখন মাত্র ২৮।
# তবে এরপর অধিনায়ক আজিজুল হাকিম তামিম চাপ সামলে ইনিংস মেরামতের দায়িত্ব নেন। শিহাব জেমসকে সঙ্গে নিয়ে এগিয়ে যান। শিহাব ২৮ রানে আউট হলেও তামিম ৭ চার ও ৩ ছক্কায় অপরাজিত ৬১ রানের ইনিংস খেলে দলকে জয় এনে দেন। বাংলাদেশ মাত্র ৩৪ ওভারে ৩ উইকেট হারিয়ে লক্ষ্যে পৌঁছে যায়।   অন্য সেমিফাইনালে ভারত ৭ উইকেটের বড় ব্যবধানে শ্রীলঙ্কাকে পরাজিত করে। আগামী ৮ ডিসেম্বর বাংলাদেশ সময় সকাল ১১টায় ফাইনালে মুখোমুখি হবে দুই চিরপ্রতিদ্বন্দ্বী ভারত ও বাংলাদেশ।
#
#
# Given Summary (if available):
# দ্বিতীয়বারের মতো অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনালে জায়গা করে নিয়েছে বাংলাদেশ। সেমিফাইনালে পাকিস্তানকে ৭ উইকেটের বড় ব্যবধানে হারিয়ে শিরোপার আরও একধাপ কাছে পৌঁছেছে লাল-সবুজের যুবারা।
#
# Generated Summary:
# অনূর্ধ্ব-১৯ এশিয়া কাপের ফাইনালে দ্বিতীয়বারের মতো জায়গা করে নিয়েছে বাংলাদেশ। পাকিস্তানকে ৭ উইকেটের বড় ব্যবধানে হারিয়ে শিরোপার আরও একধাপ কাছে পৌঁছেছে লাল-সবুজের যুবারা।

# %% [markdown]
# # **ROGUE SCORE**

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.6)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.9)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 4.9 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 17.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.5 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.6)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=e6f324ab872ab94eec29eee5b1e4266271f9b2a558867481a3b7e8aa4978e40c
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# !pip install rouge

import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from rouge import Rouge
from csv import DictReader
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# 1000
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def rougeScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)
    # return SummaryEv
    urlCSV = '/content/' + columnName + 'CSV.csv'
    SummaryEv.to_csv(urlCSV, index=False)

    with open(urlCSV, 'r') as f:
        dict_reader = DictReader(f)
        SummaryEv_dict = list(dict_reader)

    EvJson = json.dumps(SummaryEv_dict, indent = 4)
    JSON = columnName + 'EvJson.json'
    save_file_at_dir('/content', JSON, EvJson)

    urlJSON = '/content/' + columnName + 'EvJson.json'

    with open(urlJSON) as f:
        SummaryEvData = json.load(f)
    lenS = len(SummaryEvData)
    rscore1r = 0
    rscore1p = 0
    rscore1f = 0
    rscore2r = 0
    rscore2p = 0
    rscore2f = 0
    rscorelr = 0
    rscorelp = 0
    rscorelf = 0
    rouge = Rouge()
    for i in range(lenS):
        score = rouge.get_scores(SummaryEvData[i][columnName], SummaryEvData[i]['givenSummary'])
        rscore1r = rscore1r + score[0]['rouge-1']['r']
        rscore1p = rscore1p + score[0]['rouge-1']['p']
        rscore1f = rscore1f + score[0]['rouge-1']['f']
        rscore2r = rscore2r + score[0]['rouge-2']['r']
        rscore2p = rscore2p + score[0]['rouge-2']['p']
        rscore2f = rscore2f + score[0]['rouge-2']['f']
        rscorelr = rscorelr + score[0]['rouge-l']['r']
        rscorelp = rscorelp + score[0]['rouge-l']['p']
        rscorelf = rscorelf + score[0]['rouge-l']['f']

        # rscore = [[rscore1r/lenS, rscore1p/lenS, rscore1f/lenS],
        #           [rscore2r/lenS, rscore2p/lenS, rscore2f/lenS],
        #           [rscorelr/lenS, rscorelp/lenS, rscorelf/lenS]]

    rscore = {'rouge-1': {'r': rscore1r/lenS,
                        'p': rscore1p/lenS,
                        'f': rscore1f/lenS},
                'rouge-2': {'r': rscore2r/lenS,
                        'p': rscore2p/lenS,
                        'f': rscore2f/lenS},
                'rouge-l': {'r': rscorelr/lenS,
                        'p': rscorelp/lenS,
                        'f': rscorelf/lenS}}
    return rscore

# %%
mx = rougeScore('mT5_Test_XLSum')
mx
# Out:
# {'rouge-1': {'r': 0.2858224324741305,
#   'p': 0.4022763079574901,
#   'f': 0.32701292631067724},
#  'rouge-2': {'r': 0.15343618307671766,
#   'p': 0.2252965843709617,
#   'f': 0.17789355071520305},
#  'rouge-l': {'r': 0.24731278047399258,
#   'p': 0.3450585336184347,
#   'f': 0.2819551246507711}}

# %%
def getScore(m, n, x):
    strs = 'rouge-'+str(n)
    return m[strs][x]

# %%
data = {'columns':['rouge-1 r', 'rouge-1 p', 'rouge-1 f', 'rouge-2 r', 'rouge-2 p', 'rouge-2 f', 'rouge-l r', 'rouge-l p', 'rouge-l f'],
        'mT5_Test_XLSum':[getScore(mx, 1, 'r'), getScore(mx, 1, 'p'), getScore(mx, 1, 'f'), getScore(mx, 2, 'r'), getScore(mx, 2, 'p'), getScore(mx, 2, 'f'), getScore(mx, 'l', 'r'), getScore(mx, 'l', 'p'), getScore(mx, 'l', 'f')],
       }

rougeDf = pd.DataFrame(data)
rougeDf_ = rougeDf
rougeDf = rougeDf.reset_index(drop=True).T
rougeDf = rougeDf.rename(columns=rougeDf.iloc[0]).drop(rougeDf.index[0])
rougeDf.reset_index(inplace=True)
rougeDf = rougeDf.rename(columns = {'index':'Summary'})
rougeDf
# Out:
#           Summary rouge-1 r rouge-1 p rouge-1 f rouge-2 r rouge-2 p rouge-2 f  \
# 0  mT5_Test_XLSum  0.285822  0.402276  0.327013  0.153436  0.225297  0.177894
#
#   rouge-l r rouge-l p rouge-l f
# 0  0.247313  0.345059  0.281955

# %%
import matplotlib.pyplot as plt

# plotting graph
rougeDf.plot(x="Summary",
               y=['rouge-1 r',
                'rouge-1 p',
                'rouge-1 f',
                'rouge-2 r',
                'rouge-2 p',
                'rouge-2 f',
                'rouge-l r',
                'rouge-l p',
                'rouge-l f'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Rouge Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **BLEU SCORE**

# %%
import os
import json
from csv import DictReader

def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

genDf.to_csv('/content/bleuEvCSV.csv', index=False)

with open("/content/bleuEvCSV.csv", 'r') as f:
    dict_reader = DictReader(f)
    bleu_dict = list(dict_reader)
print(len(bleu_dict))

bleuEvJson = json.dumps(bleu_dict, indent = 4)
save_file_at_dir('/content', 'bleuEvJson.json', bleuEvJson)

with open('/content/bleuEvJson.json') as f:
  bleuData = json.load(f)
# Out:
# 500

# %%
import nltk

def bleuCorpass(columnName):
    ble1score = 0
    ble2score = 0
    ble3score = 0
    ble4score = 0
    for i in range(len(bleuData)):
        hypothesis = bleuData[i][columnName].split()
        reference = bleuData[i]['givenSummary'].split()
        references = [reference]
        list_of_references = [references]
        list_of_hypotheses = [hypothesis]
        ble1score = ble1score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(1, 0, 0, 0))
        ble2score = ble2score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.5, 0.5, 0, 0))
        ble3score = ble3score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.33, 0.33, 0.33, 0))
        ble4score = ble4score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.25, 0.25, 0.25, 0.25))

    print("Bleu 1: ", ble1score/len(bleuData),'\n')
    print("Bleu 2: ", ble2score/len(bleuData),'\n')
    print("Bleu 3: ", ble3score/len(bleuData),'\n')
    print("Bleu 4: ", ble4score/len(bleuData),'\n')

    return ble1score/len(bleuData), ble2score/len(bleuData), ble3score/len(bleuData), ble4score/len(bleuData)

# %%
print('mT5_Test_XLSum:', bleuCorpass('mT5_Test_XLSum'))
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Bleu 1:  0.23077939726266966
#
# Bleu 2:  0.17119022537730455
#
# Bleu 3:  0.12901931676291667
#
# Bleu 4:  0.09241319063597413
#
# mT5_Test_XLSum: (0.23077939726266966, 0.17119022537730455, 0.12901931676291667, 0.09241319063597413)

# %% [markdown]
# # **BERTSCORE**

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.46.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
from evaluate import load
bertscore = load("bertscore")
# Out:
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]

# %%
import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from csv import DictReader
# Out:
# 8200
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def bertScore(columnName):
    SummaryEv = genDf.filter(['text', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    bert_precision = 0
    bert_recall = 0
    bert_f1 = 0

    for i in range(lenS):
        results = bertscore.compute(predictions=[SummaryEv[columnName][i]], references=[SummaryEv['text'][i]], lang="bn")

        bert_precision = bert_precision + results['precision'][0]
        bert_recall = bert_recall + results['recall'][0]
        bert_f1 = bert_f1 + results['f1'][0]

    bert_score = {'precision': bert_precision/lenS,
                    'recall': bert_recall/lenS,
                    'f1': bert_f1/lenS}
    return bert_score

# %%
mx = bertScore('mT5_Test_XLSum')
mx
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# {'precision': 0.8152412575483322,
#  'recall': 0.6463060745000839,
#  'f1': 0.7207805389165878}

# %%
def getScore(m, x):
    strs = x
    return m[strs]

# %%
import pandas as pd

data = {'columns':['bert_precision', 'bert_recall', 'bert_f1'],
        'mT5_Test_XLSum':[getScore(mx, 'precision'), getScore(mx, 'recall'), getScore(mx, 'f1')],
       }

bertScoreDf = pd.DataFrame(data)
bertScoreDf_ = bertScoreDf
bertScoreDf = bertScoreDf.reset_index(drop=True).T
bertScoreDf = bertScoreDf.rename(columns=bertScoreDf.iloc[0]).drop(bertScoreDf.index[0])
bertScoreDf.reset_index(inplace=True)
bertScoreDf = bertScoreDf.rename(columns = {'index':'Summary'})
bertScoreDf
# Out:
#           Summary bert_precision bert_recall   bert_f1
# 0  mT5_Test_XLSum       0.815241    0.646306  0.720781

# %%
import matplotlib.pyplot as plt

# plotting graph
bertScoreDf.plot(x="Summary",
               y=['bert_precision',
                'bert_recall',
                'bert_f1'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Bert Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **WIL WER METEOR WITH GIVEN SUMMARY**

# %%
from collections import Counter

class MeteorScore:
    def __init__(self, alpha=0.5, beta=0.5, gamma=0.5):
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma

    def preprocess_sentence(self, sentence):
        words = sentence.split()
        return words

    def ngram_count(self, sentence, n):
        words = self.preprocess_sentence(sentence)
        ngrams = [tuple(words[i:i+n]) for i in range(len(words)-n+1)]
        return Counter(ngrams)

    def compute_precision(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        precision = overlap / sum(hyp_counts.values()) if sum(hyp_counts.values()) > 0 else 0
        return precision

    def compute_recall(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        recall = overlap / sum(ref_counts.values()) if sum(ref_counts.values()) > 0 else 0
        return recall

    def meteor_score(self, hypothesis, reference):
        precision = self.alpha * self.compute_precision(hypothesis, reference, 1) + (1-self.alpha) * self.compute_precision(hypothesis, reference, 2)
        recall = self.beta * self.compute_recall(hypothesis, reference, 1) + (1-self.beta) * self.compute_recall(hypothesis, reference, 2)
        fmean = (1-self.gamma) * precision + self.gamma * recall if (precision != 0 and recall != 0) else 0
        return fmean

# %%
# !pip install jiwer
import jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading jiwer-3.0.5-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.9 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.5 rapidfuzz-3.10.1

# %%
meteor = MeteorScore(alpha=0.5, beta=0.5, gamma=0.5)

def wilWerMeteorScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    wer_score = 0
    meteor_score = 0
    wil_score = 0

    for i in range(lenS):
        wer_result = jiwer.wer(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])
        meteor_result = meteor.meteor_score(SummaryEv[columnName][i], SummaryEv['givenSummary'][i])
        wil_result = jiwer.wil(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])

        wer_score = wer_score + wer_result
        meteor_score = meteor_score + meteor_result
        wil_score = wil_score + wil_result

    wilWerMeteor_score = {'METEOR': meteor_score/lenS,
                    'WER': wer_score/lenS,
                    'WIL': wil_score/lenS}

    return wilWerMeteor_score
    # return spice_score/lenS

# %%
mx = wilWerMeteorScore('mT5_finetuned_test')
mx
# Out:
# {'METEOR': 0.3694995375541737,
#  'WER': 1.1714886828484485,
#  'WIL': 0.8061316430611867}

# %%
import pandas as pd

data = {'columns':['WIL', 'METEOR', 'WER'],
        'mT5_finetuned_test':[getScore(mx, 'WIL'), getScore(mx, 'METEOR'), getScore(mx, 'WER')],
       }

threeScoreDf = pd.DataFrame(data)
threeScoreDf_ = threeScoreDf
threeScoreDf = threeScoreDf.reset_index(drop=True).T
threeScoreDf = threeScoreDf.rename(columns=threeScoreDf.iloc[0]).drop(threeScoreDf.index[0])
threeScoreDf.reset_index(inplace=True)
threeScoreDf = threeScoreDf.rename(columns = {'index':'Summary'})
threeScoreDf
# Out:
#               Summary       WIL  METEOR       WER
# 0  mT5_finetuned_test  0.806132  0.3695  1.171489

# %%
import matplotlib.pyplot as plt

# plotting graph
threeScoreDf.plot(x="Summary",
               y=['WIL', 'METEOR', 'WER'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Three Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a bar chart
plt.figure(figsize=(12, 6))
bar_width = 0.35
x = np.arange(len(metrics))

plt.bar(x, values, width=bar_width, color='skyblue')
plt.xticks(x, metrics, rotation=45, ha='right')
plt.ylabel('Score')
plt.title('Evaluation Metrics for Text Summarization')

# Optionally add a grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a DataFrame
df = pd.DataFrame({'Metric': metrics, 'Score': values})

# Display the table
print(df)

# If you want to export the table to a CSV file
# df.to_csv('/content/summary_evaluation_metrics.csv', index=False)
# Out:
#                    Metric   Score
# 0            ROUGE-1 (F1)  0.1666
# 1            ROUGE-2 (F1)  0.0598
# 2            ROUGE-L (F1)  0.1535
# 3                  BLEU-1  0.1067
# 4                  BLEU-2  0.0529
# 5                  BLEU-3  0.0256
# 6                  BLEU-4  0.0104
# 7   BERTScore (Precision)  0.8277
# 8      BERTScore (Recall)  0.6640
# 9          BERTScore (F1)  0.7366
# 10                 METEOR  0.1642
# 11                    WER  3.1958

# %% [markdown]
# **DATA VISUALIZATION**

# %%
import matplotlib.pyplot as plt

human_lengths = genDf['givenSummary'].apply(lambda x: len(x.split()))
generated_lengths = genDf['mT5_finetuned_test'].apply(lambda x: len(x.split()))

plt.scatter(human_lengths, generated_lengths)
plt.xlabel('Human Summary Length')
plt.ylabel('Generated Summary Length')
plt.title('Human vs. Generated Summary Length')
plt.show()

# %%
gen_length = [len(summary.split()) for summary in genDf["mT5_finetuned_test"]]
ref_length = [len(summary.split()) for summary in genDf["givenSummary"]]

plt.figure(figsize=(10, 6))
plt.scatter(ref_length, gen_length, alpha=0.5)
plt.xlabel("Reference Summary Length (words)")
plt.ylabel("Generated Summary Length (words)")
plt.title("Generated vs. Reference Summary Length")
plt.plot([0, max(ref_length)], [0, max(ref_length)], color='red', linestyle='--')  # Diagonal line
plt.show()

# %% [markdown]
# # **TEST (NOT INCLUDED)**

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from normalizer import normalize  # Assuming you have this installed
import re

# Device setup
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# Load the model and tokenizer
model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Move the model to the correct device (GPU or CPU)
model.to(device)

# Define the whitespace handler
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

# Function to generate a summary
def generate_summary(input_text):
    # Normalize the text (if needed)
    input_text = normalize(input_text)

    # Tokenize the input text
    input_ids = tokenizer(
        [WHITESPACE_HANDLER(input_text)],
        return_tensors="pt",
        padding="max_length",
        max_length=512,
        truncation=True
    )["input_ids"]

    # Generate the summary
    output_ids = model.generate(
        input_ids=input_ids.to(device),
        max_length=400,
        min_length=64,
        no_repeat_ngram_size=2,
        num_beams=4
    )[0]

    # Decode the generated summary
    summary = tokenizer.decode(
        output_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return summary
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
# Example of custom input text
custom_text = """
  'ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়ার গাড়ি, বাড়ি, প্লট, ফ্ল্যাট-কী নেই। রীতিমতো গড়েছেন সম্পদের পাহাড়। শুধু নিজের
  নামেই নয়; স্ত্রী, ছেলে-মেয়ে এবং শ্যালক-শ্যালিকার নামেও গড়েছেন বিপুল সম্পত্তি।\nঅভিযোগ রয়েছে, ডিএমপিতে ‘ঘুষ’ এবং বদলি বাণিজ্যে গড়ে তুলেছেন এসব
  সম্পদ। তার বিপুল সম্পদের বিষয়ে অনুসন্ধান চালাচ্ছে দুর্নীতি দমন কমিশন (দুকক)। যুগান্তরের অনুসন্ধানি প্রতিবেদনে এসব তথ্য ওঠে এসেছে।\nপ্রতিবেদনে জানা যায়,
  রাজধানীর অভিজাত এলাকা সিদ্ধেশ্বরীর ভিকারুননিসা স্কুলের পাশেই রূপায়ণ স্বপ্ন নিলয়। ৫৫/১ হোল্ডিংয়ে আলিশান এ ভবনটি ১১ তলা। এখানে প্রায় সাড়ে ৩ হাজার বর্গফিটের
  একটি ফ্ল্যাট রয়েছে আছাদুজ্জামানের মেয়ে আয়েশা সিদ্দিকার নামে।\nশুক্রবার (২৩ আগস্ট) দুপুরে সেখানে গেলে নিরাপত্তা ইনচার্জ আবুল কালাম আজাদ যুগান্তরকে
   বলেন, তিনি মাস দেড়েক আগে এখানে চাকরি নিয়েছেন। এই ভবনে ১৩০টি ফ্ল্যাট। তাই সব ফ্ল্যাট মালিককে ভালোভাবে চিনেন না। বাড়ির ম্যানেজার সোহেল পারভেজ
    বিস্তারিত বলতে পারবেন বলে জানান তিনি।\nএ বিষয়ে সোহেল পারভেজ জানান, আয়েশা সিদ্দিকার নামে এখানে একটি ফ্ল্যাট আছে। তবে তিনি কখনো এখানে আসেন না।
    এটি ভাড়া দেওয়া আছে।\nধানমন্ডি ১২/এ নম্বর রোডের ৬৯ নম্বর বাড়িতে রয়েছে একটি বিলাসবহুল ফ্ল্যাট। শুক্রবার দুপুরে ওই বাড়িতে যাওয়া হলে ভেতরে প্রবেশের অনুমতি
    মেলেনি। তবে নিজের নাম প্রকাশ না করার শর্তে বাড়ির একজন নিরাপত্তাকর্মী জানান, ধানমন্ডির ১২-এ রোডের ৬৯ নম্বর বাড়ির দ্বিতীয় তলার পুরো ফ্লোরটি সাবেক ডিএমপি
    কমিশনার আছাদুজ্জামান মিয়া কিনেছেন। তবে এটি তার শ্যালকের নামে।\nওই ভবনের তৃতীয় তলার ফ্ল্যাটটি চট্টগ্রাম মেট্রোপলিটন পুলিশের (সিএমপি) সাবেক কমিশনার
    ইকবাল বাহারের। এ বিষয়ে পুলিশ সদর দপ্তরের ডিআইজি কৃষ্ণপদ রায় বলেন, ‘ইকবাল বাহার হলেন আছাদুজ্জামান মিয়ার খুবই ঘনিষ্ঠ। তাই তারা দুজন একই ভবনে
    থাকতেন। আমিও একাধিকবার সেখানে গিয়েছি। আছাদুজ্জামান মিয়া কমিশনার থাকা অবস্থায় ওই ভবনে থাকতেন।’\nশুক্রবার দুপুর আড়াইটায় ইস্কাটন গার্ডেন ১৩/এ
    প্রিয়নীড়ে গিয়ে জানা যায়, সেখানে আছাদুজ্জামানের স্ত্রীর নামে একটি ফ্ল্যাট রয়েছে। বিস্তারিত জানতে চাইলে নিরাপত্তাকর্মী আব্দুস সালাম ও শাহ আলম প্রতিবেদককে
    বলেন, ‘আমরা এখানে নতুন এসেছি, তাই তেমন কিছু জানি না।’\nভবনের ম্যানেজার আজাদ আহমেদ জানান, ১৪ তলা এই ভবনে ৪০টি ফ্ল্যাট আছে। বেশিরভাগ ফ্ল্যাটই
    ২১৩৩ বর্গফুটের। ভবনের ১১ তলায় আছাদুজ্জমানের স্ত্রী আফরোজা জামানের একটি ফ্ল্যাট আছে। তবে সেখানে তিনি থাকেন না। ফ্ল্যাটটি ভাড়া দেওয়া আছে। অভ্যর্থনাকারী
    আবু বকর প্রতি মাসে ভাড়া তুলে আছাদুজ্জামানের কাছে দিয়ে আসেন। ভাড়া বকেয়া পড়লে বা কোনো সমস্যা হলে আমি নিজে স্যারের সঙ্গে (আছাদুজ্জমান) যোগাযোগ
    করেন বলে জানান তিনি।\nখোঁজ নিয়ে জানা যায়, নিকুঞ্জ-১ এর ৮/এ রোডের ৬ নম্বর বাড়িটি আছাদুজ্জামানের ছোট ছেলে আসিফ মাহাদীনের নামে। শুক্রবার বিকালে
    সেখানে যাওয়া হলে বাড়িটি ভেতর থেকে বন্ধ পাওয়া যায়। বেশ কয়েকবার কলিংবেল টিপেও সাড়া পাওয়া যাচ্ছিল না। একপর্যায়ে পাশের চার নম্বর বাড়ির গাড়িচালকের
    সঙ্গে কথা হচ্ছিল এই প্রতিবেদকের। ওই গাড়িচালক জানান, আছাদুজ্জামান সপরিবারে এই বাড়িতে থাকতেন। সরকার পতনের পর তিনি বাড়ি ছেড়ে পালিয়ে গেছেন।
    অনুসন্ধানে আরও জানা যায়, এ ছাড়া বসুন্ধরা আবাসিক এলাকার এল ব্লকের ১ নম্বর রোডের ১৬৬ এবং ১৬৭ নম্বরে ১০ কাঠার ওপর ৬ তলাবিশিষ্ট আলিশান একটি বাড়ি
    আছাদুজ্জামানের স্ত্রী আফরোজা জামানের নামে। পূর্বাচলের নিউ টাউনের ১ নম্বর সেক্টরের ৪০৬/বি নম্বর রোডে ১০ কাঠা জমি রয়েছে আছাদুজ্জামান মিয়ার নামে। ওই জমিতে
     গাড়ি রাখার শেড বানিয়ে রাখা হয়েছে। পূর্বাচলের সেক্টর ৪, রোড ১০৮-এ ৫৩ নম্বর প্লটটি আছাদুজ্জামানের স্ত্রীর নামে ছিল। ৫ কাঠার এই প্লটটি বিক্রি করে দেওয়া হয়েছে।
     আফতাবনগরে ৩ নম্বর সেক্টরে রয়েছে ২১ কাঠা জমি। সেখানে নিজের নামে ১০ কাঠা ও আত্মীয়স্বজনদের নামে রয়েছে বাকি ১১ কাঠা জমি।\nআছাদুজ্জামান
     মিয়ার স্ত্রী আফরোজা জামানের নামে ঢাকা ছাড়াও ফরিদপুর ও নারায়ণগঞ্জে বিপুল সম্পদ রয়েছে। ২০১৮ সালে তিনি রাজউক থেকে বিশেষ কোটায় একটি প্লট বরাদ্দ
     পান। অথচ রাজউকের নীতিমালা অনুযায়ী, স্বামী-স্ত্রী উভয়ের প্লট বরাদ্দ পাওয়ার সুযোগ নেই।\nজানা গেছে, গাজীপুরের কালীগঞ্জ উপজেলার চাঁদখোলা মৌজায় আফরোজা
     জামানের নামে ৬৭ শতাংশ জমি রয়েছে। ২০১৭ সালে এই জমি কেনা হয়। ওই মৌজায় তার নামে ২০১৯ সালের ৫ ফেব্রুয়ারি কেনা হয় আরও ৩৯ শতাংশ জমি। একই নামে
     ২০২০ সালে জোয়ার সাহারা মৌজায় কেনা হয় ১৫ কাঠা জমি। ওই বছর গাজীপুরের চাঁদখোলা মৌজায় ৩১ শতক জমি ক্রয় করেন আফরোজা। আফরোজা ২০১৮ সালে
     নারায়ণগঞ্জের রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ২৮ একর জমি কেনেন। ওই বছর একই মৌজায় আরও ৩২ শতক জমি কেনেন তিনি। ওই বছরই
     রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ৬০ একর জমি তার নামে কেনা হয়। পরে তা বিক্রি করে দেওয়া হয়। ২০১৯ সালে কৈয়ামসাইল-কায়েতপাড়া মৌজায়
     দশমিক ৫৭ একর জমির পাওয়ার অব অ্যাটর্নি পান আছাদুজ্জামানের স্ত্রী। এরপর ওই জমি বিক্রিও করেন।\nঅনুসন্ধানে আছাদুজ্জামান মিয়ার পরিবারের সদস্যদের মালিকানার
     দুটি কোম্পানির খোঁজ পাওয়া গেছে। এর মধ্যে একটি হলো মৌমিতা ট্রান্সপোর্ট লিমিটেড। এর চেয়ারম্যান আছাদুজ্জামানের স্ত্রী আফরোজা। আছাদুজ্জামান ডিএমপি কমিশনার
     থাকাকালীন রাজধানীর রুট পারমিট কমিটির প্রধান ছিলেন। ওই সময় মৌমিতা পরিবহণকে রুট পারমিট দেওয়া হয়। মৌমিতা ট্রান্সপোর্ট লিমিটেডের ভাইস চেয়ারম্যান হারিসুর
     রহমান সোহান হলেন আছাদুজ্জামানের শ্যালক। সোহানের নামে রাজধানীর নিউমার্কেটে আছে স্বর্ণের দোকান।\nআরও জানা যায়, শেপিয়ার্ড কনসোর্টিয়াম লিমিটেড নামে
     আরেকটি কোম্পানির চেয়ারম্যান আফরোজা জামান। এই কোম্পানির পরিচালক আছাদুজ্জামানের বড় ছেলে আসিফ শাহাদাত। আছাদুজ্জামানের শ্যালক নূর আলম ওরফে
     মিলনের নামে গাজীপুরের শ্রীপুরে দেড় একর জমি রয়েছে। ভাগনে কলমের নামেও গাজীপুরে জমি আছে দেড় একর।\nএদিকে আছাদুজ্জামান মিয়ার অবৈধ সম্পদের
     অনুসন্ধান শুরু করেছে দুদক। সংস্থাটির সচিব খোরশেদা ইয়াসমীন গণমাধ্যমকে বলেন, আছাদুজ্জামান মিয়ার বিরুদ্ধে বিভিন্ন অনিয়ম ও দুর্নীতির মাধ্যমে কোটি কোটি
     টাকার অবৈধ সম্পদ অর্জনের অভিযোগ এসেছে। এই অভিযোগ অনুসন্ধানের সিদ্ধান্ত গৃহীত হয়েছে বলে জানান তিনি।\nআওয়ামী লীগ সরকারের পতনের কয়েকদিন আগে
     আছাদুজ্জামান মিয়া জানিয়েছিলেন, তার এবং পরিবারের সদস্যদের কোনো অবৈধ সম্পদ নেই। যেসব সম্পদ আছে সবই আয়কর বিবরণীতে উল্লেখ করা আছে। সরকারের
     কোনো সংস্থা যদি এসব সম্পদের বিষয়ে অনুসন্ধান চালায় তাহলে তিনি ও তার পরিবারের সদস্যরা ওই সংস্থাকে সহযোগিতা করবেন।'
"""

# Generate the summary for the custom input text
generated_summary = generate_summary(custom_text)

# Print the original text and its generated summary
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়া রীতিমতো গড়েছেন বিপুল সম্পত্তি। তার গাড়ি, বাড়ি, প্লট এবং ফ্ল্যাট-কী নেই। অনুসন্ধানে এসব তথ্য উঠে এসেছে।

# %%
custom_text2 = """
বাংলাদেশের অর্থনৈতিক অবস্থা উন্নতির দিকে ধাবিত হচ্ছে, বিশেষ করে গত কয়েক বছরে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।
অর্থনীতিবিদরা মনে করছেন, এই অগ্রগতি ধরে রাখতে পারলে বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার অন্যতম শক্তিশালী অর্থনীতিতে পরিণত হতে পারে।
"""

generated_summary = generate_summary(custom_text2)
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার সবচেয়ে শক্তিশালী দেশগুলোর একটি হিসেবে পরিণত হতে পারে বলে মনে করছেন অর্থনৈতিক বিশ্লেষকরা। এর মধ্যে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।
